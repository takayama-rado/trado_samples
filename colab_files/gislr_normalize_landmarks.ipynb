# %% [markdown]
# <a href="https://colab.research.google.com/github/takayama-rado/trado_samples/blob/main/colab_files/gislr_normalize_landmarks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Download dataset and modules

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Copy to local.
# !cp drive/MyDrive/Datasets/gislr_dataset_top10.zip gislr_top10.zip

# %%
# !unzip -o gislr_top10.zip
# Out:
# Archive:  gislr_top10.zip
#    creating: dataset_top10/
#   inflating: dataset_top10/16069.hdf5
#   inflating: dataset_top10/18796.hdf5
#   inflating: dataset_top10/2044.hdf5
#   inflating: dataset_top10/22343.hdf5
#   inflating: dataset_top10/25571.hdf5
#   inflating: dataset_top10/26734.hdf5
#   inflating: dataset_top10/27610.hdf5
#   inflating: dataset_top10/28656.hdf5
#   inflating: dataset_top10/29302.hdf5
#   inflating: dataset_top10/30680.hdf5
#   inflating: dataset_top10/32319.hdf5
#   inflating: dataset_top10/34503.hdf5
#   inflating: dataset_top10/36257.hdf5
#   inflating: dataset_top10/37055.hdf5
#   inflating: dataset_top10/37779.hdf5
#   inflating: dataset_top10/4718.hdf5
#   inflating: dataset_top10/49445.hdf5
#   inflating: dataset_top10/53618.hdf5
#   inflating: dataset_top10/55372.hdf5
#   inflating: dataset_top10/61333.hdf5
#   inflating: dataset_top10/62590.hdf5
#   inflating: dataset_top10/LICENSE.txt
#   inflating: dataset_top10/sign_to_prediction_index_map.json

# %%
# !ls dataset_top10
# Out:
# 16069.hdf5  25571.hdf5	29302.hdf5  36257.hdf5	49445.hdf5  62590.hdf5
# 18796.hdf5  26734.hdf5	30680.hdf5  37055.hdf5	53618.hdf5  LICENSE.txt
# 2044.hdf5   27610.hdf5	32319.hdf5  37779.hdf5	55372.hdf5  sign_to_prediction_index_map.json
# 22343.hdf5  28656.hdf5	34503.hdf5  4718.hdf5	61333.hdf5

# %%
# !cat dataset_top10/sign_to_prediction_index_map.json
# Out:
# {
#     "listen": 0,
#     "look": 1,
#     "shhh": 2,
#     "donkey": 3,
#     "mouse": 4,
#     "duck": 5,
#     "uncle": 6,
#     "hear": 7,
#     "pretend": 8,
#     "cow": 9
# }

# %%
# !cat dataset_top10/LICENSE.txt
# Out:
# The dataset provided by Natsuki Takayama (Takayama Research and Development Office) is licensed under CC-BY 4.0.
# Author: Copyright 2024 Natsuki Takayama
# Title: GISLR Top 10 dataset
# Original licenser: Deaf Professional Arts Network and the Georgia Institute of Technology
# Modification
# - Extract 10 most frequent words.
# - Packaged into HDF5 format.

# %%
import h5py
with h5py.File("dataset_top10/16069.hdf5", "r") as fread:
    keys = list(fread.keys())
    print(keys)
    group = fread[keys[0]]
    print(group.keys())
    feature = group["feature"][:]
    token = group["token"][:]
    print(feature.shape)
    print(token)
# Out:
# ['1109479272', '11121526', '1120349077', '1125456612', '1159046211', '1169128497', '1186032553', '1223803476', '1259708636', '1281972067', '129232566', '1334702305', '1340979012', '1352964057', '1370052047', '1383455381', '1431148933', '1435203624', '1437919781', '1458770030', '1462881097', '1469867050', '1474050058', '147607644', '1513539919', '1520635928', '1524297234', '153676122', '1537751003', '1542212461', '1551759770', '158232956', '1585855916', '1632709119', '1638742455', '1696757219', '177479476', '1779635114', '1791684792', '1801566440', '1831167282', '1867385690', '1880570146', '1901587887', '1910121429', '1919659282', '192873038', '1935012113', '1949620203', '195098847', '1983552660', '1989475963', '1998715062', '2007709802', '2036010239', '2036360025', '2046296211', '2082116372', '2098813002', '2109640010', '2121879330', '2141852087', '2148832702', '2152013823', '2166805079', '2176613834', '2184232774', '2213965523', '2249630763', '2256677805', '2263287955', '2263683020', '2264826605', '2270117351', '2281372282', '2285328250', '2322449232', '2326092712', '2336131857', '2346410171', '2405684784', '2467219838', '2473091535', '2488751095', '2515673021', '252176572', '2555449229', '2601816518', '2624310025', '2672738462', '2679264929', '2708514724', '2708544445', '2721276879', '2723773273', '2728839865', '2740241949', '2758304792', '2772051790', '2779816680', '2804441762', '2811346655', '2811646800', '2820103955', '2839681895', '2900998385', '2976200180', '2994456336', '3057994128', '3095010437', '3104317075', '3109672704', '3137179145', '3153285641', '3173321541', '3181666887', '3201889607', '3208820205', '3248401349', '3280527321', '3283246198', '3300057240', '3355963469', '3378306304', '3383637897', '3395075403', '3399503065', '3417877266', '3433092803', '347484677', '348956807', '3490841593', '3509324997', '3527069516', '3537611572', '3543711249', '3550826234', '3574700791', '3577812263', '3608551465', '3609537739', '3622960580', '3666781780', '3701422761', '3721927307', '3751410902', '3756613238', '3769544385', '3783554953', '3794712078', '380369091', '3813230821', '3817572483', '3843929707', '3869664504', '3892179393', '3923913515', '3981562204', '4078929101', '4101587978', '4150900444', '4191136837', '4200829752', '4209136328', '420958416', '422113773', '42222766', '4233346443', '4233985575', '4236057556', '4252161228', '425542996', '4276854486', '4294775577', '431609031', '439844759', '446236576', '470582324', '472128010', '492897929', '537402693', '5501547', '561170018', '593416697', '631898947', '649410423', '654529993', '678960043', '699907539', '707716966', '713615518', '778875120', '792981518', '796465415', '798649922', '856068671', '923153024', '957739544', '970593849', '976754415']
# <KeysViewHDF5 ['feature', 'token']>
# (3, 23, 543)
# [1]

# %%
# !wget https://github.com/takayama-rado/trado_samples/archive/refs/tags/v0.1.zip -O master.zip
# Out:
# --2024-02-14 01:43:37--  https://github.com/takayama-rado/trado_samples/archive/master.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/takayama-rado/trado_samples/zip/main [following]
# --2024-02-14 01:43:37--  https://codeload.github.com/takayama-rado/trado_samples/zip/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.113.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.113.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [         <=>        ]  74.02M  20.5MB/s    in 3.6s
#
# 2024-02-14 01:43:41 (20.5 MB/s) - ‘master.zip’ saved [77614476]

# %%
# !unzip -o master.zip -d master
# Out:
# Archive:  master.zip
# 7e22b943e25c71297485361f0572c70517d4af91
#    creating: master/trado_samples-main/
#   inflating: master/trado_samples-main/.gitignore
#   inflating: master/trado_samples-main/LICENSE
#   inflating: master/trado_samples-main/README.md
#    creating: master/trado_samples-main/colab_files/
#  extracting: master/trado_samples-main/colab_files/.gitkeep
#   inflating: master/trado_samples-main/colab_files/exp_affine_np_einsum.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_jax_static.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_mpholistic_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_mpothers_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_jax.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_numpy.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_tensorflow.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_torch.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_jax.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_numpy_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_numpy_1.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_tensorflow.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_torch.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_access_dataset.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_normalize_landmarks.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_rnn_islr_model.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_rnn_islr_model_1.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_rnn_islr_model_2.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_rnn_islr_model_3.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_select_landmarks.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_simple_islr_model.ipynb
#    creating: master/trado_samples-main/src/
#    creating: master/trado_samples-main/src/modules_gislr/
#  extracting: master/trado_samples-main/src/modules_gislr/__init__.py
#   inflating: master/trado_samples-main/src/modules_gislr/dataset.py
#   inflating: master/trado_samples-main/src/modules_gislr/defines.py
#   inflating: master/trado_samples-main/src/modules_gislr/draw_functions.py
#   inflating: master/trado_samples-main/src/modules_gislr/layers.py
#   inflating: master/trado_samples-main/src/modules_gislr/train_functions.py
#   inflating: master/trado_samples-main/src/modules_gislr/transforms.py
#    creating: master/trado_samples-main/test_data/
#   inflating: master/trado_samples-main/test_data/finger_far0.mp4
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static.npy
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static_affine.npy
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static_interp.npy
#   inflating: master/trado_samples-main/test_data/finger_middle0.mp4
#   inflating: master/trado_samples-main/test_data/finger_near0.mp4
#   inflating: master/trado_samples-main/test_data/hand_only.mp4

# %%
# !mv master/trado_samples-0.1/src/modules_gislr .

# %%
# !rm -rf master master.zip gislr_top10.zip

# %%
# !ls
# Out:
# dataset_top10  drive  modules_gislr  sample_data

# %% [markdown]
# # 2. Load library

# %%
import json
import math
import sys
import time
from functools import partial
from pathlib import Path
from typing import (
    Any,
    Dict
)

# Third party's modules
import numpy as np

import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import (
    DataLoader)

from torchvision.transforms import Compose

# Local modules
sys.path.append("modules_gislr")
from modules_gislr.dataset import (
    HDF5Dataset,
    merge_padded_batch)
from modules_gislr.defines import (
    get_fullbody_landmarks,
    get_parts_connections
)
from modules_gislr.train_functions import (
    test_loop,
    train_loop,
    val_loop
)
from modules_gislr.draw_functions import (
    draw_tracking,
    showvideo_on_browser
)
from modules_gislr.layers import (
    SimpleISLR
)
from modules_gislr.transforms import (
    ReplaceNan,
    SelectLandmarksAndFeature,
    ToTensor
)

# %% [markdown]
# # 3. Implement preprocess

# %%
class PartsBasedNormalization():
    def __init__(self,
                 face_head=0, face_num=76, face_origin=[0, 2], face_unit1=[7], face_unit2=[42],
                 lhand_head=76, lhand_num=21, lhand_origin=[0, 2, 5, 9, 13, 17], lhand_unit1=[0], lhand_unit2=[2, 5, 9, 13, 17],
                 pose_head=76+21, pose_num=12, pose_origin=[0, 1], pose_unit1=[0], pose_unit2=[1],
                 rhand_head=76+21+12, rhand_num=21, rhand_origin=[0, 2, 3, 9, 13, 17], rhand_unit1=[0], rhand_unit2=[2, 5, 9, 13, 17],
                 align_mode="framewise", scale_mode="framewise") -> None:
        assert align_mode in ["framewise", "unique"]
        assert scale_mode in ["framewise", "unique", "none"]
        self.align_mode = align_mode
        self.scale_mode = scale_mode

        self.face_head = face_head
        self.face_num = face_num
        self.face_origin = face_origin
        self.face_unit1 = face_unit1
        self.face_unit2 = face_unit2

        self.lhand_head = lhand_head
        self.lhand_num = lhand_num
        self.lhand_origin = lhand_origin
        self.lhand_unit1 = lhand_unit1
        self.lhand_unit2 = lhand_unit2

        self.pose_head = pose_head
        self.pose_num = pose_num
        self.pose_origin = pose_origin
        self.pose_unit1 = pose_unit1
        self.pose_unit2 = pose_unit2

        self.rhand_head = rhand_head
        self.rhand_num = rhand_num
        self.rhand_origin = rhand_origin
        self.rhand_unit1 = rhand_unit1
        self.rhand_unit2 = rhand_unit2

    def _gen_tmask(self, feature):
        tmask = feature == 0.0
        tmask = np.all(tmask, axis=(0, 2))
        tmask = np.logical_not(tmask.reshape([1, -1, 1]))
        return tmask

    def _calc_origin(self, feature, origin_lm):
        # `[C, T, J] -> [C, T, 1]`
        origin = feature[:, :, origin_lm].mean(axis=-1, keepdims=True)
        if self.align_mode == "unique":
            # `[C, T, 1] -> [C, 1, 1]`
            mask = self._gen_tmask(origin)
            mask = mask.reshape([mask.shape[1]])
            if mask.any():
                origin = origin[:, mask, :].mean(axis=1, keepdims=True)
            else:
                origin = np.array([0.] * feature.shape[0]).reshape([-1, 1, 1])
        return origin

    def _calc_unit(self, feature, unit_lm1, unit_lm2, unit_range):
        if self.scale_mode == "none":
            return 1.0
        # The frame-wise unit lengths are unstable.
        # So, we calculate average unit length.
        # Extract.
        # `[C, T, J] -> [C, T, 1]`
        unit1 = feature[:, :, unit_lm1].mean(axis=-1)
        unit2 = feature[:, :, unit_lm2].mean(axis=-1)
        # Mean square between target points.
        unit = np.sqrt((unit1 - unit2) ** 2)
        # Norm.
        # `[C, T, J] -> [1, T, 1]`
        unit = np.linalg.norm(unit, axis=0)
        if self.scale_mode == "framewise":
            unit = unit.reshape([1, unit.shape[0], 1])
            unit[unit <= 0] = 1.0
            unit[np.isnan(unit)] = 1.0
        else:
            # Calculate average removing undetected frame.
            mask = unit > 0
            if mask.sum() > 0:
                unit = unit[unit > 0].mean()
            else:
                unit = 1.0
            unit = 1.0 if np.isnan(unit).any() else unit
        # Finally, clip extreme values.
        unit = np.clip(unit, a_min=unit_range[0], a_max=unit_range[1])
        return unit

    def _normalize(self, feature, origin_lm, unit_lm1, unit_lm2,
                   unit_range=[1.0e-3, 5.0]):
        tmask = self._gen_tmask(feature)
        origin = self._calc_origin(feature, origin_lm)
        unit = self._calc_unit(feature, unit_lm1, unit_lm2, unit_range)

        _feature = feature - origin
        _feature = _feature / unit
        _feature = _feature * tmask
        return _feature

    def __call__(self,
                 data: Dict[str, Any]) -> Dict[str, Any]:
        feature = data["feature"]
        if self.face_num > 0:
            face = feature[:, :, self.face_head: self.face_head+self.face_num]
            face = self._normalize(face, self.face_origin,
                                   self.face_unit1, self.face_unit2)
            feature[:, :, self.face_head: self.face_head+self.face_num] = face
        if self.lhand_num > 0:
            lhand = feature[:, :, self.lhand_head: self.lhand_head+self.lhand_num]
            lhand = self._normalize(lhand, self.lhand_origin,
                                    self.lhand_unit1, self.lhand_unit2)
            feature[:, :, self.lhand_head: self.lhand_head+self.lhand_num] = lhand
        if self.pose_num > 0:
            pose = feature[:, :, self.pose_head: self.pose_head+self.pose_num]
            pose = self._normalize(pose, self.pose_origin,
                                   self.pose_unit1, self.pose_unit2)
            feature[:, :, self.pose_head: self.pose_head+self.pose_num] = pose
        if self.rhand_num > 0:
            rhand = feature[:, :, self.rhand_head: self.rhand_head+self.rhand_num]
            rhand = self._normalize(rhand, self.rhand_origin,
                                    self.rhand_unit1, self.rhand_unit2)
            feature[:, :, self.rhand_head: self.rhand_head+self.rhand_num] = rhand
        data["feature"] = feature
        return data

# %%
# Access check.
dataset_dir = Path("dataset_top10")
files = list(dataset_dir.iterdir())
dictionary = [fin for fin in files if ".json" in fin.name][0]
hdf5_files = [fin for fin in files if ".hdf5" in fin.name]

print(dictionary)
print(hdf5_files)
# Out:
# dataset_top10/sign_to_prediction_index_map.json
# [PosixPath('dataset_top10/55372.hdf5'), PosixPath('dataset_top10/27610.hdf5'), PosixPath('dataset_top10/37779.hdf5'), PosixPath('dataset_top10/2044.hdf5'), PosixPath('dataset_top10/36257.hdf5'), PosixPath('dataset_top10/53618.hdf5'), PosixPath('dataset_top10/32319.hdf5'), PosixPath('dataset_top10/37055.hdf5'), PosixPath('dataset_top10/4718.hdf5'), PosixPath('dataset_top10/25571.hdf5'), PosixPath('dataset_top10/18796.hdf5'), PosixPath('dataset_top10/29302.hdf5'), PosixPath('dataset_top10/34503.hdf5'), PosixPath('dataset_top10/28656.hdf5'), PosixPath('dataset_top10/26734.hdf5'), PosixPath('dataset_top10/16069.hdf5'), PosixPath('dataset_top10/30680.hdf5'), PosixPath('dataset_top10/49445.hdf5'), PosixPath('dataset_top10/22343.hdf5'), PosixPath('dataset_top10/62590.hdf5'), PosixPath('dataset_top10/61333.hdf5')]

# %%
# Load dictionary.
with open(dictionary, "r") as fread:
    key2token = json.load(fread)

VOCAB = len(key2token)

# %% [markdown]
# ## Define transformations

# %%
_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
trans_select_feature = SelectLandmarksAndFeature(landmarks=use_landmarks, features=use_features)
trans_repnan = ReplaceNan()
align_mode = "framewise"

trans_align_whole = PartsBasedNormalization(
                              face_num=0,
                              lhand_num=0,
                              pose_head=0, pose_num=len(use_landmarks), pose_origin=[97, 98], pose_unit1=[97], pose_unit2=[98],
                              rhand_num=0,
                              align_mode=align_mode,
                              scale_mode="none")

trans_align_parts = PartsBasedNormalization(align_mode=align_mode, scale_mode="none")

trans_align_scale_whole = PartsBasedNormalization(
                              face_num=0,
                              lhand_num=0,
                              pose_head=0, pose_num=len(use_landmarks), pose_origin=[97, 98], pose_unit1=[97], pose_unit2=[98],
                              rhand_num=0,
                              align_mode=align_mode, scale_mode="unique")

trans_align_scale_parts = PartsBasedNormalization(align_mode=align_mode, scale_mode="unique")

# %%
pre_transforms_origin = Compose([trans_select_feature,
                                 trans_repnan])

pre_transforms_align_whole = Compose([trans_select_feature,
                                      trans_repnan,
                                      trans_align_whole])

pre_transforms_align_parts = Compose([trans_select_feature,
                                      trans_repnan,
                                      trans_align_parts])

pre_transforms_align_scale_whole = Compose([trans_select_feature,
                                           trans_repnan,
                                           trans_align_scale_whole])

pre_transforms_align_scale_parts = Compose([trans_select_feature,
                                           trans_repnan,
                                           trans_align_scale_parts])

transforms = Compose([ToTensor()])

# %% [markdown]
# ## Original landmarks

# %%
batch_size = 2
feature_shape = (len(use_features), -1, len(use_landmarks))
token_shape = (1,)
merge_fn = partial(merge_padded_batch,
                   feature_shape=feature_shape,
                   token_shape=token_shape,
                   feature_padding_val=0.0,
                   token_padding_val=0)

dataset = HDF5Dataset(hdf5_files, pre_transforms=pre_transforms_origin, transforms=transforms)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=merge_fn)
try:
    data = next(iter(dataloader))
    feature_origin = data["feature"]

    print(feature_origin.shape)
except Exception as inst:
    print(inst)
# Out:
# torch.Size([2, 2, 25, 130])

# %% [markdown]
# ## Aligned landmarks (whole body)

# %%
batch_size = 2
feature_shape = (len(use_features), -1, len(use_landmarks))
token_shape = (1,)
merge_fn = partial(merge_padded_batch,
                   feature_shape=feature_shape,
                   token_shape=token_shape,
                   feature_padding_val=0.0,
                   token_padding_val=0)

dataset = HDF5Dataset(hdf5_files, pre_transforms=pre_transforms_align_whole, transforms=transforms)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=merge_fn)
try:
    data = next(iter(dataloader))
    feature_align_w = data["feature"]

    print(feature_align_w.shape)
except Exception as inst:
    print(inst)
# Out:
# torch.Size([2, 2, 25, 130])

# %% [markdown]
# ## Aligned landmarks (parts-based)

# %%
batch_size = 2
feature_shape = (len(use_features), -1, len(use_landmarks))
token_shape = (1,)
merge_fn = partial(merge_padded_batch,
                   feature_shape=feature_shape,
                   token_shape=token_shape,
                   feature_padding_val=0.0,
                   token_padding_val=0)

dataset = HDF5Dataset(hdf5_files, pre_transforms=pre_transforms_align_parts, transforms=transforms)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=merge_fn)
try:
    data = next(iter(dataloader))
    feature_align_p = data["feature"]

    print(feature_align_p.shape)
except Exception as inst:
    print(inst)
# Out:
# torch.Size([2, 2, 25, 130])

# %% [markdown]
# ## Aligned and scaled landmarks (whole body)

# %%
batch_size = 2
feature_shape = (len(use_features), -1, len(use_landmarks))
token_shape = (1,)
merge_fn = partial(merge_padded_batch,
                   feature_shape=feature_shape,
                   token_shape=token_shape,
                   feature_padding_val=0.0,
                   token_padding_val=0)

dataset = HDF5Dataset(hdf5_files, pre_transforms=pre_transforms_align_scale_whole, transforms=transforms)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=merge_fn)
try:
    data = next(iter(dataloader))
    feature_align_scale_w = data["feature"]

    print(feature_align_scale_w.shape)
except Exception as inst:
    print(inst)
# Out:
# torch.Size([2, 2, 25, 130])

# %% [markdown]
# ## Aligned and scaled landmarks (parts-based)

# %%
batch_size = 2
feature_shape = (len(use_features), -1, len(use_landmarks))
token_shape = (1,)
merge_fn = partial(merge_padded_batch,
                   feature_shape=feature_shape,
                   token_shape=token_shape,
                   feature_padding_val=0.0,
                   token_padding_val=0)

dataset = HDF5Dataset(hdf5_files, pre_transforms=pre_transforms_align_scale_parts, transforms=transforms)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=merge_fn)
try:
    data = next(iter(dataloader))
    feature_align_scale_p = data["feature"]

    print(feature_align_scale_p.shape)
except Exception as inst:
    print(inst)
# Out:
# torch.Size([2, 2, 25, 130])

# %% [markdown]
# # 4. Check normalized landmarks

# %%
feature_origin = feature_origin.detach().cpu().numpy()
feature_align_w = feature_align_w.detach().cpu().numpy()
feature_align_p = feature_align_p.detach().cpu().numpy()
feature_align_scale_w = feature_align_scale_w.detach().cpu().numpy()
feature_align_scale_p = feature_align_scale_p.detach().cpu().numpy()

_, use_landmarks = get_fullbody_landmarks()
_, face_connections = get_parts_connections(use_landmarks, "face")
_, lhand_connections = get_parts_connections(use_landmarks, "lhand")
_, pose_connections = get_parts_connections(use_landmarks, "pose")
_, rhand_connections = get_parts_connections(use_landmarks, "rhand")

# %% [markdown]
# ## Original landmarks

# %%
outpath = "./track_origin.mp4"
draw_tracking(feature_origin, outpath,
              face_connections=face_connections,
              lhand_connections=lhand_connections,
              pose_connections=pose_connections,
              rhand_connections=rhand_connections,
              channel_first=True)
# Out:
# Window size: 689 752
# Offsets: 72 0

# %%
# The MP4 file generated by OpenCV can not display correctly.
# So I convert it into WEBM file.
# !ffmpeg -i track_origin.mp4 -vcodec vp9 -y track_origin.webm
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'track_origin.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:00.83, start: 0.000000, bitrate: 4271 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 688x752 [SAR 1:1 DAR 43:47], 4265 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> vp9 (libvpx-vp9))
# Press [q] to stop, [?] for help
# [libvpx-vp9 @ 0x561894a4a580] v1.11.0
# [libvpx-vp9 @ 0x561894a4a580] Neither bitrate nor constrained quality specified, using default CRF of 32
# Output #0, webm, to 'track_origin.webm':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: vp9, yuv420p(progressive), 688x752 [SAR 1:1 DAR 43:47], q=2-31, 30 fps, 1k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libvpx-vp9
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   25 fps=8.1 q=0.0 Lsize=      93kB time=00:00:00.80 bitrate= 949.9kbits/s speed=0.26x
# video:92kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.963917%

# %%
showvideo_on_browser(outpath.replace(".mp4", ".webm"))
# Out:
# <video width=500 height=500 controls><source src="data:video/mp4;base64,..."type="video/mp4" /></video>

# %% [markdown]
# ## Aligned landmarks (whole body)

# %%
outpath = "./track_align_w.mp4"
draw_tracking(feature_align_w, outpath,
              face_connections=face_connections,
              lhand_connections=lhand_connections,
              pose_connections=pose_connections,
              rhand_connections=rhand_connections,
              channel_first=True)
# Out:
# Window size: 782 853
# Offsets: 282 353

# %%
# The MP4 file generated by OpenCV can not display correctly.
# So I convert it into WEBM file.
# !ffmpeg -i track_align_w.mp4 -vcodec vp9 -y track_align_w.webm
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'track_align_w.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:00.83, start: 0.000000, bitrate: 2619 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 782x852 [SAR 1:1 DAR 391:426], 2612 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> vp9 (libvpx-vp9))
# Press [q] to stop, [?] for help
# [libvpx-vp9 @ 0x5aea1ccf5800] v1.11.0
# [libvpx-vp9 @ 0x5aea1ccf5800] Neither bitrate nor constrained quality specified, using default CRF of 32
# Output #0, webm, to 'track_align_w.webm':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: vp9, yuv420p(progressive), 782x852 [SAR 1:1 DAR 391:426], q=2-31, 30 fps, 1k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libvpx-vp9
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   25 fps=6.4 q=0.0 Lsize=      72kB time=00:00:00.80 bitrate= 732.2kbits/s speed=0.207x
# video:71kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.252745%

# %%
showvideo_on_browser(outpath.replace(".mp4", ".webm"))
# Out:
# <video width=500 height=500 controls><source src="data:video/mp4;base64,..."type="video/mp4" /></video>

# %% [markdown]
# ## Aligned landmarks (parts-based)

# %%
outpath = "./track_align_p.mp4"
draw_tracking(feature_align_p, outpath,
              face_connections=face_connections,
              lhand_connections=lhand_connections,
              pose_connections=pose_connections,
              rhand_connections=rhand_connections,
              channel_first=True)
# Out:
# Window size: 782 719
# Offsets: 282 219

# %%
# The MP4 file generated by OpenCV can not display correctly.
# So I convert it into WEBM file.
# !ffmpeg -i track_align_p.mp4 -vcodec vp9 -y track_align_p.webm
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'track_align_p.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:00.83, start: 0.000000, bitrate: 2831 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 782x718 [SAR 1:1 DAR 391:359], 2824 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> vp9 (libvpx-vp9))
# Press [q] to stop, [?] for help
# [libvpx-vp9 @ 0x580378623940] v1.11.0
# [libvpx-vp9 @ 0x580378623940] Neither bitrate nor constrained quality specified, using default CRF of 32
# Output #0, webm, to 'track_align_p.webm':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: vp9, yuv420p(progressive), 782x718 [SAR 1:1 DAR 391:359], q=2-31, 30 fps, 1k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libvpx-vp9
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   25 fps= 11 q=0.0 Lsize=      73kB time=00:00:00.80 bitrate= 747.9kbits/s speed=0.352x
# video:72kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.226107%

# %%
showvideo_on_browser(outpath.replace(".mp4", ".webm"))
# Out:
# <video width=500 height=500 controls><source src="data:video/mp4;base64,..."type="video/mp4" /></video>

# %% [markdown]
# ## Aligned and scaled landmarks (whole body)

# %%
outpath = "./track_align_scale_w.mp4"
draw_tracking(feature_align_scale_w, outpath,
              face_connections=face_connections,
              lhand_connections=lhand_connections,
              pose_connections=pose_connections,
              rhand_connections=rhand_connections,
              channel_first=True)
# Out:
# Window size: 1039 1147
# Offsets: 427 534

# %%
# The MP4 file generated by OpenCV can not display correctly.
# So I convert it into WEBM file.
# !ffmpeg -i track_align_scale_w.mp4 -vcodec vp9 -y track_align_scale_w.webm
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'track_align_scale_w.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:00.83, start: 0.000000, bitrate: 4319 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1038x1146 [SAR 1:1 DAR 173:191], 4313 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> vp9 (libvpx-vp9))
# Press [q] to stop, [?] for help
# [libvpx-vp9 @ 0x5d07317d9200] v1.11.0
# [libvpx-vp9 @ 0x5d07317d9200] Neither bitrate nor constrained quality specified, using default CRF of 32
# Output #0, webm, to 'track_align_scale_w.webm':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: vp9, yuv420p(progressive), 1038x1146 [SAR 1:1 DAR 173:191], q=2-31, 30 fps, 1k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libvpx-vp9
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   25 fps=4.5 q=0.0 Lsize=     110kB time=00:00:00.80 bitrate=1125.4kbits/s speed=0.146x
# video:109kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.811437%

# %%
showvideo_on_browser(outpath.replace(".mp4", ".webm"))
# Out:
# <video width=500 height=500 controls><source src="data:video/mp4;base64,..."type="video/mp4" /></video>

# %% [markdown]
# ## Aligned and scaled landmarks (parts-based)

# %%
outpath = "./track_align_scale_p.mp4"
draw_tracking(feature_align_scale_p, outpath,
              face_connections=face_connections,
              lhand_connections=lhand_connections,
              pose_connections=pose_connections,
              rhand_connections=rhand_connections,
              channel_first=True)
# Out:
# Window size: 1481 1345
# Offsets: 869 732

# %%
# The MP4 file generated by OpenCV can not display correctly.
# So I convert it into WEBM file.
# !ffmpeg -i track_align_scale_p.mp4 -vcodec vp9 -y track_align_scale_p.webm
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'track_align_scale_p.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:00.83, start: 0.000000, bitrate: 13794 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1480x1344 [SAR 1:1 DAR 185:168], 13796 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> vp9 (libvpx-vp9))
# Press [q] to stop, [?] for help
# [libvpx-vp9 @ 0x567d03b63200] v1.11.0
# [libvpx-vp9 @ 0x567d03b63200] Neither bitrate nor constrained quality specified, using default CRF of 32
# Output #0, webm, to 'track_align_scale_p.webm':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: vp9, yuv420p(progressive), 1480x1344 [SAR 1:1 DAR 185:168], q=2-31, 30 fps, 1k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libvpx-vp9
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   25 fps=3.2 q=0.0 Lsize=     344kB time=00:00:00.80 bitrate=3518.7kbits/s speed=0.103x
# video:343kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.259537%

# %%
showvideo_on_browser(outpath.replace(".mp4", ".webm"))
# Out:
# <video width=500 height=500 controls><source src="data:video/mp4;base64,..."type="video/mp4" /></video>

# %% [markdown]
# # 5. Train and evaluation

# %%
# Set common parameters.
batch_size = 32
load_into_ram = True
test_pid = 16069
num_workers = 1

epochs = 50
eval_every_n_epochs = 1
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} for computation.")

train_hdf5files = [fin for fin in hdf5_files if str(test_pid) not in fin.name]
val_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]
test_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]

_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
# Out:
# Using cpu for computation.

# %% [markdown]
# ## Train with original landmarks (selection only).

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_origin))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_origin,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_origin,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_origin,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_origin = np.array(val_losses)
test_accs_origin = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_origin.min()} at {np.argmin(val_losses_origin)+1} epoch.")
print(f"Maximum accuracy:{test_accs_origin.max()} at {np.argmax(test_accs_origin)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.356348 [    0/ 3881]
# loss:2.297624 [ 3200/ 3881]
# Done. Time:3.5659432879999997
# Training performance:
#  Avg loss:2.279566
#
# Start validation.
# Done. Time:0.25713910199999646
# Validation performance:
#  Avg loss:2.272972
#
# Start evaluation.
# Done. Time:0.7603478389999907
# Test performance:
#  Accuracy:14.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.290614 [    0/ 3881]
# loss:2.279571 [ 3200/ 3881]
# Done. Time:2.7809176269999796
# Training performance:
#  Avg loss:2.225771
#
# Start validation.
# Done. Time:0.25208281999999826
# Validation performance:
#  Avg loss:2.241768
#
# Start evaluation.
# Done. Time:0.761988888000019
# Test performance:
#  Accuracy:18.0%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:2.226365 [    0/ 3881]
# loss:2.251472 [ 3200/ 3881]
# Done. Time:2.7381543770000007
# Training performance:
#  Avg loss:2.174607
#
# Start validation.
# Done. Time:0.25373172299998714
# Validation performance:
#  Avg loss:2.209662
#
# Start evaluation.
# Done. Time:0.9240426309999918
# Test performance:
#  Accuracy:20.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:2.159692 [    0/ 3881]
# loss:2.222849 [ 3200/ 3881]
# Done. Time:3.9341360040000097
# Training performance:
#  Avg loss:2.128707
#
# Start validation.
# Done. Time:0.26681357199998956
# Validation performance:
#  Avg loss:2.180092
#
# Start evaluation.
# Done. Time:0.7802540650000083
# Test performance:
#  Accuracy:21.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:2.099068 [    0/ 3881]
# loss:2.197053 [ 3200/ 3881]
# Done. Time:2.762855578
# Training performance:
#  Avg loss:2.087854
#
# Start validation.
# Done. Time:0.26023264399998425
# Validation performance:
#  Avg loss:2.153628
#
# Start evaluation.
# Done. Time:0.7521026720000066
# Test performance:
#  Accuracy:22.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:2.042907 [    0/ 3881]
# loss:2.174143 [ 3200/ 3881]
# Done. Time:2.793164555000004
# Training performance:
#  Avg loss:2.053470
#
# Start validation.
# Done. Time:0.24039366200000245
# Validation performance:
#  Avg loss:2.131564
#
# Start evaluation.
# Done. Time:0.7525479040000107
# Test performance:
#  Accuracy:23.5%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.994398 [    0/ 3881]
# loss:2.152688 [ 3200/ 3881]
# Done. Time:4.323489469000009
# Training performance:
#  Avg loss:2.024218
#
# Start validation.
# Done. Time:0.2576775309999846
# Validation performance:
#  Avg loss:2.112395
#
# Start evaluation.
# Done. Time:0.7684139099999925
# Test performance:
#  Accuracy:28.5%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.954526 [    0/ 3881]
# loss:2.132439 [ 3200/ 3881]
# Done. Time:3.248979964
# Training performance:
#  Avg loss:1.998585
#
# Start validation.
# Done. Time:0.255646291000005
# Validation performance:
#  Avg loss:2.096729
#
# Start evaluation.
# Done. Time:0.7838667119999911
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.919340 [    0/ 3881]
# loss:2.115977 [ 3200/ 3881]
# Done. Time:2.9034794300000044
# Training performance:
#  Avg loss:1.977842
#
# Start validation.
# Done. Time:0.26177743400000963
# Validation performance:
#  Avg loss:2.082608
#
# Start evaluation.
# Done. Time:0.7828785259999904
# Test performance:
#  Accuracy:29.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.891042 [    0/ 3881]
# loss:2.097673 [ 3200/ 3881]
# Done. Time:4.388027391999998
# Training performance:
#  Avg loss:1.956789
#
# Start validation.
# Done. Time:0.2765636180000115
# Validation performance:
#  Avg loss:2.071163
#
# Start evaluation.
# Done. Time:0.7921107939999956
# Test performance:
#  Accuracy:29.5%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.864246 [    0/ 3881]
# loss:2.081398 [ 3200/ 3881]
# Done. Time:2.883658324999999
# Training performance:
#  Avg loss:1.939414
#
# Start validation.
# Done. Time:0.28292434200000116
# Validation performance:
#  Avg loss:2.061381
#
# Start evaluation.
# Done. Time:0.8753638839999951
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.841433 [    0/ 3881]
# loss:2.065105 [ 3200/ 3881]
# Done. Time:2.925423813000009
# Training performance:
#  Avg loss:1.923706
#
# Start validation.
# Done. Time:0.2675697100000036
# Validation performance:
#  Avg loss:2.053224
#
# Start evaluation.
# Done. Time:0.8152389619999951
# Test performance:
#  Accuracy:31.5%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.819113 [    0/ 3881]
# loss:2.050177 [ 3200/ 3881]
# Done. Time:4.626448111000002
# Training performance:
#  Avg loss:1.909665
#
# Start validation.
# Done. Time:0.2598157029999868
# Validation performance:
#  Avg loss:2.046365
#
# Start evaluation.
# Done. Time:0.8504319349999889
# Test performance:
#  Accuracy:30.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.798405 [    0/ 3881]
# loss:2.035678 [ 3200/ 3881]
# Done. Time:2.938741800999992
# Training performance:
#  Avg loss:1.896900
#
# Start validation.
# Done. Time:0.2871496199999797
# Validation performance:
#  Avg loss:2.041227
#
# Start evaluation.
# Done. Time:0.8396001659999968
# Test performance:
#  Accuracy:29.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:1.780466 [    0/ 3881]
# loss:2.022554 [ 3200/ 3881]
# Done. Time:3.0303900989999875
# Training performance:
#  Avg loss:1.885303
#
# Start validation.
# Done. Time:0.29283231300001944
# Validation performance:
#  Avg loss:2.036441
#
# Start evaluation.
# Done. Time:0.9452793720000159
# Test performance:
#  Accuracy:30.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.764636 [    0/ 3881]
# loss:2.010197 [ 3200/ 3881]
# Done. Time:4.96735053499998
# Training performance:
#  Avg loss:1.874432
#
# Start validation.
# Done. Time:0.2935732239999993
# Validation performance:
#  Avg loss:2.032478
#
# Start evaluation.
# Done. Time:1.0809310879999998
# Test performance:
#  Accuracy:30.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.750803 [    0/ 3881]
# loss:1.998425 [ 3200/ 3881]
# Done. Time:3.163057526999978
# Training performance:
#  Avg loss:1.864417
#
# Start validation.
# Done. Time:0.3242010989999926
# Validation performance:
#  Avg loss:2.028472
#
# Start evaluation.
# Done. Time:0.9479704199999901
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.737493 [    0/ 3881]
# loss:1.987613 [ 3200/ 3881]
# Done. Time:3.0778126109999846
# Training performance:
#  Avg loss:1.855251
#
# Start validation.
# Done. Time:0.28719932900000344
# Validation performance:
#  Avg loss:2.024196
#
# Start evaluation.
# Done. Time:1.1580657000000087
# Test performance:
#  Accuracy:30.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.725465 [    0/ 3881]
# loss:1.977499 [ 3200/ 3881]
# Done. Time:4.525172182999995
# Training performance:
#  Avg loss:1.846339
#
# Start validation.
# Done. Time:0.3003834520000055
# Validation performance:
#  Avg loss:2.020440
#
# Start evaluation.
# Done. Time:0.9868478410000137
# Test performance:
#  Accuracy:30.0%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.714822 [    0/ 3881]
# loss:1.967913 [ 3200/ 3881]
# Done. Time:3.115046853999985
# Training performance:
#  Avg loss:1.837948
#
# Start validation.
# Done. Time:0.299076542000023
# Validation performance:
#  Avg loss:2.016799
#
# Start evaluation.
# Done. Time:0.9084798889999774
# Test performance:
#  Accuracy:29.5%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.704460 [    0/ 3881]
# loss:1.958458 [ 3200/ 3881]
# Done. Time:3.2480920979999723
# Training performance:
#  Avg loss:1.829960
#
# Start validation.
# Done. Time:0.4559283940000114
# Validation performance:
#  Avg loss:2.013276
#
# Start evaluation.
# Done. Time:1.2949588729999846
# Test performance:
#  Accuracy:30.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.694562 [    0/ 3881]
# loss:1.949548 [ 3200/ 3881]
# Done. Time:4.104781384000006
# Training performance:
#  Avg loss:1.822314
#
# Start validation.
# Done. Time:0.3258734850000451
# Validation performance:
#  Avg loss:2.009713
#
# Start evaluation.
# Done. Time:1.1439085970000065
# Test performance:
#  Accuracy:30.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.685451 [    0/ 3881]
# loss:1.941023 [ 3200/ 3881]
# Done. Time:3.384808375000034
# Training performance:
#  Avg loss:1.814859
#
# Start validation.
# Done. Time:0.3117127120000305
# Validation performance:
#  Avg loss:2.006310
#
# Start evaluation.
# Done. Time:1.1327324029999772
# Test performance:
#  Accuracy:31.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.676902 [    0/ 3881]
# loss:1.932454 [ 3200/ 3881]
# Done. Time:4.443347044999996
# Training performance:
#  Avg loss:1.807632
#
# Start validation.
# Done. Time:0.49517269599999736
# Validation performance:
#  Avg loss:2.003080
#
# Start evaluation.
# Done. Time:1.348430062000034
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.668238 [    0/ 3881]
# loss:1.924631 [ 3200/ 3881]
# Done. Time:4.35613898500003
# Training performance:
#  Avg loss:1.800787
#
# Start validation.
# Done. Time:0.447174729999972
# Validation performance:
#  Avg loss:1.999094
#
# Start evaluation.
# Done. Time:1.1518741309999996
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.658416 [    0/ 3881]
# loss:1.917259 [ 3200/ 3881]
# Done. Time:3.5806552539999643
# Training performance:
#  Avg loss:1.793424
#
# Start validation.
# Done. Time:0.43516736600003014
# Validation performance:
#  Avg loss:1.996623
#
# Start evaluation.
# Done. Time:1.3264173970000002
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.652094 [    0/ 3881]
# loss:1.910058 [ 3200/ 3881]
# Done. Time:3.746142034000002
# Training performance:
#  Avg loss:1.787371
#
# Start validation.
# Done. Time:0.3013853749999953
# Validation performance:
#  Avg loss:1.993288
#
# Start evaluation.
# Done. Time:0.9047845519999669
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.645045 [    0/ 3881]
# loss:1.902969 [ 3200/ 3881]
# Done. Time:3.202218550999987
# Training performance:
#  Avg loss:1.780895
#
# Start validation.
# Done. Time:0.28107817199997953
# Validation performance:
#  Avg loss:1.990171
#
# Start evaluation.
# Done. Time:0.9265222780000499
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:1.637528 [    0/ 3881]
# loss:1.896049 [ 3200/ 3881]
# Done. Time:3.598284036999985
# Training performance:
#  Avg loss:1.774548
#
# Start validation.
# Done. Time:0.46548517200000106
# Validation performance:
#  Avg loss:1.987122
#
# Start evaluation.
# Done. Time:1.3689462869999716
# Test performance:
#  Accuracy:33.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.629647 [    0/ 3881]
# loss:1.889449 [ 3200/ 3881]
# Done. Time:3.399806366000007
# Training performance:
#  Avg loss:1.768347
#
# Start validation.
# Done. Time:0.2770085399999971
# Validation performance:
#  Avg loss:1.983989
#
# Start evaluation.
# Done. Time:0.9457244540000147
# Test performance:
#  Accuracy:33.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:1.622250 [    0/ 3881]
# loss:1.882968 [ 3200/ 3881]
# Done. Time:3.1571932370000013
# Training performance:
#  Avg loss:1.762233
#
# Start validation.
# Done. Time:0.27352968799999644
# Validation performance:
#  Avg loss:1.980861
#
# Start evaluation.
# Done. Time:0.8794882120000125
# Test performance:
#  Accuracy:33.5%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.615215 [    0/ 3881]
# loss:1.876567 [ 3200/ 3881]
# Done. Time:4.02681652900003
# Training performance:
#  Avg loss:1.756258
#
# Start validation.
# Done. Time:0.49073633800003336
# Validation performance:
#  Avg loss:1.977700
#
# Start evaluation.
# Done. Time:1.4595596850000447
# Test performance:
#  Accuracy:33.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:1.608270 [    0/ 3881]
# loss:1.870467 [ 3200/ 3881]
# Done. Time:3.2878370200000404
# Training performance:
#  Avg loss:1.750446
#
# Start validation.
# Done. Time:0.3191198470000245
# Validation performance:
#  Avg loss:1.974752
#
# Start evaluation.
# Done. Time:1.0445862239999997
# Test performance:
#  Accuracy:34.0%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:1.601041 [    0/ 3881]
# loss:1.864414 [ 3200/ 3881]
# Done. Time:3.276323228000024
# Training performance:
#  Avg loss:1.744640
#
# Start validation.
# Done. Time:0.2886797770000271
# Validation performance:
#  Avg loss:1.971840
#
# Start evaluation.
# Done. Time:1.060170443000004
# Test performance:
#  Accuracy:34.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.593915 [    0/ 3881]
# loss:1.858809 [ 3200/ 3881]
# Done. Time:5.045459699999981
# Training performance:
#  Avg loss:1.739078
#
# Start validation.
# Done. Time:0.30643982899999855
# Validation performance:
#  Avg loss:1.969182
#
# Start evaluation.
# Done. Time:1.0363361889999965
# Test performance:
#  Accuracy:34.0%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.586420 [    0/ 3881]
# loss:1.853114 [ 3200/ 3881]
# Done. Time:3.3301761029999852
# Training performance:
#  Avg loss:1.733477
#
# Start validation.
# Done. Time:0.31130646499997283
# Validation performance:
#  Avg loss:1.966370
#
# Start evaluation.
# Done. Time:1.0479888940000137
# Test performance:
#  Accuracy:34.5%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.579534 [    0/ 3881]
# loss:1.847791 [ 3200/ 3881]
# Done. Time:3.2516658210000173
# Training performance:
#  Avg loss:1.727936
#
# Start validation.
# Done. Time:0.3257792120000431
# Validation performance:
#  Avg loss:1.963674
#
# Start evaluation.
# Done. Time:1.4064009729999611
# Test performance:
#  Accuracy:34.5%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.572461 [    0/ 3881]
# loss:1.842534 [ 3200/ 3881]
# Done. Time:4.243991810999944
# Training performance:
#  Avg loss:1.722449
#
# Start validation.
# Done. Time:0.3139636399999972
# Validation performance:
#  Avg loss:1.960829
#
# Start evaluation.
# Done. Time:1.0046914509999851
# Test performance:
#  Accuracy:34.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:1.565454 [    0/ 3881]
# loss:1.837395 [ 3200/ 3881]
# Done. Time:3.2222417579999956
# Training performance:
#  Avg loss:1.717053
#
# Start validation.
# Done. Time:0.29341897699998754
# Validation performance:
#  Avg loss:1.957549
#
# Start evaluation.
# Done. Time:1.032099360000018
# Test performance:
#  Accuracy:34.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:1.559196 [    0/ 3881]
# loss:1.832126 [ 3200/ 3881]
# Done. Time:3.979719179999961
# Training performance:
#  Avg loss:1.711823
#
# Start validation.
# Done. Time:0.48738265499997624
# Validation performance:
#  Avg loss:1.954238
#
# Start evaluation.
# Done. Time:1.5419982559999994
# Test performance:
#  Accuracy:34.0%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:1.552696 [    0/ 3881]
# loss:1.827351 [ 3200/ 3881]
# Done. Time:3.4953929970000104
# Training performance:
#  Avg loss:1.706701
#
# Start validation.
# Done. Time:0.2838217439999653
# Validation performance:
#  Avg loss:1.951389
#
# Start evaluation.
# Done. Time:1.099028254000018
# Test performance:
#  Accuracy:34.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:1.546551 [    0/ 3881]
# loss:1.822555 [ 3200/ 3881]
# Done. Time:3.4383367590000375
# Training performance:
#  Avg loss:1.701525
#
# Start validation.
# Done. Time:0.28364903199997116
# Validation performance:
#  Avg loss:1.948727
#
# Start evaluation.
# Done. Time:1.034308489999944
# Test performance:
#  Accuracy:34.0%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:1.540331 [    0/ 3881]
# loss:1.817909 [ 3200/ 3881]
# Done. Time:4.861395500000015
# Training performance:
#  Avg loss:1.696352
#
# Start validation.
# Done. Time:0.31746521100001246
# Validation performance:
#  Avg loss:1.946241
#
# Start evaluation.
# Done. Time:0.9322554839999952
# Test performance:
#  Accuracy:34.5%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:1.534059 [    0/ 3881]
# loss:1.813302 [ 3200/ 3881]
# Done. Time:3.116796792999992
# Training performance:
#  Avg loss:1.691229
#
# Start validation.
# Done. Time:0.2735336279999956
# Validation performance:
#  Avg loss:1.943656
#
# Start evaluation.
# Done. Time:0.9292779030000133
# Test performance:
#  Accuracy:34.5%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:1.528158 [    0/ 3881]
# loss:1.808757 [ 3200/ 3881]
# Done. Time:3.1434185169999864
# Training performance:
#  Avg loss:1.686214
#
# Start validation.
# Done. Time:0.2843674759999999
# Validation performance:
#  Avg loss:1.941152
#
# Start evaluation.
# Done. Time:1.044487303999972
# Test performance:
#  Accuracy:34.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.522191 [    0/ 3881]
# loss:1.804157 [ 3200/ 3881]
# Done. Time:4.768790365000029
# Training performance:
#  Avg loss:1.681230
#
# Start validation.
# Done. Time:0.3017678330000422
# Validation performance:
#  Avg loss:1.939232
#
# Start evaluation.
# Done. Time:1.0438474590000055
# Test performance:
#  Accuracy:34.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:1.517498 [    0/ 3881]
# loss:1.799597 [ 3200/ 3881]
# Done. Time:3.255904745999999
# Training performance:
#  Avg loss:1.676173
#
# Start validation.
# Done. Time:0.30447767699996575
# Validation performance:
#  Avg loss:1.936356
#
# Start evaluation.
# Done. Time:0.9885340860000156
# Test performance:
#  Accuracy:34.5%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:1.510627 [    0/ 3881]
# loss:1.795353 [ 3200/ 3881]
# Done. Time:3.5140446699999757
# Training performance:
#  Avg loss:1.671321
#
# Start validation.
# Done. Time:0.507010173000026
# Validation performance:
#  Avg loss:1.934069
#
# Start evaluation.
# Done. Time:1.3896615029999566
# Test performance:
#  Accuracy:35.0%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:1.505208 [    0/ 3881]
# loss:1.792064 [ 3200/ 3881]
# Done. Time:3.9099464849999777
# Training performance:
#  Avg loss:1.670802
#
# Start validation.
# Done. Time:0.2958333820000121
# Validation performance:
#  Avg loss:1.932453
#
# Start evaluation.
# Done. Time:1.0655394890000025
# Test performance:
#  Accuracy:35.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:1.501171 [    0/ 3881]
# loss:1.786803 [ 3200/ 3881]
# Done. Time:3.2939662830000316
# Training performance:
#  Avg loss:1.661990
#
# Start validation.
# Done. Time:0.3098408880000534
# Validation performance:
#  Avg loss:1.930168
#
# Start evaluation.
# Done. Time:1.0551659070000028
# Test performance:
#  Accuracy:35.0%
# Minimum validation loss:1.9301677090781075 at 50 epoch.
# Maximum accuracy:35.0 at 48 epoch.

# %% [markdown]
# ## Train with aligned landmarks (whole body).

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_align_w))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_align_whole,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_align_whole,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_align_whole,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_align_w = np.array(val_losses)
test_accs_align_w = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_align_w.min()} at {np.argmin(val_losses_align_w)+1} epoch.")
print(f"Maximum accuracy:{test_accs_align_w.max()} at {np.argmax(test_accs_align_w)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.266660 [    0/ 3881]
# loss:2.293715 [ 3200/ 3881]
# Done. Time:4.106553527000017
# Training performance:
#  Avg loss:2.284043
#
# Start validation.
# Done. Time:0.5140109550000034
# Validation performance:
#  Avg loss:2.292828
#
# Start evaluation.
# Done. Time:1.593067220000023
# Test performance:
#  Accuracy:10.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.280219 [    0/ 3881]
# loss:2.276647 [ 3200/ 3881]
# Done. Time:3.6965262370000005
# Training performance:
#  Avg loss:2.221859
#
# Start validation.
# Done. Time:0.48324399299997367
# Validation performance:
#  Avg loss:2.250454
#
# Start evaluation.
# Done. Time:1.510210623999967
# Test performance:
#  Accuracy:12.0%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:2.199312 [    0/ 3881]
# loss:2.244865 [ 3200/ 3881]
# Done. Time:4.1622719430000075
# Training performance:
#  Avg loss:2.156565
#
# Start validation.
# Done. Time:0.31984776500002
# Validation performance:
#  Avg loss:2.187551
#
# Start evaluation.
# Done. Time:1.1575001589999943
# Test performance:
#  Accuracy:20.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:2.106647 [    0/ 3881]
# loss:2.215459 [ 3200/ 3881]
# Done. Time:3.275854723000009
# Training performance:
#  Avg loss:2.095510
#
# Start validation.
# Done. Time:0.29962105999999267
# Validation performance:
#  Avg loss:2.127509
#
# Start evaluation.
# Done. Time:0.9524007439999878
# Test performance:
#  Accuracy:30.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:2.018527 [    0/ 3881]
# loss:2.190897 [ 3200/ 3881]
# Done. Time:4.343294532000016
# Training performance:
#  Avg loss:2.040241
#
# Start validation.
# Done. Time:0.4978460490000316
# Validation performance:
#  Avg loss:2.079448
#
# Start evaluation.
# Done. Time:1.4283695679999937
# Test performance:
#  Accuracy:32.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.950322 [    0/ 3881]
# loss:2.168319 [ 3200/ 3881]
# Done. Time:3.3303054790000033
# Training performance:
#  Avg loss:1.995635
#
# Start validation.
# Done. Time:0.33402549699997053
# Validation performance:
#  Avg loss:2.047110
#
# Start evaluation.
# Done. Time:1.0659871729999963
# Test performance:
#  Accuracy:33.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.886695 [    0/ 3881]
# loss:2.148477 [ 3200/ 3881]
# Done. Time:3.3952145849999624
# Training performance:
#  Avg loss:1.958605
#
# Start validation.
# Done. Time:0.33597492500001636
# Validation performance:
#  Avg loss:2.020817
#
# Start evaluation.
# Done. Time:1.032837389000008
# Test performance:
#  Accuracy:33.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.834116 [    0/ 3881]
# loss:2.129993 [ 3200/ 3881]
# Done. Time:4.960739681000007
# Training performance:
#  Avg loss:1.928625
#
# Start validation.
# Done. Time:0.337109694999981
# Validation performance:
#  Avg loss:2.001167
#
# Start evaluation.
# Done. Time:1.1999395770000092
# Test performance:
#  Accuracy:33.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.794807 [    0/ 3881]
# loss:2.112082 [ 3200/ 3881]
# Done. Time:3.4815698890000135
# Training performance:
#  Avg loss:1.903700
#
# Start validation.
# Done. Time:0.3262127899999996
# Validation performance:
#  Avg loss:1.986226
#
# Start evaluation.
# Done. Time:1.1795021990000123
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.756680 [    0/ 3881]
# loss:2.095552 [ 3200/ 3881]
# Done. Time:4.0094792869999765
# Training performance:
#  Avg loss:1.881689
#
# Start validation.
# Done. Time:0.4641934210000045
# Validation performance:
#  Avg loss:1.972678
#
# Start evaluation.
# Done. Time:1.5430062359999965
# Test performance:
#  Accuracy:29.5%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.720138 [    0/ 3881]
# loss:2.081056 [ 3200/ 3881]
# Done. Time:3.5614926060000016
# Training performance:
#  Avg loss:1.862054
#
# Start validation.
# Done. Time:0.3501250959999993
# Validation performance:
#  Avg loss:1.962737
#
# Start evaluation.
# Done. Time:1.1047471279999854
# Test performance:
#  Accuracy:30.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.696143 [    0/ 3881]
# loss:2.066726 [ 3200/ 3881]
# Done. Time:3.414641855999946
# Training performance:
#  Avg loss:1.844368
#
# Start validation.
# Done. Time:0.29901929600003996
# Validation performance:
#  Avg loss:1.953932
#
# Start evaluation.
# Done. Time:1.1819806400000061
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.672237 [    0/ 3881]
# loss:2.051875 [ 3200/ 3881]
# Done. Time:5.133825347000027
# Training performance:
#  Avg loss:1.828312
#
# Start validation.
# Done. Time:0.37632358899998053
# Validation performance:
#  Avg loss:1.946871
#
# Start evaluation.
# Done. Time:1.0921313740000187
# Test performance:
#  Accuracy:30.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.651931 [    0/ 3881]
# loss:2.037894 [ 3200/ 3881]
# Done. Time:3.4550474330000043
# Training performance:
#  Avg loss:1.813771
#
# Start validation.
# Done. Time:0.31363521299999775
# Validation performance:
#  Avg loss:1.940722
#
# Start evaluation.
# Done. Time:1.1043873190000113
# Test performance:
#  Accuracy:30.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:1.631956 [    0/ 3881]
# loss:2.023886 [ 3200/ 3881]
# Done. Time:3.567493387000013
# Training performance:
#  Avg loss:1.800098
#
# Start validation.
# Done. Time:0.5198495719999983
# Validation performance:
#  Avg loss:1.933279
#
# Start evaluation.
# Done. Time:1.423095262000004
# Test performance:
#  Accuracy:30.0%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.616018 [    0/ 3881]
# loss:2.011008 [ 3200/ 3881]
# Done. Time:3.6630723030000354
# Training performance:
#  Avg loss:1.787615
#
# Start validation.
# Done. Time:0.31180615699997816
# Validation performance:
#  Avg loss:1.927672
#
# Start evaluation.
# Done. Time:0.9318138340000246
# Test performance:
#  Accuracy:30.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.601228 [    0/ 3881]
# loss:1.998446 [ 3200/ 3881]
# Done. Time:3.210255378999989
# Training performance:
#  Avg loss:1.775594
#
# Start validation.
# Done. Time:0.3111194100000034
# Validation performance:
#  Avg loss:1.923243
#
# Start evaluation.
# Done. Time:1.028465352000012
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.587373 [    0/ 3881]
# loss:1.986391 [ 3200/ 3881]
# Done. Time:4.280983061999962
# Training performance:
#  Avg loss:1.764345
#
# Start validation.
# Done. Time:0.4423821909999788
# Validation performance:
#  Avg loss:1.917163
#
# Start evaluation.
# Done. Time:1.2971402230000422
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.574282 [    0/ 3881]
# loss:1.973960 [ 3200/ 3881]
# Done. Time:3.1894750259999682
# Training performance:
#  Avg loss:1.753788
#
# Start validation.
# Done. Time:0.3088252420000117
# Validation performance:
#  Avg loss:1.912766
#
# Start evaluation.
# Done. Time:1.024671714999954
# Test performance:
#  Accuracy:31.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.562685 [    0/ 3881]
# loss:1.962552 [ 3200/ 3881]
# Done. Time:3.28416193999999
# Training performance:
#  Avg loss:1.743650
#
# Start validation.
# Done. Time:0.3077870920000123
# Validation performance:
#  Avg loss:1.908513
#
# Start evaluation.
# Done. Time:1.1061732840000786
# Test performance:
#  Accuracy:30.5%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.553277 [    0/ 3881]
# loss:1.951304 [ 3200/ 3881]
# Done. Time:4.842197828000053
# Training performance:
#  Avg loss:1.734013
#
# Start validation.
# Done. Time:0.29717830200002027
# Validation performance:
#  Avg loss:1.904645
#
# Start evaluation.
# Done. Time:1.0012299679999614
# Test performance:
#  Accuracy:30.5%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.542771 [    0/ 3881]
# loss:1.941657 [ 3200/ 3881]
# Done. Time:3.1864751909999995
# Training performance:
#  Avg loss:1.724795
#
# Start validation.
# Done. Time:0.2908766929999729
# Validation performance:
#  Avg loss:1.901567
#
# Start evaluation.
# Done. Time:0.8640175630000613
# Test performance:
#  Accuracy:30.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.532909 [    0/ 3881]
# loss:1.931056 [ 3200/ 3881]
# Done. Time:3.046722147999958
# Training performance:
#  Avg loss:1.715985
#
# Start validation.
# Done. Time:0.30819058899999163
# Validation performance:
#  Avg loss:1.898413
#
# Start evaluation.
# Done. Time:1.1190487329999996
# Test performance:
#  Accuracy:31.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.523600 [    0/ 3881]
# loss:1.921720 [ 3200/ 3881]
# Done. Time:4.460985315000016
# Training performance:
#  Avg loss:1.707490
#
# Start validation.
# Done. Time:0.3268014239999957
# Validation performance:
#  Avg loss:1.895721
#
# Start evaluation.
# Done. Time:1.1468463380000458
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.515553 [    0/ 3881]
# loss:1.913036 [ 3200/ 3881]
# Done. Time:3.469055676999915
# Training performance:
#  Avg loss:1.699353
#
# Start validation.
# Done. Time:0.31156668299990997
# Validation performance:
#  Avg loss:1.892883
#
# Start evaluation.
# Done. Time:1.0764923269999827
# Test performance:
#  Accuracy:31.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.507814 [    0/ 3881]
# loss:1.904731 [ 3200/ 3881]
# Done. Time:4.285680438999975
# Training performance:
#  Avg loss:1.691494
#
# Start validation.
# Done. Time:0.4616918629999418
# Validation performance:
#  Avg loss:1.890687
#
# Start evaluation.
# Done. Time:1.459008363999942
# Test performance:
#  Accuracy:31.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.500112 [    0/ 3881]
# loss:1.896330 [ 3200/ 3881]
# Done. Time:3.4821320959999866
# Training performance:
#  Avg loss:1.683864
#
# Start validation.
# Done. Time:0.5016711289999876
# Validation performance:
#  Avg loss:1.888474
#
# Start evaluation.
# Done. Time:1.440898094999966
# Test performance:
#  Accuracy:32.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.492676 [    0/ 3881]
# loss:1.888507 [ 3200/ 3881]
# Done. Time:3.972036583999966
# Training performance:
#  Avg loss:1.676423
#
# Start validation.
# Done. Time:0.3575019259999408
# Validation performance:
#  Avg loss:1.886336
#
# Start evaluation.
# Done. Time:1.450823008000043
# Test performance:
#  Accuracy:33.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:1.485733 [    0/ 3881]
# loss:1.881192 [ 3200/ 3881]
# Done. Time:4.272396953999987
# Training performance:
#  Avg loss:1.669245
#
# Start validation.
# Done. Time:0.32706065799993667
# Validation performance:
#  Avg loss:1.884319
#
# Start evaluation.
# Done. Time:1.097785498999997
# Test performance:
#  Accuracy:32.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.478974 [    0/ 3881]
# loss:1.873689 [ 3200/ 3881]
# Done. Time:3.3750101090000726
# Training performance:
#  Avg loss:1.662180
#
# Start validation.
# Done. Time:0.29861414100003003
# Validation performance:
#  Avg loss:1.882158
#
# Start evaluation.
# Done. Time:1.0848079409998945
# Test performance:
#  Accuracy:33.5%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:1.472454 [    0/ 3881]
# loss:1.866993 [ 3200/ 3881]
# Done. Time:4.168478562000018
# Training performance:
#  Avg loss:1.655270
#
# Start validation.
# Done. Time:0.48109229399995
# Validation performance:
#  Avg loss:1.880182
#
# Start evaluation.
# Done. Time:1.377374719000045
# Test performance:
#  Accuracy:34.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.466266 [    0/ 3881]
# loss:1.859909 [ 3200/ 3881]
# Done. Time:3.31152224799996
# Training performance:
#  Avg loss:1.648534
#
# Start validation.
# Done. Time:0.34338788400009435
# Validation performance:
#  Avg loss:1.878623
#
# Start evaluation.
# Done. Time:1.0095679849999897
# Test performance:
#  Accuracy:34.0%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:1.460584 [    0/ 3881]
# loss:1.853009 [ 3200/ 3881]
# Done. Time:3.2316273669999873
# Training performance:
#  Avg loss:1.641887
#
# Start validation.
# Done. Time:0.3122504760000311
# Validation performance:
#  Avg loss:1.876680
#
# Start evaluation.
# Done. Time:1.0597410320000336
# Test performance:
#  Accuracy:35.0%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:1.454945 [    0/ 3881]
# loss:1.851587 [ 3200/ 3881]
# Done. Time:4.966160254999977
# Training performance:
#  Avg loss:1.636186
#
# Start validation.
# Done. Time:0.32808723599998757
# Validation performance:
#  Avg loss:1.883744
#
# Start evaluation.
# Done. Time:0.9271347489999471
# Test performance:
#  Accuracy:37.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.448516 [    0/ 3881]
# loss:1.837623 [ 3200/ 3881]
# Done. Time:3.3156702719999203
# Training performance:
#  Avg loss:1.627245
#
# Start validation.
# Done. Time:0.2989305500000228
# Validation performance:
#  Avg loss:1.879766
#
# Start evaluation.
# Done. Time:0.8905298669999411
# Test performance:
#  Accuracy:35.0%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.450460 [    0/ 3881]
# loss:1.833001 [ 3200/ 3881]
# Done. Time:3.276897581999947
# Training performance:
#  Avg loss:1.622653
#
# Start validation.
# Done. Time:0.379453677000015
# Validation performance:
#  Avg loss:1.876398
#
# Start evaluation.
# Done. Time:1.2577008819999946
# Test performance:
#  Accuracy:36.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.440045 [    0/ 3881]
# loss:1.827583 [ 3200/ 3881]
# Done. Time:4.114234097999997
# Training performance:
#  Avg loss:1.616384
#
# Start validation.
# Done. Time:0.2890317659999937
# Validation performance:
#  Avg loss:1.871611
#
# Start evaluation.
# Done. Time:0.9000835120000374
# Test performance:
#  Accuracy:37.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.432447 [    0/ 3881]
# loss:1.821499 [ 3200/ 3881]
# Done. Time:3.0036238899999717
# Training performance:
#  Avg loss:1.610139
#
# Start validation.
# Done. Time:0.3085142940000196
# Validation performance:
#  Avg loss:1.873970
#
# Start evaluation.
# Done. Time:0.8689488160000565
# Test performance:
#  Accuracy:37.0%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:1.433230 [    0/ 3881]
# loss:1.816538 [ 3200/ 3881]
# Done. Time:3.367524345999982
# Training performance:
#  Avg loss:1.604110
#
# Start validation.
# Done. Time:0.4943551540000044
# Validation performance:
#  Avg loss:1.868620
#
# Start evaluation.
# Done. Time:1.322348975000068
# Test performance:
#  Accuracy:38.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:1.423975 [    0/ 3881]
# loss:1.811567 [ 3200/ 3881]
# Done. Time:3.6200178100000358
# Training performance:
#  Avg loss:1.598030
#
# Start validation.
# Done. Time:0.30650368199997047
# Validation performance:
#  Avg loss:1.870247
#
# Start evaluation.
# Done. Time:0.9434788259999323
# Test performance:
#  Accuracy:38.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:1.425205 [    0/ 3881]
# loss:1.806149 [ 3200/ 3881]
# Done. Time:3.087990641999909
# Training performance:
#  Avg loss:1.591953
#
# Start validation.
# Done. Time:0.30890530799990756
# Validation performance:
#  Avg loss:1.868038
#
# Start evaluation.
# Done. Time:0.9735215160000052
# Test performance:
#  Accuracy:38.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:1.419297 [    0/ 3881]
# loss:1.801278 [ 3200/ 3881]
# Done. Time:3.862216056999955
# Training performance:
#  Avg loss:1.586086
#
# Start validation.
# Done. Time:0.49844868699995004
# Validation performance:
#  Avg loss:1.866119
#
# Start evaluation.
# Done. Time:1.3287681289999682
# Test performance:
#  Accuracy:38.0%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:1.416512 [    0/ 3881]
# loss:1.796241 [ 3200/ 3881]
# Done. Time:3.09937379400003
# Training performance:
#  Avg loss:1.580169
#
# Start validation.
# Done. Time:0.3018052859999898
# Validation performance:
#  Avg loss:1.863750
#
# Start evaluation.
# Done. Time:0.8669357260000652
# Test performance:
#  Accuracy:38.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:1.411269 [    0/ 3881]
# loss:1.790500 [ 3200/ 3881]
# Done. Time:3.162653551999938
# Training performance:
#  Avg loss:1.574458
#
# Start validation.
# Done. Time:0.3169377279999708
# Validation performance:
#  Avg loss:1.861406
#
# Start evaluation.
# Done. Time:0.9670795920000046
# Test performance:
#  Accuracy:39.5%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:1.403876 [    0/ 3881]
# loss:1.785748 [ 3200/ 3881]
# Done. Time:4.326335622999977
# Training performance:
#  Avg loss:1.568648
#
# Start validation.
# Done. Time:0.4615485309999485
# Validation performance:
#  Avg loss:1.859330
#
# Start evaluation.
# Done. Time:1.1319748160000245
# Test performance:
#  Accuracy:39.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.400575 [    0/ 3881]
# loss:1.781031 [ 3200/ 3881]
# Done. Time:2.9716449640000064
# Training performance:
#  Avg loss:1.562724
#
# Start validation.
# Done. Time:0.27189817399994354
# Validation performance:
#  Avg loss:1.857006
#
# Start evaluation.
# Done. Time:0.8516743120000001
# Test performance:
#  Accuracy:39.5%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:1.395676 [    0/ 3881]
# loss:1.775971 [ 3200/ 3881]
# Done. Time:2.9720100859999548
# Training performance:
#  Avg loss:1.556936
#
# Start validation.
# Done. Time:0.28990018900003633
# Validation performance:
#  Avg loss:1.854805
#
# Start evaluation.
# Done. Time:0.8442453809999506
# Test performance:
#  Accuracy:39.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:1.392179 [    0/ 3881]
# loss:1.770691 [ 3200/ 3881]
# Done. Time:4.363722426999971
# Training performance:
#  Avg loss:1.551097
#
# Start validation.
# Done. Time:0.40665333599997666
# Validation performance:
#  Avg loss:1.852955
#
# Start evaluation.
# Done. Time:0.8380336010000065
# Test performance:
#  Accuracy:39.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:1.387026 [    0/ 3881]
# loss:1.766195 [ 3200/ 3881]
# Done. Time:3.0882784699999775
# Training performance:
#  Avg loss:1.545547
#
# Start validation.
# Done. Time:0.2705183349999061
# Validation performance:
#  Avg loss:1.851259
#
# Start evaluation.
# Done. Time:0.8637067979999529
# Test performance:
#  Accuracy:39.5%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:1.383347 [    0/ 3881]
# loss:1.761337 [ 3200/ 3881]
# Done. Time:3.0061470899998994
# Training performance:
#  Avg loss:1.539978
#
# Start validation.
# Done. Time:0.28958560000000944
# Validation performance:
#  Avg loss:1.849108
#
# Start evaluation.
# Done. Time:0.8611412760000121
# Test performance:
#  Accuracy:39.5%
# Minimum validation loss:1.849108133997236 at 50 epoch.
# Maximum accuracy:39.5 at 44 epoch.

# %% [markdown]
# ## Train with aligned landmarks (parts-based)

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_align_w))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_align_parts,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_align_parts,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_align_parts,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_align_p = np.array(val_losses)
test_accs_align_p = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_align_p.min()} at {np.argmin(val_losses_align_p)+1} epoch.")
print(f"Maximum accuracy:{test_accs_align_p.max()} at {np.argmax(test_accs_align_p)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.342440 [    0/ 3881]
# loss:2.295517 [ 3200/ 3881]
# Done. Time:3.0354668730000185
# Training performance:
#  Avg loss:2.291200
#
# Start validation.
# Done. Time:0.3046545059999062
# Validation performance:
#  Avg loss:2.274210
#
# Start evaluation.
# Done. Time:0.8647665539999707
# Test performance:
#  Accuracy:18.0%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.253032 [    0/ 3881]
# loss:2.251120 [ 3200/ 3881]
# Done. Time:2.994188472000019
# Training performance:
#  Avg loss:2.229142
#
# Start validation.
# Done. Time:0.2966519100000369
# Validation performance:
#  Avg loss:2.242060
#
# Start evaluation.
# Done. Time:0.85963175400002
# Test performance:
#  Accuracy:19.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:2.163866 [    0/ 3881]
# loss:2.206648 [ 3200/ 3881]
# Done. Time:4.555377626999984
# Training performance:
#  Avg loss:2.152028
#
# Start validation.
# Done. Time:0.2962826740000537
# Validation performance:
#  Avg loss:2.205221
#
# Start evaluation.
# Done. Time:0.8099166920000016
# Test performance:
#  Accuracy:20.5%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:2.055915 [    0/ 3881]
# loss:2.160084 [ 3200/ 3881]
# Done. Time:3.0597685390000606
# Training performance:
#  Avg loss:2.074143
#
# Start validation.
# Done. Time:0.3575945680000814
# Validation performance:
#  Avg loss:2.166859
#
# Start evaluation.
# Done. Time:1.1040270559999499
# Test performance:
#  Accuracy:26.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.962252 [    0/ 3881]
# loss:2.114877 [ 3200/ 3881]
# Done. Time:4.240754258000038
# Training performance:
#  Avg loss:2.005935
#
# Start validation.
# Done. Time:0.4851598359999798
# Validation performance:
#  Avg loss:2.131909
#
# Start evaluation.
# Done. Time:1.0575499579999814
# Test performance:
#  Accuracy:31.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.878330 [    0/ 3881]
# loss:2.073838 [ 3200/ 3881]
# Done. Time:3.7803683249999267
# Training performance:
#  Avg loss:1.946839
#
# Start validation.
# Done. Time:0.28614917899994907
# Validation performance:
#  Avg loss:2.098967
#
# Start evaluation.
# Done. Time:0.8373404629999186
# Test performance:
#  Accuracy:37.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.803149 [    0/ 3881]
# loss:2.036626 [ 3200/ 3881]
# Done. Time:3.041259091000029
# Training performance:
#  Avg loss:1.894456
#
# Start validation.
# Done. Time:0.30300055500003964
# Validation performance:
#  Avg loss:2.069385
#
# Start evaluation.
# Done. Time:0.8365162220000002
# Test performance:
#  Accuracy:38.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.737713 [    0/ 3881]
# loss:2.002217 [ 3200/ 3881]
# Done. Time:3.450695101000065
# Training performance:
#  Avg loss:1.847516
#
# Start validation.
# Done. Time:0.4735307380000222
# Validation performance:
#  Avg loss:2.041910
#
# Start evaluation.
# Done. Time:1.304801798000085
# Test performance:
#  Accuracy:39.5%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.676623 [    0/ 3881]
# loss:1.970774 [ 3200/ 3881]
# Done. Time:3.4276730029999953
# Training performance:
#  Avg loss:1.805051
#
# Start validation.
# Done. Time:0.3114542990000473
# Validation performance:
#  Avg loss:2.015797
#
# Start evaluation.
# Done. Time:0.845056956999997
# Test performance:
#  Accuracy:41.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.620007 [    0/ 3881]
# loss:1.941390 [ 3200/ 3881]
# Done. Time:2.974297794999984
# Training performance:
#  Avg loss:1.766233
#
# Start validation.
# Done. Time:0.2994438910000099
# Validation performance:
#  Avg loss:1.991563
#
# Start evaluation.
# Done. Time:0.8291784110000435
# Test performance:
#  Accuracy:42.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.566036 [    0/ 3881]
# loss:1.913890 [ 3200/ 3881]
# Done. Time:3.5533439700000145
# Training performance:
#  Avg loss:1.730495
#
# Start validation.
# Done. Time:0.4693730340000002
# Validation performance:
#  Avg loss:1.969088
#
# Start evaluation.
# Done. Time:1.1508096679999653
# Test performance:
#  Accuracy:43.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.514337 [    0/ 3881]
# loss:1.887979 [ 3200/ 3881]
# Done. Time:3.2483990970000605
# Training performance:
#  Avg loss:1.697297
#
# Start validation.
# Done. Time:0.3201278489999595
# Validation performance:
#  Avg loss:1.948585
#
# Start evaluation.
# Done. Time:0.8133020699999634
# Test performance:
#  Accuracy:44.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.465590 [    0/ 3881]
# loss:1.863557 [ 3200/ 3881]
# Done. Time:3.015167304999977
# Training performance:
#  Avg loss:1.666340
#
# Start validation.
# Done. Time:0.29829046700001527
# Validation performance:
#  Avg loss:1.929554
#
# Start evaluation.
# Done. Time:0.8312638040000593
# Test performance:
#  Accuracy:46.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.419685 [    0/ 3881]
# loss:1.840377 [ 3200/ 3881]
# Done. Time:3.677479458999983
# Training performance:
#  Avg loss:1.637274
#
# Start validation.
# Done. Time:0.4887452990000156
# Validation performance:
#  Avg loss:1.911743
#
# Start evaluation.
# Done. Time:1.2149161229999663
# Test performance:
#  Accuracy:48.0%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:1.376798 [    0/ 3881]
# loss:1.818605 [ 3200/ 3881]
# Done. Time:3.0173249749999513
# Training performance:
#  Avg loss:1.609858
#
# Start validation.
# Done. Time:0.3121946170000456
# Validation performance:
#  Avg loss:1.895054
#
# Start evaluation.
# Done. Time:0.8065006719999701
# Test performance:
#  Accuracy:51.0%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.337198 [    0/ 3881]
# loss:1.797853 [ 3200/ 3881]
# Done. Time:3.031852329000003
# Training performance:
#  Avg loss:1.583783
#
# Start validation.
# Done. Time:0.30287563900003533
# Validation performance:
#  Avg loss:1.879427
#
# Start evaluation.
# Done. Time:0.8273466780000263
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.300624 [    0/ 3881]
# loss:1.778064 [ 3200/ 3881]
# Done. Time:3.8142171990000406
# Training performance:
#  Avg loss:1.559123
#
# Start validation.
# Done. Time:0.5028218809999316
# Validation performance:
#  Avg loss:1.864388
#
# Start evaluation.
# Done. Time:1.142940408999948
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.267241 [    0/ 3881]
# loss:1.759125 [ 3200/ 3881]
# Done. Time:3.0001921049999964
# Training performance:
#  Avg loss:1.535584
#
# Start validation.
# Done. Time:0.2933108849999826
# Validation performance:
#  Avg loss:1.850256
#
# Start evaluation.
# Done. Time:0.8319478409999874
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.236651 [    0/ 3881]
# loss:1.741169 [ 3200/ 3881]
# Done. Time:2.9905797850000226
# Training performance:
#  Avg loss:1.512991
#
# Start validation.
# Done. Time:0.29757950400005484
# Validation performance:
#  Avg loss:1.835175
#
# Start evaluation.
# Done. Time:0.8053060890000552
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.205080 [    0/ 3881]
# loss:1.723201 [ 3200/ 3881]
# Done. Time:3.917836910999995
# Training performance:
#  Avg loss:1.490147
#
# Start validation.
# Done. Time:0.46799289299997326
# Validation performance:
#  Avg loss:1.823105
#
# Start evaluation.
# Done. Time:1.0674830259999908
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.180135 [    0/ 3881]
# loss:1.706194 [ 3200/ 3881]
# Done. Time:3.080025984000031
# Training performance:
#  Avg loss:1.469663
#
# Start validation.
# Done. Time:0.29530128400006106
# Validation performance:
#  Avg loss:1.811361
#
# Start evaluation.
# Done. Time:0.8384837520000019
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.156377 [    0/ 3881]
# loss:1.690091 [ 3200/ 3881]
# Done. Time:3.0075115260000302
# Training performance:
#  Avg loss:1.449855
#
# Start validation.
# Done. Time:0.3131167249999862
# Validation performance:
#  Avg loss:1.799988
#
# Start evaluation.
# Done. Time:0.8061094040000398
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.133640 [    0/ 3881]
# loss:1.674619 [ 3200/ 3881]
# Done. Time:4.1493216249999705
# Training performance:
#  Avg loss:1.430746
#
# Start validation.
# Done. Time:0.46784263000006376
# Validation performance:
#  Avg loss:1.788848
#
# Start evaluation.
# Done. Time:1.01338677800004
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.111981 [    0/ 3881]
# loss:1.659683 [ 3200/ 3881]
# Done. Time:3.003145905999986
# Training performance:
#  Avg loss:1.412366
#
# Start validation.
# Done. Time:0.29085037400000147
# Validation performance:
#  Avg loss:1.777862
#
# Start evaluation.
# Done. Time:0.8171937260000277
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.091765 [    0/ 3881]
# loss:1.644977 [ 3200/ 3881]
# Done. Time:3.022071588000017
# Training performance:
#  Avg loss:1.394636
#
# Start validation.
# Done. Time:0.3155771439999171
# Validation performance:
#  Avg loss:1.767437
#
# Start evaluation.
# Done. Time:0.8073255250000102
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.072811 [    0/ 3881]
# loss:1.630763 [ 3200/ 3881]
# Done. Time:4.364758645000052
# Training performance:
#  Avg loss:1.377552
#
# Start validation.
# Done. Time:0.5066597440001033
# Validation performance:
#  Avg loss:1.757372
#
# Start evaluation.
# Done. Time:0.8359497610000517
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.054921 [    0/ 3881]
# loss:1.616652 [ 3200/ 3881]
# Done. Time:3.045130474000075
# Training performance:
#  Avg loss:1.361067
#
# Start validation.
# Done. Time:0.30009730999995554
# Validation performance:
#  Avg loss:1.747816
#
# Start evaluation.
# Done. Time:0.8092172930000743
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.038031 [    0/ 3881]
# loss:1.603418 [ 3200/ 3881]
# Done. Time:3.036494681000022
# Training performance:
#  Avg loss:1.345180
#
# Start validation.
# Done. Time:0.28170153999997183
# Validation performance:
#  Avg loss:1.738142
#
# Start evaluation.
# Done. Time:0.8306811830000242
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:1.021659 [    0/ 3881]
# loss:1.589774 [ 3200/ 3881]
# Done. Time:4.548940455999968
# Training performance:
#  Avg loss:1.329765
#
# Start validation.
# Done. Time:0.3014435689999573
# Validation performance:
#  Avg loss:1.728743
#
# Start evaluation.
# Done. Time:0.8203222680000408
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.006604 [    0/ 3881]
# loss:1.576937 [ 3200/ 3881]
# Done. Time:3.063514349000002
# Training performance:
#  Avg loss:1.314943
#
# Start validation.
# Done. Time:0.30246416900001805
# Validation performance:
#  Avg loss:1.719569
#
# Start evaluation.
# Done. Time:0.8477293970000801
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.991998 [    0/ 3881]
# loss:1.564661 [ 3200/ 3881]
# Done. Time:3.0330446049999864
# Training performance:
#  Avg loss:1.300608
#
# Start validation.
# Done. Time:0.29732071899991297
# Validation performance:
#  Avg loss:1.710516
#
# Start evaluation.
# Done. Time:0.8357738490000202
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.978187 [    0/ 3881]
# loss:1.552422 [ 3200/ 3881]
# Done. Time:4.596002285000054
# Training performance:
#  Avg loss:1.286687
#
# Start validation.
# Done. Time:0.2993716429999722
# Validation performance:
#  Avg loss:1.701930
#
# Start evaluation.
# Done. Time:0.8134287179999546
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.965529 [    0/ 3881]
# loss:1.540679 [ 3200/ 3881]
# Done. Time:3.005268148999903
# Training performance:
#  Avg loss:1.273272
#
# Start validation.
# Done. Time:0.29899050200003785
# Validation performance:
#  Avg loss:1.692815
#
# Start evaluation.
# Done. Time:0.8124620309999955
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.953233 [    0/ 3881]
# loss:1.529112 [ 3200/ 3881]
# Done. Time:3.787323264000065
# Training performance:
#  Avg loss:1.260209
#
# Start validation.
# Done. Time:0.48684761899994555
# Validation performance:
#  Avg loss:1.684634
#
# Start evaluation.
# Done. Time:1.443061843999999
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.941454 [    0/ 3881]
# loss:1.518355 [ 3200/ 3881]
# Done. Time:4.329469825999922
# Training performance:
#  Avg loss:1.247528
#
# Start validation.
# Done. Time:0.3032743339999797
# Validation performance:
#  Avg loss:1.675715
#
# Start evaluation.
# Done. Time:0.8282580139999709
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.929839 [    0/ 3881]
# loss:1.507041 [ 3200/ 3881]
# Done. Time:3.1358665029999884
# Training performance:
#  Avg loss:1.235203
#
# Start validation.
# Done. Time:0.3017608900000823
# Validation performance:
#  Avg loss:1.667502
#
# Start evaluation.
# Done. Time:0.7942836910000324
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.919204 [    0/ 3881]
# loss:1.496479 [ 3200/ 3881]
# Done. Time:3.017809408000062
# Training performance:
#  Avg loss:1.223272
#
# Start validation.
# Done. Time:0.33881307100000413
# Validation performance:
#  Avg loss:1.659054
#
# Start evaluation.
# Done. Time:1.1053560520000474
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.908642 [    0/ 3881]
# loss:1.485959 [ 3200/ 3881]
# Done. Time:4.0170947880000085
# Training performance:
#  Avg loss:1.211605
#
# Start validation.
# Done. Time:0.30097019000004366
# Validation performance:
#  Avg loss:1.651398
#
# Start evaluation.
# Done. Time:0.8203043570000546
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.898996 [    0/ 3881]
# loss:1.476417 [ 3200/ 3881]
# Done. Time:3.0503859230000216
# Training performance:
#  Avg loss:1.200338
#
# Start validation.
# Done. Time:0.29182455299996946
# Validation performance:
#  Avg loss:1.642610
#
# Start evaluation.
# Done. Time:0.8996085640000047
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.888761 [    0/ 3881]
# loss:1.466913 [ 3200/ 3881]
# Done. Time:7.754429062000099
# Training performance:
#  Avg loss:1.189350
#
# Start validation.
# Done. Time:0.6288960140000199
# Validation performance:
#  Avg loss:1.634292
#
# Start evaluation.
# Done. Time:1.548362353000016
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.879353 [    0/ 3881]
# loss:1.457924 [ 3200/ 3881]
# Done. Time:6.611342863999994
# Training performance:
#  Avg loss:1.178666
#
# Start validation.
# Done. Time:0.31277991699994345
# Validation performance:
#  Avg loss:1.625878
#
# Start evaluation.
# Done. Time:0.9365001639999946
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.870243 [    0/ 3881]
# loss:1.448648 [ 3200/ 3881]
# Done. Time:4.351333300999954
# Training performance:
#  Avg loss:1.168302
#
# Start validation.
# Done. Time:0.30568533600001047
# Validation performance:
#  Avg loss:1.617834
#
# Start evaluation.
# Done. Time:0.9159918719999496
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.861768 [    0/ 3881]
# loss:1.439588 [ 3200/ 3881]
# Done. Time:3.0654259280000815
# Training performance:
#  Avg loss:1.158132
#
# Start validation.
# Done. Time:0.29626002300005894
# Validation performance:
#  Avg loss:1.609934
#
# Start evaluation.
# Done. Time:0.8314121429999659
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.853151 [    0/ 3881]
# loss:1.431160 [ 3200/ 3881]
# Done. Time:3.1144673539999985
# Training performance:
#  Avg loss:1.148381
#
# Start validation.
# Done. Time:0.2893270900000289
# Validation performance:
#  Avg loss:1.602386
#
# Start evaluation.
# Done. Time:1.075980616000038
# Test performance:
#  Accuracy:60.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.845310 [    0/ 3881]
# loss:1.422748 [ 3200/ 3881]
# Done. Time:4.0457067790000565
# Training performance:
#  Avg loss:1.138690
#
# Start validation.
# Done. Time:0.3244575989999703
# Validation performance:
#  Avg loss:1.594796
#
# Start evaluation.
# Done. Time:0.8044706620000852
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.837263 [    0/ 3881]
# loss:1.414705 [ 3200/ 3881]
# Done. Time:3.0458278959999916
# Training performance:
#  Avg loss:1.129324
#
# Start validation.
# Done. Time:0.31089820200008944
# Validation performance:
#  Avg loss:1.587176
#
# Start evaluation.
# Done. Time:0.8073100269999713
# Test performance:
#  Accuracy:60.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.830356 [    0/ 3881]
# loss:1.406762 [ 3200/ 3881]
# Done. Time:3.056901324000023
# Training performance:
#  Avg loss:1.120179
#
# Start validation.
# Done. Time:0.394132147999926
# Validation performance:
#  Avg loss:1.579539
#
# Start evaluation.
# Done. Time:1.0437458280000556
# Test performance:
#  Accuracy:60.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.822535 [    0/ 3881]
# loss:1.398887 [ 3200/ 3881]
# Done. Time:3.919975962999956
# Training performance:
#  Avg loss:1.111094
#
# Start validation.
# Done. Time:0.3150149609999744
# Validation performance:
#  Avg loss:1.572389
#
# Start evaluation.
# Done. Time:0.7996425879999833
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.814803 [    0/ 3881]
# loss:1.391082 [ 3200/ 3881]
# Done. Time:2.954798793000009
# Training performance:
#  Avg loss:1.102362
#
# Start validation.
# Done. Time:0.3084388059999128
# Validation performance:
#  Avg loss:1.564917
#
# Start evaluation.
# Done. Time:0.8453874770000311
# Test performance:
#  Accuracy:60.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.808967 [    0/ 3881]
# loss:1.383466 [ 3200/ 3881]
# Done. Time:2.9615830209999103
# Training performance:
#  Avg loss:1.093737
#
# Start validation.
# Done. Time:0.44244434300003377
# Validation performance:
#  Avg loss:1.558042
#
# Start evaluation.
# Done. Time:1.080647385999896
# Test performance:
#  Accuracy:60.5%
# Minimum validation loss:1.5580417598996843 at 50 epoch.
# Maximum accuracy:60.5 at 50 epoch.

# %% [markdown]
# ## Train with aligned and scaled landmarks (whole body)

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_align_scale_w))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_align_scale_whole,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_align_scale_whole,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_align_scale_whole,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_align_scale_w = np.array(val_losses)
test_accs_align_scale_w = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_align_scale_w.min()} at {np.argmin(val_losses_align_scale_w)+1} epoch.")
print(f"Maximum accuracy:{test_accs_align_scale_w.max()} at {np.argmax(test_accs_align_scale_w)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.435665 [    0/ 3881]
# loss:2.318661 [ 3200/ 3881]
# Done. Time:3.003444968999929
# Training performance:
#  Avg loss:2.282439
#
# Start validation.
# Done. Time:0.3175925840000673
# Validation performance:
#  Avg loss:2.279766
#
# Start evaluation.
# Done. Time:0.8410873249999895
# Test performance:
#  Accuracy:11.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.293630 [    0/ 3881]
# loss:2.286445 [ 3200/ 3881]
# Done. Time:3.061303903999942
# Training performance:
#  Avg loss:2.212327
#
# Start validation.
# Done. Time:0.4025564400000121
# Validation performance:
#  Avg loss:2.231103
#
# Start evaluation.
# Done. Time:1.0714298560000088
# Test performance:
#  Accuracy:20.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:2.189622 [    0/ 3881]
# loss:2.250222 [ 3200/ 3881]
# Done. Time:3.7172421760000134
# Training performance:
#  Avg loss:2.135295
#
# Start validation.
# Done. Time:0.31846973400001843
# Validation performance:
#  Avg loss:2.152194
#
# Start evaluation.
# Done. Time:0.8229763630000662
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:2.067008 [    0/ 3881]
# loss:2.221481 [ 3200/ 3881]
# Done. Time:2.9308346450000045
# Training performance:
#  Avg loss:2.064073
#
# Start validation.
# Done. Time:0.2929631580000205
# Validation performance:
#  Avg loss:2.092482
#
# Start evaluation.
# Done. Time:0.8159531270000571
# Test performance:
#  Accuracy:27.5%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.961804 [    0/ 3881]
# loss:2.192228 [ 3200/ 3881]
# Done. Time:2.8978311089999806
# Training performance:
#  Avg loss:2.005844
#
# Start validation.
# Done. Time:0.3872749010000689
# Validation performance:
#  Avg loss:2.041277
#
# Start evaluation.
# Done. Time:1.0753788100000747
# Test performance:
#  Accuracy:30.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.885516 [    0/ 3881]
# loss:2.168050 [ 3200/ 3881]
# Done. Time:3.771072731000004
# Training performance:
#  Avg loss:1.959030
#
# Start validation.
# Done. Time:0.30095617100005256
# Validation performance:
#  Avg loss:2.006169
#
# Start evaluation.
# Done. Time:0.8100151700000424
# Test performance:
#  Accuracy:32.5%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.827506 [    0/ 3881]
# loss:2.143054 [ 3200/ 3881]
# Done. Time:2.93882643500001
# Training performance:
#  Avg loss:1.922691
#
# Start validation.
# Done. Time:0.35580783299997165
# Validation performance:
#  Avg loss:1.981331
#
# Start evaluation.
# Done. Time:1.0133113370000046
# Test performance:
#  Accuracy:35.5%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.776198 [    0/ 3881]
# loss:2.120841 [ 3200/ 3881]
# Done. Time:4.9106097439999985
# Training performance:
#  Avg loss:1.892556
#
# Start validation.
# Done. Time:0.4796839110000519
# Validation performance:
#  Avg loss:1.961984
#
# Start evaluation.
# Done. Time:1.2265236770000456
# Test performance:
#  Accuracy:38.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.733855 [    0/ 3881]
# loss:2.101161 [ 3200/ 3881]
# Done. Time:3.055488475000061
# Training performance:
#  Avg loss:1.866978
#
# Start validation.
# Done. Time:0.3080551699999887
# Validation performance:
#  Avg loss:1.946912
#
# Start evaluation.
# Done. Time:0.8336233690000654
# Test performance:
#  Accuracy:37.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.701326 [    0/ 3881]
# loss:2.082954 [ 3200/ 3881]
# Done. Time:2.9899805360000755
# Training performance:
#  Avg loss:1.844796
#
# Start validation.
# Done. Time:0.29753369499997007
# Validation performance:
#  Avg loss:1.933871
#
# Start evaluation.
# Done. Time:0.8369837959999131
# Test performance:
#  Accuracy:36.5%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.674829 [    0/ 3881]
# loss:2.066750 [ 3200/ 3881]
# Done. Time:5.078712823000046
# Training performance:
#  Avg loss:1.824910
#
# Start validation.
# Done. Time:0.620334378999928
# Validation performance:
#  Avg loss:1.923506
#
# Start evaluation.
# Done. Time:1.4186335440000448
# Test performance:
#  Accuracy:35.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.652382 [    0/ 3881]
# loss:2.051378 [ 3200/ 3881]
# Done. Time:3.448752122999963
# Training performance:
#  Avg loss:1.806748
#
# Start validation.
# Done. Time:0.2831357200000184
# Validation performance:
#  Avg loss:1.914426
#
# Start evaluation.
# Done. Time:0.8297360159999698
# Test performance:
#  Accuracy:36.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.633704 [    0/ 3881]
# loss:2.036916 [ 3200/ 3881]
# Done. Time:2.9501605240000117
# Training performance:
#  Avg loss:1.790274
#
# Start validation.
# Done. Time:0.3120507080000152
# Validation performance:
#  Avg loss:1.906408
#
# Start evaluation.
# Done. Time:0.8205644500000062
# Test performance:
#  Accuracy:35.0%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.617433 [    0/ 3881]
# loss:2.022883 [ 3200/ 3881]
# Done. Time:3.5902802869999277
# Training performance:
#  Avg loss:1.774854
#
# Start validation.
# Done. Time:0.4494382320000341
# Validation performance:
#  Avg loss:1.899771
#
# Start evaluation.
# Done. Time:1.1673527610000747
# Test performance:
#  Accuracy:34.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:1.602731 [    0/ 3881]
# loss:2.009496 [ 3200/ 3881]
# Done. Time:3.066453974999945
# Training performance:
#  Avg loss:1.760183
#
# Start validation.
# Done. Time:0.3239870740000015
# Validation performance:
#  Avg loss:1.894052
#
# Start evaluation.
# Done. Time:0.8254003350000403
# Test performance:
#  Accuracy:35.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.588777 [    0/ 3881]
# loss:1.996810 [ 3200/ 3881]
# Done. Time:2.9782194160000017
# Training performance:
#  Avg loss:1.746216
#
# Start validation.
# Done. Time:0.30342865500006155
# Validation performance:
#  Avg loss:1.888948
#
# Start evaluation.
# Done. Time:0.8218787459999248
# Test performance:
#  Accuracy:35.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.576398 [    0/ 3881]
# loss:1.985008 [ 3200/ 3881]
# Done. Time:3.926741203000006
# Training performance:
#  Avg loss:1.733097
#
# Start validation.
# Done. Time:0.4982920469999499
# Validation performance:
#  Avg loss:1.883714
#
# Start evaluation.
# Done. Time:1.181551538000008
# Test performance:
#  Accuracy:35.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.563887 [    0/ 3881]
# loss:1.973503 [ 3200/ 3881]
# Done. Time:3.027821194000012
# Training performance:
#  Avg loss:1.720732
#
# Start validation.
# Done. Time:0.3087214640000866
# Validation performance:
#  Avg loss:1.879254
#
# Start evaluation.
# Done. Time:0.8558008009999867
# Test performance:
#  Accuracy:35.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.550113 [    0/ 3881]
# loss:1.962403 [ 3200/ 3881]
# Done. Time:3.036128015999907
# Training performance:
#  Avg loss:1.709565
#
# Start validation.
# Done. Time:0.30462113199996566
# Validation performance:
#  Avg loss:1.874269
#
# Start evaluation.
# Done. Time:0.8479736849999426
# Test performance:
#  Accuracy:35.0%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.544387 [    0/ 3881]
# loss:1.952630 [ 3200/ 3881]
# Done. Time:4.1475753229999555
# Training performance:
#  Avg loss:1.697373
#
# Start validation.
# Done. Time:0.44812526900000194
# Validation performance:
#  Avg loss:1.870327
#
# Start evaluation.
# Done. Time:0.9865120380000008
# Test performance:
#  Accuracy:36.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.531255 [    0/ 3881]
# loss:1.942975 [ 3200/ 3881]
# Done. Time:3.032964806999985
# Training performance:
#  Avg loss:1.686708
#
# Start validation.
# Done. Time:0.30443114199999854
# Validation performance:
#  Avg loss:1.867164
#
# Start evaluation.
# Done. Time:0.8464485850000756
# Test performance:
#  Accuracy:36.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.523314 [    0/ 3881]
# loss:1.933441 [ 3200/ 3881]
# Done. Time:3.0598674499998424
# Training performance:
#  Avg loss:1.676003
#
# Start validation.
# Done. Time:0.31077582599982634
# Validation performance:
#  Avg loss:1.862733
#
# Start evaluation.
# Done. Time:0.8277135910000197
# Test performance:
#  Accuracy:36.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.512731 [    0/ 3881]
# loss:1.924225 [ 3200/ 3881]
# Done. Time:5.225398976999941
# Training performance:
#  Avg loss:1.666574
#
# Start validation.
# Done. Time:0.36168095699986225
# Validation performance:
#  Avg loss:1.859494
#
# Start evaluation.
# Done. Time:0.8551219710000169
# Test performance:
#  Accuracy:36.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.505736 [    0/ 3881]
# loss:1.915173 [ 3200/ 3881]
# Done. Time:3.001629130999845
# Training performance:
#  Avg loss:1.657205
#
# Start validation.
# Done. Time:0.3192937270000584
# Validation performance:
#  Avg loss:1.855266
#
# Start evaluation.
# Done. Time:0.8884218949999649
# Test performance:
#  Accuracy:36.5%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.495327 [    0/ 3881]
# loss:1.905425 [ 3200/ 3881]
# Done. Time:3.0354188830001476
# Training performance:
#  Avg loss:1.647481
#
# Start validation.
# Done. Time:0.2891422640000201
# Validation performance:
#  Avg loss:1.852029
#
# Start evaluation.
# Done. Time:0.8296710950000943
# Test performance:
#  Accuracy:36.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.489202 [    0/ 3881]
# loss:1.896335 [ 3200/ 3881]
# Done. Time:4.588536593999834
# Training performance:
#  Avg loss:1.638630
#
# Start validation.
# Done. Time:0.30327937100014424
# Validation performance:
#  Avg loss:1.848603
#
# Start evaluation.
# Done. Time:0.8298719169999913
# Test performance:
#  Accuracy:36.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.479848 [    0/ 3881]
# loss:1.887948 [ 3200/ 3881]
# Done. Time:2.9730037780000202
# Training performance:
#  Avg loss:1.629936
#
# Start validation.
# Done. Time:0.29287561900014225
# Validation performance:
#  Avg loss:1.844897
#
# Start evaluation.
# Done. Time:0.8391443900000013
# Test performance:
#  Accuracy:37.0%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.471192 [    0/ 3881]
# loss:1.880041 [ 3200/ 3881]
# Done. Time:3.0155520569999226
# Training performance:
#  Avg loss:1.621623
#
# Start validation.
# Done. Time:0.29354069599980903
# Validation performance:
#  Avg loss:1.841964
#
# Start evaluation.
# Done. Time:0.9000209829998767
# Test performance:
#  Accuracy:36.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:1.463710 [    0/ 3881]
# loss:1.872255 [ 3200/ 3881]
# Done. Time:4.438960319999978
# Training performance:
#  Avg loss:1.613885
#
# Start validation.
# Done. Time:0.3245007830000759
# Validation performance:
#  Avg loss:1.838125
#
# Start evaluation.
# Done. Time:0.8301447829999233
# Test performance:
#  Accuracy:37.0%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.454991 [    0/ 3881]
# loss:1.864999 [ 3200/ 3881]
# Done. Time:3.050914061000185
# Training performance:
#  Avg loss:1.606054
#
# Start validation.
# Done. Time:0.3014842449999833
# Validation performance:
#  Avg loss:1.834898
#
# Start evaluation.
# Done. Time:0.8304372699999476
# Test performance:
#  Accuracy:37.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:1.448508 [    0/ 3881]
# loss:1.856625 [ 3200/ 3881]
# Done. Time:3.005338083999959
# Training performance:
#  Avg loss:1.598454
#
# Start validation.
# Done. Time:0.29135825899993506
# Validation performance:
#  Avg loss:1.832064
#
# Start evaluation.
# Done. Time:1.0450796509999236
# Test performance:
#  Accuracy:36.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.440843 [    0/ 3881]
# loss:1.849464 [ 3200/ 3881]
# Done. Time:4.0878189869999915
# Training performance:
#  Avg loss:1.590789
#
# Start validation.
# Done. Time:0.33443993599985333
# Validation performance:
#  Avg loss:1.829093
#
# Start evaluation.
# Done. Time:0.8465169559999595
# Test performance:
#  Accuracy:37.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:1.433077 [    0/ 3881]
# loss:1.842621 [ 3200/ 3881]
# Done. Time:3.035125144999938
# Training performance:
#  Avg loss:1.583777
#
# Start validation.
# Done. Time:0.2997018119999666
# Validation performance:
#  Avg loss:1.825025
#
# Start evaluation.
# Done. Time:0.825884913000209
# Test performance:
#  Accuracy:37.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:1.424346 [    0/ 3881]
# loss:1.836359 [ 3200/ 3881]
# Done. Time:3.0298936950000552
# Training performance:
#  Avg loss:1.576202
#
# Start validation.
# Done. Time:0.3189512620001551
# Validation performance:
#  Avg loss:1.822752
#
# Start evaluation.
# Done. Time:1.100413086999879
# Test performance:
#  Accuracy:38.5%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.417109 [    0/ 3881]
# loss:1.828198 [ 3200/ 3881]
# Done. Time:4.096275000999867
# Training performance:
#  Avg loss:1.569270
#
# Start validation.
# Done. Time:0.2707598049998978
# Validation performance:
#  Avg loss:1.820926
#
# Start evaluation.
# Done. Time:0.8187489660001575
# Test performance:
#  Accuracy:37.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.411668 [    0/ 3881]
# loss:1.821616 [ 3200/ 3881]
# Done. Time:3.0099980109998796
# Training performance:
#  Avg loss:1.562087
#
# Start validation.
# Done. Time:0.30232714099997793
# Validation performance:
#  Avg loss:1.818657
#
# Start evaluation.
# Done. Time:0.8278343280001081
# Test performance:
#  Accuracy:38.5%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.405389 [    0/ 3881]
# loss:1.814268 [ 3200/ 3881]
# Done. Time:3.0302088920000187
# Training performance:
#  Avg loss:1.555293
#
# Start validation.
# Done. Time:0.47830495299990616
# Validation performance:
#  Avg loss:1.817247
#
# Start evaluation.
# Done. Time:1.1290549999998802
# Test performance:
#  Accuracy:39.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.397909 [    0/ 3881]
# loss:1.807956 [ 3200/ 3881]
# Done. Time:3.8515402870000344
# Training performance:
#  Avg loss:1.548342
#
# Start validation.
# Done. Time:0.2741839020000043
# Validation performance:
#  Avg loss:1.816293
#
# Start evaluation.
# Done. Time:0.8368189249999887
# Test performance:
#  Accuracy:40.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:1.391808 [    0/ 3881]
# loss:1.801299 [ 3200/ 3881]
# Done. Time:2.9534582009998758
# Training performance:
#  Avg loss:1.541669
#
# Start validation.
# Done. Time:0.28782756900000095
# Validation performance:
#  Avg loss:1.814964
#
# Start evaluation.
# Done. Time:0.8410754080000515
# Test performance:
#  Accuracy:40.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:1.385084 [    0/ 3881]
# loss:1.794968 [ 3200/ 3881]
# Done. Time:3.197025460999839
# Training performance:
#  Avg loss:1.534922
#
# Start validation.
# Done. Time:0.4492880160000823
# Validation performance:
#  Avg loss:1.813876
#
# Start evaluation.
# Done. Time:1.1033526759999859
# Test performance:
#  Accuracy:40.0%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:1.379828 [    0/ 3881]
# loss:1.791902 [ 3200/ 3881]
# Done. Time:5.278523657999813
# Training performance:
#  Avg loss:1.528287
#
# Start validation.
# Done. Time:0.2884889279998788
# Validation performance:
#  Avg loss:1.813823
#
# Start evaluation.
# Done. Time:0.8182533770000191
# Test performance:
#  Accuracy:41.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:1.375501 [    0/ 3881]
# loss:1.783955 [ 3200/ 3881]
# Done. Time:3.0188906559999396
# Training performance:
#  Avg loss:1.520910
#
# Start validation.
# Done. Time:0.334371856999951
# Validation performance:
#  Avg loss:1.812190
#
# Start evaluation.
# Done. Time:0.8406829210000524
# Test performance:
#  Accuracy:39.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:1.370772 [    0/ 3881]
# loss:1.777634 [ 3200/ 3881]
# Done. Time:3.7603549030000067
# Training performance:
#  Avg loss:1.514196
#
# Start validation.
# Done. Time:0.48117400199998883
# Validation performance:
#  Avg loss:1.808685
#
# Start evaluation.
# Done. Time:1.1375949979999405
# Test performance:
#  Accuracy:39.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:1.366213 [    0/ 3881]
# loss:1.769260 [ 3200/ 3881]
# Done. Time:2.9864281730001494
# Training performance:
#  Avg loss:1.507405
#
# Start validation.
# Done. Time:0.2976400229999854
# Validation performance:
#  Avg loss:1.807174
#
# Start evaluation.
# Done. Time:0.8214598179999939
# Test performance:
#  Accuracy:39.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:1.364272 [    0/ 3881]
# loss:1.761665 [ 3200/ 3881]
# Done. Time:3.0060756919999676
# Training performance:
#  Avg loss:1.500174
#
# Start validation.
# Done. Time:0.28878607399997236
# Validation performance:
#  Avg loss:1.803532
#
# Start evaluation.
# Done. Time:0.8197551549999389
# Test performance:
#  Accuracy:39.0%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.358221 [    0/ 3881]
# loss:1.755239 [ 3200/ 3881]
# Done. Time:3.8365989080000418
# Training performance:
#  Avg loss:1.492979
#
# Start validation.
# Done. Time:0.45295098299993697
# Validation performance:
#  Avg loss:1.800738
#
# Start evaluation.
# Done. Time:1.1263316649999524
# Test performance:
#  Accuracy:39.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:1.352876 [    0/ 3881]
# loss:1.749418 [ 3200/ 3881]
# Done. Time:2.957452437000029
# Training performance:
#  Avg loss:1.485825
#
# Start validation.
# Done. Time:0.33286966599985135
# Validation performance:
#  Avg loss:1.798223
#
# Start evaluation.
# Done. Time:0.8209322919999522
# Test performance:
#  Accuracy:40.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:1.347605 [    0/ 3881]
# loss:1.742939 [ 3200/ 3881]
# Done. Time:2.9831225380000888
# Training performance:
#  Avg loss:1.478752
#
# Start validation.
# Done. Time:0.2726235170000564
# Validation performance:
#  Avg loss:1.796193
#
# Start evaluation.
# Done. Time:0.836689682000042
# Test performance:
#  Accuracy:41.0%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:1.342882 [    0/ 3881]
# loss:1.736453 [ 3200/ 3881]
# Done. Time:3.987358270999948
# Training performance:
#  Avg loss:1.471672
#
# Start validation.
# Done. Time:0.4718870159999824
# Validation performance:
#  Avg loss:1.794101
#
# Start evaluation.
# Done. Time:1.0564576540000417
# Test performance:
#  Accuracy:41.5%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:1.336715 [    0/ 3881]
# loss:1.730467 [ 3200/ 3881]
# Done. Time:2.9909699629999977
# Training performance:
#  Avg loss:1.464760
#
# Start validation.
# Done. Time:0.2952662039999723
# Validation performance:
#  Avg loss:1.791813
#
# Start evaluation.
# Done. Time:0.8117142050000439
# Test performance:
#  Accuracy:41.5%
# Minimum validation loss:1.7918134246553694 at 50 epoch.
# Maximum accuracy:41.5 at 49 epoch.

# %% [markdown]
# ## Train aligned and scaled landmarks (parts-based)

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_align_scale_w))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_align_scale_parts,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_align_scale_parts,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_align_scale_parts,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_align_scale_p = np.array(val_losses)
test_accs_align_scale_p = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_align_scale_p.min()} at {np.argmin(val_losses_align_scale_p)+1} epoch.")
print(f"Maximum accuracy:{test_accs_align_scale_p.max()} at {np.argmax(test_accs_align_scale_p)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.314668 [    0/ 3881]
# loss:2.264850 [ 3200/ 3881]
# Done. Time:3.9150243460001093
# Training performance:
#  Avg loss:2.228225
#
# Start validation.
# Done. Time:0.2956777829999737
# Validation performance:
#  Avg loss:2.221466
#
# Start evaluation.
# Done. Time:0.831316230000084
# Test performance:
#  Accuracy:27.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.096471 [    0/ 3881]
# loss:2.159147 [ 3200/ 3881]
# Done. Time:2.9775532519997796
# Training performance:
#  Avg loss:2.030701
#
# Start validation.
# Done. Time:0.3126132800000505
# Validation performance:
#  Avg loss:2.117974
#
# Start evaluation.
# Done. Time:0.8624913950000064
# Test performance:
#  Accuracy:39.0%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.835004 [    0/ 3881]
# loss:2.059050 [ 3200/ 3881]
# Done. Time:2.950422030000027
# Training performance:
#  Avg loss:1.861049
#
# Start validation.
# Done. Time:0.4422076210000796
# Validation performance:
#  Avg loss:2.045086
#
# Start evaluation.
# Done. Time:1.0930070370000067
# Test performance:
#  Accuracy:49.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.609052 [    0/ 3881]
# loss:1.974164 [ 3200/ 3881]
# Done. Time:3.768464573999836
# Training performance:
#  Avg loss:1.736446
#
# Start validation.
# Done. Time:0.2904415189998417
# Validation performance:
#  Avg loss:1.981829
#
# Start evaluation.
# Done. Time:0.8218739670001014
# Test performance:
#  Accuracy:51.5%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.425196 [    0/ 3881]
# loss:1.899706 [ 3200/ 3881]
# Done. Time:2.9195575429998826
# Training performance:
#  Avg loss:1.638723
#
# Start validation.
# Done. Time:0.32947289900016585
# Validation performance:
#  Avg loss:1.925899
#
# Start evaluation.
# Done. Time:0.8309466900000189
# Test performance:
#  Accuracy:52.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.300598 [    0/ 3881]
# loss:1.814568 [ 3200/ 3881]
# Done. Time:2.9967149860001427
# Training performance:
#  Avg loss:1.555295
#
# Start validation.
# Done. Time:0.4314143750000312
# Validation performance:
#  Avg loss:1.876454
#
# Start evaluation.
# Done. Time:1.079751299999998
# Test performance:
#  Accuracy:52.5%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.205250 [    0/ 3881]
# loss:1.760146 [ 3200/ 3881]
# Done. Time:3.7521636279998347
# Training performance:
#  Avg loss:1.482862
#
# Start validation.
# Done. Time:0.3109348980001414
# Validation performance:
#  Avg loss:1.837972
#
# Start evaluation.
# Done. Time:0.822407855999927
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.118451 [    0/ 3881]
# loss:1.707959 [ 3200/ 3881]
# Done. Time:2.9261544389999017
# Training performance:
#  Avg loss:1.421924
#
# Start validation.
# Done. Time:0.3157934490000116
# Validation performance:
#  Avg loss:1.797616
#
# Start evaluation.
# Done. Time:0.8286802519999128
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.051610 [    0/ 3881]
# loss:1.657529 [ 3200/ 3881]
# Done. Time:2.97646943299992
# Training performance:
#  Avg loss:1.369220
#
# Start validation.
# Done. Time:0.3491332890000649
# Validation performance:
#  Avg loss:1.763852
#
# Start evaluation.
# Done. Time:1.0728413560000263
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:0.997453 [    0/ 3881]
# loss:1.613124 [ 3200/ 3881]
# Done. Time:3.922445813999957
# Training performance:
#  Avg loss:1.322363
#
# Start validation.
# Done. Time:0.29694031100007123
# Validation performance:
#  Avg loss:1.730868
#
# Start evaluation.
# Done. Time:0.8191052790000413
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:0.957034 [    0/ 3881]
# loss:1.569159 [ 3200/ 3881]
# Done. Time:3.029145696000114
# Training performance:
#  Avg loss:1.278901
#
# Start validation.
# Done. Time:0.2819773329999862
# Validation performance:
#  Avg loss:1.707735
#
# Start evaluation.
# Done. Time:0.8302197630000592
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:0.918348 [    0/ 3881]
# loss:1.529097 [ 3200/ 3881]
# Done. Time:2.9948386500000197
# Training performance:
#  Avg loss:1.240050
#
# Start validation.
# Done. Time:0.4362079249999624
# Validation performance:
#  Avg loss:1.673439
#
# Start evaluation.
# Done. Time:1.098525231999929
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:0.888801 [    0/ 3881]
# loss:1.496685 [ 3200/ 3881]
# Done. Time:3.8291830870000467
# Training performance:
#  Avg loss:1.203227
#
# Start validation.
# Done. Time:0.32050051500004884
# Validation performance:
#  Avg loss:1.646835
#
# Start evaluation.
# Done. Time:0.8339032779999798
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:0.863595 [    0/ 3881]
# loss:1.465610 [ 3200/ 3881]
# Done. Time:2.9823324499998307
# Training performance:
#  Avg loss:1.171026
#
# Start validation.
# Done. Time:0.3021749690001343
# Validation performance:
#  Avg loss:1.620739
#
# Start evaluation.
# Done. Time:0.8417616029998953
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:0.839780 [    0/ 3881]
# loss:1.436257 [ 3200/ 3881]
# Done. Time:2.9505511229999684
# Training performance:
#  Avg loss:1.141880
#
# Start validation.
# Done. Time:0.4757395889998861
# Validation performance:
#  Avg loss:1.605869
#
# Start evaluation.
# Done. Time:1.0970114219999232
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:0.818614 [    0/ 3881]
# loss:1.409450 [ 3200/ 3881]
# Done. Time:3.795874928000103
# Training performance:
#  Avg loss:1.114433
#
# Start validation.
# Done. Time:0.30104426899993086
# Validation performance:
#  Avg loss:1.573891
#
# Start evaluation.
# Done. Time:0.8373236929999166
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:0.803620 [    0/ 3881]
# loss:1.384289 [ 3200/ 3881]
# Done. Time:2.9457720569998855
# Training performance:
#  Avg loss:1.089368
#
# Start validation.
# Done. Time:0.3058040329999585
# Validation performance:
#  Avg loss:1.552544
#
# Start evaluation.
# Done. Time:0.8222186840000631
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:0.787804 [    0/ 3881]
# loss:1.364030 [ 3200/ 3881]
# Done. Time:2.952393776000008
# Training performance:
#  Avg loss:1.065442
#
# Start validation.
# Done. Time:0.5009699939998882
# Validation performance:
#  Avg loss:1.533334
#
# Start evaluation.
# Done. Time:1.070186829000022
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:0.773675 [    0/ 3881]
# loss:1.338745 [ 3200/ 3881]
# Done. Time:3.7012627379999685
# Training performance:
#  Avg loss:1.044065
#
# Start validation.
# Done. Time:0.3113160230000176
# Validation performance:
#  Avg loss:1.511987
#
# Start evaluation.
# Done. Time:0.9433280959999593
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:0.759753 [    0/ 3881]
# loss:1.319794 [ 3200/ 3881]
# Done. Time:4.3093498020000425
# Training performance:
#  Avg loss:1.022285
#
# Start validation.
# Done. Time:0.3096683259998372
# Validation performance:
#  Avg loss:1.492142
#
# Start evaluation.
# Done. Time:0.8464443989998927
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:0.745088 [    0/ 3881]
# loss:1.298906 [ 3200/ 3881]
# Done. Time:4.203553832000125
# Training performance:
#  Avg loss:1.003358
#
# Start validation.
# Done. Time:0.4752984300000662
# Validation performance:
#  Avg loss:1.473275
#
# Start evaluation.
# Done. Time:0.8988630609999291
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:0.731852 [    0/ 3881]
# loss:1.278004 [ 3200/ 3881]
# Done. Time:3.011675288000106
# Training performance:
#  Avg loss:0.984218
#
# Start validation.
# Done. Time:0.2974421470000834
# Validation performance:
#  Avg loss:1.456064
#
# Start evaluation.
# Done. Time:0.8128094619999047
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:0.720392 [    0/ 3881]
# loss:1.260613 [ 3200/ 3881]
# Done. Time:2.9508128859999943
# Training performance:
#  Avg loss:0.966325
#
# Start validation.
# Done. Time:0.3116390879999926
# Validation performance:
#  Avg loss:1.441547
#
# Start evaluation.
# Done. Time:0.80816933899996
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:0.710955 [    0/ 3881]
# loss:1.244015 [ 3200/ 3881]
# Done. Time:4.175517007000053
# Training performance:
#  Avg loss:0.949606
#
# Start validation.
# Done. Time:0.5113126480000574
# Validation performance:
#  Avg loss:1.425808
#
# Start evaluation.
# Done. Time:0.8442888030001541
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:0.699746 [    0/ 3881]
# loss:1.227440 [ 3200/ 3881]
# Done. Time:2.9252948820001166
# Training performance:
#  Avg loss:0.933901
#
# Start validation.
# Done. Time:0.32719377400007943
# Validation performance:
#  Avg loss:1.411231
#
# Start evaluation.
# Done. Time:0.8225392249999004
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:0.688657 [    0/ 3881]
# loss:1.210910 [ 3200/ 3881]
# Done. Time:2.9740741330001583
# Training performance:
#  Avg loss:0.918844
#
# Start validation.
# Done. Time:0.31348631399987426
# Validation performance:
#  Avg loss:1.394886
#
# Start evaluation.
# Done. Time:0.8100203340000007
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:0.676282 [    0/ 3881]
# loss:1.195743 [ 3200/ 3881]
# Done. Time:4.439142175000143
# Training performance:
#  Avg loss:0.904864
#
# Start validation.
# Done. Time:0.36656082199988305
# Validation performance:
#  Avg loss:1.379948
#
# Start evaluation.
# Done. Time:0.8184294469999713
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.663019 [    0/ 3881]
# loss:1.181093 [ 3200/ 3881]
# Done. Time:2.9647317000001294
# Training performance:
#  Avg loss:0.890947
#
# Start validation.
# Done. Time:0.30855915200004347
# Validation performance:
#  Avg loss:1.368938
#
# Start evaluation.
# Done. Time:0.8588589290000073
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.653564 [    0/ 3881]
# loss:1.166493 [ 3200/ 3881]
# Done. Time:2.994826934999992
# Training performance:
#  Avg loss:0.877738
#
# Start validation.
# Done. Time:0.29242261100012
# Validation performance:
#  Avg loss:1.356369
#
# Start evaluation.
# Done. Time:0.8353348569999071
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.640807 [    0/ 3881]
# loss:1.153097 [ 3200/ 3881]
# Done. Time:4.541695273999949
# Training performance:
#  Avg loss:0.865664
#
# Start validation.
# Done. Time:0.32088685199983047
# Validation performance:
#  Avg loss:1.350368
#
# Start evaluation.
# Done. Time:0.831462786999964
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.631141 [    0/ 3881]
# loss:1.139186 [ 3200/ 3881]
# Done. Time:2.9644340690001627
# Training performance:
#  Avg loss:0.853327
#
# Start validation.
# Done. Time:0.29634085799989407
# Validation performance:
#  Avg loss:1.370305
#
# Start evaluation.
# Done. Time:0.8333644199999526
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.619907 [    0/ 3881]
# loss:1.125814 [ 3200/ 3881]
# Done. Time:2.970228797000118
# Training performance:
#  Avg loss:0.841631
#
# Start validation.
# Done. Time:0.2971490659999745
# Validation performance:
#  Avg loss:1.333261
#
# Start evaluation.
# Done. Time:0.8445195129997956
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.618822 [    0/ 3881]
# loss:1.114245 [ 3200/ 3881]
# Done. Time:4.5160131029999775
# Training performance:
#  Avg loss:0.830684
#
# Start validation.
# Done. Time:0.3199256160000914
# Validation performance:
#  Avg loss:1.328874
#
# Start evaluation.
# Done. Time:0.8545497779998641
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.601857 [    0/ 3881]
# loss:1.100189 [ 3200/ 3881]
# Done. Time:2.9878507949999857
# Training performance:
#  Avg loss:0.822942
#
# Start validation.
# Done. Time:0.3164034139999785
# Validation performance:
#  Avg loss:1.333257
#
# Start evaluation.
# Done. Time:0.8253038980001293
# Test performance:
#  Accuracy:65.5%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.585952 [    0/ 3881]
# loss:1.089810 [ 3200/ 3881]
# Done. Time:2.9375418069998886
# Training performance:
#  Avg loss:0.810414
#
# Start validation.
# Done. Time:0.3355844220000108
# Validation performance:
#  Avg loss:1.320758
#
# Start evaluation.
# Done. Time:0.8284652510001251
# Test performance:
#  Accuracy:65.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.581316 [    0/ 3881]
# loss:1.078385 [ 3200/ 3881]
# Done. Time:4.477497668000069
# Training performance:
#  Avg loss:0.800109
#
# Start validation.
# Done. Time:0.2997092610000891
# Validation performance:
#  Avg loss:1.314302
#
# Start evaluation.
# Done. Time:0.8295162210001763
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.574620 [    0/ 3881]
# loss:1.067117 [ 3200/ 3881]
# Done. Time:2.9104426599999442
# Training performance:
#  Avg loss:0.790679
#
# Start validation.
# Done. Time:0.28046629200002826
# Validation performance:
#  Avg loss:1.307727
#
# Start evaluation.
# Done. Time:0.8017953240000679
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.565941 [    0/ 3881]
# loss:1.056037 [ 3200/ 3881]
# Done. Time:2.907329729000139
# Training performance:
#  Avg loss:0.781325
#
# Start validation.
# Done. Time:0.29842767999980424
# Validation performance:
#  Avg loss:1.302905
#
# Start evaluation.
# Done. Time:0.8098353140001109
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.557829 [    0/ 3881]
# loss:1.045331 [ 3200/ 3881]
# Done. Time:4.438482481999927
# Training performance:
#  Avg loss:0.772369
#
# Start validation.
# Done. Time:0.28757037900004434
# Validation performance:
#  Avg loss:1.298526
#
# Start evaluation.
# Done. Time:0.8339573490000021
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.549779 [    0/ 3881]
# loss:1.035111 [ 3200/ 3881]
# Done. Time:2.893570711999928
# Training performance:
#  Avg loss:0.763808
#
# Start validation.
# Done. Time:0.3069593499999428
# Validation performance:
#  Avg loss:1.293352
#
# Start evaluation.
# Done. Time:0.8591604389998793
# Test performance:
#  Accuracy:67.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.541356 [    0/ 3881]
# loss:1.025415 [ 3200/ 3881]
# Done. Time:2.9782414460000837
# Training performance:
#  Avg loss:0.755549
#
# Start validation.
# Done. Time:0.2985672889999478
# Validation performance:
#  Avg loss:1.288362
#
# Start evaluation.
# Done. Time:0.8316261050001685
# Test performance:
#  Accuracy:68.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.533597 [    0/ 3881]
# loss:1.015769 [ 3200/ 3881]
# Done. Time:4.551151398000002
# Training performance:
#  Avg loss:0.747560
#
# Start validation.
# Done. Time:0.32336922299987236
# Validation performance:
#  Avg loss:1.283991
#
# Start evaluation.
# Done. Time:0.8240860870000688
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.525382 [    0/ 3881]
# loss:1.006576 [ 3200/ 3881]
# Done. Time:2.904009373000008
# Training performance:
#  Avg loss:0.739762
#
# Start validation.
# Done. Time:0.29280060999985835
# Validation performance:
#  Avg loss:1.280113
#
# Start evaluation.
# Done. Time:0.8087587130000884
# Test performance:
#  Accuracy:68.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.517605 [    0/ 3881]
# loss:0.997494 [ 3200/ 3881]
# Done. Time:2.9189475169998786
# Training performance:
#  Avg loss:0.732122
#
# Start validation.
# Done. Time:0.3009394439998232
# Validation performance:
#  Avg loss:1.275737
#
# Start evaluation.
# Done. Time:0.9033618209998622
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.509584 [    0/ 3881]
# loss:0.988736 [ 3200/ 3881]
# Done. Time:4.296845707000102
# Training performance:
#  Avg loss:0.724705
#
# Start validation.
# Done. Time:0.32693812100001196
# Validation performance:
#  Avg loss:1.271164
#
# Start evaluation.
# Done. Time:0.8306154760000481
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.501912 [    0/ 3881]
# loss:0.980374 [ 3200/ 3881]
# Done. Time:2.9290717960000165
# Training performance:
#  Avg loss:0.717547
#
# Start validation.
# Done. Time:0.33032144699996024
# Validation performance:
#  Avg loss:1.266369
#
# Start evaluation.
# Done. Time:0.8325624860001426
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.494438 [    0/ 3881]
# loss:0.972286 [ 3200/ 3881]
# Done. Time:3.002157186999966
# Training performance:
#  Avg loss:0.710598
#
# Start validation.
# Done. Time:0.30110266399992724
# Validation performance:
#  Avg loss:1.261454
#
# Start evaluation.
# Done. Time:0.9749856769999496
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.486977 [    0/ 3881]
# loss:0.964379 [ 3200/ 3881]
# Done. Time:4.311318632999928
# Training performance:
#  Avg loss:0.703881
#
# Start validation.
# Done. Time:0.3187882259999242
# Validation performance:
#  Avg loss:1.257530
#
# Start evaluation.
# Done. Time:0.829289794000033
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.479964 [    0/ 3881]
# loss:0.956783 [ 3200/ 3881]
# Done. Time:2.9476066089998767
# Training performance:
#  Avg loss:0.697336
#
# Start validation.
# Done. Time:0.3116235009999855
# Validation performance:
#  Avg loss:1.252295
#
# Start evaluation.
# Done. Time:0.8709976929999357
# Test performance:
#  Accuracy:68.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.472360 [    0/ 3881]
# loss:0.949628 [ 3200/ 3881]
# Done. Time:4.759475259000055
# Training performance:
#  Avg loss:0.690921
#
# Start validation.
# Done. Time:0.5646414329999061
# Validation performance:
#  Avg loss:1.247121
#
# Start evaluation.
# Done. Time:1.1276091020001786
# Test performance:
#  Accuracy:67.5%
# Minimum validation loss:1.2471209509032113 at 50 epoch.
# Maximum accuracy:68.5 at 42 epoch.

# %% [markdown]
# ## Plot results

# %%
import matplotlib.pyplot as plt

plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(val_losses_origin)+1)
plt.plot(xs, val_losses_origin, label="Origin", marker=".")
plt.plot(xs, val_losses_align_w, label="Align_W", marker=".")
plt.plot(xs, val_losses_align_p, label="Align_P", marker=".")
plt.plot(xs, val_losses_align_scale_w, label="Align-Scale_W", marker=".")
plt.plot(xs, val_losses_align_scale_p, label="Align-Scale_P", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Validation loss")
plt.legend()
plt.show()

# %%
plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(test_accs)+1)
ys = test_accs
plt.plot(xs, test_accs_origin, label="Origin", marker=".")
plt.plot(xs, test_accs_align_w, label="Align_W", marker=".")
plt.plot(xs, test_accs_align_p, label="Align_P", marker=".")
plt.plot(xs, test_accs_align_scale_w, label="Align-Scale_W", marker=".")
plt.plot(xs, test_accs_align_scale_p, label="Align-Scale_P", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# # Appendix: abration of alignment and scaling modes

# %%
_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
trans_select_feature = SelectLandmarksAndFeature(landmarks=use_landmarks, features=use_features)
trans_repnan = ReplaceNan()

trans_align_f_scale_f = PartsBasedNormalization(align_mode="framewise", scale_mode="framewise")
trans_align_f_scale_u = PartsBasedNormalization(align_mode="framewise", scale_mode="unique")
trans_align_u_scale_f = PartsBasedNormalization(align_mode="unique", scale_mode="framewise")
trans_align_u_scale_u = PartsBasedNormalization(align_mode="unique", scale_mode="unique")

# %%
pre_transforms_align_f_scale_f = Compose([trans_select_feature,
                                         trans_repnan,
                                         trans_align_f_scale_f])
pre_transforms_align_f_scale_u = Compose([trans_select_feature,
                                         trans_repnan,
                                         trans_align_f_scale_u])
pre_transforms_align_u_scale_f = Compose([trans_select_feature,
                                         trans_repnan,
                                         trans_align_u_scale_f])
pre_transforms_align_u_scale_u = Compose([trans_select_feature,
                                         trans_repnan,
                                         trans_align_u_scale_u])

# %% [markdown]
# ### Framewise alignment and framewise scaling

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_align_scale_w))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_align_f_scale_f,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_align_f_scale_f,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_align_f_scale_f,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_align_f_scale_f = np.array(val_losses)
test_accs_align_f_scale_f = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_align_f_scale_f.min()} at {np.argmin(val_losses_align_f_scale_f)+1} epoch.")
print(f"Maximum accuracy:{test_accs_align_f_scale_f.max()} at {np.argmax(test_accs_align_f_scale_f)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.336459 [    0/ 3881]
# loss:2.278139 [ 3200/ 3881]
# Done. Time:2.902358277999838
# Training performance:
#  Avg loss:2.246005
#
# Start validation.
# Done. Time:0.3137262239999927
# Validation performance:
#  Avg loss:2.231176
#
# Start evaluation.
# Done. Time:0.8316901119999329
# Test performance:
#  Accuracy:27.0%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.055892 [    0/ 3881]
# loss:2.147763 [ 3200/ 3881]
# Done. Time:4.507112296999821
# Training performance:
#  Avg loss:2.039864
#
# Start validation.
# Done. Time:0.27967639400003463
# Validation performance:
#  Avg loss:2.129705
#
# Start evaluation.
# Done. Time:1.1664243019999958
# Test performance:
#  Accuracy:36.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.762538 [    0/ 3881]
# loss:2.026674 [ 3200/ 3881]
# Done. Time:5.823536370000056
# Training performance:
#  Avg loss:1.843426
#
# Start validation.
# Done. Time:0.7615479969999797
# Validation performance:
#  Avg loss:2.041556
#
# Start evaluation.
# Done. Time:0.834892704999902
# Test performance:
#  Accuracy:37.5%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.520738 [    0/ 3881]
# loss:1.928383 [ 3200/ 3881]
# Done. Time:4.5319735030000174
# Training performance:
#  Avg loss:1.702795
#
# Start validation.
# Done. Time:0.2912081730000864
# Validation performance:
#  Avg loss:1.987312
#
# Start evaluation.
# Done. Time:0.8561498500000653
# Test performance:
#  Accuracy:42.5%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.340875 [    0/ 3881]
# loss:1.848343 [ 3200/ 3881]
# Done. Time:2.9089216770000803
# Training performance:
#  Avg loss:1.600834
#
# Start validation.
# Done. Time:0.29892544500012264
# Validation performance:
#  Avg loss:1.943580
#
# Start evaluation.
# Done. Time:0.8557572509998863
# Test performance:
#  Accuracy:42.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.213092 [    0/ 3881]
# loss:1.780557 [ 3200/ 3881]
# Done. Time:2.978611985000043
# Training performance:
#  Avg loss:1.522479
#
# Start validation.
# Done. Time:0.303910488999918
# Validation performance:
#  Avg loss:1.906919
#
# Start evaluation.
# Done. Time:1.3350757090001935
# Test performance:
#  Accuracy:46.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.123475 [    0/ 3881]
# loss:1.730332 [ 3200/ 3881]
# Done. Time:4.335955822999949
# Training performance:
#  Avg loss:1.456836
#
# Start validation.
# Done. Time:0.3104004030001306
# Validation performance:
#  Avg loss:1.885612
#
# Start evaluation.
# Done. Time:0.822723705000044
# Test performance:
#  Accuracy:49.5%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.055289 [    0/ 3881]
# loss:1.674444 [ 3200/ 3881]
# Done. Time:2.984197387999984
# Training performance:
#  Avg loss:1.402383
#
# Start validation.
# Done. Time:0.3061198329999115
# Validation performance:
#  Avg loss:1.842306
#
# Start evaluation.
# Done. Time:0.8219031630001155
# Test performance:
#  Accuracy:51.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.008120 [    0/ 3881]
# loss:1.630170 [ 3200/ 3881]
# Done. Time:2.8856987710000794
# Training performance:
#  Avg loss:1.353490
#
# Start validation.
# Done. Time:0.29913540100005775
# Validation performance:
#  Avg loss:1.808315
#
# Start evaluation.
# Done. Time:1.0261200939999071
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:0.964825 [    0/ 3881]
# loss:1.591879 [ 3200/ 3881]
# Done. Time:4.148564464999936
# Training performance:
#  Avg loss:1.311074
#
# Start validation.
# Done. Time:0.2959078840001439
# Validation performance:
#  Avg loss:1.779049
#
# Start evaluation.
# Done. Time:0.869545528000117
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:0.929863 [    0/ 3881]
# loss:1.557073 [ 3200/ 3881]
# Done. Time:2.9485837750000883
# Training performance:
#  Avg loss:1.272966
#
# Start validation.
# Done. Time:0.29394412200008446
# Validation performance:
#  Avg loss:1.751990
#
# Start evaluation.
# Done. Time:0.8176041639999312
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:0.899153 [    0/ 3881]
# loss:1.524409 [ 3200/ 3881]
# Done. Time:2.971591435999926
# Training performance:
#  Avg loss:1.238558
#
# Start validation.
# Done. Time:0.300787229999969
# Validation performance:
#  Avg loss:1.727403
#
# Start evaluation.
# Done. Time:1.0829903499998181
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:0.860375 [    0/ 3881]
# loss:1.494955 [ 3200/ 3881]
# Done. Time:4.05345153799999
# Training performance:
#  Avg loss:1.208764
#
# Start validation.
# Done. Time:0.30001924699990923
# Validation performance:
#  Avg loss:1.694865
#
# Start evaluation.
# Done. Time:0.8149643360000027
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:0.847134 [    0/ 3881]
# loss:1.466175 [ 3200/ 3881]
# Done. Time:2.9185299270000087
# Training performance:
#  Avg loss:1.178575
#
# Start validation.
# Done. Time:0.3179989239999941
# Validation performance:
#  Avg loss:1.669315
#
# Start evaluation.
# Done. Time:0.825944692999883
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:0.830270 [    0/ 3881]
# loss:1.441062 [ 3200/ 3881]
# Done. Time:2.96083307899994
# Training performance:
#  Avg loss:1.151146
#
# Start validation.
# Done. Time:0.30410779599992566
# Validation performance:
#  Avg loss:1.642448
#
# Start evaluation.
# Done. Time:1.0822317199999816
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:0.809219 [    0/ 3881]
# loss:1.417357 [ 3200/ 3881]
# Done. Time:3.9845945770000526
# Training performance:
#  Avg loss:1.126860
#
# Start validation.
# Done. Time:0.3015956310000547
# Validation performance:
#  Avg loss:1.618753
#
# Start evaluation.
# Done. Time:0.8500069899998834
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:0.796020 [    0/ 3881]
# loss:1.395703 [ 3200/ 3881]
# Done. Time:2.883290282999951
# Training performance:
#  Avg loss:1.103444
#
# Start validation.
# Done. Time:0.2915837499999725
# Validation performance:
#  Avg loss:1.593411
#
# Start evaluation.
# Done. Time:0.8214975619998768
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:0.779968 [    0/ 3881]
# loss:1.375762 [ 3200/ 3881]
# Done. Time:2.883844109000165
# Training performance:
#  Avg loss:1.082535
#
# Start validation.
# Done. Time:0.3079205340000044
# Validation performance:
#  Avg loss:1.575079
#
# Start evaluation.
# Done. Time:1.0440426119998847
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:0.764754 [    0/ 3881]
# loss:1.357091 [ 3200/ 3881]
# Done. Time:4.044553975999861
# Training performance:
#  Avg loss:1.061310
#
# Start validation.
# Done. Time:0.33443374800003767
# Validation performance:
#  Avg loss:1.551180
#
# Start evaluation.
# Done. Time:0.8629741949998788
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:0.752878 [    0/ 3881]
# loss:1.338086 [ 3200/ 3881]
# Done. Time:2.9582418640000014
# Training performance:
#  Avg loss:1.042240
#
# Start validation.
# Done. Time:0.2918946300001153
# Validation performance:
#  Avg loss:1.550247
#
# Start evaluation.
# Done. Time:0.8310930570000892
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:0.743720 [    0/ 3881]
# loss:1.321518 [ 3200/ 3881]
# Done. Time:3.0175409250000484
# Training performance:
#  Avg loss:1.022742
#
# Start validation.
# Done. Time:0.303574400999878
# Validation performance:
#  Avg loss:1.512498
#
# Start evaluation.
# Done. Time:1.122546591000173
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:0.728508 [    0/ 3881]
# loss:1.303774 [ 3200/ 3881]
# Done. Time:3.965199359000053
# Training performance:
#  Avg loss:1.003852
#
# Start validation.
# Done. Time:0.29879377299994303
# Validation performance:
#  Avg loss:1.496923
#
# Start evaluation.
# Done. Time:0.8316574400000718
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:0.719559 [    0/ 3881]
# loss:1.286879 [ 3200/ 3881]
# Done. Time:2.9882666649998555
# Training performance:
#  Avg loss:0.985771
#
# Start validation.
# Done. Time:0.278605639000034
# Validation performance:
#  Avg loss:1.479922
#
# Start evaluation.
# Done. Time:0.8194595459999618
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:0.712038 [    0/ 3881]
# loss:1.270636 [ 3200/ 3881]
# Done. Time:3.0039001550001103
# Training performance:
#  Avg loss:0.969519
#
# Start validation.
# Done. Time:0.4113312950000818
# Validation performance:
#  Avg loss:1.462560
#
# Start evaluation.
# Done. Time:1.0988774759998705
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:0.700543 [    0/ 3881]
# loss:1.255709 [ 3200/ 3881]
# Done. Time:3.9005869920001714
# Training performance:
#  Avg loss:0.953391
#
# Start validation.
# Done. Time:0.283175607999965
# Validation performance:
#  Avg loss:1.445432
#
# Start evaluation.
# Done. Time:0.8426667229998657
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:0.689895 [    0/ 3881]
# loss:1.239966 [ 3200/ 3881]
# Done. Time:2.9645688289999725
# Training performance:
#  Avg loss:0.938643
#
# Start validation.
# Done. Time:0.2930149139999685
# Validation performance:
#  Avg loss:1.425932
#
# Start evaluation.
# Done. Time:0.8877885929998683
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:0.680986 [    0/ 3881]
# loss:1.225718 [ 3200/ 3881]
# Done. Time:2.9346455999998398
# Training performance:
#  Avg loss:0.923694
#
# Start validation.
# Done. Time:0.4728045370000018
# Validation performance:
#  Avg loss:1.410723
#
# Start evaluation.
# Done. Time:1.087123713999972
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.664134 [    0/ 3881]
# loss:1.211283 [ 3200/ 3881]
# Done. Time:5.099517566000031
# Training performance:
#  Avg loss:0.908700
#
# Start validation.
# Done. Time:0.4733445430001666
# Validation performance:
#  Avg loss:1.393300
#
# Start evaluation.
# Done. Time:0.8817082190000747
# Test performance:
#  Accuracy:63.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.651350 [    0/ 3881]
# loss:1.198127 [ 3200/ 3881]
# Done. Time:2.8722631319999437
# Training performance:
#  Avg loss:0.894807
#
# Start validation.
# Done. Time:0.2912165099999129
# Validation performance:
#  Avg loss:1.380406
#
# Start evaluation.
# Done. Time:0.8222861170002034
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.641805 [    0/ 3881]
# loss:1.183736 [ 3200/ 3881]
# Done. Time:3.909174586000063
# Training performance:
#  Avg loss:0.881732
#
# Start validation.
# Done. Time:0.45739578300003814
# Validation performance:
#  Avg loss:1.365934
#
# Start evaluation.
# Done. Time:1.04799479899998
# Test performance:
#  Accuracy:63.5%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.631830 [    0/ 3881]
# loss:1.171178 [ 3200/ 3881]
# Done. Time:2.9272408799999994
# Training performance:
#  Avg loss:0.868842
#
# Start validation.
# Done. Time:0.2901721620000899
# Validation performance:
#  Avg loss:1.354744
#
# Start evaluation.
# Done. Time:0.8362874680001369
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.621855 [    0/ 3881]
# loss:1.159293 [ 3200/ 3881]
# Done. Time:2.914662577999934
# Training performance:
#  Avg loss:0.856791
#
# Start validation.
# Done. Time:0.2916023640000276
# Validation performance:
#  Avg loss:1.343057
#
# Start evaluation.
# Done. Time:0.8219989850001639
# Test performance:
#  Accuracy:63.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.613874 [    0/ 3881]
# loss:1.147469 [ 3200/ 3881]
# Done. Time:4.003067458000032
# Training performance:
#  Avg loss:0.845321
#
# Start validation.
# Done. Time:0.44439022900019154
# Validation performance:
#  Avg loss:1.332980
#
# Start evaluation.
# Done. Time:1.036802650000027
# Test performance:
#  Accuracy:63.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.605324 [    0/ 3881]
# loss:1.136464 [ 3200/ 3881]
# Done. Time:2.938931516999901
# Training performance:
#  Avg loss:0.833687
#
# Start validation.
# Done. Time:0.32146840499990503
# Validation performance:
#  Avg loss:1.323576
#
# Start evaluation.
# Done. Time:0.8321019400000296
# Test performance:
#  Accuracy:63.5%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.595832 [    0/ 3881]
# loss:1.125440 [ 3200/ 3881]
# Done. Time:2.9675588279999374
# Training performance:
#  Avg loss:0.823088
#
# Start validation.
# Done. Time:0.3085579640001015
# Validation performance:
#  Avg loss:1.313829
#
# Start evaluation.
# Done. Time:0.8389217960000224
# Test performance:
#  Accuracy:63.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.586726 [    0/ 3881]
# loss:1.115050 [ 3200/ 3881]
# Done. Time:4.1529257789998155
# Training performance:
#  Avg loss:0.812721
#
# Start validation.
# Done. Time:0.4472637039998517
# Validation performance:
#  Avg loss:1.304194
#
# Start evaluation.
# Done. Time:0.9559929609999926
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.577717 [    0/ 3881]
# loss:1.105161 [ 3200/ 3881]
# Done. Time:3.013676033000138
# Training performance:
#  Avg loss:0.802775
#
# Start validation.
# Done. Time:0.29987699399998746
# Validation performance:
#  Avg loss:1.294662
#
# Start evaluation.
# Done. Time:0.8271752830000878
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.569049 [    0/ 3881]
# loss:1.095466 [ 3200/ 3881]
# Done. Time:3.0021103869999024
# Training performance:
#  Avg loss:0.793249
#
# Start validation.
# Done. Time:0.31632514900002207
# Validation performance:
#  Avg loss:1.285645
#
# Start evaluation.
# Done. Time:0.840997052000148
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.559821 [    0/ 3881]
# loss:1.085982 [ 3200/ 3881]
# Done. Time:4.235468098999945
# Training performance:
#  Avg loss:0.783981
#
# Start validation.
# Done. Time:0.4761529239999618
# Validation performance:
#  Avg loss:1.276638
#
# Start evaluation.
# Done. Time:0.8514950919998228
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.550897 [    0/ 3881]
# loss:1.076612 [ 3200/ 3881]
# Done. Time:2.991764810000177
# Training performance:
#  Avg loss:0.775036
#
# Start validation.
# Done. Time:0.2982128379999267
# Validation performance:
#  Avg loss:1.267657
#
# Start evaluation.
# Done. Time:0.8714329370000087
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.541714 [    0/ 3881]
# loss:1.067715 [ 3200/ 3881]
# Done. Time:3.0103075179999905
# Training performance:
#  Avg loss:0.766385
#
# Start validation.
# Done. Time:0.3032782660000066
# Validation performance:
#  Avg loss:1.259134
#
# Start evaluation.
# Done. Time:0.8293663429999469
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.532438 [    0/ 3881]
# loss:1.059171 [ 3200/ 3881]
# Done. Time:4.505725813000026
# Training performance:
#  Avg loss:0.757900
#
# Start validation.
# Done. Time:0.3192009800000051
# Validation performance:
#  Avg loss:1.251038
#
# Start evaluation.
# Done. Time:0.8137282970001252
# Test performance:
#  Accuracy:65.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.523351 [    0/ 3881]
# loss:1.050963 [ 3200/ 3881]
# Done. Time:3.01501905300006
# Training performance:
#  Avg loss:0.749705
#
# Start validation.
# Done. Time:0.3030997529999695
# Validation performance:
#  Avg loss:1.242547
#
# Start evaluation.
# Done. Time:0.8376277499999105
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.514468 [    0/ 3881]
# loss:1.043112 [ 3200/ 3881]
# Done. Time:2.930948918000013
# Training performance:
#  Avg loss:0.741679
#
# Start validation.
# Done. Time:0.30207660900009614
# Validation performance:
#  Avg loss:1.234446
#
# Start evaluation.
# Done. Time:0.8309733890000643
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.505552 [    0/ 3881]
# loss:1.035346 [ 3200/ 3881]
# Done. Time:4.46341200400002
# Training performance:
#  Avg loss:0.733976
#
# Start validation.
# Done. Time:0.3100601539999843
# Validation performance:
#  Avg loss:1.226061
#
# Start evaluation.
# Done. Time:0.841872641000009
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.496948 [    0/ 3881]
# loss:1.027939 [ 3200/ 3881]
# Done. Time:2.9406242329998804
# Training performance:
#  Avg loss:0.726330
#
# Start validation.
# Done. Time:0.27824904599992806
# Validation performance:
#  Avg loss:1.218098
#
# Start evaluation.
# Done. Time:0.9468172889999096
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.488483 [    0/ 3881]
# loss:1.020648 [ 3200/ 3881]
# Done. Time:2.896394814000132
# Training performance:
#  Avg loss:0.718941
#
# Start validation.
# Done. Time:0.30269565999992665
# Validation performance:
#  Avg loss:1.210218
#
# Start evaluation.
# Done. Time:0.8451395080001021
# Test performance:
#  Accuracy:68.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.479998 [    0/ 3881]
# loss:1.013592 [ 3200/ 3881]
# Done. Time:4.500201457000003
# Training performance:
#  Avg loss:0.711873
#
# Start validation.
# Done. Time:0.288646437999887
# Validation performance:
#  Avg loss:1.202331
#
# Start evaluation.
# Done. Time:0.8390379960001155
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.472053 [    0/ 3881]
# loss:1.006670 [ 3200/ 3881]
# Done. Time:2.9228262299998278
# Training performance:
#  Avg loss:0.704869
#
# Start validation.
# Done. Time:0.2892579489998752
# Validation performance:
#  Avg loss:1.194827
#
# Start evaluation.
# Done. Time:0.8261734130001059
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.464056 [    0/ 3881]
# loss:1.000419 [ 3200/ 3881]
# Done. Time:2.9168173040000056
# Training performance:
#  Avg loss:0.697952
#
# Start validation.
# Done. Time:0.2899130270000114
# Validation performance:
#  Avg loss:1.187522
#
# Start evaluation.
# Done. Time:0.8220359320000625
# Test performance:
#  Accuracy:68.5%
# Minimum validation loss:1.1875216279711043 at 50 epoch.
# Maximum accuracy:68.5 at 48 epoch.

# %% [markdown]
# ### Framewise alignment and unique scaling

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_align_scale_w))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_align_f_scale_u,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_align_f_scale_u,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_align_f_scale_u,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_align_f_scale_u = np.array(val_losses)
test_accs_align_f_scale_u = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_align_f_scale_u.min()} at {np.argmin(val_losses_align_f_scale_u)+1} epoch.")
print(f"Maximum accuracy:{test_accs_align_f_scale_u.max()} at {np.argmax(test_accs_align_f_scale_u)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.254783 [    0/ 3881]
# loss:2.245947 [ 3200/ 3881]
# Done. Time:2.9423473540000487
# Training performance:
#  Avg loss:2.235934
#
# Start validation.
# Done. Time:0.30090097500010415
# Validation performance:
#  Avg loss:2.211107
#
# Start evaluation.
# Done. Time:0.8239323100001457
# Test performance:
#  Accuracy:24.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.038409 [    0/ 3881]
# loss:2.138921 [ 3200/ 3881]
# Done. Time:3.402053528000124
# Training performance:
#  Avg loss:2.028797
#
# Start validation.
# Done. Time:0.5022977010000886
# Validation performance:
#  Avg loss:2.122780
#
# Start evaluation.
# Done. Time:1.1742794050001066
# Test performance:
#  Accuracy:35.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.768165 [    0/ 3881]
# loss:2.028230 [ 3200/ 3881]
# Done. Time:3.2284186489998774
# Training performance:
#  Avg loss:1.858152
#
# Start validation.
# Done. Time:0.31197059700002683
# Validation performance:
#  Avg loss:2.054029
#
# Start evaluation.
# Done. Time:0.8389589040000374
# Test performance:
#  Accuracy:41.5%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.544041 [    0/ 3881]
# loss:1.926395 [ 3200/ 3881]
# Done. Time:3.032940090000011
# Training performance:
#  Avg loss:1.729705
#
# Start validation.
# Done. Time:0.29836805300010383
# Validation performance:
#  Avg loss:1.996996
#
# Start evaluation.
# Done. Time:0.8210271139998895
# Test performance:
#  Accuracy:46.5%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.364638 [    0/ 3881]
# loss:1.845043 [ 3200/ 3881]
# Done. Time:3.6716363789998923
# Training performance:
#  Avg loss:1.628942
#
# Start validation.
# Done. Time:0.5080045060001339
# Validation performance:
#  Avg loss:1.942463
#
# Start evaluation.
# Done. Time:1.2066867849998744
# Test performance:
#  Accuracy:48.0%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.237569 [    0/ 3881]
# loss:1.778438 [ 3200/ 3881]
# Done. Time:3.0737795249999635
# Training performance:
#  Avg loss:1.549607
#
# Start validation.
# Done. Time:0.3112605700000586
# Validation performance:
#  Avg loss:1.895840
#
# Start evaluation.
# Done. Time:0.8324196319999828
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.148238 [    0/ 3881]
# loss:1.720474 [ 3200/ 3881]
# Done. Time:4.500514889999977
# Training performance:
#  Avg loss:1.483185
#
# Start validation.
# Done. Time:0.4328997550001077
# Validation performance:
#  Avg loss:1.855895
#
# Start evaluation.
# Done. Time:0.8468872089999877
# Test performance:
#  Accuracy:51.5%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.077571 [    0/ 3881]
# loss:1.671215 [ 3200/ 3881]
# Done. Time:4.613969988999997
# Training performance:
#  Avg loss:1.424059
#
# Start validation.
# Done. Time:0.3174084749998656
# Validation performance:
#  Avg loss:1.817312
#
# Start evaluation.
# Done. Time:0.8995613130000493
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.023471 [    0/ 3881]
# loss:1.622387 [ 3200/ 3881]
# Done. Time:2.997557737000079
# Training performance:
#  Avg loss:1.372127
#
# Start validation.
# Done. Time:0.32268085800001245
# Validation performance:
#  Avg loss:1.780199
#
# Start evaluation.
# Done. Time:0.846625308000057
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:0.983272 [    0/ 3881]
# loss:1.579747 [ 3200/ 3881]
# Done. Time:3.0584300470000017
# Training performance:
#  Avg loss:1.324035
#
# Start validation.
# Done. Time:0.34166939000010643
# Validation performance:
#  Avg loss:1.751125
#
# Start evaluation.
# Done. Time:1.1180180519997975
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:0.943767 [    0/ 3881]
# loss:1.543288 [ 3200/ 3881]
# Done. Time:4.228423507000116
# Training performance:
#  Avg loss:1.281702
#
# Start validation.
# Done. Time:0.3020533330000035
# Validation performance:
#  Avg loss:1.723412
#
# Start evaluation.
# Done. Time:0.8573414520001279
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:0.914364 [    0/ 3881]
# loss:1.505885 [ 3200/ 3881]
# Done. Time:3.0104091639998387
# Training performance:
#  Avg loss:1.242635
#
# Start validation.
# Done. Time:0.3061695320000126
# Validation performance:
#  Avg loss:1.696065
#
# Start evaluation.
# Done. Time:0.823142899000004
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:0.887705 [    0/ 3881]
# loss:1.470304 [ 3200/ 3881]
# Done. Time:3.022448347000136
# Training performance:
#  Avg loss:1.206050
#
# Start validation.
# Done. Time:0.4034160310000061
# Validation performance:
#  Avg loss:1.658213
#
# Start evaluation.
# Done. Time:1.1521481409999978
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:0.856499 [    0/ 3881]
# loss:1.438197 [ 3200/ 3881]
# Done. Time:3.956327201000022
# Training performance:
#  Avg loss:1.174282
#
# Start validation.
# Done. Time:0.29559208600016973
# Validation performance:
#  Avg loss:1.637243
#
# Start evaluation.
# Done. Time:0.8563636489998316
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:0.845185 [    0/ 3881]
# loss:1.411596 [ 3200/ 3881]
# Done. Time:3.033223813999939
# Training performance:
#  Avg loss:1.142990
#
# Start validation.
# Done. Time:0.30111558900011914
# Validation performance:
#  Avg loss:1.609653
#
# Start evaluation.
# Done. Time:0.8317108570001892
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:0.821892 [    0/ 3881]
# loss:1.383031 [ 3200/ 3881]
# Done. Time:3.056482292000055
# Training performance:
#  Avg loss:1.113419
#
# Start validation.
# Done. Time:0.5053828360000807
# Validation performance:
#  Avg loss:1.582564
#
# Start evaluation.
# Done. Time:1.1098130459999993
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:0.800007 [    0/ 3881]
# loss:1.356648 [ 3200/ 3881]
# Done. Time:3.538899037999954
# Training performance:
#  Avg loss:1.087187
#
# Start validation.
# Done. Time:0.3002507189999051
# Validation performance:
#  Avg loss:1.560010
#
# Start evaluation.
# Done. Time:0.9185944880000534
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:0.785179 [    0/ 3881]
# loss:1.334594 [ 3200/ 3881]
# Done. Time:2.965327731000116
# Training performance:
#  Avg loss:1.063103
#
# Start validation.
# Done. Time:0.3085297249999712
# Validation performance:
#  Avg loss:1.536733
#
# Start evaluation.
# Done. Time:0.8393107299998519
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:0.768601 [    0/ 3881]
# loss:1.312570 [ 3200/ 3881]
# Done. Time:3.3053088169999683
# Training performance:
#  Avg loss:1.039793
#
# Start validation.
# Done. Time:0.49095794800018666
# Validation performance:
#  Avg loss:1.514803
#
# Start evaluation.
# Done. Time:1.1048735539998233
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:0.755271 [    0/ 3881]
# loss:1.291544 [ 3200/ 3881]
# Done. Time:3.4866650310000296
# Training performance:
#  Avg loss:1.018223
#
# Start validation.
# Done. Time:0.3250171399999999
# Validation performance:
#  Avg loss:1.493176
#
# Start evaluation.
# Done. Time:0.9104866490001768
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:0.740981 [    0/ 3881]
# loss:1.272423 [ 3200/ 3881]
# Done. Time:3.001855957999851
# Training performance:
#  Avg loss:0.997987
#
# Start validation.
# Done. Time:0.31159540199996627
# Validation performance:
#  Avg loss:1.473143
#
# Start evaluation.
# Done. Time:0.860877617999904
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:0.726587 [    0/ 3881]
# loss:1.253647 [ 3200/ 3881]
# Done. Time:3.5810439260001203
# Training performance:
#  Avg loss:0.978926
#
# Start validation.
# Done. Time:0.4977324699998462
# Validation performance:
#  Avg loss:1.454166
#
# Start evaluation.
# Done. Time:1.1673110140000063
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:0.713571 [    0/ 3881]
# loss:1.236002 [ 3200/ 3881]
# Done. Time:3.1586725309998656
# Training performance:
#  Avg loss:0.960921
#
# Start validation.
# Done. Time:0.31774997599995913
# Validation performance:
#  Avg loss:1.435611
#
# Start evaluation.
# Done. Time:0.8976961209998535
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:0.700280 [    0/ 3881]
# loss:1.219494 [ 3200/ 3881]
# Done. Time:2.9518322149999676
# Training performance:
#  Avg loss:0.943966
#
# Start validation.
# Done. Time:0.29727302199989936
# Validation performance:
#  Avg loss:1.418963
#
# Start evaluation.
# Done. Time:0.8967301479999605
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:0.687856 [    0/ 3881]
# loss:1.203935 [ 3200/ 3881]
# Done. Time:3.7232535759999337
# Training performance:
#  Avg loss:0.927796
#
# Start validation.
# Done. Time:0.509192062000011
# Validation performance:
#  Avg loss:1.402816
#
# Start evaluation.
# Done. Time:1.1441180289998556
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:0.675605 [    0/ 3881]
# loss:1.187362 [ 3200/ 3881]
# Done. Time:3.010784611999952
# Training performance:
#  Avg loss:0.912772
#
# Start validation.
# Done. Time:0.298684835000131
# Validation performance:
#  Avg loss:1.389493
#
# Start evaluation.
# Done. Time:0.8482609929999398
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:0.666282 [    0/ 3881]
# loss:1.173752 [ 3200/ 3881]
# Done. Time:2.9387845850001213
# Training performance:
#  Avg loss:0.898068
#
# Start validation.
# Done. Time:0.314569616999961
# Validation performance:
#  Avg loss:1.374101
#
# Start evaluation.
# Done. Time:0.8651853789999677
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.652250 [    0/ 3881]
# loss:1.160172 [ 3200/ 3881]
# Done. Time:3.8815500359999078
# Training performance:
#  Avg loss:0.884376
#
# Start validation.
# Done. Time:0.4708220600000459
# Validation performance:
#  Avg loss:1.360141
#
# Start evaluation.
# Done. Time:1.0803765339999245
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.640710 [    0/ 3881]
# loss:1.146634 [ 3200/ 3881]
# Done. Time:2.973630193999952
# Training performance:
#  Avg loss:0.871191
#
# Start validation.
# Done. Time:0.3037875150000673
# Validation performance:
#  Avg loss:1.346798
#
# Start evaluation.
# Done. Time:0.842338952000091
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.631474 [    0/ 3881]
# loss:1.134098 [ 3200/ 3881]
# Done. Time:2.996650567000188
# Training performance:
#  Avg loss:0.858615
#
# Start validation.
# Done. Time:0.3087886329999492
# Validation performance:
#  Avg loss:1.334762
#
# Start evaluation.
# Done. Time:0.81711693200009
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.622387 [    0/ 3881]
# loss:1.120548 [ 3200/ 3881]
# Done. Time:3.916179171000067
# Training performance:
#  Avg loss:0.846242
#
# Start validation.
# Done. Time:0.502602521000199
# Validation performance:
#  Avg loss:1.327030
#
# Start evaluation.
# Done. Time:1.0676981460001116
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.611129 [    0/ 3881]
# loss:1.111788 [ 3200/ 3881]
# Done. Time:2.9625904310000806
# Training performance:
#  Avg loss:0.834976
#
# Start validation.
# Done. Time:0.2872831720001159
# Validation performance:
#  Avg loss:1.315579
#
# Start evaluation.
# Done. Time:0.8345672069999637
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.600645 [    0/ 3881]
# loss:1.098983 [ 3200/ 3881]
# Done. Time:2.8861165179998807
# Training performance:
#  Avg loss:0.824374
#
# Start validation.
# Done. Time:0.29643650200000593
# Validation performance:
#  Avg loss:1.305532
#
# Start evaluation.
# Done. Time:0.8048751409999113
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.592582 [    0/ 3881]
# loss:1.088762 [ 3200/ 3881]
# Done. Time:4.040344540999968
# Training performance:
#  Avg loss:0.813458
#
# Start validation.
# Done. Time:0.4849149359999956
# Validation performance:
#  Avg loss:1.296276
#
# Start evaluation.
# Done. Time:0.9878084899999067
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.583880 [    0/ 3881]
# loss:1.078289 [ 3200/ 3881]
# Done. Time:2.9975115390000155
# Training performance:
#  Avg loss:0.804299
#
# Start validation.
# Done. Time:0.30584067599988884
# Validation performance:
#  Avg loss:1.287226
#
# Start evaluation.
# Done. Time:0.8499247170000217
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.575012 [    0/ 3881]
# loss:1.068553 [ 3200/ 3881]
# Done. Time:2.9696582670001135
# Training performance:
#  Avg loss:0.793280
#
# Start validation.
# Done. Time:0.3067039320001186
# Validation performance:
#  Avg loss:1.280243
#
# Start evaluation.
# Done. Time:0.873808254000096
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.565374 [    0/ 3881]
# loss:1.058841 [ 3200/ 3881]
# Done. Time:4.320132394999973
# Training performance:
#  Avg loss:0.784519
#
# Start validation.
# Done. Time:0.4737692710000374
# Validation performance:
#  Avg loss:1.272159
#
# Start evaluation.
# Done. Time:1.2288565470000776
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.557647 [    0/ 3881]
# loss:1.050844 [ 3200/ 3881]
# Done. Time:3.9064986030000455
# Training performance:
#  Avg loss:0.775624
#
# Start validation.
# Done. Time:0.3044750629999271
# Validation performance:
#  Avg loss:1.265237
#
# Start evaluation.
# Done. Time:0.8205640579999454
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.548284 [    0/ 3881]
# loss:1.040809 [ 3200/ 3881]
# Done. Time:2.9432444050000868
# Training performance:
#  Avg loss:0.766919
#
# Start validation.
# Done. Time:0.31388979199982714
# Validation performance:
#  Avg loss:1.257490
#
# Start evaluation.
# Done. Time:0.8551270740001655
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.542306 [    0/ 3881]
# loss:1.032624 [ 3200/ 3881]
# Done. Time:4.492419705999964
# Training performance:
#  Avg loss:0.758985
#
# Start validation.
# Done. Time:0.29415790999996716
# Validation performance:
#  Avg loss:1.250359
#
# Start evaluation.
# Done. Time:0.838963939000223
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.534333 [    0/ 3881]
# loss:1.024389 [ 3200/ 3881]
# Done. Time:3.028590212999916
# Training performance:
#  Avg loss:0.750485
#
# Start validation.
# Done. Time:0.3005538740001157
# Validation performance:
#  Avg loss:1.244420
#
# Start evaluation.
# Done. Time:0.8561811690001377
# Test performance:
#  Accuracy:67.5%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.527266 [    0/ 3881]
# loss:1.015923 [ 3200/ 3881]
# Done. Time:2.9437301429998115
# Training performance:
#  Avg loss:0.743020
#
# Start validation.
# Done. Time:0.3049622510000063
# Validation performance:
#  Avg loss:1.237953
#
# Start evaluation.
# Done. Time:1.0434946630000468
# Test performance:
#  Accuracy:67.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.519095 [    0/ 3881]
# loss:1.008613 [ 3200/ 3881]
# Done. Time:4.252336500999945
# Training performance:
#  Avg loss:0.735140
#
# Start validation.
# Done. Time:0.31402149500013365
# Validation performance:
#  Avg loss:1.232544
#
# Start evaluation.
# Done. Time:0.8256018080001013
# Test performance:
#  Accuracy:67.5%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.513958 [    0/ 3881]
# loss:1.000646 [ 3200/ 3881]
# Done. Time:2.9440043879999394
# Training performance:
#  Avg loss:0.728290
#
# Start validation.
# Done. Time:0.31808016900004077
# Validation performance:
#  Avg loss:1.226828
#
# Start evaluation.
# Done. Time:0.8621608620001098
# Test performance:
#  Accuracy:67.5%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.505300 [    0/ 3881]
# loss:0.993382 [ 3200/ 3881]
# Done. Time:3.0040861759998734
# Training performance:
#  Avg loss:0.720720
#
# Start validation.
# Done. Time:0.31426554499989834
# Validation performance:
#  Avg loss:1.221897
#
# Start evaluation.
# Done. Time:1.1078538169999774
# Test performance:
#  Accuracy:67.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.498705 [    0/ 3881]
# loss:0.986178 [ 3200/ 3881]
# Done. Time:4.013257046000035
# Training performance:
#  Avg loss:0.714037
#
# Start validation.
# Done. Time:0.31940175299996554
# Validation performance:
#  Avg loss:1.216363
#
# Start evaluation.
# Done. Time:0.8466656479999983
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.491484 [    0/ 3881]
# loss:0.979205 [ 3200/ 3881]
# Done. Time:2.967584663000025
# Training performance:
#  Avg loss:0.707115
#
# Start validation.
# Done. Time:0.2880815920000259
# Validation performance:
#  Avg loss:1.211784
#
# Start evaluation.
# Done. Time:0.8458154350000768
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.484678 [    0/ 3881]
# loss:0.972476 [ 3200/ 3881]
# Done. Time:2.9004989210000076
# Training performance:
#  Avg loss:0.700537
#
# Start validation.
# Done. Time:0.4344261329999881
# Validation performance:
#  Avg loss:1.207468
#
# Start evaluation.
# Done. Time:1.0849494680001044
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.477907 [    0/ 3881]
# loss:0.966179 [ 3200/ 3881]
# Done. Time:3.8162524790000134
# Training performance:
#  Avg loss:0.694196
#
# Start validation.
# Done. Time:0.31631051300018953
# Validation performance:
#  Avg loss:1.203131
#
# Start evaluation.
# Done. Time:0.8670724339999651
# Test performance:
#  Accuracy:67.5%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.469554 [    0/ 3881]
# loss:0.959944 [ 3200/ 3881]
# Done. Time:3.0059488300000794
# Training performance:
#  Avg loss:0.687953
#
# Start validation.
# Done. Time:0.2992889209999703
# Validation performance:
#  Avg loss:1.199272
#
# Start evaluation.
# Done. Time:0.8262717770001018
# Test performance:
#  Accuracy:67.5%
# Minimum validation loss:1.199272402695247 at 50 epoch.
# Maximum accuracy:67.5 at 41 epoch.

# %% [markdown]
# ### Unique alignment and framewise scaling

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_align_scale_w))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_align_u_scale_f,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_align_u_scale_f,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_align_u_scale_f,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_align_u_scale_f = np.array(val_losses)
test_accs_align_u_scale_f = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_align_u_scale_f.min()} at {np.argmin(val_losses_align_u_scale_f)+1} epoch.")
print(f"Maximum accuracy:{test_accs_align_u_scale_f.max()} at {np.argmax(test_accs_align_u_scale_f)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.292777 [    0/ 3881]
# loss:2.238651 [ 3200/ 3881]
# Done. Time:3.0562748379998084
# Training performance:
#  Avg loss:2.232322
#
# Start validation.
# Done. Time:0.3418452119999529
# Validation performance:
#  Avg loss:2.213798
#
# Start evaluation.
# Done. Time:0.8662988910000422
# Test performance:
#  Accuracy:17.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.076144 [    0/ 3881]
# loss:2.091627 [ 3200/ 3881]
# Done. Time:3.112171824999905
# Training performance:
#  Avg loss:1.999437
#
# Start validation.
# Done. Time:0.31249384099987765
# Validation performance:
#  Avg loss:2.124967
#
# Start evaluation.
# Done. Time:1.0571210040000096
# Test performance:
#  Accuracy:35.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.761110 [    0/ 3881]
# loss:1.984827 [ 3200/ 3881]
# Done. Time:4.401359790000015
# Training performance:
#  Avg loss:1.819337
#
# Start validation.
# Done. Time:0.3038834480000787
# Validation performance:
#  Avg loss:2.057368
#
# Start evaluation.
# Done. Time:0.8595466589999887
# Test performance:
#  Accuracy:44.5%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.544068 [    0/ 3881]
# loss:1.899232 [ 3200/ 3881]
# Done. Time:2.9901696499998707
# Training performance:
#  Avg loss:1.693970
#
# Start validation.
# Done. Time:0.2920119909999812
# Validation performance:
#  Avg loss:2.005787
#
# Start evaluation.
# Done. Time:0.8520605190001334
# Test performance:
#  Accuracy:47.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.379349 [    0/ 3881]
# loss:1.825023 [ 3200/ 3881]
# Done. Time:2.9944114070001433
# Training performance:
#  Avg loss:1.598818
#
# Start validation.
# Done. Time:0.29881741899998815
# Validation performance:
#  Avg loss:1.964786
#
# Start evaluation.
# Done. Time:1.0180195220000314
# Test performance:
#  Accuracy:47.0%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.255270 [    0/ 3881]
# loss:1.763914 [ 3200/ 3881]
# Done. Time:4.142678483999816
# Training performance:
#  Avg loss:1.521806
#
# Start validation.
# Done. Time:0.3111351540001124
# Validation performance:
#  Avg loss:1.923861
#
# Start evaluation.
# Done. Time:0.8397092170000633
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.163076 [    0/ 3881]
# loss:1.711446 [ 3200/ 3881]
# Done. Time:3.8451342359999217
# Training performance:
#  Avg loss:1.457934
#
# Start validation.
# Done. Time:0.3229932419999386
# Validation performance:
#  Avg loss:1.888210
#
# Start evaluation.
# Done. Time:0.8595750189999762
# Test performance:
#  Accuracy:49.5%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.090725 [    0/ 3881]
# loss:1.666295 [ 3200/ 3881]
# Done. Time:3.2692892059999394
# Training performance:
#  Avg loss:1.402801
#
# Start validation.
# Done. Time:0.44806298000003153
# Validation performance:
#  Avg loss:1.855693
#
# Start evaluation.
# Done. Time:1.1173833720001767
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.032510 [    0/ 3881]
# loss:1.626474 [ 3200/ 3881]
# Done. Time:3.5247524900000826
# Training performance:
#  Avg loss:1.354537
#
# Start validation.
# Done. Time:0.30109468599994216
# Validation performance:
#  Avg loss:1.829312
#
# Start evaluation.
# Done. Time:0.8338190269998904
# Test performance:
#  Accuracy:51.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:0.986858 [    0/ 3881]
# loss:1.589777 [ 3200/ 3881]
# Done. Time:2.9329844740000226
# Training performance:
#  Avg loss:1.311218
#
# Start validation.
# Done. Time:0.29121258999998645
# Validation performance:
#  Avg loss:1.806119
#
# Start evaluation.
# Done. Time:0.8459120840000196
# Test performance:
#  Accuracy:52.5%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:0.949852 [    0/ 3881]
# loss:1.557855 [ 3200/ 3881]
# Done. Time:3.165117321000025
# Training performance:
#  Avg loss:1.272586
#
# Start validation.
# Done. Time:0.47929470500002935
# Validation performance:
#  Avg loss:1.786567
#
# Start evaluation.
# Done. Time:1.0837909460001356
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:0.919599 [    0/ 3881]
# loss:1.530980 [ 3200/ 3881]
# Done. Time:3.4436679659997935
# Training performance:
#  Avg loss:1.236848
#
# Start validation.
# Done. Time:0.2835548520001794
# Validation performance:
#  Avg loss:1.768583
#
# Start evaluation.
# Done. Time:0.8606704920000539
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:0.895199 [    0/ 3881]
# loss:1.505606 [ 3200/ 3881]
# Done. Time:2.89999590299999
# Training performance:
#  Avg loss:1.204931
#
# Start validation.
# Done. Time:0.3082257370001571
# Validation performance:
#  Avg loss:1.753483
#
# Start evaluation.
# Done. Time:0.8225257609999517
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:0.872949 [    0/ 3881]
# loss:1.484715 [ 3200/ 3881]
# Done. Time:3.137495433999902
# Training performance:
#  Avg loss:1.175803
#
# Start validation.
# Done. Time:0.5168207060000896
# Validation performance:
#  Avg loss:1.736368
#
# Start evaluation.
# Done. Time:1.1498178979998102
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:0.850673 [    0/ 3881]
# loss:1.462995 [ 3200/ 3881]
# Done. Time:3.5502411969998775
# Training performance:
#  Avg loss:1.149363
#
# Start validation.
# Done. Time:0.34643978300005074
# Validation performance:
#  Avg loss:1.726067
#
# Start evaluation.
# Done. Time:0.8502559670000664
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:0.837321 [    0/ 3881]
# loss:1.444636 [ 3200/ 3881]
# Done. Time:3.285382846999937
# Training performance:
#  Avg loss:1.124037
#
# Start validation.
# Done. Time:0.47682496199990965
# Validation performance:
#  Avg loss:1.713851
#
# Start evaluation.
# Done. Time:1.1136340509999627
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:0.820879 [    0/ 3881]
# loss:1.427724 [ 3200/ 3881]
# Done. Time:4.540475255999809
# Training performance:
#  Avg loss:1.101136
#
# Start validation.
# Done. Time:0.4776069350000398
# Validation performance:
#  Avg loss:1.703323
#
# Start evaluation.
# Done. Time:0.960873293000077
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:0.807264 [    0/ 3881]
# loss:1.413226 [ 3200/ 3881]
# Done. Time:2.9424248140001055
# Training performance:
#  Avg loss:1.079174
#
# Start validation.
# Done. Time:0.30268721899983575
# Validation performance:
#  Avg loss:1.692441
#
# Start evaluation.
# Done. Time:0.8194063809999079
# Test performance:
#  Accuracy:60.0%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:0.795443 [    0/ 3881]
# loss:1.398172 [ 3200/ 3881]
# Done. Time:2.8670378809999875
# Training performance:
#  Avg loss:1.058605
#
# Start validation.
# Done. Time:0.3237598800001251
# Validation performance:
#  Avg loss:1.680389
#
# Start evaluation.
# Done. Time:0.8451646359999359
# Test performance:
#  Accuracy:60.0%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:0.784986 [    0/ 3881]
# loss:1.383547 [ 3200/ 3881]
# Done. Time:4.236602835999975
# Training performance:
#  Avg loss:1.039031
#
# Start validation.
# Done. Time:0.485302479999973
# Validation performance:
#  Avg loss:1.668387
#
# Start evaluation.
# Done. Time:0.8957828349998636
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:0.772759 [    0/ 3881]
# loss:1.369551 [ 3200/ 3881]
# Done. Time:2.9304345289999674
# Training performance:
#  Avg loss:1.019924
#
# Start validation.
# Done. Time:0.2980109849997916
# Validation performance:
#  Avg loss:1.655799
#
# Start evaluation.
# Done. Time:0.8510159940001358
# Test performance:
#  Accuracy:60.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:0.763440 [    0/ 3881]
# loss:1.356312 [ 3200/ 3881]
# Done. Time:2.9619787890001135
# Training performance:
#  Avg loss:1.002026
#
# Start validation.
# Done. Time:0.29847748800011686
# Validation performance:
#  Avg loss:1.642870
#
# Start evaluation.
# Done. Time:0.8375021029999061
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:0.753896 [    0/ 3881]
# loss:1.343633 [ 3200/ 3881]
# Done. Time:4.309211606999952
# Training performance:
#  Avg loss:0.985234
#
# Start validation.
# Done. Time:0.4986387280000599
# Validation performance:
#  Avg loss:1.631232
#
# Start evaluation.
# Done. Time:0.8525527560000228
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:0.744293 [    0/ 3881]
# loss:1.331097 [ 3200/ 3881]
# Done. Time:3.00178769199988
# Training performance:
#  Avg loss:0.969413
#
# Start validation.
# Done. Time:0.3065602579999904
# Validation performance:
#  Avg loss:1.618775
#
# Start evaluation.
# Done. Time:0.8443870230000812
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:0.735012 [    0/ 3881]
# loss:1.319122 [ 3200/ 3881]
# Done. Time:3.025838444000101
# Training performance:
#  Avg loss:0.954353
#
# Start validation.
# Done. Time:0.30075953999994454
# Validation performance:
#  Avg loss:1.607762
#
# Start evaluation.
# Done. Time:0.8448610259999896
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:0.725687 [    0/ 3881]
# loss:1.307680 [ 3200/ 3881]
# Done. Time:4.460515637000071
# Training performance:
#  Avg loss:0.939986
#
# Start validation.
# Done. Time:0.33512272000007215
# Validation performance:
#  Avg loss:1.597296
#
# Start evaluation.
# Done. Time:0.8382437889999892
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:0.716564 [    0/ 3881]
# loss:1.296696 [ 3200/ 3881]
# Done. Time:2.9477225450000333
# Training performance:
#  Avg loss:0.926331
#
# Start validation.
# Done. Time:0.33013495699992745
# Validation performance:
#  Avg loss:1.586922
#
# Start evaluation.
# Done. Time:0.8331079130000489
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.708133 [    0/ 3881]
# loss:1.285954 [ 3200/ 3881]
# Done. Time:2.94292627599998
# Training performance:
#  Avg loss:0.913397
#
# Start validation.
# Done. Time:0.29868456700000934
# Validation performance:
#  Avg loss:1.577273
#
# Start evaluation.
# Done. Time:0.8564137460000438
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.700233 [    0/ 3881]
# loss:1.275714 [ 3200/ 3881]
# Done. Time:4.500412863000065
# Training performance:
#  Avg loss:0.900904
#
# Start validation.
# Done. Time:0.30694470100002036
# Validation performance:
#  Avg loss:1.565917
#
# Start evaluation.
# Done. Time:0.8827309030000379
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.691460 [    0/ 3881]
# loss:1.265205 [ 3200/ 3881]
# Done. Time:2.9294684730000426
# Training performance:
#  Avg loss:0.888995
#
# Start validation.
# Done. Time:0.31390705799981333
# Validation performance:
#  Avg loss:1.557524
#
# Start evaluation.
# Done. Time:0.8364271749999261
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.684300 [    0/ 3881]
# loss:1.255812 [ 3200/ 3881]
# Done. Time:2.949322410999912
# Training performance:
#  Avg loss:0.877454
#
# Start validation.
# Done. Time:0.29914933899999596
# Validation performance:
#  Avg loss:1.546420
#
# Start evaluation.
# Done. Time:0.861324593000063
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.676365 [    0/ 3881]
# loss:1.245800 [ 3200/ 3881]
# Done. Time:4.520937520000189
# Training performance:
#  Avg loss:0.866205
#
# Start validation.
# Done. Time:0.30452190599999085
# Validation performance:
#  Avg loss:1.536648
#
# Start evaluation.
# Done. Time:0.8735695420000411
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.668721 [    0/ 3881]
# loss:1.236399 [ 3200/ 3881]
# Done. Time:3.0094631590000063
# Training performance:
#  Avg loss:0.855386
#
# Start validation.
# Done. Time:0.2978509389999999
# Validation performance:
#  Avg loss:1.527619
#
# Start evaluation.
# Done. Time:0.8296549469998808
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.660839 [    0/ 3881]
# loss:1.227362 [ 3200/ 3881]
# Done. Time:2.9611622690001695
# Training performance:
#  Avg loss:0.845004
#
# Start validation.
# Done. Time:0.3257467429998542
# Validation performance:
#  Avg loss:1.518948
#
# Start evaluation.
# Done. Time:0.8331925090001278
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.653457 [    0/ 3881]
# loss:1.218989 [ 3200/ 3881]
# Done. Time:4.501766134999798
# Training performance:
#  Avg loss:0.834991
#
# Start validation.
# Done. Time:0.3273469109999496
# Validation performance:
#  Avg loss:1.510676
#
# Start evaluation.
# Done. Time:0.8430888120001327
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.646127 [    0/ 3881]
# loss:1.209900 [ 3200/ 3881]
# Done. Time:2.9335392859998137
# Training performance:
#  Avg loss:0.825312
#
# Start validation.
# Done. Time:0.28867904299977454
# Validation performance:
#  Avg loss:1.502519
#
# Start evaluation.
# Done. Time:0.8220121730000756
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.639272 [    0/ 3881]
# loss:1.201194 [ 3200/ 3881]
# Done. Time:2.931159903999742
# Training performance:
#  Avg loss:0.815894
#
# Start validation.
# Done. Time:0.3194585520000146
# Validation performance:
#  Avg loss:1.493550
#
# Start evaluation.
# Done. Time:0.8633997410001939
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.630483 [    0/ 3881]
# loss:1.192789 [ 3200/ 3881]
# Done. Time:4.313601583000036
# Training performance:
#  Avg loss:0.806919
#
# Start validation.
# Done. Time:0.28980148499977076
# Validation performance:
#  Avg loss:1.485705
#
# Start evaluation.
# Done. Time:0.846193306999794
# Test performance:
#  Accuracy:65.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.623033 [    0/ 3881]
# loss:1.184580 [ 3200/ 3881]
# Done. Time:2.972286302000157
# Training performance:
#  Avg loss:0.798286
#
# Start validation.
# Done. Time:0.29780970000001616
# Validation performance:
#  Avg loss:1.477834
#
# Start evaluation.
# Done. Time:0.8405636880002021
# Test performance:
#  Accuracy:65.5%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.615438 [    0/ 3881]
# loss:1.176307 [ 3200/ 3881]
# Done. Time:2.840653163999832
# Training performance:
#  Avg loss:0.789897
#
# Start validation.
# Done. Time:0.29368985099972633
# Validation performance:
#  Avg loss:1.470416
#
# Start evaluation.
# Done. Time:0.8964537669999117
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.607286 [    0/ 3881]
# loss:1.168343 [ 3200/ 3881]
# Done. Time:4.33316958100022
# Training performance:
#  Avg loss:0.781708
#
# Start validation.
# Done. Time:0.29458828399992854
# Validation performance:
#  Avg loss:1.462265
#
# Start evaluation.
# Done. Time:0.8244805399999677
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.599766 [    0/ 3881]
# loss:1.160607 [ 3200/ 3881]
# Done. Time:2.945749631000126
# Training performance:
#  Avg loss:0.773768
#
# Start validation.
# Done. Time:0.30348342599972966
# Validation performance:
#  Avg loss:1.454187
#
# Start evaluation.
# Done. Time:0.830615095000212
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.592179 [    0/ 3881]
# loss:1.152761 [ 3200/ 3881]
# Done. Time:2.9197674310003094
# Training performance:
#  Avg loss:0.766031
#
# Start validation.
# Done. Time:0.29403123499969297
# Validation performance:
#  Avg loss:1.445947
#
# Start evaluation.
# Done. Time:1.017291159999786
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.584561 [    0/ 3881]
# loss:1.145066 [ 3200/ 3881]
# Done. Time:4.327910471999985
# Training performance:
#  Avg loss:0.758490
#
# Start validation.
# Done. Time:0.27848458299968115
# Validation performance:
#  Avg loss:1.437696
#
# Start evaluation.
# Done. Time:0.8294549000002007
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.576709 [    0/ 3881]
# loss:1.137561 [ 3200/ 3881]
# Done. Time:2.9423911680000856
# Training performance:
#  Avg loss:0.751114
#
# Start validation.
# Done. Time:0.3024507610002729
# Validation performance:
#  Avg loss:1.427481
#
# Start evaluation.
# Done. Time:0.8459998229996017
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.568784 [    0/ 3881]
# loss:1.129928 [ 3200/ 3881]
# Done. Time:3.0212041169997974
# Training performance:
#  Avg loss:0.743848
#
# Start validation.
# Done. Time:0.29926190000014685
# Validation performance:
#  Avg loss:1.417220
#
# Start evaluation.
# Done. Time:1.0391189179999856
# Test performance:
#  Accuracy:67.5%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.561802 [    0/ 3881]
# loss:1.122742 [ 3200/ 3881]
# Done. Time:5.552103964999787
# Training performance:
#  Avg loss:0.736852
#
# Start validation.
# Done. Time:0.5048320949999834
# Validation performance:
#  Avg loss:1.405216
#
# Start evaluation.
# Done. Time:0.8968277240001044
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.553142 [    0/ 3881]
# loss:1.115351 [ 3200/ 3881]
# Done. Time:3.033029754000381
# Training performance:
#  Avg loss:0.729965
#
# Start validation.
# Done. Time:0.3079968900001404
# Validation performance:
#  Avg loss:1.395828
#
# Start evaluation.
# Done. Time:0.8704284410000582
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.545552 [    0/ 3881]
# loss:1.107857 [ 3200/ 3881]
# Done. Time:3.0304432689999885
# Training performance:
#  Avg loss:0.723198
#
# Start validation.
# Done. Time:0.3035435500000858
# Validation performance:
#  Avg loss:1.388579
#
# Start evaluation.
# Done. Time:1.1339347480002289
# Test performance:
#  Accuracy:68.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.537556 [    0/ 3881]
# loss:1.101039 [ 3200/ 3881]
# Done. Time:3.9782739160000347
# Training performance:
#  Avg loss:0.716688
#
# Start validation.
# Done. Time:0.3015452100003131
# Validation performance:
#  Avg loss:1.377623
#
# Start evaluation.
# Done. Time:0.8600029059998633
# Test performance:
#  Accuracy:68.0%
# Minimum validation loss:1.377623404775347 at 50 epoch.
# Maximum accuracy:68.5 at 47 epoch.

# %% [markdown]
# ### Unique alignment and unique scaling

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_align_scale_w))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_align_u_scale_u,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_align_u_scale_u,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_align_u_scale_u,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_align_u_scale_u = np.array(val_losses)
test_accs_align_u_scale_u = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_align_u_scale_u.min()} at {np.argmin(val_losses_align_u_scale_u)+1} epoch.")
print(f"Maximum accuracy:{test_accs_align_u_scale_u.max()} at {np.argmax(test_accs_align_u_scale_u)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.375162 [    0/ 3881]
# loss:2.260629 [ 3200/ 3881]
# Done. Time:4.239328226999987
# Training performance:
#  Avg loss:2.238879
#
# Start validation.
# Done. Time:0.3022567890002392
# Validation performance:
#  Avg loss:2.219960
#
# Start evaluation.
# Done. Time:0.8412291479999112
# Test performance:
#  Accuracy:16.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.114100 [    0/ 3881]
# loss:2.128647 [ 3200/ 3881]
# Done. Time:3.0041426200000387
# Training performance:
#  Avg loss:2.020554
#
# Start validation.
# Done. Time:0.32973317300002236
# Validation performance:
#  Avg loss:2.134398
#
# Start evaluation.
# Done. Time:0.8444807830001082
# Test performance:
#  Accuracy:24.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.826996 [    0/ 3881]
# loss:2.010484 [ 3200/ 3881]
# Done. Time:2.973707131000083
# Training performance:
#  Avg loss:1.835348
#
# Start validation.
# Done. Time:0.31526365599984274
# Validation performance:
#  Avg loss:2.062078
#
# Start evaluation.
# Done. Time:1.0778488569999354
# Test performance:
#  Accuracy:36.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.589297 [    0/ 3881]
# loss:1.914267 [ 3200/ 3881]
# Done. Time:4.054355925999971
# Training performance:
#  Avg loss:1.697515
#
# Start validation.
# Done. Time:0.29452991600010137
# Validation performance:
#  Avg loss:2.017158
#
# Start evaluation.
# Done. Time:0.8341670110003179
# Test performance:
#  Accuracy:45.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.377131 [    0/ 3881]
# loss:1.841687 [ 3200/ 3881]
# Done. Time:2.967873309999959
# Training performance:
#  Avg loss:1.598186
#
# Start validation.
# Done. Time:0.3257632210002157
# Validation performance:
#  Avg loss:1.977164
#
# Start evaluation.
# Done. Time:0.8461385860000519
# Test performance:
#  Accuracy:46.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.256315 [    0/ 3881]
# loss:1.779337 [ 3200/ 3881]
# Done. Time:2.9888518860002478
# Training performance:
#  Avg loss:1.520494
#
# Start validation.
# Done. Time:0.3478214870001466
# Validation performance:
#  Avg loss:1.944034
#
# Start evaluation.
# Done. Time:1.145322415999999
# Test performance:
#  Accuracy:49.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.165399 [    0/ 3881]
# loss:1.725878 [ 3200/ 3881]
# Done. Time:3.927808800999628
# Training performance:
#  Avg loss:1.456831
#
# Start validation.
# Done. Time:0.2826720039997781
# Validation performance:
#  Avg loss:1.915504
#
# Start evaluation.
# Done. Time:0.8467971240002043
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.097298 [    0/ 3881]
# loss:1.670188 [ 3200/ 3881]
# Done. Time:2.9529704839997066
# Training performance:
#  Avg loss:1.401340
#
# Start validation.
# Done. Time:0.31161130800001047
# Validation performance:
#  Avg loss:1.894772
#
# Start evaluation.
# Done. Time:0.8844661120001547
# Test performance:
#  Accuracy:49.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.041551 [    0/ 3881]
# loss:1.637034 [ 3200/ 3881]
# Done. Time:3.085357300999931
# Training performance:
#  Avg loss:1.354733
#
# Start validation.
# Done. Time:0.4974863130000813
# Validation performance:
#  Avg loss:1.871197
#
# Start evaluation.
# Done. Time:1.1238948099999106
# Test performance:
#  Accuracy:51.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:0.994753 [    0/ 3881]
# loss:1.598157 [ 3200/ 3881]
# Done. Time:3.6773516130001553
# Training performance:
#  Avg loss:1.312737
#
# Start validation.
# Done. Time:0.30654884399973525
# Validation performance:
#  Avg loss:1.850448
#
# Start evaluation.
# Done. Time:0.8548329519999243
# Test performance:
#  Accuracy:50.5%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:0.958739 [    0/ 3881]
# loss:1.567422 [ 3200/ 3881]
# Done. Time:2.957877671999995
# Training performance:
#  Avg loss:1.274960
#
# Start validation.
# Done. Time:0.3047963660001187
# Validation performance:
#  Avg loss:1.829880
#
# Start evaluation.
# Done. Time:0.8499112980002792
# Test performance:
#  Accuracy:51.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:0.930256 [    0/ 3881]
# loss:1.534196 [ 3200/ 3881]
# Done. Time:3.0165068400001473
# Training performance:
#  Avg loss:1.239990
#
# Start validation.
# Done. Time:0.5110841460000302
# Validation performance:
#  Avg loss:1.813386
#
# Start evaluation.
# Done. Time:1.1173154319999412
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:0.908505 [    0/ 3881]
# loss:1.508713 [ 3200/ 3881]
# Done. Time:3.6193343910003932
# Training performance:
#  Avg loss:1.208423
#
# Start validation.
# Done. Time:0.3112917660000676
# Validation performance:
#  Avg loss:1.795379
#
# Start evaluation.
# Done. Time:0.8465786130000197
# Test performance:
#  Accuracy:52.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:0.886176 [    0/ 3881]
# loss:1.485109 [ 3200/ 3881]
# Done. Time:3.071783370999583
# Training performance:
#  Avg loss:1.180080
#
# Start validation.
# Done. Time:0.3066218080002727
# Validation performance:
#  Avg loss:1.777491
#
# Start evaluation.
# Done. Time:0.8476474980002422
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:0.866590 [    0/ 3881]
# loss:1.463671 [ 3200/ 3881]
# Done. Time:3.221080898999844
# Training performance:
#  Avg loss:1.153770
#
# Start validation.
# Done. Time:0.4975490609999724
# Validation performance:
#  Avg loss:1.759710
#
# Start evaluation.
# Done. Time:1.1060568399998374
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:0.847575 [    0/ 3881]
# loss:1.443881 [ 3200/ 3881]
# Done. Time:3.6299603899997237
# Training performance:
#  Avg loss:1.129305
#
# Start validation.
# Done. Time:0.328183731000081
# Validation performance:
#  Avg loss:1.741850
#
# Start evaluation.
# Done. Time:0.9062130329998581
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:0.829885 [    0/ 3881]
# loss:1.421896 [ 3200/ 3881]
# Done. Time:3.2318205560000024
# Training performance:
#  Avg loss:1.105851
#
# Start validation.
# Done. Time:0.3293352290002076
# Validation performance:
#  Avg loss:1.720892
#
# Start evaluation.
# Done. Time:0.9572965279999153
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:0.817507 [    0/ 3881]
# loss:1.407549 [ 3200/ 3881]
# Done. Time:4.147400751000077
# Training performance:
#  Avg loss:1.085170
#
# Start validation.
# Done. Time:0.48655759799976295
# Validation performance:
#  Avg loss:1.710480
#
# Start evaluation.
# Done. Time:1.3071149410002363
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:0.801958 [    0/ 3881]
# loss:1.390140 [ 3200/ 3881]
# Done. Time:3.414791742000034
# Training performance:
#  Avg loss:1.064402
#
# Start validation.
# Done. Time:0.3339980249998007
# Validation performance:
#  Avg loss:1.693249
#
# Start evaluation.
# Done. Time:0.9598067540000557
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:0.790531 [    0/ 3881]
# loss:1.373906 [ 3200/ 3881]
# Done. Time:3.2681881490002525
# Training performance:
#  Avg loss:1.045120
#
# Start validation.
# Done. Time:0.338402522999786
# Validation performance:
#  Avg loss:1.677403
#
# Start evaluation.
# Done. Time:0.9651880389997132
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:0.779707 [    0/ 3881]
# loss:1.358894 [ 3200/ 3881]
# Done. Time:5.000563234999845
# Training performance:
#  Avg loss:1.027097
#
# Start validation.
# Done. Time:0.34113825599979464
# Validation performance:
#  Avg loss:1.662158
#
# Start evaluation.
# Done. Time:1.096144145999915
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:0.769475 [    0/ 3881]
# loss:1.344953 [ 3200/ 3881]
# Done. Time:3.301373865000187
# Training performance:
#  Avg loss:1.009408
#
# Start validation.
# Done. Time:0.3386025080003492
# Validation performance:
#  Avg loss:1.646668
#
# Start evaluation.
# Done. Time:0.9984818630000518
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:0.757401 [    0/ 3881]
# loss:1.331958 [ 3200/ 3881]
# Done. Time:3.5228338829997483
# Training performance:
#  Avg loss:0.992577
#
# Start validation.
# Done. Time:0.5724322139999458
# Validation performance:
#  Avg loss:1.630092
#
# Start evaluation.
# Done. Time:1.5490573880001648
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:0.746027 [    0/ 3881]
# loss:1.318581 [ 3200/ 3881]
# Done. Time:5.085579621999841
# Training performance:
#  Avg loss:0.976896
#
# Start validation.
# Done. Time:0.5821395149996533
# Validation performance:
#  Avg loss:1.616591
#
# Start evaluation.
# Done. Time:1.603171398000086
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:0.734942 [    0/ 3881]
# loss:1.306721 [ 3200/ 3881]
# Done. Time:3.459093219999886
# Training performance:
#  Avg loss:0.961136
#
# Start validation.
# Done. Time:0.3390471580000849
# Validation performance:
#  Avg loss:1.598866
#
# Start evaluation.
# Done. Time:1.228382739999688
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:0.723164 [    0/ 3881]
# loss:1.295142 [ 3200/ 3881]
# Done. Time:4.297746237999945
# Training performance:
#  Avg loss:0.946528
#
# Start validation.
# Done. Time:0.3334515910000846
# Validation performance:
#  Avg loss:1.584811
#
# Start evaluation.
# Done. Time:0.9797087849997297
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:0.712673 [    0/ 3881]
# loss:1.283579 [ 3200/ 3881]
# Done. Time:3.20537651199993
# Training performance:
#  Avg loss:0.931974
#
# Start validation.
# Done. Time:0.31688054999995074
# Validation performance:
#  Avg loss:1.568919
#
# Start evaluation.
# Done. Time:1.0191899520000334
# Test performance:
#  Accuracy:60.0%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.702132 [    0/ 3881]
# loss:1.271786 [ 3200/ 3881]
# Done. Time:3.8334376580000935
# Training performance:
#  Avg loss:0.918267
#
# Start validation.
# Done. Time:0.5842238889999862
# Validation performance:
#  Avg loss:1.554763
#
# Start evaluation.
# Done. Time:1.5395352330001515
# Test performance:
#  Accuracy:60.0%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.691745 [    0/ 3881]
# loss:1.260634 [ 3200/ 3881]
# Done. Time:3.533280096999988
# Training performance:
#  Avg loss:0.904928
#
# Start validation.
# Done. Time:0.34833025700027065
# Validation performance:
#  Avg loss:1.540243
#
# Start evaluation.
# Done. Time:1.1637683690000813
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.680986 [    0/ 3881]
# loss:1.250032 [ 3200/ 3881]
# Done. Time:3.565760925000177
# Training performance:
#  Avg loss:0.892098
#
# Start validation.
# Done. Time:0.37609193899970705
# Validation performance:
#  Avg loss:1.528936
#
# Start evaluation.
# Done. Time:1.2536088500000915
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.670741 [    0/ 3881]
# loss:1.239579 [ 3200/ 3881]
# Done. Time:5.116195312999935
# Training performance:
#  Avg loss:0.879812
#
# Start validation.
# Done. Time:0.33132885700024417
# Validation performance:
#  Avg loss:1.514831
#
# Start evaluation.
# Done. Time:0.9878715350000675
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.660793 [    0/ 3881]
# loss:1.229324 [ 3200/ 3881]
# Done. Time:3.432274414999938
# Training performance:
#  Avg loss:0.868099
#
# Start validation.
# Done. Time:0.35506290400007856
# Validation performance:
#  Avg loss:1.501925
#
# Start evaluation.
# Done. Time:1.005372288000217
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.651310 [    0/ 3881]
# loss:1.219296 [ 3200/ 3881]
# Done. Time:3.6413463210001282
# Training performance:
#  Avg loss:0.856891
#
# Start validation.
# Done. Time:0.5603108919999613
# Validation performance:
#  Avg loss:1.490016
#
# Start evaluation.
# Done. Time:1.5885340479999286
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.642434 [    0/ 3881]
# loss:1.209900 [ 3200/ 3881]
# Done. Time:3.7770211160000144
# Training performance:
#  Avg loss:0.846153
#
# Start validation.
# Done. Time:0.35315126700015753
# Validation performance:
#  Avg loss:1.477711
#
# Start evaluation.
# Done. Time:0.9511272359995928
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.635105 [    0/ 3881]
# loss:1.200183 [ 3200/ 3881]
# Done. Time:3.2317869989997234
# Training performance:
#  Avg loss:0.835805
#
# Start validation.
# Done. Time:0.3187013910001042
# Validation performance:
#  Avg loss:1.466183
#
# Start evaluation.
# Done. Time:1.0750678459999108
# Test performance:
#  Accuracy:63.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.627676 [    0/ 3881]
# loss:1.190689 [ 3200/ 3881]
# Done. Time:4.918411926999852
# Training performance:
#  Avg loss:0.825840
#
# Start validation.
# Done. Time:0.3362124989998847
# Validation performance:
#  Avg loss:1.455552
#
# Start evaluation.
# Done. Time:1.0687943860002633
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.620825 [    0/ 3881]
# loss:1.182048 [ 3200/ 3881]
# Done. Time:3.2903072809999685
# Training performance:
#  Avg loss:0.816134
#
# Start validation.
# Done. Time:0.33354072599968276
# Validation performance:
#  Avg loss:1.445381
#
# Start evaluation.
# Done. Time:0.9928580219998366
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.613715 [    0/ 3881]
# loss:1.172740 [ 3200/ 3881]
# Done. Time:3.3514508890002617
# Training performance:
#  Avg loss:0.806789
#
# Start validation.
# Done. Time:0.33248559799994837
# Validation performance:
#  Avg loss:1.435407
#
# Start evaluation.
# Done. Time:1.3571656280000752
# Test performance:
#  Accuracy:63.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.607534 [    0/ 3881]
# loss:1.163465 [ 3200/ 3881]
# Done. Time:4.349340955999651
# Training performance:
#  Avg loss:0.797775
#
# Start validation.
# Done. Time:0.3554719940002542
# Validation performance:
#  Avg loss:1.425496
#
# Start evaluation.
# Done. Time:0.998095975999604
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.601485 [    0/ 3881]
# loss:1.154839 [ 3200/ 3881]
# Done. Time:3.279400520999843
# Training performance:
#  Avg loss:0.789090
#
# Start validation.
# Done. Time:0.3422306020001997
# Validation performance:
#  Avg loss:1.416090
#
# Start evaluation.
# Done. Time:1.1255264890000944
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.595287 [    0/ 3881]
# loss:1.146329 [ 3200/ 3881]
# Done. Time:4.1201688770001965
# Training performance:
#  Avg loss:0.780684
#
# Start validation.
# Done. Time:0.5337839849999
# Validation performance:
#  Avg loss:1.406479
#
# Start evaluation.
# Done. Time:1.4221339830000943
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.589396 [    0/ 3881]
# loss:1.138387 [ 3200/ 3881]
# Done. Time:3.2904234650000035
# Training performance:
#  Avg loss:0.772532
#
# Start validation.
# Done. Time:0.3393230550000226
# Validation performance:
#  Avg loss:1.396453
#
# Start evaluation.
# Done. Time:1.0542931059999319
# Test performance:
#  Accuracy:65.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.583536 [    0/ 3881]
# loss:1.130164 [ 3200/ 3881]
# Done. Time:3.2380089550001685
# Training performance:
#  Avg loss:0.764573
#
# Start validation.
# Done. Time:0.3293293749998156
# Validation performance:
#  Avg loss:1.385227
#
# Start evaluation.
# Done. Time:0.9653974560001188
# Test performance:
#  Accuracy:65.5%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.577707 [    0/ 3881]
# loss:1.121842 [ 3200/ 3881]
# Done. Time:4.87886080699991
# Training performance:
#  Avg loss:0.756809
#
# Start validation.
# Done. Time:0.33069715199962957
# Validation performance:
#  Avg loss:1.373357
#
# Start evaluation.
# Done. Time:1.0061534530000245
# Test performance:
#  Accuracy:65.5%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.571400 [    0/ 3881]
# loss:1.114032 [ 3200/ 3881]
# Done. Time:3.249763192000046
# Training performance:
#  Avg loss:0.749285
#
# Start validation.
# Done. Time:0.3264657560002888
# Validation performance:
#  Avg loss:1.362453
#
# Start evaluation.
# Done. Time:0.9814198709996163
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.565282 [    0/ 3881]
# loss:1.106684 [ 3200/ 3881]
# Done. Time:3.239809583999886
# Training performance:
#  Avg loss:0.741999
#
# Start validation.
# Done. Time:0.321899064000263
# Validation performance:
#  Avg loss:1.351263
#
# Start evaluation.
# Done. Time:1.3072931349997816
# Test performance:
#  Accuracy:65.5%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.558758 [    0/ 3881]
# loss:1.099708 [ 3200/ 3881]
# Done. Time:4.306111660999704
# Training performance:
#  Avg loss:0.734931
#
# Start validation.
# Done. Time:0.3357953740000994
# Validation performance:
#  Avg loss:1.341721
#
# Start evaluation.
# Done. Time:1.0177109030000793
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.552284 [    0/ 3881]
# loss:1.092766 [ 3200/ 3881]
# Done. Time:3.285646890999942
# Training performance:
#  Avg loss:0.728017
#
# Start validation.
# Done. Time:0.3322133159999794
# Validation performance:
#  Avg loss:1.331771
#
# Start evaluation.
# Done. Time:0.9625185290001355
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.545425 [    0/ 3881]
# loss:1.085865 [ 3200/ 3881]
# Done. Time:4.051668147000328
# Training performance:
#  Avg loss:0.721194
#
# Start validation.
# Done. Time:0.5362096949997976
# Validation performance:
#  Avg loss:1.323209
#
# Start evaluation.
# Done. Time:1.4579196859999684
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.539032 [    0/ 3881]
# loss:1.079124 [ 3200/ 3881]
# Done. Time:3.328154172000268
# Training performance:
#  Avg loss:0.714565
#
# Start validation.
# Done. Time:0.3386069270000007
# Validation performance:
#  Avg loss:1.314811
#
# Start evaluation.
# Done. Time:1.0421367869998903
# Test performance:
#  Accuracy:66.5%
# Minimum validation loss:1.3148107188088554 at 50 epoch.
# Maximum accuracy:66.5 at 49 epoch.

# %% [markdown]
# ### Plot

# %%
import matplotlib.pyplot as plt

plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(val_losses_origin)+1)
plt.plot(xs, val_losses_align_f_scale_f, label="Align_F-Scale_F", marker=".")
plt.plot(xs, val_losses_align_f_scale_u, label="Align_F-Scale_U", marker=".")
plt.plot(xs, val_losses_align_u_scale_f, label="Align_U-Scale_F", marker=".")
plt.plot(xs, val_losses_align_u_scale_u, label="Align_U-Scale_U", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Validation loss")
plt.legend()
plt.show()

# %%
plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(test_accs)+1)
ys = test_accs
plt.plot(xs, test_accs_align_f_scale_f, label="Align_F-Scale_F", marker=".")
plt.plot(xs, test_accs_align_f_scale_u, label="Align_F-Scale_U", marker=".")
plt.plot(xs, test_accs_align_u_scale_f, label="Align_U-Scale_F", marker=".")
plt.plot(xs, test_accs_align_u_scale_u, label="Align_U-Scale_U", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
