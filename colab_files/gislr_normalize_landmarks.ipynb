# %% [markdown]
# <a href="https://colab.research.google.com/github/takayama-rado/trado_samples/blob/main/colab_files/gislr_normalize_landmarks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Download dataset and modules

# %%
# I do not why, but only older virsion is works.
# https://github.com/wkentaro/gdown/issues/43#issuecomment-1426653602
# !pip install gdown==4.6.0
# Out:
# Collecting gdown==4.6.0
#   Downloading gdown-4.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown==4.6.0) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown==4.6.0) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown==4.6.0) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown==4.6.0) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown==4.6.0) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown==4.6.0) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.6.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.6.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.6.0) (2023.11.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.6.0) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.7.3
#     Uninstalling gdown-4.7.3:
#       Successfully uninstalled gdown-4.7.3
# Successfully installed gdown-4.6.0

# %%
import gdown

url = "https://drive.google.com/uc?id=1LJDGEwr4zqpBftjqO9SiSOLgUcNhMiSe"
output = "gislr_top10.zip"
gdown.download(url, output, quiet=False, fuzzy=True)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1LJDGEwr4zqpBftjqO9SiSOLgUcNhMiSe
# To: /content/gislr_top10.zip
# 100%|██████████| 880M/880M [00:05<00:00, 162MB/s]
# 'gislr_top10.zip'

# %%
# !unzip -o gislr_top10.zip
# Out:
# Archive:  gislr_top10.zip
#    creating: dataset_top10/
#   inflating: dataset_top10/16069.hdf5
#   inflating: dataset_top10/18796.hdf5
#   inflating: dataset_top10/2044.hdf5
#   inflating: dataset_top10/22343.hdf5
#   inflating: dataset_top10/25571.hdf5
#   inflating: dataset_top10/26734.hdf5
#   inflating: dataset_top10/27610.hdf5
#   inflating: dataset_top10/28656.hdf5
#   inflating: dataset_top10/29302.hdf5
#   inflating: dataset_top10/30680.hdf5
#   inflating: dataset_top10/32319.hdf5
#   inflating: dataset_top10/34503.hdf5
#   inflating: dataset_top10/36257.hdf5
#   inflating: dataset_top10/37055.hdf5
#   inflating: dataset_top10/37779.hdf5
#   inflating: dataset_top10/4718.hdf5
#   inflating: dataset_top10/49445.hdf5
#   inflating: dataset_top10/53618.hdf5
#   inflating: dataset_top10/55372.hdf5
#   inflating: dataset_top10/61333.hdf5
#   inflating: dataset_top10/62590.hdf5
#   inflating: dataset_top10/LICENSE.txt
#   inflating: dataset_top10/sign_to_prediction_index_map.json

# %%
# !ls dataset_top10
# Out:
# 16069.hdf5  25571.hdf5	29302.hdf5  36257.hdf5	49445.hdf5  62590.hdf5
# 18796.hdf5  26734.hdf5	30680.hdf5  37055.hdf5	53618.hdf5  LICENSE.txt
# 2044.hdf5   27610.hdf5	32319.hdf5  37779.hdf5	55372.hdf5  sign_to_prediction_index_map.json
# 22343.hdf5  28656.hdf5	34503.hdf5  4718.hdf5	61333.hdf5

# %%
# !cat dataset_top10/sign_to_prediction_index_map.json
# Out:
# {
#     "listen": 0,
#     "look": 1,
#     "shhh": 2,
#     "donkey": 3,
#     "mouse": 4,
#     "duck": 5,
#     "uncle": 6,
#     "hear": 7,
#     "pretend": 8,
#     "cow": 9
# }

# %%
# !cat dataset_top10/LICENSE.txt
# Out:
# The dataset provided by Natsuki Takayama (Takayama Research and Development Office) is licensed under CC-BY 4.0.
# Author: Copyright 2024 Natsuki Takayama
# Title: GISLR Top 10 dataset
# Original licenser: Deaf Professional Arts Network and the Georgia Institute of Technology
# Modification
# - Extract 10 most frequent words.
# - Packaged into HDF5 format.

# %%
import h5py
with h5py.File("dataset_top10/16069.hdf5", "r") as fread:
    keys = list(fread.keys())
    print(keys)
    group = fread[keys[0]]
    print(group.keys())
    feature = group["feature"][:]
    token = group["token"][:]
    print(feature.shape)
    print(token)
# Out:
# ['1109479272', '11121526', '1120349077', '1125456612', '1159046211', '1169128497', '1186032553', '1223803476', '1259708636', '1281972067', '129232566', '1334702305', '1340979012', '1352964057', '1370052047', '1383455381', '1431148933', '1435203624', '1437919781', '1458770030', '1462881097', '1469867050', '1474050058', '147607644', '1513539919', '1520635928', '1524297234', '153676122', '1537751003', '1542212461', '1551759770', '158232956', '1585855916', '1632709119', '1638742455', '1696757219', '177479476', '1779635114', '1791684792', '1801566440', '1831167282', '1867385690', '1880570146', '1901587887', '1910121429', '1919659282', '192873038', '1935012113', '1949620203', '195098847', '1983552660', '1989475963', '1998715062', '2007709802', '2036010239', '2036360025', '2046296211', '2082116372', '2098813002', '2109640010', '2121879330', '2141852087', '2148832702', '2152013823', '2166805079', '2176613834', '2184232774', '2213965523', '2249630763', '2256677805', '2263287955', '2263683020', '2264826605', '2270117351', '2281372282', '2285328250', '2322449232', '2326092712', '2336131857', '2346410171', '2405684784', '2467219838', '2473091535', '2488751095', '2515673021', '252176572', '2555449229', '2601816518', '2624310025', '2672738462', '2679264929', '2708514724', '2708544445', '2721276879', '2723773273', '2728839865', '2740241949', '2758304792', '2772051790', '2779816680', '2804441762', '2811346655', '2811646800', '2820103955', '2839681895', '2900998385', '2976200180', '2994456336', '3057994128', '3095010437', '3104317075', '3109672704', '3137179145', '3153285641', '3173321541', '3181666887', '3201889607', '3208820205', '3248401349', '3280527321', '3283246198', '3300057240', '3355963469', '3378306304', '3383637897', '3395075403', '3399503065', '3417877266', '3433092803', '347484677', '348956807', '3490841593', '3509324997', '3527069516', '3537611572', '3543711249', '3550826234', '3574700791', '3577812263', '3608551465', '3609537739', '3622960580', '3666781780', '3701422761', '3721927307', '3751410902', '3756613238', '3769544385', '3783554953', '3794712078', '380369091', '3813230821', '3817572483', '3843929707', '3869664504', '3892179393', '3923913515', '3981562204', '4078929101', '4101587978', '4150900444', '4191136837', '4200829752', '4209136328', '420958416', '422113773', '42222766', '4233346443', '4233985575', '4236057556', '4252161228', '425542996', '4276854486', '4294775577', '431609031', '439844759', '446236576', '470582324', '472128010', '492897929', '537402693', '5501547', '561170018', '593416697', '631898947', '649410423', '654529993', '678960043', '699907539', '707716966', '713615518', '778875120', '792981518', '796465415', '798649922', '856068671', '923153024', '957739544', '970593849', '976754415']
# <KeysViewHDF5 ['feature', 'token']>
# (3, 23, 543)
# [1]

# %%
# !wget https://github.com/takayama-rado/trado_samples/archive/master.zip
# Out:
# --2024-01-30 06:32:13--  https://github.com/takayama-rado/trado_samples/archive/master.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/takayama-rado/trado_samples/zip/main [following]
# --2024-01-30 06:32:13--  https://codeload.github.com/takayama-rado/trado_samples/zip/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [           <=>      ]  73.01M  17.8MB/s    in 4.1s
#
# 2024-01-30 06:32:17 (17.8 MB/s) - ‘master.zip’ saved [76552294]

# %%
# !unzip -o master.zip -d master
# Out:
# Archive:  master.zip
# 3ea96aba27be218a1fed57d97681e9014a3502a5
#    creating: master/trado_samples-main/
#   inflating: master/trado_samples-main/.gitignore
#   inflating: master/trado_samples-main/LICENSE
#   inflating: master/trado_samples-main/README.md
#    creating: master/trado_samples-main/colab_files/
#  extracting: master/trado_samples-main/colab_files/.gitkeep
#   inflating: master/trado_samples-main/colab_files/exp_affine_np_einsum.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_jax_static.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_mpholistic_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_mpothers_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_jax.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_numpy.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_tensorflow.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_torch.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_jax.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_numpy_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_numpy_1.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_tensorflow.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_torch.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_access_dataset.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_align_and_normalize_landmarks.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_select_landmarks.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_simple_islr_model.ipynb
#    creating: master/trado_samples-main/src/
#    creating: master/trado_samples-main/src/modules_gislr/
#  extracting: master/trado_samples-main/src/modules_gislr/__init__.py
#   inflating: master/trado_samples-main/src/modules_gislr/dataset.py
#   inflating: master/trado_samples-main/src/modules_gislr/defines.py
#   inflating: master/trado_samples-main/src/modules_gislr/draw_functions.py
#   inflating: master/trado_samples-main/src/modules_gislr/layers.py
#   inflating: master/trado_samples-main/src/modules_gislr/train_functions.py
#   inflating: master/trado_samples-main/src/modules_gislr/transforms.py
#    creating: master/trado_samples-main/test_data/
#   inflating: master/trado_samples-main/test_data/finger_far0.mp4
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static.npy
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static_affine.npy
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static_interp.npy
#   inflating: master/trado_samples-main/test_data/finger_middle0.mp4
#   inflating: master/trado_samples-main/test_data/finger_near0.mp4
#   inflating: master/trado_samples-main/test_data/hand_only.mp4

# %%
# !mv master/trado_samples-main/src/modules_gislr .

# %%
# !rm -rf master master.zip gislr_top10.zip

# %%
# !ls
# Out:
# dataset_top10  modules_gislr  sample_data

# %% [markdown]
# # 2. Load library

# %%
import json
import math
import sys
import time
from functools import partial
from pathlib import Path
from typing import (
    Any,
    Dict
)

# Third party's modules
import numpy as np

import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import (
    DataLoader)

from torchvision.transforms import Compose

# Local modules
sys.path.append("modules_gislr")
from modules_gislr.dataset import (
    HDF5Dataset,
    merge_padded_batch)
from modules_gislr.defines import (
    get_fullbody_landmarks,
    get_parts_connections
)
from modules_gislr.train_functions import (
    test_loop,
    train_loop,
    val_loop
)
from modules_gislr.draw_functions import (
    draw_tracking,
    showvideo_on_browser
)
from modules_gislr.layers import (
    SimpleISLR
)
from modules_gislr.transforms import (
    ReplaceNan,
    SelectLandmarksAndFeature,
    ToTensor
)

# %% [markdown]
# # 3. Implement preprocess

# %%
class PartsBasedNormalization():
    def __init__(self,
                 face_head=0, face_num=76, face_origin=[0, 2], face_unit1=[7], face_unit2=[42],
                 lhand_head=76, lhand_num=21, lhand_origin=[0, 2, 5, 9, 13, 17], lhand_unit1=[0], lhand_unit2=[2, 5, 9, 13, 17],
                 pose_head=76+21, pose_num=12, pose_origin=[0, 1], pose_unit1=[0], pose_unit2=[1],
                 rhand_head=76+21+12, rhand_num=21, rhand_origin=[0, 2, 3, 9, 13, 17], rhand_unit1=[0], rhand_unit2=[2, 5, 9, 13, 17],
                 align_mode="framewise", scale_mode="framewise") -> None:
        assert align_mode in ["framewise", "unique"]
        assert scale_mode in ["framewise", "unique", "none"]
        self.align_mode = align_mode
        self.scale_mode = scale_mode

        self.face_head = face_head
        self.face_num = face_num
        self.face_origin = face_origin
        self.face_unit1 = face_unit1
        self.face_unit2 = face_unit2

        self.lhand_head = lhand_head
        self.lhand_num = lhand_num
        self.lhand_origin = lhand_origin
        self.lhand_unit1 = lhand_unit1
        self.lhand_unit2 = lhand_unit2

        self.pose_head = pose_head
        self.pose_num = pose_num
        self.pose_origin = pose_origin
        self.pose_unit1 = pose_unit1
        self.pose_unit2 = pose_unit2

        self.rhand_head = rhand_head
        self.rhand_num = rhand_num
        self.rhand_origin = rhand_origin
        self.rhand_unit1 = rhand_unit1
        self.rhand_unit2 = rhand_unit2

    def _gen_tmask(self, feature):
        tmask = feature == 0.0
        tmask = np.all(tmask, axis=(0, 2))
        tmask = np.logical_not(tmask.reshape([1, -1, 1]))
        return tmask

    def _calc_origin(self, feature, origin_lm):
        # `[C, T, J] -> [C, T, 1]`
        origin = feature[:, :, origin_lm].mean(axis=-1, keepdims=True)
        if self.align_mode == "unique":
            # `[C, T, 1] -> [C, 1, 1]`
            mask = self._gen_tmask(origin)
            mask = mask.reshape([mask.shape[1]])
            if mask.any():
                origin = origin[:, mask, :].mean(axis=1, keepdims=True)
            else:
                origin = np.array([0.] * feature.shape[0]).reshape([-1, 1, 1])
        return origin

    def _calc_unit(self, feature, unit_lm1, unit_lm2, unit_range):
        if self.scale_mode == "none":
            return 1.0
        # The frame-wise unit lengths are unstable.
        # So, we calculate average unit length.
        # Extract.
        # `[C, T, J] -> [C, T, 1]`
        unit1 = feature[:, :, unit_lm1].mean(axis=-1)
        unit2 = feature[:, :, unit_lm2].mean(axis=-1)
        # Mean square between target points.
        unit = np.sqrt((unit1 - unit2) ** 2)
        # Norm.
        # `[C, T, J] -> [1, T, 1]`
        unit = np.linalg.norm(unit, axis=0)
        if self.scale_mode == "framewise":
            unit = unit.reshape([1, unit.shape[0], 1])
            unit[unit <= 0] = 1.0
            unit[np.isnan(unit)] = 1.0
        else:
            # Calculate average removing undetected frame.
            mask = unit > 0
            if mask.sum() > 0:
                unit = unit[unit > 0].mean()
            else:
                unit = 1.0
            unit = 1.0 if np.isnan(unit).any() else unit
        # Finally, clip extreme values.
        unit = np.clip(unit, a_min=unit_range[0], a_max=unit_range[1])
        return unit

    def _normalize(self, feature, origin_lm, unit_lm1, unit_lm2,
                   unit_range=[1.0e-3, 5.0]):
        tmask = self._gen_tmask(feature)
        origin = self._calc_origin(feature, origin_lm)
        unit = self._calc_unit(feature, unit_lm1, unit_lm2, unit_range)

        _feature = feature - origin
        _feature = _feature / unit
        _feature = _feature * tmask
        return _feature

    def __call__(self,
                 data: Dict[str, Any]) -> Dict[str, Any]:
        feature = data["feature"]
        if self.face_num > 0:
            face = feature[:, :, self.face_head: self.face_head+self.face_num]
            face = self._normalize(face, self.face_origin,
                                   self.face_unit1, self.face_unit2)
            feature[:, :, self.face_head: self.face_head+self.face_num] = face
        if self.lhand_num > 0:
            lhand = feature[:, :, self.lhand_head: self.lhand_head+self.lhand_num]
            lhand = self._normalize(lhand, self.lhand_origin,
                                    self.lhand_unit1, self.lhand_unit2)
            feature[:, :, self.lhand_head: self.lhand_head+self.lhand_num] = lhand
        if self.pose_num > 0:
            pose = feature[:, :, self.pose_head: self.pose_head+self.pose_num]
            pose = self._normalize(pose, self.pose_origin,
                                   self.pose_unit1, self.pose_unit2)
            feature[:, :, self.pose_head: self.pose_head+self.pose_num] = pose
        if self.rhand_num > 0:
            rhand = feature[:, :, self.rhand_head: self.rhand_head+self.rhand_num]
            rhand = self._normalize(rhand, self.rhand_origin,
                                    self.rhand_unit1, self.rhand_unit2)
            feature[:, :, self.rhand_head: self.rhand_head+self.rhand_num] = rhand
        data["feature"] = feature
        return data

# %%
# Access check.
dataset_dir = Path("dataset_top10")
files = list(dataset_dir.iterdir())
dictionary = [fin for fin in files if ".json" in fin.name][0]
hdf5_files = [fin for fin in files if ".hdf5" in fin.name]

print(dictionary)
print(hdf5_files)
# Out:
# dataset_top10/sign_to_prediction_index_map.json
# [PosixPath('dataset_top10/28656.hdf5'), PosixPath('dataset_top10/30680.hdf5'), PosixPath('dataset_top10/18796.hdf5'), PosixPath('dataset_top10/2044.hdf5'), PosixPath('dataset_top10/37055.hdf5'), PosixPath('dataset_top10/61333.hdf5'), PosixPath('dataset_top10/4718.hdf5'), PosixPath('dataset_top10/26734.hdf5'), PosixPath('dataset_top10/29302.hdf5'), PosixPath('dataset_top10/37779.hdf5'), PosixPath('dataset_top10/25571.hdf5'), PosixPath('dataset_top10/55372.hdf5'), PosixPath('dataset_top10/36257.hdf5'), PosixPath('dataset_top10/27610.hdf5'), PosixPath('dataset_top10/32319.hdf5'), PosixPath('dataset_top10/62590.hdf5'), PosixPath('dataset_top10/34503.hdf5'), PosixPath('dataset_top10/22343.hdf5'), PosixPath('dataset_top10/49445.hdf5'), PosixPath('dataset_top10/53618.hdf5'), PosixPath('dataset_top10/16069.hdf5')]

# %%
# Load dictionary.
with open(dictionary, "r") as fread:
    key2token = json.load(fread)

VOCAB = len(key2token)

# %% [markdown]
# ## Define transformations

# %%
_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
trans_select_feature = SelectLandmarksAndFeature(landmarks=use_landmarks, features=use_features)
trans_repnan = ReplaceNan()
align_mode = "framewise"

trans_align_whole = PartsBasedNormalization(
                              face_num=0,
                              lhand_num=0,
                              pose_head=0, pose_num=len(use_landmarks), pose_origin=[97, 98], pose_unit1=[97], pose_unit2=[98],
                              rhand_num=0,
                              align_mode=align_mode,
                              scale_mode="none")

trans_align_parts = PartsBasedNormalization(align_mode=align_mode, scale_mode="none")

trans_align_scale_whole = PartsBasedNormalization(
                              face_num=0,
                              lhand_num=0,
                              pose_head=0, pose_num=len(use_landmarks), pose_origin=[97, 98], pose_unit1=[97], pose_unit2=[98],
                              rhand_num=0,
                              align_mode=align_mode, scale_mode="unique")

trans_align_scale_parts = PartsBasedNormalization(align_mode=align_mode, scale_mode="unique")

# %%
pre_transforms_origin = Compose([trans_select_feature,
                                 trans_repnan])

pre_transforms_align_whole = Compose([trans_select_feature,
                                      trans_repnan,
                                      trans_align_whole])

pre_transforms_align_parts = Compose([trans_select_feature,
                                      trans_repnan,
                                      trans_align_parts])

pre_transforms_align_scale_whole = Compose([trans_select_feature,
                                           trans_repnan,
                                           trans_align_scale_whole])

pre_transforms_align_scale_parts = Compose([trans_select_feature,
                                           trans_repnan,
                                           trans_align_scale_parts])

transforms = Compose([ToTensor()])

# %% [markdown]
# ## Original landmarks

# %%
batch_size = 2
feature_shape = (len(use_features), -1, len(use_landmarks))
token_shape = (1,)
merge_fn = partial(merge_padded_batch,
                   feature_shape=feature_shape,
                   token_shape=token_shape,
                   feature_padding_val=0.0,
                   token_padding_val=0)

dataset = HDF5Dataset(hdf5_files, pre_transforms=pre_transforms_origin, transforms=transforms)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=merge_fn)
try:
    data = next(iter(dataloader))
    feature_origin = data["feature"]

    print(feature_origin.shape)
except Exception as inst:
    print(inst)
# Out:
# torch.Size([2, 2, 27, 130])

# %% [markdown]
# ## Aligned landmarks (whole body)

# %%
batch_size = 2
feature_shape = (len(use_features), -1, len(use_landmarks))
token_shape = (1,)
merge_fn = partial(merge_padded_batch,
                   feature_shape=feature_shape,
                   token_shape=token_shape,
                   feature_padding_val=0.0,
                   token_padding_val=0)

dataset = HDF5Dataset(hdf5_files, pre_transforms=pre_transforms_align_whole, transforms=transforms)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=merge_fn)
try:
    data = next(iter(dataloader))
    feature_align_w = data["feature"]

    print(feature_align_w.shape)
except Exception as inst:
    print(inst)
# Out:
# torch.Size([2, 2, 27, 130])

# %% [markdown]
# ## Aligned landmarks (parts-based)

# %%
batch_size = 2
feature_shape = (len(use_features), -1, len(use_landmarks))
token_shape = (1,)
merge_fn = partial(merge_padded_batch,
                   feature_shape=feature_shape,
                   token_shape=token_shape,
                   feature_padding_val=0.0,
                   token_padding_val=0)

dataset = HDF5Dataset(hdf5_files, pre_transforms=pre_transforms_align_parts, transforms=transforms)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=merge_fn)
try:
    data = next(iter(dataloader))
    feature_align_p = data["feature"]

    print(feature_align_p.shape)
except Exception as inst:
    print(inst)
# Out:
# torch.Size([2, 2, 27, 130])

# %% [markdown]
# ## Aligned and scaled landmarks (whole body)

# %%
batch_size = 2
feature_shape = (len(use_features), -1, len(use_landmarks))
token_shape = (1,)
merge_fn = partial(merge_padded_batch,
                   feature_shape=feature_shape,
                   token_shape=token_shape,
                   feature_padding_val=0.0,
                   token_padding_val=0)

dataset = HDF5Dataset(hdf5_files, pre_transforms=pre_transforms_align_scale_whole, transforms=transforms)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=merge_fn)
try:
    data = next(iter(dataloader))
    feature_align_scale_w = data["feature"]

    print(feature_align_scale_w.shape)
except Exception as inst:
    print(inst)
# Out:
# torch.Size([2, 2, 27, 130])

# %% [markdown]
# ## Aligned and scaled landmarks (parts-based)

# %%
batch_size = 2
feature_shape = (len(use_features), -1, len(use_landmarks))
token_shape = (1,)
merge_fn = partial(merge_padded_batch,
                   feature_shape=feature_shape,
                   token_shape=token_shape,
                   feature_padding_val=0.0,
                   token_padding_val=0)

dataset = HDF5Dataset(hdf5_files, pre_transforms=pre_transforms_align_scale_parts, transforms=transforms)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=merge_fn)
try:
    data = next(iter(dataloader))
    feature_align_scale_p = data["feature"]

    print(feature_align_scale_p.shape)
except Exception as inst:
    print(inst)
# Out:
# torch.Size([2, 2, 27, 130])

# %% [markdown]
# # 4. Check normalized landmarks

# %%
feature_origin = feature_origin.detach().cpu().numpy()
feature_align_w = feature_align_w.detach().cpu().numpy()
feature_align_p = feature_align_p.detach().cpu().numpy()
feature_align_scale_w = feature_align_scale_w.detach().cpu().numpy()
feature_align_scale_p = feature_align_scale_p.detach().cpu().numpy()

_, use_landmarks = get_fullbody_landmarks()
_, face_connections = get_parts_connections(use_landmarks, "face")
_, lhand_connections = get_parts_connections(use_landmarks, "lhand")
_, pose_connections = get_parts_connections(use_landmarks, "pose")
_, rhand_connections = get_parts_connections(use_landmarks, "rhand")

# %% [markdown]
# ## Original landmarks

# %%
outpath = "./track_origin.mp4"
draw_tracking(feature_origin, outpath,
              face_connections=face_connections,
              lhand_connections=lhand_connections,
              pose_connections=pose_connections,
              rhand_connections=rhand_connections,
              channel_first=True)
# Out:
# Window size: 739 747
# Offsets: 118 0

# %%
# The MP4 file generated by OpenCV can not display correctly.
# So I convert it into WEBM file.
# !ffmpeg -i track_origin.mp4 -vcodec vp9 -y track_origin.webm
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'track_origin.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:00.90, start: 0.000000, bitrate: 3978 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 738x746 [SAR 1:1 DAR 369:373], 3969 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> vp9 (libvpx-vp9))
# Press [q] to stop, [?] for help
# [libvpx-vp9 @ 0x569882009780] v1.11.0
# [libvpx-vp9 @ 0x569882009780] Neither bitrate nor constrained quality specified, using default CRF of 32
# Output #0, webm, to 'track_origin.webm':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: vp9, yuv420p(progressive), 738x746 [SAR 1:1 DAR 369:373], q=2-31, 30 fps, 1k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libvpx-vp9
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   27 fps=7.3 q=0.0 Lsize=     112kB time=00:00:00.86 bitrate=1055.8kbits/s speed=0.236x
# video:111kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.811377%

# %%
showvideo_on_browser(outpath.replace(".mp4", ".webm"))
# Out:
# <video width=500 height=500 controls><source src="data:video/mp4;base64,..."type="video/mp4" /></video>

# %% [markdown]
# ## Aligned landmarks (whole body)

# %%
outpath = "./track_align_w.mp4"
draw_tracking(feature_align_w, outpath,
              face_connections=face_connections,
              lhand_connections=lhand_connections,
              pose_connections=pose_connections,
              rhand_connections=rhand_connections,
              channel_first=True)
# Out:
# Window size: 911 867
# Offsets: 411 367

# %%
# The MP4 file generated by OpenCV can not display correctly.
# So I convert it into WEBM file.
# !ffmpeg -i track_align_w.mp4 -vcodec vp9 -y track_align_w.webm
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'track_align_w.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:00.90, start: 0.000000, bitrate: 3366 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 910x866 [SAR 1:1 DAR 455:433], 3357 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> vp9 (libvpx-vp9))
# Press [q] to stop, [?] for help
# [libvpx-vp9 @ 0x560e30dcb7c0] v1.11.0
# [libvpx-vp9 @ 0x560e30dcb7c0] Neither bitrate nor constrained quality specified, using default CRF of 32
# Output #0, webm, to 'track_align_w.webm':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: vp9, yuv420p(progressive), 910x866 [SAR 1:1 DAR 455:433], q=2-31, 30 fps, 1k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libvpx-vp9
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   27 fps=8.9 q=0.0 Lsize=      93kB time=00:00:00.86 bitrate= 882.3kbits/s speed=0.287x
# video:93kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.971427%

# %%
showvideo_on_browser(outpath.replace(".mp4", ".webm"))
# Out:
# <video width=500 height=500 controls><source src="data:video/mp4;base64,..."type="video/mp4" /></video>

# %% [markdown]
# ## Aligned landmarks (parts-based)

# %%
outpath = "./track_align_p.mp4"
draw_tracking(feature_align_p, outpath,
              face_connections=face_connections,
              lhand_connections=lhand_connections,
              pose_connections=pose_connections,
              rhand_connections=rhand_connections,
              channel_first=True)
# Out:
# Window size: 911 687
# Offsets: 411 187

# %%
# The MP4 file generated by OpenCV can not display correctly.
# So I convert it into WEBM file.
# !ffmpeg -i track_align_p.mp4 -vcodec vp9 -y track_align_p.webm
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'track_align_p.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:00.90, start: 0.000000, bitrate: 3473 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 910x686 [SAR 1:1 DAR 65:49], 3464 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> vp9 (libvpx-vp9))
# Press [q] to stop, [?] for help
# [libvpx-vp9 @ 0x568afcdb2240] v1.11.0
# [libvpx-vp9 @ 0x568afcdb2240] Neither bitrate nor constrained quality specified, using default CRF of 32
# Output #0, webm, to 'track_align_p.webm':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: vp9, yuv420p(progressive), 910x686 [SAR 1:1 DAR 65:49], q=2-31, 30 fps, 1k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libvpx-vp9
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   27 fps=9.7 q=0.0 Lsize=      90kB time=00:00:00.86 bitrate= 847.5kbits/s speed=0.313x
# video:89kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.011732%

# %%
showvideo_on_browser(outpath.replace(".mp4", ".webm"))
# Out:
# <video width=500 height=500 controls><source src="data:video/mp4;base64,..."type="video/mp4" /></video>

# %% [markdown]
# ## Aligned and scaled landmarks (whole body)

# %%
outpath = "./track_align_scale_w.mp4"
draw_tracking(feature_align_scale_w, outpath,
              face_connections=face_connections,
              lhand_connections=lhand_connections,
              pose_connections=pose_connections,
              rhand_connections=rhand_connections,
              channel_first=True)
# Out:
# Window size: 1115 1135
# Offsets: 615 548

# %%
# The MP4 file generated by OpenCV can not display correctly.
# So I convert it into WEBM file.
# !ffmpeg -i track_align_scale_w.mp4 -vcodec vp9 -y track_align_scale_w.webm
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'track_align_scale_w.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:00.90, start: 0.000000, bitrate: 5037 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1114x1134 [SAR 1:1 DAR 557:567], 5028 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> vp9 (libvpx-vp9))
# Press [q] to stop, [?] for help
# [libvpx-vp9 @ 0x587692bbd180] v1.11.0
# [libvpx-vp9 @ 0x587692bbd180] Neither bitrate nor constrained quality specified, using default CRF of 32
# Output #0, webm, to 'track_align_scale_w.webm':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: vp9, yuv420p(progressive), 1114x1134 [SAR 1:1 DAR 557:567], q=2-31, 30 fps, 1k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libvpx-vp9
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   27 fps=4.7 q=0.0 Lsize=     137kB time=00:00:00.86 bitrate=1289.6kbits/s speed=0.151x
# video:136kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.663319%

# %%
showvideo_on_browser(outpath.replace(".mp4", ".webm"))
# Out:
# <video width=500 height=500 controls><source src="data:video/mp4;base64,..."type="video/mp4" /></video>

# %% [markdown]
# ## Aligned and scaled landmarks (parts-based)

# %%
outpath = "./track_align_scale_p.mp4"
draw_tracking(feature_align_scale_p, outpath,
              face_connections=face_connections,
              lhand_connections=lhand_connections,
              pose_connections=pose_connections,
              rhand_connections=rhand_connections,
              channel_first=True)
# Out:
# Window size: 1374 1311
# Offsets: 615 574

# %%
# The MP4 file generated by OpenCV can not display correctly.
# So I convert it into WEBM file.
# !ffmpeg -i track_align_scale_p.mp4 -vcodec vp9 -y track_align_scale_p.webm
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'track_align_scale_p.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:00.90, start: 0.000000, bitrate: 10441 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1374x1310 [SAR 1:1 DAR 687:655], 10432 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> vp9 (libvpx-vp9))
# Press [q] to stop, [?] for help
# [libvpx-vp9 @ 0x5922190bbb40] v1.11.0
# [libvpx-vp9 @ 0x5922190bbb40] Neither bitrate nor constrained quality specified, using default CRF of 32
# Output #0, webm, to 'track_align_scale_p.webm':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: vp9, yuv420p(progressive), 1374x1310 [SAR 1:1 DAR 687:655], q=2-31, 30 fps, 1k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libvpx-vp9
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   27 fps=3.5 q=0.0 Lsize=     278kB time=00:00:00.86 bitrate=2627.1kbits/s speed=0.111x
# video:277kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.325928%

# %%
showvideo_on_browser(outpath.replace(".mp4", ".webm"))
# Out:
# <video width=500 height=500 controls><source src="data:video/mp4;base64,..."type="video/mp4" /></video>

# %% [markdown]
# # 5. Train and evaluation

# %%
# Set common parameters.
batch_size = 32
load_into_ram = True
test_pid = 16069
num_workers = 1

epochs = 50
eval_every_n_epochs = 1
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} for computation.")

train_hdf5files = [fin for fin in hdf5_files if str(test_pid) not in fin.name]
val_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]
test_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]

_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
# Out:
# Using cpu for computation.

# %% [markdown]
# ## Train with original landmarks (selection only).

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_origin))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_origin,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_origin,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_origin,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_origin = np.array(val_losses)
test_accs_origin = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_origin.min()} at {np.argmin(val_losses_origin)+1} epoch.")
print(f"Maximum accuracy:{test_accs_origin.max()} at {np.argmax(test_accs_origin)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.397505 [    0/ 3881]
# loss:2.293054 [ 3200/ 3881]
# Done. Time:3.210748345000013
# Start validation.
# Done. Time:0.2671058600000151
# Validation performance:
#  Avg loss:2.284921
#
# Start evaluation.
# Done. Time:0.8380756489999897
# Test performance:
#  Accuracy:16.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.225931 [    0/ 3881]
# loss:2.256440 [ 3200/ 3881]
# Done. Time:3.9943283519999966
# Start validation.
# Done. Time:0.41670277299999725
# Validation performance:
#  Avg loss:2.260611
#
# Start evaluation.
# Done. Time:0.8227325229999849
# Test performance:
#  Accuracy:15.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:2.195938 [    0/ 3881]
# loss:2.226194 [ 3200/ 3881]
# Done. Time:4.008227259999984
# Start validation.
# Done. Time:0.27329921800000534
# Validation performance:
#  Avg loss:2.241097
#
# Start evaluation.
# Done. Time:0.8383047160000103
# Test performance:
#  Accuracy:21.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:2.168865 [    0/ 3881]
# loss:2.197325 [ 3200/ 3881]
# Done. Time:3.0488355839999883
# Start validation.
# Done. Time:0.2858856399999752
# Validation performance:
#  Avg loss:2.224326
#
# Start evaluation.
# Done. Time:0.8509001490000117
# Test performance:
#  Accuracy:21.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:2.157957 [    0/ 3881]
# loss:2.182248 [ 3200/ 3881]
# Done. Time:3.050713424999998
# Start validation.
# Done. Time:0.36302048199999604
# Validation performance:
#  Avg loss:2.202284
#
# Start evaluation.
# Done. Time:1.2058622100000207
# Test performance:
#  Accuracy:23.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:2.142878 [    0/ 3881]
# loss:2.143875 [ 3200/ 3881]
# Done. Time:3.3086371739999834
# Start validation.
# Done. Time:0.257207625999996
# Validation performance:
#  Avg loss:2.186189
#
# Start evaluation.
# Done. Time:0.8746819350000123
# Test performance:
#  Accuracy:23.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:2.115248 [    0/ 3881]
# loss:2.101776 [ 3200/ 3881]
# Done. Time:3.03273200000001
# Start validation.
# Done. Time:0.26597158300000956
# Validation performance:
#  Avg loss:2.172597
#
# Start evaluation.
# Done. Time:0.8248726650000151
# Test performance:
#  Accuracy:25.5%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:2.094890 [    0/ 3881]
# loss:2.064521 [ 3200/ 3881]
# Done. Time:3.6660684089999904
# Start validation.
# Done. Time:0.3964691040000048
# Validation performance:
#  Avg loss:2.160880
#
# Start evaluation.
# Done. Time:0.9312655359999837
# Test performance:
#  Accuracy:27.5%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:2.078774 [    0/ 3881]
# loss:2.033616 [ 3200/ 3881]
# Done. Time:3.030985168000001
# Start validation.
# Done. Time:0.2663521120000212
# Validation performance:
#  Avg loss:2.150416
#
# Start evaluation.
# Done. Time:0.8206190300000173
# Test performance:
#  Accuracy:26.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:2.065440 [    0/ 3881]
# loss:2.011013 [ 3200/ 3881]
# Done. Time:3.034183705999993
# Start validation.
# Done. Time:0.27041386700000203
# Validation performance:
#  Avg loss:2.140190
#
# Start evaluation.
# Done. Time:0.8622313109999595
# Test performance:
#  Accuracy:25.5%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:2.059076 [    0/ 3881]
# loss:1.981191 [ 3200/ 3881]
# Done. Time:4.560001704000001
# Start validation.
# Done. Time:0.2768300959999692
# Validation performance:
#  Avg loss:2.133889
#
# Start evaluation.
# Done. Time:0.8396041139999966
# Test performance:
#  Accuracy:24.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:2.041337 [    0/ 3881]
# loss:1.962414 [ 3200/ 3881]
# Done. Time:4.127306046000001
# Start validation.
# Done. Time:0.2897743549999632
# Validation performance:
#  Avg loss:2.124051
#
# Start evaluation.
# Done. Time:0.8839420399999653
# Test performance:
#  Accuracy:25.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:2.028762 [    0/ 3881]
# loss:1.939235 [ 3200/ 3881]
# Done. Time:3.5406543010000178
# Start validation.
# Done. Time:0.41723955499998056
# Validation performance:
#  Avg loss:2.115935
#
# Start evaluation.
# Done. Time:1.1902187270000013
# Test performance:
#  Accuracy:25.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:2.017783 [    0/ 3881]
# loss:1.919049 [ 3200/ 3881]
# Done. Time:3.1058113450000064
# Start validation.
# Done. Time:0.27347660499998483
# Validation performance:
#  Avg loss:2.108104
#
# Start evaluation.
# Done. Time:0.884480577999966
# Test performance:
#  Accuracy:26.0%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:2.006671 [    0/ 3881]
# loss:1.902199 [ 3200/ 3881]
# Done. Time:3.813072169999998
# Start validation.
# Done. Time:0.2512925539999742
# Validation performance:
#  Avg loss:2.099489
#
# Start evaluation.
# Done. Time:0.8776304000000437
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.998238 [    0/ 3881]
# loss:1.885606 [ 3200/ 3881]
# Done. Time:4.074871510999969
# Start validation.
# Done. Time:0.2661028500000384
# Validation performance:
#  Avg loss:2.090814
#
# Start evaluation.
# Done. Time:0.8651389480000375
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.988846 [    0/ 3881]
# loss:1.871500 [ 3200/ 3881]
# Done. Time:3.038702830000034
# Start validation.
# Done. Time:0.27752466399999776
# Validation performance:
#  Avg loss:2.085350
#
# Start evaluation.
# Done. Time:0.8394680469999685
# Test performance:
#  Accuracy:27.0%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.977252 [    0/ 3881]
# loss:1.859321 [ 3200/ 3881]
# Done. Time:3.0994698549999953
# Start validation.
# Done. Time:0.2503240510000069
# Validation performance:
#  Avg loss:2.079806
#
# Start evaluation.
# Done. Time:1.1255840499999863
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.967706 [    0/ 3881]
# loss:1.843243 [ 3200/ 3881]
# Done. Time:3.5359818150000137
# Start validation.
# Done. Time:0.2666241830000331
# Validation performance:
#  Avg loss:2.075606
#
# Start evaluation.
# Done. Time:0.838079687000004
# Test performance:
#  Accuracy:27.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.958527 [    0/ 3881]
# loss:1.830069 [ 3200/ 3881]
# Done. Time:3.034537608999983
# Start validation.
# Done. Time:0.2549466589999838
# Validation performance:
#  Avg loss:2.071385
#
# Start evaluation.
# Done. Time:0.8460481390000041
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.950298 [    0/ 3881]
# loss:1.816910 [ 3200/ 3881]
# Done. Time:3.435100632000001
# Start validation.
# Done. Time:0.4128200919999472
# Validation performance:
#  Avg loss:2.066722
#
# Start evaluation.
# Done. Time:1.1018140689999996
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.942737 [    0/ 3881]
# loss:1.803040 [ 3200/ 3881]
# Done. Time:3.0506017800000222
# Start validation.
# Done. Time:0.26440860400003885
# Validation performance:
#  Avg loss:2.062934
#
# Start evaluation.
# Done. Time:0.8604611850000197
# Test performance:
#  Accuracy:24.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.932484 [    0/ 3881]
# loss:1.790401 [ 3200/ 3881]
# Done. Time:3.0909498949999943
# Start validation.
# Done. Time:0.28795079200000373
# Validation performance:
#  Avg loss:2.058898
#
# Start evaluation.
# Done. Time:1.0862394140000333
# Test performance:
#  Accuracy:25.0%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.924925 [    0/ 3881]
# loss:1.779010 [ 3200/ 3881]
# Done. Time:4.560352246000036
# Start validation.
# Done. Time:0.2724433660000045
# Validation performance:
#  Avg loss:2.054368
#
# Start evaluation.
# Done. Time:0.7911285050000174
# Test performance:
#  Accuracy:25.5%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.918902 [    0/ 3881]
# loss:1.766753 [ 3200/ 3881]
# Done. Time:3.06516077699996
# Start validation.
# Done. Time:0.2794226010000216
# Validation performance:
#  Avg loss:2.050363
#
# Start evaluation.
# Done. Time:0.8364243539999734
# Test performance:
#  Accuracy:24.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.911367 [    0/ 3881]
# loss:1.755348 [ 3200/ 3881]
# Done. Time:3.1133445689999917
# Start validation.
# Done. Time:0.2730680500000062
# Validation performance:
#  Avg loss:2.046788
#
# Start evaluation.
# Done. Time:0.9499582870000154
# Test performance:
#  Accuracy:24.0%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.904212 [    0/ 3881]
# loss:1.743611 [ 3200/ 3881]
# Done. Time:3.8039960660000247
# Start validation.
# Done. Time:0.2799572650000073
# Validation performance:
#  Avg loss:2.043499
#
# Start evaluation.
# Done. Time:0.8444672990000299
# Test performance:
#  Accuracy:24.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.896825 [    0/ 3881]
# loss:1.734254 [ 3200/ 3881]
# Done. Time:3.069444970999996
# Start validation.
# Done. Time:0.27770722200000364
# Validation performance:
#  Avg loss:2.040556
#
# Start evaluation.
# Done. Time:0.8236362119999967
# Test performance:
#  Accuracy:25.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:1.890750 [    0/ 3881]
# loss:1.722877 [ 3200/ 3881]
# Done. Time:3.2942923699999938
# Start validation.
# Done. Time:0.4386575350000044
# Validation performance:
#  Avg loss:2.037665
#
# Start evaluation.
# Done. Time:1.159467463999988
# Test performance:
#  Accuracy:25.0%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.884073 [    0/ 3881]
# loss:1.713009 [ 3200/ 3881]
# Done. Time:3.062794212999961
# Start validation.
# Done. Time:0.2602380010000047
# Validation performance:
#  Avg loss:2.034575
#
# Start evaluation.
# Done. Time:0.8496277279999731
# Test performance:
#  Accuracy:25.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:1.877916 [    0/ 3881]
# loss:1.703560 [ 3200/ 3881]
# Done. Time:3.0485601679999945
# Start validation.
# Done. Time:0.2645047839999961
# Validation performance:
#  Avg loss:2.031774
#
# Start evaluation.
# Done. Time:0.8445795619999785
# Test performance:
#  Accuracy:26.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.872018 [    0/ 3881]
# loss:1.694434 [ 3200/ 3881]
# Done. Time:4.006352258999982
# Start validation.
# Done. Time:0.3232281539999917
# Validation performance:
#  Avg loss:2.028694
#
# Start evaluation.
# Done. Time:0.8275952390000043
# Test performance:
#  Accuracy:25.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:1.866879 [    0/ 3881]
# loss:1.686053 [ 3200/ 3881]
# Done. Time:3.0882169000000204
# Start validation.
# Done. Time:0.26450653800003465
# Validation performance:
#  Avg loss:2.025902
#
# Start evaluation.
# Done. Time:0.8354513030000135
# Test performance:
#  Accuracy:26.0%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:1.861987 [    0/ 3881]
# loss:1.677876 [ 3200/ 3881]
# Done. Time:3.0282524230000263
# Start validation.
# Done. Time:0.270189863999974
# Validation performance:
#  Avg loss:2.023135
#
# Start evaluation.
# Done. Time:0.8201396659999887
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.857174 [    0/ 3881]
# loss:1.669900 [ 3200/ 3881]
# Done. Time:4.022196123000015
# Start validation.
# Done. Time:0.2661818199999857
# Validation performance:
#  Avg loss:2.020418
#
# Start evaluation.
# Done. Time:0.8423334330000216
# Test performance:
#  Accuracy:27.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.852993 [    0/ 3881]
# loss:1.662252 [ 3200/ 3881]
# Done. Time:3.0846580279999785
# Start validation.
# Done. Time:0.2459733690000121
# Validation performance:
#  Avg loss:2.017802
#
# Start evaluation.
# Done. Time:0.818187824000006
# Test performance:
#  Accuracy:27.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.849233 [    0/ 3881]
# loss:1.654583 [ 3200/ 3881]
# Done. Time:3.078544982999972
# Start validation.
# Done. Time:0.2733447589999969
# Validation performance:
#  Avg loss:2.015385
#
# Start evaluation.
# Done. Time:1.0252964499999848
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.845217 [    0/ 3881]
# loss:1.647643 [ 3200/ 3881]
# Done. Time:3.748563102999981
# Start validation.
# Done. Time:0.2768274949999636
# Validation performance:
#  Avg loss:2.012809
#
# Start evaluation.
# Done. Time:0.8716614730000174
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:1.842074 [    0/ 3881]
# loss:1.640636 [ 3200/ 3881]
# Done. Time:3.0999357740000164
# Start validation.
# Done. Time:0.2621538330000135
# Validation performance:
#  Avg loss:2.010261
#
# Start evaluation.
# Done. Time:0.8511844579999774
# Test performance:
#  Accuracy:27.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:1.839206 [    0/ 3881]
# loss:1.633903 [ 3200/ 3881]
# Done. Time:3.513493538999967
# Start validation.
# Done. Time:0.43528449199999386
# Validation performance:
#  Avg loss:2.007711
#
# Start evaluation.
# Done. Time:1.05233382199998
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:1.836511 [    0/ 3881]
# loss:1.627395 [ 3200/ 3881]
# Done. Time:3.087063600000022
# Start validation.
# Done. Time:0.25653086400001257
# Validation performance:
#  Avg loss:2.004973
#
# Start evaluation.
# Done. Time:0.8174415700000282
# Test performance:
#  Accuracy:27.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:1.833890 [    0/ 3881]
# loss:1.621312 [ 3200/ 3881]
# Done. Time:3.051004316999979
# Start validation.
# Done. Time:0.25842604899997923
# Validation performance:
#  Avg loss:2.002748
#
# Start evaluation.
# Done. Time:0.8197870079999916
# Test performance:
#  Accuracy:27.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:1.831292 [    0/ 3881]
# loss:1.615206 [ 3200/ 3881]
# Done. Time:4.070695665999949
# Start validation.
# Done. Time:0.2682430650000356
# Validation performance:
#  Avg loss:2.000160
#
# Start evaluation.
# Done. Time:0.883819098999993
# Test performance:
#  Accuracy:28.5%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:1.828771 [    0/ 3881]
# loss:1.608634 [ 3200/ 3881]
# Done. Time:3.1206283440000107
# Start validation.
# Done. Time:0.2650819399999591
# Validation performance:
#  Avg loss:1.997603
#
# Start evaluation.
# Done. Time:0.8592555380000135
# Test performance:
#  Accuracy:28.5%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:1.827009 [    0/ 3881]
# loss:1.602613 [ 3200/ 3881]
# Done. Time:3.069810758000017
# Start validation.
# Done. Time:0.26858455499996126
# Validation performance:
#  Avg loss:1.995032
#
# Start evaluation.
# Done. Time:0.8945549750000055
# Test performance:
#  Accuracy:28.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.825072 [    0/ 3881]
# loss:1.596804 [ 3200/ 3881]
# Done. Time:4.108072861000039
# Start validation.
# Done. Time:0.2824176350000016
# Validation performance:
#  Avg loss:1.992529
#
# Start evaluation.
# Done. Time:0.8715189579999674
# Test performance:
#  Accuracy:28.5%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:1.823245 [    0/ 3881]
# loss:1.591279 [ 3200/ 3881]
# Done. Time:3.140283958999987
# Start validation.
# Done. Time:0.2826865289999887
# Validation performance:
#  Avg loss:1.990065
#
# Start evaluation.
# Done. Time:0.8524410269999976
# Test performance:
#  Accuracy:28.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:1.821375 [    0/ 3881]
# loss:1.585949 [ 3200/ 3881]
# Done. Time:3.2935449550000158
# Start validation.
# Done. Time:0.41768904099996007
# Validation performance:
#  Avg loss:1.987660
#
# Start evaluation.
# Done. Time:1.1587176959999965
# Test performance:
#  Accuracy:27.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:1.819751 [    0/ 3881]
# loss:1.580814 [ 3200/ 3881]
# Done. Time:3.5146902079999904
# Start validation.
# Done. Time:0.43124690299998747
# Validation performance:
#  Avg loss:1.985285
#
# Start evaluation.
# Done. Time:1.2769668299999921
# Test performance:
#  Accuracy:27.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:1.818054 [    0/ 3881]
# loss:1.575389 [ 3200/ 3881]
# Done. Time:3.115006970999957
# Start validation.
# Done. Time:0.27557992300000933
# Validation performance:
#  Avg loss:1.982963
#
# Start evaluation.
# Done. Time:0.8766784900000175
# Test performance:
#  Accuracy:27.5%
# Minimum validation loss:1.9829625061580114 at 50 epoch.
# Maximum accuracy:28.499999999999996 at 43 epoch.

# %% [markdown]
# ## Train with aligned landmarks (whole body).

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_align_w))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_align_whole,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_align_whole,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_align_whole,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_align_w = np.array(val_losses)
test_accs_align_w = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_align_w.min()} at {np.argmin(val_losses_align_w)+1} epoch.")
print(f"Maximum accuracy:{test_accs_align_w.max()} at {np.argmax(test_accs_align_w)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.371861 [    0/ 3881]
# loss:2.307200 [ 3200/ 3881]
# Done. Time:3.2022675769999864
# Start validation.
# Done. Time:0.283661861999974
# Validation performance:
#  Avg loss:2.297523
#
# Start evaluation.
# Done. Time:0.853408241000011
# Test performance:
#  Accuracy:10.0%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.198170 [    0/ 3881]
# loss:2.267911 [ 3200/ 3881]
# Done. Time:3.1367857710000067
# Start validation.
# Done. Time:0.2803026939999995
# Validation performance:
#  Avg loss:2.277375
#
# Start evaluation.
# Done. Time:1.0360213870000052
# Test performance:
#  Accuracy:10.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:2.151343 [    0/ 3881]
# loss:2.205324 [ 3200/ 3881]
# Done. Time:4.79352709799997
# Start validation.
# Done. Time:0.31002179400002206
# Validation performance:
#  Avg loss:2.248542
#
# Start evaluation.
# Done. Time:0.8649259320000056
# Test performance:
#  Accuracy:16.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:2.103931 [    0/ 3881]
# loss:2.122076 [ 3200/ 3881]
# Done. Time:3.1083474419999675
# Start validation.
# Done. Time:0.26439257400005545
# Validation performance:
#  Avg loss:2.210253
#
# Start evaluation.
# Done. Time:0.8737774479999985
# Test performance:
#  Accuracy:18.5%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:2.057547 [    0/ 3881]
# loss:2.042981 [ 3200/ 3881]
# Done. Time:3.9327222949999623
# Start validation.
# Done. Time:0.4560307220000368
# Validation performance:
#  Avg loss:2.169686
#
# Start evaluation.
# Done. Time:0.9306455600000163
# Test performance:
#  Accuracy:20.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:2.014559 [    0/ 3881]
# loss:1.967781 [ 3200/ 3881]
# Done. Time:3.1592307430000233
# Start validation.
# Done. Time:0.27277867700001934
# Validation performance:
#  Avg loss:2.133321
#
# Start evaluation.
# Done. Time:0.8684529500000053
# Test performance:
#  Accuracy:22.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.975523 [    0/ 3881]
# loss:1.910719 [ 3200/ 3881]
# Done. Time:3.1509702000000175
# Start validation.
# Done. Time:0.2806543419999912
# Validation performance:
#  Avg loss:2.104135
#
# Start evaluation.
# Done. Time:0.9169816200000014
# Test performance:
#  Accuracy:22.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.945577 [    0/ 3881]
# loss:1.862320 [ 3200/ 3881]
# Done. Time:4.158284166999977
# Start validation.
# Done. Time:0.30726099800000384
# Validation performance:
#  Avg loss:2.077194
#
# Start evaluation.
# Done. Time:0.8614657950000151
# Test performance:
#  Accuracy:25.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.910748 [    0/ 3881]
# loss:1.823899 [ 3200/ 3881]
# Done. Time:3.127991226000006
# Start validation.
# Done. Time:0.26365295499999775
# Validation performance:
#  Avg loss:2.055670
#
# Start evaluation.
# Done. Time:0.8412082699999814
# Test performance:
#  Accuracy:24.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.886208 [    0/ 3881]
# loss:1.789181 [ 3200/ 3881]
# Done. Time:3.122932784999989
# Start validation.
# Done. Time:0.4136530850000213
# Validation performance:
#  Avg loss:2.038054
#
# Start evaluation.
# Done. Time:1.1895726250000394
# Test performance:
#  Accuracy:24.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.863400 [    0/ 3881]
# loss:1.758456 [ 3200/ 3881]
# Done. Time:3.39056168999997
# Start validation.
# Done. Time:0.302592030000028
# Validation performance:
#  Avg loss:2.022518
#
# Start evaluation.
# Done. Time:0.8629212320000192
# Test performance:
#  Accuracy:27.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.845543 [    0/ 3881]
# loss:1.732430 [ 3200/ 3881]
# Done. Time:3.16831694199999
# Start validation.
# Done. Time:0.28016838700000335
# Validation performance:
#  Avg loss:2.008834
#
# Start evaluation.
# Done. Time:0.9007039210000016
# Test performance:
#  Accuracy:29.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.830382 [    0/ 3881]
# loss:1.708756 [ 3200/ 3881]
# Done. Time:4.1655655400000455
# Start validation.
# Done. Time:0.27759119099999907
# Validation performance:
#  Avg loss:1.996951
#
# Start evaluation.
# Done. Time:0.8687316470000042
# Test performance:
#  Accuracy:30.0%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.816015 [    0/ 3881]
# loss:1.686110 [ 3200/ 3881]
# Done. Time:4.261326525000015
# Start validation.
# Done. Time:0.28488671599995996
# Validation performance:
#  Avg loss:1.986424
#
# Start evaluation.
# Done. Time:0.9193574939999962
# Test performance:
#  Accuracy:30.0%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:1.803859 [    0/ 3881]
# loss:1.665718 [ 3200/ 3881]
# Done. Time:3.1990900399999873
# Start validation.
# Done. Time:0.339144110999996
# Validation performance:
#  Avg loss:1.976989
#
# Start evaluation.
# Done. Time:1.267904243000089
# Test performance:
#  Accuracy:27.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.793612 [    0/ 3881]
# loss:1.645966 [ 3200/ 3881]
# Done. Time:3.446844715999987
# Start validation.
# Done. Time:0.27890784200008056
# Validation performance:
#  Avg loss:1.969022
#
# Start evaluation.
# Done. Time:0.9165456489999997
# Test performance:
#  Accuracy:27.0%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.783028 [    0/ 3881]
# loss:1.627738 [ 3200/ 3881]
# Done. Time:3.11840987100004
# Start validation.
# Done. Time:0.2757408379999333
# Validation performance:
#  Avg loss:1.961665
#
# Start evaluation.
# Done. Time:0.8553440329999376
# Test performance:
#  Accuracy:27.0%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.774482 [    0/ 3881]
# loss:1.609546 [ 3200/ 3881]
# Done. Time:3.981592589999991
# Start validation.
# Done. Time:0.3585737280000103
# Validation performance:
#  Avg loss:1.955116
#
# Start evaluation.
# Done. Time:0.8595459040000151
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.767121 [    0/ 3881]
# loss:1.592698 [ 3200/ 3881]
# Done. Time:3.1251515310000286
# Start validation.
# Done. Time:0.30617333499992583
# Validation performance:
#  Avg loss:1.950131
#
# Start evaluation.
# Done. Time:0.8822095670000181
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.760030 [    0/ 3881]
# loss:1.577180 [ 3200/ 3881]
# Done. Time:3.1707019440000295
# Start validation.
# Done. Time:0.27469989999997324
# Validation performance:
#  Avg loss:1.943569
#
# Start evaluation.
# Done. Time:0.8721137239999734
# Test performance:
#  Accuracy:27.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.752017 [    0/ 3881]
# loss:1.561304 [ 3200/ 3881]
# Done. Time:4.137949109000033
# Start validation.
# Done. Time:0.2945943240000588
# Validation performance:
#  Avg loss:1.938457
#
# Start evaluation.
# Done. Time:0.8860655940000015
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.745495 [    0/ 3881]
# loss:1.546866 [ 3200/ 3881]
# Done. Time:3.1542340439999634
# Start validation.
# Done. Time:0.27799505699999827
# Validation performance:
#  Avg loss:1.933583
#
# Start evaluation.
# Done. Time:1.314076671999942
# Test performance:
#  Accuracy:28.0%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.739217 [    0/ 3881]
# loss:1.534040 [ 3200/ 3881]
# Done. Time:5.601418661000025
# Start validation.
# Done. Time:0.281020452000007
# Validation performance:
#  Avg loss:1.928378
#
# Start evaluation.
# Done. Time:0.9035816100000602
# Test performance:
#  Accuracy:28.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.734179 [    0/ 3881]
# loss:1.523947 [ 3200/ 3881]
# Done. Time:3.200355054999932
# Start validation.
# Done. Time:0.2779242440000189
# Validation performance:
#  Avg loss:1.924840
#
# Start evaluation.
# Done. Time:0.9017066499999373
# Test performance:
#  Accuracy:27.5%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.729377 [    0/ 3881]
# loss:1.513624 [ 3200/ 3881]
# Done. Time:3.205215235999958
# Start validation.
# Done. Time:0.2866208209999286
# Validation performance:
#  Avg loss:1.921263
#
# Start evaluation.
# Done. Time:1.0466880629999196
# Test performance:
#  Accuracy:27.0%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.724082 [    0/ 3881]
# loss:1.502366 [ 3200/ 3881]
# Done. Time:3.867652524999926
# Start validation.
# Done. Time:0.31041995099997166
# Validation performance:
#  Avg loss:1.917748
#
# Start evaluation.
# Done. Time:0.8840386050000006
# Test performance:
#  Accuracy:28.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.717816 [    0/ 3881]
# loss:1.492055 [ 3200/ 3881]
# Done. Time:3.210752126999978
# Start validation.
# Done. Time:0.2951387909999994
# Validation performance:
#  Avg loss:1.915924
#
# Start evaluation.
# Done. Time:0.9092737580000403
# Test performance:
#  Accuracy:30.0%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.723707 [    0/ 3881]
# loss:1.483097 [ 3200/ 3881]
# Done. Time:3.617497536999963
# Start validation.
# Done. Time:0.4699948280000399
# Validation performance:
#  Avg loss:1.911147
#
# Start evaluation.
# Done. Time:1.0252795019999894
# Test performance:
#  Accuracy:29.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:1.708700 [    0/ 3881]
# loss:1.472910 [ 3200/ 3881]
# Done. Time:3.2113692519999404
# Start validation.
# Done. Time:0.2793856319999577
# Validation performance:
#  Avg loss:1.908475
#
# Start evaluation.
# Done. Time:0.8631992140000193
# Test performance:
#  Accuracy:29.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.703171 [    0/ 3881]
# loss:1.464834 [ 3200/ 3881]
# Done. Time:3.1513105789999827
# Start validation.
# Done. Time:0.28186861400001817
# Validation performance:
#  Avg loss:1.904681
#
# Start evaluation.
# Done. Time:0.8966894349999848
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:1.699416 [    0/ 3881]
# loss:1.454459 [ 3200/ 3881]
# Done. Time:4.458464111000012
# Start validation.
# Done. Time:0.8868266150000181
# Validation performance:
#  Avg loss:1.901810
#
# Start evaluation.
# Done. Time:1.4617840979999528
# Test performance:
#  Accuracy:30.5%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.694907 [    0/ 3881]
# loss:1.444923 [ 3200/ 3881]
# Done. Time:6.7812121749999505
# Start validation.
# Done. Time:0.5070757189999995
# Validation performance:
#  Avg loss:1.898481
#
# Start evaluation.
# Done. Time:1.3649840749999385
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:1.692460 [    0/ 3881]
# loss:1.436783 [ 3200/ 3881]
# Done. Time:3.476372000000083
# Start validation.
# Done. Time:0.2868185759999733
# Validation performance:
#  Avg loss:1.895525
#
# Start evaluation.
# Done. Time:0.8947032450000734
# Test performance:
#  Accuracy:30.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:1.687027 [    0/ 3881]
# loss:1.428539 [ 3200/ 3881]
# Done. Time:3.2762430080000513
# Start validation.
# Done. Time:0.2938517290000391
# Validation performance:
#  Avg loss:1.892324
#
# Start evaluation.
# Done. Time:0.903975846000094
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.682783 [    0/ 3881]
# loss:1.420675 [ 3200/ 3881]
# Done. Time:4.266587917000038
# Start validation.
# Done. Time:0.29894911099995625
# Validation performance:
#  Avg loss:1.889673
#
# Start evaluation.
# Done. Time:0.9009776130000091
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.678797 [    0/ 3881]
# loss:1.413326 [ 3200/ 3881]
# Done. Time:3.28079371299998
# Start validation.
# Done. Time:0.30678055099997437
# Validation performance:
#  Avg loss:1.886885
#
# Start evaluation.
# Done. Time:0.9079930139999988
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.674405 [    0/ 3881]
# loss:1.405572 [ 3200/ 3881]
# Done. Time:3.3279462190000686
# Start validation.
# Done. Time:0.4257188660000111
# Validation performance:
#  Avg loss:1.883780
#
# Start evaluation.
# Done. Time:1.2888895869999715
# Test performance:
#  Accuracy:31.5%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.670768 [    0/ 3881]
# loss:1.398489 [ 3200/ 3881]
# Done. Time:3.47613757900001
# Start validation.
# Done. Time:0.305035265000015
# Validation performance:
#  Avg loss:1.881076
#
# Start evaluation.
# Done. Time:0.9285101719999602
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:1.666817 [    0/ 3881]
# loss:1.392314 [ 3200/ 3881]
# Done. Time:3.3652238399999987
# Start validation.
# Done. Time:0.3782664330000216
# Validation performance:
#  Avg loss:1.878519
#
# Start evaluation.
# Done. Time:1.1035578539999733
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:1.661931 [    0/ 3881]
# loss:1.385440 [ 3200/ 3881]
# Done. Time:6.972734555999978
# Start validation.
# Done. Time:0.703405001999954
# Validation performance:
#  Avg loss:1.875716
#
# Start evaluation.
# Done. Time:1.2450865139999223
# Test performance:
#  Accuracy:31.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:1.657984 [    0/ 3881]
# loss:1.379205 [ 3200/ 3881]
# Done. Time:3.50640832199997
# Start validation.
# Done. Time:0.30021835900004135
# Validation performance:
#  Avg loss:1.873086
#
# Start evaluation.
# Done. Time:0.9220018380000283
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:1.654022 [    0/ 3881]
# loss:1.373329 [ 3200/ 3881]
# Done. Time:4.707211751000045
# Start validation.
# Done. Time:0.4748035359999676
# Validation performance:
#  Avg loss:1.871078
#
# Start evaluation.
# Done. Time:1.3254716679999774
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:1.649680 [    0/ 3881]
# loss:1.367537 [ 3200/ 3881]
# Done. Time:4.930796724000061
# Start validation.
# Done. Time:0.4702039159999458
# Validation performance:
#  Avg loss:1.869643
#
# Start evaluation.
# Done. Time:1.1559166090000872
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:1.644622 [    0/ 3881]
# loss:1.361704 [ 3200/ 3881]
# Done. Time:4.609781855000051
# Start validation.
# Done. Time:0.3136548400000265
# Validation performance:
#  Avg loss:1.868012
#
# Start evaluation.
# Done. Time:0.9169648319999624
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:1.640432 [    0/ 3881]
# loss:1.356604 [ 3200/ 3881]
# Done. Time:3.329134331000091
# Start validation.
# Done. Time:0.30706106800005273
# Validation performance:
#  Avg loss:1.866637
#
# Start evaluation.
# Done. Time:0.9206568790000347
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.636036 [    0/ 3881]
# loss:1.352001 [ 3200/ 3881]
# Done. Time:4.5383008500000415
# Start validation.
# Done. Time:0.5096658979999802
# Validation performance:
#  Avg loss:1.864624
#
# Start evaluation.
# Done. Time:1.1464393229999814
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:1.630530 [    0/ 3881]
# loss:1.346304 [ 3200/ 3881]
# Done. Time:3.6532455330000175
# Start validation.
# Done. Time:0.31081985299999815
# Validation performance:
#  Avg loss:1.862968
#
# Start evaluation.
# Done. Time:0.9373274560000482
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:1.624972 [    0/ 3881]
# loss:1.340084 [ 3200/ 3881]
# Done. Time:3.4730464770000253
# Start validation.
# Done. Time:0.32011805399997684
# Validation performance:
#  Avg loss:1.860921
#
# Start evaluation.
# Done. Time:1.055295233000038
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:1.619132 [    0/ 3881]
# loss:1.334413 [ 3200/ 3881]
# Done. Time:4.096769451
# Start validation.
# Done. Time:0.3101944979999871
# Validation performance:
#  Avg loss:1.859261
#
# Start evaluation.
# Done. Time:0.9058422829999699
# Test performance:
#  Accuracy:31.5%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:1.613272 [    0/ 3881]
# loss:1.329013 [ 3200/ 3881]
# Done. Time:3.331735579999986
# Start validation.
# Done. Time:0.38498852899999747
# Validation performance:
#  Avg loss:1.857718
#
# Start evaluation.
# Done. Time:0.9617480959999511
# Test performance:
#  Accuracy:31.5%
# Minimum validation loss:1.8577179057257516 at 50 epoch.
# Maximum accuracy:32.0 at 41 epoch.

# %% [markdown]
# ## Train with aligned landmarks (parts-based)

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_align_w))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_align_parts,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_align_parts,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_align_parts,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_align_p = np.array(val_losses)
test_accs_align_p = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_align_p.min()} at {np.argmin(val_losses_align_p)+1} epoch.")
print(f"Maximum accuracy:{test_accs_align_p.max()} at {np.argmax(test_accs_align_p)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.327745 [    0/ 3881]
# loss:2.237723 [ 3200/ 3881]
# Done. Time:4.243088309999962
# Start validation.
# Done. Time:0.32538927799998874
# Validation performance:
#  Avg loss:2.271088
#
# Start evaluation.
# Done. Time:0.9605911950000063
# Test performance:
#  Accuracy:18.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.244117 [    0/ 3881]
# loss:2.143863 [ 3200/ 3881]
# Done. Time:4.092963759999975
# Start validation.
# Done. Time:0.5041704220000156
# Validation performance:
#  Avg loss:2.229730
#
# Start evaluation.
# Done. Time:1.1798907239999608
# Test performance:
#  Accuracy:27.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:2.188554 [    0/ 3881]
# loss:2.053945 [ 3200/ 3881]
# Done. Time:3.399013550999939
# Start validation.
# Done. Time:0.3288118460000078
# Validation performance:
#  Avg loss:2.186623
#
# Start evaluation.
# Done. Time:0.9176794640000026
# Test performance:
#  Accuracy:28.5%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:2.150337 [    0/ 3881]
# loss:1.972817 [ 3200/ 3881]
# Done. Time:3.574983338000038
# Start validation.
# Done. Time:0.3463999620000777
# Validation performance:
#  Avg loss:2.147064
#
# Start evaluation.
# Done. Time:1.0888153260000308
# Test performance:
#  Accuracy:28.5%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:2.127714 [    0/ 3881]
# loss:1.904065 [ 3200/ 3881]
# Done. Time:4.978905038000107
# Start validation.
# Done. Time:0.6948898470000131
# Validation performance:
#  Avg loss:2.115025
#
# Start evaluation.
# Done. Time:0.9584720259999813
# Test performance:
#  Accuracy:29.0%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:2.113068 [    0/ 3881]
# loss:1.844568 [ 3200/ 3881]
# Done. Time:4.000693611999964
# Start validation.
# Done. Time:0.3183023959999218
# Validation performance:
#  Avg loss:2.090339
#
# Start evaluation.
# Done. Time:0.8811411450000151
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:2.102090 [    0/ 3881]
# loss:1.793050 [ 3200/ 3881]
# Done. Time:4.462067767000008
# Start validation.
# Done. Time:0.31013818700000684
# Validation performance:
#  Avg loss:2.065757
#
# Start evaluation.
# Done. Time:0.9118311149999272
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:2.091615 [    0/ 3881]
# loss:1.753653 [ 3200/ 3881]
# Done. Time:3.6450917290000007
# Start validation.
# Done. Time:0.3199008489999642
# Validation performance:
#  Avg loss:2.043022
#
# Start evaluation.
# Done. Time:0.87282011100001
# Test performance:
#  Accuracy:33.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:2.080450 [    0/ 3881]
# loss:1.721911 [ 3200/ 3881]
# Done. Time:3.3997456869999496
# Start validation.
# Done. Time:0.5165611720000243
# Validation performance:
#  Avg loss:2.023896
#
# Start evaluation.
# Done. Time:1.4106198890000314
# Test performance:
#  Accuracy:35.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:2.066388 [    0/ 3881]
# loss:1.687590 [ 3200/ 3881]
# Done. Time:3.705823584999962
# Start validation.
# Done. Time:0.3285706320000372
# Validation performance:
#  Avg loss:2.005198
#
# Start evaluation.
# Done. Time:0.9582812849999982
# Test performance:
#  Accuracy:35.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:2.051307 [    0/ 3881]
# loss:1.654076 [ 3200/ 3881]
# Done. Time:3.5272060639999836
# Start validation.
# Done. Time:0.3155136399999492
# Validation performance:
#  Avg loss:1.988667
#
# Start evaluation.
# Done. Time:0.9475811659999636
# Test performance:
#  Accuracy:36.0%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:2.039528 [    0/ 3881]
# loss:1.631445 [ 3200/ 3881]
# Done. Time:4.271884063999892
# Start validation.
# Done. Time:0.32405003400003807
# Validation performance:
#  Avg loss:1.972000
#
# Start evaluation.
# Done. Time:0.9835221929999989
# Test performance:
#  Accuracy:36.5%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:2.019565 [    0/ 3881]
# loss:1.608034 [ 3200/ 3881]
# Done. Time:3.49796654499994
# Start validation.
# Done. Time:0.3157513390000304
# Validation performance:
#  Avg loss:1.955436
#
# Start evaluation.
# Done. Time:0.9471663660000331
# Test performance:
#  Accuracy:37.0%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:2.000012 [    0/ 3881]
# loss:1.584864 [ 3200/ 3881]
# Done. Time:3.9980615069999885
# Start validation.
# Done. Time:0.5228478159999668
# Validation performance:
#  Avg loss:1.940723
#
# Start evaluation.
# Done. Time:1.060453831000018
# Test performance:
#  Accuracy:39.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:1.975312 [    0/ 3881]
# loss:1.561685 [ 3200/ 3881]
# Done. Time:3.35787918099993
# Start validation.
# Done. Time:0.30852939199996854
# Validation performance:
#  Avg loss:1.924757
#
# Start evaluation.
# Done. Time:0.9209923100000879
# Test performance:
#  Accuracy:42.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.958547 [    0/ 3881]
# loss:1.540837 [ 3200/ 3881]
# Done. Time:3.379285267
# Start validation.
# Done. Time:0.32087931299997763
# Validation performance:
#  Avg loss:1.911129
#
# Start evaluation.
# Done. Time:0.9338876130000244
# Test performance:
#  Accuracy:43.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.935409 [    0/ 3881]
# loss:1.520452 [ 3200/ 3881]
# Done. Time:4.300682018999964
# Start validation.
# Done. Time:0.32474191900007554
# Validation performance:
#  Avg loss:1.897557
#
# Start evaluation.
# Done. Time:0.9174215589999903
# Test performance:
#  Accuracy:46.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.912824 [    0/ 3881]
# loss:1.500858 [ 3200/ 3881]
# Done. Time:3.890256253999951
# Start validation.
# Done. Time:0.3706571160000749
# Validation performance:
#  Avg loss:1.885027
#
# Start evaluation.
# Done. Time:0.9365389499999992
# Test performance:
#  Accuracy:48.0%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.890687 [    0/ 3881]
# loss:1.481914 [ 3200/ 3881]
# Done. Time:4.358368861000031
# Start validation.
# Done. Time:0.35469987700003003
# Validation performance:
#  Avg loss:1.873316
#
# Start evaluation.
# Done. Time:1.0016085859999748
# Test performance:
#  Accuracy:48.0%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.868351 [    0/ 3881]
# loss:1.463782 [ 3200/ 3881]
# Done. Time:3.6235382480000453
# Start validation.
# Done. Time:0.3094062390000545
# Validation performance:
#  Avg loss:1.862106
#
# Start evaluation.
# Done. Time:0.9095753949999335
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.846954 [    0/ 3881]
# loss:1.446079 [ 3200/ 3881]
# Done. Time:3.5449066190000167
# Start validation.
# Done. Time:0.3074797579999995
# Validation performance:
#  Avg loss:1.851584
#
# Start evaluation.
# Done. Time:1.236083084000029
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.826058 [    0/ 3881]
# loss:1.429384 [ 3200/ 3881]
# Done. Time:3.7883011630000283
# Start validation.
# Done. Time:0.3386234179999974
# Validation performance:
#  Avg loss:1.842742
#
# Start evaluation.
# Done. Time:0.8937856149999561
# Test performance:
#  Accuracy:48.0%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.804940 [    0/ 3881]
# loss:1.413319 [ 3200/ 3881]
# Done. Time:3.571267116000058
# Start validation.
# Done. Time:0.3624370720000343
# Validation performance:
#  Avg loss:1.833552
#
# Start evaluation.
# Done. Time:0.9008356620000768
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.785655 [    0/ 3881]
# loss:1.398105 [ 3200/ 3881]
# Done. Time:4.313878747999979
# Start validation.
# Done. Time:0.3073036429999547
# Validation performance:
#  Avg loss:1.825449
#
# Start evaluation.
# Done. Time:0.8933475840000256
# Test performance:
#  Accuracy:49.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.766086 [    0/ 3881]
# loss:1.382961 [ 3200/ 3881]
# Done. Time:3.3202608609999515
# Start validation.
# Done. Time:0.3177960499999699
# Validation performance:
#  Avg loss:1.818183
#
# Start evaluation.
# Done. Time:0.9082556880000539
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.747270 [    0/ 3881]
# loss:1.368771 [ 3200/ 3881]
# Done. Time:4.00687515300001
# Start validation.
# Done. Time:0.5243135230000462
# Validation performance:
#  Avg loss:1.810254
#
# Start evaluation.
# Done. Time:1.3803065419999712
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.729013 [    0/ 3881]
# loss:1.355399 [ 3200/ 3881]
# Done. Time:3.4492785610000283
# Start validation.
# Done. Time:0.33602654200001325
# Validation performance:
#  Avg loss:1.802452
#
# Start evaluation.
# Done. Time:1.0172165779999887
# Test performance:
#  Accuracy:49.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.712282 [    0/ 3881]
# loss:1.342713 [ 3200/ 3881]
# Done. Time:4.88343790600004
# Start validation.
# Done. Time:0.37251910800000587
# Validation performance:
#  Avg loss:1.795016
#
# Start evaluation.
# Done. Time:1.2614535699999578
# Test performance:
#  Accuracy:49.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:1.693929 [    0/ 3881]
# loss:1.329623 [ 3200/ 3881]
# Done. Time:3.616852279999989
# Start validation.
# Done. Time:0.2971548460000122
# Validation performance:
#  Avg loss:1.787641
#
# Start evaluation.
# Done. Time:0.8790664890000244
# Test performance:
#  Accuracy:49.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.676616 [    0/ 3881]
# loss:1.317025 [ 3200/ 3881]
# Done. Time:3.2862976760000038
# Start validation.
# Done. Time:0.3132853409999825
# Validation performance:
#  Avg loss:1.780533
#
# Start evaluation.
# Done. Time:0.8957569909999847
# Test performance:
#  Accuracy:49.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:1.660537 [    0/ 3881]
# loss:1.304931 [ 3200/ 3881]
# Done. Time:4.484234412999967
# Start validation.
# Done. Time:0.32378836299994873
# Validation performance:
#  Avg loss:1.773147
#
# Start evaluation.
# Done. Time:0.9135644709999724
# Test performance:
#  Accuracy:49.5%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.643303 [    0/ 3881]
# loss:1.293364 [ 3200/ 3881]
# Done. Time:3.3727647219999426
# Start validation.
# Done. Time:0.3048071210000671
# Validation performance:
#  Avg loss:1.765870
#
# Start evaluation.
# Done. Time:0.9016679119999935
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:1.627596 [    0/ 3881]
# loss:1.282346 [ 3200/ 3881]
# Done. Time:3.4547294149999743
# Start validation.
# Done. Time:0.34455888600007256
# Validation performance:
#  Avg loss:1.758867
#
# Start evaluation.
# Done. Time:1.3526169109999273
# Test performance:
#  Accuracy:50.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:1.612401 [    0/ 3881]
# loss:1.271835 [ 3200/ 3881]
# Done. Time:5.027985887999989
# Start validation.
# Done. Time:0.3361504629999672
# Validation performance:
#  Avg loss:1.751527
#
# Start evaluation.
# Done. Time:0.9214349800000718
# Test performance:
#  Accuracy:50.5%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.596599 [    0/ 3881]
# loss:1.261724 [ 3200/ 3881]
# Done. Time:3.4032651699999406
# Start validation.
# Done. Time:0.36532388299997365
# Validation performance:
#  Avg loss:1.744060
#
# Start evaluation.
# Done. Time:0.9859859350000306
# Test performance:
#  Accuracy:50.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.581272 [    0/ 3881]
# loss:1.252344 [ 3200/ 3881]
# Done. Time:4.941095952000069
# Start validation.
# Done. Time:0.3336010460000125
# Validation performance:
#  Avg loss:1.736760
#
# Start evaluation.
# Done. Time:1.1079508020000048
# Test performance:
#  Accuracy:51.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.566965 [    0/ 3881]
# loss:1.243319 [ 3200/ 3881]
# Done. Time:4.070631309999953
# Start validation.
# Done. Time:0.2904075430000148
# Validation performance:
#  Avg loss:1.730339
#
# Start evaluation.
# Done. Time:0.8972273050000013
# Test performance:
#  Accuracy:51.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.552293 [    0/ 3881]
# loss:1.234630 [ 3200/ 3881]
# Done. Time:4.6941732059999595
# Start validation.
# Done. Time:0.48793696400002773
# Validation performance:
#  Avg loss:1.723524
#
# Start evaluation.
# Done. Time:0.9689430899999252
# Test performance:
#  Accuracy:51.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:1.537907 [    0/ 3881]
# loss:1.226377 [ 3200/ 3881]
# Done. Time:3.531098350000093
# Start validation.
# Done. Time:0.3021691000000146
# Validation performance:
#  Avg loss:1.717301
#
# Start evaluation.
# Done. Time:0.9281518020000021
# Test performance:
#  Accuracy:51.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:1.525060 [    0/ 3881]
# loss:1.218320 [ 3200/ 3881]
# Done. Time:3.446582836999937
# Start validation.
# Done. Time:0.32590765899999496
# Validation performance:
#  Avg loss:1.711142
#
# Start evaluation.
# Done. Time:1.1046187279999913
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:1.511790 [    0/ 3881]
# loss:1.210293 [ 3200/ 3881]
# Done. Time:4.049433284999964
# Start validation.
# Done. Time:0.3086799320000182
# Validation performance:
#  Avg loss:1.704830
#
# Start evaluation.
# Done. Time:0.9310279569999693
# Test performance:
#  Accuracy:52.5%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:1.498459 [    0/ 3881]
# loss:1.202528 [ 3200/ 3881]
# Done. Time:3.3522149460000037
# Start validation.
# Done. Time:0.34250718500004496
# Validation performance:
#  Avg loss:1.698866
#
# Start evaluation.
# Done. Time:0.9437500159999672
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:1.485692 [    0/ 3881]
# loss:1.194907 [ 3200/ 3881]
# Done. Time:4.646806804999983
# Start validation.
# Done. Time:0.3171265290000065
# Validation performance:
#  Avg loss:1.693056
#
# Start evaluation.
# Done. Time:0.9448259920000055
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:1.473238 [    0/ 3881]
# loss:1.187397 [ 3200/ 3881]
# Done. Time:3.321113622999974
# Start validation.
# Done. Time:0.31244728300009683
# Validation performance:
#  Avg loss:1.687161
#
# Start evaluation.
# Done. Time:0.9093520730000364
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:1.461549 [    0/ 3881]
# loss:1.179994 [ 3200/ 3881]
# Done. Time:3.312430868999968
# Start validation.
# Done. Time:0.31134295999993356
# Validation performance:
#  Avg loss:1.681459
#
# Start evaluation.
# Done. Time:1.0604669010000407
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.449347 [    0/ 3881]
# loss:1.172712 [ 3200/ 3881]
# Done. Time:4.024455700999965
# Start validation.
# Done. Time:0.32079463799993846
# Validation performance:
#  Avg loss:1.675675
#
# Start evaluation.
# Done. Time:0.8970621870000741
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:1.438111 [    0/ 3881]
# loss:1.165655 [ 3200/ 3881]
# Done. Time:3.547883842000033
# Start validation.
# Done. Time:0.3179992590000893
# Validation performance:
#  Avg loss:1.670360
#
# Start evaluation.
# Done. Time:0.9222971719999578
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:1.426887 [    0/ 3881]
# loss:1.158597 [ 3200/ 3881]
# Done. Time:4.550922764999996
# Start validation.
# Done. Time:0.3099961659999053
# Validation performance:
#  Avg loss:1.664850
#
# Start evaluation.
# Done. Time:0.9872262919999457
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:1.415381 [    0/ 3881]
# loss:1.151727 [ 3200/ 3881]
# Done. Time:3.4907897430000503
# Start validation.
# Done. Time:0.3299753569999666
# Validation performance:
#  Avg loss:1.659690
#
# Start evaluation.
# Done. Time:0.9341997980000087
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:1.404743 [    0/ 3881]
# loss:1.144852 [ 3200/ 3881]
# Done. Time:3.5437450199999603
# Start validation.
# Done. Time:0.395436023000002
# Validation performance:
#  Avg loss:1.654152
#
# Start evaluation.
# Done. Time:1.3967280499999788
# Test performance:
#  Accuracy:59.5%
# Minimum validation loss:1.6541523081915719 at 50 epoch.
# Maximum accuracy:59.5 at 50 epoch.

# %% [markdown]
# ## Train with aligned and scaled landmarks (whole body)

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_align_scale_w))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_align_scale_whole,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_align_scale_whole,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_align_scale_whole,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_align_scale_w = np.array(val_losses)
test_accs_align_scale_w = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_align_scale_w.min()} at {np.argmin(val_losses_align_scale_w)+1} epoch.")
print(f"Maximum accuracy:{test_accs_align_scale_w.max()} at {np.argmax(test_accs_align_scale_w)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.192952 [    0/ 3881]
# loss:2.253134 [ 3200/ 3881]
# Done. Time:3.3228901820000374
# Start validation.
# Done. Time:0.3068442869999899
# Validation performance:
#  Avg loss:2.287181
#
# Start evaluation.
# Done. Time:0.9119138050000402
# Test performance:
#  Accuracy:11.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.159160 [    0/ 3881]
# loss:2.164239 [ 3200/ 3881]
# Done. Time:4.23074641300002
# Start validation.
# Done. Time:0.30624915199996394
# Validation performance:
#  Avg loss:2.213255
#
# Start evaluation.
# Done. Time:0.9203525979999085
# Test performance:
#  Accuracy:22.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:2.078036 [    0/ 3881]
# loss:2.007634 [ 3200/ 3881]
# Done. Time:3.421906075000038
# Start validation.
# Done. Time:0.296310806000065
# Validation performance:
#  Avg loss:2.166301
#
# Start evaluation.
# Done. Time:0.9256208670000206
# Test performance:
#  Accuracy:22.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:2.018026 [    0/ 3881]
# loss:1.913904 [ 3200/ 3881]
# Done. Time:3.46807031000003
# Start validation.
# Done. Time:0.4556997270000238
# Validation performance:
#  Avg loss:2.145437
#
# Start evaluation.
# Done. Time:1.2603522599999906
# Test performance:
#  Accuracy:21.5%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.940759 [    0/ 3881]
# loss:1.850167 [ 3200/ 3881]
# Done. Time:3.727306956999996
# Start validation.
# Done. Time:0.3249820070000169
# Validation performance:
#  Avg loss:2.098860
#
# Start evaluation.
# Done. Time:0.9672671600000058
# Test performance:
#  Accuracy:21.0%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.930775 [    0/ 3881]
# loss:1.797612 [ 3200/ 3881]
# Done. Time:3.386825440999928
# Start validation.
# Done. Time:0.29324773900009404
# Validation performance:
#  Avg loss:2.071810
#
# Start evaluation.
# Done. Time:0.921281932999932
# Test performance:
#  Accuracy:22.5%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.897348 [    0/ 3881]
# loss:1.757989 [ 3200/ 3881]
# Done. Time:4.750204755000027
# Start validation.
# Done. Time:0.28877362000002904
# Validation performance:
#  Avg loss:2.061146
#
# Start evaluation.
# Done. Time:0.9501969109999209
# Test performance:
#  Accuracy:21.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.838989 [    0/ 3881]
# loss:1.726691 [ 3200/ 3881]
# Done. Time:3.294598621999967
# Start validation.
# Done. Time:0.3149884250000241
# Validation performance:
#  Avg loss:2.035961
#
# Start evaluation.
# Done. Time:0.927360507000003
# Test performance:
#  Accuracy:24.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.847003 [    0/ 3881]
# loss:1.700957 [ 3200/ 3881]
# Done. Time:3.326017567000008
# Start validation.
# Done. Time:0.4657132959999899
# Validation performance:
#  Avg loss:2.022512
#
# Start evaluation.
# Done. Time:1.325881111000058
# Test performance:
#  Accuracy:24.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.825779 [    0/ 3881]
# loss:1.676451 [ 3200/ 3881]
# Done. Time:3.4506260480000037
# Start validation.
# Done. Time:0.2961228400001801
# Validation performance:
#  Avg loss:2.008891
#
# Start evaluation.
# Done. Time:0.9259007040000142
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.809690 [    0/ 3881]
# loss:1.657899 [ 3200/ 3881]
# Done. Time:3.6712872410000728
# Start validation.
# Done. Time:0.345306237999921
# Validation performance:
#  Avg loss:1.997102
#
# Start evaluation.
# Done. Time:0.993096334000029
# Test performance:
#  Accuracy:26.0%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.797412 [    0/ 3881]
# loss:1.641419 [ 3200/ 3881]
# Done. Time:4.861817815999984
# Start validation.
# Done. Time:0.31847838499993486
# Validation performance:
#  Avg loss:1.988569
#
# Start evaluation.
# Done. Time:0.979703895000057
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.786687 [    0/ 3881]
# loss:1.626464 [ 3200/ 3881]
# Done. Time:3.5752685519998977
# Start validation.
# Done. Time:0.29009048700004314
# Validation performance:
#  Avg loss:1.979660
#
# Start evaluation.
# Done. Time:0.9137790130000667
# Test performance:
#  Accuracy:26.0%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.777880 [    0/ 3881]
# loss:1.611691 [ 3200/ 3881]
# Done. Time:3.5123953639999854
# Start validation.
# Done. Time:0.5040358619999097
# Validation performance:
#  Avg loss:1.971289
#
# Start evaluation.
# Done. Time:1.4651609239999743
# Test performance:
#  Accuracy:28.0%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:1.769923 [    0/ 3881]
# loss:1.602247 [ 3200/ 3881]
# Done. Time:4.820684788000108
# Start validation.
# Done. Time:0.3179790060000869
# Validation performance:
#  Avg loss:1.956240
#
# Start evaluation.
# Done. Time:0.9908723240000654
# Test performance:
#  Accuracy:34.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.767649 [    0/ 3881]
# loss:1.587634 [ 3200/ 3881]
# Done. Time:3.6092590770001607
# Start validation.
# Done. Time:0.33855802099992616
# Validation performance:
#  Avg loss:1.959379
#
# Start evaluation.
# Done. Time:1.2948234429998138
# Test performance:
#  Accuracy:30.0%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.755009 [    0/ 3881]
# loss:1.570909 [ 3200/ 3881]
# Done. Time:3.6440151660001447
# Start validation.
# Done. Time:0.29168796699991617
# Validation performance:
#  Avg loss:1.948748
#
# Start evaluation.
# Done. Time:0.9305866310000965
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.751259 [    0/ 3881]
# loss:1.559456 [ 3200/ 3881]
# Done. Time:3.305221566
# Start validation.
# Done. Time:0.297976411000036
# Validation performance:
#  Avg loss:1.942770
#
# Start evaluation.
# Done. Time:0.904125281000006
# Test performance:
#  Accuracy:32.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.744713 [    0/ 3881]
# loss:1.546727 [ 3200/ 3881]
# Done. Time:4.281817622000062
# Start validation.
# Done. Time:0.3065756799999235
# Validation performance:
#  Avg loss:1.936205
#
# Start evaluation.
# Done. Time:0.9258036629998969
# Test performance:
#  Accuracy:34.0%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.739029 [    0/ 3881]
# loss:1.536303 [ 3200/ 3881]
# Done. Time:3.295494324999936
# Start validation.
# Done. Time:0.2967699249998077
# Validation performance:
#  Avg loss:1.930459
#
# Start evaluation.
# Done. Time:0.9448856789999809
# Test performance:
#  Accuracy:35.5%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.733028 [    0/ 3881]
# loss:1.522042 [ 3200/ 3881]
# Done. Time:3.3623641310000494
# Start validation.
# Done. Time:0.3455787140001121
# Validation performance:
#  Avg loss:1.924842
#
# Start evaluation.
# Done. Time:1.2610942510000314
# Test performance:
#  Accuracy:36.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.727030 [    0/ 3881]
# loss:1.509300 [ 3200/ 3881]
# Done. Time:3.8005302070000653
# Start validation.
# Done. Time:0.3227748799999972
# Validation performance:
#  Avg loss:1.919483
#
# Start evaluation.
# Done. Time:0.9421103130000574
# Test performance:
#  Accuracy:35.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.721984 [    0/ 3881]
# loss:1.485488 [ 3200/ 3881]
# Done. Time:3.3002756930000032
# Start validation.
# Done. Time:0.321592776999978
# Validation performance:
#  Avg loss:1.917102
#
# Start evaluation.
# Done. Time:0.9222285889998147
# Test performance:
#  Accuracy:34.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.716735 [    0/ 3881]
# loss:1.487994 [ 3200/ 3881]
# Done. Time:4.319125197999938
# Start validation.
# Done. Time:0.3152491349999309
# Validation performance:
#  Avg loss:1.911259
#
# Start evaluation.
# Done. Time:0.957927558999927
# Test performance:
#  Accuracy:35.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.709890 [    0/ 3881]
# loss:1.474887 [ 3200/ 3881]
# Done. Time:3.771798421000085
# Start validation.
# Done. Time:0.4988445410001532
# Validation performance:
#  Avg loss:1.907472
#
# Start evaluation.
# Done. Time:1.19695275700019
# Test performance:
#  Accuracy:35.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.704805 [    0/ 3881]
# loss:1.463741 [ 3200/ 3881]
# Done. Time:3.7718040400000064
# Start validation.
# Done. Time:0.4776473450001504
# Validation performance:
#  Avg loss:1.904335
#
# Start evaluation.
# Done. Time:1.4569360899999992
# Test performance:
#  Accuracy:36.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.698667 [    0/ 3881]
# loss:1.452293 [ 3200/ 3881]
# Done. Time:4.400661275000175
# Start validation.
# Done. Time:0.2958725839998806
# Validation performance:
#  Avg loss:1.900556
#
# Start evaluation.
# Done. Time:0.893566870000086
# Test performance:
#  Accuracy:36.0%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.693066 [    0/ 3881]
# loss:1.441814 [ 3200/ 3881]
# Done. Time:3.292580150999811
# Start validation.
# Done. Time:0.2919799220001096
# Validation performance:
#  Avg loss:1.897015
#
# Start evaluation.
# Done. Time:0.9213645249999445
# Test performance:
#  Accuracy:37.0%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:1.686876 [    0/ 3881]
# loss:1.431568 [ 3200/ 3881]
# Done. Time:4.22168739000017
# Start validation.
# Done. Time:0.29078325399996174
# Validation performance:
#  Avg loss:1.893656
#
# Start evaluation.
# Done. Time:0.8838556400000925
# Test performance:
#  Accuracy:38.0%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.680713 [    0/ 3881]
# loss:1.422080 [ 3200/ 3881]
# Done. Time:3.240680375000011
# Start validation.
# Done. Time:0.2965778809998483
# Validation performance:
#  Avg loss:1.890206
#
# Start evaluation.
# Done. Time:0.8825910830000794
# Test performance:
#  Accuracy:37.5%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:1.674903 [    0/ 3881]
# loss:1.412662 [ 3200/ 3881]
# Done. Time:3.568520420000141
# Start validation.
# Done. Time:0.46662567400016997
# Validation performance:
#  Avg loss:1.886788
#
# Start evaluation.
# Done. Time:1.1825390589999643
# Test performance:
#  Accuracy:37.5%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.669197 [    0/ 3881]
# loss:1.403594 [ 3200/ 3881]
# Done. Time:3.25718043400002
# Start validation.
# Done. Time:0.34374792400012666
# Validation performance:
#  Avg loss:1.883740
#
# Start evaluation.
# Done. Time:1.0297176660001242
# Test performance:
#  Accuracy:38.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:1.663563 [    0/ 3881]
# loss:1.394971 [ 3200/ 3881]
# Done. Time:3.7325674399999116
# Start validation.
# Done. Time:0.36594694900009017
# Validation performance:
#  Avg loss:1.880482
#
# Start evaluation.
# Done. Time:0.989447883000139
# Test performance:
#  Accuracy:38.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:1.658104 [    0/ 3881]
# loss:1.386136 [ 3200/ 3881]
# Done. Time:4.485225643000149
# Start validation.
# Done. Time:0.33555498999999145
# Validation performance:
#  Avg loss:1.877377
#
# Start evaluation.
# Done. Time:0.9721813109999857
# Test performance:
#  Accuracy:39.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.652803 [    0/ 3881]
# loss:1.371515 [ 3200/ 3881]
# Done. Time:3.395610010999917
# Start validation.
# Done. Time:0.28503568000019186
# Validation performance:
#  Avg loss:1.869468
#
# Start evaluation.
# Done. Time:0.8462502539998695
# Test performance:
#  Accuracy:40.0%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.647973 [    0/ 3881]
# loss:1.360687 [ 3200/ 3881]
# Done. Time:3.83525369899985
# Start validation.
# Done. Time:0.4982134470001256
# Validation performance:
#  Avg loss:1.864045
#
# Start evaluation.
# Done. Time:0.9784034550000342
# Test performance:
#  Accuracy:41.5%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.644353 [    0/ 3881]
# loss:1.352780 [ 3200/ 3881]
# Done. Time:3.508685344000014
# Start validation.
# Done. Time:0.33215824800004157
# Validation performance:
#  Avg loss:1.860456
#
# Start evaluation.
# Done. Time:0.9581672660001459
# Test performance:
#  Accuracy:42.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.639677 [    0/ 3881]
# loss:1.343285 [ 3200/ 3881]
# Done. Time:3.636236318000101
# Start validation.
# Done. Time:0.3355861030001961
# Validation performance:
#  Avg loss:1.857041
#
# Start evaluation.
# Done. Time:1.115284956000096
# Test performance:
#  Accuracy:42.0%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:1.634489 [    0/ 3881]
# loss:1.335976 [ 3200/ 3881]
# Done. Time:4.203720389999944
# Start validation.
# Done. Time:0.3314919590000045
# Validation performance:
#  Avg loss:1.853495
#
# Start evaluation.
# Done. Time:0.985791251000137
# Test performance:
#  Accuracy:42.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:1.629956 [    0/ 3881]
# loss:1.328943 [ 3200/ 3881]
# Done. Time:3.360528099000021
# Start validation.
# Done. Time:0.3142348800001855
# Validation performance:
#  Avg loss:1.849997
#
# Start evaluation.
# Done. Time:0.8778212590000294
# Test performance:
#  Accuracy:42.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:1.624931 [    0/ 3881]
# loss:1.321737 [ 3200/ 3881]
# Done. Time:4.05513232699991
# Start validation.
# Done. Time:0.44432334099997206
# Validation performance:
#  Avg loss:1.846850
#
# Start evaluation.
# Done. Time:0.890571158000057
# Test performance:
#  Accuracy:43.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:1.620136 [    0/ 3881]
# loss:1.314623 [ 3200/ 3881]
# Done. Time:3.2700650560000213
# Start validation.
# Done. Time:0.3018411840000681
# Validation performance:
#  Avg loss:1.843585
#
# Start evaluation.
# Done. Time:0.8876056020001215
# Test performance:
#  Accuracy:44.0%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:1.615260 [    0/ 3881]
# loss:1.307649 [ 3200/ 3881]
# Done. Time:3.2271386049999364
# Start validation.
# Done. Time:0.29785292499991556
# Validation performance:
#  Avg loss:1.840257
#
# Start evaluation.
# Done. Time:0.8825432969999838
# Test performance:
#  Accuracy:44.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:1.610241 [    0/ 3881]
# loss:1.300811 [ 3200/ 3881]
# Done. Time:4.222234824999987
# Start validation.
# Done. Time:0.3198342190000858
# Validation performance:
#  Avg loss:1.837550
#
# Start evaluation.
# Done. Time:0.9352577559998281
# Test performance:
#  Accuracy:45.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:1.605443 [    0/ 3881]
# loss:1.294243 [ 3200/ 3881]
# Done. Time:3.6449266889999308
# Start validation.
# Done. Time:0.7398000139999112
# Validation performance:
#  Avg loss:1.835398
#
# Start evaluation.
# Done. Time:1.4760987669999395
# Test performance:
#  Accuracy:45.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.600669 [    0/ 3881]
# loss:1.287198 [ 3200/ 3881]
# Done. Time:8.097128666999879
# Start validation.
# Done. Time:0.33462703200007127
# Validation performance:
#  Avg loss:1.832698
#
# Start evaluation.
# Done. Time:0.8385669409999537
# Test performance:
#  Accuracy:45.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:1.596189 [    0/ 3881]
# loss:1.280208 [ 3200/ 3881]
# Done. Time:3.3575171959998897
# Start validation.
# Done. Time:0.2909947129999182
# Validation performance:
#  Avg loss:1.830470
#
# Start evaluation.
# Done. Time:0.8925993350001136
# Test performance:
#  Accuracy:45.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:1.591082 [    0/ 3881]
# loss:1.273247 [ 3200/ 3881]
# Done. Time:4.257987156999889
# Start validation.
# Done. Time:0.3034792700000253
# Validation performance:
#  Avg loss:1.828120
#
# Start evaluation.
# Done. Time:0.8581760990000475
# Test performance:
#  Accuracy:44.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:1.585865 [    0/ 3881]
# loss:1.273195 [ 3200/ 3881]
# Done. Time:3.268991966000158
# Start validation.
# Done. Time:0.3002724240000134
# Validation performance:
#  Avg loss:1.825673
#
# Start evaluation.
# Done. Time:0.8652511860000232
# Test performance:
#  Accuracy:44.5%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:1.581819 [    0/ 3881]
# loss:1.260498 [ 3200/ 3881]
# Done. Time:3.3219075640001847
# Start validation.
# Done. Time:0.30223062999994
# Validation performance:
#  Avg loss:1.824402
#
# Start evaluation.
# Done. Time:1.1872914100001708
# Test performance:
#  Accuracy:44.5%
# Minimum validation loss:1.8244019917079382 at 50 epoch.
# Maximum accuracy:45.5 at 45 epoch.

# %% [markdown]
# ## Train aligned and scaled landmarks (parts-based)

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_align_scale_w))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_align_scale_parts,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_align_scale_parts,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_align_scale_parts,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_align_scale_p = np.array(val_losses)
test_accs_align_scale_p = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_align_scale_p.min()} at {np.argmin(val_losses_align_scale_p)+1} epoch.")
print(f"Maximum accuracy:{test_accs_align_scale_p.max()} at {np.argmax(test_accs_align_scale_p)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.328298 [    0/ 3881]
# loss:2.119237 [ 3200/ 3881]
# Done. Time:4.8627882039997985
# Start validation.
# Done. Time:0.47164192700006424
# Validation performance:
#  Avg loss:2.201830
#
# Start evaluation.
# Done. Time:1.0239656010001
# Test performance:
#  Accuracy:22.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.226182 [    0/ 3881]
# loss:1.924204 [ 3200/ 3881]
# Done. Time:3.2580399260000377
# Start validation.
# Done. Time:0.30873063799981537
# Validation performance:
#  Avg loss:2.112022
#
# Start evaluation.
# Done. Time:0.8996005899998636
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:2.071416 [    0/ 3881]
# loss:1.730421 [ 3200/ 3881]
# Done. Time:3.2974859459998243
# Start validation.
# Done. Time:0.3110312999999678
# Validation performance:
#  Avg loss:2.030494
#
# Start evaluation.
# Done. Time:0.8691299849999723
# Test performance:
#  Accuracy:40.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:2.001705 [    0/ 3881]
# loss:1.604363 [ 3200/ 3881]
# Done. Time:4.175871266000058
# Start validation.
# Done. Time:0.3188939560000108
# Validation performance:
#  Avg loss:1.973393
#
# Start evaluation.
# Done. Time:0.8842545300001348
# Test performance:
#  Accuracy:44.5%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.934078 [    0/ 3881]
# loss:1.526521 [ 3200/ 3881]
# Done. Time:3.265629525999884
# Start validation.
# Done. Time:0.3177793190000102
# Validation performance:
#  Avg loss:1.928852
#
# Start evaluation.
# Done. Time:0.880837978000045
# Test performance:
#  Accuracy:44.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.875944 [    0/ 3881]
# loss:1.471205 [ 3200/ 3881]
# Done. Time:3.4831208950001837
# Start validation.
# Done. Time:0.4663138840001011
# Validation performance:
#  Avg loss:1.895667
#
# Start evaluation.
# Done. Time:1.1878983029998835
# Test performance:
#  Accuracy:44.5%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.826824 [    0/ 3881]
# loss:1.435109 [ 3200/ 3881]
# Done. Time:3.2665698149999116
# Start validation.
# Done. Time:0.3134662520001257
# Validation performance:
#  Avg loss:1.869719
#
# Start evaluation.
# Done. Time:0.9013574499999777
# Test performance:
#  Accuracy:45.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.782051 [    0/ 3881]
# loss:1.401983 [ 3200/ 3881]
# Done. Time:3.258502907000093
# Start validation.
# Done. Time:0.3051449950000915
# Validation performance:
#  Avg loss:1.847072
#
# Start evaluation.
# Done. Time:0.9033831790000022
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.739323 [    0/ 3881]
# loss:1.372710 [ 3200/ 3881]
# Done. Time:4.227342393000072
# Start validation.
# Done. Time:0.2850450720000026
# Validation performance:
#  Avg loss:1.824688
#
# Start evaluation.
# Done. Time:0.8620903330001966
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.696424 [    0/ 3881]
# loss:1.350685 [ 3200/ 3881]
# Done. Time:3.234936245999961
# Start validation.
# Done. Time:0.3026139549999698
# Validation performance:
#  Avg loss:1.805070
#
# Start evaluation.
# Done. Time:0.8863330059998589
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.656002 [    0/ 3881]
# loss:1.331553 [ 3200/ 3881]
# Done. Time:3.287321711000004
# Start validation.
# Done. Time:0.3646620330000587
# Validation performance:
#  Avg loss:1.784448
#
# Start evaluation.
# Done. Time:1.20384721299979
# Test performance:
#  Accuracy:52.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.621132 [    0/ 3881]
# loss:1.312671 [ 3200/ 3881]
# Done. Time:3.5272269380000125
# Start validation.
# Done. Time:0.39187206500014327
# Validation performance:
#  Avg loss:1.763727
#
# Start evaluation.
# Done. Time:1.2294950489999792
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.592411 [    0/ 3881]
# loss:1.294007 [ 3200/ 3881]
# Done. Time:3.5565212190001603
# Start validation.
# Done. Time:0.29759456800002226
# Validation performance:
#  Avg loss:1.744623
#
# Start evaluation.
# Done. Time:0.8575472019999779
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.563997 [    0/ 3881]
# loss:1.271545 [ 3200/ 3881]
# Done. Time:4.173226627000076
# Start validation.
# Done. Time:0.33448490499995387
# Validation performance:
#  Avg loss:1.725963
#
# Start evaluation.
# Done. Time:0.8559740989999227
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:1.537080 [    0/ 3881]
# loss:1.254350 [ 3200/ 3881]
# Done. Time:3.2470755639999425
# Start validation.
# Done. Time:0.3132912559999568
# Validation performance:
#  Avg loss:1.701494
#
# Start evaluation.
# Done. Time:0.9162149349999709
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.515947 [    0/ 3881]
# loss:1.228092 [ 3200/ 3881]
# Done. Time:3.26056878899999
# Start validation.
# Done. Time:0.4169504159999633
# Validation performance:
#  Avg loss:1.686625
#
# Start evaluation.
# Done. Time:1.2859074980001424
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.490549 [    0/ 3881]
# loss:1.210911 [ 3200/ 3881]
# Done. Time:3.4735704610000084
# Start validation.
# Done. Time:0.32349096399980226
# Validation performance:
#  Avg loss:1.667437
#
# Start evaluation.
# Done. Time:0.9230523359999552
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.468920 [    0/ 3881]
# loss:1.192825 [ 3200/ 3881]
# Done. Time:3.2665800820000186
# Start validation.
# Done. Time:0.3115522840000722
# Validation performance:
#  Avg loss:1.648692
#
# Start evaluation.
# Done. Time:0.9073156399999789
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.447719 [    0/ 3881]
# loss:1.173240 [ 3200/ 3881]
# Done. Time:4.948902941999904
# Start validation.
# Done. Time:0.5083515769999849
# Validation performance:
#  Avg loss:1.629917
#
# Start evaluation.
# Done. Time:1.0881497769998987
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.429930 [    0/ 3881]
# loss:1.155696 [ 3200/ 3881]
# Done. Time:3.3278730460001498
# Start validation.
# Done. Time:0.32680778400003874
# Validation performance:
#  Avg loss:1.611326
#
# Start evaluation.
# Done. Time:0.9068081220000295
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.412743 [    0/ 3881]
# loss:1.139384 [ 3200/ 3881]
# Done. Time:3.25800819899996
# Start validation.
# Done. Time:0.3119060509998235
# Validation performance:
#  Avg loss:1.593234
#
# Start evaluation.
# Done. Time:1.1921422369998709
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.397349 [    0/ 3881]
# loss:1.124052 [ 3200/ 3881]
# Done. Time:3.6645396259998506
# Start validation.
# Done. Time:0.3165961879999486
# Validation performance:
#  Avg loss:1.579058
#
# Start evaluation.
# Done. Time:0.9413955449999776
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.383096 [    0/ 3881]
# loss:1.106945 [ 3200/ 3881]
# Done. Time:3.3452478960000462
# Start validation.
# Done. Time:0.31195963300001495
# Validation performance:
#  Avg loss:1.559515
#
# Start evaluation.
# Done. Time:0.9164860749999661
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.369198 [    0/ 3881]
# loss:1.094014 [ 3200/ 3881]
# Done. Time:4.2325958860001265
# Start validation.
# Done. Time:0.3049884669999301
# Validation performance:
#  Avg loss:1.543157
#
# Start evaluation.
# Done. Time:0.9263777119999759
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.354145 [    0/ 3881]
# loss:1.079213 [ 3200/ 3881]
# Done. Time:3.252233565999859
# Start validation.
# Done. Time:0.31408617000010963
# Validation performance:
#  Avg loss:1.523875
#
# Start evaluation.
# Done. Time:0.8863460389998181
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.340643 [    0/ 3881]
# loss:1.063557 [ 3200/ 3881]
# Done. Time:3.307477689999814
# Start validation.
# Done. Time:0.31428979799989065
# Validation performance:
#  Avg loss:1.507225
#
# Start evaluation.
# Done. Time:1.0659294480001336
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.330184 [    0/ 3881]
# loss:1.050779 [ 3200/ 3881]
# Done. Time:3.8944841649999944
# Start validation.
# Done. Time:0.3136986810000053
# Validation performance:
#  Avg loss:1.490577
#
# Start evaluation.
# Done. Time:0.8568298109998977
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.316270 [    0/ 3881]
# loss:1.036272 [ 3200/ 3881]
# Done. Time:3.2759861900001397
# Start validation.
# Done. Time:0.3220221690000926
# Validation performance:
#  Avg loss:1.477071
#
# Start evaluation.
# Done. Time:0.8682935420001741
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:1.304430 [    0/ 3881]
# loss:1.020030 [ 3200/ 3881]
# Done. Time:4.069501668000157
# Start validation.
# Done. Time:0.47930301300016254
# Validation performance:
#  Avg loss:1.464377
#
# Start evaluation.
# Done. Time:0.9312232319998657
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.295508 [    0/ 3881]
# loss:1.007690 [ 3200/ 3881]
# Done. Time:3.2869004259998746
# Start validation.
# Done. Time:0.3186568309999984
# Validation performance:
#  Avg loss:1.444977
#
# Start evaluation.
# Done. Time:0.8711154879999867
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:1.288306 [    0/ 3881]
# loss:0.997325 [ 3200/ 3881]
# Done. Time:3.26676875499993
# Start validation.
# Done. Time:0.3372323689998211
# Validation performance:
#  Avg loss:1.430977
#
# Start evaluation.
# Done. Time:0.8801810439999826
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.276632 [    0/ 3881]
# loss:0.984272 [ 3200/ 3881]
# Done. Time:4.248019082999917
# Start validation.
# Done. Time:0.3429099259999475
# Validation performance:
#  Avg loss:1.421469
#
# Start evaluation.
# Done. Time:0.8930791549998958
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:1.265923 [    0/ 3881]
# loss:0.972021 [ 3200/ 3881]
# Done. Time:3.272369929999968
# Start validation.
# Done. Time:0.29831620799996017
# Validation performance:
#  Avg loss:1.408341
#
# Start evaluation.
# Done. Time:0.8847415490001822
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:1.256331 [    0/ 3881]
# loss:0.963352 [ 3200/ 3881]
# Done. Time:3.6401536190001025
# Start validation.
# Done. Time:0.49407273500014526
# Validation performance:
#  Avg loss:1.397011
#
# Start evaluation.
# Done. Time:1.0895847790000062
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.247254 [    0/ 3881]
# loss:0.953718 [ 3200/ 3881]
# Done. Time:3.2836511519999476
# Start validation.
# Done. Time:0.3112580380000054
# Validation performance:
#  Avg loss:1.387050
#
# Start evaluation.
# Done. Time:0.8834707459998299
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.238016 [    0/ 3881]
# loss:0.946062 [ 3200/ 3881]
# Done. Time:3.269039525999915
# Start validation.
# Done. Time:0.31779145400014386
# Validation performance:
#  Avg loss:1.377130
#
# Start evaluation.
# Done. Time:0.9133703429999969
# Test performance:
#  Accuracy:63.5%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.228128 [    0/ 3881]
# loss:0.936079 [ 3200/ 3881]
# Done. Time:4.251034376999996
# Start validation.
# Done. Time:0.3062339579998934
# Validation performance:
#  Avg loss:1.368005
#
# Start evaluation.
# Done. Time:0.8884160380000594
# Test performance:
#  Accuracy:63.5%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.219711 [    0/ 3881]
# loss:0.924722 [ 3200/ 3881]
# Done. Time:3.2498369320001075
# Start validation.
# Done. Time:0.31478532400001313
# Validation performance:
#  Avg loss:1.359790
#
# Start evaluation.
# Done. Time:0.9026237420000598
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:1.210097 [    0/ 3881]
# loss:0.913365 [ 3200/ 3881]
# Done. Time:3.38871847900009
# Start validation.
# Done. Time:0.49886660399988614
# Validation performance:
#  Avg loss:1.351828
#
# Start evaluation.
# Done. Time:1.2851463530000728
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:1.201244 [    0/ 3881]
# loss:0.902597 [ 3200/ 3881]
# Done. Time:3.2142894199998864
# Start validation.
# Done. Time:0.32860597000012604
# Validation performance:
#  Avg loss:1.345545
#
# Start evaluation.
# Done. Time:0.8864695170000232
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:1.193204 [    0/ 3881]
# loss:0.892641 [ 3200/ 3881]
# Done. Time:4.2441119579998485
# Start validation.
# Done. Time:0.3671130279999488
# Validation performance:
#  Avg loss:1.337495
#
# Start evaluation.
# Done. Time:0.9049104910000096
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:1.185540 [    0/ 3881]
# loss:0.883122 [ 3200/ 3881]
# Done. Time:4.213417739000079
# Start validation.
# Done. Time:0.3152251359999809
# Validation performance:
#  Avg loss:1.330886
#
# Start evaluation.
# Done. Time:0.9285331319999841
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:1.177822 [    0/ 3881]
# loss:0.874002 [ 3200/ 3881]
# Done. Time:3.2635093360001974
# Start validation.
# Done. Time:0.3135882369999763
# Validation performance:
#  Avg loss:1.324377
#
# Start evaluation.
# Done. Time:0.885654944999942
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:1.170693 [    0/ 3881]
# loss:0.865430 [ 3200/ 3881]
# Done. Time:3.8199973360001422
# Start validation.
# Done. Time:0.5027135580000959
# Validation performance:
#  Avg loss:1.318261
#
# Start evaluation.
# Done. Time:0.9834589019999385
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:1.163172 [    0/ 3881]
# loss:0.856332 [ 3200/ 3881]
# Done. Time:3.2757143809999434
# Start validation.
# Done. Time:0.31518537700003435
# Validation performance:
#  Avg loss:1.312501
#
# Start evaluation.
# Done. Time:0.8961356400000113
# Test performance:
#  Accuracy:65.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.155711 [    0/ 3881]
# loss:0.849123 [ 3200/ 3881]
# Done. Time:3.2235498719999214
# Start validation.
# Done. Time:0.32670010600008936
# Validation performance:
#  Avg loss:1.305832
#
# Start evaluation.
# Done. Time:0.9034759589999339
# Test performance:
#  Accuracy:65.5%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:1.147850 [    0/ 3881]
# loss:0.841373 [ 3200/ 3881]
# Done. Time:4.2177322479999475
# Start validation.
# Done. Time:0.3075708769999892
# Validation performance:
#  Avg loss:1.300703
#
# Start evaluation.
# Done. Time:0.9322994359999939
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:1.140019 [    0/ 3881]
# loss:0.833318 [ 3200/ 3881]
# Done. Time:3.242248454999981
# Start validation.
# Done. Time:0.3224147680000442
# Validation performance:
#  Avg loss:1.295698
#
# Start evaluation.
# Done. Time:0.9125720729998648
# Test performance:
#  Accuracy:65.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:1.132303 [    0/ 3881]
# loss:0.826059 [ 3200/ 3881]
# Done. Time:3.5272273319999385
# Start validation.
# Done. Time:0.5034524929999407
# Validation performance:
#  Avg loss:1.290341
#
# Start evaluation.
# Done. Time:1.2198998660001052
# Test performance:
#  Accuracy:65.5%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:1.124974 [    0/ 3881]
# loss:0.818256 [ 3200/ 3881]
# Done. Time:3.244584272999873
# Start validation.
# Done. Time:0.3018700089999129
# Validation performance:
#  Avg loss:1.285479
#
# Start evaluation.
# Done. Time:0.8816774259998965
# Test performance:
#  Accuracy:65.5%
# Minimum validation loss:1.2854791368756975 at 50 epoch.
# Maximum accuracy:66.0 at 47 epoch.

# %% [markdown]
# ## Plot results

# %%
import matplotlib.pyplot as plt

plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(val_losses_origin)+1)
plt.plot(xs, val_losses_origin, label="Origin", marker=".")
plt.plot(xs, val_losses_align_w, label="Align_W", marker=".")
plt.plot(xs, val_losses_align_p, label="Align_P", marker=".")
plt.plot(xs, val_losses_align_scale_w, label="Align-Scale_W", marker=".")
plt.plot(xs, val_losses_align_scale_p, label="Align-Scale_P", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Validation loss")
plt.legend()
plt.show()

# %%
plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(test_accs)+1)
ys = test_accs
plt.plot(xs, test_accs_origin, label="Origin", marker=".")
plt.plot(xs, test_accs_align_w, label="Align_W", marker=".")
plt.plot(xs, test_accs_align_p, label="Align_P", marker=".")
plt.plot(xs, test_accs_align_scale_w, label="Align-Scale_W", marker=".")
plt.plot(xs, test_accs_align_scale_p, label="Align-Scale_P", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# # Appendix: aburation of alignment and scaling modes

# %%
_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
trans_select_feature = SelectLandmarksAndFeature(landmarks=use_landmarks, features=use_features)
trans_repnan = ReplaceNan()

trans_align_f_scale_f = PartsBasedNormalization(align_mode="framewise", scale_mode="framewise")
trans_align_f_scale_u = PartsBasedNormalization(align_mode="framewise", scale_mode="unique")
trans_align_u_scale_f = PartsBasedNormalization(align_mode="unique", scale_mode="framewise")
trans_align_u_scale_u = PartsBasedNormalization(align_mode="unique", scale_mode="unique")

# %%
pre_transforms_align_f_scale_f = Compose([trans_select_feature,
                                         trans_repnan,
                                         trans_align_f_scale_f])
pre_transforms_align_f_scale_u = Compose([trans_select_feature,
                                         trans_repnan,
                                         trans_align_f_scale_u])
pre_transforms_align_u_scale_f = Compose([trans_select_feature,
                                         trans_repnan,
                                         trans_align_u_scale_f])
pre_transforms_align_u_scale_u = Compose([trans_select_feature,
                                         trans_repnan,
                                         trans_align_u_scale_u])

# %% [markdown]
# ### Framewise alignment and framewise scaling

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_align_scale_w))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_align_f_scale_f,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_align_f_scale_f,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_align_f_scale_f,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_align_f_scale_f = np.array(val_losses)
test_accs_align_f_scale_f = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_align_f_scale_f.min()} at {np.argmin(val_losses_align_f_scale_f)+1} epoch.")
print(f"Maximum accuracy:{test_accs_align_f_scale_f.max()} at {np.argmax(test_accs_align_f_scale_f)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.388217 [    0/ 3881]
# loss:2.078134 [ 3200/ 3881]
# Done. Time:3.596127699000135
# Start validation.
# Done. Time:0.5045361479999428
# Validation performance:
#  Avg loss:2.200676
#
# Start evaluation.
# Done. Time:1.1645072589999472
# Test performance:
#  Accuracy:33.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.182485 [    0/ 3881]
# loss:1.879188 [ 3200/ 3881]
# Done. Time:3.281742298000154
# Start validation.
# Done. Time:0.29564334599990616
# Validation performance:
#  Avg loss:2.085568
#
# Start evaluation.
# Done. Time:1.0201939409998886
# Test performance:
#  Accuracy:39.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:2.123240 [    0/ 3881]
# loss:1.729802 [ 3200/ 3881]
# Done. Time:4.027755564000017
# Start validation.
# Done. Time:0.3177008200000273
# Validation performance:
#  Avg loss:2.017352
#
# Start evaluation.
# Done. Time:0.88096192099988
# Test performance:
#  Accuracy:45.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:2.071126 [    0/ 3881]
# loss:1.620735 [ 3200/ 3881]
# Done. Time:3.2476087139998526
# Start validation.
# Done. Time:0.3364147789998242
# Validation performance:
#  Avg loss:1.958842
#
# Start evaluation.
# Done. Time:0.9116792590000387
# Test performance:
#  Accuracy:42.5%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:2.016910 [    0/ 3881]
# loss:1.530410 [ 3200/ 3881]
# Done. Time:4.1369146380000075
# Start validation.
# Done. Time:0.40695899599995755
# Validation performance:
#  Avg loss:1.908852
#
# Start evaluation.
# Done. Time:0.8912419590001264
# Test performance:
#  Accuracy:48.0%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.973726 [    0/ 3881]
# loss:1.470767 [ 3200/ 3881]
# Done. Time:3.260215578000043
# Start validation.
# Done. Time:0.3159026509999876
# Validation performance:
#  Avg loss:1.869218
#
# Start evaluation.
# Done. Time:0.8884278949999498
# Test performance:
#  Accuracy:43.5%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.911035 [    0/ 3881]
# loss:1.416737 [ 3200/ 3881]
# Done. Time:3.2554481719998876
# Start validation.
# Done. Time:0.3286384939999607
# Validation performance:
#  Avg loss:1.830559
#
# Start evaluation.
# Done. Time:0.9035511300000962
# Test performance:
#  Accuracy:45.5%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.847565 [    0/ 3881]
# loss:1.380350 [ 3200/ 3881]
# Done. Time:4.26071062699998
# Start validation.
# Done. Time:0.32078138799988665
# Validation performance:
#  Avg loss:1.803919
#
# Start evaluation.
# Done. Time:0.8942196109999259
# Test performance:
#  Accuracy:47.5%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.797343 [    0/ 3881]
# loss:1.344714 [ 3200/ 3881]
# Done. Time:3.2231321230001413
# Start validation.
# Done. Time:0.30157651500007887
# Validation performance:
#  Avg loss:1.772203
#
# Start evaluation.
# Done. Time:0.873560543999929
# Test performance:
#  Accuracy:47.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.749424 [    0/ 3881]
# loss:1.316996 [ 3200/ 3881]
# Done. Time:3.7033457080001426
# Start validation.
# Done. Time:0.5026464590000614
# Validation performance:
#  Avg loss:1.746846
#
# Start evaluation.
# Done. Time:1.1113242870001159
# Test performance:
#  Accuracy:47.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.697706 [    0/ 3881]
# loss:1.292076 [ 3200/ 3881]
# Done. Time:3.214049176999879
# Start validation.
# Done. Time:0.3209560269999656
# Validation performance:
#  Avg loss:1.716899
#
# Start evaluation.
# Done. Time:0.893489203999934
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.656432 [    0/ 3881]
# loss:1.263764 [ 3200/ 3881]
# Done. Time:3.23094253499994
# Start validation.
# Done. Time:0.316191457000059
# Validation performance:
#  Avg loss:1.697210
#
# Start evaluation.
# Done. Time:0.8976899409999533
# Test performance:
#  Accuracy:49.5%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.615007 [    0/ 3881]
# loss:1.238742 [ 3200/ 3881]
# Done. Time:5.318143451000196
# Start validation.
# Done. Time:0.368049732000145
# Validation performance:
#  Avg loss:1.667550
#
# Start evaluation.
# Done. Time:0.9284485149999
# Test performance:
#  Accuracy:51.0%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.567541 [    0/ 3881]
# loss:1.216444 [ 3200/ 3881]
# Done. Time:3.289300574000208
# Start validation.
# Done. Time:0.33960512600015136
# Validation performance:
#  Avg loss:1.646923
#
# Start evaluation.
# Done. Time:0.9028880480000225
# Test performance:
#  Accuracy:53.0%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:1.541741 [    0/ 3881]
# loss:1.194112 [ 3200/ 3881]
# Done. Time:3.518664243999865
# Start validation.
# Done. Time:0.5117923359998713
# Validation performance:
#  Avg loss:1.627024
#
# Start evaluation.
# Done. Time:1.1890549220001958
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.515444 [    0/ 3881]
# loss:1.173062 [ 3200/ 3881]
# Done. Time:3.2730168929999763
# Start validation.
# Done. Time:0.31899260599993795
# Validation performance:
#  Avg loss:1.609663
#
# Start evaluation.
# Done. Time:0.9312989679999646
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.492498 [    0/ 3881]
# loss:1.154397 [ 3200/ 3881]
# Done. Time:3.276036445000045
# Start validation.
# Done. Time:0.3213098290000289
# Validation performance:
#  Avg loss:1.593630
#
# Start evaluation.
# Done. Time:0.9032005000001391
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.471906 [    0/ 3881]
# loss:1.136516 [ 3200/ 3881]
# Done. Time:4.251188442000057
# Start validation.
# Done. Time:0.33087379900007363
# Validation performance:
#  Avg loss:1.579092
#
# Start evaluation.
# Done. Time:0.8733249650001653
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.453817 [    0/ 3881]
# loss:1.114923 [ 3200/ 3881]
# Done. Time:3.249603040000011
# Start validation.
# Done. Time:0.3112789199999497
# Validation performance:
#  Avg loss:1.566992
#
# Start evaluation.
# Done. Time:0.929307246999997
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.435950 [    0/ 3881]
# loss:1.106934 [ 3200/ 3881]
# Done. Time:3.365009848999989
# Start validation.
# Done. Time:0.5040064759998586
# Validation performance:
#  Avg loss:1.551914
#
# Start evaluation.
# Done. Time:1.27946867799983
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.425789 [    0/ 3881]
# loss:1.087265 [ 3200/ 3881]
# Done. Time:3.290401455999927
# Start validation.
# Done. Time:0.31755999500001053
# Validation performance:
#  Avg loss:1.538859
#
# Start evaluation.
# Done. Time:0.8826568919998863
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.408551 [    0/ 3881]
# loss:1.070887 [ 3200/ 3881]
# Done. Time:3.2495023100000253
# Start validation.
# Done. Time:0.33408391100010704
# Validation performance:
#  Avg loss:1.526160
#
# Start evaluation.
# Done. Time:0.878310287999966
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.397193 [    0/ 3881]
# loss:1.056682 [ 3200/ 3881]
# Done. Time:4.258550502999924
# Start validation.
# Done. Time:0.32942555800013906
# Validation performance:
#  Avg loss:1.513321
#
# Start evaluation.
# Done. Time:0.9022197689998848
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.385923 [    0/ 3881]
# loss:1.041019 [ 3200/ 3881]
# Done. Time:3.319334800999968
# Start validation.
# Done. Time:0.3130458229998112
# Validation performance:
#  Avg loss:1.501217
#
# Start evaluation.
# Done. Time:0.9382407719999719
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.374703 [    0/ 3881]
# loss:1.029206 [ 3200/ 3881]
# Done. Time:3.2753729219998604
# Start validation.
# Done. Time:0.41995327399990856
# Validation performance:
#  Avg loss:1.488242
#
# Start evaluation.
# Done. Time:1.2278659050000442
# Test performance:
#  Accuracy:60.0%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.364065 [    0/ 3881]
# loss:1.013613 [ 3200/ 3881]
# Done. Time:3.527195679999977
# Start validation.
# Done. Time:0.34548628100014867
# Validation performance:
#  Avg loss:1.476749
#
# Start evaluation.
# Done. Time:0.875982421000117
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.354207 [    0/ 3881]
# loss:1.001903 [ 3200/ 3881]
# Done. Time:3.289250316999869
# Start validation.
# Done. Time:0.3179347660000076
# Validation performance:
#  Avg loss:1.464831
#
# Start evaluation.
# Done. Time:0.8551895749999403
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.341160 [    0/ 3881]
# loss:0.989090 [ 3200/ 3881]
# Done. Time:4.256311853999932
# Start validation.
# Done. Time:0.3157514669999273
# Validation performance:
#  Avg loss:1.453657
#
# Start evaluation.
# Done. Time:0.9153663800000231
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:1.332775 [    0/ 3881]
# loss:0.976153 [ 3200/ 3881]
# Done. Time:3.5975961319998078
# Start validation.
# Done. Time:0.491312520000065
# Validation performance:
#  Avg loss:1.443515
#
# Start evaluation.
# Done. Time:1.1549620659998254
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.322922 [    0/ 3881]
# loss:0.963854 [ 3200/ 3881]
# Done. Time:3.4303265190001184
# Start validation.
# Done. Time:0.47466002099986326
# Validation performance:
#  Avg loss:1.433857
#
# Start evaluation.
# Done. Time:1.2644836110000597
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:1.312860 [    0/ 3881]
# loss:0.952352 [ 3200/ 3881]
# Done. Time:3.2274523460000637
# Start validation.
# Done. Time:0.31111749999990934
# Validation performance:
#  Avg loss:1.425146
#
# Start evaluation.
# Done. Time:0.8852452510000148
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.296262 [    0/ 3881]
# loss:0.939362 [ 3200/ 3881]
# Done. Time:3.2422166090000246
# Start validation.
# Done. Time:0.32371312499981286
# Validation performance:
#  Avg loss:1.415653
#
# Start evaluation.
# Done. Time:0.9336918590001915
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:1.293528 [    0/ 3881]
# loss:0.927240 [ 3200/ 3881]
# Done. Time:4.252875658999983
# Start validation.
# Done. Time:0.32812220499999967
# Validation performance:
#  Avg loss:1.406832
#
# Start evaluation.
# Done. Time:0.8906403400001182
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:1.278280 [    0/ 3881]
# loss:0.917080 [ 3200/ 3881]
# Done. Time:3.2720780390000073
# Start validation.
# Done. Time:0.32878918300002624
# Validation performance:
#  Avg loss:1.398660
#
# Start evaluation.
# Done. Time:0.9299446059999354
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.274697 [    0/ 3881]
# loss:0.904131 [ 3200/ 3881]
# Done. Time:3.247693922000053
# Start validation.
# Done. Time:0.38102160599987656
# Validation performance:
#  Avg loss:1.389795
#
# Start evaluation.
# Done. Time:1.2320631350000895
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.261855 [    0/ 3881]
# loss:0.894889 [ 3200/ 3881]
# Done. Time:3.5435532110000167
# Start validation.
# Done. Time:0.31114668099985465
# Validation performance:
#  Avg loss:1.382317
#
# Start evaluation.
# Done. Time:0.8649018290000186
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.255612 [    0/ 3881]
# loss:0.883232 [ 3200/ 3881]
# Done. Time:3.286453278999943
# Start validation.
# Done. Time:0.3349929299999985
# Validation performance:
#  Avg loss:1.373953
#
# Start evaluation.
# Done. Time:0.889442691000113
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.245494 [    0/ 3881]
# loss:0.873975 [ 3200/ 3881]
# Done. Time:4.204130511999892
# Start validation.
# Done. Time:0.29733167399990634
# Validation performance:
#  Avg loss:1.366662
#
# Start evaluation.
# Done. Time:0.8956376579999414
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:1.237218 [    0/ 3881]
# loss:0.863890 [ 3200/ 3881]
# Done. Time:3.2785820470001
# Start validation.
# Done. Time:0.33480893099999776
# Validation performance:
#  Avg loss:1.358538
#
# Start evaluation.
# Done. Time:0.8837635330000921
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:1.228143 [    0/ 3881]
# loss:0.854379 [ 3200/ 3881]
# Done. Time:3.270949384000005
# Start validation.
# Done. Time:0.3049454260001312
# Validation performance:
#  Avg loss:1.350942
#
# Start evaluation.
# Done. Time:1.0123112629999014
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:1.219743 [    0/ 3881]
# loss:0.845109 [ 3200/ 3881]
# Done. Time:3.978110126999809
# Start validation.
# Done. Time:0.3268865879999794
# Validation performance:
#  Avg loss:1.343459
#
# Start evaluation.
# Done. Time:1.035327425999867
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:1.211152 [    0/ 3881]
# loss:0.836354 [ 3200/ 3881]
# Done. Time:3.9975788639999337
# Start validation.
# Done. Time:0.31385677100001885
# Validation performance:
#  Avg loss:1.335768
#
# Start evaluation.
# Done. Time:0.8898190969998723
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:1.202635 [    0/ 3881]
# loss:0.827899 [ 3200/ 3881]
# Done. Time:4.275829385999941
# Start validation.
# Done. Time:0.3143209200000001
# Validation performance:
#  Avg loss:1.328662
#
# Start evaluation.
# Done. Time:0.9444812970000385
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:1.194142 [    0/ 3881]
# loss:0.819853 [ 3200/ 3881]
# Done. Time:3.2947776700000304
# Start validation.
# Done. Time:0.3282112159999997
# Validation performance:
#  Avg loss:1.321123
#
# Start evaluation.
# Done. Time:0.8858998359999077
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:1.186105 [    0/ 3881]
# loss:0.812011 [ 3200/ 3881]
# Done. Time:3.3031309329999203
# Start validation.
# Done. Time:0.3401766750000661
# Validation performance:
#  Avg loss:1.313898
#
# Start evaluation.
# Done. Time:1.197178329000053
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.177755 [    0/ 3881]
# loss:0.804911 [ 3200/ 3881]
# Done. Time:3.5973106080000434
# Start validation.
# Done. Time:0.3128968819999045
# Validation performance:
#  Avg loss:1.307454
#
# Start evaluation.
# Done. Time:0.9127500090000922
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:1.170175 [    0/ 3881]
# loss:0.797324 [ 3200/ 3881]
# Done. Time:3.2820458899998357
# Start validation.
# Done. Time:0.33036624300007134
# Validation performance:
#  Avg loss:1.300243
#
# Start evaluation.
# Done. Time:0.8774168989998543
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:1.162564 [    0/ 3881]
# loss:0.790714 [ 3200/ 3881]
# Done. Time:4.290536890999874
# Start validation.
# Done. Time:0.3035467230001814
# Validation performance:
#  Avg loss:1.293373
#
# Start evaluation.
# Done. Time:0.917566842000042
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:1.155596 [    0/ 3881]
# loss:0.783803 [ 3200/ 3881]
# Done. Time:3.3217699350000203
# Start validation.
# Done. Time:0.33251874799998404
# Validation performance:
#  Avg loss:1.286632
#
# Start evaluation.
# Done. Time:0.9133583800000906
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:1.148573 [    0/ 3881]
# loss:0.777316 [ 3200/ 3881]
# Done. Time:3.28927772499992
# Start validation.
# Done. Time:0.3454637949998869
# Validation performance:
#  Avg loss:1.279757
#
# Start evaluation.
# Done. Time:1.169647321000184
# Test performance:
#  Accuracy:65.0%
# Minimum validation loss:1.2797566652297974 at 50 epoch.
# Maximum accuracy:65.0 at 48 epoch.

# %% [markdown]
# ### Framewise alignment and unique scaling

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_align_scale_w))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_align_f_scale_u,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_align_f_scale_u,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_align_f_scale_u,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_align_f_scale_u = np.array(val_losses)
test_accs_align_f_scale_u = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_align_f_scale_u.min()} at {np.argmin(val_losses_align_f_scale_u)+1} epoch.")
print(f"Maximum accuracy:{test_accs_align_f_scale_u.max()} at {np.argmax(test_accs_align_f_scale_u)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.305183 [    0/ 3881]
# loss:2.152459 [ 3200/ 3881]
# Done. Time:3.2400578079998468
# Start validation.
# Done. Time:0.32970881300002475
# Validation performance:
#  Avg loss:2.218600
#
# Start evaluation.
# Done. Time:1.2692432020000979
# Test performance:
#  Accuracy:27.0%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.215600 [    0/ 3881]
# loss:1.945811 [ 3200/ 3881]
# Done. Time:3.5678831590000755
# Start validation.
# Done. Time:0.3274072899998828
# Validation performance:
#  Avg loss:2.148177
#
# Start evaluation.
# Done. Time:0.8836275099999966
# Test performance:
#  Accuracy:31.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:2.124283 [    0/ 3881]
# loss:1.816302 [ 3200/ 3881]
# Done. Time:3.2461679359998925
# Start validation.
# Done. Time:0.3165585459998965
# Validation performance:
#  Avg loss:2.060849
#
# Start evaluation.
# Done. Time:0.8996846600000481
# Test performance:
#  Accuracy:35.5%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:2.068404 [    0/ 3881]
# loss:1.685851 [ 3200/ 3881]
# Done. Time:4.186658853999916
# Start validation.
# Done. Time:0.29971518800016383
# Validation performance:
#  Avg loss:1.989742
#
# Start evaluation.
# Done. Time:0.8710879350001051
# Test performance:
#  Accuracy:39.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.992763 [    0/ 3881]
# loss:1.607566 [ 3200/ 3881]
# Done. Time:3.231321828999853
# Start validation.
# Done. Time:0.3197005919998901
# Validation performance:
#  Avg loss:1.939610
#
# Start evaluation.
# Done. Time:0.8813730779997968
# Test performance:
#  Accuracy:38.0%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.913715 [    0/ 3881]
# loss:1.550925 [ 3200/ 3881]
# Done. Time:3.284551663000002
# Start validation.
# Done. Time:0.31278189699992254
# Validation performance:
#  Avg loss:1.898499
#
# Start evaluation.
# Done. Time:1.0367300719999548
# Test performance:
#  Accuracy:39.5%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.874158 [    0/ 3881]
# loss:1.514156 [ 3200/ 3881]
# Done. Time:5.153231036000079
# Start validation.
# Done. Time:0.3236056460000327
# Validation performance:
#  Avg loss:1.863638
#
# Start evaluation.
# Done. Time:0.8920481939999263
# Test performance:
#  Accuracy:39.5%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.834273 [    0/ 3881]
# loss:1.487352 [ 3200/ 3881]
# Done. Time:3.231190152999943
# Start validation.
# Done. Time:0.31373248299996703
# Validation performance:
#  Avg loss:1.834876
#
# Start evaluation.
# Done. Time:0.9047439399998893
# Test performance:
#  Accuracy:41.5%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.792455 [    0/ 3881]
# loss:1.445152 [ 3200/ 3881]
# Done. Time:3.907437284000025
# Start validation.
# Done. Time:0.4668346040000415
# Validation performance:
#  Avg loss:1.800072
#
# Start evaluation.
# Done. Time:0.99649923700008
# Test performance:
#  Accuracy:43.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.768880 [    0/ 3881]
# loss:1.438239 [ 3200/ 3881]
# Done. Time:3.2189493569999286
# Start validation.
# Done. Time:0.31783093100011683
# Validation performance:
#  Avg loss:1.782395
#
# Start evaluation.
# Done. Time:0.8781380370000988
# Test performance:
#  Accuracy:44.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.713540 [    0/ 3881]
# loss:1.418947 [ 3200/ 3881]
# Done. Time:3.2996315970001433
# Start validation.
# Done. Time:0.3134677749999355
# Validation performance:
#  Avg loss:1.774744
#
# Start evaluation.
# Done. Time:0.8866868820000491
# Test performance:
#  Accuracy:40.0%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.680993 [    0/ 3881]
# loss:1.395775 [ 3200/ 3881]
# Done. Time:4.259737659999928
# Start validation.
# Done. Time:0.316765026999974
# Validation performance:
#  Avg loss:1.735634
#
# Start evaluation.
# Done. Time:0.8808527670000785
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.640913 [    0/ 3881]
# loss:1.371250 [ 3200/ 3881]
# Done. Time:3.2529062749999866
# Start validation.
# Done. Time:0.33293746999993346
# Validation performance:
#  Avg loss:1.714149
#
# Start evaluation.
# Done. Time:0.8940679649999765
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.610582 [    0/ 3881]
# loss:1.345802 [ 3200/ 3881]
# Done. Time:4.674018390000128
# Start validation.
# Done. Time:1.0190515500000856
# Validation performance:
#  Avg loss:1.695471
#
# Start evaluation.
# Done. Time:2.2352777219998643
# Test performance:
#  Accuracy:51.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:1.576904 [    0/ 3881]
# loss:1.322249 [ 3200/ 3881]
# Done. Time:6.340506108999989
# Start validation.
# Done. Time:0.4359811689998878
# Validation performance:
#  Avg loss:1.678815
#
# Start evaluation.
# Done. Time:0.8911660480000592
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.551616 [    0/ 3881]
# loss:1.308137 [ 3200/ 3881]
# Done. Time:4.404034845999831
# Start validation.
# Done. Time:0.3180680670000129
# Validation performance:
#  Avg loss:1.657317
#
# Start evaluation.
# Done. Time:0.9100187299998197
# Test performance:
#  Accuracy:52.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.525112 [    0/ 3881]
# loss:1.278229 [ 3200/ 3881]
# Done. Time:4.310537566999983
# Start validation.
# Done. Time:0.3125054289998843
# Validation performance:
#  Avg loss:1.634480
#
# Start evaluation.
# Done. Time:0.8886340540000219
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.518117 [    0/ 3881]
# loss:1.251657 [ 3200/ 3881]
# Done. Time:3.2727560419998554
# Start validation.
# Done. Time:0.4598022499999388
# Validation performance:
#  Avg loss:1.623402
#
# Start evaluation.
# Done. Time:1.2635068229999433
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.498884 [    0/ 3881]
# loss:1.228041 [ 3200/ 3881]
# Done. Time:3.356520909999972
# Start validation.
# Done. Time:0.3082619029999023
# Validation performance:
#  Avg loss:1.609157
#
# Start evaluation.
# Done. Time:0.8921859570000379
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.477790 [    0/ 3881]
# loss:1.207054 [ 3200/ 3881]
# Done. Time:3.242667759999904
# Start validation.
# Done. Time:0.3215060730001369
# Validation performance:
#  Avg loss:1.595981
#
# Start evaluation.
# Done. Time:0.873414319999938
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.461758 [    0/ 3881]
# loss:1.188560 [ 3200/ 3881]
# Done. Time:4.2752266410000175
# Start validation.
# Done. Time:0.3064130230000046
# Validation performance:
#  Avg loss:1.579241
#
# Start evaluation.
# Done. Time:0.8790040169999429
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.436053 [    0/ 3881]
# loss:1.165779 [ 3200/ 3881]
# Done. Time:3.2545964739999818
# Start validation.
# Done. Time:0.32516775499993855
# Validation performance:
#  Avg loss:1.569866
#
# Start evaluation.
# Done. Time:0.8741539429997829
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.429934 [    0/ 3881]
# loss:1.146331 [ 3200/ 3881]
# Done. Time:3.324668015000043
# Start validation.
# Done. Time:0.3359758950000469
# Validation performance:
#  Avg loss:1.556503
#
# Start evaluation.
# Done. Time:1.2315148479999607
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.414782 [    0/ 3881]
# loss:1.129898 [ 3200/ 3881]
# Done. Time:3.6190271259999918
# Start validation.
# Done. Time:0.32511763900015467
# Validation performance:
#  Avg loss:1.543567
#
# Start evaluation.
# Done. Time:0.8628180279999924
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.406716 [    0/ 3881]
# loss:1.108515 [ 3200/ 3881]
# Done. Time:3.2108469280001373
# Start validation.
# Done. Time:0.3320486689999598
# Validation performance:
#  Avg loss:1.530237
#
# Start evaluation.
# Done. Time:0.8747209680000196
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.391212 [    0/ 3881]
# loss:1.087811 [ 3200/ 3881]
# Done. Time:4.247365778999892
# Start validation.
# Done. Time:0.2996517770000082
# Validation performance:
#  Avg loss:1.518405
#
# Start evaluation.
# Done. Time:0.8784872220001034
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.361698 [    0/ 3881]
# loss:1.073394 [ 3200/ 3881]
# Done. Time:3.2179240390000814
# Start validation.
# Done. Time:0.31355921299996226
# Validation performance:
#  Avg loss:1.510834
#
# Start evaluation.
# Done. Time:0.8992934099999275
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.372433 [    0/ 3881]
# loss:1.056357 [ 3200/ 3881]
# Done. Time:3.2064362660000825
# Start validation.
# Done. Time:0.31823095400000057
# Validation performance:
#  Avg loss:1.496650
#
# Start evaluation.
# Done. Time:0.9396909449999384
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:1.358238 [    0/ 3881]
# loss:1.038562 [ 3200/ 3881]
# Done. Time:4.164654593000023
# Start validation.
# Done. Time:0.38965289699990535
# Validation performance:
#  Avg loss:1.486947
#
# Start evaluation.
# Done. Time:1.2035511110000243
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.348730 [    0/ 3881]
# loss:1.024248 [ 3200/ 3881]
# Done. Time:3.4800872509999863
# Start validation.
# Done. Time:0.32416536200003065
# Validation performance:
#  Avg loss:1.476641
#
# Start evaluation.
# Done. Time:0.9330794899999546
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:1.338991 [    0/ 3881]
# loss:1.013532 [ 3200/ 3881]
# Done. Time:4.237601459999951
# Start validation.
# Done. Time:0.3263907430000472
# Validation performance:
#  Avg loss:1.469115
#
# Start evaluation.
# Done. Time:0.9122725500001252
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.329424 [    0/ 3881]
# loss:0.994433 [ 3200/ 3881]
# Done. Time:3.2849539339999865
# Start validation.
# Done. Time:0.3220642469998438
# Validation performance:
#  Avg loss:1.452936
#
# Start evaluation.
# Done. Time:0.8753331810000873
# Test performance:
#  Accuracy:60.0%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:1.321785 [    0/ 3881]
# loss:0.979732 [ 3200/ 3881]
# Done. Time:3.280490762999989
# Start validation.
# Done. Time:0.33803310000007514
# Validation performance:
#  Avg loss:1.445635
#
# Start evaluation.
# Done. Time:1.1014453789998697
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:1.314915 [    0/ 3881]
# loss:0.966895 [ 3200/ 3881]
# Done. Time:3.838580082999897
# Start validation.
# Done. Time:0.32602518099997724
# Validation performance:
#  Avg loss:1.434531
#
# Start evaluation.
# Done. Time:0.894889682999974
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.307704 [    0/ 3881]
# loss:0.952067 [ 3200/ 3881]
# Done. Time:3.304900641999893
# Start validation.
# Done. Time:0.3121294659999876
# Validation performance:
#  Avg loss:1.427827
#
# Start evaluation.
# Done. Time:0.8869750260000728
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.298815 [    0/ 3881]
# loss:0.938632 [ 3200/ 3881]
# Done. Time:4.27276721699991
# Start validation.
# Done. Time:0.339293280999982
# Validation performance:
#  Avg loss:1.420571
#
# Start evaluation.
# Done. Time:0.9030986970001322
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.290712 [    0/ 3881]
# loss:0.925525 [ 3200/ 3881]
# Done. Time:3.3002439209999466
# Start validation.
# Done. Time:0.33364364199997
# Validation performance:
#  Avg loss:1.413641
#
# Start evaluation.
# Done. Time:0.9184993889998623
# Test performance:
#  Accuracy:63.5%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.283128 [    0/ 3881]
# loss:0.913842 [ 3200/ 3881]
# Done. Time:3.2558685539997896
# Start validation.
# Done. Time:0.3206614340001579
# Validation performance:
#  Avg loss:1.408541
#
# Start evaluation.
# Done. Time:1.0412268210000093
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:1.277198 [    0/ 3881]
# loss:0.907107 [ 3200/ 3881]
# Done. Time:4.0171211700001095
# Start validation.
# Done. Time:0.3122606070000984
# Validation performance:
#  Avg loss:1.402992
#
# Start evaluation.
# Done. Time:0.8548581939999167
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:1.269707 [    0/ 3881]
# loss:0.887286 [ 3200/ 3881]
# Done. Time:3.312360832999957
# Start validation.
# Done. Time:0.3320870489999379
# Validation performance:
#  Avg loss:1.393616
#
# Start evaluation.
# Done. Time:0.9196532350001689
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:1.263431 [    0/ 3881]
# loss:0.876726 [ 3200/ 3881]
# Done. Time:4.164287211999863
# Start validation.
# Done. Time:0.4290629160000208
# Validation performance:
#  Avg loss:1.386408
#
# Start evaluation.
# Done. Time:0.906727286999967
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:1.255128 [    0/ 3881]
# loss:0.864438 [ 3200/ 3881]
# Done. Time:3.2564140780000344
# Start validation.
# Done. Time:0.3264618569999129
# Validation performance:
#  Avg loss:1.378758
#
# Start evaluation.
# Done. Time:0.8872697550000339
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:1.247362 [    0/ 3881]
# loss:0.852227 [ 3200/ 3881]
# Done. Time:3.2545889729999544
# Start validation.
# Done. Time:0.32740360999991935
# Validation performance:
#  Avg loss:1.371200
#
# Start evaluation.
# Done. Time:0.8766775199999302
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:1.239288 [    0/ 3881]
# loss:0.841780 [ 3200/ 3881]
# Done. Time:4.234941076000041
# Start validation.
# Done. Time:0.3154119470000296
# Validation performance:
#  Avg loss:1.364019
#
# Start evaluation.
# Done. Time:0.8998556389999521
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:1.231000 [    0/ 3881]
# loss:0.831386 [ 3200/ 3881]
# Done. Time:3.2969631549999576
# Start validation.
# Done. Time:0.31079569500002435
# Validation performance:
#  Avg loss:1.356680
#
# Start evaluation.
# Done. Time:0.9130264049999823
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.221851 [    0/ 3881]
# loss:0.820574 [ 3200/ 3881]
# Done. Time:3.7967836399998305
# Start validation.
# Done. Time:0.5088582959999712
# Validation performance:
#  Avg loss:1.349482
#
# Start evaluation.
# Done. Time:1.0610122410000713
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:1.213976 [    0/ 3881]
# loss:0.811370 [ 3200/ 3881]
# Done. Time:3.263820624000118
# Start validation.
# Done. Time:0.30777493499999764
# Validation performance:
#  Avg loss:1.342398
#
# Start evaluation.
# Done. Time:0.9108069829999295
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:1.205363 [    0/ 3881]
# loss:0.802428 [ 3200/ 3881]
# Done. Time:3.256592605999913
# Start validation.
# Done. Time:0.3166190160000042
# Validation performance:
#  Avg loss:1.335680
#
# Start evaluation.
# Done. Time:0.9144970010001998
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:1.197707 [    0/ 3881]
# loss:0.794248 [ 3200/ 3881]
# Done. Time:4.229716699999926
# Start validation.
# Done. Time:0.330277937000119
# Validation performance:
#  Avg loss:1.328327
#
# Start evaluation.
# Done. Time:0.8940304650000144
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:1.189072 [    0/ 3881]
# loss:0.785610 [ 3200/ 3881]
# Done. Time:3.27485572400019
# Start validation.
# Done. Time:0.30758176199992704
# Validation performance:
#  Avg loss:1.321088
#
# Start evaluation.
# Done. Time:0.905106921999959
# Test performance:
#  Accuracy:67.5%
# Minimum validation loss:1.3210880671228682 at 50 epoch.
# Maximum accuracy:67.5 at 50 epoch.

# %% [markdown]
# ### Unique alignment and framewise scaling

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_align_scale_w))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_align_u_scale_f,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_align_u_scale_f,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_align_u_scale_f,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_align_u_scale_f = np.array(val_losses)
test_accs_align_u_scale_f = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_align_u_scale_f.min()} at {np.argmin(val_losses_align_u_scale_f)+1} epoch.")
print(f"Maximum accuracy:{test_accs_align_u_scale_f.max()} at {np.argmax(test_accs_align_u_scale_f)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.308775 [    0/ 3881]
# loss:2.057521 [ 3200/ 3881]
# Done. Time:3.295363130999931
# Start validation.
# Done. Time:0.3379978369998753
# Validation performance:
#  Avg loss:2.169266
#
# Start evaluation.
# Done. Time:0.9065494269998453
# Test performance:
#  Accuracy:28.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.140757 [    0/ 3881]
# loss:1.884111 [ 3200/ 3881]
# Done. Time:4.084749491999901
# Start validation.
# Done. Time:0.4757931629999348
# Validation performance:
#  Avg loss:2.107512
#
# Start evaluation.
# Done. Time:0.8916583140000967
# Test performance:
#  Accuracy:28.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:2.003964 [    0/ 3881]
# loss:1.740703 [ 3200/ 3881]
# Done. Time:3.264616839999917
# Start validation.
# Done. Time:0.3192830509999567
# Validation performance:
#  Avg loss:2.027392
#
# Start evaluation.
# Done. Time:0.8784691810001277
# Test performance:
#  Accuracy:37.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.907533 [    0/ 3881]
# loss:1.629752 [ 3200/ 3881]
# Done. Time:3.263501020000149
# Start validation.
# Done. Time:0.3261153389998981
# Validation performance:
#  Avg loss:1.991201
#
# Start evaluation.
# Done. Time:0.9103131550000398
# Test performance:
#  Accuracy:37.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.844679 [    0/ 3881]
# loss:1.557960 [ 3200/ 3881]
# Done. Time:4.273539247000144
# Start validation.
# Done. Time:0.32330429299986463
# Validation performance:
#  Avg loss:1.962575
#
# Start evaluation.
# Done. Time:1.2242123599999104
# Test performance:
#  Accuracy:38.0%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.806790 [    0/ 3881]
# loss:1.518037 [ 3200/ 3881]
# Done. Time:3.687217280000141
# Start validation.
# Done. Time:0.3258895440001197
# Validation performance:
#  Avg loss:1.942689
#
# Start evaluation.
# Done. Time:0.9151078690001668
# Test performance:
#  Accuracy:37.5%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.764040 [    0/ 3881]
# loss:1.481126 [ 3200/ 3881]
# Done. Time:4.297078644999829
# Start validation.
# Done. Time:0.29359529900011694
# Validation performance:
#  Avg loss:1.920587
#
# Start evaluation.
# Done. Time:0.9027233060000981
# Test performance:
#  Accuracy:38.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.725130 [    0/ 3881]
# loss:1.457340 [ 3200/ 3881]
# Done. Time:3.325557362000154
# Start validation.
# Done. Time:0.3293429330001345
# Validation performance:
#  Avg loss:1.899414
#
# Start evaluation.
# Done. Time:0.8799444749997747
# Test performance:
#  Accuracy:40.5%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.706468 [    0/ 3881]
# loss:1.435014 [ 3200/ 3881]
# Done. Time:3.2648281380002118
# Start validation.
# Done. Time:0.3052613949998886
# Validation performance:
#  Avg loss:1.890223
#
# Start evaluation.
# Done. Time:1.0336000779998358
# Test performance:
#  Accuracy:42.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.672149 [    0/ 3881]
# loss:1.410353 [ 3200/ 3881]
# Done. Time:3.9602566829998977
# Start validation.
# Done. Time:0.3296207950002099
# Validation performance:
#  Avg loss:1.870421
#
# Start evaluation.
# Done. Time:0.9192913580000095
# Test performance:
#  Accuracy:43.5%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.645314 [    0/ 3881]
# loss:1.391191 [ 3200/ 3881]
# Done. Time:3.300391956999647
# Start validation.
# Done. Time:0.32738555300011285
# Validation performance:
#  Avg loss:1.862412
#
# Start evaluation.
# Done. Time:0.9191235220000635
# Test performance:
#  Accuracy:43.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.606314 [    0/ 3881]
# loss:1.364367 [ 3200/ 3881]
# Done. Time:4.099421221000284
# Start validation.
# Done. Time:0.41631711800027915
# Validation performance:
#  Avg loss:1.841654
#
# Start evaluation.
# Done. Time:0.8899846240001352
# Test performance:
#  Accuracy:45.5%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.583782 [    0/ 3881]
# loss:1.349131 [ 3200/ 3881]
# Done. Time:3.33096020100038
# Start validation.
# Done. Time:0.3180249890001505
# Validation performance:
#  Avg loss:1.828809
#
# Start evaluation.
# Done. Time:0.8988483389998692
# Test performance:
#  Accuracy:46.0%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.559516 [    0/ 3881]
# loss:1.322851 [ 3200/ 3881]
# Done. Time:3.3050843519999944
# Start validation.
# Done. Time:0.315369181999813
# Validation performance:
#  Avg loss:1.820272
#
# Start evaluation.
# Done. Time:0.9540206679998846
# Test performance:
#  Accuracy:46.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:1.532993 [    0/ 3881]
# loss:1.306106 [ 3200/ 3881]
# Done. Time:4.175814873000036
# Start validation.
# Done. Time:0.3326132789998155
# Validation performance:
#  Avg loss:1.799993
#
# Start evaluation.
# Done. Time:0.9011955720002334
# Test performance:
#  Accuracy:47.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.509100 [    0/ 3881]
# loss:1.287146 [ 3200/ 3881]
# Done. Time:3.2669001369999933
# Start validation.
# Done. Time:0.32515193500012174
# Validation performance:
#  Avg loss:1.788757
#
# Start evaluation.
# Done. Time:0.8856865640000251
# Test performance:
#  Accuracy:48.0%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.486309 [    0/ 3881]
# loss:1.264303 [ 3200/ 3881]
# Done. Time:3.9569250469999133
# Start validation.
# Done. Time:0.48901473500018255
# Validation performance:
#  Avg loss:1.774306
#
# Start evaluation.
# Done. Time:0.9383465679998153
# Test performance:
#  Accuracy:49.0%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.468282 [    0/ 3881]
# loss:1.245952 [ 3200/ 3881]
# Done. Time:3.580081932000212
# Start validation.
# Done. Time:0.5166206049998436
# Validation performance:
#  Avg loss:1.761073
#
# Start evaluation.
# Done. Time:1.238066629000059
# Test performance:
#  Accuracy:49.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.449418 [    0/ 3881]
# loss:1.226542 [ 3200/ 3881]
# Done. Time:3.318491874999836
# Start validation.
# Done. Time:0.3500480449997667
# Validation performance:
#  Avg loss:1.749014
#
# Start evaluation.
# Done. Time:1.1923631059999025
# Test performance:
#  Accuracy:51.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.431869 [    0/ 3881]
# loss:1.209066 [ 3200/ 3881]
# Done. Time:3.708048565000354
# Start validation.
# Done. Time:0.33234278700001596
# Validation performance:
#  Avg loss:1.738684
#
# Start evaluation.
# Done. Time:0.9108294339998793
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.414010 [    0/ 3881]
# loss:1.191397 [ 3200/ 3881]
# Done. Time:3.3399397469997893
# Start validation.
# Done. Time:0.32105047899995043
# Validation performance:
#  Avg loss:1.729657
#
# Start evaluation.
# Done. Time:0.9014505630002532
# Test performance:
#  Accuracy:53.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.397205 [    0/ 3881]
# loss:1.174062 [ 3200/ 3881]
# Done. Time:4.273390589999963
# Start validation.
# Done. Time:0.33653341900026135
# Validation performance:
#  Avg loss:1.720256
#
# Start evaluation.
# Done. Time:0.9264672600002086
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.382994 [    0/ 3881]
# loss:1.157864 [ 3200/ 3881]
# Done. Time:3.3121738459999506
# Start validation.
# Done. Time:0.3001545840002109
# Validation performance:
#  Avg loss:1.711508
#
# Start evaluation.
# Done. Time:0.8915114370001902
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.368938 [    0/ 3881]
# loss:1.142273 [ 3200/ 3881]
# Done. Time:3.2742719359998773
# Start validation.
# Done. Time:0.3308098779998545
# Validation performance:
#  Avg loss:1.702710
#
# Start evaluation.
# Done. Time:1.1398834639999222
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.356069 [    0/ 3881]
# loss:1.126545 [ 3200/ 3881]
# Done. Time:3.9019060810001065
# Start validation.
# Done. Time:0.3160456699997667
# Validation performance:
#  Avg loss:1.694370
#
# Start evaluation.
# Done. Time:0.8834359859997676
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.342739 [    0/ 3881]
# loss:1.110950 [ 3200/ 3881]
# Done. Time:3.322891530999641
# Start validation.
# Done. Time:0.32777601500038145
# Validation performance:
#  Avg loss:1.685916
#
# Start evaluation.
# Done. Time:0.8885367560001214
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.329785 [    0/ 3881]
# loss:1.095957 [ 3200/ 3881]
# Done. Time:4.1302067770002395
# Start validation.
# Done. Time:0.36455156200008787
# Validation performance:
#  Avg loss:1.677659
#
# Start evaluation.
# Done. Time:0.902655545000016
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.317331 [    0/ 3881]
# loss:1.081941 [ 3200/ 3881]
# Done. Time:3.2902629889999844
# Start validation.
# Done. Time:0.31395459999976083
# Validation performance:
#  Avg loss:1.669279
#
# Start evaluation.
# Done. Time:0.9170995289996426
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:1.305434 [    0/ 3881]
# loss:1.068498 [ 3200/ 3881]
# Done. Time:3.27901139900041
# Start validation.
# Done. Time:0.32338172000027043
# Validation performance:
#  Avg loss:1.661343
#
# Start evaluation.
# Done. Time:0.9757708219999586
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.293981 [    0/ 3881]
# loss:1.055427 [ 3200/ 3881]
# Done. Time:4.119194208999943
# Start validation.
# Done. Time:0.30496489699999074
# Validation performance:
#  Avg loss:1.653330
#
# Start evaluation.
# Done. Time:0.9136913249999452
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:1.282730 [    0/ 3881]
# loss:1.042960 [ 3200/ 3881]
# Done. Time:3.284833556000194
# Start validation.
# Done. Time:0.2991695330001676
# Validation performance:
#  Avg loss:1.645432
#
# Start evaluation.
# Done. Time:0.8937618600002679
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.272041 [    0/ 3881]
# loss:1.031038 [ 3200/ 3881]
# Done. Time:4.046561899000153
# Start validation.
# Done. Time:0.5012872809998044
# Validation performance:
#  Avg loss:1.637593
#
# Start evaluation.
# Done. Time:0.9170171299997492
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:1.260856 [    0/ 3881]
# loss:1.019477 [ 3200/ 3881]
# Done. Time:3.3756262780002544
# Start validation.
# Done. Time:0.3214130119999936
# Validation performance:
#  Avg loss:1.629464
#
# Start evaluation.
# Done. Time:0.9242982920000031
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:1.250548 [    0/ 3881]
# loss:1.008046 [ 3200/ 3881]
# Done. Time:3.2205341409999164
# Start validation.
# Done. Time:0.33592300400005115
# Validation performance:
#  Avg loss:1.620248
#
# Start evaluation.
# Done. Time:0.9042424980002579
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.240126 [    0/ 3881]
# loss:0.997204 [ 3200/ 3881]
# Done. Time:4.202631429000121
# Start validation.
# Done. Time:0.32322017799970126
# Validation performance:
#  Avg loss:1.610493
#
# Start evaluation.
# Done. Time:0.8559268149997479
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.229567 [    0/ 3881]
# loss:0.985517 [ 3200/ 3881]
# Done. Time:3.284057657000176
# Start validation.
# Done. Time:0.31608325300021534
# Validation performance:
#  Avg loss:1.598581
#
# Start evaluation.
# Done. Time:0.8962152560002323
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.220311 [    0/ 3881]
# loss:0.974151 [ 3200/ 3881]
# Done. Time:3.8306367960003627
# Start validation.
# Done. Time:0.4952751570003784
# Validation performance:
#  Avg loss:1.586891
#
# Start evaluation.
# Done. Time:1.0095255659998656
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.211448 [    0/ 3881]
# loss:0.962710 [ 3200/ 3881]
# Done. Time:3.2975993299996844
# Start validation.
# Done. Time:0.3226840100001027
# Validation performance:
#  Avg loss:1.580328
#
# Start evaluation.
# Done. Time:0.9344309149996661
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:1.203163 [    0/ 3881]
# loss:0.951607 [ 3200/ 3881]
# Done. Time:3.287054317000184
# Start validation.
# Done. Time:0.3236849740001162
# Validation performance:
#  Avg loss:1.573700
#
# Start evaluation.
# Done. Time:0.9015003269996669
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:1.194996 [    0/ 3881]
# loss:0.940077 [ 3200/ 3881]
# Done. Time:4.278085227999782
# Start validation.
# Done. Time:0.30851158900031805
# Validation performance:
#  Avg loss:1.564806
#
# Start evaluation.
# Done. Time:0.8943119959999422
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:1.186795 [    0/ 3881]
# loss:0.928972 [ 3200/ 3881]
# Done. Time:3.3284024849999696
# Start validation.
# Done. Time:0.32369961099993816
# Validation performance:
#  Avg loss:1.555256
#
# Start evaluation.
# Done. Time:0.9116459599999871
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:1.178619 [    0/ 3881]
# loss:0.917941 [ 3200/ 3881]
# Done. Time:3.886760073000005
# Start validation.
# Done. Time:0.48845865799967214
# Validation performance:
#  Avg loss:1.546470
#
# Start evaluation.
# Done. Time:1.0192234539999845
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:1.170460 [    0/ 3881]
# loss:0.907061 [ 3200/ 3881]
# Done. Time:3.2881660400003057
# Start validation.
# Done. Time:0.31660410099993896
# Validation performance:
#  Avg loss:1.536904
#
# Start evaluation.
# Done. Time:0.8992236099998081
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:1.163215 [    0/ 3881]
# loss:0.896458 [ 3200/ 3881]
# Done. Time:3.290091088999816
# Start validation.
# Done. Time:0.3191412940000191
# Validation performance:
#  Avg loss:1.529931
#
# Start evaluation.
# Done. Time:0.9352872470003604
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:1.156312 [    0/ 3881]
# loss:0.886293 [ 3200/ 3881]
# Done. Time:5.465898036999988
# Start validation.
# Done. Time:0.3501325120000729
# Validation performance:
#  Avg loss:1.523570
#
# Start evaluation.
# Done. Time:0.9151780810002492
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.148332 [    0/ 3881]
# loss:0.876126 [ 3200/ 3881]
# Done. Time:4.280527572999745
# Start validation.
# Done. Time:0.30076099999996586
# Validation performance:
#  Avg loss:1.516950
#
# Start evaluation.
# Done. Time:0.9002972050002427
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:1.139344 [    0/ 3881]
# loss:0.867286 [ 3200/ 3881]
# Done. Time:3.7410595860001195
# Start validation.
# Done. Time:0.5043206880000071
# Validation performance:
#  Avg loss:1.510521
#
# Start evaluation.
# Done. Time:1.0451783579997027
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:1.130604 [    0/ 3881]
# loss:0.858071 [ 3200/ 3881]
# Done. Time:3.32326415200032
# Start validation.
# Done. Time:0.3364520669997546
# Validation performance:
#  Avg loss:1.504506
#
# Start evaluation.
# Done. Time:0.9047800430003008
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:1.121899 [    0/ 3881]
# loss:0.849303 [ 3200/ 3881]
# Done. Time:3.3234339259997796
# Start validation.
# Done. Time:0.31393052900011753
# Validation performance:
#  Avg loss:1.499099
#
# Start evaluation.
# Done. Time:0.9254908920001981
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:1.113887 [    0/ 3881]
# loss:0.840390 [ 3200/ 3881]
# Done. Time:4.2853886999996575
# Start validation.
# Done. Time:0.3485310269998081
# Validation performance:
#  Avg loss:1.494217
#
# Start evaluation.
# Done. Time:0.9076079120000031
# Test performance:
#  Accuracy:66.0%
# Minimum validation loss:1.4942170551845007 at 50 epoch.
# Maximum accuracy:66.0 at 50 epoch.

# %% [markdown]
# ### Unique alignment and unique scaling

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
out_channels = VOCAB

model = SimpleISLR(in_channels, out_channels)
print(model)

# Sanity check.
logit = model(torch.from_numpy(feature_align_scale_w))
print(logit.shape)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# SimpleISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms_align_u_scale_u,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms_align_u_scale_u,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms_align_u_scale_u,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers)

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_align_u_scale_u = np.array(val_losses)
test_accs_align_u_scale_u = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_align_u_scale_u.min()} at {np.argmin(val_losses_align_u_scale_u)+1} epoch.")
print(f"Maximum accuracy:{test_accs_align_u_scale_u.max()} at {np.argmax(test_accs_align_u_scale_u)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.356804 [    0/ 3881]
# loss:2.133924 [ 3200/ 3881]
# Done. Time:3.621455201000117
# Start validation.
# Done. Time:0.3315764889998718
# Validation performance:
#  Avg loss:2.186662
#
# Start evaluation.
# Done. Time:0.9126656960002038
# Test performance:
#  Accuracy:25.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.161606 [    0/ 3881]
# loss:1.973583 [ 3200/ 3881]
# Done. Time:3.2558218089998263
# Start validation.
# Done. Time:0.3277916510000978
# Validation performance:
#  Avg loss:2.080949
#
# Start evaluation.
# Done. Time:0.8904122870003448
# Test performance:
#  Accuracy:32.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:2.037266 [    0/ 3881]
# loss:1.816467 [ 3200/ 3881]
# Done. Time:4.244625337999878
# Start validation.
# Done. Time:0.34323743699997067
# Validation performance:
#  Avg loss:2.009231
#
# Start evaluation.
# Done. Time:0.9001596220000465
# Test performance:
#  Accuracy:37.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.982023 [    0/ 3881]
# loss:1.679941 [ 3200/ 3881]
# Done. Time:3.2672707450001326
# Start validation.
# Done. Time:0.3034171510003034
# Validation performance:
#  Avg loss:1.961525
#
# Start evaluation.
# Done. Time:0.9206006229997001
# Test performance:
#  Accuracy:40.5%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.950414 [    0/ 3881]
# loss:1.599067 [ 3200/ 3881]
# Done. Time:3.2980501899996852
# Start validation.
# Done. Time:0.3228728260000935
# Validation performance:
#  Avg loss:1.928378
#
# Start evaluation.
# Done. Time:1.0960833730000559
# Test performance:
#  Accuracy:41.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.907602 [    0/ 3881]
# loss:1.545781 [ 3200/ 3881]
# Done. Time:5.227876192000167
# Start validation.
# Done. Time:0.3360405339999488
# Validation performance:
#  Avg loss:1.908453
#
# Start evaluation.
# Done. Time:0.9420912160003354
# Test performance:
#  Accuracy:40.5%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.860408 [    0/ 3881]
# loss:1.504757 [ 3200/ 3881]
# Done. Time:3.2603459629999634
# Start validation.
# Done. Time:0.31958192499996585
# Validation performance:
#  Avg loss:1.889369
#
# Start evaluation.
# Done. Time:0.912062160000005
# Test performance:
#  Accuracy:44.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.815048 [    0/ 3881]
# loss:1.466063 [ 3200/ 3881]
# Done. Time:4.227794067999639
# Start validation.
# Done. Time:0.3249314750000849
# Validation performance:
#  Avg loss:1.877368
#
# Start evaluation.
# Done. Time:0.9108807989996421
# Test performance:
#  Accuracy:44.5%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.772750 [    0/ 3881]
# loss:1.432020 [ 3200/ 3881]
# Done. Time:3.287912781000159
# Start validation.
# Done. Time:0.3256392919997779
# Validation performance:
#  Avg loss:1.868079
#
# Start evaluation.
# Done. Time:0.913516085000083
# Test performance:
#  Accuracy:45.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.732147 [    0/ 3881]
# loss:1.401352 [ 3200/ 3881]
# Done. Time:3.5241603399999804
# Start validation.
# Done. Time:0.526969906999966
# Validation performance:
#  Avg loss:1.860273
#
# Start evaluation.
# Done. Time:1.2407157819998247
# Test performance:
#  Accuracy:46.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.698509 [    0/ 3881]
# loss:1.370098 [ 3200/ 3881]
# Done. Time:3.315473129000111
# Start validation.
# Done. Time:0.33447332400010055
# Validation performance:
#  Avg loss:1.853161
#
# Start evaluation.
# Done. Time:0.9381969930000196
# Test performance:
#  Accuracy:46.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.658953 [    0/ 3881]
# loss:1.348029 [ 3200/ 3881]
# Done. Time:3.308264920000056
# Start validation.
# Done. Time:0.3326525649999894
# Validation performance:
#  Avg loss:1.844289
#
# Start evaluation.
# Done. Time:0.9062103349997415
# Test performance:
#  Accuracy:47.5%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.626155 [    0/ 3881]
# loss:1.324101 [ 3200/ 3881]
# Done. Time:4.260642366999946
# Start validation.
# Done. Time:0.33807949599986387
# Validation performance:
#  Avg loss:1.832587
#
# Start evaluation.
# Done. Time:0.926647819000209
# Test performance:
#  Accuracy:47.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.600952 [    0/ 3881]
# loss:1.302366 [ 3200/ 3881]
# Done. Time:3.281800769000256
# Start validation.
# Done. Time:0.32925511100029325
# Validation performance:
#  Avg loss:1.830006
#
# Start evaluation.
# Done. Time:0.9047435170000426
# Test performance:
#  Accuracy:49.0%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:1.584784 [    0/ 3881]
# loss:1.271691 [ 3200/ 3881]
# Done. Time:3.6219191129998762
# Start validation.
# Done. Time:0.5115813349998461
# Validation performance:
#  Avg loss:1.810343
#
# Start evaluation.
# Done. Time:1.2158206330000212
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.551642 [    0/ 3881]
# loss:1.247044 [ 3200/ 3881]
# Done. Time:3.2923703569999816
# Start validation.
# Done. Time:0.32201140699999087
# Validation performance:
#  Avg loss:1.792919
#
# Start evaluation.
# Done. Time:0.9363134720001653
# Test performance:
#  Accuracy:49.0%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.531854 [    0/ 3881]
# loss:1.221004 [ 3200/ 3881]
# Done. Time:3.357042024999828
# Start validation.
# Done. Time:0.3207820239999819
# Validation performance:
#  Avg loss:1.778448
#
# Start evaluation.
# Done. Time:0.9061811139999918
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.511954 [    0/ 3881]
# loss:1.195783 [ 3200/ 3881]
# Done. Time:4.272359185999903
# Start validation.
# Done. Time:0.33317551200025264
# Validation performance:
#  Avg loss:1.771170
#
# Start evaluation.
# Done. Time:0.9575277589997313
# Test performance:
#  Accuracy:53.0%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.492260 [    0/ 3881]
# loss:1.176263 [ 3200/ 3881]
# Done. Time:3.3113304549997338
# Start validation.
# Done. Time:0.3189327370000683
# Validation performance:
#  Avg loss:1.749589
#
# Start evaluation.
# Done. Time:0.9008716540001842
# Test performance:
#  Accuracy:50.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.474175 [    0/ 3881]
# loss:1.152647 [ 3200/ 3881]
# Done. Time:3.656350925999959
# Start validation.
# Done. Time:0.529990923999776
# Validation performance:
#  Avg loss:1.735861
#
# Start evaluation.
# Done. Time:1.1299242820000472
# Test performance:
#  Accuracy:51.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.458463 [    0/ 3881]
# loss:1.138345 [ 3200/ 3881]
# Done. Time:3.2858927889997176
# Start validation.
# Done. Time:0.32690609900009804
# Validation performance:
#  Avg loss:1.711522
#
# Start evaluation.
# Done. Time:0.9018931350001367
# Test performance:
#  Accuracy:51.5%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.447157 [    0/ 3881]
# loss:1.112188 [ 3200/ 3881]
# Done. Time:3.2710334660000626
# Start validation.
# Done. Time:0.3007588999998916
# Validation performance:
#  Avg loss:1.703739
#
# Start evaluation.
# Done. Time:0.9249602380000397
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.434681 [    0/ 3881]
# loss:1.093546 [ 3200/ 3881]
# Done. Time:4.279151997000099
# Start validation.
# Done. Time:0.3322217410000121
# Validation performance:
#  Avg loss:1.694930
#
# Start evaluation.
# Done. Time:0.9128874289999658
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.418031 [    0/ 3881]
# loss:1.078114 [ 3200/ 3881]
# Done. Time:3.286247775999982
# Start validation.
# Done. Time:0.32602119900002435
# Validation performance:
#  Avg loss:1.681683
#
# Start evaluation.
# Done. Time:0.9291443980000622
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.401777 [    0/ 3881]
# loss:1.062081 [ 3200/ 3881]
# Done. Time:3.5544927930000085
# Start validation.
# Done. Time:0.46097780999980387
# Validation performance:
#  Avg loss:1.666741
#
# Start evaluation.
# Done. Time:1.187002307000057
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.389247 [    0/ 3881]
# loss:1.046146 [ 3200/ 3881]
# Done. Time:3.298863314999835
# Start validation.
# Done. Time:0.32919973699972616
# Validation performance:
#  Avg loss:1.651216
#
# Start evaluation.
# Done. Time:0.9098758599998291
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.376789 [    0/ 3881]
# loss:1.029514 [ 3200/ 3881]
# Done. Time:3.285063451000042
# Start validation.
# Done. Time:0.346618651999961
# Validation performance:
#  Avg loss:1.636395
#
# Start evaluation.
# Done. Time:0.9126341709998087
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.364265 [    0/ 3881]
# loss:1.014111 [ 3200/ 3881]
# Done. Time:4.2703657060001206
# Start validation.
# Done. Time:0.31802069000013944
# Validation performance:
#  Avg loss:1.622222
#
# Start evaluation.
# Done. Time:0.9450595200000862
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:1.352357 [    0/ 3881]
# loss:0.998808 [ 3200/ 3881]
# Done. Time:3.313026139000158
# Start validation.
# Done. Time:0.32342358799996873
# Validation performance:
#  Avg loss:1.607905
#
# Start evaluation.
# Done. Time:0.8954420850000133
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.340750 [    0/ 3881]
# loss:0.984795 [ 3200/ 3881]
# Done. Time:3.361650001000271
# Start validation.
# Done. Time:0.5081668209995769
# Validation performance:
#  Avg loss:1.595458
#
# Start evaluation.
# Done. Time:1.2594870069997341
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:1.328302 [    0/ 3881]
# loss:0.970755 [ 3200/ 3881]
# Done. Time:3.3134153579999293
# Start validation.
# Done. Time:0.3478292619997774
# Validation performance:
#  Avg loss:1.581224
#
# Start evaluation.
# Done. Time:0.8962505039999087
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.318280 [    0/ 3881]
# loss:0.956650 [ 3200/ 3881]
# Done. Time:3.2941295380001065
# Start validation.
# Done. Time:0.31850153400000636
# Validation performance:
#  Avg loss:1.567324
#
# Start evaluation.
# Done. Time:0.9027725649998501
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:1.308337 [    0/ 3881]
# loss:0.941221 [ 3200/ 3881]
# Done. Time:4.2360176520001005
# Start validation.
# Done. Time:0.8079790829997364
# Validation performance:
#  Avg loss:1.553677
#
# Start evaluation.
# Done. Time:1.430644408000262
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:1.299388 [    0/ 3881]
# loss:0.929635 [ 3200/ 3881]
# Done. Time:6.308158091000223
# Start validation.
# Done. Time:0.9490039970000907
# Validation performance:
#  Avg loss:1.541779
#
# Start evaluation.
# Done. Time:1.7825635639997017
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.288256 [    0/ 3881]
# loss:0.916021 [ 3200/ 3881]
# Done. Time:5.560500693999984
# Start validation.
# Done. Time:0.3537425539998367
# Validation performance:
#  Avg loss:1.528794
#
# Start evaluation.
# Done. Time:0.9260702480000873
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.279935 [    0/ 3881]
# loss:0.902736 [ 3200/ 3881]
# Done. Time:3.378362900999946
# Start validation.
# Done. Time:0.33512914700031615
# Validation performance:
#  Avg loss:1.517236
#
# Start evaluation.
# Done. Time:0.9176258580000649
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.272289 [    0/ 3881]
# loss:0.890423 [ 3200/ 3881]
# Done. Time:4.304437663000044
# Start validation.
# Done. Time:0.3411878809997688
# Validation performance:
#  Avg loss:1.507100
#
# Start evaluation.
# Done. Time:0.9143615910002154
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.264555 [    0/ 3881]
# loss:0.878990 [ 3200/ 3881]
# Done. Time:3.2363144179998926
# Start validation.
# Done. Time:0.31671295599971927
# Validation performance:
#  Avg loss:1.495900
#
# Start evaluation.
# Done. Time:0.888995709000028
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:1.257771 [    0/ 3881]
# loss:0.867263 [ 3200/ 3881]
# Done. Time:5.216158797999924
# Start validation.
# Done. Time:0.5163190049997866
# Validation performance:
#  Avg loss:1.486654
#
# Start evaluation.
# Done. Time:0.9566649880002842
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:1.250527 [    0/ 3881]
# loss:0.856776 [ 3200/ 3881]
# Done. Time:3.3312736630000472
# Start validation.
# Done. Time:0.3302689160000227
# Validation performance:
#  Avg loss:1.477987
#
# Start evaluation.
# Done. Time:0.9258260019996669
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:1.242863 [    0/ 3881]
# loss:0.846532 [ 3200/ 3881]
# Done. Time:3.2903031430000738
# Start validation.
# Done. Time:0.3288861089999955
# Validation performance:
#  Avg loss:1.469309
#
# Start evaluation.
# Done. Time:0.9594455370001924
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:1.235748 [    0/ 3881]
# loss:0.836376 [ 3200/ 3881]
# Done. Time:4.16810760899989
# Start validation.
# Done. Time:0.3272262479999881
# Validation performance:
#  Avg loss:1.461604
#
# Start evaluation.
# Done. Time:0.9152081610000096
# Test performance:
#  Accuracy:63.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:1.228124 [    0/ 3881]
# loss:0.826358 [ 3200/ 3881]
# Done. Time:3.286401771000328
# Start validation.
# Done. Time:0.31253361200015206
# Validation performance:
#  Avg loss:1.453114
#
# Start evaluation.
# Done. Time:0.9046069000000898
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:1.221442 [    0/ 3881]
# loss:0.816528 [ 3200/ 3881]
# Done. Time:3.894608051999967
# Start validation.
# Done. Time:0.4840078319998611
# Validation performance:
#  Avg loss:1.444468
#
# Start evaluation.
# Done. Time:1.1542158010001913
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:1.216586 [    0/ 3881]
# loss:0.806748 [ 3200/ 3881]
# Done. Time:4.030554686999949
# Start validation.
# Done. Time:0.3416975380000622
# Validation performance:
#  Avg loss:1.436486
#
# Start evaluation.
# Done. Time:0.9020115260000239
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.211026 [    0/ 3881]
# loss:0.796968 [ 3200/ 3881]
# Done. Time:3.297303607000231
# Start validation.
# Done. Time:0.3376033969998389
# Validation performance:
#  Avg loss:1.428626
#
# Start evaluation.
# Done. Time:1.177993233000052
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:1.204639 [    0/ 3881]
# loss:0.787708 [ 3200/ 3881]
# Done. Time:3.777214490999995
# Start validation.
# Done. Time:0.3609165440002471
# Validation performance:
#  Avg loss:1.420987
#
# Start evaluation.
# Done. Time:0.9429506159999619
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:1.198044 [    0/ 3881]
# loss:0.779009 [ 3200/ 3881]
# Done. Time:3.281792962000054
# Start validation.
# Done. Time:0.3170974119998391
# Validation performance:
#  Avg loss:1.413249
#
# Start evaluation.
# Done. Time:0.924095060000127
# Test performance:
#  Accuracy:65.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:1.191290 [    0/ 3881]
# loss:0.770063 [ 3200/ 3881]
# Done. Time:4.2928443570003765
# Start validation.
# Done. Time:0.3376773999998477
# Validation performance:
#  Avg loss:1.405563
#
# Start evaluation.
# Done. Time:0.895103699000174
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:1.184193 [    0/ 3881]
# loss:0.761253 [ 3200/ 3881]
# Done. Time:3.2842807750002976
# Start validation.
# Done. Time:0.33401022899988675
# Validation performance:
#  Avg loss:1.398150
#
# Start evaluation.
# Done. Time:0.9196161909999319
# Test performance:
#  Accuracy:66.5%
# Minimum validation loss:1.3981502567018782 at 50 epoch.
# Maximum accuracy:66.5 at 50 epoch.

# %% [markdown]
# ### Plot

# %%
import matplotlib.pyplot as plt

plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(val_losses_origin)+1)
plt.plot(xs, val_losses_align_f_scale_f, label="Align_F-Scale_F", marker=".")
plt.plot(xs, val_losses_align_f_scale_u, label="Align_F-Scale_U", marker=".")
plt.plot(xs, val_losses_align_u_scale_f, label="Align_U-Scale_F", marker=".")
plt.plot(xs, val_losses_align_u_scale_u, label="Align_U-Scale_U", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Validation loss")
plt.legend()
plt.show()

# %%
plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(test_accs)+1)
ys = test_accs
plt.plot(xs, test_accs_align_f_scale_f, label="Align_F-Scale_F", marker=".")
plt.plot(xs, test_accs_align_f_scale_u, label="Align_F-Scale_U", marker=".")
plt.plot(xs, test_accs_align_u_scale_f, label="Align_U-Scale_F", marker=".")
plt.plot(xs, test_accs_align_u_scale_u, label="Align_U-Scale_U", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
