# %% [markdown]
# <a href="https://colab.research.google.com/github/takayama-rado/trado_samples/blob/main/colab_files/gislr_macaronnet_encoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Download dataset and modules

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Copy to local.
# !cp drive/MyDrive/Datasets/gislr_dataset_top10.zip gislr_top10.zip

# %%
# !unzip -o gislr_top10.zip
# Out:
# Archive:  gislr_top10.zip
#    creating: dataset_top10/
#   inflating: dataset_top10/16069.hdf5
#   inflating: dataset_top10/18796.hdf5
#   inflating: dataset_top10/2044.hdf5
#   inflating: dataset_top10/22343.hdf5
#   inflating: dataset_top10/25571.hdf5
#   inflating: dataset_top10/26734.hdf5
#   inflating: dataset_top10/27610.hdf5
#   inflating: dataset_top10/28656.hdf5
#   inflating: dataset_top10/29302.hdf5
#   inflating: dataset_top10/30680.hdf5
#   inflating: dataset_top10/32319.hdf5
#   inflating: dataset_top10/34503.hdf5
#   inflating: dataset_top10/36257.hdf5
#   inflating: dataset_top10/37055.hdf5
#   inflating: dataset_top10/37779.hdf5
#   inflating: dataset_top10/4718.hdf5
#   inflating: dataset_top10/49445.hdf5
#   inflating: dataset_top10/53618.hdf5
#   inflating: dataset_top10/55372.hdf5
#   inflating: dataset_top10/61333.hdf5
#   inflating: dataset_top10/62590.hdf5
#   inflating: dataset_top10/LICENSE.txt
#   inflating: dataset_top10/sign_to_prediction_index_map.json

# %%
# !ls dataset_top10
# Out:
# 16069.hdf5  25571.hdf5	29302.hdf5  36257.hdf5	49445.hdf5  62590.hdf5
# 18796.hdf5  26734.hdf5	30680.hdf5  37055.hdf5	53618.hdf5  LICENSE.txt
# 2044.hdf5   27610.hdf5	32319.hdf5  37779.hdf5	55372.hdf5  sign_to_prediction_index_map.json
# 22343.hdf5  28656.hdf5	34503.hdf5  4718.hdf5	61333.hdf5

# %%
# !cat dataset_top10/sign_to_prediction_index_map.json
# Out:
# {
#     "listen": 0,
#     "look": 1,
#     "shhh": 2,
#     "donkey": 3,
#     "mouse": 4,
#     "duck": 5,
#     "uncle": 6,
#     "hear": 7,
#     "pretend": 8,
#     "cow": 9
# }

# %%
# !cat dataset_top10/LICENSE.txt
# Out:
# The dataset provided by Natsuki Takayama (Takayama Research and Development Office) is licensed under CC-BY 4.0.
# Author: Copyright 2024 Natsuki Takayama
# Title: GISLR Top 10 dataset
# Original licenser: Deaf Professional Arts Network and the Georgia Institute of Technology
# Modification
# - Extract 10 most frequent words.
# - Packaged into HDF5 format.

# %%
import h5py
with h5py.File("dataset_top10/16069.hdf5", "r") as fread:
    keys = list(fread.keys())
    print(keys)
    group = fread[keys[0]]
    print(group.keys())
    feature = group["feature"][:]
    token = group["token"][:]
    print(feature.shape)
    print(token)
# Out:
# ['1109479272', '11121526', '1120349077', '1125456612', '1159046211', '1169128497', '1186032553', '1223803476', '1259708636', '1281972067', '129232566', '1334702305', '1340979012', '1352964057', '1370052047', '1383455381', '1431148933', '1435203624', '1437919781', '1458770030', '1462881097', '1469867050', '1474050058', '147607644', '1513539919', '1520635928', '1524297234', '153676122', '1537751003', '1542212461', '1551759770', '158232956', '1585855916', '1632709119', '1638742455', '1696757219', '177479476', '1779635114', '1791684792', '1801566440', '1831167282', '1867385690', '1880570146', '1901587887', '1910121429', '1919659282', '192873038', '1935012113', '1949620203', '195098847', '1983552660', '1989475963', '1998715062', '2007709802', '2036010239', '2036360025', '2046296211', '2082116372', '2098813002', '2109640010', '2121879330', '2141852087', '2148832702', '2152013823', '2166805079', '2176613834', '2184232774', '2213965523', '2249630763', '2256677805', '2263287955', '2263683020', '2264826605', '2270117351', '2281372282', '2285328250', '2322449232', '2326092712', '2336131857', '2346410171', '2405684784', '2467219838', '2473091535', '2488751095', '2515673021', '252176572', '2555449229', '2601816518', '2624310025', '2672738462', '2679264929', '2708514724', '2708544445', '2721276879', '2723773273', '2728839865', '2740241949', '2758304792', '2772051790', '2779816680', '2804441762', '2811346655', '2811646800', '2820103955', '2839681895', '2900998385', '2976200180', '2994456336', '3057994128', '3095010437', '3104317075', '3109672704', '3137179145', '3153285641', '3173321541', '3181666887', '3201889607', '3208820205', '3248401349', '3280527321', '3283246198', '3300057240', '3355963469', '3378306304', '3383637897', '3395075403', '3399503065', '3417877266', '3433092803', '347484677', '348956807', '3490841593', '3509324997', '3527069516', '3537611572', '3543711249', '3550826234', '3574700791', '3577812263', '3608551465', '3609537739', '3622960580', '3666781780', '3701422761', '3721927307', '3751410902', '3756613238', '3769544385', '3783554953', '3794712078', '380369091', '3813230821', '3817572483', '3843929707', '3869664504', '3892179393', '3923913515', '3981562204', '4078929101', '4101587978', '4150900444', '4191136837', '4200829752', '4209136328', '420958416', '422113773', '42222766', '4233346443', '4233985575', '4236057556', '4252161228', '425542996', '4276854486', '4294775577', '431609031', '439844759', '446236576', '470582324', '472128010', '492897929', '537402693', '5501547', '561170018', '593416697', '631898947', '649410423', '654529993', '678960043', '699907539', '707716966', '713615518', '778875120', '792981518', '796465415', '798649922', '856068671', '923153024', '957739544', '970593849', '976754415']
# <KeysViewHDF5 ['feature', 'token']>
# (3, 23, 543)
# [1]

# %%
# !wget https://github.com/takayama-rado/trado_samples/archive/refs/tags/v0.2.zip -O master.zip
# Out:
# --2024-08-15 02:45:40--  https://github.com/takayama-rado/trado_samples/archive/refs/tags/v0.2.zip
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/takayama-rado/trado_samples/zip/refs/tags/v0.2 [following]
# --2024-08-15 02:45:41--  https://codeload.github.com/takayama-rado/trado_samples/zip/refs/tags/v0.2
# Resolving codeload.github.com (codeload.github.com)... 20.205.243.165
# Connecting to codeload.github.com (codeload.github.com)|20.205.243.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [        <=>         ]  76.21M  14.9MB/s    in 5.9s
#
# 2024-08-15 02:45:47 (12.8 MB/s) - ‘master.zip’ saved [79912224]

# %%
# !unzip -o master.zip -d master
# Out:
# Archive:  master.zip
# 4907710e233440b5197bbae5462c3e135f8f8711
#    creating: master/trado_samples-0.2/
#   inflating: master/trado_samples-0.2/.gitignore
#   inflating: master/trado_samples-0.2/LICENSE
#   inflating: master/trado_samples-0.2/README.md
#    creating: master/trado_samples-0.2/colab_files/
#  extracting: master/trado_samples-0.2/colab_files/.gitkeep
#   inflating: master/trado_samples-0.2/colab_files/exp_affine_np_einsum.ipynb
#   inflating: master/trado_samples-0.2/colab_files/exp_jax_static.ipynb
#   inflating: master/trado_samples-0.2/colab_files/exp_mpholistic_0.ipynb
#   inflating: master/trado_samples-0.2/colab_files/exp_mpothers_0.ipynb
#   inflating: master/trado_samples-0.2/colab_files/exp_track_affine_jax.ipynb
#   inflating: master/trado_samples-0.2/colab_files/exp_track_affine_numpy.ipynb
#   inflating: master/trado_samples-0.2/colab_files/exp_track_affine_tensorflow.ipynb
#   inflating: master/trado_samples-0.2/colab_files/exp_track_affine_torch.ipynb
#   inflating: master/trado_samples-0.2/colab_files/exp_track_interp_jax.ipynb
#   inflating: master/trado_samples-0.2/colab_files/exp_track_interp_numpy_0.ipynb
#   inflating: master/trado_samples-0.2/colab_files/exp_track_interp_numpy_1.ipynb
#   inflating: master/trado_samples-0.2/colab_files/exp_track_interp_tensorflow.ipynb
#   inflating: master/trado_samples-0.2/colab_files/exp_track_interp_torch.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_access_dataset.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_create_dataset.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_normalize_landmarks.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_rnn_islr_model_1.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_rnn_islr_model_2.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_rnn_islr_model_3.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_select_landmarks.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_simple_attention.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_simple_islr_model.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_transformer_encoder.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_transformer_encoder_daug_drop.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_transformer_encoder_daug_hflip.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_transformer_encoder_daug_resize.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_transformer_encoder_daug_saffine.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_transformer_encoder_daug_snoise.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_transformer_encoder_daug_tclip.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_transformer_encoder_daug_tinterp.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_transformer_encoder_daug_twarping.ipynb
#   inflating: master/trado_samples-0.2/colab_files/gislr_transformer_encoder_w_ls.ipynb
#    creating: master/trado_samples-0.2/src/
#    creating: master/trado_samples-0.2/src/modules_gislr/
#  extracting: master/trado_samples-0.2/src/modules_gislr/__init__.py
#   inflating: master/trado_samples-0.2/src/modules_gislr/activation.py
#   inflating: master/trado_samples-0.2/src/modules_gislr/dataset.py
#   inflating: master/trado_samples-0.2/src/modules_gislr/defines.py
#   inflating: master/trado_samples-0.2/src/modules_gislr/draw_functions.py
#   inflating: master/trado_samples-0.2/src/modules_gislr/layers.py
#   inflating: master/trado_samples-0.2/src/modules_gislr/train_functions.py
#   inflating: master/trado_samples-0.2/src/modules_gislr/transforms.py
#   inflating: master/trado_samples-0.2/src/modules_gislr/utils.py
#    creating: master/trado_samples-0.2/test_data/
#   inflating: master/trado_samples-0.2/test_data/finger_far0.mp4
#   inflating: master/trado_samples-0.2/test_data/finger_far0_non_static.npy
#   inflating: master/trado_samples-0.2/test_data/finger_far0_non_static_affine.npy
#   inflating: master/trado_samples-0.2/test_data/finger_far0_non_static_interp.npy
#   inflating: master/trado_samples-0.2/test_data/finger_middle0.mp4
#   inflating: master/trado_samples-0.2/test_data/finger_near0.mp4
#   inflating: master/trado_samples-0.2/test_data/hand_only.mp4

# %%
# !mv master/trado_samples-0.2/src/modules_gislr .

# %%
# !rm -rf master master.zip gislr_top10.zip

# %%
# !ls
# Out:
# dataset_top10  drive  modules_gislr  sample_data

# %% [markdown]
# # 2. Load library

# %%
import copy
import json
import os
import sys
from functools import partial
from inspect import signature
from pathlib import Path

# Third party's modules
import numpy as np

import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import (
    DataLoader)

from torchvision.transforms import Compose

# Local modules
sys.path.append("modules_gislr")
from modules_gislr.dataset import (
    HDF5Dataset,
    merge_padded_batch)
from modules_gislr.defines import (
    get_fullbody_landmarks
)
from modules_gislr.layers import (
    Identity,
    GPoolRecognitionHead,
    PositionalEncoding,
    MultiheadAttention,
    PositionwiseFeedForward,
    TransformerEncoderLayer,
    TransformerEnISLR
)
from modules_gislr.train_functions import (
    test_loop,
    val_loop,
    train_loop
)
from modules_gislr.transforms import (
    PartsBasedNormalization,
    ReplaceNan,
    SelectLandmarksAndFeature,
    ToTensor
)
from modules_gislr.utils import (
    make_causal_mask,
    make_san_mask,
    select_reluwise_activation
)

# %% [markdown]
# # 3. Implement Transformer ISLR model (Encoder only)

# %% [markdown]
# ### Utility functions

# %%
def create_norm(norm_type, dim_model, eps=1e-5, add_bias=None):
    # The argument `bias` was added at v2.1.0.
    # So, we check whether LayerNorm has this.
    sig = signature(nn.LayerNorm)
    available_bias = bool("bias" in sig.parameters)
    if norm_type == "layer":
        if available_bias:
            norm = nn.LayerNorm(dim_model, eps=eps, bias=add_bias)
        else:
            norm = nn.LayerNorm(dim_model, eps=eps)
    elif norm_type == "batch":
        norm = nn.BatchNorm1d(dim_model, eps=eps)
    return norm


def apply_norm(norm_layer, feature):
    # `[N, T, C]`
    if isinstance(norm_layer, nn.LayerNorm):
        feature = norm_layer(feature)
    elif isinstance(norm_layer, nn.BatchNorm1d):
        # `[N, T, C] -> [N, C, T]`
        feature = feature.permute([0, 2, 1])
        feature = norm_layer(feature)
        # `[N, C, T] -> [N, T, C]`
        feature = feature.permute([0, 2, 1])
    return feature

# %% [markdown]
# ### MacaronNet encoder layer

# %%
class MacaronNetEncoderLayer(nn.Module):
    def __init__(self,
                 dim_model,
                 num_heads,
                 dim_ffw,
                 dropout,
                 activation,
                 norm_type_sattn,
                 norm_type_ffw,
                 norm_eps,
                 add_bias):
        super().__init__()

        self.fc_factor = 0.5

        # =====================================================================
        # First half PFFN.
        # =====================================================================
        self.norm_ffw1 = create_norm(norm_type_ffw, dim_model, norm_eps, add_bias)
        self.ffw1 = PositionwiseFeedForward(
            dim_model=dim_model,
            dim_ffw=dim_ffw,
            dropout=dropout,
            activation=activation,
            add_bias=add_bias)
        # =====================================================================
        # MHA.
        # =====================================================================
        self.norm_sattn = create_norm(norm_type_sattn, dim_model, norm_eps, add_bias)
        self.self_attn = MultiheadAttention(
            key_dim=dim_model,
            query_dim=dim_model,
            att_dim=dim_model,
            out_dim=dim_model,
            num_heads=num_heads,
            dropout=dropout,
            add_bias=add_bias)
        # =====================================================================
        # Second half PFFN.
        # =====================================================================
        self.norm_ffw2 = create_norm(norm_type_ffw, dim_model, norm_eps, add_bias)
        self.ffw2 = PositionwiseFeedForward(
            dim_model=dim_model,
            dim_ffw=dim_ffw,
            dropout=dropout,
            activation=activation,
            add_bias=add_bias)

        self.dropout = nn.Dropout(p=dropout)

        # To store attention weights.
        self.attw = None

    def forward(self,
                feature,
                causal_mask=None,
                src_key_padding_mask=None):
        bsize, qlen = feature.shape[:2]
        if src_key_padding_mask is not None:
            san_mask = make_san_mask(src_key_padding_mask, causal_mask)
        elif causal_mask is not None:
            san_mask = causal_mask
        else:
            san_mask = None

        #################################################
        # First half PFFN.
        #################################################
        # `[N, qlen, dim_model]`
        residual = feature
        feature = apply_norm(self.norm_ffw1, feature)
        feature = self.ffw1(feature)
        feature = self.fc_factor * self.dropout(feature) + residual

        #################################################
        # MHA.
        #################################################
        # `[N, qlen, dim_model]`
        residual = feature
        feature = apply_norm(self.norm_sattn, feature)
        feature, self.attw = self.self_attn(
            key=feature,
            value=feature,
            query=feature,
            mask=san_mask)
        feature = self.dropout(feature) + residual

        #################################################
        # Second half PFFN.
        #################################################
        # `[N, qlen, dim_model]`
        residual = feature
        feature = apply_norm(self.norm_ffw2, feature)
        feature = self.ffw2(feature)
        feature = self.fc_factor * self.dropout(feature) + residual

        return feature

# %% [markdown]
# ### Transformer encoder block (update)

# %%
class TransformerEncoder(nn.Module):
    def __init__(self,
                 encoder_layer,
                 num_layers,
                 dim_model,
                 dropout_pe,
                 norm_type_tail,
                 norm_eps,
                 norm_first,
                 add_bias,
                 add_tailnorm):
        super().__init__()

        self.pos_encoder = PositionalEncoding(dim_model, dropout_pe)
        self.layers = nn.ModuleList([copy.deepcopy(encoder_layer) for _ in range(num_layers)])

        # Add LayerNorm at tail position.
        # This is applied only when norm_first is True because
        # post-normalization structure includes tail-normalization in encoder
        # layers.
        if add_tailnorm and norm_first:
            self.norm_tail = create_norm(norm_type_tail, dim_model, norm_eps, add_bias)
        else:
            self.norm_tail = Identity()

    def forward(self,
                feature,
                causal_mask,
                src_key_padding_mask):
        feature = self.pos_encoder(feature)
        for layer in self.layers:
            feature = layer(feature,
                            causal_mask,
                            src_key_padding_mask)
        feature = apply_norm(self.norm_tail, feature)
        return feature

# %% [markdown]
# ### ISLR model

# %%
class MacaronNetEnISLR(nn.Module):
    def __init__(self,
                 in_channels,
                 inter_channels,
                 out_channels,
                 activation="relu",
                 pooling_type="none",
                 tren_num_layers=1,
                 tren_num_heads=1,
                 tren_dim_ffw=256,
                 tren_dropout_pe=0.1,
                 tren_dropout=0.1,
                 tren_norm_type_sattn="layer",
                 tren_norm_type_ffw="layer",
                 tren_norm_type_tail="layer",
                 tren_norm_eps=1e-5,
                 tren_add_bias=True,
                 tren_add_tailnorm=True):
        super().__init__()

        # Feature extraction.
        self.linear = nn.Linear(in_channels, inter_channels)
        self.activation = select_reluwise_activation(activation)

        if pooling_type == "none":
            self.pooling = Identity()
        elif pooling_type == "average":
            self.pooling = nn.AvgPool2d(
                kernel_size=[2, 1],
                stride=[2, 1],
                padding=0)
        elif pooling_type == "max":
            self.pooling = nn.MaxPool2d(
                kernel_size=[2, 1],
                stride=[2, 1],
                padding=0)

        # Transformer-Encoder with Macaron-Net architecture.
        enlayer = MacaronNetEncoderLayer(
            dim_model=inter_channels,
            num_heads=tren_num_heads,
            dim_ffw=tren_dim_ffw,
            dropout=tren_dropout,
            activation=activation,
            norm_type_sattn=tren_norm_type_sattn,
            norm_type_ffw=tren_norm_type_ffw,
            norm_eps=tren_norm_eps,
            add_bias=tren_add_bias)
        self.tr_encoder = TransformerEncoder(
            encoder_layer=enlayer,
            num_layers=tren_num_layers,
            dim_model=inter_channels,
            dropout_pe=tren_dropout_pe,
            norm_type_tail=tren_norm_type_tail,
            norm_eps=tren_norm_eps,
            norm_first=True,  # Fixed for Macaron-Net.
            add_bias=tren_add_bias,
            add_tailnorm=tren_add_tailnorm)

        self.head = GPoolRecognitionHead(inter_channels, out_channels)

    def forward(self,
                feature,
                feature_causal_mask=None,
                feature_pad_mask=None):
        # Feature extraction.
        # `[N, C, T, J] -> [N, T, C, J] -> [N, T, C*J] -> [N, T, C']`
        N, C, T, J = feature.shape
        feature = feature.permute([0, 2, 1, 3])
        feature = feature.reshape(N, T, -1)

        feature = self.linear(feature)
        if torch.isnan(feature).any():
            raise ValueError()
        feature = self.activation(feature)
        if torch.isnan(feature).any():
            raise ValueError()

        # Apply pooling.
        feature = self.pooling(feature)
        if feature_pad_mask is not None:
            # Cast to apply pooling.
            feature_pad_mask = feature_pad_mask.to(feature.dtype)
            feature_pad_mask = self.pooling(feature_pad_mask.unsqueeze(-1)).squeeze(-1)
            # Binarization.
            # This removes averaged signals with padding.
            feature_pad_mask = feature_pad_mask > 0.5
            if feature_causal_mask is not None:
                feature_causal_mask = make_causal_mask(feature_pad_mask)

        feature = self.tr_encoder(
            feature=feature,
            causal_mask=feature_causal_mask,
            src_key_padding_mask=feature_pad_mask)
        if torch.isnan(feature).any():
            raise ValueError()

        # `[N, T, C] -> [N, C, T]`
        logit = self.head(feature.permute([0, 2, 1]), feature_pad_mask)
        if torch.isnan(feature).any():
            raise ValueError()
        return logit

# %% [markdown]
# ## Sanity check

# %%
# Access check.
dataset_dir = Path("dataset_top10")
files = list(dataset_dir.iterdir())
dictionary = [fin for fin in files if ".json" in fin.name][0]
hdf5_files = [fin for fin in files if ".hdf5" in fin.name]

print(dictionary)
print(hdf5_files)
# Out:
# dataset_top10/sign_to_prediction_index_map.json
# [PosixPath('dataset_top10/32319.hdf5'), PosixPath('dataset_top10/36257.hdf5'), PosixPath('dataset_top10/16069.hdf5'), PosixPath('dataset_top10/22343.hdf5'), PosixPath('dataset_top10/2044.hdf5'), PosixPath('dataset_top10/25571.hdf5'), PosixPath('dataset_top10/30680.hdf5'), PosixPath('dataset_top10/27610.hdf5'), PosixPath('dataset_top10/61333.hdf5'), PosixPath('dataset_top10/55372.hdf5'), PosixPath('dataset_top10/28656.hdf5'), PosixPath('dataset_top10/49445.hdf5'), PosixPath('dataset_top10/29302.hdf5'), PosixPath('dataset_top10/37055.hdf5'), PosixPath('dataset_top10/26734.hdf5'), PosixPath('dataset_top10/53618.hdf5'), PosixPath('dataset_top10/18796.hdf5'), PosixPath('dataset_top10/62590.hdf5'), PosixPath('dataset_top10/37779.hdf5'), PosixPath('dataset_top10/34503.hdf5'), PosixPath('dataset_top10/4718.hdf5')]

# %%
# Load dictionary.
with open(dictionary, "r") as fread:
    key2token = json.load(fread)

VOCAB = len(key2token)

# %%
_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
trans_select_feature = SelectLandmarksAndFeature(landmarks=use_landmarks, features=use_features)
trans_repnan = ReplaceNan()
trans_norm = PartsBasedNormalization(align_mode="framewise", scale_mode="unique")

pre_transforms = Compose([trans_select_feature,
                          trans_repnan,
                          trans_norm])
transforms = Compose([ToTensor()])

# %%
batch_size = 2
feature_shape = (len(use_features), -1, len(use_landmarks))
token_shape = (1,)
merge_fn = partial(merge_padded_batch,
                   feature_shape=feature_shape,
                   token_shape=token_shape,
                   feature_padding_val=0.0,
                   token_padding_val=0)

dataset = HDF5Dataset(hdf5_files, pre_transforms=pre_transforms, transforms=transforms)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=merge_fn)
try:
    data = next(iter(dataloader))
    feature_origin = data["feature"]

    print(feature_origin.shape)
except Exception as inst:
    print(inst)
# Out:
# torch.Size([2, 2, 24, 130])

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
inter_channels = 64
out_channels = VOCAB
activation = "relu"
pooling_type = "none"
tren_num_layers = 2
tren_num_heads = 2
tren_dim_ffw = 256
tren_dropout_pe = 0.1
tren_dropout = 0.1
tren_norm_type_sattn = "layer"
tren_norm_type_ffw = "layer"
tren_norm_type_tail = "layer"
tren_norm_eps = 1e-5
tren_norm_first = True  # For Transformer.
tren_add_bias = True
tren_add_tailnorm = True

model = MacaronNetEnISLR(in_channels=in_channels,
                         inter_channels=inter_channels,
                         out_channels=out_channels,
                         activation=activation,
                         pooling_type=pooling_type,
                         tren_num_layers=tren_num_layers,
                         tren_num_heads=tren_num_heads,
                         tren_dim_ffw=tren_dim_ffw,
                         tren_dropout_pe=tren_dropout_pe,
                         tren_dropout=tren_dropout,
                         tren_norm_type_sattn=tren_norm_type_sattn,
                         tren_norm_type_ffw=tren_norm_type_ffw,
                         tren_norm_type_tail=tren_norm_type_tail,
                         tren_norm_eps=tren_norm_eps,
                         tren_add_bias=tren_add_bias,
                         tren_add_tailnorm=tren_add_tailnorm)
print(model)

# Sanity check.
logit = model(feature_origin)
print(logit.shape)
attw0 = model.tr_encoder.layers[0].attw.detach().cpu().numpy()
attw1 = model.tr_encoder.layers[0].attw.detach().cpu().numpy()
print(attw0.shape, attw1.shape)
# Out:
# MacaronNetEnISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (pooling): Identity()
#   (tr_encoder): TransformerEncoder(
#     (pos_encoder): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-1): 2 x MacaronNetEncoderLayer(
#         (norm_ffw1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (ffw1): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=256, bias=True)
#           (w_2): Linear(in_features=256, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (norm_sattn): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (self_attn): MultiheadAttention(
#           (w_key): Linear(in_features=64, out_features=64, bias=True)
#           (w_value): Linear(in_features=64, out_features=64, bias=True)
#           (w_query): Linear(in_features=64, out_features=64, bias=True)
#           (w_out): Linear(in_features=64, out_features=64, bias=True)
#           (dropout_attn): Dropout(p=0.1, inplace=False)
#         )
#         (norm_ffw2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (ffw2): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=256, bias=True)
#           (w_2): Linear(in_features=256, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (norm_tail): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])
# (2, 2, 24, 24) (2, 2, 24, 24)

# %% [markdown]
# # 4. Train and evaluation

# %% [markdown]
# ## 4.1 Set common parameters.

# %%
# Set common parameters.
batch_size = 32
load_into_ram = True
test_pid = 16069
num_workers = os.cpu_count()
print(f"Using {num_workers} cores for data loading.")
lr = 3e-4

epochs = 50
eval_every_n_epochs = 1
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} for computation.")

train_hdf5files = [fin for fin in hdf5_files if str(test_pid) not in fin.name]
val_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]
test_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]

_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
# Out:
# Using 2 cores for data loading.
# Using cuda for computation.

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)

# %% [markdown]
# ## 4.2 Run training process

# %% [markdown]
# ### MacaronNet

# %%
model_macaron = MacaronNetEnISLR(
    in_channels=in_channels,
    inter_channels=inter_channels,
    out_channels=out_channels,
    activation=activation,
    pooling_type=pooling_type,
    tren_num_layers=tren_num_layers,
    tren_num_heads=tren_num_heads,
    tren_dim_ffw=tren_dim_ffw,
    tren_dropout_pe=tren_dropout_pe,
    tren_dropout=tren_dropout,
    tren_norm_type_sattn=tren_norm_type_sattn,
    tren_norm_type_ffw=tren_norm_type_ffw,
    tren_norm_type_tail=tren_norm_type_tail,
    tren_norm_eps=tren_norm_eps,
    tren_add_bias=tren_add_bias,
    tren_add_tailnorm=tren_add_tailnorm)
print(model_macaron)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model_macaron.parameters(), lr=lr)
# Out:
# MacaronNetEnISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (pooling): Identity()
#   (tr_encoder): TransformerEncoder(
#     (pos_encoder): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-1): 2 x MacaronNetEncoderLayer(
#         (norm_ffw1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (ffw1): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=256, bias=True)
#           (w_2): Linear(in_features=256, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (norm_sattn): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (self_attn): MultiheadAttention(
#           (w_key): Linear(in_features=64, out_features=64, bias=True)
#           (w_value): Linear(in_features=64, out_features=64, bias=True)
#           (w_query): Linear(in_features=64, out_features=64, bias=True)
#           (w_out): Linear(in_features=64, out_features=64, bias=True)
#           (dropout_attn): Dropout(p=0.1, inplace=False)
#         )
#         (norm_ffw2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (ffw2): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=256, bias=True)
#           (w_2): Linear(in_features=256, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (norm_tail): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model_macaron.to(device)

train_losses = []
val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_losses = train_loop(train_dataloader, model_macaron, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model_macaron, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model_macaron, device)
        test_accs.append(acc)
train_losses_macaron = np.array(train_losses)
val_losses_macaron = np.array(val_losses)
test_accs_macaron = np.array(test_accs)

print(f"Minimum validation loss:{val_losses_macaron.min()} at {np.argmin(val_losses_macaron)+1} epoch.")
print(f"Maximum accuracy:{test_accs_macaron.max()} at {np.argmax(test_accs_macaron)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:3.077432 [    0/ 3881]
# loss:2.068993 [ 3200/ 3881]
# Done. Time:4.522592245999988
# Training performance:
#  Avg loss:2.044730
#
# Start validation.
# Done. Time:0.25345869099999163
# Validation performance:
#  Avg loss:2.031111
#
# Start evaluation.
# Done. Time:1.2937657340000044
# Test performance:
#  Accuracy:29.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:1.576146 [    0/ 3881]
# loss:1.231866 [ 3200/ 3881]
# Done. Time:4.575180742000015
# Training performance:
#  Avg loss:1.405592
#
# Start validation.
# Done. Time:0.3237608059999957
# Validation performance:
#  Avg loss:1.521979
#
# Start evaluation.
# Done. Time:1.237990572000001
# Test performance:
#  Accuracy:47.0%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:0.853771 [    0/ 3881]
# loss:0.808964 [ 3200/ 3881]
# Done. Time:3.0131788410000127
# Training performance:
#  Avg loss:1.098371
#
# Start validation.
# Done. Time:0.25873692100000767
# Validation performance:
#  Avg loss:1.435491
#
# Start evaluation.
# Done. Time:1.2547257429999945
# Test performance:
#  Accuracy:47.5%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:0.883918 [    0/ 3881]
# loss:1.036701 [ 3200/ 3881]
# Done. Time:2.980110977999999
# Training performance:
#  Avg loss:0.929718
#
# Start validation.
# Done. Time:0.24355961000000548
# Validation performance:
#  Avg loss:1.346082
#
# Start evaluation.
# Done. Time:1.392277149999984
# Test performance:
#  Accuracy:51.5%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:0.868646 [    0/ 3881]
# loss:0.741882 [ 3200/ 3881]
# Done. Time:4.6878873940000005
# Training performance:
#  Avg loss:0.831233
#
# Start validation.
# Done. Time:0.2552827890000344
# Validation performance:
#  Avg loss:1.135497
#
# Start evaluation.
# Done. Time:1.243770306999977
# Test performance:
#  Accuracy:63.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:0.623097 [    0/ 3881]
# loss:0.697230 [ 3200/ 3881]
# Done. Time:2.8983634929999766
# Training performance:
#  Avg loss:0.750631
#
# Start validation.
# Done. Time:0.2388743309999768
# Validation performance:
#  Avg loss:1.114677
#
# Start evaluation.
# Done. Time:1.2712779720000071
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:0.676786 [    0/ 3881]
# loss:0.808492 [ 3200/ 3881]
# Done. Time:2.934096468000007
# Training performance:
#  Avg loss:0.672527
#
# Start validation.
# Done. Time:0.25556411299999127
# Validation performance:
#  Avg loss:1.203963
#
# Start evaluation.
# Done. Time:1.5229265270000383
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:0.921438 [    0/ 3881]
# loss:0.428417 [ 3200/ 3881]
# Done. Time:4.382007686999998
# Training performance:
#  Avg loss:0.650585
#
# Start validation.
# Done. Time:0.2620606039999984
# Validation performance:
#  Avg loss:1.032763
#
# Start evaluation.
# Done. Time:1.3233080640000026
# Test performance:
#  Accuracy:65.5%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:0.538637 [    0/ 3881]
# loss:0.678195 [ 3200/ 3881]
# Done. Time:2.9960280619999935
# Training performance:
#  Avg loss:0.604237
#
# Start validation.
# Done. Time:0.23992977299997165
# Validation performance:
#  Avg loss:1.133150
#
# Start evaluation.
# Done. Time:1.2538470750000101
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:0.762083 [    0/ 3881]
# loss:0.419988 [ 3200/ 3881]
# Done. Time:2.9796571159999985
# Training performance:
#  Avg loss:0.582252
#
# Start validation.
# Done. Time:0.3854791169999885
# Validation performance:
#  Avg loss:1.098120
#
# Start evaluation.
# Done. Time:1.6286297539999737
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:0.593671 [    0/ 3881]
# loss:0.863924 [ 3200/ 3881]
# Done. Time:3.961616661999983
# Training performance:
#  Avg loss:0.521092
#
# Start validation.
# Done. Time:0.25507858600002464
# Validation performance:
#  Avg loss:1.045260
#
# Start evaluation.
# Done. Time:1.2455143810000209
# Test performance:
#  Accuracy:69.0%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:0.665092 [    0/ 3881]
# loss:0.385009 [ 3200/ 3881]
# Done. Time:2.9256217320000246
# Training performance:
#  Avg loss:0.486167
#
# Start validation.
# Done. Time:0.24171776499997577
# Validation performance:
#  Avg loss:0.874251
#
# Start evaluation.
# Done. Time:1.2434087359999921
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:0.430963 [    0/ 3881]
# loss:0.395827 [ 3200/ 3881]
# Done. Time:2.998874470999965
# Training performance:
#  Avg loss:0.487990
#
# Start validation.
# Done. Time:0.38158969099998785
# Validation performance:
#  Avg loss:0.883090
#
# Start evaluation.
# Done. Time:1.6021618259999855
# Test performance:
#  Accuracy:74.0%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:0.264626 [    0/ 3881]
# loss:0.632081 [ 3200/ 3881]
# Done. Time:3.8726830769999765
# Training performance:
#  Avg loss:0.438789
#
# Start validation.
# Done. Time:0.24075787000003857
# Validation performance:
#  Avg loss:0.914751
#
# Start evaluation.
# Done. Time:1.2275006339999663
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:0.314071 [    0/ 3881]
# loss:0.802394 [ 3200/ 3881]
# Done. Time:2.941943536999986
# Training performance:
#  Avg loss:0.450344
#
# Start validation.
# Done. Time:0.25893427299996574
# Validation performance:
#  Avg loss:0.899486
#
# Start evaluation.
# Done. Time:1.270725938000055
# Test performance:
#  Accuracy:70.0%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:0.323995 [    0/ 3881]
# loss:0.692838 [ 3200/ 3881]
# Done. Time:3.3880617419999908
# Training performance:
#  Avg loss:0.418494
#
# Start validation.
# Done. Time:0.3698851629999922
# Validation performance:
#  Avg loss:0.749762
#
# Start evaluation.
# Done. Time:1.7428671570000347
# Test performance:
#  Accuracy:74.0%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:0.314198 [    0/ 3881]
# loss:0.456946 [ 3200/ 3881]
# Done. Time:3.1187639479999802
# Training performance:
#  Avg loss:0.411934
#
# Start validation.
# Done. Time:0.2444736060000423
# Validation performance:
#  Avg loss:0.877015
#
# Start evaluation.
# Done. Time:1.242675348999967
# Test performance:
#  Accuracy:69.0%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:0.249417 [    0/ 3881]
# loss:0.346533 [ 3200/ 3881]
# Done. Time:2.8778096679999976
# Training performance:
#  Avg loss:0.402439
#
# Start validation.
# Done. Time:0.2630080050000174
# Validation performance:
#  Avg loss:0.709825
#
# Start evaluation.
# Done. Time:1.2922836139999845
# Test performance:
#  Accuracy:74.0%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:0.580082 [    0/ 3881]
# loss:0.296464 [ 3200/ 3881]
# Done. Time:3.7972042009999996
# Training performance:
#  Avg loss:0.365148
#
# Start validation.
# Done. Time:0.3635074029999714
# Validation performance:
#  Avg loss:0.711336
#
# Start evaluation.
# Done. Time:1.7136127900000133
# Test performance:
#  Accuracy:77.0%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:0.236912 [    0/ 3881]
# loss:0.379186 [ 3200/ 3881]
# Done. Time:2.8906316110000034
# Training performance:
#  Avg loss:0.367713
#
# Start validation.
# Done. Time:0.2519948999999997
# Validation performance:
#  Avg loss:0.743077
#
# Start evaluation.
# Done. Time:1.2835261330000094
# Test performance:
#  Accuracy:78.5%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:0.302541 [    0/ 3881]
# loss:0.309275 [ 3200/ 3881]
# Done. Time:2.9566970800000263
# Training performance:
#  Avg loss:0.379845
#
# Start validation.
# Done. Time:0.23644505699996898
# Validation performance:
#  Avg loss:0.713766
#
# Start evaluation.
# Done. Time:1.3008469450000462
# Test performance:
#  Accuracy:75.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:0.256210 [    0/ 3881]
# loss:0.554435 [ 3200/ 3881]
# Done. Time:4.096117041000014
# Training performance:
#  Avg loss:0.341763
#
# Start validation.
# Done. Time:0.4186362539999777
# Validation performance:
#  Avg loss:0.672118
#
# Start evaluation.
# Done. Time:1.3956665389999898
# Test performance:
#  Accuracy:78.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:0.184328 [    0/ 3881]
# loss:0.369097 [ 3200/ 3881]
# Done. Time:2.8983215089999703
# Training performance:
#  Avg loss:0.343167
#
# Start validation.
# Done. Time:0.2510980659999973
# Validation performance:
#  Avg loss:0.818015
#
# Start evaluation.
# Done. Time:1.2605618420000155
# Test performance:
#  Accuracy:76.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:0.258258 [    0/ 3881]
# loss:0.528706 [ 3200/ 3881]
# Done. Time:2.8758458270000347
# Training performance:
#  Avg loss:0.324706
#
# Start validation.
# Done. Time:0.2420138989999714
# Validation performance:
#  Avg loss:0.739589
#
# Start evaluation.
# Done. Time:1.274208462000047
# Test performance:
#  Accuracy:75.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:0.325907 [    0/ 3881]
# loss:0.209724 [ 3200/ 3881]
# Done. Time:4.65364354999997
# Training performance:
#  Avg loss:0.311712
#
# Start validation.
# Done. Time:0.35744014300001936
# Validation performance:
#  Avg loss:0.755155
#
# Start evaluation.
# Done. Time:1.2441017560000205
# Test performance:
#  Accuracy:79.0%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:0.262427 [    0/ 3881]
# loss:0.283985 [ 3200/ 3881]
# Done. Time:2.968985574000044
# Training performance:
#  Avg loss:0.304699
#
# Start validation.
# Done. Time:0.24844271900002468
# Validation performance:
#  Avg loss:0.696014
#
# Start evaluation.
# Done. Time:1.2497177609999994
# Test performance:
#  Accuracy:81.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:0.311464 [    0/ 3881]
# loss:0.536892 [ 3200/ 3881]
# Done. Time:2.811676539999951
# Training performance:
#  Avg loss:0.302457
#
# Start validation.
# Done. Time:0.27023725599997306
# Validation performance:
#  Avg loss:0.652360
#
# Start evaluation.
# Done. Time:1.3618888629999901
# Test performance:
#  Accuracy:79.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.221014 [    0/ 3881]
# loss:0.222425 [ 3200/ 3881]
# Done. Time:4.766539797999997
# Training performance:
#  Avg loss:0.288575
#
# Start validation.
# Done. Time:0.24686299199998984
# Validation performance:
#  Avg loss:0.735939
#
# Start evaluation.
# Done. Time:1.233258554000031
# Test performance:
#  Accuracy:78.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.337489 [    0/ 3881]
# loss:0.210643 [ 3200/ 3881]
# Done. Time:2.92103812299996
# Training performance:
#  Avg loss:0.276590
#
# Start validation.
# Done. Time:0.24266709300002276
# Validation performance:
#  Avg loss:0.818014
#
# Start evaluation.
# Done. Time:1.2345826079999824
# Test performance:
#  Accuracy:75.0%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.392962 [    0/ 3881]
# loss:0.282839 [ 3200/ 3881]
# Done. Time:2.9056748080000148
# Training performance:
#  Avg loss:0.274898
#
# Start validation.
# Done. Time:0.23699444100003575
# Validation performance:
#  Avg loss:0.808272
#
# Start evaluation.
# Done. Time:1.5387834160000011
# Test performance:
#  Accuracy:77.5%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.245781 [    0/ 3881]
# loss:0.262795 [ 3200/ 3881]
# Done. Time:4.216116342999953
# Training performance:
#  Avg loss:0.268614
#
# Start validation.
# Done. Time:0.26690087600002244
# Validation performance:
#  Avg loss:0.734620
#
# Start evaluation.
# Done. Time:1.2663981199999625
# Test performance:
#  Accuracy:79.5%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.237734 [    0/ 3881]
# loss:0.153894 [ 3200/ 3881]
# Done. Time:2.842300977999969
# Training performance:
#  Avg loss:0.271306
#
# Start validation.
# Done. Time:0.25231039700003066
# Validation performance:
#  Avg loss:0.660700
#
# Start evaluation.
# Done. Time:1.2647388490000253
# Test performance:
#  Accuracy:81.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.193252 [    0/ 3881]
# loss:0.175232 [ 3200/ 3881]
# Done. Time:2.866717809000022
# Training performance:
#  Avg loss:0.268364
#
# Start validation.
# Done. Time:0.3325471339999808
# Validation performance:
#  Avg loss:0.705595
#
# Start evaluation.
# Done. Time:1.6056144359999962
# Test performance:
#  Accuracy:82.0%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.155512 [    0/ 3881]
# loss:0.450155 [ 3200/ 3881]
# Done. Time:4.2636928539999985
# Training performance:
#  Avg loss:0.245444
#
# Start validation.
# Done. Time:0.24438263299998653
# Validation performance:
#  Avg loss:0.909538
#
# Start evaluation.
# Done. Time:1.2573780250000368
# Test performance:
#  Accuracy:77.5%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.134452 [    0/ 3881]
# loss:0.098918 [ 3200/ 3881]
# Done. Time:2.903547995999986
# Training performance:
#  Avg loss:0.252783
#
# Start validation.
# Done. Time:0.2491188770000008
# Validation performance:
#  Avg loss:0.675350
#
# Start evaluation.
# Done. Time:1.2643780210000273
# Test performance:
#  Accuracy:77.0%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.188321 [    0/ 3881]
# loss:0.340856 [ 3200/ 3881]
# Done. Time:3.0967030570000134
# Training performance:
#  Avg loss:0.230578
#
# Start validation.
# Done. Time:0.38734231899996985
# Validation performance:
#  Avg loss:0.688768
#
# Start evaluation.
# Done. Time:1.6416342320000012
# Test performance:
#  Accuracy:81.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.281378 [    0/ 3881]
# loss:0.332125 [ 3200/ 3881]
# Done. Time:4.01046982500003
# Training performance:
#  Avg loss:0.231247
#
# Start validation.
# Done. Time:0.24076307500001803
# Validation performance:
#  Avg loss:0.684683
#
# Start evaluation.
# Done. Time:1.2543277220000277
# Test performance:
#  Accuracy:81.5%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.048226 [    0/ 3881]
# loss:0.212337 [ 3200/ 3881]
# Done. Time:2.9246572600000036
# Training performance:
#  Avg loss:0.222078
#
# Start validation.
# Done. Time:0.24455096700000922
# Validation performance:
#  Avg loss:0.730293
#
# Start evaluation.
# Done. Time:1.2547447310000166
# Test performance:
#  Accuracy:79.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.286380 [    0/ 3881]
# loss:0.200854 [ 3200/ 3881]
# Done. Time:3.133052527000018
# Training performance:
#  Avg loss:0.226346
#
# Start validation.
# Done. Time:0.39756741700000475
# Validation performance:
#  Avg loss:0.724770
#
# Start evaluation.
# Done. Time:1.6777826210000057
# Test performance:
#  Accuracy:79.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.127320 [    0/ 3881]
# loss:0.117727 [ 3200/ 3881]
# Done. Time:3.923398110999983
# Training performance:
#  Avg loss:0.228663
#
# Start validation.
# Done. Time:0.271592677000001
# Validation performance:
#  Avg loss:0.789615
#
# Start evaluation.
# Done. Time:1.2560475920000158
# Test performance:
#  Accuracy:82.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.194976 [    0/ 3881]
# loss:0.155349 [ 3200/ 3881]
# Done. Time:2.913733323000031
# Training performance:
#  Avg loss:0.215379
#
# Start validation.
# Done. Time:0.24208530800001427
# Validation performance:
#  Avg loss:0.690797
#
# Start evaluation.
# Done. Time:1.2690215540000054
# Test performance:
#  Accuracy:79.5%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.092941 [    0/ 3881]
# loss:0.139980 [ 3200/ 3881]
# Done. Time:3.2820581849999826
# Training performance:
#  Avg loss:0.208651
#
# Start validation.
# Done. Time:0.3806875249999848
# Validation performance:
#  Avg loss:0.680828
#
# Start evaluation.
# Done. Time:1.702987840999981
# Test performance:
#  Accuracy:81.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.145197 [    0/ 3881]
# loss:0.235641 [ 3200/ 3881]
# Done. Time:3.0757877290000124
# Training performance:
#  Avg loss:0.226121
#
# Start validation.
# Done. Time:0.26026816099999905
# Validation performance:
#  Avg loss:0.778727
#
# Start evaluation.
# Done. Time:1.2589509039999598
# Test performance:
#  Accuracy:78.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.149246 [    0/ 3881]
# loss:0.092045 [ 3200/ 3881]
# Done. Time:2.902566057999991
# Training performance:
#  Avg loss:0.198376
#
# Start validation.
# Done. Time:0.251273421999997
# Validation performance:
#  Avg loss:0.735031
#
# Start evaluation.
# Done. Time:1.2487291610000284
# Test performance:
#  Accuracy:82.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.172559 [    0/ 3881]
# loss:0.224657 [ 3200/ 3881]
# Done. Time:3.866134106000004
# Training performance:
#  Avg loss:0.198413
#
# Start validation.
# Done. Time:0.37684805699996105
# Validation performance:
#  Avg loss:1.234167
#
# Start evaluation.
# Done. Time:1.7732918280000263
# Test performance:
#  Accuracy:73.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.166758 [    0/ 3881]
# loss:0.320262 [ 3200/ 3881]
# Done. Time:2.9360275619999925
# Training performance:
#  Avg loss:0.186258
#
# Start validation.
# Done. Time:0.2557865910000032
# Validation performance:
#  Avg loss:0.839400
#
# Start evaluation.
# Done. Time:1.2342024440000046
# Test performance:
#  Accuracy:77.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.160364 [    0/ 3881]
# loss:0.114050 [ 3200/ 3881]
# Done. Time:2.893711448000033
# Training performance:
#  Avg loss:0.184879
#
# Start validation.
# Done. Time:0.24259372099999155
# Validation performance:
#  Avg loss:0.724922
#
# Start evaluation.
# Done. Time:1.3023016719999987
# Test performance:
#  Accuracy:77.5%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.297764 [    0/ 3881]
# loss:0.121844 [ 3200/ 3881]
# Done. Time:4.057536037000034
# Training performance:
#  Avg loss:0.203743
#
# Start validation.
# Done. Time:0.4400126959999966
# Validation performance:
#  Avg loss:0.674893
#
# Start evaluation.
# Done. Time:1.3539448239999956
# Test performance:
#  Accuracy:80.0%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.285550 [    0/ 3881]
# loss:0.131455 [ 3200/ 3881]
# Done. Time:2.9328260080000064
# Training performance:
#  Avg loss:0.174044
#
# Start validation.
# Done. Time:0.2596456790000161
# Validation performance:
#  Avg loss:0.723316
#
# Start evaluation.
# Done. Time:1.2525824179999745
# Test performance:
#  Accuracy:81.5%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.105367 [    0/ 3881]
# loss:0.137955 [ 3200/ 3881]
# Done. Time:2.9604755469999873
# Training performance:
#  Avg loss:0.173550
#
# Start validation.
# Done. Time:0.2568066980000481
# Validation performance:
#  Avg loss:0.736782
#
# Start evaluation.
# Done. Time:1.2513119850000294
# Test performance:
#  Accuracy:78.5%
# Minimum validation loss:0.6523600816726685 at 27 epoch.
# Maximum accuracy:82.5 at 40 epoch.

# %% [markdown]
# ### Transformer

# %%
model_trans = TransformerEnISLR(
    in_channels=in_channels,
    inter_channels=inter_channels,
    out_channels=out_channels,
    activation=activation,
    pooling_type=pooling_type,
    tren_num_layers=tren_num_layers,
    tren_num_heads=tren_num_heads,
    tren_dim_ffw=tren_dim_ffw,
    tren_dropout_pe=tren_dropout_pe,
    tren_dropout=tren_dropout,
    tren_norm_type_sattn=tren_norm_type_sattn,
    tren_norm_type_ffw=tren_norm_type_ffw,
    tren_norm_type_tail=tren_norm_type_tail,
    tren_norm_eps=tren_norm_eps,
    tren_norm_first=tren_norm_first,
    tren_add_bias=tren_add_bias,
    tren_add_tailnorm=tren_add_tailnorm)
print(model_trans)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model_trans.parameters(), lr=lr)
# Out:
# TransformerEnISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (pooling): Identity()
#   (tr_encoder): TransformerEncoder(
#     (pos_encoder): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (w_key): Linear(in_features=64, out_features=64, bias=True)
#           (w_value): Linear(in_features=64, out_features=64, bias=True)
#           (w_query): Linear(in_features=64, out_features=64, bias=True)
#           (w_out): Linear(in_features=64, out_features=64, bias=True)
#           (dropout_attn): Dropout(p=0.1, inplace=False)
#         )
#         (norm_sattn): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (ffw): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=256, bias=True)
#           (w_2): Linear(in_features=256, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (norm_ffw): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (norm_tail): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model_trans.to(device)

train_losses = []
val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_losses = train_loop(train_dataloader, model_trans, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model_trans, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model_trans, device)
        test_accs.append(acc)
train_losses_trans = np.array(train_losses)
val_losses_trans = np.array(val_losses)
test_accs_trans = np.array(test_accs)

print(f"Minimum validation loss:{val_losses_trans.min()} at {np.argmin(val_losses_trans)+1} epoch.")
print(f"Maximum accuracy:{test_accs_trans.max()} at {np.argmax(test_accs_trans)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:6.080705 [    0/ 3881]
# loss:2.205144 [ 3200/ 3881]
# Done. Time:4.650706043999946
# Training performance:
#  Avg loss:2.297427
#
# Start validation.
# Done. Time:0.31905816099998674
# Validation performance:
#  Avg loss:2.040964
#
# Start evaluation.
# Done. Time:1.150339520999978
# Test performance:
#  Accuracy:24.0%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:1.961216 [    0/ 3881]
# loss:1.364433 [ 3200/ 3881]
# Done. Time:2.7870327130000305
# Training performance:
#  Avg loss:1.644698
#
# Start validation.
# Done. Time:0.2481701140000041
# Validation performance:
#  Avg loss:2.013738
#
# Start evaluation.
# Done. Time:1.1849638099999993
# Test performance:
#  Accuracy:28.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.574695 [    0/ 3881]
# loss:1.205273 [ 3200/ 3881]
# Done. Time:2.694856769000012
# Training performance:
#  Avg loss:1.241224
#
# Start validation.
# Done. Time:0.24925740700001597
# Validation performance:
#  Avg loss:1.641982
#
# Start evaluation.
# Done. Time:1.1640134909999915
# Test performance:
#  Accuracy:42.5%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:0.981184 [    0/ 3881]
# loss:0.821195 [ 3200/ 3881]
# Done. Time:4.304324238999982
# Training performance:
#  Avg loss:1.002588
#
# Start validation.
# Done. Time:0.4065118890000008
# Validation performance:
#  Avg loss:1.512901
#
# Start evaluation.
# Done. Time:1.1505461049999894
# Test performance:
#  Accuracy:45.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:0.816714 [    0/ 3881]
# loss:1.208931 [ 3200/ 3881]
# Done. Time:2.820409519000009
# Training performance:
#  Avg loss:0.884212
#
# Start validation.
# Done. Time:0.25702842800001235
# Validation performance:
#  Avg loss:1.453236
#
# Start evaluation.
# Done. Time:1.1557623570000146
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:0.817200 [    0/ 3881]
# loss:1.251088 [ 3200/ 3881]
# Done. Time:2.7248210650000146
# Training performance:
#  Avg loss:0.800972
#
# Start validation.
# Done. Time:0.2521004900000321
# Validation performance:
#  Avg loss:1.364480
#
# Start evaluation.
# Done. Time:1.1673954809999714
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:0.862234 [    0/ 3881]
# loss:0.528741 [ 3200/ 3881]
# Done. Time:4.323381132999998
# Training performance:
#  Avg loss:0.692622
#
# Start validation.
# Done. Time:0.39000423100003445
# Validation performance:
#  Avg loss:1.214394
#
# Start evaluation.
# Done. Time:1.20109344399998
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:0.592530 [    0/ 3881]
# loss:0.773432 [ 3200/ 3881]
# Done. Time:2.8134685400000308
# Training performance:
#  Avg loss:0.663505
#
# Start validation.
# Done. Time:0.2521984429999975
# Validation performance:
#  Avg loss:1.135035
#
# Start evaluation.
# Done. Time:1.150838619999945
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:0.817409 [    0/ 3881]
# loss:0.656543 [ 3200/ 3881]
# Done. Time:2.7429217650000055
# Training performance:
#  Avg loss:0.639676
#
# Start validation.
# Done. Time:0.24663098199994238
# Validation performance:
#  Avg loss:1.196841
#
# Start evaluation.
# Done. Time:1.1645415579999963
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:0.658571 [    0/ 3881]
# loss:0.320410 [ 3200/ 3881]
# Done. Time:4.443607065000037
# Training performance:
#  Avg loss:0.566121
#
# Start validation.
# Done. Time:0.3814978270000893
# Validation performance:
#  Avg loss:0.980170
#
# Start evaluation.
# Done. Time:1.1797605120000298
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:0.370777 [    0/ 3881]
# loss:0.642919 [ 3200/ 3881]
# Done. Time:2.7436588890000166
# Training performance:
#  Avg loss:0.566184
#
# Start validation.
# Done. Time:0.24320326299994122
# Validation performance:
#  Avg loss:1.111343
#
# Start evaluation.
# Done. Time:1.1490822279999975
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:0.453173 [    0/ 3881]
# loss:0.654221 [ 3200/ 3881]
# Done. Time:2.718547681000018
# Training performance:
#  Avg loss:0.505337
#
# Start validation.
# Done. Time:0.2519457550000652
# Validation performance:
#  Avg loss:0.913901
#
# Start evaluation.
# Done. Time:1.1655257139999549
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:0.644540 [    0/ 3881]
# loss:0.529408 [ 3200/ 3881]
# Done. Time:4.25902966000001
# Training performance:
#  Avg loss:0.491535
#
# Start validation.
# Done. Time:0.4020415070000354
# Validation performance:
#  Avg loss:0.872927
#
# Start evaluation.
# Done. Time:1.145932978000019
# Test performance:
#  Accuracy:69.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:0.392639 [    0/ 3881]
# loss:0.284838 [ 3200/ 3881]
# Done. Time:2.7161677010000176
# Training performance:
#  Avg loss:0.468106
#
# Start validation.
# Done. Time:0.24756671299996924
# Validation performance:
#  Avg loss:1.010316
#
# Start evaluation.
# Done. Time:1.2094701120000764
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:0.672877 [    0/ 3881]
# loss:0.274766 [ 3200/ 3881]
# Done. Time:2.7835631369999874
# Training performance:
#  Avg loss:0.455723
#
# Start validation.
# Done. Time:0.2584828829999424
# Validation performance:
#  Avg loss:0.858318
#
# Start evaluation.
# Done. Time:1.159811848000004
# Test performance:
#  Accuracy:70.0%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:0.414719 [    0/ 3881]
# loss:0.375895 [ 3200/ 3881]
# Done. Time:4.271998130000043
# Training performance:
#  Avg loss:0.438083
#
# Start validation.
# Done. Time:0.3933272940000734
# Validation performance:
#  Avg loss:1.023131
#
# Start evaluation.
# Done. Time:1.1399712270000464
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:0.344899 [    0/ 3881]
# loss:0.350355 [ 3200/ 3881]
# Done. Time:2.6786053429999583
# Training performance:
#  Avg loss:0.421889
#
# Start validation.
# Done. Time:0.25179816700006086
# Validation performance:
#  Avg loss:0.993195
#
# Start evaluation.
# Done. Time:1.1429073130000234
# Test performance:
#  Accuracy:69.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:0.314264 [    0/ 3881]
# loss:0.354480 [ 3200/ 3881]
# Done. Time:2.8421802320000324
# Training performance:
#  Avg loss:0.405550
#
# Start validation.
# Done. Time:0.25061428000003616
# Validation performance:
#  Avg loss:0.814863
#
# Start evaluation.
# Done. Time:1.1307093269999768
# Test performance:
#  Accuracy:73.0%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:0.629367 [    0/ 3881]
# loss:0.387336 [ 3200/ 3881]
# Done. Time:4.023956797999972
# Training performance:
#  Avg loss:0.400996
#
# Start validation.
# Done. Time:0.3894539220000297
# Validation performance:
#  Avg loss:0.935457
#
# Start evaluation.
# Done. Time:1.208709075999991
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:0.176248 [    0/ 3881]
# loss:0.485929 [ 3200/ 3881]
# Done. Time:2.7394989980000446
# Training performance:
#  Avg loss:0.382726
#
# Start validation.
# Done. Time:0.25814813099998446
# Validation performance:
#  Avg loss:0.773701
#
# Start evaluation.
# Done. Time:1.1969974149999416
# Test performance:
#  Accuracy:73.5%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:0.423640 [    0/ 3881]
# loss:0.198730 [ 3200/ 3881]
# Done. Time:2.8157586020000736
# Training performance:
#  Avg loss:0.386895
#
# Start validation.
# Done. Time:0.2752984530000049
# Validation performance:
#  Avg loss:0.941737
#
# Start evaluation.
# Done. Time:1.1621207819999881
# Test performance:
#  Accuracy:70.5%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:0.343295 [    0/ 3881]
# loss:0.565155 [ 3200/ 3881]
# Done. Time:4.383364830000005
# Training performance:
#  Avg loss:0.356417
#
# Start validation.
# Done. Time:0.3898068800000374
# Validation performance:
#  Avg loss:0.775294
#
# Start evaluation.
# Done. Time:1.1745393040000636
# Test performance:
#  Accuracy:75.0%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:0.294807 [    0/ 3881]
# loss:0.265747 [ 3200/ 3881]
# Done. Time:2.743144012999892
# Training performance:
#  Avg loss:0.347104
#
# Start validation.
# Done. Time:0.25125946599996496
# Validation performance:
#  Avg loss:0.926855
#
# Start evaluation.
# Done. Time:1.138487218000023
# Test performance:
#  Accuracy:73.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:0.236718 [    0/ 3881]
# loss:0.314726 [ 3200/ 3881]
# Done. Time:2.6288971390000597
# Training performance:
#  Avg loss:0.340035
#
# Start validation.
# Done. Time:0.2525840950000884
# Validation performance:
#  Avg loss:0.847285
#
# Start evaluation.
# Done. Time:1.1362749050000502
# Test performance:
#  Accuracy:71.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:0.344813 [    0/ 3881]
# loss:0.634185 [ 3200/ 3881]
# Done. Time:4.033455240999956
# Training performance:
#  Avg loss:0.340557
#
# Start validation.
# Done. Time:0.3762473780000164
# Validation performance:
#  Avg loss:0.814532
#
# Start evaluation.
# Done. Time:1.2383005240000102
# Test performance:
#  Accuracy:73.0%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:0.355533 [    0/ 3881]
# loss:0.381171 [ 3200/ 3881]
# Done. Time:2.7116657359999863
# Training performance:
#  Avg loss:0.325992
#
# Start validation.
# Done. Time:0.2543059669999366
# Validation performance:
#  Avg loss:0.922328
#
# Start evaluation.
# Done. Time:1.1599703760000466
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:0.501083 [    0/ 3881]
# loss:0.296111 [ 3200/ 3881]
# Done. Time:2.6671512570000004
# Training performance:
#  Avg loss:0.311591
#
# Start validation.
# Done. Time:0.26305167399993934
# Validation performance:
#  Avg loss:0.853559
#
# Start evaluation.
# Done. Time:1.1542381780000142
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.455114 [    0/ 3881]
# loss:0.214586 [ 3200/ 3881]
# Done. Time:4.149157938999906
# Training performance:
#  Avg loss:0.318316
#
# Start validation.
# Done. Time:0.3836681950000411
# Validation performance:
#  Avg loss:0.829921
#
# Start evaluation.
# Done. Time:1.2267031930000485
# Test performance:
#  Accuracy:77.0%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.239222 [    0/ 3881]
# loss:0.339905 [ 3200/ 3881]
# Done. Time:2.715584584999988
# Training performance:
#  Avg loss:0.301448
#
# Start validation.
# Done. Time:0.2709885059999806
# Validation performance:
#  Avg loss:1.004462
#
# Start evaluation.
# Done. Time:1.1676750289999518
# Test performance:
#  Accuracy:70.0%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.350860 [    0/ 3881]
# loss:0.308940 [ 3200/ 3881]
# Done. Time:2.6296943899999405
# Training performance:
#  Avg loss:0.302414
#
# Start validation.
# Done. Time:0.24884966299998723
# Validation performance:
#  Avg loss:0.992439
#
# Start evaluation.
# Done. Time:1.1460494340000196
# Test performance:
#  Accuracy:70.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.308659 [    0/ 3881]
# loss:0.166900 [ 3200/ 3881]
# Done. Time:4.152098507000005
# Training performance:
#  Avg loss:0.293503
#
# Start validation.
# Done. Time:0.3830222029999959
# Validation performance:
#  Avg loss:0.878889
#
# Start evaluation.
# Done. Time:1.1915069649999168
# Test performance:
#  Accuracy:76.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.219115 [    0/ 3881]
# loss:0.105600 [ 3200/ 3881]
# Done. Time:2.77391262499998
# Training performance:
#  Avg loss:0.270663
#
# Start validation.
# Done. Time:0.2761743410000008
# Validation performance:
#  Avg loss:1.155132
#
# Start evaluation.
# Done. Time:1.1686645419999877
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.348206 [    0/ 3881]
# loss:0.460891 [ 3200/ 3881]
# Done. Time:2.685110284000075
# Training performance:
#  Avg loss:0.293767
#
# Start validation.
# Done. Time:0.2653787199999442
# Validation performance:
#  Avg loss:0.808142
#
# Start evaluation.
# Done. Time:1.1642152509999733
# Test performance:
#  Accuracy:76.0%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.262536 [    0/ 3881]
# loss:0.621895 [ 3200/ 3881]
# Done. Time:4.220962079999936
# Training performance:
#  Avg loss:0.281651
#
# Start validation.
# Done. Time:0.3857424349999974
# Validation performance:
#  Avg loss:1.121604
#
# Start evaluation.
# Done. Time:1.1695125950000147
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.112852 [    0/ 3881]
# loss:0.180110 [ 3200/ 3881]
# Done. Time:2.6857964349999293
# Training performance:
#  Avg loss:0.267725
#
# Start validation.
# Done. Time:0.2453677720000087
# Validation performance:
#  Avg loss:1.041385
#
# Start evaluation.
# Done. Time:1.1284591589999309
# Test performance:
#  Accuracy:70.0%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.127821 [    0/ 3881]
# loss:0.124586 [ 3200/ 3881]
# Done. Time:2.760104086999945
# Training performance:
#  Avg loss:0.261160
#
# Start validation.
# Done. Time:0.2614184630000409
# Validation performance:
#  Avg loss:0.991816
#
# Start evaluation.
# Done. Time:1.1678757370000312
# Test performance:
#  Accuracy:73.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.491735 [    0/ 3881]
# loss:0.246583 [ 3200/ 3881]
# Done. Time:4.070750497000063
# Training performance:
#  Avg loss:0.254946
#
# Start validation.
# Done. Time:0.36979561399994054
# Validation performance:
#  Avg loss:0.865809
#
# Start evaluation.
# Done. Time:1.2185968329999923
# Test performance:
#  Accuracy:75.5%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.319795 [    0/ 3881]
# loss:0.252317 [ 3200/ 3881]
# Done. Time:2.682504902000005
# Training performance:
#  Avg loss:0.233892
#
# Start validation.
# Done. Time:0.26118611799995506
# Validation performance:
#  Avg loss:1.166618
#
# Start evaluation.
# Done. Time:1.1818646790000003
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.166468 [    0/ 3881]
# loss:0.215183 [ 3200/ 3881]
# Done. Time:2.8046692570000005
# Training performance:
#  Avg loss:0.265307
#
# Start validation.
# Done. Time:0.2427081129999351
# Validation performance:
#  Avg loss:1.095610
#
# Start evaluation.
# Done. Time:1.1386933589999444
# Test performance:
#  Accuracy:69.5%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.234335 [    0/ 3881]
# loss:0.156965 [ 3200/ 3881]
# Done. Time:4.061254850999944
# Training performance:
#  Avg loss:0.244760
#
# Start validation.
# Done. Time:0.3869447309999714
# Validation performance:
#  Avg loss:0.832564
#
# Start evaluation.
# Done. Time:1.2666784179999695
# Test performance:
#  Accuracy:77.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.210911 [    0/ 3881]
# loss:0.122514 [ 3200/ 3881]
# Done. Time:2.710413647999985
# Training performance:
#  Avg loss:0.244993
#
# Start validation.
# Done. Time:0.2579323539999905
# Validation performance:
#  Avg loss:1.087704
#
# Start evaluation.
# Done. Time:1.1650555170000416
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.355042 [    0/ 3881]
# loss:0.284640 [ 3200/ 3881]
# Done. Time:2.69054547799999
# Training performance:
#  Avg loss:0.220660
#
# Start validation.
# Done. Time:0.24359657600007267
# Validation performance:
#  Avg loss:1.156138
#
# Start evaluation.
# Done. Time:1.164954347000048
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.133091 [    0/ 3881]
# loss:0.241073 [ 3200/ 3881]
# Done. Time:4.120273509999947
# Training performance:
#  Avg loss:0.237904
#
# Start validation.
# Done. Time:0.3874544419999211
# Validation performance:
#  Avg loss:1.025940
#
# Start evaluation.
# Done. Time:1.2004751020000413
# Test performance:
#  Accuracy:77.5%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.065188 [    0/ 3881]
# loss:0.288248 [ 3200/ 3881]
# Done. Time:2.7321767590000263
# Training performance:
#  Avg loss:0.216469
#
# Start validation.
# Done. Time:0.26298243799999454
# Validation performance:
#  Avg loss:1.333952
#
# Start evaluation.
# Done. Time:1.1412080279999373
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.103322 [    0/ 3881]
# loss:0.146810 [ 3200/ 3881]
# Done. Time:2.6614997980000226
# Training performance:
#  Avg loss:0.217646
#
# Start validation.
# Done. Time:0.2930855130000509
# Validation performance:
#  Avg loss:1.193730
#
# Start evaluation.
# Done. Time:1.1350540030000502
# Test performance:
#  Accuracy:71.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.106298 [    0/ 3881]
# loss:0.391259 [ 3200/ 3881]
# Done. Time:4.125619727999947
# Training performance:
#  Avg loss:0.211570
#
# Start validation.
# Done. Time:0.3884127559999797
# Validation performance:
#  Avg loss:1.048007
#
# Start evaluation.
# Done. Time:1.2575365569999803
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.395539 [    0/ 3881]
# loss:0.308499 [ 3200/ 3881]
# Done. Time:2.8171631819999448
# Training performance:
#  Avg loss:0.211432
#
# Start validation.
# Done. Time:0.25246926900001654
# Validation performance:
#  Avg loss:1.172995
#
# Start evaluation.
# Done. Time:1.21848791299999
# Test performance:
#  Accuracy:69.5%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.208622 [    0/ 3881]
# loss:0.439007 [ 3200/ 3881]
# Done. Time:2.64515223300009
# Training performance:
#  Avg loss:0.203166
#
# Start validation.
# Done. Time:0.255826844000012
# Validation performance:
#  Avg loss:1.024260
#
# Start evaluation.
# Done. Time:1.137425449000034
# Test performance:
#  Accuracy:72.0%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.207899 [    0/ 3881]
# loss:0.285167 [ 3200/ 3881]
# Done. Time:4.370568530000014
# Training performance:
#  Avg loss:0.203514
#
# Start validation.
# Done. Time:0.38548953099996197
# Validation performance:
#  Avg loss:1.022518
#
# Start evaluation.
# Done. Time:1.1802788870000995
# Test performance:
#  Accuracy:73.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.149614 [    0/ 3881]
# loss:0.223060 [ 3200/ 3881]
# Done. Time:2.7613462729999583
# Training performance:
#  Avg loss:0.210263
#
# Start validation.
# Done. Time:0.24510787199994866
# Validation performance:
#  Avg loss:0.952962
#
# Start evaluation.
# Done. Time:1.1480944369999406
# Test performance:
#  Accuracy:72.0%
# Minimum validation loss:0.7737005438123431 at 20 epoch.
# Maximum accuracy:77.5 at 40 epoch.

# %% [markdown]
# ### Plort result
# #### Recognition performance

# %%
import matplotlib.pyplot as plt

plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(val_losses_trans)+1)
plt.plot(xs, val_losses_trans, label="Transformer", marker=".")
plt.plot(xs, val_losses_macaron, label="Macaron-Net", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.ylim([0.0, 2.5])
plt.legend()
plt.show()

# %%
plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(test_accs_trans)+1)
plt.plot(xs, test_accs_trans, label="Transformer", marker=".")
plt.plot(xs, test_accs_macaron, label="Macaron-Net", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.ylim([0.0, 100.0])
plt.legend()
plt.show()
