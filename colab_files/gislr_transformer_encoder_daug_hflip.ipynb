# %% [markdown]
# <a href="https://colab.research.google.com/github/takayama-rado/trado_samples/blob/main/colab_files/gislr_transformer_encoder_daug_hflip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Download dataset and modules

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Copy to local.
# !cp drive/MyDrive/Datasets/gislr_dataset_top10.zip gislr_top10.zip

# %%
# !unzip -o gislr_top10.zip
# Out:
# Archive:  gislr_top10.zip
#    creating: dataset_top10/
#   inflating: dataset_top10/16069.hdf5
#   inflating: dataset_top10/18796.hdf5
#   inflating: dataset_top10/2044.hdf5
#   inflating: dataset_top10/22343.hdf5
#   inflating: dataset_top10/25571.hdf5
#   inflating: dataset_top10/26734.hdf5
#   inflating: dataset_top10/27610.hdf5
#   inflating: dataset_top10/28656.hdf5
#   inflating: dataset_top10/29302.hdf5
#   inflating: dataset_top10/30680.hdf5
#   inflating: dataset_top10/32319.hdf5
#   inflating: dataset_top10/34503.hdf5
#   inflating: dataset_top10/36257.hdf5
#   inflating: dataset_top10/37055.hdf5
#   inflating: dataset_top10/37779.hdf5
#   inflating: dataset_top10/4718.hdf5
#   inflating: dataset_top10/49445.hdf5
#   inflating: dataset_top10/53618.hdf5
#   inflating: dataset_top10/55372.hdf5
#   inflating: dataset_top10/61333.hdf5
#   inflating: dataset_top10/62590.hdf5
#   inflating: dataset_top10/LICENSE.txt
#   inflating: dataset_top10/sign_to_prediction_index_map.json

# %%
# !ls dataset_top10
# Out:
# 16069.hdf5  25571.hdf5	29302.hdf5  36257.hdf5	49445.hdf5  62590.hdf5
# 18796.hdf5  26734.hdf5	30680.hdf5  37055.hdf5	53618.hdf5  LICENSE.txt
# 2044.hdf5   27610.hdf5	32319.hdf5  37779.hdf5	55372.hdf5  sign_to_prediction_index_map.json
# 22343.hdf5  28656.hdf5	34503.hdf5  4718.hdf5	61333.hdf5

# %%
# !cat dataset_top10/sign_to_prediction_index_map.json
# Out:
# {
#     "listen": 0,
#     "look": 1,
#     "shhh": 2,
#     "donkey": 3,
#     "mouse": 4,
#     "duck": 5,
#     "uncle": 6,
#     "hear": 7,
#     "pretend": 8,
#     "cow": 9
# }

# %%
# !cat dataset_top10/LICENSE.txt
# Out:
# The dataset provided by Natsuki Takayama (Takayama Research and Development Office) is licensed under CC-BY 4.0.
# Author: Copyright 2024 Natsuki Takayama
# Title: GISLR Top 10 dataset
# Original licenser: Deaf Professional Arts Network and the Georgia Institute of Technology
# Modification
# - Extract 10 most frequent words.
# - Packaged into HDF5 format.

# %%
import h5py
with h5py.File("dataset_top10/16069.hdf5", "r") as fread:
    keys = list(fread.keys())
    print(keys)
    group = fread[keys[0]]
    print(group.keys())
    feature = group["feature"][:]
    token = group["token"][:]
    print(feature.shape)
    print(token)
# Out:
# ['1109479272', '11121526', '1120349077', '1125456612', '1159046211', '1169128497', '1186032553', '1223803476', '1259708636', '1281972067', '129232566', '1334702305', '1340979012', '1352964057', '1370052047', '1383455381', '1431148933', '1435203624', '1437919781', '1458770030', '1462881097', '1469867050', '1474050058', '147607644', '1513539919', '1520635928', '1524297234', '153676122', '1537751003', '1542212461', '1551759770', '158232956', '1585855916', '1632709119', '1638742455', '1696757219', '177479476', '1779635114', '1791684792', '1801566440', '1831167282', '1867385690', '1880570146', '1901587887', '1910121429', '1919659282', '192873038', '1935012113', '1949620203', '195098847', '1983552660', '1989475963', '1998715062', '2007709802', '2036010239', '2036360025', '2046296211', '2082116372', '2098813002', '2109640010', '2121879330', '2141852087', '2148832702', '2152013823', '2166805079', '2176613834', '2184232774', '2213965523', '2249630763', '2256677805', '2263287955', '2263683020', '2264826605', '2270117351', '2281372282', '2285328250', '2322449232', '2326092712', '2336131857', '2346410171', '2405684784', '2467219838', '2473091535', '2488751095', '2515673021', '252176572', '2555449229', '2601816518', '2624310025', '2672738462', '2679264929', '2708514724', '2708544445', '2721276879', '2723773273', '2728839865', '2740241949', '2758304792', '2772051790', '2779816680', '2804441762', '2811346655', '2811646800', '2820103955', '2839681895', '2900998385', '2976200180', '2994456336', '3057994128', '3095010437', '3104317075', '3109672704', '3137179145', '3153285641', '3173321541', '3181666887', '3201889607', '3208820205', '3248401349', '3280527321', '3283246198', '3300057240', '3355963469', '3378306304', '3383637897', '3395075403', '3399503065', '3417877266', '3433092803', '347484677', '348956807', '3490841593', '3509324997', '3527069516', '3537611572', '3543711249', '3550826234', '3574700791', '3577812263', '3608551465', '3609537739', '3622960580', '3666781780', '3701422761', '3721927307', '3751410902', '3756613238', '3769544385', '3783554953', '3794712078', '380369091', '3813230821', '3817572483', '3843929707', '3869664504', '3892179393', '3923913515', '3981562204', '4078929101', '4101587978', '4150900444', '4191136837', '4200829752', '4209136328', '420958416', '422113773', '42222766', '4233346443', '4233985575', '4236057556', '4252161228', '425542996', '4276854486', '4294775577', '431609031', '439844759', '446236576', '470582324', '472128010', '492897929', '537402693', '5501547', '561170018', '593416697', '631898947', '649410423', '654529993', '678960043', '699907539', '707716966', '713615518', '778875120', '792981518', '796465415', '798649922', '856068671', '923153024', '957739544', '970593849', '976754415']
# <KeysViewHDF5 ['feature', 'token']>
# (3, 23, 543)
# [1]

# %%
# !wget https://github.com/takayama-rado/trado_samples/archive/master.zip
# Out:
# --2024-05-06 02:47:26--  https://github.com/takayama-rado/trado_samples/archive/master.zip
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/takayama-rado/trado_samples/zip/main [following]
# --2024-05-06 02:47:26--  https://codeload.github.com/takayama-rado/trado_samples/zip/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.116.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.116.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [            <=>     ]  74.85M  19.0MB/s    in 3.9s
#
# 2024-05-06 02:47:30 (19.0 MB/s) - ‘master.zip’ saved [78481816]

# %%
# !unzip -o master.zip -d master
# Out:
# Archive:  master.zip
# 756735ccb11e88d80dc1a5b703aa74aa9ad67fd3
#    creating: master/trado_samples-main/
#   inflating: master/trado_samples-main/.gitignore
#   inflating: master/trado_samples-main/LICENSE
#   inflating: master/trado_samples-main/README.md
#    creating: master/trado_samples-main/colab_files/
#  extracting: master/trado_samples-main/colab_files/.gitkeep
#   inflating: master/trado_samples-main/colab_files/exp_affine_np_einsum.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_jax_static.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_mpholistic_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_mpothers_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_jax.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_numpy.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_tensorflow.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_torch.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_jax.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_numpy_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_numpy_1.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_tensorflow.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_torch.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_access_dataset.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_normalize_landmarks.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_rnn_islr_model_1.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_rnn_islr_model_2.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_rnn_islr_model_3.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_select_landmarks.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_simple_attention.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_simple_islr_model.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_transformer_encoder.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_transformer_encoder_w_ls.ipynb
#    creating: master/trado_samples-main/src/
#    creating: master/trado_samples-main/src/modules_gislr/
#  extracting: master/trado_samples-main/src/modules_gislr/__init__.py
#   inflating: master/trado_samples-main/src/modules_gislr/dataset.py
#   inflating: master/trado_samples-main/src/modules_gislr/defines.py
#   inflating: master/trado_samples-main/src/modules_gislr/draw_functions.py
#   inflating: master/trado_samples-main/src/modules_gislr/layers.py
#   inflating: master/trado_samples-main/src/modules_gislr/train_functions.py
#   inflating: master/trado_samples-main/src/modules_gislr/transforms.py
#   inflating: master/trado_samples-main/src/modules_gislr/utils.py
#    creating: master/trado_samples-main/test_data/
#   inflating: master/trado_samples-main/test_data/finger_far0.mp4
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static.npy
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static_affine.npy
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static_interp.npy
#   inflating: master/trado_samples-main/test_data/finger_middle0.mp4
#   inflating: master/trado_samples-main/test_data/finger_near0.mp4
#   inflating: master/trado_samples-main/test_data/hand_only.mp4

# %%
# !mv master/trado_samples-main/src/modules_gislr .

# %%
# !rm -rf master master.zip gislr_top10.zip

# %%
# !ls
# Out:
# dataset_top10  drive  modules_gislr  sample_data

# %% [markdown]
# # 2. Load library

# %%
import copy
import json
import math
import os
import random
import sys
from functools import partial
from inspect import signature
from pathlib import Path
from typing import (
    Any,
    Dict,
    List
)

# Third party's modules
import numpy as np

import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import (
    DataLoader)

from torchvision.transforms import Compose

# Local modules
sys.path.append("modules_gislr")
from modules_gislr.dataset import (
    HDF5Dataset,
    merge_padded_batch)
from modules_gislr.defines import (
    get_fullbody_landmarks,
    get_fullbody_swappairs,
)
from modules_gislr.layers import (
    Identity,
    GPoolRecognitionHead,
    TransformerEnISLR
)
from modules_gislr.train_functions import (
    test_loop,
    val_loop,
    train_loop
)
from modules_gislr.transforms import (
    PartsBasedNormalization,
    ReplaceNan,
    SelectLandmarksAndFeature,
    ToTensor
)

# %% [markdown]
# # 3. Implement horizontal flip.

# %%
class RandomHorizontalFlip():
    """Horizontally flip the keypoints randomly.

    # Args:
      - apply_ratio: The ratio to apply augmentation.
      - num_joints: The number of input joints.
      - swap_pairs: The pairs of exchanged joint indices.
      - flip_center: The center position of horizontal flipping.
        The swapped joints are calculated as bellow.
        swapped_x = -(orig_x - flip_center) + flip_center
                  = -orig_x + 2*flip_center
      - feature_dim: The expected dimension of each joint.
      - include_conf: If True, we assume each joint includes confidence value
        after the coordinates.
      - post_offset_x: The offset translation in the post process.
        This intended to adjust flip center.
    """
    def __init__(self,
                 apply_ratio: float,
                 num_joints: int,
                 swap_pairs: List[List[int]],
                 flip_center: float = 0.5,
                 feature_dim: int = 2,
                 include_conf: bool = True) -> None:
        self.apply_ratio = apply_ratio
        self.flip_center = flip_center
        self.feature_dim = feature_dim + 1 if include_conf else feature_dim

        indices = np.arange(0, num_joints, 1)
        for pair in swap_pairs:
            indices[pair[0]] = pair[1]
            indices[pair[1]] = pair[0]
        self.swap_indices = indices

    def __call__(self,
                 data: Dict[str, Any]) -> Dict[str, Any]:
        """Execute flipping.
        """
        if random.random() > self.apply_ratio:
            return data

        feature = data["feature"]
        # Flip positions.
        temp = copy.deepcopy(feature)
        shape = temp.shape
        # `[C, T, J] -> [C, T*J]`
        temp = temp.reshape([self.feature_dim, -1])

        # Filter out when all elements == 0.
        # (it should be confidence == 0).
        row_indices = np.where((temp == 0).all(axis=0) == np.True_)[0]
        temp[0, :] = -temp[0, :] + 2 * self.flip_center
        temp[:, row_indices] = np.array([0] * self.feature_dim)[:, None]
        temp = temp.reshape(shape)
        temp = temp[:, :, self.swap_indices]
        assert temp.shape == feature.shape, f"{temp.shape}, {feature.shape}"

        data["feature"] = temp
        return data

    def __str__(self):
        return f"{self.__class__.__name__}:{self.__dict__}"

# %% [markdown]
# # 4. Sanity check

# %%
# Access check.
dataset_dir = Path("dataset_top10")
files = list(dataset_dir.iterdir())
dictionary = [fin for fin in files if ".json" in fin.name][0]
hdf5_files = [fin for fin in files if ".hdf5" in fin.name]

print(dictionary)
print(hdf5_files)
# Out:
# dataset_top10/sign_to_prediction_index_map.json
# [PosixPath('dataset_top10/25571.hdf5'), PosixPath('dataset_top10/29302.hdf5'), PosixPath('dataset_top10/32319.hdf5'), PosixPath('dataset_top10/36257.hdf5'), PosixPath('dataset_top10/37779.hdf5'), PosixPath('dataset_top10/27610.hdf5'), PosixPath('dataset_top10/34503.hdf5'), PosixPath('dataset_top10/53618.hdf5'), PosixPath('dataset_top10/37055.hdf5'), PosixPath('dataset_top10/61333.hdf5'), PosixPath('dataset_top10/16069.hdf5'), PosixPath('dataset_top10/62590.hdf5'), PosixPath('dataset_top10/18796.hdf5'), PosixPath('dataset_top10/22343.hdf5'), PosixPath('dataset_top10/55372.hdf5'), PosixPath('dataset_top10/49445.hdf5'), PosixPath('dataset_top10/28656.hdf5'), PosixPath('dataset_top10/30680.hdf5'), PosixPath('dataset_top10/26734.hdf5'), PosixPath('dataset_top10/2044.hdf5'), PosixPath('dataset_top10/4718.hdf5')]

# %%
# Load dictionary.
with open(dictionary, "r") as fread:
    key2token = json.load(fread)

VOCAB = len(key2token)

# %%
_, use_landmarks = get_fullbody_landmarks()
swap_pairs, _ = get_fullbody_swappairs()
use_features = ["x", "y"]
trans_select_feature = SelectLandmarksAndFeature(landmarks=use_landmarks, features=use_features)
trans_repnan = ReplaceNan()
trans_norm = PartsBasedNormalization(align_mode="framewise", scale_mode="unique")

pre_transforms = Compose([trans_select_feature,
                          trans_repnan,
                          trans_norm])
transforms_default = Compose([ToTensor()])

transforms_w_daug = Compose([
    RandomHorizontalFlip(
        apply_ratio=0.5,
        num_joints=len(use_landmarks),
        swap_pairs=swap_pairs,
        flip_center=0.0,
        feature_dim=2,
        include_conf=False),
    ToTensor()])

# %%
batch_size = 2
feature_shape = (len(use_features), -1, len(use_landmarks))
token_shape = (1,)
merge_fn = partial(merge_padded_batch,
                   feature_shape=feature_shape,
                   token_shape=token_shape,
                   feature_padding_val=0.0,
                   token_padding_val=0)

dataset = HDF5Dataset(hdf5_files, pre_transforms=pre_transforms, transforms=transforms_w_daug)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=merge_fn)
try:
    data = next(iter(dataloader))
    feature_origin = data["feature"]

    print(feature_origin.shape)
except Exception as inst:
    print(inst)
# Out:
# torch.Size([2, 2, 10, 130])

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
inter_channels = 64
out_channels = VOCAB
activation = "relu"
tren_num_layers = 2
tren_num_heads = 2
tren_dim_ffw = 256
tren_dropout_pe = 0.1
tren_dropout = 0.1
tren_layer_norm_eps = 1e-5
tren_norm_first = True
tren_add_bias = True
tren_add_tailnorm = True

model = TransformerEnISLR(in_channels=in_channels,
                          inter_channels=inter_channels,
                          out_channels=out_channels,
                          activation=activation,
                          tren_num_layers=tren_num_layers,
                          tren_num_heads=tren_num_heads,
                          tren_dim_ffw=tren_dim_ffw,
                          tren_dropout_pe=tren_dropout_pe,
                          tren_dropout=tren_dropout,
                          tren_layer_norm_eps=tren_layer_norm_eps,
                          tren_norm_first=tren_norm_first,
                          tren_add_bias=tren_add_bias,
                          tren_add_tailnorm=tren_add_tailnorm)
print(model)

# Sanity check.
logit = model(feature_origin)
print(logit.shape)
attw0 = model.tr_encoder.layers[0].attw.detach().cpu().numpy()
attw1 = model.tr_encoder.layers[0].attw.detach().cpu().numpy()
print(attw0.shape, attw1.shape)
# Out:
# TransformerEnISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (tr_encoder): TransformerEncoder(
#     (pos_encoder): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (w_key): Linear(in_features=64, out_features=64, bias=True)
#           (w_value): Linear(in_features=64, out_features=64, bias=True)
#           (w_query): Linear(in_features=64, out_features=64, bias=True)
#           (w_out): Linear(in_features=64, out_features=64, bias=True)
#           (dropout_attn): Dropout(p=0.1, inplace=False)
#         )
#         (ffw): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=256, bias=True)
#           (w_2): Linear(in_features=256, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#         (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])
# (2, 2, 10, 10) (2, 2, 10, 10)

# %% [markdown]
# # 5. Train and evaluation

# %% [markdown]
# ## 5.1 Set common parameters.

# %%
# Set common parameters.
batch_size = 32
load_into_ram = True
test_pid = 16069
num_workers = os.cpu_count()
print(f"Using {num_workers} cores for data loading.")
lr = 3e-4

epochs = 50
eval_every_n_epochs = 1
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} for computation.")

train_hdf5files = [fin for fin in hdf5_files if str(test_pid) not in fin.name]
val_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]
test_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]

_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
# Out:
# Using 2 cores for data loading.
# Using cuda for computation.

# %% [markdown]
# ## 5.2 Run training process

# %% [markdown]
# ### Default settings

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(
    train_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_default,
    load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(
    val_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_default,
    load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(
    test_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_default,
    load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)

# %%
tren_norm_first = True
tren_add_tailnorm = True

model_default = TransformerEnISLR(
    in_channels=in_channels,
    inter_channels=inter_channels,
    out_channels=out_channels,
    activation=activation,
    tren_num_layers=tren_num_layers,
    tren_num_heads=tren_num_heads,
    tren_dim_ffw=tren_dim_ffw,
    tren_dropout_pe=tren_dropout_pe,
    tren_dropout=tren_dropout,
    tren_layer_norm_eps=tren_layer_norm_eps,
    tren_norm_first=tren_norm_first,
    tren_add_bias=tren_add_bias,
    tren_add_tailnorm=tren_add_tailnorm)
print(model_default)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model_default.parameters(), lr=lr)
# Out:
# TransformerEnISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (tr_encoder): TransformerEncoder(
#     (pos_encoder): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (w_key): Linear(in_features=64, out_features=64, bias=True)
#           (w_value): Linear(in_features=64, out_features=64, bias=True)
#           (w_query): Linear(in_features=64, out_features=64, bias=True)
#           (w_out): Linear(in_features=64, out_features=64, bias=True)
#           (dropout_attn): Dropout(p=0.1, inplace=False)
#         )
#         (ffw): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=256, bias=True)
#           (w_2): Linear(in_features=256, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#         (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model_default.to(device)

train_losses = []
val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_losses = train_loop(train_dataloader, model_default, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model_default, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model_default, device)
        test_accs.append(acc)
train_losses_default = np.array(train_losses)
val_losses_default = np.array(val_losses)
test_accs_default = np.array(test_accs)

print(f"Minimum validation loss:{val_losses_default.min()} at {np.argmin(val_losses_default)+1} epoch.")
print(f"Maximum accuracy:{test_accs_default.max()} at {np.argmax(test_accs_default)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# loss:3.609038 [    0/ 3881]
# loss:1.963860 [ 3200/ 3881]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Done. Time:3.981357500999991
# Training performance:
#  Avg loss:2.207429
#
# Start validation.
# Done. Time:0.2220761939999818
# Validation performance:
#  Avg loss:2.024836
#
# Start evaluation.
# Done. Time:1.2789244779999933
# Test performance:
#  Accuracy:28.0%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:1.918701 [    0/ 3881]
# loss:1.205049 [ 3200/ 3881]
# Done. Time:3.8259336970000106
# Training performance:
#  Avg loss:1.486995
#
# Start validation.
# Done. Time:0.216481468000012
# Validation performance:
#  Avg loss:1.722514
#
# Start evaluation.
# Done. Time:1.0895257710000124
# Test performance:
#  Accuracy:40.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.170488 [    0/ 3881]
# loss:1.269139 [ 3200/ 3881]
# Done. Time:2.5793711310000162
# Training performance:
#  Avg loss:1.103475
#
# Start validation.
# Done. Time:0.22417321999998308
# Validation performance:
#  Avg loss:1.859631
#
# Start evaluation.
# Done. Time:1.1166583969999806
# Test performance:
#  Accuracy:42.5%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:0.871591 [    0/ 3881]
# loss:0.784624 [ 3200/ 3881]
# Done. Time:2.560222328000009
# Training performance:
#  Avg loss:0.928277
#
# Start validation.
# Done. Time:0.23526092600002357
# Validation performance:
#  Avg loss:1.527206
#
# Start evaluation.
# Done. Time:1.1624057870000115
# Test performance:
#  Accuracy:47.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:0.970828 [    0/ 3881]
# loss:0.845087 [ 3200/ 3881]
# Done. Time:3.9557090600000038
# Training performance:
#  Avg loss:0.834372
#
# Start validation.
# Done. Time:0.23324327299999936
# Validation performance:
#  Avg loss:1.620390
#
# Start evaluation.
# Done. Time:1.0870767109999804
# Test performance:
#  Accuracy:45.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.123115 [    0/ 3881]
# loss:0.642431 [ 3200/ 3881]
# Done. Time:2.5506302770000104
# Training performance:
#  Avg loss:0.760994
#
# Start validation.
# Done. Time:0.22923446999999442
# Validation performance:
#  Avg loss:1.342439
#
# Start evaluation.
# Done. Time:1.1011073429999954
# Test performance:
#  Accuracy:51.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:0.837411 [    0/ 3881]
# loss:0.432314 [ 3200/ 3881]
# Done. Time:2.5787204489999738
# Training performance:
#  Avg loss:0.692052
#
# Start validation.
# Done. Time:0.23353974200000494
# Validation performance:
#  Avg loss:1.270360
#
# Start evaluation.
# Done. Time:1.0826120309999965
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:0.652200 [    0/ 3881]
# loss:0.836640 [ 3200/ 3881]
# Done. Time:4.023359411999991
# Training performance:
#  Avg loss:0.645730
#
# Start validation.
# Done. Time:0.22598169599999096
# Validation performance:
#  Avg loss:1.163905
#
# Start evaluation.
# Done. Time:1.085145898999997
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:0.627631 [    0/ 3881]
# loss:0.695522 [ 3200/ 3881]
# Done. Time:2.5580095349999965
# Training performance:
#  Avg loss:0.603693
#
# Start validation.
# Done. Time:0.22018685399999072
# Validation performance:
#  Avg loss:1.078374
#
# Start evaluation.
# Done. Time:1.0777770980000128
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:0.558630 [    0/ 3881]
# loss:0.275928 [ 3200/ 3881]
# Done. Time:2.6106886850000137
# Training performance:
#  Avg loss:0.584981
#
# Start validation.
# Done. Time:0.22770122200000742
# Validation performance:
#  Avg loss:1.005392
#
# Start evaluation.
# Done. Time:1.1240258450000056
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:0.686808 [    0/ 3881]
# loss:0.422323 [ 3200/ 3881]
# Done. Time:4.030155315999991
# Training performance:
#  Avg loss:0.554621
#
# Start validation.
# Done. Time:0.22137761900000896
# Validation performance:
#  Avg loss:1.007961
#
# Start evaluation.
# Done. Time:1.1113168210000026
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:0.509514 [    0/ 3881]
# loss:0.219698 [ 3200/ 3881]
# Done. Time:3.0432794609999974
# Training performance:
#  Avg loss:0.514016
#
# Start validation.
# Done. Time:0.23984091799999874
# Validation performance:
#  Avg loss:0.941609
#
# Start evaluation.
# Done. Time:1.1114467129999923
# Test performance:
#  Accuracy:68.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:0.571248 [    0/ 3881]
# loss:0.618528 [ 3200/ 3881]
# Done. Time:2.638496773000014
# Training performance:
#  Avg loss:0.481383
#
# Start validation.
# Done. Time:0.2248899629999812
# Validation performance:
#  Avg loss:1.112474
#
# Start evaluation.
# Done. Time:1.1220880889999876
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:0.312821 [    0/ 3881]
# loss:0.535376 [ 3200/ 3881]
# Done. Time:4.1248710579999965
# Training performance:
#  Avg loss:0.469953
#
# Start validation.
# Done. Time:0.23992666099999838
# Validation performance:
#  Avg loss:1.294619
#
# Start evaluation.
# Done. Time:1.116541973000011
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:0.294834 [    0/ 3881]
# loss:0.379259 [ 3200/ 3881]
# Done. Time:2.5991193590000137
# Training performance:
#  Avg loss:0.456392
#
# Start validation.
# Done. Time:0.22263013500000284
# Validation performance:
#  Avg loss:0.851455
#
# Start evaluation.
# Done. Time:1.1170856589999971
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:0.385081 [    0/ 3881]
# loss:0.514132 [ 3200/ 3881]
# Done. Time:2.5729893500000003
# Training performance:
#  Avg loss:0.432375
#
# Start validation.
# Done. Time:0.22559382000000028
# Validation performance:
#  Avg loss:0.895904
#
# Start evaluation.
# Done. Time:1.1055860179999968
# Test performance:
#  Accuracy:70.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:0.470705 [    0/ 3881]
# loss:0.342156 [ 3200/ 3881]
# Done. Time:4.1970558470000014
# Training performance:
#  Avg loss:0.408718
#
# Start validation.
# Done. Time:0.2349476690000074
# Validation performance:
#  Avg loss:0.978632
#
# Start evaluation.
# Done. Time:1.1213797739999904
# Test performance:
#  Accuracy:71.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:0.285397 [    0/ 3881]
# loss:0.378422 [ 3200/ 3881]
# Done. Time:2.6047628919999966
# Training performance:
#  Avg loss:0.406274
#
# Start validation.
# Done. Time:0.22743687999999906
# Validation performance:
#  Avg loss:0.710418
#
# Start evaluation.
# Done. Time:1.0980733510000107
# Test performance:
#  Accuracy:74.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:0.370149 [    0/ 3881]
# loss:0.301787 [ 3200/ 3881]
# Done. Time:2.5866917129999933
# Training performance:
#  Avg loss:0.397833
#
# Start validation.
# Done. Time:0.2268408440000087
# Validation performance:
#  Avg loss:0.831008
#
# Start evaluation.
# Done. Time:1.1034960990000116
# Test performance:
#  Accuracy:74.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:0.253816 [    0/ 3881]
# loss:0.186258 [ 3200/ 3881]
# Done. Time:4.082107788999991
# Training performance:
#  Avg loss:0.385354
#
# Start validation.
# Done. Time:0.24829815500001473
# Validation performance:
#  Avg loss:1.034544
#
# Start evaluation.
# Done. Time:1.1250001600000132
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:0.140371 [    0/ 3881]
# loss:0.546281 [ 3200/ 3881]
# Done. Time:2.6209181090000016
# Training performance:
#  Avg loss:0.367921
#
# Start validation.
# Done. Time:0.22421691699997837
# Validation performance:
#  Avg loss:0.872970
#
# Start evaluation.
# Done. Time:1.1222182629999793
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:0.382167 [    0/ 3881]
# loss:0.237792 [ 3200/ 3881]
# Done. Time:2.594217020000002
# Training performance:
#  Avg loss:0.339578
#
# Start validation.
# Done. Time:0.2264440319999892
# Validation performance:
#  Avg loss:0.844747
#
# Start evaluation.
# Done. Time:1.119704578000011
# Test performance:
#  Accuracy:73.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:0.291567 [    0/ 3881]
# loss:0.389372 [ 3200/ 3881]
# Done. Time:4.872568722000011
# Training performance:
#  Avg loss:0.339796
#
# Start validation.
# Done. Time:0.24297421800000052
# Validation performance:
#  Avg loss:0.799748
#
# Start evaluation.
# Done. Time:1.1661623239999983
# Test performance:
#  Accuracy:71.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:0.165792 [    0/ 3881]
# loss:0.381825 [ 3200/ 3881]
# Done. Time:2.6328260530000023
# Training performance:
#  Avg loss:0.320767
#
# Start validation.
# Done. Time:0.22093445800001632
# Validation performance:
#  Avg loss:0.721472
#
# Start evaluation.
# Done. Time:1.1197670389999814
# Test performance:
#  Accuracy:78.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:0.147878 [    0/ 3881]
# loss:0.252027 [ 3200/ 3881]
# Done. Time:2.5538858869999785
# Training performance:
#  Avg loss:0.303112
#
# Start validation.
# Done. Time:0.24489453500001446
# Validation performance:
#  Avg loss:0.903697
#
# Start evaluation.
# Done. Time:1.138196143000016
# Test performance:
#  Accuracy:71.0%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:0.347547 [    0/ 3881]
# loss:0.631913 [ 3200/ 3881]
# Done. Time:4.137701276000001
# Training performance:
#  Avg loss:0.330099
#
# Start validation.
# Done. Time:0.2253912970000158
# Validation performance:
#  Avg loss:0.783142
#
# Start evaluation.
# Done. Time:1.1145916529999909
# Test performance:
#  Accuracy:75.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:0.258785 [    0/ 3881]
# loss:0.310488 [ 3200/ 3881]
# Done. Time:2.5937255429999766
# Training performance:
#  Avg loss:0.301004
#
# Start validation.
# Done. Time:0.2383583250000072
# Validation performance:
#  Avg loss:0.969417
#
# Start evaluation.
# Done. Time:1.1178008579999812
# Test performance:
#  Accuracy:72.0%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.621984 [    0/ 3881]
# loss:0.077423 [ 3200/ 3881]
# Done. Time:2.6411884249999957
# Training performance:
#  Avg loss:0.293767
#
# Start validation.
# Done. Time:0.23804953600000545
# Validation performance:
#  Avg loss:1.001801
#
# Start evaluation.
# Done. Time:1.1156613429999993
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.354396 [    0/ 3881]
# loss:0.214229 [ 3200/ 3881]
# Done. Time:4.116256480000004
# Training performance:
#  Avg loss:0.296981
#
# Start validation.
# Done. Time:0.22864789900000915
# Validation performance:
#  Avg loss:0.873272
#
# Start evaluation.
# Done. Time:1.1146756560000028
# Test performance:
#  Accuracy:73.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.199237 [    0/ 3881]
# loss:0.258696 [ 3200/ 3881]
# Done. Time:2.695984710999994
# Training performance:
#  Avg loss:0.283748
#
# Start validation.
# Done. Time:0.2454386320000026
# Validation performance:
#  Avg loss:1.119795
#
# Start evaluation.
# Done. Time:1.1289997380000045
# Test performance:
#  Accuracy:70.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.329980 [    0/ 3881]
# loss:0.181171 [ 3200/ 3881]
# Done. Time:2.667551352999965
# Training performance:
#  Avg loss:0.294654
#
# Start validation.
# Done. Time:0.2400108059999866
# Validation performance:
#  Avg loss:1.148049
#
# Start evaluation.
# Done. Time:1.1258217790000344
# Test performance:
#  Accuracy:71.5%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.170276 [    0/ 3881]
# loss:0.184187 [ 3200/ 3881]
# Done. Time:4.141801072000021
# Training performance:
#  Avg loss:0.260867
#
# Start validation.
# Done. Time:0.23460680800002365
# Validation performance:
#  Avg loss:0.956375
#
# Start evaluation.
# Done. Time:1.1322481519999883
# Test performance:
#  Accuracy:75.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.305038 [    0/ 3881]
# loss:0.434395 [ 3200/ 3881]
# Done. Time:2.6276980729999764
# Training performance:
#  Avg loss:0.251765
#
# Start validation.
# Done. Time:0.21981157300001541
# Validation performance:
#  Avg loss:1.198876
#
# Start evaluation.
# Done. Time:1.1157689319999804
# Test performance:
#  Accuracy:70.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.214415 [    0/ 3881]
# loss:0.283102 [ 3200/ 3881]
# Done. Time:2.685587648999956
# Training performance:
#  Avg loss:0.264781
#
# Start validation.
# Done. Time:0.22993897200001356
# Validation performance:
#  Avg loss:1.008167
#
# Start evaluation.
# Done. Time:1.111144505000027
# Test performance:
#  Accuracy:73.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.295266 [    0/ 3881]
# loss:0.352066 [ 3200/ 3881]
# Done. Time:4.110478505999993
# Training performance:
#  Avg loss:0.252496
#
# Start validation.
# Done. Time:0.24596433499999648
# Validation performance:
#  Avg loss:0.884685
#
# Start evaluation.
# Done. Time:1.1090693390000297
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.299566 [    0/ 3881]
# loss:0.166901 [ 3200/ 3881]
# Done. Time:2.6152487819999806
# Training performance:
#  Avg loss:0.234336
#
# Start validation.
# Done. Time:0.22839434000002257
# Validation performance:
#  Avg loss:1.220113
#
# Start evaluation.
# Done. Time:1.111835171999985
# Test performance:
#  Accuracy:71.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.303707 [    0/ 3881]
# loss:0.246583 [ 3200/ 3881]
# Done. Time:2.696530910999968
# Training performance:
#  Avg loss:0.240245
#
# Start validation.
# Done. Time:0.23346953000003623
# Validation performance:
#  Avg loss:0.900010
#
# Start evaluation.
# Done. Time:1.1265367280000191
# Test performance:
#  Accuracy:74.5%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.301154 [    0/ 3881]
# loss:0.147252 [ 3200/ 3881]
# Done. Time:4.159240127000032
# Training performance:
#  Avg loss:0.235901
#
# Start validation.
# Done. Time:0.23283630700001368
# Validation performance:
#  Avg loss:0.854204
#
# Start evaluation.
# Done. Time:1.1174087050000026
# Test performance:
#  Accuracy:77.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.179118 [    0/ 3881]
# loss:0.640819 [ 3200/ 3881]
# Done. Time:2.5810166079999703
# Training performance:
#  Avg loss:0.241275
#
# Start validation.
# Done. Time:0.2273945660000436
# Validation performance:
#  Avg loss:0.940752
#
# Start evaluation.
# Done. Time:1.1214904810000235
# Test performance:
#  Accuracy:76.5%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.129319 [    0/ 3881]
# loss:0.199231 [ 3200/ 3881]
# Done. Time:2.60508586200001
# Training performance:
#  Avg loss:0.231009
#
# Start validation.
# Done. Time:0.23225717100001475
# Validation performance:
#  Avg loss:0.880172
#
# Start evaluation.
# Done. Time:1.1279425330000095
# Test performance:
#  Accuracy:74.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.083210 [    0/ 3881]
# loss:0.296702 [ 3200/ 3881]
# Done. Time:4.125296299000013
# Training performance:
#  Avg loss:0.220707
#
# Start validation.
# Done. Time:0.23517707999997128
# Validation performance:
#  Avg loss:0.917034
#
# Start evaluation.
# Done. Time:1.1070008650000318
# Test performance:
#  Accuracy:78.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.096731 [    0/ 3881]
# loss:0.071336 [ 3200/ 3881]
# Done. Time:2.644703402999994
# Training performance:
#  Avg loss:0.226543
#
# Start validation.
# Done. Time:0.23192503199999237
# Validation performance:
#  Avg loss:0.985867
#
# Start evaluation.
# Done. Time:1.1298684540000181
# Test performance:
#  Accuracy:74.0%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.094313 [    0/ 3881]
# loss:0.261979 [ 3200/ 3881]
# Done. Time:2.6319548019999957
# Training performance:
#  Avg loss:0.216961
#
# Start validation.
# Done. Time:0.23416207200000372
# Validation performance:
#  Avg loss:1.042774
#
# Start evaluation.
# Done. Time:1.1232248510000318
# Test performance:
#  Accuracy:70.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.311580 [    0/ 3881]
# loss:0.214648 [ 3200/ 3881]
# Done. Time:4.234322065000015
# Training performance:
#  Avg loss:0.212489
#
# Start validation.
# Done. Time:0.24956974399998444
# Validation performance:
#  Avg loss:1.036761
#
# Start evaluation.
# Done. Time:1.115756920000024
# Test performance:
#  Accuracy:75.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.098079 [    0/ 3881]
# loss:0.148891 [ 3200/ 3881]
# Done. Time:2.630440510000028
# Training performance:
#  Avg loss:0.203978
#
# Start validation.
# Done. Time:0.22869884200002843
# Validation performance:
#  Avg loss:0.900509
#
# Start evaluation.
# Done. Time:1.1233106000000248
# Test performance:
#  Accuracy:74.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.244683 [    0/ 3881]
# loss:0.275885 [ 3200/ 3881]
# Done. Time:2.5981223620000264
# Training performance:
#  Avg loss:0.202758
#
# Start validation.
# Done. Time:0.23829874799997697
# Validation performance:
#  Avg loss:0.894729
#
# Start evaluation.
# Done. Time:1.109833913999978
# Test performance:
#  Accuracy:71.5%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.097245 [    0/ 3881]
# loss:0.260933 [ 3200/ 3881]
# Done. Time:4.151406624999993
# Training performance:
#  Avg loss:0.204140
#
# Start validation.
# Done. Time:0.23299116099997264
# Validation performance:
#  Avg loss:0.832781
#
# Start evaluation.
# Done. Time:1.1350451480000174
# Test performance:
#  Accuracy:81.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.088447 [    0/ 3881]
# loss:0.114173 [ 3200/ 3881]
# Done. Time:2.639596953000023
# Training performance:
#  Avg loss:0.191597
#
# Start validation.
# Done. Time:0.2343900999999846
# Validation performance:
#  Avg loss:0.988875
#
# Start evaluation.
# Done. Time:1.1271965120000118
# Test performance:
#  Accuracy:76.0%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.151231 [    0/ 3881]
# loss:0.124296 [ 3200/ 3881]
# Done. Time:2.6378965299999777
# Training performance:
#  Avg loss:0.187618
#
# Start validation.
# Done. Time:0.2293065079999792
# Validation performance:
#  Avg loss:1.010803
#
# Start evaluation.
# Done. Time:1.1180104919999962
# Test performance:
#  Accuracy:76.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.073741 [    0/ 3881]
# loss:0.321340 [ 3200/ 3881]
# Done. Time:4.094882912999992
# Training performance:
#  Avg loss:0.194064
#
# Start validation.
# Done. Time:0.2738575529999707
# Validation performance:
#  Avg loss:1.101403
#
# Start evaluation.
# Done. Time:1.1261648530000343
# Test performance:
#  Accuracy:72.0%
# Minimum validation loss:0.7104180072035108 at 18 epoch.
# Maximum accuracy:81.0 at 47 epoch.

# %% [markdown]
# ### Apply horizontal flip.

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(
    train_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_w_daug,
    load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(
    val_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_default,
    load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(
    test_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_default,
    load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)

# %%
tren_norm_first = True
tren_add_tailnorm = True

model_pnorm = TransformerEnISLR(
    in_channels=in_channels,
    inter_channels=inter_channels,
    out_channels=out_channels,
    activation=activation,
    tren_num_layers=tren_num_layers,
    tren_num_heads=tren_num_heads,
    tren_dim_ffw=tren_dim_ffw,
    tren_dropout_pe=tren_dropout_pe,
    tren_dropout=tren_dropout,
    tren_layer_norm_eps=tren_layer_norm_eps,
    tren_norm_first=tren_norm_first,
    tren_add_bias=tren_add_bias,
    tren_add_tailnorm=tren_add_tailnorm)
print(model_pnorm)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model_pnorm.parameters(), lr=lr)
# Out:
# TransformerEnISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (tr_encoder): TransformerEncoder(
#     (pos_encoder): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (w_key): Linear(in_features=64, out_features=64, bias=True)
#           (w_value): Linear(in_features=64, out_features=64, bias=True)
#           (w_query): Linear(in_features=64, out_features=64, bias=True)
#           (w_out): Linear(in_features=64, out_features=64, bias=True)
#           (dropout_attn): Dropout(p=0.1, inplace=False)
#         )
#         (ffw): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=256, bias=True)
#           (w_2): Linear(in_features=256, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#         (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model_pnorm.to(device)

train_losses = []
val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_losses = train_loop(train_dataloader, model_pnorm, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model_pnorm, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model_pnorm, device)
        test_accs.append(acc)
train_losses_w_daug = np.array(train_losses)
val_losses_w_daug = np.array(val_losses)
test_accs_w_daug = np.array(test_accs)

print(f"Minimum validation loss:{val_losses_w_daug.min()} at {np.argmin(val_losses_w_daug)+1} epoch.")
print(f"Maximum accuracy:{test_accs_w_daug.max()} at {np.argmax(test_accs_w_daug)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:4.213373 [    0/ 3881]
# loss:1.833129 [ 3200/ 3881]
# Done. Time:3.028186572999971
# Training performance:
#  Avg loss:2.176731
#
# Start validation.
# Done. Time:0.39730006799999273
# Validation performance:
#  Avg loss:1.976122
#
# Start evaluation.
# Done. Time:1.5178202950000355
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:1.932670 [    0/ 3881]
# loss:1.035877 [ 3200/ 3881]
# Done. Time:3.335723267999981
# Training performance:
#  Avg loss:1.576362
#
# Start validation.
# Done. Time:0.25944317199997613
# Validation performance:
#  Avg loss:1.802183
#
# Start evaluation.
# Done. Time:1.1745054190000133
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.710310 [    0/ 3881]
# loss:0.952744 [ 3200/ 3881]
# Done. Time:2.8956400280000025
# Training performance:
#  Avg loss:1.202915
#
# Start validation.
# Done. Time:0.25922125599998935
# Validation performance:
#  Avg loss:1.291161
#
# Start evaluation.
# Done. Time:1.1625340909999977
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.291894 [    0/ 3881]
# loss:1.147363 [ 3200/ 3881]
# Done. Time:3.694296496999982
# Training performance:
#  Avg loss:1.021651
#
# Start validation.
# Done. Time:0.4293390889999955
# Validation performance:
#  Avg loss:1.179535
#
# Start evaluation.
# Done. Time:1.4757093690000147
# Test performance:
#  Accuracy:53.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:0.837739 [    0/ 3881]
# loss:0.672592 [ 3200/ 3881]
# Done. Time:2.9444056720000162
# Training performance:
#  Avg loss:0.928413
#
# Start validation.
# Done. Time:0.26212753100003283
# Validation performance:
#  Avg loss:1.024670
#
# Start evaluation.
# Done. Time:1.1868661810000276
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:0.914581 [    0/ 3881]
# loss:0.920042 [ 3200/ 3881]
# Done. Time:2.973095247999993
# Training performance:
#  Avg loss:0.845215
#
# Start validation.
# Done. Time:0.2570900780000329
# Validation performance:
#  Avg loss:0.815611
#
# Start evaluation.
# Done. Time:1.173155730000019
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:0.914991 [    0/ 3881]
# loss:0.592864 [ 3200/ 3881]
# Done. Time:4.403936815999998
# Training performance:
#  Avg loss:0.770699
#
# Start validation.
# Done. Time:0.27962632099996654
# Validation performance:
#  Avg loss:0.848630
#
# Start evaluation.
# Done. Time:1.2000286539999934
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.234637 [    0/ 3881]
# loss:0.870094 [ 3200/ 3881]
# Done. Time:3.032262045999971
# Training performance:
#  Avg loss:0.729832
#
# Start validation.
# Done. Time:0.2602495980000299
# Validation performance:
#  Avg loss:0.765768
#
# Start evaluation.
# Done. Time:1.2240222450000147
# Test performance:
#  Accuracy:72.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:0.662013 [    0/ 3881]
# loss:0.770886 [ 3200/ 3881]
# Done. Time:3.024877263999997
# Training performance:
#  Avg loss:0.672142
#
# Start validation.
# Done. Time:0.2727745299999924
# Validation performance:
#  Avg loss:0.852838
#
# Start evaluation.
# Done. Time:1.38927733700001
# Test performance:
#  Accuracy:70.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:0.616240 [    0/ 3881]
# loss:0.682527 [ 3200/ 3881]
# Done. Time:4.103791699999988
# Training performance:
#  Avg loss:0.638486
#
# Start validation.
# Done. Time:0.2518294449999985
# Validation performance:
#  Avg loss:0.654490
#
# Start evaluation.
# Done. Time:1.1881650660000105
# Test performance:
#  Accuracy:76.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:0.561634 [    0/ 3881]
# loss:0.619341 [ 3200/ 3881]
# Done. Time:3.0016784669999765
# Training performance:
#  Avg loss:0.599186
#
# Start validation.
# Done. Time:0.2678736830000048
# Validation performance:
#  Avg loss:0.601384
#
# Start evaluation.
# Done. Time:1.2387087650000126
# Test performance:
#  Accuracy:78.0%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:0.509164 [    0/ 3881]
# loss:0.369277 [ 3200/ 3881]
# Done. Time:3.3209909480000306
# Training performance:
#  Avg loss:0.558948
#
# Start validation.
# Done. Time:0.4158290699999725
# Validation performance:
#  Avg loss:0.663657
#
# Start evaluation.
# Done. Time:1.5937718940000423
# Test performance:
#  Accuracy:71.5%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:0.469588 [    0/ 3881]
# loss:0.193264 [ 3200/ 3881]
# Done. Time:3.144940571999996
# Training performance:
#  Avg loss:0.540019
#
# Start validation.
# Done. Time:0.2592171930000404
# Validation performance:
#  Avg loss:0.637929
#
# Start evaluation.
# Done. Time:1.1850709709999592
# Test performance:
#  Accuracy:76.0%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:0.429332 [    0/ 3881]
# loss:0.634454 [ 3200/ 3881]
# Done. Time:2.978731721000031
# Training performance:
#  Avg loss:0.522112
#
# Start validation.
# Done. Time:0.2528542100000095
# Validation performance:
#  Avg loss:0.573221
#
# Start evaluation.
# Done. Time:1.1963469480000413
# Test performance:
#  Accuracy:81.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:0.571664 [    0/ 3881]
# loss:0.490061 [ 3200/ 3881]
# Done. Time:4.143151776000025
# Training performance:
#  Avg loss:0.500051
#
# Start validation.
# Done. Time:0.42442685399998936
# Validation performance:
#  Avg loss:0.614946
#
# Start evaluation.
# Done. Time:1.2849220230000356
# Test performance:
#  Accuracy:79.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:0.521596 [    0/ 3881]
# loss:0.370277 [ 3200/ 3881]
# Done. Time:2.990510876999963
# Training performance:
#  Avg loss:0.481478
#
# Start validation.
# Done. Time:0.2582099730000209
# Validation performance:
#  Avg loss:0.665959
#
# Start evaluation.
# Done. Time:1.2046240749999697
# Test performance:
#  Accuracy:76.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:0.624184 [    0/ 3881]
# loss:0.525228 [ 3200/ 3881]
# Done. Time:2.9345356569999694
# Training performance:
#  Avg loss:0.472000
#
# Start validation.
# Done. Time:0.2633194119999871
# Validation performance:
#  Avg loss:0.597938
#
# Start evaluation.
# Done. Time:1.1872181790000127
# Test performance:
#  Accuracy:80.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:0.394232 [    0/ 3881]
# loss:0.564280 [ 3200/ 3881]
# Done. Time:4.5942197080000255
# Training performance:
#  Avg loss:0.461539
#
# Start validation.
# Done. Time:0.2727721200000133
# Validation performance:
#  Avg loss:0.580831
#
# Start evaluation.
# Done. Time:1.1756165020000253
# Test performance:
#  Accuracy:84.0%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:0.264936 [    0/ 3881]
# loss:0.284151 [ 3200/ 3881]
# Done. Time:2.944041377000019
# Training performance:
#  Avg loss:0.452962
#
# Start validation.
# Done. Time:0.25539366300000665
# Validation performance:
#  Avg loss:0.565224
#
# Start evaluation.
# Done. Time:1.1719899330000203
# Test performance:
#  Accuracy:81.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:0.271823 [    0/ 3881]
# loss:0.207318 [ 3200/ 3881]
# Done. Time:2.9710861709999676
# Training performance:
#  Avg loss:0.431457
#
# Start validation.
# Done. Time:0.26132870300000377
# Validation performance:
#  Avg loss:0.578765
#
# Start evaluation.
# Done. Time:1.516026060999991
# Test performance:
#  Accuracy:83.5%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:0.391078 [    0/ 3881]
# loss:0.350497 [ 3200/ 3881]
# Done. Time:3.846847077999996
# Training performance:
#  Avg loss:0.411078
#
# Start validation.
# Done. Time:0.255102566000005
# Validation performance:
#  Avg loss:0.568681
#
# Start evaluation.
# Done. Time:1.1932493190000173
# Test performance:
#  Accuracy:81.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:0.508679 [    0/ 3881]
# loss:0.257539 [ 3200/ 3881]
# Done. Time:2.9545799019999777
# Training performance:
#  Avg loss:0.418633
#
# Start validation.
# Done. Time:0.2692693149999741
# Validation performance:
#  Avg loss:0.597896
#
# Start evaluation.
# Done. Time:1.1786415359999864
# Test performance:
#  Accuracy:81.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:0.222693 [    0/ 3881]
# loss:0.252550 [ 3200/ 3881]
# Done. Time:3.4686731180000265
# Training performance:
#  Avg loss:0.391022
#
# Start validation.
# Done. Time:0.43529010499997867
# Validation performance:
#  Avg loss:0.591479
#
# Start evaluation.
# Done. Time:1.6040697459999933
# Test performance:
#  Accuracy:84.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:0.574556 [    0/ 3881]
# loss:0.295977 [ 3200/ 3881]
# Done. Time:3.078542620999997
# Training performance:
#  Avg loss:0.406502
#
# Start validation.
# Done. Time:0.261420548999979
# Validation performance:
#  Avg loss:0.718517
#
# Start evaluation.
# Done. Time:1.1879327620000026
# Test performance:
#  Accuracy:80.5%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:0.310788 [    0/ 3881]
# loss:0.376694 [ 3200/ 3881]
# Done. Time:2.991541219999988
# Training performance:
#  Avg loss:0.379151
#
# Start validation.
# Done. Time:0.25706665000001294
# Validation performance:
#  Avg loss:0.731222
#
# Start evaluation.
# Done. Time:1.1805271640000115
# Test performance:
#  Accuracy:80.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:0.315378 [    0/ 3881]
# loss:0.264089 [ 3200/ 3881]
# Done. Time:4.345329048999986
# Training performance:
#  Avg loss:0.385216
#
# Start validation.
# Done. Time:0.35067762900001753
# Validation performance:
#  Avg loss:0.608776
#
# Start evaluation.
# Done. Time:1.2016657340000165
# Test performance:
#  Accuracy:82.0%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:0.394533 [    0/ 3881]
# loss:0.486285 [ 3200/ 3881]
# Done. Time:3.2581326179999905
# Training performance:
#  Avg loss:0.360750
#
# Start validation.
# Done. Time:0.26251787199998944
# Validation performance:
#  Avg loss:0.537073
#
# Start evaluation.
# Done. Time:1.1784922119999806
# Test performance:
#  Accuracy:85.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.479689 [    0/ 3881]
# loss:0.537335 [ 3200/ 3881]
# Done. Time:3.080970222000019
# Training performance:
#  Avg loss:0.356151
#
# Start validation.
# Done. Time:0.2633782669999505
# Validation performance:
#  Avg loss:0.709363
#
# Start evaluation.
# Done. Time:1.440844855000023
# Test performance:
#  Accuracy:82.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.738526 [    0/ 3881]
# loss:0.298791 [ 3200/ 3881]
# Done. Time:4.254374377999966
# Training performance:
#  Avg loss:0.350480
#
# Start validation.
# Done. Time:0.2747531079999703
# Validation performance:
#  Avg loss:0.643358
#
# Start evaluation.
# Done. Time:1.2100780419999637
# Test performance:
#  Accuracy:84.0%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.235024 [    0/ 3881]
# loss:0.203143 [ 3200/ 3881]
# Done. Time:3.0875529599999822
# Training performance:
#  Avg loss:0.340716
#
# Start validation.
# Done. Time:0.2769177609999929
# Validation performance:
#  Avg loss:0.654028
#
# Start evaluation.
# Done. Time:1.1919841839999776
# Test performance:
#  Accuracy:80.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.126437 [    0/ 3881]
# loss:0.394986 [ 3200/ 3881]
# Done. Time:3.5486911969999824
# Training performance:
#  Avg loss:0.342524
#
# Start validation.
# Done. Time:0.41465525199998865
# Validation performance:
#  Avg loss:0.578459
#
# Start evaluation.
# Done. Time:1.5775828700000147
# Test performance:
#  Accuracy:84.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.299166 [    0/ 3881]
# loss:0.362116 [ 3200/ 3881]
# Done. Time:2.977010188999998
# Training performance:
#  Avg loss:0.332547
#
# Start validation.
# Done. Time:0.26906513400001586
# Validation performance:
#  Avg loss:0.585738
#
# Start evaluation.
# Done. Time:1.175474677000011
# Test performance:
#  Accuracy:87.0%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.186352 [    0/ 3881]
# loss:0.101432 [ 3200/ 3881]
# Done. Time:3.043908244000022
# Training performance:
#  Avg loss:0.308996
#
# Start validation.
# Done. Time:0.2751561509999192
# Validation performance:
#  Avg loss:0.448815
#
# Start evaluation.
# Done. Time:1.1943017370000462
# Test performance:
#  Accuracy:83.0%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.272578 [    0/ 3881]
# loss:0.146900 [ 3200/ 3881]
# Done. Time:4.352016545999959
# Training performance:
#  Avg loss:0.324464
#
# Start validation.
# Done. Time:0.3002320950000694
# Validation performance:
#  Avg loss:0.586009
#
# Start evaluation.
# Done. Time:1.181229978000033
# Test performance:
#  Accuracy:84.5%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.191344 [    0/ 3881]
# loss:0.557518 [ 3200/ 3881]
# Done. Time:3.0086542699999654
# Training performance:
#  Avg loss:0.318595
#
# Start validation.
# Done. Time:0.2831003060000512
# Validation performance:
#  Avg loss:0.493399
#
# Start evaluation.
# Done. Time:1.1917693159999772
# Test performance:
#  Accuracy:86.0%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.495428 [    0/ 3881]
# loss:0.232165 [ 3200/ 3881]
# Done. Time:3.0890301789999057
# Training performance:
#  Avg loss:0.298464
#
# Start validation.
# Done. Time:0.2568886509999402
# Validation performance:
#  Avg loss:0.526749
#
# Start evaluation.
# Done. Time:1.3112455790000013
# Test performance:
#  Accuracy:83.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.431247 [    0/ 3881]
# loss:0.242482 [ 3200/ 3881]
# Done. Time:4.174524555000062
# Training performance:
#  Avg loss:0.290322
#
# Start validation.
# Done. Time:0.26913470800002415
# Validation performance:
#  Avg loss:0.600712
#
# Start evaluation.
# Done. Time:1.1947649579999506
# Test performance:
#  Accuracy:84.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.127982 [    0/ 3881]
# loss:0.678399 [ 3200/ 3881]
# Done. Time:3.0128019379999387
# Training performance:
#  Avg loss:0.291015
#
# Start validation.
# Done. Time:0.26589539100007187
# Validation performance:
#  Avg loss:0.552727
#
# Start evaluation.
# Done. Time:1.1628344729999753
# Test performance:
#  Accuracy:83.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.346182 [    0/ 3881]
# loss:0.394826 [ 3200/ 3881]
# Done. Time:3.088434164000091
# Training performance:
#  Avg loss:0.286737
#
# Start validation.
# Done. Time:0.4001767070000142
# Validation performance:
#  Avg loss:0.538234
#
# Start evaluation.
# Done. Time:1.5632952409999916
# Test performance:
#  Accuracy:82.5%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.175079 [    0/ 3881]
# loss:0.309691 [ 3200/ 3881]
# Done. Time:3.5075394840000627
# Training performance:
#  Avg loss:0.295281
#
# Start validation.
# Done. Time:0.26674042700005884
# Validation performance:
#  Avg loss:0.519482
#
# Start evaluation.
# Done. Time:1.1817860940000173
# Test performance:
#  Accuracy:85.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.317358 [    0/ 3881]
# loss:0.261647 [ 3200/ 3881]
# Done. Time:2.9244923170000447
# Training performance:
#  Avg loss:0.281856
#
# Start validation.
# Done. Time:0.2686643530000765
# Validation performance:
#  Avg loss:0.566531
#
# Start evaluation.
# Done. Time:1.1893590779999386
# Test performance:
#  Accuracy:82.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.195904 [    0/ 3881]
# loss:0.230232 [ 3200/ 3881]
# Done. Time:3.821116189999998
# Training performance:
#  Avg loss:0.265710
#
# Start validation.
# Done. Time:0.4133661990000519
# Validation performance:
#  Avg loss:0.563755
#
# Start evaluation.
# Done. Time:1.5235859150000124
# Test performance:
#  Accuracy:84.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.352951 [    0/ 3881]
# loss:0.395116 [ 3200/ 3881]
# Done. Time:2.9736398170000484
# Training performance:
#  Avg loss:0.257769
#
# Start validation.
# Done. Time:0.27839749899999333
# Validation performance:
#  Avg loss:0.489043
#
# Start evaluation.
# Done. Time:1.1783108810000158
# Test performance:
#  Accuracy:85.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.425726 [    0/ 3881]
# loss:0.096836 [ 3200/ 3881]
# Done. Time:3.011993328000017
# Training performance:
#  Avg loss:0.270687
#
# Start validation.
# Done. Time:0.26235978900001555
# Validation performance:
#  Avg loss:0.434440
#
# Start evaluation.
# Done. Time:1.1904113960000586
# Test performance:
#  Accuracy:86.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.337148 [    0/ 3881]
# loss:0.168754 [ 3200/ 3881]
# Done. Time:4.450783427999909
# Training performance:
#  Avg loss:0.251893
#
# Start validation.
# Done. Time:0.2944019720000597
# Validation performance:
#  Avg loss:0.697191
#
# Start evaluation.
# Done. Time:1.1978862050000316
# Test performance:
#  Accuracy:83.0%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.149743 [    0/ 3881]
# loss:0.297243 [ 3200/ 3881]
# Done. Time:3.0344573459999538
# Training performance:
#  Avg loss:0.263888
#
# Start validation.
# Done. Time:0.2622843340000145
# Validation performance:
#  Avg loss:0.583199
#
# Start evaluation.
# Done. Time:1.1962674960000186
# Test performance:
#  Accuracy:83.5%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.243875 [    0/ 3881]
# loss:0.135509 [ 3200/ 3881]
# Done. Time:2.9787392830000954
# Training performance:
#  Avg loss:0.248808
#
# Start validation.
# Done. Time:0.26526953300003697
# Validation performance:
#  Avg loss:0.677318
#
# Start evaluation.
# Done. Time:1.3682942089999415
# Test performance:
#  Accuracy:82.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.238654 [    0/ 3881]
# loss:0.310897 [ 3200/ 3881]
# Done. Time:4.197746223000081
# Training performance:
#  Avg loss:0.247497
#
# Start validation.
# Done. Time:0.26065147700001035
# Validation performance:
#  Avg loss:0.500190
#
# Start evaluation.
# Done. Time:1.2207213619999493
# Test performance:
#  Accuracy:84.0%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.377604 [    0/ 3881]
# loss:0.375097 [ 3200/ 3881]
# Done. Time:3.0126655630000414
# Training performance:
#  Avg loss:0.261187
#
# Start validation.
# Done. Time:0.2642252929999813
# Validation performance:
#  Avg loss:0.569819
#
# Start evaluation.
# Done. Time:1.1815281220000315
# Test performance:
#  Accuracy:82.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.231142 [    0/ 3881]
# loss:0.547729 [ 3200/ 3881]
# Done. Time:3.301511209999944
# Training performance:
#  Avg loss:0.250687
#
# Start validation.
# Done. Time:0.4294140270000071
# Validation performance:
#  Avg loss:0.542645
#
# Start evaluation.
# Done. Time:1.5592737669999224
# Test performance:
#  Accuracy:84.0%
# Minimum validation loss:0.43444038714681354 at 44 epoch.
# Maximum accuracy:87.0 at 32 epoch.

# %% [markdown]
# ### Plort result
# #### Recognition performance

# %%
import matplotlib.pyplot as plt

plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(val_losses_default)+1)
plt.plot(xs, val_losses_default, label="Default", marker=".")
plt.plot(xs, val_losses_w_daug, label="+ H-Flip", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.ylim([0.0, 2.5])
plt.legend()
plt.show()

# %%
plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(test_accs_default)+1)
plt.plot(xs, test_accs_default, label="Default", marker=".")
plt.plot(xs, test_accs_w_daug, label="+ H-Flip", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.ylim([0.0, 100.0])
plt.legend()
plt.show()
