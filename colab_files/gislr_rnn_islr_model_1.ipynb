# %% [markdown]
# <a href="https://colab.research.google.com/github/takayama-rado/trado_samples/blob/main/colab_files/gislr_rnn_islr_model_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Download dataset and modules

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Copy to local.
# !cp drive/MyDrive/Datasets/gislr_dataset_top10.zip gislr_top10.zip

# %%
# !unzip -o gislr_top10.zip
# Out:
# Archive:  gislr_top10.zip
#    creating: dataset_top10/
#   inflating: dataset_top10/16069.hdf5
#   inflating: dataset_top10/18796.hdf5
#   inflating: dataset_top10/2044.hdf5
#   inflating: dataset_top10/22343.hdf5
#   inflating: dataset_top10/25571.hdf5
#   inflating: dataset_top10/26734.hdf5
#   inflating: dataset_top10/27610.hdf5
#   inflating: dataset_top10/28656.hdf5
#   inflating: dataset_top10/29302.hdf5
#   inflating: dataset_top10/30680.hdf5
#   inflating: dataset_top10/32319.hdf5
#   inflating: dataset_top10/34503.hdf5
#   inflating: dataset_top10/36257.hdf5
#   inflating: dataset_top10/37055.hdf5
#   inflating: dataset_top10/37779.hdf5
#   inflating: dataset_top10/4718.hdf5
#   inflating: dataset_top10/49445.hdf5
#   inflating: dataset_top10/53618.hdf5
#   inflating: dataset_top10/55372.hdf5
#   inflating: dataset_top10/61333.hdf5
#   inflating: dataset_top10/62590.hdf5
#   inflating: dataset_top10/LICENSE.txt
#   inflating: dataset_top10/sign_to_prediction_index_map.json

# %%
# !ls dataset_top10
# Out:
# 16069.hdf5  25571.hdf5	29302.hdf5  36257.hdf5	49445.hdf5  62590.hdf5
# 18796.hdf5  26734.hdf5	30680.hdf5  37055.hdf5	53618.hdf5  LICENSE.txt
# 2044.hdf5   27610.hdf5	32319.hdf5  37779.hdf5	55372.hdf5  sign_to_prediction_index_map.json
# 22343.hdf5  28656.hdf5	34503.hdf5  4718.hdf5	61333.hdf5

# %%
# !cat dataset_top10/sign_to_prediction_index_map.json
# Out:
# {
#     "listen": 0,
#     "look": 1,
#     "shhh": 2,
#     "donkey": 3,
#     "mouse": 4,
#     "duck": 5,
#     "uncle": 6,
#     "hear": 7,
#     "pretend": 8,
#     "cow": 9
# }

# %%
# !cat dataset_top10/LICENSE.txt
# Out:
# The dataset provided by Natsuki Takayama (Takayama Research and Development Office) is licensed under CC-BY 4.0.
# Author: Copyright 2024 Natsuki Takayama
# Title: GISLR Top 10 dataset
# Original licenser: Deaf Professional Arts Network and the Georgia Institute of Technology
# Modification
# - Extract 10 most frequent words.
# - Packaged into HDF5 format.

# %%
import h5py
with h5py.File("dataset_top10/16069.hdf5", "r") as fread:
    keys = list(fread.keys())
    print(keys)
    group = fread[keys[0]]
    print(group.keys())
    feature = group["feature"][:]
    token = group["token"][:]
    print(feature.shape)
    print(token)
# Out:
# ['1109479272', '11121526', '1120349077', '1125456612', '1159046211', '1169128497', '1186032553', '1223803476', '1259708636', '1281972067', '129232566', '1334702305', '1340979012', '1352964057', '1370052047', '1383455381', '1431148933', '1435203624', '1437919781', '1458770030', '1462881097', '1469867050', '1474050058', '147607644', '1513539919', '1520635928', '1524297234', '153676122', '1537751003', '1542212461', '1551759770', '158232956', '1585855916', '1632709119', '1638742455', '1696757219', '177479476', '1779635114', '1791684792', '1801566440', '1831167282', '1867385690', '1880570146', '1901587887', '1910121429', '1919659282', '192873038', '1935012113', '1949620203', '195098847', '1983552660', '1989475963', '1998715062', '2007709802', '2036010239', '2036360025', '2046296211', '2082116372', '2098813002', '2109640010', '2121879330', '2141852087', '2148832702', '2152013823', '2166805079', '2176613834', '2184232774', '2213965523', '2249630763', '2256677805', '2263287955', '2263683020', '2264826605', '2270117351', '2281372282', '2285328250', '2322449232', '2326092712', '2336131857', '2346410171', '2405684784', '2467219838', '2473091535', '2488751095', '2515673021', '252176572', '2555449229', '2601816518', '2624310025', '2672738462', '2679264929', '2708514724', '2708544445', '2721276879', '2723773273', '2728839865', '2740241949', '2758304792', '2772051790', '2779816680', '2804441762', '2811346655', '2811646800', '2820103955', '2839681895', '2900998385', '2976200180', '2994456336', '3057994128', '3095010437', '3104317075', '3109672704', '3137179145', '3153285641', '3173321541', '3181666887', '3201889607', '3208820205', '3248401349', '3280527321', '3283246198', '3300057240', '3355963469', '3378306304', '3383637897', '3395075403', '3399503065', '3417877266', '3433092803', '347484677', '348956807', '3490841593', '3509324997', '3527069516', '3537611572', '3543711249', '3550826234', '3574700791', '3577812263', '3608551465', '3609537739', '3622960580', '3666781780', '3701422761', '3721927307', '3751410902', '3756613238', '3769544385', '3783554953', '3794712078', '380369091', '3813230821', '3817572483', '3843929707', '3869664504', '3892179393', '3923913515', '3981562204', '4078929101', '4101587978', '4150900444', '4191136837', '4200829752', '4209136328', '420958416', '422113773', '42222766', '4233346443', '4233985575', '4236057556', '4252161228', '425542996', '4276854486', '4294775577', '431609031', '439844759', '446236576', '470582324', '472128010', '492897929', '537402693', '5501547', '561170018', '593416697', '631898947', '649410423', '654529993', '678960043', '699907539', '707716966', '713615518', '778875120', '792981518', '796465415', '798649922', '856068671', '923153024', '957739544', '970593849', '976754415']
# <KeysViewHDF5 ['feature', 'token']>
# (3, 23, 543)
# [1]

# %%
# !wget https://github.com/takayama-rado/trado_samples/archive/refs/tags/v0.1.zip -O master.zip
# Out:
# --2024-02-13 07:07:54--  https://github.com/takayama-rado/trado_samples/archive/master.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/takayama-rado/trado_samples/zip/main [following]
# --2024-02-13 07:07:54--  https://codeload.github.com/takayama-rado/trado_samples/zip/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [           <=>      ]  73.82M  17.8MB/s    in 4.1s
#
# 2024-02-13 07:07:59 (17.8 MB/s) - ‘master.zip’ saved [77410707]

# %%
# !unzip -o master.zip -d master
# Out:
# Archive:  master.zip
# ad5d2655032e0c2e4c8df7e4dd6f3e71d5b65f5d
#    creating: master/trado_samples-main/
#   inflating: master/trado_samples-main/.gitignore
#   inflating: master/trado_samples-main/LICENSE
#   inflating: master/trado_samples-main/README.md
#    creating: master/trado_samples-main/colab_files/
#  extracting: master/trado_samples-main/colab_files/.gitkeep
#   inflating: master/trado_samples-main/colab_files/exp_affine_np_einsum.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_jax_static.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_mpholistic_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_mpothers_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_jax.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_numpy.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_tensorflow.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_torch.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_jax.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_numpy_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_numpy_1.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_tensorflow.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_torch.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_access_dataset.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_normalize_landmarks.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_rnn_islr_model.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_rnn_islr_model_1.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_rnn_islr_model_2.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_select_landmarks.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_simple_islr_model.ipynb
#    creating: master/trado_samples-main/src/
#    creating: master/trado_samples-main/src/modules_gislr/
#  extracting: master/trado_samples-main/src/modules_gislr/__init__.py
#   inflating: master/trado_samples-main/src/modules_gislr/dataset.py
#   inflating: master/trado_samples-main/src/modules_gislr/defines.py
#   inflating: master/trado_samples-main/src/modules_gislr/draw_functions.py
#   inflating: master/trado_samples-main/src/modules_gislr/layers.py
#   inflating: master/trado_samples-main/src/modules_gislr/train_functions.py
#   inflating: master/trado_samples-main/src/modules_gislr/transforms.py
#    creating: master/trado_samples-main/test_data/
#   inflating: master/trado_samples-main/test_data/finger_far0.mp4
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static.npy
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static_affine.npy
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static_interp.npy
#   inflating: master/trado_samples-main/test_data/finger_middle0.mp4
#   inflating: master/trado_samples-main/test_data/finger_near0.mp4
#   inflating: master/trado_samples-main/test_data/hand_only.mp4

# %%
# !mv master/trado_samples-main/src/modules_gislr .

# %%
# !rm -rf master master.zip gislr_top10.zip

# %%
# !ls
# Out:
# dataset_top10  drive  modules_gislr  sample_data

# %% [markdown]
# # 2. Load library

# %%
import json
import math
import sys
import time
from functools import partial
from pathlib import Path
from typing import (
    Any,
    Dict
)

# Third party's modules
import numpy as np

import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import (
    DataLoader)

from torchvision.transforms import Compose

# Local modules
sys.path.append("modules_gislr")
from modules_gislr.dataset import (
    HDF5Dataset,
    merge_padded_batch)
from modules_gislr.defines import (
    get_fullbody_landmarks
)
from modules_gislr.layers import (
    GPoolRecognitionHead
)
from modules_gislr.transforms import (
    PartsBasedNormalization,
    ReplaceNan,
    SelectLandmarksAndFeature,
    ToTensor
)
from modules_gislr.train_functions import (
    test_loop,
    train_loop,
    val_loop
)

# %% [markdown]
# # 3. Implement RNN ISLR model

# %% [markdown]
# ## RNN encoder

# %%
class RNNEncoder(nn.Module):
    def __init__(self,
                 in_channels,
                 out_channels,
                 num_layers,
                 activation,
                 bidir,
                 dropout):
        super().__init__()

        # If num_layers = 1, we remove dropout option of RNN layers to avoid warning.
        rnn_dropout = 0.0 if num_layers == 1 else dropout

        self.rnn = nn.RNN(input_size=in_channels,
                          hidden_size=out_channels,
                          num_layers=num_layers,
                          nonlinearity=activation,
                          batch_first=True,
                          dropout=rnn_dropout,
                          bidirectional=bidir)
        # Dropout is added into intermediate RNN layers expect the last layer.
        # So, we add Dropout layer for the last layer explicitly.
        if dropout > 0:
            self.dropout = nn.Dropout(dropout)
        else:
            self.dropout = nn.Identity()

    def forward(self, feature):
        hidden_seqs, last_hstate = self.rnn(feature)
        hidden_seqs = self.dropout(hidden_seqs)

        return hidden_seqs, last_hstate

# %% [markdown]
# ## ISLR model

# %%
class RNNISLR(nn.Module):
    def __init__(self,
                 in_channels,
                 hidden_channels,
                 out_channels,
                 rnn_num_layers=1,
                 rnn_activation="tanh",
                 rnn_bidir=False,
                 rnn_dropout=0.1):
        super().__init__()

        self.linear = nn.Linear(in_channels, hidden_channels)
        self.activation = nn.ReLU()

        self.rnn = RNNEncoder(
            in_channels=hidden_channels,
            out_channels=hidden_channels,
            num_layers=rnn_num_layers,
            activation=rnn_activation,
            bidir=rnn_bidir,
            dropout=rnn_dropout)

        if rnn_bidir:
            self.head = GPoolRecognitionHead(hidden_channels * 2, out_channels)
        else:
            self.head = GPoolRecognitionHead(hidden_channels, out_channels)

    def forward(self, feature):
        # Feature extraction.
        # `[N, C, T, J] -> [N, T, C, J] -> [N, T, C*J] -> [N, T, C']`
        N, C, T, J = feature.shape
        feature = feature.permute([0, 2, 1, 3])
        feature = feature.reshape(N, T, -1)

        feature = self.linear(feature)
        feature = self.activation(feature)

        hidden_seqs, last_hstate = self.rnn(feature)

        # `[N, T, C'] -> [N, C', T]`
        feature = hidden_seqs.permute(0, 2, 1)

        logit = self.head(feature)
        return logit

# %% [markdown]
# ## Sanity check

# %%
# Access check.
dataset_dir = Path("dataset_top10")
files = list(dataset_dir.iterdir())
dictionary = [fin for fin in files if ".json" in fin.name][0]
hdf5_files = [fin for fin in files if ".hdf5" in fin.name]

print(dictionary)
print(hdf5_files)
# Out:
# dataset_top10/sign_to_prediction_index_map.json
# [PosixPath('dataset_top10/36257.hdf5'), PosixPath('dataset_top10/26734.hdf5'), PosixPath('dataset_top10/34503.hdf5'), PosixPath('dataset_top10/2044.hdf5'), PosixPath('dataset_top10/49445.hdf5'), PosixPath('dataset_top10/32319.hdf5'), PosixPath('dataset_top10/55372.hdf5'), PosixPath('dataset_top10/37055.hdf5'), PosixPath('dataset_top10/62590.hdf5'), PosixPath('dataset_top10/27610.hdf5'), PosixPath('dataset_top10/28656.hdf5'), PosixPath('dataset_top10/16069.hdf5'), PosixPath('dataset_top10/53618.hdf5'), PosixPath('dataset_top10/4718.hdf5'), PosixPath('dataset_top10/61333.hdf5'), PosixPath('dataset_top10/18796.hdf5'), PosixPath('dataset_top10/29302.hdf5'), PosixPath('dataset_top10/22343.hdf5'), PosixPath('dataset_top10/25571.hdf5'), PosixPath('dataset_top10/30680.hdf5'), PosixPath('dataset_top10/37779.hdf5')]

# %%
# Load dictionary.
with open(dictionary, "r") as fread:
    key2token = json.load(fread)

VOCAB = len(key2token)

# %%
_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
trans_select_feature = SelectLandmarksAndFeature(landmarks=use_landmarks, features=use_features)
trans_repnan = ReplaceNan()
trans_norm = PartsBasedNormalization(align_mode="framewise", scale_mode="unique")

pre_transforms = Compose([trans_select_feature,
                          trans_repnan,
                          trans_norm])
transforms = Compose([ToTensor()])

# %%
batch_size = 2
feature_shape = (len(use_features), -1, len(use_landmarks))
token_shape = (1,)
merge_fn = partial(merge_padded_batch,
                   feature_shape=feature_shape,
                   token_shape=token_shape,
                   feature_padding_val=0.0,
                   token_padding_val=0)

dataset = HDF5Dataset(hdf5_files, pre_transforms=pre_transforms, transforms=transforms)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=merge_fn)
try:
    data = next(iter(dataloader))
    feature_origin = data["feature"]

    print(feature_origin.shape)
except Exception as inst:
    print(inst)
# Out:
# torch.Size([2, 2, 75, 130])

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
hidden_channels = 64
out_channels = VOCAB
rnn_num_layers=1
rnn_bidir=False
rnn_dropout=0.1

model = RNNISLR(in_channels=in_channels,
                hidden_channels=hidden_channels,
                out_channels=out_channels,
                rnn_num_layers=rnn_num_layers,
                rnn_bidir=rnn_bidir)
print(model)

# Sanity check.
logit = model(feature_origin)
print(logit.shape)
# Out:
# RNNISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (rnn): RNNEncoder(
#     (rnn): RNN(64, 64, batch_first=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %% [markdown]
# # 4. Train and evaluation

# %% [markdown]
# ## 4.1 Common settings

# %%
# Set common parameters.
batch_size = 32
load_into_ram = True
test_pid = 16069
num_workers = 1
lr = 3e-4

epochs = 50
eval_every_n_epochs = 1
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} for computation.")

train_hdf5files = [fin for fin in hdf5_files if str(test_pid) not in fin.name]
val_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]
test_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]

_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
# Out:
# Using cpu for computation.

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)

# %% [markdown]
# ## 4.2 Compare RNN processing

# %% [markdown]
# ### Default settings

# %%
rnn_num_layers = 1
rnn_bidir = False

model = RNNISLR(in_channels=in_channels,
                hidden_channels=hidden_channels,
                out_channels=out_channels,
                rnn_num_layers=rnn_num_layers,
                rnn_bidir=rnn_bidir)
print(model)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
# Out:
# RNNISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (rnn): RNNEncoder(
#     (rnn): RNN(64, 64, batch_first=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_default = np.array(val_losses)
test_accs_default = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_default.min()} at {np.argmin(val_losses_default)+1} epoch.")
print(f"Maximum accuracy:{test_accs_default.max()} at {np.argmax(test_accs_default)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.381061 [    0/ 3881]
# loss:2.203806 [ 3200/ 3881]
# Done. Time:8.330574689999992
# Training performance:
#  Avg loss:2.285100
#
# Start validation.
# Done. Time:0.4123331119999989
# Validation performance:
#  Avg loss:2.250277
#
# Start evaluation.
# Done. Time:1.990554211000017
# Test performance:
#  Accuracy:31.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.232667 [    0/ 3881]
# loss:2.010535 [ 3200/ 3881]
# Done. Time:8.846898243999988
# Training performance:
#  Avg loss:2.079818
#
# Start validation.
# Done. Time:0.41894534700003305
# Validation performance:
#  Avg loss:1.992667
#
# Start evaluation.
# Done. Time:1.2393297779999557
# Test performance:
#  Accuracy:25.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.999848 [    0/ 3881]
# loss:2.154104 [ 3200/ 3881]
# Done. Time:9.626410497000052
# Training performance:
#  Avg loss:2.031224
#
# Start validation.
# Done. Time:0.34122946799999454
# Validation performance:
#  Avg loss:2.003095
#
# Start evaluation.
# Done. Time:1.0738683330000072
# Test performance:
#  Accuracy:34.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.896698 [    0/ 3881]
# loss:2.174790 [ 3200/ 3881]
# Done. Time:10.375704101999986
# Training performance:
#  Avg loss:1.941445
#
# Start validation.
# Done. Time:0.34163883399997985
# Validation performance:
#  Avg loss:2.448371
#
# Start evaluation.
# Done. Time:1.0090154569999754
# Test performance:
#  Accuracy:27.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:2.179247 [    0/ 3881]
# loss:1.748843 [ 3200/ 3881]
# Done. Time:9.469051519000004
# Training performance:
#  Avg loss:1.871249
#
# Start validation.
# Done. Time:0.5229598160000251
# Validation performance:
#  Avg loss:1.912372
#
# Start evaluation.
# Done. Time:1.1541847679999933
# Test performance:
#  Accuracy:37.0%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.821376 [    0/ 3881]
# loss:1.836896 [ 3200/ 3881]
# Done. Time:8.133256732000007
# Training performance:
#  Avg loss:1.811995
#
# Start validation.
# Done. Time:0.35078496400001313
# Validation performance:
#  Avg loss:1.815764
#
# Start evaluation.
# Done. Time:1.5401435769999807
# Test performance:
#  Accuracy:29.5%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.930623 [    0/ 3881]
# loss:1.738157 [ 3200/ 3881]
# Done. Time:9.531255531999989
# Training performance:
#  Avg loss:1.773885
#
# Start validation.
# Done. Time:0.4060961749999592
# Validation performance:
#  Avg loss:1.856452
#
# Start evaluation.
# Done. Time:1.0367683200000215
# Test performance:
#  Accuracy:44.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.921852 [    0/ 3881]
# loss:2.920776 [ 3200/ 3881]
# Done. Time:10.810719909
# Training performance:
#  Avg loss:2.120889
#
# Start validation.
# Done. Time:0.3710904999999798
# Validation performance:
#  Avg loss:2.288758
#
# Start evaluation.
# Done. Time:1.3422237120000204
# Test performance:
#  Accuracy:30.5%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:2.258072 [    0/ 3881]
# loss:2.273216 [ 3200/ 3881]
# Done. Time:10.491417044000002
# Training performance:
#  Avg loss:2.060750
#
# Start validation.
# Done. Time:0.36990486700000247
# Validation performance:
#  Avg loss:1.958074
#
# Start evaluation.
# Done. Time:1.3766154000000483
# Test performance:
#  Accuracy:36.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:2.082300 [    0/ 3881]
# loss:1.782544 [ 3200/ 3881]
# Done. Time:10.031249481999964
# Training performance:
#  Avg loss:1.917457
#
# Start validation.
# Done. Time:0.3452963519999912
# Validation performance:
#  Avg loss:1.909491
#
# Start evaluation.
# Done. Time:1.025277898000013
# Test performance:
#  Accuracy:38.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.842420 [    0/ 3881]
# loss:1.875620 [ 3200/ 3881]
# Done. Time:9.054716237999969
# Training performance:
#  Avg loss:1.860904
#
# Start validation.
# Done. Time:0.5685106529999757
# Validation performance:
#  Avg loss:1.908012
#
# Start evaluation.
# Done. Time:1.6121718960000067
# Test performance:
#  Accuracy:37.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.566030 [    0/ 3881]
# loss:1.989510 [ 3200/ 3881]
# Done. Time:8.541109197999958
# Training performance:
#  Avg loss:1.815739
#
# Start validation.
# Done. Time:0.42644541900000377
# Validation performance:
#  Avg loss:1.895698
#
# Start evaluation.
# Done. Time:1.5027159539999957
# Test performance:
#  Accuracy:38.5%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.902078 [    0/ 3881]
# loss:1.813339 [ 3200/ 3881]
# Done. Time:9.721786270999985
# Training performance:
#  Avg loss:1.828948
#
# Start validation.
# Done. Time:0.35182979799998293
# Validation performance:
#  Avg loss:1.821843
#
# Start evaluation.
# Done. Time:1.180401302000007
# Test performance:
#  Accuracy:42.0%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.895631 [    0/ 3881]
# loss:1.619098 [ 3200/ 3881]
# Done. Time:9.661350129000027
# Training performance:
#  Avg loss:1.775338
#
# Start validation.
# Done. Time:0.4563106649999895
# Validation performance:
#  Avg loss:1.828757
#
# Start evaluation.
# Done. Time:1.1460447680000243
# Test performance:
#  Accuracy:40.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:1.649376 [    0/ 3881]
# loss:1.650616 [ 3200/ 3881]
# Done. Time:10.11522359700001
# Training performance:
#  Avg loss:1.749062
#
# Start validation.
# Done. Time:0.42323661999995466
# Validation performance:
#  Avg loss:1.743049
#
# Start evaluation.
# Done. Time:1.299634009999977
# Test performance:
#  Accuracy:39.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.902464 [    0/ 3881]
# loss:1.683168 [ 3200/ 3881]
# Done. Time:10.332338132000018
# Training performance:
#  Avg loss:1.730403
#
# Start validation.
# Done. Time:0.6783338799999683
# Validation performance:
#  Avg loss:1.766940
#
# Start evaluation.
# Done. Time:1.3697597550000182
# Test performance:
#  Accuracy:39.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.937396 [    0/ 3881]
# loss:1.912755 [ 3200/ 3881]
# Done. Time:8.514140079000015
# Training performance:
#  Avg loss:1.710566
#
# Start validation.
# Done. Time:0.479757262000021
# Validation performance:
#  Avg loss:1.717701
#
# Start evaluation.
# Done. Time:1.740108308999993
# Test performance:
#  Accuracy:42.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.614588 [    0/ 3881]
# loss:2.021308 [ 3200/ 3881]
# Done. Time:9.442309480999995
# Training performance:
#  Avg loss:1.686694
#
# Start validation.
# Done. Time:0.4459172020000324
# Validation performance:
#  Avg loss:1.716353
#
# Start evaluation.
# Done. Time:1.1646005499999887
# Test performance:
#  Accuracy:41.0%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.639657 [    0/ 3881]
# loss:1.555969 [ 3200/ 3881]
# Done. Time:10.146797150999987
# Training performance:
#  Avg loss:1.670039
#
# Start validation.
# Done. Time:0.35976112100001956
# Validation performance:
#  Avg loss:1.680863
#
# Start evaluation.
# Done. Time:1.086620914999969
# Test performance:
#  Accuracy:40.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.553420 [    0/ 3881]
# loss:1.348008 [ 3200/ 3881]
# Done. Time:9.883965079999996
# Training performance:
#  Avg loss:1.656350
#
# Start validation.
# Done. Time:0.41983070300000236
# Validation performance:
#  Avg loss:1.659849
#
# Start evaluation.
# Done. Time:1.0709611579999887
# Test performance:
#  Accuracy:42.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:2.000562 [    0/ 3881]
# loss:1.699819 [ 3200/ 3881]
# Done. Time:10.02039941800001
# Training performance:
#  Avg loss:1.640577
#
# Start validation.
# Done. Time:0.36367682799999557
# Validation performance:
#  Avg loss:1.619400
#
# Start evaluation.
# Done. Time:1.0585318120000125
# Test performance:
#  Accuracy:39.5%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.741950 [    0/ 3881]
# loss:1.645875 [ 3200/ 3881]
# Done. Time:8.850892416000022
# Training performance:
#  Avg loss:1.604731
#
# Start validation.
# Done. Time:0.6777440879999972
# Validation performance:
#  Avg loss:1.645955
#
# Start evaluation.
# Done. Time:1.6854730679999648
# Test performance:
#  Accuracy:44.0%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.680812 [    0/ 3881]
# loss:1.517929 [ 3200/ 3881]
# Done. Time:8.637028655999984
# Training performance:
#  Avg loss:1.606289
#
# Start validation.
# Done. Time:0.4587304140000015
# Validation performance:
#  Avg loss:1.659254
#
# Start evaluation.
# Done. Time:1.2791362899999967
# Test performance:
#  Accuracy:42.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.621113 [    0/ 3881]
# loss:1.585683 [ 3200/ 3881]
# Done. Time:10.902249966
# Training performance:
#  Avg loss:1.628454
#
# Start validation.
# Done. Time:1.0850059269999974
# Validation performance:
#  Avg loss:1.574200
#
# Start evaluation.
# Done. Time:3.6508064430000786
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.478584 [    0/ 3881]
# loss:1.632286 [ 3200/ 3881]
# Done. Time:9.356592661000036
# Training performance:
#  Avg loss:1.639080
#
# Start validation.
# Done. Time:0.41941478299997925
# Validation performance:
#  Avg loss:1.565048
#
# Start evaluation.
# Done. Time:1.2138158679999833
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.553617 [    0/ 3881]
# loss:1.764918 [ 3200/ 3881]
# Done. Time:9.936889627000028
# Training performance:
#  Avg loss:1.589100
#
# Start validation.
# Done. Time:0.4475037419999808
# Validation performance:
#  Avg loss:1.562937
#
# Start evaluation.
# Done. Time:1.4307228870000017
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.563341 [    0/ 3881]
# loss:1.641979 [ 3200/ 3881]
# Done. Time:10.356578500999944
# Training performance:
#  Avg loss:1.730021
#
# Start validation.
# Done. Time:0.4447805449999578
# Validation performance:
#  Avg loss:1.640590
#
# Start evaluation.
# Done. Time:1.5172716530000798
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.578378 [    0/ 3881]
# loss:1.490805 [ 3200/ 3881]
# Done. Time:9.778289333999965
# Training performance:
#  Avg loss:1.598739
#
# Start validation.
# Done. Time:0.38526857099998324
# Validation performance:
#  Avg loss:1.593051
#
# Start evaluation.
# Done. Time:1.3012292170000137
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:1.623613 [    0/ 3881]
# loss:1.770474 [ 3200/ 3881]
# Done. Time:9.747773880999944
# Training performance:
#  Avg loss:1.561631
#
# Start validation.
# Done. Time:1.378377955000019
# Validation performance:
#  Avg loss:1.627555
#
# Start evaluation.
# Done. Time:3.1954987750000328
# Test performance:
#  Accuracy:50.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.643484 [    0/ 3881]
# loss:1.149522 [ 3200/ 3881]
# Done. Time:12.319660490000047
# Training performance:
#  Avg loss:1.550082
#
# Start validation.
# Done. Time:0.6090587639999967
# Validation performance:
#  Avg loss:1.550678
#
# Start evaluation.
# Done. Time:1.5305987279999727
# Test performance:
#  Accuracy:50.5%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:1.481821 [    0/ 3881]
# loss:1.458218 [ 3200/ 3881]
# Done. Time:13.482394505999991
# Training performance:
#  Avg loss:1.519902
#
# Start validation.
# Done. Time:0.7845028689999936
# Validation performance:
#  Avg loss:1.566311
#
# Start evaluation.
# Done. Time:1.8790733499999988
# Test performance:
#  Accuracy:48.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.508722 [    0/ 3881]
# loss:1.332744 [ 3200/ 3881]
# Done. Time:12.399798912000051
# Training performance:
#  Avg loss:1.510300
#
# Start validation.
# Done. Time:0.6016658700000335
# Validation performance:
#  Avg loss:1.565664
#
# Start evaluation.
# Done. Time:1.419219812999927
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:1.625754 [    0/ 3881]
# loss:1.824798 [ 3200/ 3881]
# Done. Time:10.327310205999993
# Training performance:
#  Avg loss:1.508816
#
# Start validation.
# Done. Time:0.7333798619999925
# Validation performance:
#  Avg loss:1.516315
#
# Start evaluation.
# Done. Time:1.6841565259999243
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:1.700072 [    0/ 3881]
# loss:1.452805 [ 3200/ 3881]
# Done. Time:8.213156679000008
# Training performance:
#  Avg loss:1.508616
#
# Start validation.
# Done. Time:0.39170669899999666
# Validation performance:
#  Avg loss:1.503395
#
# Start evaluation.
# Done. Time:1.6472718999999643
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.576695 [    0/ 3881]
# loss:1.684050 [ 3200/ 3881]
# Done. Time:10.045311135999896
# Training performance:
#  Avg loss:1.477413
#
# Start validation.
# Done. Time:0.48317747700002656
# Validation performance:
#  Avg loss:1.541149
#
# Start evaluation.
# Done. Time:1.3094523459999436
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.860755 [    0/ 3881]
# loss:1.336361 [ 3200/ 3881]
# Done. Time:9.556760438000083
# Training performance:
#  Avg loss:1.537767
#
# Start validation.
# Done. Time:0.370324668999956
# Validation performance:
#  Avg loss:1.540799
#
# Start evaluation.
# Done. Time:1.0835957870000357
# Test performance:
#  Accuracy:53.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.377318 [    0/ 3881]
# loss:2.112043 [ 3200/ 3881]
# Done. Time:10.156646432000002
# Training performance:
#  Avg loss:1.609838
#
# Start validation.
# Done. Time:0.3849580070000229
# Validation performance:
#  Avg loss:1.815126
#
# Start evaluation.
# Done. Time:1.123625532999995
# Test performance:
#  Accuracy:39.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.489206 [    0/ 3881]
# loss:1.596280 [ 3200/ 3881]
# Done. Time:9.277129133000017
# Training performance:
#  Avg loss:1.591382
#
# Start validation.
# Done. Time:0.6044153560000041
# Validation performance:
#  Avg loss:1.570992
#
# Start evaluation.
# Done. Time:1.3777413750000278
# Test performance:
#  Accuracy:49.0%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:1.804117 [    0/ 3881]
# loss:1.480091 [ 3200/ 3881]
# Done. Time:9.077889724999977
# Training performance:
#  Avg loss:1.511874
#
# Start validation.
# Done. Time:0.5424637649999795
# Validation performance:
#  Avg loss:2.019498
#
# Start evaluation.
# Done. Time:2.0580043340000884
# Test performance:
#  Accuracy:38.5%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:1.623614 [    0/ 3881]
# loss:1.983542 [ 3200/ 3881]
# Done. Time:9.51222609399997
# Training performance:
#  Avg loss:1.539427
#
# Start validation.
# Done. Time:0.4539486090000082
# Validation performance:
#  Avg loss:1.646274
#
# Start evaluation.
# Done. Time:1.5221090409999078
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:1.291821 [    0/ 3881]
# loss:1.494985 [ 3200/ 3881]
# Done. Time:10.209800200000018
# Training performance:
#  Avg loss:1.430790
#
# Start validation.
# Done. Time:0.37972931700005574
# Validation performance:
#  Avg loss:1.494573
#
# Start evaluation.
# Done. Time:1.0201305809999894
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:1.348432 [    0/ 3881]
# loss:1.667758 [ 3200/ 3881]
# Done. Time:10.428521564999983
# Training performance:
#  Avg loss:1.459554
#
# Start validation.
# Done. Time:0.3738325930000883
# Validation performance:
#  Avg loss:1.466977
#
# Start evaluation.
# Done. Time:1.0492617190000146
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:1.336133 [    0/ 3881]
# loss:1.199041 [ 3200/ 3881]
# Done. Time:10.155142904999934
# Training performance:
#  Avg loss:1.437659
#
# Start validation.
# Done. Time:0.483824377000019
# Validation performance:
#  Avg loss:1.582771
#
# Start evaluation.
# Done. Time:1.4122478990000218
# Test performance:
#  Accuracy:50.5%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.986570 [    0/ 3881]
# loss:1.226243 [ 3200/ 3881]
# Done. Time:10.303956793999987
# Training performance:
#  Avg loss:1.387474
#
# Start validation.
# Done. Time:0.439949666000075
# Validation performance:
#  Avg loss:1.505280
#
# Start evaluation.
# Done. Time:1.3738947839999582
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:1.064789 [    0/ 3881]
# loss:1.230252 [ 3200/ 3881]
# Done. Time:9.279600588999983
# Training performance:
#  Avg loss:1.376129
#
# Start validation.
# Done. Time:0.5791674239999338
# Validation performance:
#  Avg loss:1.468119
#
# Start evaluation.
# Done. Time:1.641369028999975
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.465055 [    0/ 3881]
# loss:1.378769 [ 3200/ 3881]
# Done. Time:9.11124923300008
# Training performance:
#  Avg loss:1.384121
#
# Start validation.
# Done. Time:0.4231315409999752
# Validation performance:
#  Avg loss:1.649245
#
# Start evaluation.
# Done. Time:1.9096566340000436
# Test performance:
#  Accuracy:45.5%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:1.539585 [    0/ 3881]
# loss:1.167004 [ 3200/ 3881]
# Done. Time:9.412545942000065
# Training performance:
#  Avg loss:1.341374
#
# Start validation.
# Done. Time:0.37714712100000725
# Validation performance:
#  Avg loss:1.390662
#
# Start evaluation.
# Done. Time:1.0708817549999594
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:1.226749 [    0/ 3881]
# loss:1.584334 [ 3200/ 3881]
# Done. Time:10.591974820000019
# Training performance:
#  Avg loss:1.366256
#
# Start validation.
# Done. Time:0.3518150360000618
# Validation performance:
#  Avg loss:1.423794
#
# Start evaluation.
# Done. Time:1.2056476940000493
# Test performance:
#  Accuracy:53.0%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:1.283378 [    0/ 3881]
# loss:1.376007 [ 3200/ 3881]
# Done. Time:10.435017742000014
# Training performance:
#  Avg loss:1.351346
#
# Start validation.
# Done. Time:0.3728738009999688
# Validation performance:
#  Avg loss:1.372449
#
# Start evaluation.
# Done. Time:1.0064036420000093
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:1.730530 [    0/ 3881]
# loss:1.089235 [ 3200/ 3881]
# Done. Time:10.270259231000068
# Training performance:
#  Avg loss:1.319444
#
# Start validation.
# Done. Time:0.37530362199993306
# Validation performance:
#  Avg loss:1.381896
#
# Start evaluation.
# Done. Time:1.0423784470000328
# Test performance:
#  Accuracy:54.0%
# Minimum validation loss:1.3724491085324968 at 49 epoch.
# Maximum accuracy:56.00000000000001 at 40 epoch.

# %% [markdown]
# ### Layer settings
# #### Stacked RNN

# %%
rnn_num_layers = 2
rnn_bidir = False

model = RNNISLR(in_channels=in_channels,
                hidden_channels=hidden_channels,
                out_channels=out_channels,
                rnn_num_layers=rnn_num_layers,
                rnn_bidir=rnn_bidir)
print(model)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
# Out:
# RNNISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (rnn): RNNEncoder(
#     (rnn): RNN(64, 64, num_layers=2, batch_first=True, dropout=0.1)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_stacked = np.array(val_losses)
test_accs_stacked = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_stacked.min()} at {np.argmin(val_losses_stacked)+1} epoch.")
print(f"Maximum accuracy:{test_accs_stacked.max()} at {np.argmax(test_accs_stacked)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.322615 [    0/ 3881]
# loss:2.139993 [ 3200/ 3881]
# Done. Time:13.653494953999939
# Training performance:
#  Avg loss:2.268299
#
# Start validation.
# Done. Time:0.41295460699996056
# Validation performance:
#  Avg loss:2.198188
#
# Start evaluation.
# Done. Time:1.2576938539999674
# Test performance:
#  Accuracy:14.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.238565 [    0/ 3881]
# loss:2.236607 [ 3200/ 3881]
# Done. Time:14.590651777000062
# Training performance:
#  Avg loss:2.038709
#
# Start validation.
# Done. Time:0.46869870400007585
# Validation performance:
#  Avg loss:2.348731
#
# Start evaluation.
# Done. Time:1.2892606410000553
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:2.044657 [    0/ 3881]
# loss:2.022045 [ 3200/ 3881]
# Done. Time:13.864282656
# Training performance:
#  Avg loss:2.023497
#
# Start validation.
# Done. Time:0.41318255600003795
# Validation performance:
#  Avg loss:2.108187
#
# Start evaluation.
# Done. Time:1.4526707810000516
# Test performance:
#  Accuracy:24.5%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:2.076860 [    0/ 3881]
# loss:1.845271 [ 3200/ 3881]
# Done. Time:15.026237234000064
# Training performance:
#  Avg loss:2.028505
#
# Start validation.
# Done. Time:0.5209920629999942
# Validation performance:
#  Avg loss:2.049610
#
# Start evaluation.
# Done. Time:1.8135464619999766
# Test performance:
#  Accuracy:38.5%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.940642 [    0/ 3881]
# loss:1.705820 [ 3200/ 3881]
# Done. Time:14.50061478200007
# Training performance:
#  Avg loss:1.856223
#
# Start validation.
# Done. Time:0.6869791379999697
# Validation performance:
#  Avg loss:1.978801
#
# Start evaluation.
# Done. Time:1.6274294400000144
# Test performance:
#  Accuracy:34.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.776575 [    0/ 3881]
# loss:1.523424 [ 3200/ 3881]
# Done. Time:14.230172427999946
# Training performance:
#  Avg loss:1.760953
#
# Start validation.
# Done. Time:0.52973280599997
# Validation performance:
#  Avg loss:1.947545
#
# Start evaluation.
# Done. Time:1.5971467340000345
# Test performance:
#  Accuracy:36.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.891959 [    0/ 3881]
# loss:1.853075 [ 3200/ 3881]
# Done. Time:14.556352855
# Training performance:
#  Avg loss:1.867483
#
# Start validation.
# Done. Time:0.4284123180000279
# Validation performance:
#  Avg loss:1.819978
#
# Start evaluation.
# Done. Time:1.7160937229999718
# Test performance:
#  Accuracy:36.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.901552 [    0/ 3881]
# loss:2.137980 [ 3200/ 3881]
# Done. Time:14.654299585000103
# Training performance:
#  Avg loss:1.812289
#
# Start validation.
# Done. Time:0.43082024099999217
# Validation performance:
#  Avg loss:1.857902
#
# Start evaluation.
# Done. Time:1.4330234330000167
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.769461 [    0/ 3881]
# loss:1.511931 [ 3200/ 3881]
# Done. Time:14.890192364999962
# Training performance:
#  Avg loss:1.725812
#
# Start validation.
# Done. Time:0.6309029169999576
# Validation performance:
#  Avg loss:1.691472
#
# Start evaluation.
# Done. Time:2.049917564999987
# Test performance:
#  Accuracy:38.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.776761 [    0/ 3881]
# loss:1.623907 [ 3200/ 3881]
# Done. Time:15.895664760000045
# Training performance:
#  Avg loss:1.659467
#
# Start validation.
# Done. Time:0.5357049970000389
# Validation performance:
#  Avg loss:1.735623
#
# Start evaluation.
# Done. Time:1.3583190709999826
# Test performance:
#  Accuracy:37.5%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.651177 [    0/ 3881]
# loss:1.738941 [ 3200/ 3881]
# Done. Time:14.470217404999971
# Training performance:
#  Avg loss:1.591887
#
# Start validation.
# Done. Time:0.5463586260000284
# Validation performance:
#  Avg loss:1.645636
#
# Start evaluation.
# Done. Time:1.5151670630000353
# Test performance:
#  Accuracy:41.0%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.542480 [    0/ 3881]
# loss:1.719964 [ 3200/ 3881]
# Done. Time:14.50532925199991
# Training performance:
#  Avg loss:1.544626
#
# Start validation.
# Done. Time:0.44209427100008725
# Validation performance:
#  Avg loss:1.642458
#
# Start evaluation.
# Done. Time:1.303130603999989
# Test performance:
#  Accuracy:43.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.873030 [    0/ 3881]
# loss:1.285999 [ 3200/ 3881]
# Done. Time:14.129711456999985
# Training performance:
#  Avg loss:1.438529
#
# Start validation.
# Done. Time:0.4450537720001648
# Validation performance:
#  Avg loss:1.634086
#
# Start evaluation.
# Done. Time:1.297052623000127
# Test performance:
#  Accuracy:46.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.675059 [    0/ 3881]
# loss:1.315136 [ 3200/ 3881]
# Done. Time:14.588447008000003
# Training performance:
#  Avg loss:1.393861
#
# Start validation.
# Done. Time:0.7581840800000919
# Validation performance:
#  Avg loss:1.738647
#
# Start evaluation.
# Done. Time:1.8792273720000594
# Test performance:
#  Accuracy:48.0%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:1.300067 [    0/ 3881]
# loss:1.145968 [ 3200/ 3881]
# Done. Time:14.71629090600004
# Training performance:
#  Avg loss:1.350643
#
# Start validation.
# Done. Time:0.6014322689998153
# Validation performance:
#  Avg loss:1.614426
#
# Start evaluation.
# Done. Time:1.2684196060001796
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.846536 [    0/ 3881]
# loss:1.469759 [ 3200/ 3881]
# Done. Time:15.787559298999895
# Training performance:
#  Avg loss:1.375177
#
# Start validation.
# Done. Time:0.5463982939998004
# Validation performance:
#  Avg loss:1.587441
#
# Start evaluation.
# Done. Time:1.5403085400000691
# Test performance:
#  Accuracy:53.0%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.278838 [    0/ 3881]
# loss:1.922542 [ 3200/ 3881]
# Done. Time:14.393653682999911
# Training performance:
#  Avg loss:1.523076
#
# Start validation.
# Done. Time:0.5451187259998278
# Validation performance:
#  Avg loss:1.587628
#
# Start evaluation.
# Done. Time:1.3093540120000853
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.314327 [    0/ 3881]
# loss:1.261463 [ 3200/ 3881]
# Done. Time:14.774522036000008
# Training performance:
#  Avg loss:1.452905
#
# Start validation.
# Done. Time:0.44915265100007673
# Validation performance:
#  Avg loss:1.422882
#
# Start evaluation.
# Done. Time:1.5875653729999613
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.271955 [    0/ 3881]
# loss:1.247220 [ 3200/ 3881]
# Done. Time:14.258657533999894
# Training performance:
#  Avg loss:1.600625
#
# Start validation.
# Done. Time:0.782311017999973
# Validation performance:
#  Avg loss:1.698998
#
# Start evaluation.
# Done. Time:1.7451899819998289
# Test performance:
#  Accuracy:49.0%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:2.286342 [    0/ 3881]
# loss:1.262439 [ 3200/ 3881]
# Done. Time:14.254542571999991
# Training performance:
#  Avg loss:1.457115
#
# Start validation.
# Done. Time:0.4261715830000412
# Validation performance:
#  Avg loss:1.873625
#
# Start evaluation.
# Done. Time:1.2276884850000442
# Test performance:
#  Accuracy:47.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.789600 [    0/ 3881]
# loss:1.360998 [ 3200/ 3881]
# Done. Time:13.69605733100002
# Training performance:
#  Avg loss:1.415514
#
# Start validation.
# Done. Time:0.4343059650000214
# Validation performance:
#  Avg loss:1.465886
#
# Start evaluation.
# Done. Time:1.2212468369998533
# Test performance:
#  Accuracy:52.5%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.387318 [    0/ 3881]
# loss:1.531392 [ 3200/ 3881]
# Done. Time:19.276884968999866
# Training performance:
#  Avg loss:1.339151
#
# Start validation.
# Done. Time:0.5527408839998316
# Validation performance:
#  Avg loss:1.470303
#
# Start evaluation.
# Done. Time:1.2761567180000384
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.267411 [    0/ 3881]
# loss:1.221144 [ 3200/ 3881]
# Done. Time:13.79273946499984
# Training performance:
#  Avg loss:1.216329
#
# Start validation.
# Done. Time:0.5091277550000086
# Validation performance:
#  Avg loss:1.280584
#
# Start evaluation.
# Done. Time:1.2654141230000278
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.029989 [    0/ 3881]
# loss:1.448038 [ 3200/ 3881]
# Done. Time:13.914641469999879
# Training performance:
#  Avg loss:1.281384
#
# Start validation.
# Done. Time:0.4467329819999577
# Validation performance:
#  Avg loss:1.292000
#
# Start evaluation.
# Done. Time:1.4808737430000747
# Test performance:
#  Accuracy:52.5%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.342149 [    0/ 3881]
# loss:0.754236 [ 3200/ 3881]
# Done. Time:15.59607421099986
# Training performance:
#  Avg loss:1.153286
#
# Start validation.
# Done. Time:0.6320748200000708
# Validation performance:
#  Avg loss:1.247722
#
# Start evaluation.
# Done. Time:1.9133133469999848
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.233800 [    0/ 3881]
# loss:1.168204 [ 3200/ 3881]
# Done. Time:14.619485274999988
# Training performance:
#  Avg loss:1.117483
#
# Start validation.
# Done. Time:0.5563330160000532
# Validation performance:
#  Avg loss:1.311270
#
# Start evaluation.
# Done. Time:1.6501469310001085
# Test performance:
#  Accuracy:60.0%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.215478 [    0/ 3881]
# loss:1.217647 [ 3200/ 3881]
# Done. Time:15.544562910999957
# Training performance:
#  Avg loss:1.144866
#
# Start validation.
# Done. Time:0.5680817679999564
# Validation performance:
#  Avg loss:1.302499
#
# Start evaluation.
# Done. Time:1.5219903160000285
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.967600 [    0/ 3881]
# loss:0.959587 [ 3200/ 3881]
# Done. Time:14.755282793999868
# Training performance:
#  Avg loss:1.088927
#
# Start validation.
# Done. Time:0.46569200199996885
# Validation performance:
#  Avg loss:1.191664
#
# Start evaluation.
# Done. Time:1.4285156779999397
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.626723 [    0/ 3881]
# loss:0.799656 [ 3200/ 3881]
# Done. Time:13.65514876799989
# Training performance:
#  Avg loss:1.041146
#
# Start validation.
# Done. Time:0.6511565980001706
# Validation performance:
#  Avg loss:1.144071
#
# Start evaluation.
# Done. Time:1.8723260899998877
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.823430 [    0/ 3881]
# loss:1.271987 [ 3200/ 3881]
# Done. Time:13.586184940000066
# Training performance:
#  Avg loss:0.991424
#
# Start validation.
# Done. Time:0.681544059000089
# Validation performance:
#  Avg loss:1.230637
#
# Start evaluation.
# Done. Time:1.258149814000035
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.974351 [    0/ 3881]
# loss:0.910630 [ 3200/ 3881]
# Done. Time:13.619592839999996
# Training performance:
#  Avg loss:0.960034
#
# Start validation.
# Done. Time:0.43877301399993485
# Validation performance:
#  Avg loss:1.140071
#
# Start evaluation.
# Done. Time:1.2711566959999345
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.833556 [    0/ 3881]
# loss:0.772450 [ 3200/ 3881]
# Done. Time:14.025665598999922
# Training performance:
#  Avg loss:0.949557
#
# Start validation.
# Done. Time:0.4364116429999285
# Validation performance:
#  Avg loss:1.164977
#
# Start evaluation.
# Done. Time:1.4543484949999765
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.834703 [    0/ 3881]
# loss:0.868325 [ 3200/ 3881]
# Done. Time:13.763984979999805
# Training performance:
#  Avg loss:0.957516
#
# Start validation.
# Done. Time:0.43283828100015853
# Validation performance:
#  Avg loss:2.433313
#
# Start evaluation.
# Done. Time:1.2820186960000228
# Test performance:
#  Accuracy:30.0%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:1.204468 [    0/ 3881]
# loss:1.340336 [ 3200/ 3881]
# Done. Time:15.35214139499999
# Training performance:
#  Avg loss:1.116308
#
# Start validation.
# Done. Time:0.4510395200002222
# Validation performance:
#  Avg loss:1.379430
#
# Start evaluation.
# Done. Time:1.4709536469999875
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.972679 [    0/ 3881]
# loss:0.793002 [ 3200/ 3881]
# Done. Time:14.494744702999924
# Training performance:
#  Avg loss:1.835022
#
# Start validation.
# Done. Time:0.7142774220001229
# Validation performance:
#  Avg loss:1.931557
#
# Start evaluation.
# Done. Time:2.0406265460001123
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.425874 [    0/ 3881]
# loss:1.237852 [ 3200/ 3881]
# Done. Time:14.687900712999863
# Training performance:
#  Avg loss:1.600231
#
# Start validation.
# Done. Time:0.4424824359998638
# Validation performance:
#  Avg loss:1.482284
#
# Start evaluation.
# Done. Time:1.2545600490000197
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.917735 [    0/ 3881]
# loss:0.845066 [ 3200/ 3881]
# Done. Time:13.992723872999932
# Training performance:
#  Avg loss:1.107849
#
# Start validation.
# Done. Time:0.44680211800005054
# Validation performance:
#  Avg loss:1.412017
#
# Start evaluation.
# Done. Time:1.296650629000169
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.150112 [    0/ 3881]
# loss:0.952203 [ 3200/ 3881]
# Done. Time:14.377527934
# Training performance:
#  Avg loss:1.069927
#
# Start validation.
# Done. Time:0.5621721709999292
# Validation performance:
#  Avg loss:1.338728
#
# Start evaluation.
# Done. Time:1.2640144499998769
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.906733 [    0/ 3881]
# loss:1.122172 [ 3200/ 3881]
# Done. Time:14.17140091400006
# Training performance:
#  Avg loss:0.934873
#
# Start validation.
# Done. Time:0.44800347299997156
# Validation performance:
#  Avg loss:1.353324
#
# Start evaluation.
# Done. Time:1.2998376619998453
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.751847 [    0/ 3881]
# loss:0.767503 [ 3200/ 3881]
# Done. Time:15.167080139000063
# Training performance:
#  Avg loss:0.978708
#
# Start validation.
# Done. Time:0.528480798000146
# Validation performance:
#  Avg loss:1.376804
#
# Start evaluation.
# Done. Time:2.318501296000022
# Test performance:
#  Accuracy:53.0%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.593845 [    0/ 3881]
# loss:1.019250 [ 3200/ 3881]
# Done. Time:14.55018542599987
# Training performance:
#  Avg loss:0.898567
#
# Start validation.
# Done. Time:0.7346080530001018
# Validation performance:
#  Avg loss:1.416093
#
# Start evaluation.
# Done. Time:1.2989675260000695
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.652295 [    0/ 3881]
# loss:1.137999 [ 3200/ 3881]
# Done. Time:14.424210260000109
# Training performance:
#  Avg loss:0.896407
#
# Start validation.
# Done. Time:0.5501070370000889
# Validation performance:
#  Avg loss:1.267257
#
# Start evaluation.
# Done. Time:1.4585773430001154
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.697579 [    0/ 3881]
# loss:1.360433 [ 3200/ 3881]
# Done. Time:14.10023055900001
# Training performance:
#  Avg loss:0.995297
#
# Start validation.
# Done. Time:0.5773005210000974
# Validation performance:
#  Avg loss:1.792238
#
# Start evaluation.
# Done. Time:1.337481106000041
# Test performance:
#  Accuracy:35.5%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.953514 [    0/ 3881]
# loss:1.142191 [ 3200/ 3881]
# Done. Time:15.248668648000148
# Training performance:
#  Avg loss:1.105500
#
# Start validation.
# Done. Time:0.556601351999916
# Validation performance:
#  Avg loss:1.512183
#
# Start evaluation.
# Done. Time:1.2837960619999649
# Test performance:
#  Accuracy:49.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.950996 [    0/ 3881]
# loss:1.448585 [ 3200/ 3881]
# Done. Time:14.246642564000012
# Training performance:
#  Avg loss:1.155681
#
# Start validation.
# Done. Time:0.44701602600002843
# Validation performance:
#  Avg loss:1.563362
#
# Start evaluation.
# Done. Time:1.937449178000179
# Test performance:
#  Accuracy:51.0%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.241988 [    0/ 3881]
# loss:1.440133 [ 3200/ 3881]
# Done. Time:14.896965693000084
# Training performance:
#  Avg loss:1.225063
#
# Start validation.
# Done. Time:0.7298174929999277
# Validation performance:
#  Avg loss:1.611168
#
# Start evaluation.
# Done. Time:1.4535813249999592
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:1.159273 [    0/ 3881]
# loss:2.642059 [ 3200/ 3881]
# Done. Time:14.489939182999933
# Training performance:
#  Avg loss:1.377002
#
# Start validation.
# Done. Time:0.4517807330000778
# Validation performance:
#  Avg loss:2.034287
#
# Start evaluation.
# Done. Time:1.2773655080000026
# Test performance:
#  Accuracy:38.5%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:1.359158 [    0/ 3881]
# loss:1.301970 [ 3200/ 3881]
# Done. Time:14.83425948199988
# Training performance:
#  Avg loss:1.442564
#
# Start validation.
# Done. Time:0.5361177699999189
# Validation performance:
#  Avg loss:1.572216
#
# Start evaluation.
# Done. Time:1.299896512000032
# Test performance:
#  Accuracy:51.0%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:1.720033 [    0/ 3881]
# loss:1.351265 [ 3200/ 3881]
# Done. Time:13.845179098000017
# Training performance:
#  Avg loss:1.308452
#
# Start validation.
# Done. Time:0.4448050119999607
# Validation performance:
#  Avg loss:1.502444
#
# Start evaluation.
# Done. Time:1.2570518879999781
# Test performance:
#  Accuracy:51.5%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:1.245982 [    0/ 3881]
# loss:0.932748 [ 3200/ 3881]
# Done. Time:14.725174239000125
# Training performance:
#  Avg loss:1.101934
#
# Start validation.
# Done. Time:0.4686780510000972
# Validation performance:
#  Avg loss:1.409058
#
# Start evaluation.
# Done. Time:1.7807051190000038
# Test performance:
#  Accuracy:53.5%
# Minimum validation loss:1.1400705320494515 at 31 epoch.
# Maximum accuracy:62.0 at 42 epoch.

# %% [markdown]
# #### Bidirectional RNN

# %%
rnn_num_layers = 1
rnn_bidir = True

model = RNNISLR(in_channels=in_channels,
                hidden_channels=hidden_channels,
                out_channels=out_channels,
                rnn_num_layers=rnn_num_layers,
                rnn_bidir=rnn_bidir)
print(model)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
# Out:
# RNNISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (rnn): RNNEncoder(
#     (rnn): RNN(64, 64, batch_first=True, bidirectional=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_bidir = np.array(val_losses)
test_accs_bidir = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_bidir.min()} at {np.argmin(val_losses_bidir)+1} epoch.")
print(f"Maximum accuracy:{test_accs_bidir.max()} at {np.argmax(test_accs_bidir)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.441820 [    0/ 3881]
# loss:2.204273 [ 3200/ 3881]
# Done. Time:16.3610092429999
# Training performance:
#  Avg loss:2.270479
#
# Start validation.
# Done. Time:0.6221634840001116
# Validation performance:
#  Avg loss:2.179463
#
# Start evaluation.
# Done. Time:1.2991981129998749
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.137298 [    0/ 3881]
# loss:1.991005 [ 3200/ 3881]
# Done. Time:15.421301946999847
# Training performance:
#  Avg loss:2.059482
#
# Start validation.
# Done. Time:0.5248382449999554
# Validation performance:
#  Avg loss:1.992030
#
# Start evaluation.
# Done. Time:1.494536213999936
# Test performance:
#  Accuracy:29.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.858036 [    0/ 3881]
# loss:2.295428 [ 3200/ 3881]
# Done. Time:15.447531408000032
# Training performance:
#  Avg loss:1.876907
#
# Start validation.
# Done. Time:0.5000737150000987
# Validation performance:
#  Avg loss:1.865532
#
# Start evaluation.
# Done. Time:1.3019388860000163
# Test performance:
#  Accuracy:39.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.760159 [    0/ 3881]
# loss:1.908725 [ 3200/ 3881]
# Done. Time:15.462493503999895
# Training performance:
#  Avg loss:1.745337
#
# Start validation.
# Done. Time:0.8263721039998018
# Validation performance:
#  Avg loss:1.960264
#
# Start evaluation.
# Done. Time:2.0964986269998462
# Test performance:
#  Accuracy:44.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.555050 [    0/ 3881]
# loss:1.634740 [ 3200/ 3881]
# Done. Time:15.677860114000168
# Training performance:
#  Avg loss:1.658923
#
# Start validation.
# Done. Time:0.5929486800000632
# Validation performance:
#  Avg loss:1.686637
#
# Start evaluation.
# Done. Time:1.463773331000084
# Test performance:
#  Accuracy:40.0%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.750088 [    0/ 3881]
# loss:1.493718 [ 3200/ 3881]
# Done. Time:15.765719861999969
# Training performance:
#  Avg loss:1.553780
#
# Start validation.
# Done. Time:0.48625743599995985
# Validation performance:
#  Avg loss:1.739443
#
# Start evaluation.
# Done. Time:1.5306363900001543
# Test performance:
#  Accuracy:43.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.680264 [    0/ 3881]
# loss:1.826796 [ 3200/ 3881]
# Done. Time:18.338704602000007
# Training performance:
#  Avg loss:1.885747
#
# Start validation.
# Done. Time:0.748667388000058
# Validation performance:
#  Avg loss:1.839283
#
# Start evaluation.
# Done. Time:1.5260019700001521
# Test performance:
#  Accuracy:35.5%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:2.072755 [    0/ 3881]
# loss:1.515020 [ 3200/ 3881]
# Done. Time:20.203866499000014
# Training performance:
#  Avg loss:1.814004
#
# Start validation.
# Done. Time:0.47899710000001505
# Validation performance:
#  Avg loss:1.758992
#
# Start evaluation.
# Done. Time:1.666735018000054
# Test performance:
#  Accuracy:43.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.725291 [    0/ 3881]
# loss:1.577056 [ 3200/ 3881]
# Done. Time:15.077606543999991
# Training performance:
#  Avg loss:1.757631
#
# Start validation.
# Done. Time:0.5977788319999036
# Validation performance:
#  Avg loss:1.752700
#
# Start evaluation.
# Done. Time:1.3729285130000335
# Test performance:
#  Accuracy:40.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.667818 [    0/ 3881]
# loss:1.757061 [ 3200/ 3881]
# Done. Time:16.983252515000004
# Training performance:
#  Avg loss:1.705874
#
# Start validation.
# Done. Time:0.7475149059998785
# Validation performance:
#  Avg loss:1.707170
#
# Start evaluation.
# Done. Time:1.349272418000055
# Test performance:
#  Accuracy:46.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.822367 [    0/ 3881]
# loss:1.535901 [ 3200/ 3881]
# Done. Time:15.478682517999914
# Training performance:
#  Avg loss:1.661288
#
# Start validation.
# Done. Time:0.5622273599999517
# Validation performance:
#  Avg loss:1.669419
#
# Start evaluation.
# Done. Time:1.3042194679999284
# Test performance:
#  Accuracy:47.0%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.479227 [    0/ 3881]
# loss:1.582189 [ 3200/ 3881]
# Done. Time:15.434797021000122
# Training performance:
#  Avg loss:1.628490
#
# Start validation.
# Done. Time:0.482611352000049
# Validation performance:
#  Avg loss:1.654997
#
# Start evaluation.
# Done. Time:1.3952700700001515
# Test performance:
#  Accuracy:47.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.392409 [    0/ 3881]
# loss:1.428525 [ 3200/ 3881]
# Done. Time:14.74960060599983
# Training performance:
#  Avg loss:1.599187
#
# Start validation.
# Done. Time:0.582687986999872
# Validation performance:
#  Avg loss:1.604412
#
# Start evaluation.
# Done. Time:2.1595000849999906
# Test performance:
#  Accuracy:53.0%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.798170 [    0/ 3881]
# loss:1.570829 [ 3200/ 3881]
# Done. Time:15.500216310000042
# Training performance:
#  Avg loss:1.581752
#
# Start validation.
# Done. Time:0.5018075830000726
# Validation performance:
#  Avg loss:1.669798
#
# Start evaluation.
# Done. Time:1.459950162000041
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:1.858022 [    0/ 3881]
# loss:1.250315 [ 3200/ 3881]
# Done. Time:15.243637372999956
# Training performance:
#  Avg loss:1.567029
#
# Start validation.
# Done. Time:0.5689829790001113
# Validation performance:
#  Avg loss:1.596312
#
# Start evaluation.
# Done. Time:1.334259424000038
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.667645 [    0/ 3881]
# loss:1.502659 [ 3200/ 3881]
# Done. Time:15.41577118500004
# Training performance:
#  Avg loss:1.495872
#
# Start validation.
# Done. Time:0.6111572439999691
# Validation performance:
#  Avg loss:1.586637
#
# Start evaluation.
# Done. Time:1.4936075000000528
# Test performance:
#  Accuracy:49.0%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.419327 [    0/ 3881]
# loss:1.232314 [ 3200/ 3881]
# Done. Time:15.525272361999896
# Training performance:
#  Avg loss:1.481336
#
# Start validation.
# Done. Time:0.7521132140000191
# Validation performance:
#  Avg loss:1.571458
#
# Start evaluation.
# Done. Time:1.8532279910000398
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.402245 [    0/ 3881]
# loss:1.369370 [ 3200/ 3881]
# Done. Time:15.38482238000006
# Training performance:
#  Avg loss:1.454762
#
# Start validation.
# Done. Time:0.4787129349999759
# Validation performance:
#  Avg loss:1.525257
#
# Start evaluation.
# Done. Time:1.3459202409999307
# Test performance:
#  Accuracy:50.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.667834 [    0/ 3881]
# loss:1.287899 [ 3200/ 3881]
# Done. Time:16.661884311999984
# Training performance:
#  Avg loss:1.418592
#
# Start validation.
# Done. Time:0.6179510609999852
# Validation performance:
#  Avg loss:1.541438
#
# Start evaluation.
# Done. Time:1.7597327989999485
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.438738 [    0/ 3881]
# loss:1.653100 [ 3200/ 3881]
# Done. Time:15.433804518999978
# Training performance:
#  Avg loss:1.404079
#
# Start validation.
# Done. Time:0.6822245169998951
# Validation performance:
#  Avg loss:1.526863
#
# Start evaluation.
# Done. Time:1.9664378579998356
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.091287 [    0/ 3881]
# loss:1.313303 [ 3200/ 3881]
# Done. Time:14.841771080999933
# Training performance:
#  Avg loss:1.383390
#
# Start validation.
# Done. Time:0.6422055029997864
# Validation performance:
#  Avg loss:1.479117
#
# Start evaluation.
# Done. Time:1.291445523999755
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.511088 [    0/ 3881]
# loss:0.990006 [ 3200/ 3881]
# Done. Time:15.918174761000046
# Training performance:
#  Avg loss:1.355815
#
# Start validation.
# Done. Time:0.5067324920000829
# Validation performance:
#  Avg loss:1.478510
#
# Start evaluation.
# Done. Time:1.2818585109998821
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.289793 [    0/ 3881]
# loss:1.437322 [ 3200/ 3881]
# Done. Time:15.813073267000163
# Training performance:
#  Avg loss:1.333894
#
# Start validation.
# Done. Time:0.48495223999998416
# Validation performance:
#  Avg loss:1.461354
#
# Start evaluation.
# Done. Time:1.7088654019999012
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.160249 [    0/ 3881]
# loss:1.295598 [ 3200/ 3881]
# Done. Time:15.626152306999757
# Training performance:
#  Avg loss:1.340208
#
# Start validation.
# Done. Time:0.760568879999937
# Validation performance:
#  Avg loss:1.518286
#
# Start evaluation.
# Done. Time:1.873241255999801
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.401022 [    0/ 3881]
# loss:1.366210 [ 3200/ 3881]
# Done. Time:15.474238713999966
# Training performance:
#  Avg loss:1.306371
#
# Start validation.
# Done. Time:0.5003325849997964
# Validation performance:
#  Avg loss:1.484303
#
# Start evaluation.
# Done. Time:1.5416863139998895
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.163292 [    0/ 3881]
# loss:0.830138 [ 3200/ 3881]
# Done. Time:15.262369656999908
# Training performance:
#  Avg loss:1.314655
#
# Start validation.
# Done. Time:0.49053598599994075
# Validation performance:
#  Avg loss:1.430236
#
# Start evaluation.
# Done. Time:1.2799198640000213
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.205608 [    0/ 3881]
# loss:1.143365 [ 3200/ 3881]
# Done. Time:15.098935949999941
# Training performance:
#  Avg loss:1.254485
#
# Start validation.
# Done. Time:0.5025041339999916
# Validation performance:
#  Avg loss:1.458324
#
# Start evaluation.
# Done. Time:1.2890906040001937
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.373089 [    0/ 3881]
# loss:1.106767 [ 3200/ 3881]
# Done. Time:15.495700212000429
# Training performance:
#  Avg loss:1.245424
#
# Start validation.
# Done. Time:0.7656926929998917
# Validation performance:
#  Avg loss:1.446083
#
# Start evaluation.
# Done. Time:1.638225514000169
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:1.172730 [    0/ 3881]
# loss:1.100696 [ 3200/ 3881]
# Done. Time:15.293387730000177
# Training performance:
#  Avg loss:1.243810
#
# Start validation.
# Done. Time:0.6000348620000295
# Validation performance:
#  Avg loss:1.439895
#
# Start evaluation.
# Done. Time:1.6612741049998476
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.826905 [    0/ 3881]
# loss:0.832969 [ 3200/ 3881]
# Done. Time:14.797098795000238
# Training performance:
#  Avg loss:1.202878
#
# Start validation.
# Done. Time:0.6024563980004132
# Validation performance:
#  Avg loss:1.454054
#
# Start evaluation.
# Done. Time:1.4124431519999234
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:1.409491 [    0/ 3881]
# loss:0.939471 [ 3200/ 3881]
# Done. Time:15.206639291000101
# Training performance:
#  Avg loss:1.197000
#
# Start validation.
# Done. Time:0.5273825640001633
# Validation performance:
#  Avg loss:1.488644
#
# Start evaluation.
# Done. Time:2.1914216670002133
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.653961 [    0/ 3881]
# loss:1.024972 [ 3200/ 3881]
# Done. Time:17.231860922000124
# Training performance:
#  Avg loss:1.186997
#
# Start validation.
# Done. Time:0.5879237519998242
# Validation performance:
#  Avg loss:1.408842
#
# Start evaluation.
# Done. Time:1.4364563019998968
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:1.401286 [    0/ 3881]
# loss:0.968341 [ 3200/ 3881]
# Done. Time:14.701283480000257
# Training performance:
#  Avg loss:1.129471
#
# Start validation.
# Done. Time:0.6014188009999089
# Validation performance:
#  Avg loss:1.383984
#
# Start evaluation.
# Done. Time:1.3216555839999273
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.996799 [    0/ 3881]
# loss:1.435328 [ 3200/ 3881]
# Done. Time:15.78058827599989
# Training performance:
#  Avg loss:1.127911
#
# Start validation.
# Done. Time:0.47959422999974777
# Validation performance:
#  Avg loss:1.394186
#
# Start evaluation.
# Done. Time:1.4543543989998398
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.214908 [    0/ 3881]
# loss:0.973529 [ 3200/ 3881]
# Done. Time:16.248927987000116
# Training performance:
#  Avg loss:1.092615
#
# Start validation.
# Done. Time:0.775584360999801
# Validation performance:
#  Avg loss:1.332878
#
# Start evaluation.
# Done. Time:1.9347579639998003
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.081140 [    0/ 3881]
# loss:1.318351 [ 3200/ 3881]
# Done. Time:15.298733895000169
# Training performance:
#  Avg loss:1.129943
#
# Start validation.
# Done. Time:0.48241167299966037
# Validation performance:
#  Avg loss:1.455716
#
# Start evaluation.
# Done. Time:1.3086123100001714
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.431673 [    0/ 3881]
# loss:0.960456 [ 3200/ 3881]
# Done. Time:16.10357870300004
# Training performance:
#  Avg loss:1.068318
#
# Start validation.
# Done. Time:0.557223821000207
# Validation performance:
#  Avg loss:1.374636
#
# Start evaluation.
# Done. Time:1.4243230560000484
# Test performance:
#  Accuracy:56.5%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.117507 [    0/ 3881]
# loss:1.333634 [ 3200/ 3881]
# Done. Time:16.758042468999975
# Training performance:
#  Avg loss:1.046841
#
# Start validation.
# Done. Time:0.7118249939999259
# Validation performance:
#  Avg loss:1.398197
#
# Start evaluation.
# Done. Time:1.8193187150000085
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.838761 [    0/ 3881]
# loss:0.839953 [ 3200/ 3881]
# Done. Time:15.900455145000251
# Training performance:
#  Avg loss:1.041415
#
# Start validation.
# Done. Time:0.5905378150000615
# Validation performance:
#  Avg loss:1.438880
#
# Start evaluation.
# Done. Time:1.4174458560000858
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:1.032183 [    0/ 3881]
# loss:1.209902 [ 3200/ 3881]
# Done. Time:15.42639783200002
# Training performance:
#  Avg loss:1.070955
#
# Start validation.
# Done. Time:0.6234332760000143
# Validation performance:
#  Avg loss:1.391616
#
# Start evaluation.
# Done. Time:1.732554603999688
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.690496 [    0/ 3881]
# loss:0.949269 [ 3200/ 3881]
# Done. Time:15.347798540999975
# Training performance:
#  Avg loss:1.049269
#
# Start validation.
# Done. Time:0.6963231820000146
# Validation performance:
#  Avg loss:1.460678
#
# Start evaluation.
# Done. Time:2.171282990000236
# Test performance:
#  Accuracy:52.5%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:1.367527 [    0/ 3881]
# loss:0.848282 [ 3200/ 3881]
# Done. Time:20.588931084999786
# Training performance:
#  Avg loss:1.052015
#
# Start validation.
# Done. Time:0.5777693250001903
# Validation performance:
#  Avg loss:1.362356
#
# Start evaluation.
# Done. Time:1.4011045330003071
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:1.165806 [    0/ 3881]
# loss:1.325546 [ 3200/ 3881]
# Done. Time:15.58839763900005
# Training performance:
#  Avg loss:1.019760
#
# Start validation.
# Done. Time:0.5012210780000714
# Validation performance:
#  Avg loss:1.411022
#
# Start evaluation.
# Done. Time:1.2846175399999993
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.714129 [    0/ 3881]
# loss:0.918283 [ 3200/ 3881]
# Done. Time:16.250168342000052
# Training performance:
#  Avg loss:1.009384
#
# Start validation.
# Done. Time:0.7442146500002309
# Validation performance:
#  Avg loss:1.341849
#
# Start evaluation.
# Done. Time:2.17669585800013
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:1.021431 [    0/ 3881]
# loss:1.168701 [ 3200/ 3881]
# Done. Time:15.580727639000088
# Training performance:
#  Avg loss:1.004169
#
# Start validation.
# Done. Time:0.4892949220002265
# Validation performance:
#  Avg loss:1.286644
#
# Start evaluation.
# Done. Time:1.315489929999785
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.021557 [    0/ 3881]
# loss:0.685543 [ 3200/ 3881]
# Done. Time:15.049750888999824
# Training performance:
#  Avg loss:1.061465
#
# Start validation.
# Done. Time:0.5691906579995702
# Validation performance:
#  Avg loss:1.299187
#
# Start evaluation.
# Done. Time:1.311508933999903
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.858492 [    0/ 3881]
# loss:1.399267 [ 3200/ 3881]
# Done. Time:15.66568181699995
# Training performance:
#  Avg loss:0.998684
#
# Start validation.
# Done. Time:0.5040697069998714
# Validation performance:
#  Avg loss:1.336526
#
# Start evaluation.
# Done. Time:1.2759325920001174
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:1.255754 [    0/ 3881]
# loss:1.334644 [ 3200/ 3881]
# Done. Time:17.137185457000214
# Training performance:
#  Avg loss:1.015010
#
# Start validation.
# Done. Time:0.6083486640000046
# Validation performance:
#  Avg loss:1.430212
#
# Start evaluation.
# Done. Time:1.2961763330004032
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.752562 [    0/ 3881]
# loss:0.501718 [ 3200/ 3881]
# Done. Time:15.617049611999846
# Training performance:
#  Avg loss:0.945310
#
# Start validation.
# Done. Time:0.6020557709998684
# Validation performance:
#  Avg loss:1.354660
#
# Start evaluation.
# Done. Time:1.5735742770002616
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.839449 [    0/ 3881]
# loss:0.995201 [ 3200/ 3881]
# Done. Time:15.597491881000224
# Training performance:
#  Avg loss:0.970157
#
# Start validation.
# Done. Time:0.5571137310002996
# Validation performance:
#  Avg loss:1.307833
#
# Start evaluation.
# Done. Time:1.3059863280000172
# Test performance:
#  Accuracy:63.0%
# Minimum validation loss:1.2866438712392534 at 45 epoch.
# Maximum accuracy:63.0 at 50 epoch.

# %% [markdown]
# #### Stacked and bidirectional RNN

# %%
rnn_num_layers = 2
rnn_bidir = True

model = RNNISLR(in_channels=in_channels,
                hidden_channels=hidden_channels,
                out_channels=out_channels,
                rnn_num_layers=rnn_num_layers,
                rnn_bidir=rnn_bidir)
print(model)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
# Out:
# RNNISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (rnn): RNNEncoder(
#     (rnn): RNN(64, 64, num_layers=2, batch_first=True, dropout=0.1, bidirectional=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_stacked_bidir = np.array(val_losses)
test_accs_stacked_bidir = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_stacked_bidir.min()} at {np.argmin(val_losses_stacked_bidir)+1} epoch.")
print(f"Maximum accuracy:{test_accs_stacked_bidir.max()} at {np.argmax(test_accs_stacked_bidir)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.413501 [    0/ 3881]
# loss:2.132262 [ 3200/ 3881]
# Done. Time:27.674318821999805
# Training performance:
#  Avg loss:2.224635
#
# Start validation.
# Done. Time:0.7261442009998973
# Validation performance:
#  Avg loss:2.169648
#
# Start evaluation.
# Done. Time:2.359703416999764
# Test performance:
#  Accuracy:20.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.185413 [    0/ 3881]
# loss:1.908527 [ 3200/ 3881]
# Done. Time:27.49541572199996
# Training performance:
#  Avg loss:1.964099
#
# Start validation.
# Done. Time:0.9807008770003449
# Validation performance:
#  Avg loss:2.108040
#
# Start evaluation.
# Done. Time:1.8747733949999201
# Test performance:
#  Accuracy:37.0%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.540177 [    0/ 3881]
# loss:1.739257 [ 3200/ 3881]
# Done. Time:26.980106436999904
# Training performance:
#  Avg loss:1.785978
#
# Start validation.
# Done. Time:0.6515858200000366
# Validation performance:
#  Avg loss:1.944243
#
# Start evaluation.
# Done. Time:1.9089937139997346
# Test performance:
#  Accuracy:42.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.697463 [    0/ 3881]
# loss:1.817796 [ 3200/ 3881]
# Done. Time:26.196720780000305
# Training performance:
#  Avg loss:1.689346
#
# Start validation.
# Done. Time:0.7275373929996931
# Validation performance:
#  Avg loss:1.851911
#
# Start evaluation.
# Done. Time:1.8768130479998035
# Test performance:
#  Accuracy:43.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.791793 [    0/ 3881]
# loss:1.708511 [ 3200/ 3881]
# Done. Time:26.762274312000045
# Training performance:
#  Avg loss:1.549119
#
# Start validation.
# Done. Time:0.6683374949998324
# Validation performance:
#  Avg loss:1.614027
#
# Start evaluation.
# Done. Time:1.6781735429999571
# Test performance:
#  Accuracy:44.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.604564 [    0/ 3881]
# loss:1.533886 [ 3200/ 3881]
# Done. Time:27.454582583000047
# Training performance:
#  Avg loss:1.441615
#
# Start validation.
# Done. Time:0.709114273999603
# Validation performance:
#  Avg loss:1.667055
#
# Start evaluation.
# Done. Time:1.8504262460000973
# Test performance:
#  Accuracy:45.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.650553 [    0/ 3881]
# loss:1.197631 [ 3200/ 3881]
# Done. Time:27.684970258999783
# Training performance:
#  Avg loss:1.372299
#
# Start validation.
# Done. Time:0.6535778649999884
# Validation performance:
#  Avg loss:1.703730
#
# Start evaluation.
# Done. Time:2.4540208479998
# Test performance:
#  Accuracy:45.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.203198 [    0/ 3881]
# loss:1.254770 [ 3200/ 3881]
# Done. Time:26.947651595000025
# Training performance:
#  Avg loss:1.304797
#
# Start validation.
# Done. Time:0.9758612880000328
# Validation performance:
#  Avg loss:1.551859
#
# Start evaluation.
# Done. Time:2.288083800000095
# Test performance:
#  Accuracy:44.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.163862 [    0/ 3881]
# loss:1.226103 [ 3200/ 3881]
# Done. Time:27.808382218000133
# Training performance:
#  Avg loss:1.243204
#
# Start validation.
# Done. Time:0.7618741060000502
# Validation performance:
#  Avg loss:1.583629
#
# Start evaluation.
# Done. Time:2.0209564420001698
# Test performance:
#  Accuracy:46.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:0.993622 [    0/ 3881]
# loss:1.143977 [ 3200/ 3881]
# Done. Time:26.887254469000254
# Training performance:
#  Avg loss:1.230792
#
# Start validation.
# Done. Time:0.7885475580001184
# Validation performance:
#  Avg loss:1.360206
#
# Start evaluation.
# Done. Time:2.1240328320000117
# Test performance:
#  Accuracy:51.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.145621 [    0/ 3881]
# loss:1.221197 [ 3200/ 3881]
# Done. Time:28.233047049000106
# Training performance:
#  Avg loss:1.351749
#
# Start validation.
# Done. Time:0.6819481719999203
# Validation performance:
#  Avg loss:1.463454
#
# Start evaluation.
# Done. Time:1.8954317039997477
# Test performance:
#  Accuracy:52.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.141560 [    0/ 3881]
# loss:0.910036 [ 3200/ 3881]
# Done. Time:27.696921998000107
# Training performance:
#  Avg loss:1.168765
#
# Start validation.
# Done. Time:0.8073779579999609
# Validation performance:
#  Avg loss:1.550508
#
# Start evaluation.
# Done. Time:2.3185686000001624
# Test performance:
#  Accuracy:51.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.107078 [    0/ 3881]
# loss:0.703229 [ 3200/ 3881]
# Done. Time:26.861442462000014
# Training performance:
#  Avg loss:1.137029
#
# Start validation.
# Done. Time:1.1280946490001043
# Validation performance:
#  Avg loss:1.359925
#
# Start evaluation.
# Done. Time:2.4215916779999134
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.232910 [    0/ 3881]
# loss:1.050653 [ 3200/ 3881]
# Done. Time:26.773897542000213
# Training performance:
#  Avg loss:1.075026
#
# Start validation.
# Done. Time:0.6728555559998313
# Validation performance:
#  Avg loss:1.303364
#
# Start evaluation.
# Done. Time:1.9601335950001157
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:0.814416 [    0/ 3881]
# loss:1.106554 [ 3200/ 3881]
# Done. Time:27.49439634800001
# Training performance:
#  Avg loss:1.007824
#
# Start validation.
# Done. Time:1.2065118569998958
# Validation performance:
#  Avg loss:1.259623
#
# Start evaluation.
# Done. Time:3.921523113999683
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:0.862630 [    0/ 3881]
# loss:1.393359 [ 3200/ 3881]
# Done. Time:31.962552119000065
# Training performance:
#  Avg loss:0.972460
#
# Start validation.
# Done. Time:1.1124000780000642
# Validation performance:
#  Avg loss:1.386258
#
# Start evaluation.
# Done. Time:2.104277209999964
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:0.820637 [    0/ 3881]
# loss:1.060050 [ 3200/ 3881]
# Done. Time:25.103293290999773
# Training performance:
#  Avg loss:1.002089
#
# Start validation.
# Done. Time:1.0080921959997795
# Validation performance:
#  Avg loss:1.483320
#
# Start evaluation.
# Done. Time:1.8566116489996602
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.396041 [    0/ 3881]
# loss:1.173735 [ 3200/ 3881]
# Done. Time:26.434280416000092
# Training performance:
#  Avg loss:1.109575
#
# Start validation.
# Done. Time:0.6639617210003053
# Validation performance:
#  Avg loss:1.450743
#
# Start evaluation.
# Done. Time:1.8654453550002472
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.144706 [    0/ 3881]
# loss:1.071525 [ 3200/ 3881]
# Done. Time:27.322613529000137
# Training performance:
#  Avg loss:1.176758
#
# Start validation.
# Done. Time:0.808878525000182
# Validation performance:
#  Avg loss:1.467914
#
# Start evaluation.
# Done. Time:1.7641748169999119
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.358640 [    0/ 3881]
# loss:0.721703 [ 3200/ 3881]
# Done. Time:27.918896966000375
# Training performance:
#  Avg loss:1.070423
#
# Start validation.
# Done. Time:0.7939191649998065
# Validation performance:
#  Avg loss:1.589047
#
# Start evaluation.
# Done. Time:2.12122015299974
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:0.966899 [    0/ 3881]
# loss:1.360219 [ 3200/ 3881]
# Done. Time:26.433890980999877
# Training performance:
#  Avg loss:1.387156
#
# Start validation.
# Done. Time:0.6653861700001471
# Validation performance:
#  Avg loss:1.569624
#
# Start evaluation.
# Done. Time:1.7906210579999424
# Test performance:
#  Accuracy:60.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.559451 [    0/ 3881]
# loss:1.147237 [ 3200/ 3881]
# Done. Time:27.534705223999936
# Training performance:
#  Avg loss:1.274662
#
# Start validation.
# Done. Time:0.8214412869997432
# Validation performance:
#  Avg loss:1.427904
#
# Start evaluation.
# Done. Time:2.4943204490000426
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.250904 [    0/ 3881]
# loss:1.270074 [ 3200/ 3881]
# Done. Time:27.32163347200003
# Training performance:
#  Avg loss:1.179774
#
# Start validation.
# Done. Time:1.084035379999932
# Validation performance:
#  Avg loss:1.330100
#
# Start evaluation.
# Done. Time:1.7989060909999353
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.136156 [    0/ 3881]
# loss:1.155227 [ 3200/ 3881]
# Done. Time:26.684788627000216
# Training performance:
#  Avg loss:1.120485
#
# Start validation.
# Done. Time:0.6908583149997867
# Validation performance:
#  Avg loss:1.341649
#
# Start evaluation.
# Done. Time:1.896286395000061
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.024057 [    0/ 3881]
# loss:1.373760 [ 3200/ 3881]
# Done. Time:26.08341568800006
# Training performance:
#  Avg loss:1.039342
#
# Start validation.
# Done. Time:0.8167232670002704
# Validation performance:
#  Avg loss:1.269158
#
# Start evaluation.
# Done. Time:1.797227847999693
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.348558 [    0/ 3881]
# loss:0.897782 [ 3200/ 3881]
# Done. Time:25.792471882999962
# Training performance:
#  Avg loss:1.005416
#
# Start validation.
# Done. Time:0.811587046999648
# Validation performance:
#  Avg loss:1.350638
#
# Start evaluation.
# Done. Time:1.9201559879998058
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.105923 [    0/ 3881]
# loss:1.301516 [ 3200/ 3881]
# Done. Time:26.83267983299993
# Training performance:
#  Avg loss:1.033287
#
# Start validation.
# Done. Time:0.671427266000137
# Validation performance:
#  Avg loss:1.273858
#
# Start evaluation.
# Done. Time:2.129254562999904
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.930197 [    0/ 3881]
# loss:0.811170 [ 3200/ 3881]
# Done. Time:27.050040660999912
# Training performance:
#  Avg loss:0.959707
#
# Start validation.
# Done. Time:0.6680580540000847
# Validation performance:
#  Avg loss:1.353135
#
# Start evaluation.
# Done. Time:1.7976012869999067
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.963776 [    0/ 3881]
# loss:0.989862 [ 3200/ 3881]
# Done. Time:27.349381555000036
# Training performance:
#  Avg loss:0.944114
#
# Start validation.
# Done. Time:0.8503465429998869
# Validation performance:
#  Avg loss:1.286551
#
# Start evaluation.
# Done. Time:2.0763172909996683
# Test performance:
#  Accuracy:67.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.501170 [    0/ 3881]
# loss:0.540893 [ 3200/ 3881]
# Done. Time:26.250903761000245
# Training performance:
#  Avg loss:0.907165
#
# Start validation.
# Done. Time:1.2020376559999022
# Validation performance:
#  Avg loss:1.019592
#
# Start evaluation.
# Done. Time:2.3015416430002915
# Test performance:
#  Accuracy:69.5%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:1.551170 [    0/ 3881]
# loss:1.127720 [ 3200/ 3881]
# Done. Time:26.0501281869997
# Training performance:
#  Avg loss:0.902609
#
# Start validation.
# Done. Time:0.9659026190001896
# Validation performance:
#  Avg loss:1.187041
#
# Start evaluation.
# Done. Time:2.0091513930001383
# Test performance:
#  Accuracy:69.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.083951 [    0/ 3881]
# loss:0.761213 [ 3200/ 3881]
# Done. Time:26.976487281999653
# Training performance:
#  Avg loss:0.896353
#
# Start validation.
# Done. Time:0.6694336400000793
# Validation performance:
#  Avg loss:1.153556
#
# Start evaluation.
# Done. Time:1.9710967619998883
# Test performance:
#  Accuracy:69.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:1.113633 [    0/ 3881]
# loss:0.719420 [ 3200/ 3881]
# Done. Time:27.99605390099987
# Training performance:
#  Avg loss:0.899935
#
# Start validation.
# Done. Time:0.8004794299999958
# Validation performance:
#  Avg loss:1.149689
#
# Start evaluation.
# Done. Time:1.7342585019996477
# Test performance:
#  Accuracy:74.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.901219 [    0/ 3881]
# loss:1.071373 [ 3200/ 3881]
# Done. Time:27.0481203129998
# Training performance:
#  Avg loss:0.843619
#
# Start validation.
# Done. Time:0.6899181970002246
# Validation performance:
#  Avg loss:1.089298
#
# Start evaluation.
# Done. Time:2.0153038470002684
# Test performance:
#  Accuracy:70.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.749719 [    0/ 3881]
# loss:0.796207 [ 3200/ 3881]
# Done. Time:26.368506671999967
# Training performance:
#  Avg loss:0.873046
#
# Start validation.
# Done. Time:0.6727371550000498
# Validation performance:
#  Avg loss:1.204987
#
# Start evaluation.
# Done. Time:1.8555102010000155
# Test performance:
#  Accuracy:71.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.621743 [    0/ 3881]
# loss:0.916042 [ 3200/ 3881]
# Done. Time:26.337810954999895
# Training performance:
#  Avg loss:0.819349
#
# Start validation.
# Done. Time:0.7001605259997632
# Validation performance:
#  Avg loss:1.195897
#
# Start evaluation.
# Done. Time:2.642445876000238
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.007811 [    0/ 3881]
# loss:1.128686 [ 3200/ 3881]
# Done. Time:24.912178010999924
# Training performance:
#  Avg loss:0.809088
#
# Start validation.
# Done. Time:0.8027213330001359
# Validation performance:
#  Avg loss:1.192720
#
# Start evaluation.
# Done. Time:2.8080184390000795
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.627120 [    0/ 3881]
# loss:0.852695 [ 3200/ 3881]
# Done. Time:27.39559176099965
# Training performance:
#  Avg loss:0.806641
#
# Start validation.
# Done. Time:1.139461126000242
# Validation performance:
#  Avg loss:1.121089
#
# Start evaluation.
# Done. Time:1.8770064589998583
# Test performance:
#  Accuracy:73.0%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.868635 [    0/ 3881]
# loss:0.811412 [ 3200/ 3881]
# Done. Time:26.50579113699996
# Training performance:
#  Avg loss:0.783215
#
# Start validation.
# Done. Time:0.6631284459999733
# Validation performance:
#  Avg loss:1.137571
#
# Start evaluation.
# Done. Time:1.8147406449998016
# Test performance:
#  Accuracy:70.5%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.621113 [    0/ 3881]
# loss:0.608189 [ 3200/ 3881]
# Done. Time:27.685227964000205
# Training performance:
#  Avg loss:0.741694
#
# Start validation.
# Done. Time:0.6879792740000994
# Validation performance:
#  Avg loss:1.042367
#
# Start evaluation.
# Done. Time:1.6663806300002761
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.438012 [    0/ 3881]
# loss:0.773069 [ 3200/ 3881]
# Done. Time:26.071106799000063
# Training performance:
#  Avg loss:0.746408
#
# Start validation.
# Done. Time:0.6691784029999326
# Validation performance:
#  Avg loss:1.175849
#
# Start evaluation.
# Done. Time:1.9015925710000374
# Test performance:
#  Accuracy:70.5%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.659412 [    0/ 3881]
# loss:1.025666 [ 3200/ 3881]
# Done. Time:26.85243801300021
# Training performance:
#  Avg loss:1.010273
#
# Start validation.
# Done. Time:0.8677658659998997
# Validation performance:
#  Avg loss:1.163544
#
# Start evaluation.
# Done. Time:1.8770702890001303
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.843438 [    0/ 3881]
# loss:1.012380 [ 3200/ 3881]
# Done. Time:26.585459986999922
# Training performance:
#  Avg loss:0.791067
#
# Start validation.
# Done. Time:0.8276187620003839
# Validation performance:
#  Avg loss:1.187801
#
# Start evaluation.
# Done. Time:2.0774788489998173
# Test performance:
#  Accuracy:72.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.687083 [    0/ 3881]
# loss:0.576291 [ 3200/ 3881]
# Done. Time:27.310174268000083
# Training performance:
#  Avg loss:0.742435
#
# Start validation.
# Done. Time:0.7820886289996452
# Validation performance:
#  Avg loss:1.315161
#
# Start evaluation.
# Done. Time:2.180750888000148
# Test performance:
#  Accuracy:73.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:1.280572 [    0/ 3881]
# loss:0.556748 [ 3200/ 3881]
# Done. Time:26.387791573999948
# Training performance:
#  Avg loss:0.720838
#
# Start validation.
# Done. Time:1.0094798439999977
# Validation performance:
#  Avg loss:1.032947
#
# Start evaluation.
# Done. Time:2.4708782869997776
# Test performance:
#  Accuracy:69.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.010768 [    0/ 3881]
# loss:0.867207 [ 3200/ 3881]
# Done. Time:27.339142480999726
# Training performance:
#  Avg loss:0.711991
#
# Start validation.
# Done. Time:0.6817226999996819
# Validation performance:
#  Avg loss:0.938984
#
# Start evaluation.
# Done. Time:1.8958192159998362
# Test performance:
#  Accuracy:75.5%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.722951 [    0/ 3881]
# loss:0.772840 [ 3200/ 3881]
# Done. Time:26.19126843899994
# Training performance:
#  Avg loss:0.703245
#
# Start validation.
# Done. Time:0.822154104999754
# Validation performance:
#  Avg loss:1.147138
#
# Start evaluation.
# Done. Time:2.155189326999789
# Test performance:
#  Accuracy:70.5%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.567122 [    0/ 3881]
# loss:0.662216 [ 3200/ 3881]
# Done. Time:26.186801398999705
# Training performance:
#  Avg loss:0.682987
#
# Start validation.
# Done. Time:0.7695518900000025
# Validation performance:
#  Avg loss:1.135611
#
# Start evaluation.
# Done. Time:2.200475396999991
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.539878 [    0/ 3881]
# loss:0.706468 [ 3200/ 3881]
# Done. Time:27.670059221999963
# Training performance:
#  Avg loss:0.668558
#
# Start validation.
# Done. Time:0.696873794000112
# Validation performance:
#  Avg loss:0.946649
#
# Start evaluation.
# Done. Time:2.005827692999901
# Test performance:
#  Accuracy:74.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.731647 [    0/ 3881]
# loss:0.645320 [ 3200/ 3881]
# Done. Time:27.062203918999785
# Training performance:
#  Avg loss:0.642219
#
# Start validation.
# Done. Time:0.7178187309996247
# Validation performance:
#  Avg loss:1.107851
#
# Start evaluation.
# Done. Time:1.7035483059999024
# Test performance:
#  Accuracy:71.0%
# Minimum validation loss:0.9389841726848057 at 46 epoch.
# Maximum accuracy:75.5 at 46 epoch.

# %% [markdown]
# #### Plot result

# %%
import matplotlib.pyplot as plt

plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(val_losses_default)+1)
plt.plot(xs, val_losses_default, label="Default", marker=".")
plt.plot(xs, val_losses_stacked, label="+ Stacked", marker=".")
plt.plot(xs, val_losses_bidir, label="+ Bidir", marker=".")
plt.plot(xs, val_losses_stacked_bidir, label="+ Stacked + Bidir", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Validation loss")
plt.ylim([0.0, 2.5])
plt.legend()
plt.show()

# %%
plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(test_accs_default)+1)
plt.plot(xs, test_accs_default, label="Default", marker=".")
plt.plot(xs, test_accs_stacked, label="+ Stacked", marker=".")
plt.plot(xs, test_accs_bidir, label="+ Bidir", marker=".")
plt.plot(xs, test_accs_stacked_bidir, label="+ Stacked + Bidir", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.ylim([0.0, 100.0])
plt.legend()
plt.show()

# %%
print(f"Default: {test_accs_default.max()}")
print(f"+ Stacked: {test_accs_stacked.max()}")
print(f"+ Bidir: {test_accs_bidir.max()}")
print(f"+ Stacked + Bidir: {test_accs_stacked_bidir.max()}")
# Out:
# Default: 56.00000000000001
# + Stacked: 62.0
# + Bidir: 63.0
# + Stacked + Bidir: 75.5
