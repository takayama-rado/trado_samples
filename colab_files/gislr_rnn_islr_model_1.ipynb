# %% [markdown]
# <a href="https://colab.research.google.com/github/takayama-rado/trado_samples/blob/main/colab_files/gislr_rnn_islr_model_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Download dataset and modules

# %%
# I do not why, but only older virsion is works.
# https://github.com/wkentaro/gdown/issues/43#issuecomment-1426653602
# !pip install gdown==4.6.0
# Out:
# Requirement already satisfied: gdown==4.6.0 in /usr/local/lib/python3.10/dist-packages (4.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown==4.6.0) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown==4.6.0) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown==4.6.0) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown==4.6.0) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown==4.6.0) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown==4.6.0) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.6.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.6.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.6.0) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown==4.6.0) (1.7.1)

# %%
import gdown

url = "https://drive.google.com/uc?id=1LJDGEwr4zqpBftjqO9SiSOLgUcNhMiSe"
output = "gislr_top10.zip"
gdown.download(url, output, quiet=False, fuzzy=True)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1LJDGEwr4zqpBftjqO9SiSOLgUcNhMiSe
# To: /content/gislr_top10.zip
# 100%|██████████| 880M/880M [00:08<00:00, 103MB/s]
# 'gislr_top10.zip'

# %%
# !unzip -o gislr_top10.zip
# Out:
# Archive:  gislr_top10.zip
#   inflating: dataset_top10/16069.hdf5
#   inflating: dataset_top10/18796.hdf5
#   inflating: dataset_top10/2044.hdf5
#   inflating: dataset_top10/22343.hdf5
#   inflating: dataset_top10/25571.hdf5
#   inflating: dataset_top10/26734.hdf5
#   inflating: dataset_top10/27610.hdf5
#   inflating: dataset_top10/28656.hdf5
#   inflating: dataset_top10/29302.hdf5
#   inflating: dataset_top10/30680.hdf5
#   inflating: dataset_top10/32319.hdf5
#   inflating: dataset_top10/34503.hdf5
#   inflating: dataset_top10/36257.hdf5
#   inflating: dataset_top10/37055.hdf5
#   inflating: dataset_top10/37779.hdf5
#   inflating: dataset_top10/4718.hdf5
#   inflating: dataset_top10/49445.hdf5
#   inflating: dataset_top10/53618.hdf5
#   inflating: dataset_top10/55372.hdf5
#   inflating: dataset_top10/61333.hdf5
#   inflating: dataset_top10/62590.hdf5
#   inflating: dataset_top10/LICENSE.txt
#   inflating: dataset_top10/sign_to_prediction_index_map.json

# %%
# !ls dataset_top10
# Out:
# 16069.hdf5  25571.hdf5	29302.hdf5  36257.hdf5	49445.hdf5  62590.hdf5
# 18796.hdf5  26734.hdf5	30680.hdf5  37055.hdf5	53618.hdf5  LICENSE.txt
# 2044.hdf5   27610.hdf5	32319.hdf5  37779.hdf5	55372.hdf5  sign_to_prediction_index_map.json
# 22343.hdf5  28656.hdf5	34503.hdf5  4718.hdf5	61333.hdf5

# %%
# !cat dataset_top10/sign_to_prediction_index_map.json
# Out:
# {
#     "listen": 0,
#     "look": 1,
#     "shhh": 2,
#     "donkey": 3,
#     "mouse": 4,
#     "duck": 5,
#     "uncle": 6,
#     "hear": 7,
#     "pretend": 8,
#     "cow": 9
# }

# %%
# !cat dataset_top10/LICENSE.txt
# Out:
# The dataset provided by Natsuki Takayama (Takayama Research and Development Office) is licensed under CC-BY 4.0.
# Author: Copyright 2024 Natsuki Takayama
# Title: GISLR Top 10 dataset
# Original licenser: Deaf Professional Arts Network and the Georgia Institute of Technology
# Modification
# - Extract 10 most frequent words.
# - Packaged into HDF5 format.

# %%
import h5py
with h5py.File("dataset_top10/16069.hdf5", "r") as fread:
    keys = list(fread.keys())
    print(keys)
    group = fread[keys[0]]
    print(group.keys())
    feature = group["feature"][:]
    token = group["token"][:]
    print(feature.shape)
    print(token)
# Out:
# ['1109479272', '11121526', '1120349077', '1125456612', '1159046211', '1169128497', '1186032553', '1223803476', '1259708636', '1281972067', '129232566', '1334702305', '1340979012', '1352964057', '1370052047', '1383455381', '1431148933', '1435203624', '1437919781', '1458770030', '1462881097', '1469867050', '1474050058', '147607644', '1513539919', '1520635928', '1524297234', '153676122', '1537751003', '1542212461', '1551759770', '158232956', '1585855916', '1632709119', '1638742455', '1696757219', '177479476', '1779635114', '1791684792', '1801566440', '1831167282', '1867385690', '1880570146', '1901587887', '1910121429', '1919659282', '192873038', '1935012113', '1949620203', '195098847', '1983552660', '1989475963', '1998715062', '2007709802', '2036010239', '2036360025', '2046296211', '2082116372', '2098813002', '2109640010', '2121879330', '2141852087', '2148832702', '2152013823', '2166805079', '2176613834', '2184232774', '2213965523', '2249630763', '2256677805', '2263287955', '2263683020', '2264826605', '2270117351', '2281372282', '2285328250', '2322449232', '2326092712', '2336131857', '2346410171', '2405684784', '2467219838', '2473091535', '2488751095', '2515673021', '252176572', '2555449229', '2601816518', '2624310025', '2672738462', '2679264929', '2708514724', '2708544445', '2721276879', '2723773273', '2728839865', '2740241949', '2758304792', '2772051790', '2779816680', '2804441762', '2811346655', '2811646800', '2820103955', '2839681895', '2900998385', '2976200180', '2994456336', '3057994128', '3095010437', '3104317075', '3109672704', '3137179145', '3153285641', '3173321541', '3181666887', '3201889607', '3208820205', '3248401349', '3280527321', '3283246198', '3300057240', '3355963469', '3378306304', '3383637897', '3395075403', '3399503065', '3417877266', '3433092803', '347484677', '348956807', '3490841593', '3509324997', '3527069516', '3537611572', '3543711249', '3550826234', '3574700791', '3577812263', '3608551465', '3609537739', '3622960580', '3666781780', '3701422761', '3721927307', '3751410902', '3756613238', '3769544385', '3783554953', '3794712078', '380369091', '3813230821', '3817572483', '3843929707', '3869664504', '3892179393', '3923913515', '3981562204', '4078929101', '4101587978', '4150900444', '4191136837', '4200829752', '4209136328', '420958416', '422113773', '42222766', '4233346443', '4233985575', '4236057556', '4252161228', '425542996', '4276854486', '4294775577', '431609031', '439844759', '446236576', '470582324', '472128010', '492897929', '537402693', '5501547', '561170018', '593416697', '631898947', '649410423', '654529993', '678960043', '699907539', '707716966', '713615518', '778875120', '792981518', '796465415', '798649922', '856068671', '923153024', '957739544', '970593849', '976754415']
# <KeysViewHDF5 ['feature', 'token']>
# (3, 23, 543)
# [1]

# %%
# !wget https://github.com/takayama-rado/trado_samples/archive/master.zip
# Out:
# --2024-02-08 15:23:17--  https://github.com/takayama-rado/trado_samples/archive/master.zip
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/takayama-rado/trado_samples/zip/main [following]
# --2024-02-08 15:23:18--  https://codeload.github.com/takayama-rado/trado_samples/zip/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.121.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.121.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [              <=>   ]  73.53M  15.3MB/s    in 5.5s
#
# 2024-02-08 15:23:23 (13.4 MB/s) - ‘master.zip’ saved [77099490]

# %%
# !unzip -o master.zip -d master
# Out:
# Archive:  master.zip
# a0fb8907f39a7b517caf623964b1ac4ddb714d2a
#    creating: master/trado_samples-main/
#   inflating: master/trado_samples-main/.gitignore
#   inflating: master/trado_samples-main/LICENSE
#   inflating: master/trado_samples-main/README.md
#    creating: master/trado_samples-main/colab_files/
#  extracting: master/trado_samples-main/colab_files/.gitkeep
#   inflating: master/trado_samples-main/colab_files/exp_affine_np_einsum.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_jax_static.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_mpholistic_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_mpothers_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_jax.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_numpy.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_tensorflow.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_torch.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_jax.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_numpy_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_numpy_1.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_tensorflow.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_torch.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_access_dataset.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_normalize_landmarks.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_rnn_islr_model.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_select_landmarks.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_simple_islr_model.ipynb
#    creating: master/trado_samples-main/src/
#    creating: master/trado_samples-main/src/modules_gislr/
#  extracting: master/trado_samples-main/src/modules_gislr/__init__.py
#   inflating: master/trado_samples-main/src/modules_gislr/dataset.py
#   inflating: master/trado_samples-main/src/modules_gislr/defines.py
#   inflating: master/trado_samples-main/src/modules_gislr/draw_functions.py
#   inflating: master/trado_samples-main/src/modules_gislr/layers.py
#   inflating: master/trado_samples-main/src/modules_gislr/train_functions.py
#   inflating: master/trado_samples-main/src/modules_gislr/transforms.py
#    creating: master/trado_samples-main/test_data/
#   inflating: master/trado_samples-main/test_data/finger_far0.mp4
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static.npy
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static_affine.npy
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static_interp.npy
#   inflating: master/trado_samples-main/test_data/finger_middle0.mp4
#   inflating: master/trado_samples-main/test_data/finger_near0.mp4
#   inflating: master/trado_samples-main/test_data/hand_only.mp4

# %%
# !mv master/trado_samples-main/src/modules_gislr .
# Out:
# mv: cannot move 'master/trado_samples-main/src/modules_gislr' to './modules_gislr': Directory not empty

# %%
# !rm -rf master master.zip gislr_top10.zip

# %%
# !ls
# Out:
# dataset_top10  modules_gislr  sample_data

# %% [markdown]
# # 2. Load library

# %%
import json
import math
import sys
import time
from functools import partial
from pathlib import Path
from typing import (
    Any,
    Dict
)

# Third party's modules
import numpy as np

import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import (
    DataLoader)

from torchvision.transforms import Compose

# Local modules
sys.path.append("modules_gislr")
from modules_gislr.dataset import (
    HDF5Dataset,
    merge_padded_batch)
from modules_gislr.defines import (
    get_fullbody_landmarks
)
from modules_gislr.transforms import (
    PartsBasedNormalization,
    ReplaceNan,
    SelectLandmarksAndFeature,
    ToTensor
)

# %% [markdown]
# # 3. Implement RNN ISLR model

# %% [markdown]
# ## RNN encoder

# %%
class RNNEncoder(nn.Module):
    def __init__(self,
                 in_channels,
                 out_channels,
                 num_layers,
                 activation,
                 bidir,
                 dropout,
                 apply_mask):
        super().__init__()

        # If num_layers = 1, we remove dropout option of RNN layers to avoid warning.
        rnn_dropout = 0.0 if num_layers == 1 else dropout

        self.rnn = nn.RNN(input_size=in_channels,
                          hidden_size=out_channels,
                          num_layers=num_layers,
                          nonlinearity=activation,
                          batch_first=True,
                          dropout=rnn_dropout,
                          bidirectional=bidir)
        # Dropout is added into intermediate RNN layers expect the last layer.
        # So, we add Dropout layer for the last layer explicitly.
        if dropout > 0:
            self.dropout = nn.Dropout(dropout)
        else:
            self.dropout = nn.Identity()

        self.apply_mask = apply_mask

    def forward(self, feature, feature_pad_mask=None):
        if feature_pad_mask is not None and self.apply_mask:
            tlength = feature_pad_mask.sum(axis=-1).detach().cpu()
            feature = nn.utils.rnn.pack_padded_sequence(
                feature, tlength, batch_first=True, enforce_sorted=False)

        hidden_seqs, last_hstate = self.rnn(feature)
        # Unpack hidden sequence.
        if isinstance(hidden_seqs, nn.utils.rnn.PackedSequence):
            hidden_seqs = nn.utils.rnn.unpack_sequence(hidden_seqs)
            # Back list to padded batch.
            hidden_seqs = nn.utils.rnn.pad_sequence(
                hidden_seqs, batch_first=True, padding_value=0.0)
        hidden_seqs = self.dropout(hidden_seqs)

        return hidden_seqs, last_hstate, last_cstate

# %% [markdown]
# ## Update recognition head to apply masked global average pooling

# %%
class GPoolRecognitionHead(nn.Module):
    def __init__(self,
                 in_channels,
                 out_channels):
        super().__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels

        self.head = nn.Linear(in_channels, out_channels)
        self._init_weight()

    def _init_weight(self):
        nn.init.normal_(self.head.weight,
                        mean=0.,
                        std=math.sqrt(1. / self.out_channels))

    def forward(self, feature, feature_pad_mask=None):
        # Averaging over temporal axis.
        # `[N, C, T] -> [N, C, 1] -> [N, C]`
        if feature_pad_mask is not None:
            tlength = feature_pad_mask.sum(dim=-1)
            feature = feature * feature_pad_mask.unsqueeze(1)
            feature = feature.sum(dim=-1) / tlength.unsqueeze(-1)
        else:
            feature = F.avg_pool1d(feature, kernel_size=feature.shape[-1])
        feature = feature.reshape(feature.shape[0], -1)

        # Predict.
        feature = self.head(feature)
        return feature

# %% [markdown]
# ## ISLR model

# %%
class RNNISLR(nn.Module):
    def __init__(self,
                 in_channels,
                 hidden_channels,
                 out_channels,
                 rnn_num_layers=1,
                 rnn_activation="tanh",
                 rnn_bidir=False,
                 rnn_dropout=0.1,
                 masking_type="both"):
        super().__init__()
        assert masking_type in ["none", "rnn", "head", "both"]

        self.linear = nn.Linear(in_channels, hidden_channels)
        self.activation = nn.ReLU()

        apply_mask = True if masking_type in ["rnn", "both"] else False
        self.rnn = RNNEncoder(
            in_channels=hidden_channels,
            out_channels=hidden_channels,
            num_layers=rnn_num_layers,
            activation=rnn_activation,
            bidir=rnn_bidir,
            dropout=rnn_dropout,
            apply_mask=apply_mask)

        if rnn_bidir:
            self.head = GPoolRecognitionHead(hidden_channels * 2, out_channels)
        else:
            self.head = GPoolRecognitionHead(hidden_channels, out_channels)

        self.masking_type = masking_type

    def forward(self, feature, feature_pad_mask=None):
        # Feature extraction.
        # `[N, C, T, J] -> [N, T, C, J] -> [N, T, C*J] -> [N, T, C']`
        N, C, T, J = feature.shape
        feature = feature.permute([0, 2, 1, 3])
        feature = feature.reshape(N, T, -1)

        feature = self.linear(feature)
        feature = self.activation(feature)

        hidden_seqs, last_hstate = self.rnn(feature, feature_pad_mask)[:2]

        # `[N, T, C'] -> [N, C', T]`
        feature = hidden_seqs.permute(0, 2, 1)

        if feature_pad_mask is not None and self.masking_type in ["head", "both"]:
            logit = self.head(feature, feature_pad_mask)
        else:
            logit = self.head(feature)
        return logit

# %% [markdown]
# ## Sanity check

# %%
# Access check.
dataset_dir = Path("dataset_top10")
files = list(dataset_dir.iterdir())
dictionary = [fin for fin in files if ".json" in fin.name][0]
hdf5_files = [fin for fin in files if ".hdf5" in fin.name]

print(dictionary)
print(hdf5_files)
# Out:
# dataset_top10/sign_to_prediction_index_map.json
# [PosixPath('dataset_top10/2044.hdf5'), PosixPath('dataset_top10/32319.hdf5'), PosixPath('dataset_top10/18796.hdf5'), PosixPath('dataset_top10/36257.hdf5'), PosixPath('dataset_top10/62590.hdf5'), PosixPath('dataset_top10/16069.hdf5'), PosixPath('dataset_top10/29302.hdf5'), PosixPath('dataset_top10/34503.hdf5'), PosixPath('dataset_top10/37055.hdf5'), PosixPath('dataset_top10/37779.hdf5'), PosixPath('dataset_top10/27610.hdf5'), PosixPath('dataset_top10/53618.hdf5'), PosixPath('dataset_top10/49445.hdf5'), PosixPath('dataset_top10/30680.hdf5'), PosixPath('dataset_top10/22343.hdf5'), PosixPath('dataset_top10/55372.hdf5'), PosixPath('dataset_top10/26734.hdf5'), PosixPath('dataset_top10/28656.hdf5'), PosixPath('dataset_top10/61333.hdf5'), PosixPath('dataset_top10/4718.hdf5'), PosixPath('dataset_top10/25571.hdf5')]

# %%
# Load dictionary.
with open(dictionary, "r") as fread:
    key2token = json.load(fread)

VOCAB = len(key2token)

# %%
_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
trans_select_feature = SelectLandmarksAndFeature(landmarks=use_landmarks, features=use_features)
trans_repnan = ReplaceNan()
trans_norm = PartsBasedNormalization(align_mode="framewise", scale_mode="unique")

pre_transforms = Compose([trans_select_feature,
                          trans_repnan,
                          trans_norm])
transforms = Compose([ToTensor()])

# %%
batch_size = 2
feature_shape = (len(use_features), -1, len(use_landmarks))
token_shape = (1,)
merge_fn = partial(merge_padded_batch,
                   feature_shape=feature_shape,
                   token_shape=token_shape,
                   feature_padding_val=0.0,
                   token_padding_val=0)

dataset = HDF5Dataset(hdf5_files, pre_transforms=pre_transforms, transforms=transforms)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=merge_fn)
try:
    data = next(iter(dataloader))
    feature_origin = data["feature"]

    print(feature_origin.shape)
except Exception as inst:
    print(inst)
# Out:
# torch.Size([2, 2, 24, 130])

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
hidden_channels = 64
out_channels = VOCAB
rnn_num_layers=1
rnn_bidir=False
rnn_dropout=0.1
masking_type="none"

model = RNNISLR(in_channels=in_channels,
                hidden_channels=hidden_channels,
                out_channels=out_channels,
                rnn_num_layers=rnn_num_layers,
                rnn_bidir=rnn_bidir,
                masking_type=masking_type)
print(model)

# Sanity check.
logit = model(feature_origin)
print(logit.shape)
# Out:
# RNNISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (rnn): RNNEncoder(
#     (rnn): RNN(64, 64, batch_first=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %% [markdown]
# # 4. Train and evaluation

# %% [markdown]
# ## 4.1 Update training functions

# %%
from inspect import signature

def train_loop(dataloader, model, loss_fn, optimizer, device, use_mask=True):
    num_batches = len(dataloader)
    train_loss = 0
    size = len(dataloader.dataset)

    # Inspect model signature.
    sig = signature(model.forward)
    use_mask = True if "feature_pad_mask" in sig.parameters and use_mask is True else False

    # Switch to training mode.
    model.train()
    # Main loop.
    print("Start training.")
    start = time.perf_counter()
    for batch_idx, batch_sample in enumerate(dataloader):
        feature = batch_sample["feature"]
        token = batch_sample["token"]
        feature = feature.to(device)
        token = token.to(device)

        # Predict.
        if use_mask:
            feature_pad_mask = batch_sample["feature_pad_mask"]
            feature_pad_mask = feature_pad_mask.to(device)
            pred = model(feature, feature_pad_mask=feature_pad_mask)
        else:
            pred = model(feature)
        # Compute loss.
        loss = loss_fn(pred, token.squeeze(-1))

        # Back propagation.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        # Print current loss per 100 steps.
        if batch_idx % 100 == 0:
            loss = loss.item()
            steps = batch_idx * len(feature)
            print(f"loss:{loss:>7f} [{steps:>5d}/{size:>5d}]")
    print(f"Done. Time:{time.perf_counter()-start}")
    # Average loss.
    train_loss /= num_batches
    print("Training performance: \n",
          f"Avg loss:{train_loss:>8f}\n")
    return train_loss

# %%
def val_loop(dataloader, model, loss_fn, device, use_mask=True):
    num_batches = len(dataloader)
    val_loss = 0

    # Inspect model signature.
    sig = signature(model.forward)
    use_mask = True if "feature_pad_mask" in sig.parameters and use_mask is True else False

    # Switch to evaluation mode.
    model.eval()
    # Main loop.
    print("Start validation.")
    start = time.perf_counter()
    with torch.no_grad():
        for batch_sample in dataloader:
            feature = batch_sample["feature"]
            token = batch_sample["token"]
            feature = feature.to(device)
            token = token.to(device)

            # Predict.
            if use_mask:
                feature_pad_mask = batch_sample["feature_pad_mask"]
                feature_pad_mask = feature_pad_mask.to(device)
                pred = model(feature, feature_pad_mask=feature_pad_mask)
            else:
                pred = model(feature)
            val_loss += loss_fn(pred, token.squeeze(-1)).item()
    print(f"Done. Time:{time.perf_counter()-start}")

    # Average loss.
    val_loss /= num_batches
    print("Validation performance: \n",
          f"Avg loss:{val_loss:>8f}\n")
    return val_loss

# %%
def test_loop(dataloader, model, device, use_mask=False):
    size = len(dataloader.dataset)
    correct = 0

    # Inspect model signature.
    sig = signature(model.forward)
    use_mask = True if "feature_pad_mask" in sig.parameters and use_mask is True else False

    # Switch to evaluation mode.
    model.eval()
    # Main loop.
    print("Start evaluation.")
    start = time.perf_counter()
    with torch.no_grad():
        for batch_sample in dataloader:
            feature = batch_sample["feature"]
            token = batch_sample["token"]
            feature = feature.to(device)
            token = token.to(device)

            # Predict.
            if use_mask:
                feature_pad_mask = batch_sample["feature_pad_mask"]
                feature_pad_mask = feature_pad_mask.to(device)
                pred = model(feature, feature_pad_mask=feature_pad_mask)
            else:
                pred = model(feature)

            pred_ids = pred.argmax(dim=1).unsqueeze(-1)
            count = (pred_ids == token).sum().detach().cpu().numpy()
            correct += int(count)
    print(f"Done. Time:{time.perf_counter()-start}")

    acc = correct / size * 100
    print("Test performance: \n",
          f"Accuracy:{acc:>0.1f}%")
    return acc

# %%
# Set common parameters.
batch_size = 32
load_into_ram = True
test_pid = 16069
num_workers = 1
lr = 3e-4

epochs = 50
eval_every_n_epochs = 1
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} for computation.")

train_hdf5files = [fin for fin in hdf5_files if str(test_pid) not in fin.name]
val_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]
test_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]

_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
# Out:
# Using cpu for computation.

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms,
    transforms=transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms,
    transforms=transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms,
    transforms=transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)

# %% [markdown]
# ## 4.2 Compare RNN processing

# %% [markdown]
# ### Default settings

# %%
rnn_num_layers = 1
rnn_bidir = False
masking_type = "none"

model = RNNISLR(in_channels=in_channels,
                hidden_channels=hidden_channels,
                out_channels=out_channels,
                rnn_num_layers=rnn_num_layers,
                rnn_bidir=rnn_bidir,
                masking_type=masking_type)
print(model)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
# Out:
# RNNISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (rnn): RNNEncoder(
#     (rnn): RNN(64, 64, batch_first=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_default = np.array(val_losses)
test_accs_default = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_default.min()} at {np.argmin(val_losses_default)+1} epoch.")
print(f"Maximum accuracy:{test_accs_default.max()} at {np.argmax(test_accs_default)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.438656 [    0/ 3881]
# loss:2.169352 [ 3200/ 3881]
# Done. Time:8.977812445999916
# Training performance:
#  Avg loss:2.254690
#
# Start validation.
# Done. Time:0.3972259900001518
# Validation performance:
#  Avg loss:2.100680
#
# Start evaluation.
# Done. Time:1.1756815200005803
# Test performance:
#  Accuracy:21.0%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:1.975049 [    0/ 3881]
# loss:2.027038 [ 3200/ 3881]
# Done. Time:9.382897471999968
# Training performance:
#  Avg loss:2.019722
#
# Start validation.
# Done. Time:0.38691818799998146
# Validation performance:
#  Avg loss:2.054066
#
# Start evaluation.
# Done. Time:1.170146728999498
# Test performance:
#  Accuracy:30.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.981767 [    0/ 3881]
# loss:2.082178 [ 3200/ 3881]
# Done. Time:9.510382688999925
# Training performance:
#  Avg loss:2.147291
#
# Start validation.
# Done. Time:0.39523858499978815
# Validation performance:
#  Avg loss:2.153093
#
# Start evaluation.
# Done. Time:1.1153798989998904
# Test performance:
#  Accuracy:31.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:2.116619 [    0/ 3881]
# loss:1.988158 [ 3200/ 3881]
# Done. Time:9.409055273999911
# Training performance:
#  Avg loss:1.981169
#
# Start validation.
# Done. Time:0.3914270340001167
# Validation performance:
#  Avg loss:2.296568
#
# Start evaluation.
# Done. Time:1.1392985020002016
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.991855 [    0/ 3881]
# loss:1.982237 [ 3200/ 3881]
# Done. Time:9.509930989000168
# Training performance:
#  Avg loss:1.920530
#
# Start validation.
# Done. Time:0.3858165650008232
# Validation performance:
#  Avg loss:2.037199
#
# Start evaluation.
# Done. Time:1.141009232000215
# Test performance:
#  Accuracy:25.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.684275 [    0/ 3881]
# loss:1.890618 [ 3200/ 3881]
# Done. Time:9.208597358000588
# Training performance:
#  Avg loss:1.885162
#
# Start validation.
# Done. Time:0.5702389479993144
# Validation performance:
#  Avg loss:1.978006
#
# Start evaluation.
# Done. Time:1.1481558800005587
# Test performance:
#  Accuracy:40.5%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:2.015458 [    0/ 3881]
# loss:1.741695 [ 3200/ 3881]
# Done. Time:8.85364099599974
# Training performance:
#  Avg loss:2.089107
#
# Start validation.
# Done. Time:1.4796339690001332
# Validation performance:
#  Avg loss:2.014869
#
# Start evaluation.
# Done. Time:2.0186996889997317
# Test performance:
#  Accuracy:39.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.823084 [    0/ 3881]
# loss:1.896565 [ 3200/ 3881]
# Done. Time:8.544787820999773
# Training performance:
#  Avg loss:1.864153
#
# Start validation.
# Done. Time:0.3947927110002638
# Validation performance:
#  Avg loss:2.672732
#
# Start evaluation.
# Done. Time:1.6096463559997574
# Test performance:
#  Accuracy:20.5%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:2.837380 [    0/ 3881]
# loss:1.474250 [ 3200/ 3881]
# Done. Time:8.679989991999719
# Training performance:
#  Avg loss:1.874366
#
# Start validation.
# Done. Time:0.40326566099975025
# Validation performance:
#  Avg loss:2.006127
#
# Start evaluation.
# Done. Time:1.172247329000129
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:2.073272 [    0/ 3881]
# loss:1.539921 [ 3200/ 3881]
# Done. Time:9.278252876999431
# Training performance:
#  Avg loss:1.759918
#
# Start validation.
# Done. Time:0.3832319789999019
# Validation performance:
#  Avg loss:1.766196
#
# Start evaluation.
# Done. Time:1.168471629999658
# Test performance:
#  Accuracy:38.5%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.443167 [    0/ 3881]
# loss:2.343973 [ 3200/ 3881]
# Done. Time:9.22827735699957
# Training performance:
#  Avg loss:1.939202
#
# Start validation.
# Done. Time:0.38611543200022425
# Validation performance:
#  Avg loss:2.298647
#
# Start evaluation.
# Done. Time:1.1608278630001223
# Test performance:
#  Accuracy:17.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:2.232071 [    0/ 3881]
# loss:2.222530 [ 3200/ 3881]
# Done. Time:9.247453126999972
# Training performance:
#  Avg loss:2.096461
#
# Start validation.
# Done. Time:0.4423324159997719
# Validation performance:
#  Avg loss:2.133565
#
# Start evaluation.
# Done. Time:1.1822061860002577
# Test performance:
#  Accuracy:29.5%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:2.241208 [    0/ 3881]
# loss:2.139581 [ 3200/ 3881]
# Done. Time:9.513025410999944
# Training performance:
#  Avg loss:2.023118
#
# Start validation.
# Done. Time:0.4073455140005535
# Validation performance:
#  Avg loss:2.071717
#
# Start evaluation.
# Done. Time:1.1590878670003804
# Test performance:
#  Accuracy:39.0%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:2.120907 [    0/ 3881]
# loss:1.912488 [ 3200/ 3881]
# Done. Time:8.614819448000162
# Training performance:
#  Avg loss:1.973251
#
# Start validation.
# Done. Time:0.6039447459997973
# Validation performance:
#  Avg loss:2.025763
#
# Start evaluation.
# Done. Time:1.5733571259997916
# Test performance:
#  Accuracy:43.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:2.065479 [    0/ 3881]
# loss:2.122813 [ 3200/ 3881]
# Done. Time:8.636196191999261
# Training performance:
#  Avg loss:1.939455
#
# Start validation.
# Done. Time:0.40661540499968396
# Validation performance:
#  Avg loss:1.993690
#
# Start evaluation.
# Done. Time:1.4688616849998652
# Test performance:
#  Accuracy:39.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.725602 [    0/ 3881]
# loss:1.822896 [ 3200/ 3881]
# Done. Time:9.135985978999997
# Training performance:
#  Avg loss:1.890275
#
# Start validation.
# Done. Time:0.3926362590000281
# Validation performance:
#  Avg loss:1.964474
#
# Start evaluation.
# Done. Time:1.1399202669999795
# Test performance:
#  Accuracy:38.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.862228 [    0/ 3881]
# loss:1.841410 [ 3200/ 3881]
# Done. Time:9.391766734999692
# Training performance:
#  Avg loss:1.838552
#
# Start validation.
# Done. Time:0.3863278649996573
# Validation performance:
#  Avg loss:1.896985
#
# Start evaluation.
# Done. Time:1.1241256749999593
# Test performance:
#  Accuracy:43.0%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.970609 [    0/ 3881]
# loss:2.153536 [ 3200/ 3881]
# Done. Time:9.451315184999658
# Training performance:
#  Avg loss:1.820911
#
# Start validation.
# Done. Time:0.38647162200049934
# Validation performance:
#  Avg loss:2.032458
#
# Start evaluation.
# Done. Time:1.164304785999775
# Test performance:
#  Accuracy:39.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.775020 [    0/ 3881]
# loss:1.648945 [ 3200/ 3881]
# Done. Time:9.313662530999864
# Training performance:
#  Avg loss:1.698467
#
# Start validation.
# Done. Time:0.393301151999367
# Validation performance:
#  Avg loss:1.859865
#
# Start evaluation.
# Done. Time:1.1550147269999798
# Test performance:
#  Accuracy:47.0%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.699943 [    0/ 3881]
# loss:1.517946 [ 3200/ 3881]
# Done. Time:9.548326711999835
# Training performance:
#  Avg loss:1.665967
#
# Start validation.
# Done. Time:0.4107376980000481
# Validation performance:
#  Avg loss:1.701360
#
# Start evaluation.
# Done. Time:1.1479861550005808
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.580193 [    0/ 3881]
# loss:1.734942 [ 3200/ 3881]
# Done. Time:9.005163593999896
# Training performance:
#  Avg loss:1.642701
#
# Start validation.
# Done. Time:0.6110951740001838
# Validation performance:
#  Avg loss:1.720868
#
# Start evaluation.
# Done. Time:1.3728378910000174
# Test performance:
#  Accuracy:49.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.986969 [    0/ 3881]
# loss:1.679832 [ 3200/ 3881]
# Done. Time:10.929747554999267
# Training performance:
#  Avg loss:1.646205
#
# Start validation.
# Done. Time:1.0550213710002936
# Validation performance:
#  Avg loss:1.659139
#
# Start evaluation.
# Done. Time:2.3377990700000737
# Test performance:
#  Accuracy:49.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.628386 [    0/ 3881]
# loss:1.964823 [ 3200/ 3881]
# Done. Time:14.500200477999897
# Training performance:
#  Avg loss:1.865633
#
# Start validation.
# Done. Time:0.39350796899998386
# Validation performance:
#  Avg loss:2.227641
#
# Start evaluation.
# Done. Time:1.1266766529997767
# Test performance:
#  Accuracy:25.0%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:2.253459 [    0/ 3881]
# loss:2.131011 [ 3200/ 3881]
# Done. Time:9.478270979999252
# Training performance:
#  Avg loss:1.933510
#
# Start validation.
# Done. Time:0.39326671799972246
# Validation performance:
#  Avg loss:1.992476
#
# Start evaluation.
# Done. Time:1.1764823230005277
# Test performance:
#  Accuracy:30.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.873580 [    0/ 3881]
# loss:1.932864 [ 3200/ 3881]
# Done. Time:9.3681016190003
# Training performance:
#  Avg loss:1.806458
#
# Start validation.
# Done. Time:0.38202620899937756
# Validation performance:
#  Avg loss:1.916142
#
# Start evaluation.
# Done. Time:1.162052384999697
# Test performance:
#  Accuracy:40.0%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.741534 [    0/ 3881]
# loss:1.593475 [ 3200/ 3881]
# Done. Time:8.654825028999767
# Training performance:
#  Avg loss:1.743918
#
# Start validation.
# Done. Time:0.6462243159994614
# Validation performance:
#  Avg loss:1.869948
#
# Start evaluation.
# Done. Time:1.618913731000248
# Test performance:
#  Accuracy:45.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.824980 [    0/ 3881]
# loss:1.728094 [ 3200/ 3881]
# Done. Time:8.426602643000479
# Training performance:
#  Avg loss:1.685106
#
# Start validation.
# Done. Time:0.4088132470005803
# Validation performance:
#  Avg loss:1.753338
#
# Start evaluation.
# Done. Time:1.3026444160004758
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.770851 [    0/ 3881]
# loss:1.620792 [ 3200/ 3881]
# Done. Time:9.085926853000274
# Training performance:
#  Avg loss:1.597422
#
# Start validation.
# Done. Time:0.40362611599994125
# Validation performance:
#  Avg loss:1.829197
#
# Start evaluation.
# Done. Time:1.1118716520004455
# Test performance:
#  Accuracy:49.0%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:1.582787 [    0/ 3881]
# loss:1.533416 [ 3200/ 3881]
# Done. Time:9.320548589000282
# Training performance:
#  Avg loss:1.545882
#
# Start validation.
# Done. Time:0.41323561900026107
# Validation performance:
#  Avg loss:1.629730
#
# Start evaluation.
# Done. Time:1.1372100110002066
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.740756 [    0/ 3881]
# loss:1.381373 [ 3200/ 3881]
# Done. Time:9.482347922999907
# Training performance:
#  Avg loss:1.533783
#
# Start validation.
# Done. Time:0.39746497699979955
# Validation performance:
#  Avg loss:2.061802
#
# Start evaluation.
# Done. Time:1.1495564699998795
# Test performance:
#  Accuracy:47.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:2.121219 [    0/ 3881]
# loss:1.560578 [ 3200/ 3881]
# Done. Time:9.486472285000673
# Training performance:
#  Avg loss:1.923097
#
# Start validation.
# Done. Time:0.4049498260001201
# Validation performance:
#  Avg loss:1.703236
#
# Start evaluation.
# Done. Time:1.131730590999723
# Test performance:
#  Accuracy:49.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.951638 [    0/ 3881]
# loss:1.828691 [ 3200/ 3881]
# Done. Time:9.719116302000657
# Training performance:
#  Avg loss:1.595775
#
# Start validation.
# Done. Time:0.385687168000004
# Validation performance:
#  Avg loss:1.788472
#
# Start evaluation.
# Done. Time:1.1147115699995993
# Test performance:
#  Accuracy:40.0%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:1.503268 [    0/ 3881]
# loss:1.893287 [ 3200/ 3881]
# Done. Time:8.760465902999385
# Training performance:
#  Avg loss:1.705242
#
# Start validation.
# Done. Time:0.6240797640002711
# Validation performance:
#  Avg loss:1.759861
#
# Start evaluation.
# Done. Time:1.4247073890001047
# Test performance:
#  Accuracy:48.0%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:1.292964 [    0/ 3881]
# loss:1.470756 [ 3200/ 3881]
# Done. Time:9.383423962999586
# Training performance:
#  Avg loss:1.578807
#
# Start validation.
# Done. Time:0.6111389190000409
# Validation performance:
#  Avg loss:1.660232
#
# Start evaluation.
# Done. Time:1.711794073999954
# Test performance:
#  Accuracy:53.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.548307 [    0/ 3881]
# loss:1.747699 [ 3200/ 3881]
# Done. Time:8.673618132999763
# Training performance:
#  Avg loss:1.515931
#
# Start validation.
# Done. Time:0.38652907100004086
# Validation performance:
#  Avg loss:1.634488
#
# Start evaluation.
# Done. Time:1.2834089670004687
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.467770 [    0/ 3881]
# loss:1.386197 [ 3200/ 3881]
# Done. Time:9.458665226999983
# Training performance:
#  Avg loss:1.470808
#
# Start validation.
# Done. Time:0.4002907679996497
# Validation performance:
#  Avg loss:1.602909
#
# Start evaluation.
# Done. Time:1.1670076310001605
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.607026 [    0/ 3881]
# loss:1.114023 [ 3200/ 3881]
# Done. Time:9.496954121999806
# Training performance:
#  Avg loss:1.435097
#
# Start validation.
# Done. Time:0.41114406300039263
# Validation performance:
#  Avg loss:1.579881
#
# Start evaluation.
# Done. Time:1.1507232829999339
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.376787 [    0/ 3881]
# loss:1.633538 [ 3200/ 3881]
# Done. Time:9.40627557300013
# Training performance:
#  Avg loss:1.467250
#
# Start validation.
# Done. Time:0.39816906200030644
# Validation performance:
#  Avg loss:1.760513
#
# Start evaluation.
# Done. Time:1.1306481149995307
# Test performance:
#  Accuracy:43.0%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:1.824843 [    0/ 3881]
# loss:1.344059 [ 3200/ 3881]
# Done. Time:9.485912408999866
# Training performance:
#  Avg loss:1.460121
#
# Start validation.
# Done. Time:0.40762549999999464
# Validation performance:
#  Avg loss:1.710333
#
# Start evaluation.
# Done. Time:1.1371073549998982
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.865731 [    0/ 3881]
# loss:1.670735 [ 3200/ 3881]
# Done. Time:9.687104806999741
# Training performance:
#  Avg loss:1.410063
#
# Start validation.
# Done. Time:0.688309544000731
# Validation performance:
#  Avg loss:1.616742
#
# Start evaluation.
# Done. Time:2.137623956000425
# Test performance:
#  Accuracy:53.0%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:1.204542 [    0/ 3881]
# loss:1.800605 [ 3200/ 3881]
# Done. Time:9.618610625000656
# Training performance:
#  Avg loss:1.391788
#
# Start validation.
# Done. Time:0.39292957300040143
# Validation performance:
#  Avg loss:1.621505
#
# Start evaluation.
# Done. Time:1.1674940970005991
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:1.655762 [    0/ 3881]
# loss:1.011681 [ 3200/ 3881]
# Done. Time:8.870483211000646
# Training performance:
#  Avg loss:1.317882
#
# Start validation.
# Done. Time:0.6082660379997833
# Validation performance:
#  Avg loss:1.541688
#
# Start evaluation.
# Done. Time:1.443155222000314
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:1.090618 [    0/ 3881]
# loss:1.243969 [ 3200/ 3881]
# Done. Time:8.385633181999765
# Training performance:
#  Avg loss:1.302991
#
# Start validation.
# Done. Time:0.40172987099958846
# Validation performance:
#  Avg loss:1.441949
#
# Start evaluation.
# Done. Time:1.4290307780001967
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:1.233132 [    0/ 3881]
# loss:2.202354 [ 3200/ 3881]
# Done. Time:9.100099223999678
# Training performance:
#  Avg loss:1.557152
#
# Start validation.
# Done. Time:0.3959526829994502
# Validation performance:
#  Avg loss:2.001187
#
# Start evaluation.
# Done. Time:1.1866818369999237
# Test performance:
#  Accuracy:51.5%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:1.775321 [    0/ 3881]
# loss:1.498349 [ 3200/ 3881]
# Done. Time:9.402694909000274
# Training performance:
#  Avg loss:1.583958
#
# Start validation.
# Done. Time:0.4125195850001546
# Validation performance:
#  Avg loss:1.758690
#
# Start evaluation.
# Done. Time:1.188246935999814
# Test performance:
#  Accuracy:41.0%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.821130 [    0/ 3881]
# loss:1.370864 [ 3200/ 3881]
# Done. Time:9.458636113000466
# Training performance:
#  Avg loss:1.420401
#
# Start validation.
# Done. Time:0.4120525960006489
# Validation performance:
#  Avg loss:2.250689
#
# Start evaluation.
# Done. Time:1.1980680609995034
# Test performance:
#  Accuracy:45.5%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:1.320312 [    0/ 3881]
# loss:1.540002 [ 3200/ 3881]
# Done. Time:9.526077723000526
# Training performance:
#  Avg loss:1.631634
#
# Start validation.
# Done. Time:0.40874501899997995
# Validation performance:
#  Avg loss:5.406327
#
# Start evaluation.
# Done. Time:1.1644811639998807
# Test performance:
#  Accuracy:15.5%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:4.501852 [    0/ 3881]
# loss:1.772046 [ 3200/ 3881]
# Done. Time:9.297264361999623
# Training performance:
#  Avg loss:2.860614
#
# Start validation.
# Done. Time:0.41319411099993886
# Validation performance:
#  Avg loss:2.185847
#
# Start evaluation.
# Done. Time:1.159273000000212
# Test performance:
#  Accuracy:22.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:1.846635 [    0/ 3881]
# loss:1.450057 [ 3200/ 3881]
# Done. Time:8.76314020800055
# Training performance:
#  Avg loss:1.741574
#
# Start validation.
# Done. Time:0.5973592480004299
# Validation performance:
#  Avg loss:1.857258
#
# Start evaluation.
# Done. Time:1.413708979999683
# Test performance:
#  Accuracy:36.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:1.522435 [    0/ 3881]
# loss:1.242285 [ 3200/ 3881]
# Done. Time:8.391038106999986
# Training performance:
#  Avg loss:1.549366
#
# Start validation.
# Done. Time:0.4106935540003178
# Validation performance:
#  Avg loss:1.707978
#
# Start evaluation.
# Done. Time:1.4809079639999254
# Test performance:
#  Accuracy:48.0%
# Minimum validation loss:1.4419490269252233 at 43 epoch.
# Maximum accuracy:56.00000000000001 at 42 epoch.

# %% [markdown]
# ### Layer settings
# #### Stacked RNN

# %%
rnn_num_layers = 2
rnn_bidir = False
masking_type = "none"

model = RNNISLR(in_channels=in_channels,
                hidden_channels=hidden_channels,
                out_channels=out_channels,
                rnn_num_layers=rnn_num_layers,
                rnn_bidir=rnn_bidir,
                masking_type=masking_type)
print(model)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
# Out:
# RNNISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (rnn): RNNEncoder(
#     (rnn): RNN(64, 64, num_layers=2, batch_first=True, dropout=0.1)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_stacked = np.array(val_losses)
test_accs_stacked = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_stacked.min()} at {np.argmin(val_losses_stacked)+1} epoch.")
print(f"Maximum accuracy:{test_accs_stacked.max()} at {np.argmax(test_accs_stacked)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.344200 [    0/ 3881]
# loss:2.101118 [ 3200/ 3881]
# Done. Time:14.029346252000323
# Training performance:
#  Avg loss:2.240531
#
# Start validation.
# Done. Time:0.4586100960004842
# Validation performance:
#  Avg loss:2.078632
#
# Start evaluation.
# Done. Time:2.1010115680001036
# Test performance:
#  Accuracy:26.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:1.975421 [    0/ 3881]
# loss:1.927735 [ 3200/ 3881]
# Done. Time:19.268538607000664
# Training performance:
#  Avg loss:2.039213
#
# Start validation.
# Done. Time:0.4541315019996546
# Validation performance:
#  Avg loss:2.004758
#
# Start evaluation.
# Done. Time:1.3691728320000038
# Test performance:
#  Accuracy:28.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.841368 [    0/ 3881]
# loss:1.898510 [ 3200/ 3881]
# Done. Time:13.848950694999985
# Training performance:
#  Avg loss:1.937202
#
# Start validation.
# Done. Time:0.46224495000024035
# Validation performance:
#  Avg loss:2.027964
#
# Start evaluation.
# Done. Time:1.961799446000441
# Test performance:
#  Accuracy:34.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.649317 [    0/ 3881]
# loss:1.581895 [ 3200/ 3881]
# Done. Time:14.06263938200027
# Training performance:
#  Avg loss:1.891967
#
# Start validation.
# Done. Time:0.45840204800060746
# Validation performance:
#  Avg loss:1.842605
#
# Start evaluation.
# Done. Time:1.3389399389998289
# Test performance:
#  Accuracy:37.5%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.779383 [    0/ 3881]
# loss:1.876185 [ 3200/ 3881]
# Done. Time:14.022850812000797
# Training performance:
#  Avg loss:1.850229
#
# Start validation.
# Done. Time:0.47591738700066344
# Validation performance:
#  Avg loss:1.751874
#
# Start evaluation.
# Done. Time:1.3548495889999685
# Test performance:
#  Accuracy:39.0%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.829675 [    0/ 3881]
# loss:1.689013 [ 3200/ 3881]
# Done. Time:13.793387016000452
# Training performance:
#  Avg loss:1.686467
#
# Start validation.
# Done. Time:0.475575089000813
# Validation performance:
#  Avg loss:1.607503
#
# Start evaluation.
# Done. Time:1.379574682000566
# Test performance:
#  Accuracy:44.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.572233 [    0/ 3881]
# loss:1.560793 [ 3200/ 3881]
# Done. Time:13.62775521399999
# Training performance:
#  Avg loss:1.635599
#
# Start validation.
# Done. Time:0.6282795759998407
# Validation performance:
#  Avg loss:1.715808
#
# Start evaluation.
# Done. Time:1.9567583110001578
# Test performance:
#  Accuracy:45.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.647829 [    0/ 3881]
# loss:1.787962 [ 3200/ 3881]
# Done. Time:13.427709384000082
# Training performance:
#  Avg loss:1.514380
#
# Start validation.
# Done. Time:0.45562227400023403
# Validation performance:
#  Avg loss:1.548845
#
# Start evaluation.
# Done. Time:1.332105798000157
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.452418 [    0/ 3881]
# loss:1.358768 [ 3200/ 3881]
# Done. Time:13.52393527499953
# Training performance:
#  Avg loss:1.553776
#
# Start validation.
# Done. Time:0.4804058010004155
# Validation performance:
#  Avg loss:1.517543
#
# Start evaluation.
# Done. Time:1.3889724740001839
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.406092 [    0/ 3881]
# loss:1.489331 [ 3200/ 3881]
# Done. Time:13.566009925000799
# Training performance:
#  Avg loss:1.419270
#
# Start validation.
# Done. Time:0.47236016700026084
# Validation performance:
#  Avg loss:1.526232
#
# Start evaluation.
# Done. Time:1.3876159760002338
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.217767 [    0/ 3881]
# loss:1.788205 [ 3200/ 3881]
# Done. Time:13.643153668000195
# Training performance:
#  Avg loss:1.420978
#
# Start validation.
# Done. Time:0.49450897200040345
# Validation performance:
#  Avg loss:1.589535
#
# Start evaluation.
# Done. Time:1.6941089070005546
# Test performance:
#  Accuracy:45.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.267234 [    0/ 3881]
# loss:1.558854 [ 3200/ 3881]
# Done. Time:14.086178440000367
# Training performance:
#  Avg loss:1.390328
#
# Start validation.
# Done. Time:0.45892763800020475
# Validation performance:
#  Avg loss:1.424555
#
# Start evaluation.
# Done. Time:1.355327782999666
# Test performance:
#  Accuracy:46.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.309397 [    0/ 3881]
# loss:1.303798 [ 3200/ 3881]
# Done. Time:13.305050844000107
# Training performance:
#  Avg loss:1.372890
#
# Start validation.
# Done. Time:0.48563479899985396
# Validation performance:
#  Avg loss:1.929018
#
# Start evaluation.
# Done. Time:1.3996643529999346
# Test performance:
#  Accuracy:44.0%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.829329 [    0/ 3881]
# loss:1.330501 [ 3200/ 3881]
# Done. Time:13.437858476000656
# Training performance:
#  Avg loss:1.492331
#
# Start validation.
# Done. Time:0.4863137160000406
# Validation performance:
#  Avg loss:1.724078
#
# Start evaluation.
# Done. Time:1.3273502150004788
# Test performance:
#  Accuracy:48.0%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:1.202423 [    0/ 3881]
# loss:2.245493 [ 3200/ 3881]
# Done. Time:13.429698169999938
# Training performance:
#  Avg loss:1.624372
#
# Start validation.
# Done. Time:0.4597622189994581
# Validation performance:
#  Avg loss:1.783588
#
# Start evaluation.
# Done. Time:1.3865802860000258
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.845579 [    0/ 3881]
# loss:1.559566 [ 3200/ 3881]
# Done. Time:13.926975567999762
# Training performance:
#  Avg loss:1.604331
#
# Start validation.
# Done. Time:0.7221248199994079
# Validation performance:
#  Avg loss:1.435587
#
# Start evaluation.
# Done. Time:1.5527216760001465
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.761470 [    0/ 3881]
# loss:1.626132 [ 3200/ 3881]
# Done. Time:13.813797048000197
# Training performance:
#  Avg loss:1.463029
#
# Start validation.
# Done. Time:0.45669392600029823
# Validation performance:
#  Avg loss:1.576670
#
# Start evaluation.
# Done. Time:1.3902465299997857
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.860623 [    0/ 3881]
# loss:1.410081 [ 3200/ 3881]
# Done. Time:13.562326421999387
# Training performance:
#  Avg loss:1.602115
#
# Start validation.
# Done. Time:0.4666431499999817
# Validation performance:
#  Avg loss:1.597201
#
# Start evaluation.
# Done. Time:1.372871584000677
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.314695 [    0/ 3881]
# loss:1.287466 [ 3200/ 3881]
# Done. Time:13.516470030999699
# Training performance:
#  Avg loss:1.447271
#
# Start validation.
# Done. Time:0.47236279100070533
# Validation performance:
#  Avg loss:1.363557
#
# Start evaluation.
# Done. Time:1.3252670230003787
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.554781 [    0/ 3881]
# loss:1.171822 [ 3200/ 3881]
# Done. Time:13.89659230899997
# Training performance:
#  Avg loss:1.299690
#
# Start validation.
# Done. Time:0.7359892580006999
# Validation performance:
#  Avg loss:1.304175
#
# Start evaluation.
# Done. Time:1.6016944539996985
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.081548 [    0/ 3881]
# loss:1.057029 [ 3200/ 3881]
# Done. Time:13.655783563000114
# Training performance:
#  Avg loss:1.206337
#
# Start validation.
# Done. Time:0.4662739679997685
# Validation performance:
#  Avg loss:1.415217
#
# Start evaluation.
# Done. Time:1.3836776280004415
# Test performance:
#  Accuracy:52.5%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.530859 [    0/ 3881]
# loss:1.464110 [ 3200/ 3881]
# Done. Time:13.629681030000029
# Training performance:
#  Avg loss:1.160122
#
# Start validation.
# Done. Time:0.47084265499961475
# Validation performance:
#  Avg loss:1.362365
#
# Start evaluation.
# Done. Time:1.3626826510007959
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.463221 [    0/ 3881]
# loss:1.105480 [ 3200/ 3881]
# Done. Time:13.408768338999835
# Training performance:
#  Avg loss:1.241502
#
# Start validation.
# Done. Time:0.4697017729995423
# Validation performance:
#  Avg loss:1.497872
#
# Start evaluation.
# Done. Time:1.3890678999996453
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.458573 [    0/ 3881]
# loss:1.349680 [ 3200/ 3881]
# Done. Time:13.270034598000166
# Training performance:
#  Avg loss:1.170561
#
# Start validation.
# Done. Time:0.7092642019997584
# Validation performance:
#  Avg loss:2.408811
#
# Start evaluation.
# Done. Time:1.8779719889998887
# Test performance:
#  Accuracy:48.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.797274 [    0/ 3881]
# loss:2.086860 [ 3200/ 3881]
# Done. Time:13.720302333999825
# Training performance:
#  Avg loss:1.620945
#
# Start validation.
# Done. Time:0.4536947890001102
# Validation performance:
#  Avg loss:1.815468
#
# Start evaluation.
# Done. Time:1.3375951779999014
# Test performance:
#  Accuracy:46.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:2.220867 [    0/ 3881]
# loss:1.149388 [ 3200/ 3881]
# Done. Time:13.50106665200019
# Training performance:
#  Avg loss:1.537550
#
# Start validation.
# Done. Time:0.4707794659998399
# Validation performance:
#  Avg loss:1.456670
#
# Start evaluation.
# Done. Time:1.3584932019994085
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.313540 [    0/ 3881]
# loss:0.897839 [ 3200/ 3881]
# Done. Time:13.86266040999999
# Training performance:
#  Avg loss:1.278471
#
# Start validation.
# Done. Time:0.4674670459999106
# Validation performance:
#  Avg loss:1.662416
#
# Start evaluation.
# Done. Time:1.3431086290001986
# Test performance:
#  Accuracy:60.0%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.627809 [    0/ 3881]
# loss:0.958820 [ 3200/ 3881]
# Done. Time:13.50356591199943
# Training performance:
#  Avg loss:1.239649
#
# Start validation.
# Done. Time:0.6203018360001806
# Validation performance:
#  Avg loss:1.542257
#
# Start evaluation.
# Done. Time:2.043917169999986
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:1.555904 [    0/ 3881]
# loss:0.933965 [ 3200/ 3881]
# Done. Time:13.702898392000861
# Training performance:
#  Avg loss:1.168214
#
# Start validation.
# Done. Time:0.47882398900037515
# Validation performance:
#  Avg loss:1.912805
#
# Start evaluation.
# Done. Time:1.3461453769996297
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.208091 [    0/ 3881]
# loss:1.336171 [ 3200/ 3881]
# Done. Time:13.477488924000681
# Training performance:
#  Avg loss:1.175038
#
# Start validation.
# Done. Time:0.46858879499995965
# Validation performance:
#  Avg loss:1.449389
#
# Start evaluation.
# Done. Time:1.4802149389997794
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:1.070151 [    0/ 3881]
# loss:0.997000 [ 3200/ 3881]
# Done. Time:13.453871069999877
# Training performance:
#  Avg loss:1.064431
#
# Start validation.
# Done. Time:0.46884954100005416
# Validation performance:
#  Avg loss:1.425885
#
# Start evaluation.
# Done. Time:1.388977597000121
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.474514 [    0/ 3881]
# loss:1.225541 [ 3200/ 3881]
# Done. Time:13.31249624299926
# Training performance:
#  Avg loss:1.176421
#
# Start validation.
# Done. Time:0.4637792769999578
# Validation performance:
#  Avg loss:1.559023
#
# Start evaluation.
# Done. Time:1.785900080999454
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:1.184385 [    0/ 3881]
# loss:1.777351 [ 3200/ 3881]
# Done. Time:13.843049525999959
# Training performance:
#  Avg loss:1.090976
#
# Start validation.
# Done. Time:0.46911199300029693
# Validation performance:
#  Avg loss:1.502966
#
# Start evaluation.
# Done. Time:1.445617403000142
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:1.344890 [    0/ 3881]
# loss:1.522377 [ 3200/ 3881]
# Done. Time:13.622120209000059
# Training performance:
#  Avg loss:1.130525
#
# Start validation.
# Done. Time:0.46856895299970347
# Validation performance:
#  Avg loss:1.412368
#
# Start evaluation.
# Done. Time:1.340771039000174
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.077028 [    0/ 3881]
# loss:0.953675 [ 3200/ 3881]
# Done. Time:13.668878071999643
# Training performance:
#  Avg loss:1.131227
#
# Start validation.
# Done. Time:0.4535072239996225
# Validation performance:
#  Avg loss:1.228172
#
# Start evaluation.
# Done. Time:1.3865716250002151
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.079451 [    0/ 3881]
# loss:0.968658 [ 3200/ 3881]
# Done. Time:13.572790674999851
# Training performance:
#  Avg loss:1.070873
#
# Start validation.
# Done. Time:0.4522216430004846
# Validation performance:
#  Avg loss:1.202789
#
# Start evaluation.
# Done. Time:1.6096876469991912
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.428840 [    0/ 3881]
# loss:1.019586 [ 3200/ 3881]
# Done. Time:13.720211011000174
# Training performance:
#  Avg loss:1.013028
#
# Start validation.
# Done. Time:0.6971605480002836
# Validation performance:
#  Avg loss:1.347554
#
# Start evaluation.
# Done. Time:1.360009916999843
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.826345 [    0/ 3881]
# loss:1.304139 [ 3200/ 3881]
# Done. Time:13.520683163000285
# Training performance:
#  Avg loss:1.007369
#
# Start validation.
# Done. Time:0.47054876599941053
# Validation performance:
#  Avg loss:1.222224
#
# Start evaluation.
# Done. Time:1.3715473180000117
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.906160 [    0/ 3881]
# loss:1.637099 [ 3200/ 3881]
# Done. Time:13.800551303000248
# Training performance:
#  Avg loss:1.497924
#
# Start validation.
# Done. Time:0.4792292879992601
# Validation performance:
#  Avg loss:1.717817
#
# Start evaluation.
# Done. Time:1.3953360719997363
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:1.370409 [    0/ 3881]
# loss:1.111158 [ 3200/ 3881]
# Done. Time:13.619719223000175
# Training performance:
#  Avg loss:1.350523
#
# Start validation.
# Done. Time:0.4805348640002194
# Validation performance:
#  Avg loss:1.471274
#
# Start evaluation.
# Done. Time:1.390090703000169
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:1.099738 [    0/ 3881]
# loss:1.007839 [ 3200/ 3881]
# Done. Time:13.557490835999488
# Training performance:
#  Avg loss:1.213570
#
# Start validation.
# Done. Time:0.7686983820003661
# Validation performance:
#  Avg loss:1.492883
#
# Start evaluation.
# Done. Time:1.557142028999806
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:1.265892 [    0/ 3881]
# loss:1.127537 [ 3200/ 3881]
# Done. Time:13.641955608999524
# Training performance:
#  Avg loss:1.168502
#
# Start validation.
# Done. Time:0.4669325109998681
# Validation performance:
#  Avg loss:1.506367
#
# Start evaluation.
# Done. Time:1.3788382980001188
# Test performance:
#  Accuracy:51.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:1.068228 [    0/ 3881]
# loss:1.275672 [ 3200/ 3881]
# Done. Time:13.63878767299957
# Training performance:
#  Avg loss:1.160567
#
# Start validation.
# Done. Time:0.46650020600009157
# Validation performance:
#  Avg loss:1.456040
#
# Start evaluation.
# Done. Time:1.347471000999576
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:1.253445 [    0/ 3881]
# loss:1.218501 [ 3200/ 3881]
# Done. Time:13.652282166000077
# Training performance:
#  Avg loss:1.208051
#
# Start validation.
# Done. Time:0.4744254870001896
# Validation performance:
#  Avg loss:1.310173
#
# Start evaluation.
# Done. Time:1.3333867090004787
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.828482 [    0/ 3881]
# loss:0.868937 [ 3200/ 3881]
# Done. Time:14.1851207109994
# Training performance:
#  Avg loss:1.056974
#
# Start validation.
# Done. Time:0.7425979839999854
# Validation performance:
#  Avg loss:1.528863
#
# Start evaluation.
# Done. Time:1.546815092999168
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.989992 [    0/ 3881]
# loss:1.204079 [ 3200/ 3881]
# Done. Time:13.568741232999855
# Training performance:
#  Avg loss:1.074365
#
# Start validation.
# Done. Time:0.46571015999961674
# Validation performance:
#  Avg loss:1.585994
#
# Start evaluation.
# Done. Time:1.4337983810000878
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.924770 [    0/ 3881]
# loss:0.613536 [ 3200/ 3881]
# Done. Time:13.515810126999895
# Training performance:
#  Avg loss:0.988587
#
# Start validation.
# Done. Time:0.4613611179993313
# Validation performance:
#  Avg loss:1.319178
#
# Start evaluation.
# Done. Time:1.3897575179998967
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:1.141895 [    0/ 3881]
# loss:0.723395 [ 3200/ 3881]
# Done. Time:13.722634413000378
# Training performance:
#  Avg loss:0.962852
#
# Start validation.
# Done. Time:0.48217207299967413
# Validation performance:
#  Avg loss:1.428410
#
# Start evaluation.
# Done. Time:1.4243535269997665
# Test performance:
#  Accuracy:60.0%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:1.291174 [    0/ 3881]
# loss:1.072716 [ 3200/ 3881]
# Done. Time:13.887195323000014
# Training performance:
#  Avg loss:1.024703
#
# Start validation.
# Done. Time:0.7404531800002587
# Validation performance:
#  Avg loss:1.267056
#
# Start evaluation.
# Done. Time:1.6052569629991922
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:1.133847 [    0/ 3881]
# loss:0.910700 [ 3200/ 3881]
# Done. Time:13.547580627999196
# Training performance:
#  Avg loss:1.024295
#
# Start validation.
# Done. Time:0.46686557000066387
# Validation performance:
#  Avg loss:1.337113
#
# Start evaluation.
# Done. Time:1.346592619999683
# Test performance:
#  Accuracy:59.5%
# Minimum validation loss:1.2027894599097115 at 36 epoch.
# Maximum accuracy:62.5 at 41 epoch.

# %% [markdown]
# #### Bidirectional RNN

# %%
rnn_num_layers = 1
rnn_bidir = True
masking_type = "none"

model = RNNISLR(in_channels=in_channels,
                hidden_channels=hidden_channels,
                out_channels=out_channels,
                rnn_num_layers=rnn_num_layers,
                rnn_bidir=rnn_bidir,
                masking_type=masking_type)
print(model)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
# Out:
# RNNISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (rnn): RNNEncoder(
#     (rnn): RNN(64, 64, batch_first=True, bidirectional=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_bidir = np.array(val_losses)
test_accs_bidir = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_bidir.min()} at {np.argmin(val_losses_bidir)+1} epoch.")
print(f"Maximum accuracy:{test_accs_bidir.max()} at {np.argmax(test_accs_bidir)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.285999 [    0/ 3881]
# loss:2.161733 [ 3200/ 3881]
# Done. Time:14.556123979999938
# Training performance:
#  Avg loss:2.269978
#
# Start validation.
# Done. Time:0.517479937000644
# Validation performance:
#  Avg loss:2.219255
#
# Start evaluation.
# Done. Time:1.4481565140004022
# Test performance:
#  Accuracy:32.0%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.122603 [    0/ 3881]
# loss:2.712458 [ 3200/ 3881]
# Done. Time:14.34558038799969
# Training performance:
#  Avg loss:2.066762
#
# Start validation.
# Done. Time:0.5267254599993976
# Validation performance:
#  Avg loss:2.399603
#
# Start evaluation.
# Done. Time:1.953633944000103
# Test performance:
#  Accuracy:23.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:2.242402 [    0/ 3881]
# loss:1.611427 [ 3200/ 3881]
# Done. Time:14.366401482000583
# Training performance:
#  Avg loss:1.871755
#
# Start validation.
# Done. Time:0.5180976279998504
# Validation performance:
#  Avg loss:2.035533
#
# Start evaluation.
# Done. Time:1.3794739259992639
# Test performance:
#  Accuracy:28.5%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.709168 [    0/ 3881]
# loss:1.769670 [ 3200/ 3881]
# Done. Time:14.5055865180002
# Training performance:
#  Avg loss:1.744542
#
# Start validation.
# Done. Time:0.5087539969999852
# Validation performance:
#  Avg loss:1.853001
#
# Start evaluation.
# Done. Time:1.4221464470001592
# Test performance:
#  Accuracy:43.5%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.847381 [    0/ 3881]
# loss:2.022423 [ 3200/ 3881]
# Done. Time:14.414289080000344
# Training performance:
#  Avg loss:1.841375
#
# Start validation.
# Done. Time:0.5070837970006323
# Validation performance:
#  Avg loss:1.924192
#
# Start evaluation.
# Done. Time:1.727123804999792
# Test performance:
#  Accuracy:36.0%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.775225 [    0/ 3881]
# loss:1.390693 [ 3200/ 3881]
# Done. Time:14.923869909000132
# Training performance:
#  Avg loss:1.753429
#
# Start validation.
# Done. Time:0.5009987600005843
# Validation performance:
#  Avg loss:1.750679
#
# Start evaluation.
# Done. Time:1.4492524950001098
# Test performance:
#  Accuracy:40.5%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.839590 [    0/ 3881]
# loss:1.578748 [ 3200/ 3881]
# Done. Time:14.18878617000064
# Training performance:
#  Avg loss:1.587297
#
# Start validation.
# Done. Time:0.5106082399997831
# Validation performance:
#  Avg loss:1.630302
#
# Start evaluation.
# Done. Time:1.4354828380000981
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.647899 [    0/ 3881]
# loss:1.551135 [ 3200/ 3881]
# Done. Time:14.276886689999628
# Training performance:
#  Avg loss:1.559104
#
# Start validation.
# Done. Time:0.49711662199933926
# Validation performance:
#  Avg loss:1.625421
#
# Start evaluation.
# Done. Time:1.4192539679997935
# Test performance:
#  Accuracy:47.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.577896 [    0/ 3881]
# loss:1.538357 [ 3200/ 3881]
# Done. Time:15.385636963999787
# Training performance:
#  Avg loss:1.516806
#
# Start validation.
# Done. Time:0.5140836410000702
# Validation performance:
#  Avg loss:1.528334
#
# Start evaluation.
# Done. Time:1.4227793609998116
# Test performance:
#  Accuracy:49.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.338851 [    0/ 3881]
# loss:1.542449 [ 3200/ 3881]
# Done. Time:14.234719377000147
# Training performance:
#  Avg loss:1.473215
#
# Start validation.
# Done. Time:0.49292810800034204
# Validation performance:
#  Avg loss:1.677067
#
# Start evaluation.
# Done. Time:1.4005580900002315
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.537252 [    0/ 3881]
# loss:1.485469 [ 3200/ 3881]
# Done. Time:14.127139076000276
# Training performance:
#  Avg loss:1.414321
#
# Start validation.
# Done. Time:0.49666566899941245
# Validation performance:
#  Avg loss:1.522482
#
# Start evaluation.
# Done. Time:1.4224800390002201
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.258104 [    0/ 3881]
# loss:1.447282 [ 3200/ 3881]
# Done. Time:14.756498816000203
# Training performance:
#  Avg loss:1.454565
#
# Start validation.
# Done. Time:0.7505773689999842
# Validation performance:
#  Avg loss:1.541059
#
# Start evaluation.
# Done. Time:1.5458697940002821
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.409104 [    0/ 3881]
# loss:1.313155 [ 3200/ 3881]
# Done. Time:14.133146928000315
# Training performance:
#  Avg loss:1.346971
#
# Start validation.
# Done. Time:0.5108657259997926
# Validation performance:
#  Avg loss:1.588717
#
# Start evaluation.
# Done. Time:1.374377332000222
# Test performance:
#  Accuracy:52.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.320191 [    0/ 3881]
# loss:1.196379 [ 3200/ 3881]
# Done. Time:14.457145100000162
# Training performance:
#  Avg loss:1.264409
#
# Start validation.
# Done. Time:0.5274138129998391
# Validation performance:
#  Avg loss:1.402575
#
# Start evaluation.
# Done. Time:1.4084613120003269
# Test performance:
#  Accuracy:49.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:1.110204 [    0/ 3881]
# loss:1.556474 [ 3200/ 3881]
# Done. Time:14.319900825999866
# Training performance:
#  Avg loss:1.304048
#
# Start validation.
# Done. Time:0.7617911869992895
# Validation performance:
#  Avg loss:1.484318
#
# Start evaluation.
# Done. Time:1.833465795999473
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.391145 [    0/ 3881]
# loss:1.410710 [ 3200/ 3881]
# Done. Time:14.362621928000408
# Training performance:
#  Avg loss:1.253137
#
# Start validation.
# Done. Time:0.5289776930003427
# Validation performance:
#  Avg loss:1.527106
#
# Start evaluation.
# Done. Time:1.387736521000079
# Test performance:
#  Accuracy:46.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:1.411536 [    0/ 3881]
# loss:1.261231 [ 3200/ 3881]
# Done. Time:14.498886684000354
# Training performance:
#  Avg loss:1.239352
#
# Start validation.
# Done. Time:0.5141306349996739
# Validation performance:
#  Avg loss:1.259491
#
# Start evaluation.
# Done. Time:1.3506861949999802
# Test performance:
#  Accuracy:52.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.406871 [    0/ 3881]
# loss:2.348671 [ 3200/ 3881]
# Done. Time:14.384991957000238
# Training performance:
#  Avg loss:1.450974
#
# Start validation.
# Done. Time:0.5870207739999387
# Validation performance:
#  Avg loss:1.662813
#
# Start evaluation.
# Done. Time:2.0002734690006037
# Test performance:
#  Accuracy:41.0%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.629508 [    0/ 3881]
# loss:1.274950 [ 3200/ 3881]
# Done. Time:14.37348258199927
# Training performance:
#  Avg loss:1.390844
#
# Start validation.
# Done. Time:0.521877608000068
# Validation performance:
#  Avg loss:1.638214
#
# Start evaluation.
# Done. Time:1.3652003119996152
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.634920 [    0/ 3881]
# loss:1.119151 [ 3200/ 3881]
# Done. Time:14.523894295999526
# Training performance:
#  Avg loss:1.323668
#
# Start validation.
# Done. Time:0.505244820000371
# Validation performance:
#  Avg loss:1.422019
#
# Start evaluation.
# Done. Time:1.4186285949999728
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:0.998760 [    0/ 3881]
# loss:1.142398 [ 3200/ 3881]
# Done. Time:14.4232477380001
# Training performance:
#  Avg loss:1.220226
#
# Start validation.
# Done. Time:0.5020713909998449
# Validation performance:
#  Avg loss:1.438036
#
# Start evaluation.
# Done. Time:2.014689286999783
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.412939 [    0/ 3881]
# loss:1.039457 [ 3200/ 3881]
# Done. Time:14.763190056000894
# Training performance:
#  Avg loss:1.195415
#
# Start validation.
# Done. Time:0.5203601850007544
# Validation performance:
#  Avg loss:1.484467
#
# Start evaluation.
# Done. Time:1.4175769069997841
# Test performance:
#  Accuracy:51.0%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:0.792994 [    0/ 3881]
# loss:1.466892 [ 3200/ 3881]
# Done. Time:14.580143362999479
# Training performance:
#  Avg loss:1.174862
#
# Start validation.
# Done. Time:0.5041571969995857
# Validation performance:
#  Avg loss:1.812196
#
# Start evaluation.
# Done. Time:1.4297084850004467
# Test performance:
#  Accuracy:40.0%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.776910 [    0/ 3881]
# loss:1.387324 [ 3200/ 3881]
# Done. Time:14.347931940999842
# Training performance:
#  Avg loss:1.400882
#
# Start validation.
# Done. Time:0.5267725169996993
# Validation performance:
#  Avg loss:1.482926
#
# Start evaluation.
# Done. Time:2.008706123999218
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.482745 [    0/ 3881]
# loss:1.117471 [ 3200/ 3881]
# Done. Time:13.997372300999814
# Training performance:
#  Avg loss:1.192000
#
# Start validation.
# Done. Time:0.5032141050005521
# Validation performance:
#  Avg loss:1.369431
#
# Start evaluation.
# Done. Time:1.4124438970002302
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:0.857970 [    0/ 3881]
# loss:0.977204 [ 3200/ 3881]
# Done. Time:14.29468149100012
# Training performance:
#  Avg loss:1.165495
#
# Start validation.
# Done. Time:0.501074057000551
# Validation performance:
#  Avg loss:1.496122
#
# Start evaluation.
# Done. Time:1.4085155880002276
# Test performance:
#  Accuracy:50.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.545798 [    0/ 3881]
# loss:1.168525 [ 3200/ 3881]
# Done. Time:14.284968341000422
# Training performance:
#  Avg loss:1.186619
#
# Start validation.
# Done. Time:0.5100711109998883
# Validation performance:
#  Avg loss:1.299661
#
# Start evaluation.
# Done. Time:1.5756356319998304
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.924615 [    0/ 3881]
# loss:1.049690 [ 3200/ 3881]
# Done. Time:15.587619635999545
# Training performance:
#  Avg loss:1.145764
#
# Start validation.
# Done. Time:0.5101846839997961
# Validation performance:
#  Avg loss:1.191554
#
# Start evaluation.
# Done. Time:1.41815035000036
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.718137 [    0/ 3881]
# loss:1.030269 [ 3200/ 3881]
# Done. Time:14.31838612699994
# Training performance:
#  Avg loss:1.095799
#
# Start validation.
# Done. Time:0.5206240499992418
# Validation performance:
#  Avg loss:1.328038
#
# Start evaluation.
# Done. Time:1.4045515180005168
# Test performance:
#  Accuracy:52.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.378035 [    0/ 3881]
# loss:0.869403 [ 3200/ 3881]
# Done. Time:14.512927639999361
# Training performance:
#  Avg loss:1.079650
#
# Start validation.
# Done. Time:0.4904037000005701
# Validation performance:
#  Avg loss:1.205896
#
# Start evaluation.
# Done. Time:1.4321094189999712
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.973162 [    0/ 3881]
# loss:1.061271 [ 3200/ 3881]
# Done. Time:15.176517856999453
# Training performance:
#  Avg loss:1.015681
#
# Start validation.
# Done. Time:0.5070604530001219
# Validation performance:
#  Avg loss:1.156081
#
# Start evaluation.
# Done. Time:1.4563324569999168
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.948098 [    0/ 3881]
# loss:1.370926 [ 3200/ 3881]
# Done. Time:14.58735280899964
# Training performance:
#  Avg loss:1.098245
#
# Start validation.
# Done. Time:0.5228398680001192
# Validation performance:
#  Avg loss:1.266063
#
# Start evaluation.
# Done. Time:1.3841438469999048
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.929352 [    0/ 3881]
# loss:1.264745 [ 3200/ 3881]
# Done. Time:14.405761431000428
# Training performance:
#  Avg loss:1.027610
#
# Start validation.
# Done. Time:0.5113321680000809
# Validation performance:
#  Avg loss:1.250262
#
# Start evaluation.
# Done. Time:1.4204206890008209
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:1.148772 [    0/ 3881]
# loss:0.945877 [ 3200/ 3881]
# Done. Time:15.527478480000354
# Training performance:
#  Avg loss:1.023823
#
# Start validation.
# Done. Time:0.5121533100000306
# Validation performance:
#  Avg loss:1.250941
#
# Start evaluation.
# Done. Time:1.4228998569997202
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.001164 [    0/ 3881]
# loss:0.905305 [ 3200/ 3881]
# Done. Time:14.54950289199951
# Training performance:
#  Avg loss:1.023167
#
# Start validation.
# Done. Time:0.5302075180006796
# Validation performance:
#  Avg loss:1.245423
#
# Start evaluation.
# Done. Time:1.458121140000003
# Test performance:
#  Accuracy:60.0%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:1.137592 [    0/ 3881]
# loss:1.068305 [ 3200/ 3881]
# Done. Time:14.461890786000367
# Training performance:
#  Avg loss:0.992491
#
# Start validation.
# Done. Time:0.5141209479997997
# Validation performance:
#  Avg loss:1.319554
#
# Start evaluation.
# Done. Time:1.5183901170003082
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.943218 [    0/ 3881]
# loss:1.167894 [ 3200/ 3881]
# Done. Time:15.49321646000044
# Training performance:
#  Avg loss:1.029634
#
# Start validation.
# Done. Time:0.5029626650002683
# Validation performance:
#  Avg loss:1.282816
#
# Start evaluation.
# Done. Time:1.4561944150000272
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.513457 [    0/ 3881]
# loss:0.983139 [ 3200/ 3881]
# Done. Time:14.425232060999406
# Training performance:
#  Avg loss:0.945726
#
# Start validation.
# Done. Time:0.5611882590001187
# Validation performance:
#  Avg loss:1.215837
#
# Start evaluation.
# Done. Time:1.4459639340002468
# Test performance:
#  Accuracy:54.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:1.410725 [    0/ 3881]
# loss:1.002281 [ 3200/ 3881]
# Done. Time:14.655039518999729
# Training performance:
#  Avg loss:0.978937
#
# Start validation.
# Done. Time:0.5061939799998072
# Validation performance:
#  Avg loss:1.440968
#
# Start evaluation.
# Done. Time:1.4727842350002902
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:1.103074 [    0/ 3881]
# loss:0.878081 [ 3200/ 3881]
# Done. Time:15.261341068000547
# Training performance:
#  Avg loss:1.093350
#
# Start validation.
# Done. Time:0.4998628250004913
# Validation performance:
#  Avg loss:1.245604
#
# Start evaluation.
# Done. Time:1.396722602000409
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:1.110678 [    0/ 3881]
# loss:1.011619 [ 3200/ 3881]
# Done. Time:14.523831980000068
# Training performance:
#  Avg loss:1.002287
#
# Start validation.
# Done. Time:0.5141172149997146
# Validation performance:
#  Avg loss:1.353085
#
# Start evaluation.
# Done. Time:1.4630598949997875
# Test performance:
#  Accuracy:52.5%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.841486 [    0/ 3881]
# loss:1.042022 [ 3200/ 3881]
# Done. Time:14.37627457400049
# Training performance:
#  Avg loss:1.007075
#
# Start validation.
# Done. Time:0.5027098419996037
# Validation performance:
#  Avg loss:1.160488
#
# Start evaluation.
# Done. Time:1.4392476439998063
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:1.044968 [    0/ 3881]
# loss:0.754613 [ 3200/ 3881]
# Done. Time:15.272155309000482
# Training performance:
#  Avg loss:0.993469
#
# Start validation.
# Done. Time:0.5459523869994882
# Validation performance:
#  Avg loss:1.169738
#
# Start evaluation.
# Done. Time:1.402402398999584
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:1.048968 [    0/ 3881]
# loss:1.453087 [ 3200/ 3881]
# Done. Time:14.263013941000281
# Training performance:
#  Avg loss:0.961818
#
# Start validation.
# Done. Time:0.4994731659999161
# Validation performance:
#  Avg loss:1.282728
#
# Start evaluation.
# Done. Time:1.420605424000314
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.945809 [    0/ 3881]
# loss:1.060771 [ 3200/ 3881]
# Done. Time:14.106663427000058
# Training performance:
#  Avg loss:0.933752
#
# Start validation.
# Done. Time:0.5286192789999404
# Validation performance:
#  Avg loss:1.166276
#
# Start evaluation.
# Done. Time:1.4336754349997136
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:1.224291 [    0/ 3881]
# loss:0.756175 [ 3200/ 3881]
# Done. Time:14.963368241999888
# Training performance:
#  Avg loss:0.869602
#
# Start validation.
# Done. Time:0.7715854589996525
# Validation performance:
#  Avg loss:1.097364
#
# Start evaluation.
# Done. Time:1.5674220299997614
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.665913 [    0/ 3881]
# loss:0.830796 [ 3200/ 3881]
# Done. Time:14.30978606500048
# Training performance:
#  Avg loss:0.827625
#
# Start validation.
# Done. Time:0.49757941200005007
# Validation performance:
#  Avg loss:1.153355
#
# Start evaluation.
# Done. Time:1.4769895010003893
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.893080 [    0/ 3881]
# loss:1.391879 [ 3200/ 3881]
# Done. Time:14.649492358000316
# Training performance:
#  Avg loss:1.073694
#
# Start validation.
# Done. Time:0.5043017469997721
# Validation performance:
#  Avg loss:1.651443
#
# Start evaluation.
# Done. Time:1.4508876979998604
# Test performance:
#  Accuracy:50.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:1.456948 [    0/ 3881]
# loss:1.097727 [ 3200/ 3881]
# Done. Time:14.68103486400014
# Training performance:
#  Avg loss:1.125523
#
# Start validation.
# Done. Time:0.8140850090003369
# Validation performance:
#  Avg loss:1.315910
#
# Start evaluation.
# Done. Time:1.6118658069999583
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.907461 [    0/ 3881]
# loss:0.845843 [ 3200/ 3881]
# Done. Time:14.457675880000352
# Training performance:
#  Avg loss:1.006260
#
# Start validation.
# Done. Time:0.5185751090002668
# Validation performance:
#  Avg loss:1.281995
#
# Start evaluation.
# Done. Time:1.4251845660000981
# Test performance:
#  Accuracy:60.5%
# Minimum validation loss:1.097364366054535 at 46 epoch.
# Maximum accuracy:65.0 at 34 epoch.

# %% [markdown]
# #### Stacked and bidirectional RNN

# %%
rnn_num_layers = 2
rnn_bidir = True
masking_type = "none"

model = RNNISLR(in_channels=in_channels,
                hidden_channels=hidden_channels,
                out_channels=out_channels,
                rnn_num_layers=rnn_num_layers,
                rnn_bidir=rnn_bidir,
                masking_type=masking_type)
print(model)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
# Out:
# RNNISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (rnn): RNNEncoder(
#     (rnn): RNN(64, 64, num_layers=2, batch_first=True, dropout=0.1, bidirectional=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model.to(device)

val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_loop(train_dataloader, model, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model, device)
        test_accs.append(acc)
val_losses_stacked_bidir = np.array(val_losses)
test_accs_stacked_bidir = np.array(test_accs)
print(f"Minimum validation loss:{val_losses_stacked_bidir.min()} at {np.argmin(val_losses_stacked_bidir)+1} epoch.")
print(f"Maximum accuracy:{test_accs_stacked_bidir.max()} at {np.argmax(test_accs_stacked_bidir)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.400419 [    0/ 3881]
# loss:2.189917 [ 3200/ 3881]
# Done. Time:24.75635624499955
# Training performance:
#  Avg loss:2.236449
#
# Start validation.
# Done. Time:0.6661902280002323
# Validation performance:
#  Avg loss:2.130273
#
# Start evaluation.
# Done. Time:1.834972860000562
# Test performance:
#  Accuracy:22.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:2.058236 [    0/ 3881]
# loss:1.826254 [ 3200/ 3881]
# Done. Time:24.836248436999995
# Training performance:
#  Avg loss:1.938738
#
# Start validation.
# Done. Time:0.6599497390006945
# Validation performance:
#  Avg loss:1.874335
#
# Start evaluation.
# Done. Time:1.7558331899999757
# Test performance:
#  Accuracy:35.0%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.895455 [    0/ 3881]
# loss:1.595721 [ 3200/ 3881]
# Done. Time:23.68752749699979
# Training performance:
#  Avg loss:1.789278
#
# Start validation.
# Done. Time:0.6655782780007939
# Validation performance:
#  Avg loss:1.961785
#
# Start evaluation.
# Done. Time:1.8777986220002276
# Test performance:
#  Accuracy:33.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.830717 [    0/ 3881]
# loss:1.423991 [ 3200/ 3881]
# Done. Time:24.466514181000093
# Training performance:
#  Avg loss:1.655916
#
# Start validation.
# Done. Time:0.8042437519998202
# Validation performance:
#  Avg loss:1.651597
#
# Start evaluation.
# Done. Time:2.404377537000073
# Test performance:
#  Accuracy:43.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.603565 [    0/ 3881]
# loss:1.377510 [ 3200/ 3881]
# Done. Time:23.449520770999698
# Training performance:
#  Avg loss:1.528949
#
# Start validation.
# Done. Time:1.016122027000165
# Validation performance:
#  Avg loss:1.695585
#
# Start evaluation.
# Done. Time:1.8050393399998939
# Test performance:
#  Accuracy:47.0%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.394858 [    0/ 3881]
# loss:1.472440 [ 3200/ 3881]
# Done. Time:24.342852874000528
# Training performance:
#  Avg loss:1.483212
#
# Start validation.
# Done. Time:0.6646777719997772
# Validation performance:
#  Avg loss:1.693430
#
# Start evaluation.
# Done. Time:1.8384536909998133
# Test performance:
#  Accuracy:39.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.125784 [    0/ 3881]
# loss:1.459845 [ 3200/ 3881]
# Done. Time:24.535015729000406
# Training performance:
#  Avg loss:1.389116
#
# Start validation.
# Done. Time:0.6690848340003868
# Validation performance:
#  Avg loss:1.760855
#
# Start evaluation.
# Done. Time:1.7995506209999803
# Test performance:
#  Accuracy:45.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.296075 [    0/ 3881]
# loss:1.147197 [ 3200/ 3881]
# Done. Time:24.62964760700015
# Training performance:
#  Avg loss:1.342964
#
# Start validation.
# Done. Time:0.6547983430000386
# Validation performance:
#  Avg loss:1.484988
#
# Start evaluation.
# Done. Time:1.7609755969997423
# Test performance:
#  Accuracy:55.5%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.265183 [    0/ 3881]
# loss:1.020594 [ 3200/ 3881]
# Done. Time:24.706871055000192
# Training performance:
#  Avg loss:1.306339
#
# Start validation.
# Done. Time:0.6746711690002485
# Validation performance:
#  Avg loss:1.524530
#
# Start evaluation.
# Done. Time:1.782560783000008
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.405584 [    0/ 3881]
# loss:1.195317 [ 3200/ 3881]
# Done. Time:24.880401386999438
# Training performance:
#  Avg loss:1.210596
#
# Start validation.
# Done. Time:0.6708461640000678
# Validation performance:
#  Avg loss:1.410337
#
# Start evaluation.
# Done. Time:2.3319544389996736
# Test performance:
#  Accuracy:60.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.173293 [    0/ 3881]
# loss:1.034216 [ 3200/ 3881]
# Done. Time:24.219951085000503
# Training performance:
#  Avg loss:1.164983
#
# Start validation.
# Done. Time:1.0264103050003541
# Validation performance:
#  Avg loss:1.494345
#
# Start evaluation.
# Done. Time:1.9718616529999053
# Test performance:
#  Accuracy:53.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.151387 [    0/ 3881]
# loss:1.392170 [ 3200/ 3881]
# Done. Time:25.030921233999834
# Training performance:
#  Avg loss:1.120274
#
# Start validation.
# Done. Time:0.6664035949997924
# Validation performance:
#  Avg loss:1.308820
#
# Start evaluation.
# Done. Time:1.7939967710008204
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:0.986461 [    0/ 3881]
# loss:1.061556 [ 3200/ 3881]
# Done. Time:24.252779775000818
# Training performance:
#  Avg loss:1.106636
#
# Start validation.
# Done. Time:0.685621233999882
# Validation performance:
#  Avg loss:1.421915
#
# Start evaluation.
# Done. Time:1.8169458560005296
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:0.896062 [    0/ 3881]
# loss:1.282237 [ 3200/ 3881]
# Done. Time:24.751323354000306
# Training performance:
#  Avg loss:1.024319
#
# Start validation.
# Done. Time:0.6504348819998995
# Validation performance:
#  Avg loss:1.201150
#
# Start evaluation.
# Done. Time:1.753372118999323
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:0.873362 [    0/ 3881]
# loss:0.869755 [ 3200/ 3881]
# Done. Time:24.195159764999516
# Training performance:
#  Avg loss:0.995004
#
# Start validation.
# Done. Time:0.6777398369995353
# Validation performance:
#  Avg loss:1.239603
#
# Start evaluation.
# Done. Time:1.8253077029994529
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:0.881671 [    0/ 3881]
# loss:1.125092 [ 3200/ 3881]
# Done. Time:24.49555058199985
# Training performance:
#  Avg loss:1.068176
#
# Start validation.
# Done. Time:0.6724129969998103
# Validation performance:
#  Avg loss:1.258883
#
# Start evaluation.
# Done. Time:2.1864962489999016
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:0.891351 [    0/ 3881]
# loss:0.599188 [ 3200/ 3881]
# Done. Time:23.711715757000093
# Training performance:
#  Avg loss:0.956619
#
# Start validation.
# Done. Time:0.9154088840004988
# Validation performance:
#  Avg loss:1.322214
#
# Start evaluation.
# Done. Time:2.28426001599928
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.291136 [    0/ 3881]
# loss:0.817788 [ 3200/ 3881]
# Done. Time:24.596466543000133
# Training performance:
#  Avg loss:1.027702
#
# Start validation.
# Done. Time:0.6547416930006875
# Validation performance:
#  Avg loss:1.554186
#
# Start evaluation.
# Done. Time:1.870205254999746
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:0.985001 [    0/ 3881]
# loss:0.948497 [ 3200/ 3881]
# Done. Time:24.57912808800029
# Training performance:
#  Avg loss:1.002018
#
# Start validation.
# Done. Time:0.6506827619996329
# Validation performance:
#  Avg loss:1.472119
#
# Start evaluation.
# Done. Time:1.7141675530001521
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.250196 [    0/ 3881]
# loss:1.501442 [ 3200/ 3881]
# Done. Time:24.870707404999848
# Training performance:
#  Avg loss:0.900142
#
# Start validation.
# Done. Time:0.6708491180006604
# Validation performance:
#  Avg loss:1.182785
#
# Start evaluation.
# Done. Time:1.761006757999894
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:0.683227 [    0/ 3881]
# loss:1.408770 [ 3200/ 3881]
# Done. Time:24.00757342399993
# Training performance:
#  Avg loss:1.052017
#
# Start validation.
# Done. Time:0.6609310760004519
# Validation performance:
#  Avg loss:1.355559
#
# Start evaluation.
# Done. Time:1.851122836000286
# Test performance:
#  Accuracy:62.5%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.741513 [    0/ 3881]
# loss:1.155770 [ 3200/ 3881]
# Done. Time:24.96742501300014
# Training performance:
#  Avg loss:0.921496
#
# Start validation.
# Done. Time:0.6755855910005266
# Validation performance:
#  Avg loss:1.128075
#
# Start evaluation.
# Done. Time:1.8879427619995113
# Test performance:
#  Accuracy:68.0%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:0.600281 [    0/ 3881]
# loss:0.609687 [ 3200/ 3881]
# Done. Time:23.94589734500005
# Training performance:
#  Avg loss:0.825042
#
# Start validation.
# Done. Time:0.6530337110007167
# Validation performance:
#  Avg loss:1.169959
#
# Start evaluation.
# Done. Time:2.401044240000374
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:0.988584 [    0/ 3881]
# loss:0.916099 [ 3200/ 3881]
# Done. Time:24.092504997000106
# Training performance:
#  Avg loss:1.169988
#
# Start validation.
# Done. Time:1.017999489000431
# Validation performance:
#  Avg loss:1.417279
#
# Start evaluation.
# Done. Time:1.8764924959996279
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:0.900387 [    0/ 3881]
# loss:0.920870 [ 3200/ 3881]
# Done. Time:24.270131295999818
# Training performance:
#  Avg loss:0.933255
#
# Start validation.
# Done. Time:0.6553470159997232
# Validation performance:
#  Avg loss:1.271176
#
# Start evaluation.
# Done. Time:1.8284864799998104
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:0.927532 [    0/ 3881]
# loss:0.789429 [ 3200/ 3881]
# Done. Time:24.068082016000517
# Training performance:
#  Avg loss:0.872865
#
# Start validation.
# Done. Time:0.6527541390005354
# Validation performance:
#  Avg loss:1.243210
#
# Start evaluation.
# Done. Time:1.8128445570000622
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.094604 [    0/ 3881]
# loss:0.914232 [ 3200/ 3881]
# Done. Time:24.1237520629993
# Training performance:
#  Avg loss:0.838268
#
# Start validation.
# Done. Time:0.6759163990000161
# Validation performance:
#  Avg loss:1.439717
#
# Start evaluation.
# Done. Time:1.7970214150000174
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.981128 [    0/ 3881]
# loss:0.767276 [ 3200/ 3881]
# Done. Time:23.649473002000377
# Training performance:
#  Avg loss:1.046591
#
# Start validation.
# Done. Time:0.6535256229999504
# Validation performance:
#  Avg loss:1.373761
#
# Start evaluation.
# Done. Time:1.7705360680001831
# Test performance:
#  Accuracy:65.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.712129 [    0/ 3881]
# loss:1.023634 [ 3200/ 3881]
# Done. Time:24.198981573999845
# Training performance:
#  Avg loss:0.967493
#
# Start validation.
# Done. Time:0.655482934000247
# Validation performance:
#  Avg loss:1.149023
#
# Start evaluation.
# Done. Time:1.8507777660006468
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:1.050810 [    0/ 3881]
# loss:0.592445 [ 3200/ 3881]
# Done. Time:24.675395199000377
# Training performance:
#  Avg loss:0.852224
#
# Start validation.
# Done. Time:0.6656386329996167
# Validation performance:
#  Avg loss:1.238916
#
# Start evaluation.
# Done. Time:2.1576421139998274
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.976946 [    0/ 3881]
# loss:0.866370 [ 3200/ 3881]
# Done. Time:24.249310647999664
# Training performance:
#  Avg loss:0.818365
#
# Start validation.
# Done. Time:1.0005497860001924
# Validation performance:
#  Avg loss:1.265716
#
# Start evaluation.
# Done. Time:2.0729849930003184
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.694175 [    0/ 3881]
# loss:0.888487 [ 3200/ 3881]
# Done. Time:24.495860267999888
# Training performance:
#  Avg loss:0.782092
#
# Start validation.
# Done. Time:0.6481904659995052
# Validation performance:
#  Avg loss:1.048990
#
# Start evaluation.
# Done. Time:1.7583967989994562
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.984843 [    0/ 3881]
# loss:1.151539 [ 3200/ 3881]
# Done. Time:24.639031468000212
# Training performance:
#  Avg loss:0.797072
#
# Start validation.
# Done. Time:0.667902414999844
# Validation performance:
#  Avg loss:2.044794
#
# Start evaluation.
# Done. Time:1.7530208070002118
# Test performance:
#  Accuracy:51.0%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.921873 [    0/ 3881]
# loss:0.892335 [ 3200/ 3881]
# Done. Time:24.31858212499992
# Training performance:
#  Avg loss:1.038784
#
# Start validation.
# Done. Time:0.6927219710005375
# Validation performance:
#  Avg loss:1.407597
#
# Start evaluation.
# Done. Time:1.800931157999912
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.751546 [    0/ 3881]
# loss:0.692574 [ 3200/ 3881]
# Done. Time:24.212170335999872
# Training performance:
#  Avg loss:0.934457
#
# Start validation.
# Done. Time:0.6724032729998726
# Validation performance:
#  Avg loss:1.394234
#
# Start evaluation.
# Done. Time:1.7564676520005378
# Test performance:
#  Accuracy:63.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.564354 [    0/ 3881]
# loss:1.010215 [ 3200/ 3881]
# Done. Time:24.34870439199949
# Training performance:
#  Avg loss:0.871877
#
# Start validation.
# Done. Time:0.6638299209998877
# Validation performance:
#  Avg loss:1.374062
#
# Start evaluation.
# Done. Time:1.805291231999945
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.644867 [    0/ 3881]
# loss:1.064476 [ 3200/ 3881]
# Done. Time:24.434532143999604
# Training performance:
#  Avg loss:0.838360
#
# Start validation.
# Done. Time:0.6697204820002298
# Validation performance:
#  Avg loss:1.292346
#
# Start evaluation.
# Done. Time:2.4286906679999447
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:1.032782 [    0/ 3881]
# loss:0.478528 [ 3200/ 3881]
# Done. Time:23.607722237000416
# Training performance:
#  Avg loss:0.853778
#
# Start validation.
# Done. Time:0.9887873589996161
# Validation performance:
#  Avg loss:1.823946
#
# Start evaluation.
# Done. Time:1.9598286430000371
# Test performance:
#  Accuracy:52.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:1.438186 [    0/ 3881]
# loss:0.783793 [ 3200/ 3881]
# Done. Time:24.529055762999633
# Training performance:
#  Avg loss:0.939432
#
# Start validation.
# Done. Time:0.6469438350004566
# Validation performance:
#  Avg loss:1.172156
#
# Start evaluation.
# Done. Time:1.780482514999676
# Test performance:
#  Accuracy:69.5%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:1.305428 [    0/ 3881]
# loss:0.826961 [ 3200/ 3881]
# Done. Time:23.639351142999658
# Training performance:
#  Avg loss:0.779580
#
# Start validation.
# Done. Time:0.6660252199999377
# Validation performance:
#  Avg loss:1.263220
#
# Start evaluation.
# Done. Time:1.7781297569999879
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.802055 [    0/ 3881]
# loss:0.557352 [ 3200/ 3881]
# Done. Time:24.729146925999885
# Training performance:
#  Avg loss:0.752722
#
# Start validation.
# Done. Time:0.7199961939995774
# Validation performance:
#  Avg loss:1.280301
#
# Start evaluation.
# Done. Time:1.9076057070005845
# Test performance:
#  Accuracy:63.5%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.964047 [    0/ 3881]
# loss:0.598554 [ 3200/ 3881]
# Done. Time:24.850039254000876
# Training performance:
#  Avg loss:0.735889
#
# Start validation.
# Done. Time:0.6414395270003297
# Validation performance:
#  Avg loss:1.132265
#
# Start evaluation.
# Done. Time:1.7368218980000165
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.898944 [    0/ 3881]
# loss:0.748373 [ 3200/ 3881]
# Done. Time:24.4759626619998
# Training performance:
#  Avg loss:0.708610
#
# Start validation.
# Done. Time:0.6419438079992688
# Validation performance:
#  Avg loss:1.162507
#
# Start evaluation.
# Done. Time:1.8505095810005514
# Test performance:
#  Accuracy:68.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.513032 [    0/ 3881]
# loss:0.810972 [ 3200/ 3881]
# Done. Time:24.51721737600019
# Training performance:
#  Avg loss:0.686303
#
# Start validation.
# Done. Time:0.8612879629999952
# Validation performance:
#  Avg loss:1.294469
#
# Start evaluation.
# Done. Time:2.308639091000259
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.976017 [    0/ 3881]
# loss:0.633435 [ 3200/ 3881]
# Done. Time:24.435501152999677
# Training performance:
#  Avg loss:0.648095
#
# Start validation.
# Done. Time:0.6948608010006865
# Validation performance:
#  Avg loss:1.170071
#
# Start evaluation.
# Done. Time:1.8077624570005355
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.960439 [    0/ 3881]
# loss:0.904731 [ 3200/ 3881]
# Done. Time:24.853622925999844
# Training performance:
#  Avg loss:0.656249
#
# Start validation.
# Done. Time:0.6773156380004366
# Validation performance:
#  Avg loss:1.143961
#
# Start evaluation.
# Done. Time:1.7865935939998963
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.592213 [    0/ 3881]
# loss:0.587042 [ 3200/ 3881]
# Done. Time:24.182426301000305
# Training performance:
#  Avg loss:0.671685
#
# Start validation.
# Done. Time:0.6535561059999964
# Validation performance:
#  Avg loss:1.214000
#
# Start evaluation.
# Done. Time:1.8802097629995842
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.690598 [    0/ 3881]
# loss:1.309857 [ 3200/ 3881]
# Done. Time:24.10219314400001
# Training performance:
#  Avg loss:0.700950
#
# Start validation.
# Done. Time:0.6832465749994299
# Validation performance:
#  Avg loss:1.150276
#
# Start evaluation.
# Done. Time:1.75888737600053
# Test performance:
#  Accuracy:67.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.705527 [    0/ 3881]
# loss:0.880816 [ 3200/ 3881]
# Done. Time:24.286894062999636
# Training performance:
#  Avg loss:0.687060
#
# Start validation.
# Done. Time:0.6622351350006284
# Validation performance:
#  Avg loss:1.241441
#
# Start evaluation.
# Done. Time:1.7526846420005313
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.688045 [    0/ 3881]
# loss:0.902101 [ 3200/ 3881]
# Done. Time:24.729283415000282
# Training performance:
#  Avg loss:0.622539
#
# Start validation.
# Done. Time:0.6839908430001742
# Validation performance:
#  Avg loss:1.176678
#
# Start evaluation.
# Done. Time:2.4323159079995094
# Test performance:
#  Accuracy:69.0%
# Minimum validation loss:1.048990079334804 at 32 epoch.
# Maximum accuracy:72.5 at 49 epoch.

# %% [markdown]
# #### Plot result

# %%
import matplotlib.pyplot as plt

plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(val_losses_default)+1)
plt.plot(xs, val_losses_default, label="Default", marker=".")
plt.plot(xs, val_losses_stacked, label="+ Stacked", marker=".")
plt.plot(xs, val_losses_bidir, label="+ Bidir", marker=".")
plt.plot(xs, val_losses_stacked_bidir, label="+ Stacked + Bidir", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Validation loss")
plt.ylim([0.0, 2.5])
plt.legend()
plt.show()

# %%
plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(test_accs_default)+1)
plt.plot(xs, test_accs_default, label="Default", marker=".")
plt.plot(xs, test_accs_stacked, label="+ Stacked", marker=".")
plt.plot(xs, test_accs_bidir, label="+ Bidir", marker=".")
plt.plot(xs, test_accs_stacked_bidir, label="+ Stacked + Bidir", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.ylim([0.0, 100.0])
plt.legend()
plt.show()

# %%
print(f"Default: {test_accs_default.max()}")
print(f"+ Stacked: {test_accs_stacked.max()}")
print(f"+ Bidir: {test_accs_bidir.max()}")
print(f"+ Stacked + Bidir: {test_accs_stacked_bidir.max()}")
# Out:
# Default: 56.00000000000001
# + Stacked: 62.5
# + Bidir: 65.0
# + Stacked + Bidir: 72.5
