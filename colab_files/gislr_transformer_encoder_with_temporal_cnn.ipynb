# %% [markdown]
# <a href="https://colab.research.google.com/github/takayama-rado/trado_samples/blob/main/colab_files/gislr_transfomer_encoder_with_temporal_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Download dataset and modules

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Copy to local.
# !cp drive/MyDrive/Datasets/gislr_dataset_top10.zip gislr_top10.zip

# %%
# !unzip -o gislr_top10.zip
# Out:
# Archive:  gislr_top10.zip
#    creating: dataset_top10/
#   inflating: dataset_top10/16069.hdf5
#   inflating: dataset_top10/18796.hdf5
#   inflating: dataset_top10/2044.hdf5
#   inflating: dataset_top10/22343.hdf5
#   inflating: dataset_top10/25571.hdf5
#   inflating: dataset_top10/26734.hdf5
#   inflating: dataset_top10/27610.hdf5
#   inflating: dataset_top10/28656.hdf5
#   inflating: dataset_top10/29302.hdf5
#   inflating: dataset_top10/30680.hdf5
#   inflating: dataset_top10/32319.hdf5
#   inflating: dataset_top10/34503.hdf5
#   inflating: dataset_top10/36257.hdf5
#   inflating: dataset_top10/37055.hdf5
#   inflating: dataset_top10/37779.hdf5
#   inflating: dataset_top10/4718.hdf5
#   inflating: dataset_top10/49445.hdf5
#   inflating: dataset_top10/53618.hdf5
#   inflating: dataset_top10/55372.hdf5
#   inflating: dataset_top10/61333.hdf5
#   inflating: dataset_top10/62590.hdf5
#   inflating: dataset_top10/LICENSE.txt
#   inflating: dataset_top10/sign_to_prediction_index_map.json

# %%
# !ls dataset_top10
# Out:
# 16069.hdf5  25571.hdf5	29302.hdf5  36257.hdf5	49445.hdf5  62590.hdf5
# 18796.hdf5  26734.hdf5	30680.hdf5  37055.hdf5	53618.hdf5  LICENSE.txt
# 2044.hdf5   27610.hdf5	32319.hdf5  37779.hdf5	55372.hdf5  sign_to_prediction_index_map.json
# 22343.hdf5  28656.hdf5	34503.hdf5  4718.hdf5	61333.hdf5

# %%
# !cat dataset_top10/sign_to_prediction_index_map.json
# Out:
# {
#     "listen": 0,
#     "look": 1,
#     "shhh": 2,
#     "donkey": 3,
#     "mouse": 4,
#     "duck": 5,
#     "uncle": 6,
#     "hear": 7,
#     "pretend": 8,
#     "cow": 9
# }

# %%
# !cat dataset_top10/LICENSE.txt
# Out:
# The dataset provided by Natsuki Takayama (Takayama Research and Development Office) is licensed under CC-BY 4.0.
# Author: Copyright 2024 Natsuki Takayama
# Title: GISLR Top 10 dataset
# Original licenser: Deaf Professional Arts Network and the Georgia Institute of Technology
# Modification
# - Extract 10 most frequent words.
# - Packaged into HDF5 format.

# %%
import h5py
with h5py.File("dataset_top10/16069.hdf5", "r") as fread:
    keys = list(fread.keys())
    print(keys)
    group = fread[keys[0]]
    print(group.keys())
    feature = group["feature"][:]
    token = group["token"][:]
    print(feature.shape)
    print(token)
# Out:
# ['1109479272', '11121526', '1120349077', '1125456612', '1159046211', '1169128497', '1186032553', '1223803476', '1259708636', '1281972067', '129232566', '1334702305', '1340979012', '1352964057', '1370052047', '1383455381', '1431148933', '1435203624', '1437919781', '1458770030', '1462881097', '1469867050', '1474050058', '147607644', '1513539919', '1520635928', '1524297234', '153676122', '1537751003', '1542212461', '1551759770', '158232956', '1585855916', '1632709119', '1638742455', '1696757219', '177479476', '1779635114', '1791684792', '1801566440', '1831167282', '1867385690', '1880570146', '1901587887', '1910121429', '1919659282', '192873038', '1935012113', '1949620203', '195098847', '1983552660', '1989475963', '1998715062', '2007709802', '2036010239', '2036360025', '2046296211', '2082116372', '2098813002', '2109640010', '2121879330', '2141852087', '2148832702', '2152013823', '2166805079', '2176613834', '2184232774', '2213965523', '2249630763', '2256677805', '2263287955', '2263683020', '2264826605', '2270117351', '2281372282', '2285328250', '2322449232', '2326092712', '2336131857', '2346410171', '2405684784', '2467219838', '2473091535', '2488751095', '2515673021', '252176572', '2555449229', '2601816518', '2624310025', '2672738462', '2679264929', '2708514724', '2708544445', '2721276879', '2723773273', '2728839865', '2740241949', '2758304792', '2772051790', '2779816680', '2804441762', '2811346655', '2811646800', '2820103955', '2839681895', '2900998385', '2976200180', '2994456336', '3057994128', '3095010437', '3104317075', '3109672704', '3137179145', '3153285641', '3173321541', '3181666887', '3201889607', '3208820205', '3248401349', '3280527321', '3283246198', '3300057240', '3355963469', '3378306304', '3383637897', '3395075403', '3399503065', '3417877266', '3433092803', '347484677', '348956807', '3490841593', '3509324997', '3527069516', '3537611572', '3543711249', '3550826234', '3574700791', '3577812263', '3608551465', '3609537739', '3622960580', '3666781780', '3701422761', '3721927307', '3751410902', '3756613238', '3769544385', '3783554953', '3794712078', '380369091', '3813230821', '3817572483', '3843929707', '3869664504', '3892179393', '3923913515', '3981562204', '4078929101', '4101587978', '4150900444', '4191136837', '4200829752', '4209136328', '420958416', '422113773', '42222766', '4233346443', '4233985575', '4236057556', '4252161228', '425542996', '4276854486', '4294775577', '431609031', '439844759', '446236576', '470582324', '472128010', '492897929', '537402693', '5501547', '561170018', '593416697', '631898947', '649410423', '654529993', '678960043', '699907539', '707716966', '713615518', '778875120', '792981518', '796465415', '798649922', '856068671', '923153024', '957739544', '970593849', '976754415']
# <KeysViewHDF5 ['feature', 'token']>
# (3, 23, 543)
# [1]

# %%
# !wget https://github.com/takayama-rado/trado_samples/archive/refs/tags/v0.4.1.zip -O master.zip
# Out:
# --2024-10-23 04:27:31--  https://github.com/takayama-rado/trado_samples/archive/refs/tags/v0.4.1.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/takayama-rado/trado_samples/zip/refs/tags/v0.4.1 [following]
# --2024-10-23 04:27:32--  https://codeload.github.com/takayama-rado/trado_samples/zip/refs/tags/v0.4.1
# Resolving codeload.github.com (codeload.github.com)... 140.82.116.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.116.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [           <=>      ]  76.64M  18.9MB/s    in 4.1s
#
# 2024-10-23 04:27:36 (18.9 MB/s) - ‘master.zip’ saved [80365125]

# %%
# !unzip -o master.zip -d master
# Out:
# Archive:  master.zip
# ab8d10d4e0745f02a625f681f21bd5f5d0038f10
#    creating: master/trado_samples-0.4.1/
#   inflating: master/trado_samples-0.4.1/.gitignore
#   inflating: master/trado_samples-0.4.1/LICENSE
#   inflating: master/trado_samples-0.4.1/README.md
#    creating: master/trado_samples-0.4.1/colab_files/
#  extracting: master/trado_samples-0.4.1/colab_files/.gitkeep
#   inflating: master/trado_samples-0.4.1/colab_files/exp_affine_np_einsum.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/exp_jax_static.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/exp_mpholistic_0.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/exp_mpothers_0.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/exp_track_affine_jax.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/exp_track_affine_numpy.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/exp_track_affine_tensorflow.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/exp_track_affine_torch.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/exp_track_interp_jax.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/exp_track_interp_numpy_0.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/exp_track_interp_numpy_1.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/exp_track_interp_tensorflow.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/exp_track_interp_torch.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gafs_create_dataset.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gafs_rnn_encoder_decoder_cslr.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gafs_transformer_encoder_decoder_cslr.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_access_dataset.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_conformer_encoder.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_create_dataset.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_macaronnet_encoder.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_normalize_landmarks.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_rnn_islr_model_1.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_rnn_islr_model_2.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_rnn_islr_model_3.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_select_landmarks.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_simple_attention.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_simple_islr_model.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_transformer_encoder.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_transformer_encoder_daug_drop.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_transformer_encoder_daug_hflip.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_transformer_encoder_daug_resize.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_transformer_encoder_daug_saffine.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_transformer_encoder_daug_snoise.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_transformer_encoder_daug_tclip.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_transformer_encoder_daug_tinterp.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_transformer_encoder_daug_twarping.ipynb
#   inflating: master/trado_samples-0.4.1/colab_files/gislr_transformer_encoder_w_ls.ipynb
#    creating: master/trado_samples-0.4.1/src/
#    creating: master/trado_samples-0.4.1/src/modules_gislr/
#  extracting: master/trado_samples-0.4.1/src/modules_gislr/__init__.py
#   inflating: master/trado_samples-0.4.1/src/modules_gislr/activation.py
#   inflating: master/trado_samples-0.4.1/src/modules_gislr/dataset.py
#   inflating: master/trado_samples-0.4.1/src/modules_gislr/defines.py
#   inflating: master/trado_samples-0.4.1/src/modules_gislr/draw_functions.py
#    creating: master/trado_samples-0.4.1/src/modules_gislr/layers/
#  extracting: master/trado_samples-0.4.1/src/modules_gislr/layers/__init__.py
#   inflating: master/trado_samples-0.4.1/src/modules_gislr/layers/conformer.py
#   inflating: master/trado_samples-0.4.1/src/modules_gislr/layers/macaronnet.py
#   inflating: master/trado_samples-0.4.1/src/modules_gislr/layers/misc.py
#   inflating: master/trado_samples-0.4.1/src/modules_gislr/layers/rnn.py
#   inflating: master/trado_samples-0.4.1/src/modules_gislr/layers/simple_islr.py
#   inflating: master/trado_samples-0.4.1/src/modules_gislr/layers/transformer.py
#   inflating: master/trado_samples-0.4.1/src/modules_gislr/train_functions.py
#   inflating: master/trado_samples-0.4.1/src/modules_gislr/transforms.py
#   inflating: master/trado_samples-0.4.1/src/modules_gislr/utils.py
#    creating: master/trado_samples-0.4.1/test_data/
#   inflating: master/trado_samples-0.4.1/test_data/finger_far0.mp4
#   inflating: master/trado_samples-0.4.1/test_data/finger_far0_non_static.npy
#   inflating: master/trado_samples-0.4.1/test_data/finger_far0_non_static_affine.npy
#   inflating: master/trado_samples-0.4.1/test_data/finger_far0_non_static_interp.npy
#   inflating: master/trado_samples-0.4.1/test_data/finger_middle0.mp4
#   inflating: master/trado_samples-0.4.1/test_data/finger_near0.mp4
#   inflating: master/trado_samples-0.4.1/test_data/hand_only.mp4

# %%
# !mv master/trado_samples-0.4.1/src/modules_gislr .

# %%
# !rm -rf master master.zip gislr_top10.zip

# %%
# !ls
# Out:
# dataset_top10  drive  modules_gislr  sample_data

# %% [markdown]
# # 2. Load library

# %%
import collections
import copy
import json
import math
import os
import sys
from functools import partial
from pathlib import Path

# Third party's modules
import numpy as np

from pydantic import (
    BaseModel,
    ConfigDict,
    Field)

import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import (
    DataLoader)

from torchvision.transforms import Compose

# Local modules
sys.path.append("modules_gislr")
from modules_gislr.dataset import (
    HDF5Dataset,
    merge_padded_batch)
from modules_gislr.defines import (
    get_fullbody_landmarks,
    get_fullbody_swappairs
)
from modules_gislr.layers.misc import (
    GPoolRecognitionHeadSettings,
    Identity,
    Zero,
    apply_norm,
    create_norm
)
from modules_gislr.train_functions import (
    test_loop,
    val_loop,
    train_loop
)
from modules_gislr.transforms import (
    PartsBasedNormalization,
    RandomAffineTransform2D,
    RandomClip,
    RandomDropParts,
    RandomHorizontalFlip,
    RandomNoise,
    RandomTimeWarping,
    ReplaceNan,
    SelectLandmarksAndFeature,
    ToTensor
)
from modules_gislr.utils import (
    make_causal_mask,
    make_san_mask,
    select_reluwise_activation
)

# %% [markdown]
# # 3. Implement feature extraction module

# %% [markdown]
# ### Configured Pydantic model

# %%
class ConfiguredModel(BaseModel):
    model_config = ConfigDict(extra="forbid")

# %% [markdown]
# ### Linear feature extraction

# %%
class LinearFeatureExtractorSettings(ConfiguredModel):
    fext_type: str = "linear"
    in_channels: int = 64
    out_channels: int = 64
    norm_type: str = Field(default="batch", pattern=r"batch|layer")
    norm_eps: float = 1e-5
    activation: str = Field(default="relu",
        pattern=r"relu|gelu|swish|silu|mish|geluacc|tanhexp")
    add_bias: bool = True
    dropout: float = 0.1
    channel_first: bool = True
    add_residual: bool = True

    def build_layer(self):
        return LinearFeatureExtractor(self)

# %%
class LinearFeatureExtractor(nn.Module):
    def __init__(self,
                 settings):
        super().__init__()
        assert isinstance(settings, LinearFeatureExtractorSettings)
        self.settings = settings
        self.channel_first = settings.channel_first

        self.linear = nn.Linear(
            in_features=settings.in_channels,
            out_features=settings.out_channels,
            bias=settings.add_bias)

        self.norm = create_norm(
            settings.norm_type, settings.out_channels, settings.norm_eps,
            settings.add_bias)

        self.activation = select_reluwise_activation(settings.activation)

        self.dropout = nn.Dropout(p=settings.dropout)

        if settings.add_residual and settings.in_channels == settings.out_channels:
            self.residual = Identity()
        else:
            self.residual = Zero()

    def forward(self,
                feature):
        shape = feature.shape
        if self.channel_first:
            # `[N, C, T] -> [N, T, C]`
            if len(shape) == 3:
                feature = feature.permute([0, 2, 1])
            # `[N, C, T, *] -> [N, T, C, *] -> [N, T, C']`
            elif len(shape) == 4:
                feature = feature.permute([0, 2, 1, 3])
                feature = feature.reshape([shape[0], shape[2], -1])
            # `[N, C, T, *, *] -> [N, T, C, *, *] -> [N, T, C']`
            elif len(shape) == 5:
                feature = feature.permute([0, 2, 1, 3, 4])
                feature = feature.reshape([shape[0], shape[2], -1])
            else:
                raise NotImplementedError(f"Unsupported feature shape:{shape}.")
        res = self.residual(feature)
        feature = self.linear(feature)
        feature = apply_norm(self.norm, feature, channel_first=False)
        feature = self.activation(feature)
        feature = self.dropout(feature)
        feature = feature + res
        if self.channel_first:
            # `[N, T, C] -> [N, C, T]`
            feature = feature.permute([0, 2, 1])
        return feature

# %% [markdown]
# ### Temporal CNN feature extraction

# %%
class CNN1DFeatureExtractorSettings(ConfiguredModel):
    fext_type: str = "cnn1d"
    in_channels: int = 64
    out_channels: int = 64
    # Conv1D settings.
    kernel_size: int = Field(default=3, ge=3)
    stride: int = Field(default=1, ge=1)
    padding_mode: str = "zeros"
    norm_type: str = Field(default="batch",
        pattern=r"layer|batch")
    norm_eps: float = 1e-5
    activation: str = Field(default="swish",
        pattern=r"relu|gelu|swish|silu|mish|geluacc|tanhexp")
    causal: bool | None = False
    add_residual: bool = True
    add_bias: bool = True
    dropout: float = 0.1

    def model_post_init(self, __context):
        message = f"kernel_size:{self.kernel_size} must be the odd number."
        assert (self.kernel_size - 1) % 2 == 0, message

    def build_layer(self):
        return CNN1DFeatureExtractor(self)

# %%
class CNN1DFeatureExtractor(nn.Module):
    def __init__(self,
                 settings):
        super().__init__()
        assert isinstance(settings, CNN1DFeatureExtractorSettings)
        self.settings = settings
        self.causal = settings.causal

        if settings.causal:
            self.padding = (settings.kernel_size - 1)
        else:
            self.padding = (settings.kernel_size - 1) // 2

        self.conv_module = self._build_conv_module(settings, self.padding)
        self.norm = create_norm(settings.norm_type, settings.out_channels, settings.norm_eps)
        self.activation = select_reluwise_activation(settings.activation)
        self.dropout = nn.Dropout(p=settings.dropout)

        if settings.add_residual:
            if settings.in_channels == settings.out_channels:
                if settings.stride == 1:
                    self.residual = Identity()
                else:
                    self.residual = nn.MaxPool1d(
                        kernel_size=settings.kernel_size,
                        stride=settings.stride,
                        padding=self.padding)
            else:
                self.residual = nn.Conv1d(
                    in_channels=settings.in_channels,
                    out_channels=settings.out_channels,
                    kernel_size=1,
                    stride=settings.stride)
        else:
            self.residual = Zero()


    def _build_conv_module(self, settings, padding):
        dict_modules = collections.OrderedDict([
            # Point-wise.
            ("pconv",
             nn.Conv1d(
                in_channels=settings.in_channels,
                out_channels=settings.out_channels,
                kernel_size=1,
                stride=1,
                padding=0,
                bias=settings.add_bias)),
            # Depth-wise
            ("dconv",
             nn.Conv1d(
                in_channels=settings.out_channels,
                out_channels=settings.out_channels,
                kernel_size=settings.kernel_size,
                stride=settings.stride,
                padding=padding,
                groups=settings.out_channels,
                padding_mode=settings.padding_mode,
                bias=settings.add_bias))])

        conv_module = nn.Sequential(dict_modules)
        return conv_module

    def forward(self,
                feature):
        shape = feature.shape
        if len(shape) == 4:
            # `[N, C, T, *] -> [N, C, *, T] -> [N, C', T]`
            feature = feature.permute([0, 1, 3, 2])
            feature = feature.reshape([shape[0], -1, shape[2]])
        elif len(shape) == 5:
            # `[N, C, T, *, *] -> [N, C, *, *, T] -> [N, C', T]`
            feature = feature.permute([0, 1, 3, 4, 2])
            feature = feature.reshape([shape[0], -1, shape[2]])

        res = self.residual(feature)
        feature = self.conv_module(feature)
        feature = apply_norm(self.norm, feature, channel_first=True)
        feature = self.activation(feature)
        feature = self.dropout(feature)
        feature = feature + res
        return feature

# %%
def create_fext_module(settings):
    if settings is None:
        fext_module = nn.ModuleList(
            [Identity()])
    else:
        fext_module = nn.ModuleList(
            [setting.build_layer() for setting in settings])
    return fext_module

# %% [markdown]
# # 4. Refactor Transformer ISLR model

# %% [markdown]
# ### Postional encoding

# %%
class PositionalEncodingSettings(ConfiguredModel):
    dim_model: int = 64
    dropout: float = 0.1
    max_len: int = 5000

    def build_layer(self):
        return PositionalEncoding(self)

# %%
class PositionalEncoding(nn.Module):
    def __init__(self,
                 settings):
        super().__init__()
        assert isinstance(settings, PositionalEncodingSettings)
        self.settings = settings

        self.dim_model = settings.dim_model
        # Compute the positional encodings once in log space.
        pose = torch.zeros(settings.max_len, settings.dim_model,
            dtype=torch.float32)
        position = torch.arange(0, settings.max_len,
            dtype=torch.float32).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, settings.dim_model, 2).float()
                             * -(math.log(10000.0) / settings.dim_model))
        pose[:, 0::2] = torch.sin(position * div_term)
        pose[:, 1::2] = torch.cos(position * div_term)
        self.register_buffer("pose", pose)

        self.dropout = nn.Dropout(p=settings.dropout)

    def forward(self,
                feature):
        feature = feature + self.pose[None, :feature.shape[1], :]
        feature = self.dropout(feature)
        return feature

# %% [markdown]
# ### Multi-head attention

# %%
class MultiheadAttentionSettings(ConfiguredModel):
    key_dim: int = 64
    query_dim: int = 64
    att_dim: int = 64
    out_dim: int = 64
    num_heads: int = 1
    dropout: float = 0.1
    add_bias: bool = True

    def build_layer(self):
        return MultiheadAttention(self)

# %%
class MultiheadAttention(nn.Module):
    def __init__(self,
                 settings):
        super().__init__()
        assert isinstance(settings, MultiheadAttentionSettings)
        self.settings = settings

        assert settings.att_dim % settings.num_heads == 0
        self.head_dim = settings.att_dim // settings.num_heads
        self.num_heads = settings.num_heads
        self.scale = math.sqrt(self.head_dim)

        self.w_key = nn.Linear(settings.key_dim, settings.att_dim,
            bias=settings.add_bias)
        self.w_value = nn.Linear(settings.key_dim, settings.att_dim,
            bias=settings.add_bias)
        self.w_query = nn.Linear(settings.query_dim, settings.att_dim,
            bias=settings.add_bias)

        self.w_out = nn.Linear(settings.att_dim, settings.out_dim, bias=settings.add_bias)

        self.dropout_attn = nn.Dropout(p=settings.dropout)

        self.neg_inf = None

        self.qkv_same_dim = settings.key_dim == settings.query_dim
        self.reset_parameters(settings.add_bias)

    def reset_parameters(self, add_bias):
        """Initialize parameters with Xavier uniform distribution.

        # NOTE: For this initialization, please refer
        https://github.com/pytorch/fairseq/blob/master/fairseq/modules/multihead_attention.py  # pylint: disable=line-too-long

        """
        if self.qkv_same_dim:
            nn.init.xavier_uniform_(self.w_key.weight, gain=1 / math.sqrt(2))
            nn.init.xavier_uniform_(self.w_value.weight, gain=1 / math.sqrt(2))
            nn.init.xavier_uniform_(self.w_query.weight, gain=1 / math.sqrt(2))
        else:
            nn.init.xavier_uniform_(self.w_key.weight)
            nn.init.xavier_uniform_(self.w_value.weight)
            nn.init.xavier_uniform_(self.w_query.weight)
        nn.init.xavier_uniform_(self.w_out.weight)
        if add_bias:
            nn.init.constant_(self.w_key.bias, 0.)
            nn.init.constant_(self.w_value.bias, 0.)
            nn.init.constant_(self.w_query.bias, 0.)
            nn.init.constant_(self.w_out.bias, 0.)

    def forward(self,
                key: torch.Tensor,
                value: torch.Tensor,
                query: torch.Tensor,
                mask: torch.Tensor):
        if self.neg_inf is None:
            self.neg_inf = float(np.finfo(
                torch.tensor(0, dtype=key.dtype).numpy().dtype).min)

        bsize, klen = key.size()[: 2]
        qlen = query.size(1)

        # key: `[N, klen, kdim] -> [N, klen, adim] -> [N, klen, H, adim/H(=hdim)]`
        # value: `[N, klen, vdim] -> [N, klen, adim] -> [N, klen, H, adim/H(=hdim)]`
        # query: `[N, qlen, qdim] -> [N, qlen, adim] -> [N, qlen, H, adim/H(=hdim)]`
        key = self.w_key(key).reshape([bsize, -1, self.num_heads, self.head_dim])
        value = self.w_value(value).reshape([bsize, -1, self.num_heads, self.head_dim])
        query = self.w_query(query).reshape([bsize, -1, self.num_heads, self.head_dim])

        # qk_score: `[N, qlen, H, hdim] x [N, klen, H, hdim] -> [N, qlen, klen, H]`
        qk_score = torch.einsum("bihd,bjhd->bijh", (query, key)) / self.scale

        # Apply mask.
        if mask is not None:
            # `[N, qlen, klen] -> [N, qlen, klen, H]`
            mask = mask.unsqueeze(3).repeat([1, 1, 1, self.num_heads])
            mask_size = (bsize, qlen, klen, self.num_heads)
            assert mask.size() == mask_size, f"{mask.size()}:{mask_size}"
            # Negative infinity should be 0 in softmax.
            qk_score = qk_score.masked_fill_(mask == 0, self.neg_inf)
        # Compute attention weight.
        attw = torch.softmax(qk_score, dim=2)
        attw = self.dropout_attn(attw)

        # cvec: `[N, qlen, klen, H] x [N, qlen, h, hdim] -> [N, qlen, H, hdim]
        # -> [N, qlen, H * hdim]`
        cvec = torch.einsum("bijh,bjhd->bihd", (attw, value))
        cvec = cvec.reshape([bsize, -1, self.num_heads * self.head_dim])
        cvec = self.w_out(cvec)
        # attw: `[N, qlen, klen, H]` -> `[N, H, qlen, klen]`
        attw = attw.permute(0, 3, 1, 2)
        return cvec, attw

# %% [markdown]
# ### Positionwise feed-forward

# %%
class PositionwiseFeedForwardSettings(ConfiguredModel):
    dim_model: int = 64
    dim_pffn: int = 256
    dropout: float = 0.1
    activation: str = Field(default="relu",
        pattern=r"relu|gelu|swish|silu|mish|geluacc|tanhexp")
    add_bias: bool = True

    def build_layer(self):
        return PositionwiseFeedForward(self)

# %%
class PositionwiseFeedForward(nn.Module):
    def __init__(self,
                 settings):
       super().__init__()
       assert isinstance(settings, PositionwiseFeedForwardSettings)

       self.w_1 = nn.Linear(settings.dim_model, settings.dim_pffn,
           bias=settings.add_bias)
       self.w_2 = nn.Linear(settings.dim_pffn, settings.dim_model,
           bias=settings.add_bias)

       self.dropout = nn.Dropout(p=settings.dropout)

       self.activation = select_reluwise_activation(settings.activation)

    def forward(self, feature):
        feature = self.w_1(feature)
        feature = self.activation(feature)
        feature = self.dropout(feature)
        feature = self.w_2(feature)
        return feature

# %% [markdown]
# ### Transformer encoder layer

# %%
class TransformerEncoderLayerSettings(ConfiguredModel):
    dim_model: int = 64
    dim_pffn: int = 256
    activation: str = Field(default="relu",
        pattern=r"relu|gelu|swish|silu|mish|geluacc|tanhexp")
    norm_type_sattn: str = Field(default="layer", pattern=r"layer|batch")
    norm_type_pffn: str = Field(default="layer", pattern=r"layer|batch")
    norm_eps: float = 1e-5
    norm_first: bool = True
    dropout: float = 0.1

    mhsa_settings: MultiheadAttentionSettings = Field(
        default_factory=lambda: MultiheadAttentionSettings())
    pffn_settings: PositionwiseFeedForwardSettings = Field(
        default_factory=lambda: PositionwiseFeedForwardSettings())

    def model_post_init(self, __context):
        # Adjust mhsa_settings.
        self.mhsa_settings.key_dim = self.dim_model
        self.mhsa_settings.query_dim = self.dim_model
        self.mhsa_settings.att_dim = self.dim_model
        self.mhsa_settings.out_dim = self.dim_model
        # Adjust pffn_settings.
        self.pffn_settings.dim_model = self.dim_model
        self.pffn_settings.dim_pffn = self.dim_pffn
        self.pffn_settings.activation = self.activation

        # Propagate.
        self.mhsa_settings.model_post_init(__context)
        self.pffn_settings.model_post_init(__context)

    def build_layer(self):
        if self.norm_first:
            layer = PreNormTransformerEncoderLayer(self)
        else:
            layer = PostNormTransformerEncoderLayer(self)
        return layer

# %%
def create_encoder_mask(src_key_padding_mask,
                        causal_mask):
    if src_key_padding_mask is not None:
        san_mask = make_san_mask(src_key_padding_mask, causal_mask)
    elif causal_mask is not None:
        san_mask = causal_mask
    else:
        san_mask = None
    return san_mask

# %%
class PreNormTransformerEncoderLayer(nn.Module):
    """Pre-normalization structure.

    For the details, please refer
    https://arxiv.org/pdf/2002.04745v1.pdf
    """
    def __init__(self,
                 settings):
        super().__init__()
        assert isinstance(settings, TransformerEncoderLayerSettings)
        assert settings.norm_first is True
        self.settings = settings

        #################################################
        # MHSA.
        #################################################
        self.norm_sattn = create_norm(
            settings.norm_type_sattn, settings.dim_model, settings.norm_eps,
            settings.mhsa_settings.add_bias)
        self.self_attn = settings.mhsa_settings.build_layer()

        #################################################
        # PFFN.
        #################################################
        self.norm_pffn = create_norm(settings.norm_type_pffn, settings.dim_model,
            settings.norm_eps, settings.pffn_settings.add_bias)
        self.pffn = settings.pffn_settings.build_layer()

        self.dropout = nn.Dropout(p=settings.dropout)

        # To store attention weights.
        self.attw = None

    def forward(self,
                feature,
                causal_mask=None,
                src_key_padding_mask=None):
        bsize, qlen = feature.shape[:2]
        san_mask = create_encoder_mask(src_key_padding_mask, causal_mask)

        #################################################
        # MHSA
        #################################################
        # `[N, qlen, dim_model]`
        residual = feature
        feature = apply_norm(self.norm_sattn, feature)
        feature, self.attw = self.self_attn(
            key=feature,
            value=feature,
            query=feature,
            mask=san_mask)
        feature = self.dropout(feature) + residual

        #################################################
        # PFFN
        #################################################
        residual = feature
        # `[N, qlen, dim_model]`
        feature = apply_norm(self.norm_pffn, feature)
        feature = self.pffn(feature)
        feature = self.dropout(feature) + residual

        return feature

# %%
class PostNormTransformerEncoderLayer(nn.Module):
    """Post-normalization structure (Standard).

    For the details, please refer
    https://arxiv.org/pdf/2002.04745v1.pdf
    """
    def __init__(self,
                 settings):
        super().__init__()
        assert isinstance(settings, TransformerEncoderLayerSettings)
        assert settings.norm_first is False
        self.settings = settings

        #################################################
        # MHSA.
        #################################################
        self.self_attn = settings.mhsa_settings.build_layer()
        self.norm_sattn = create_norm(
            settings.norm_type_sattn, settings.dim_model, settings.norm_eps,
            settings.mhsa_settings.add_bias)

        #################################################
        # PFFN.
        #################################################
        self.pffn = settings.pffn_settings.build_layer()
        self.norm_pffn = create_norm(settings.norm_type_pffn, settings.dim_model,
            settings.norm_eps, settings.pffn_settings.add_bias)

        self.dropout = nn.Dropout(p=settings.dropout)

        # To store attention weights.
        self.attw = None

    def forward(self,
                feature,
                causal_mask=None,
                src_key_padding_mask=None):
        bsize, qlen = feature.shape[:2]
        san_mask = create_encoder_mask(src_key_padding_mask, causal_mask)

        #################################################
        # MHSA
        #################################################
        # `[N, qlen, dim_model]`
        residual = feature
        feature, self.attw = self.self_attn(
            key=feature,
            value=feature,
            query=feature,
            mask=san_mask)
        feature = self.dropout(feature) + residual
        feature = apply_norm(self.norm_sattn, feature)

        #################################################
        # PFFN
        #################################################
        residual = feature
        # `[N, qlen, dim_model]`
        feature = self.pffn(feature)
        feature = self.dropout(feature) + residual
        feature = apply_norm(self.norm_pffn, feature)

        return feature

# %% [markdown]
# ### Transformer encoder block

# %%
class TransformerEncoderSettings(ConfiguredModel):
    num_layers: int = 1
    norm_type_tail: str = Field(default="layer", pattern=r"layer|batch")
    norm_eps: float = 1e-5
    add_bias: bool = True
    add_tailnorm: bool = True

    pe_settings: PositionalEncodingSettings = Field(
        default_factory=lambda: PositionalEncodingSettings())

    def build_layer(self, encoder_layer):
        return TransformerEncoder(self, encoder_layer)

# %%
class TransformerEncoder(nn.Module):
    def __init__(self,
                 settings,
                 encoder_layer):
        super().__init__()
        assert isinstance(settings, TransformerEncoderSettings)
        dim_model = settings.pe_settings.dim_model
        assert dim_model == encoder_layer.settings.dim_model
        self.settings = settings

        self.pos_encoder = settings.pe_settings.build_layer()
        self.layers = nn.ModuleList([copy.deepcopy(encoder_layer) for _
            in range(settings.num_layers)])

        # Add LayerNorm at tail position.
        # This is applied only for pre-normalization structure because
        # post-normalization structure includes tail-normalization in encoder
        # layers.
        add_tailnorm0 = settings.add_tailnorm
        add_tailnorm1 = not isinstance(encoder_layer, PostNormTransformerEncoderLayer)
        if add_tailnorm0 and add_tailnorm1:
            self.norm_tail = create_norm(settings.norm_type_tail, dim_model,
                settings.norm_eps, settings.add_bias)
        else:
            self.norm_tail = Identity()

    def forward(self,
                feature,
                causal_mask,
                src_key_padding_mask):
        feature = self.pos_encoder(feature)
        for layer in self.layers:
            feature = layer(feature,
                            causal_mask,
                            src_key_padding_mask)
        feature = apply_norm(self.norm_tail, feature)
        return feature

# %% [markdown]
# ### Transformer ISLR model

# %%
class TransformerEnISLRSettings(ConfiguredModel):
    in_channels: int = 64
    inter_channels: int = 64
    out_channels: int = 64
    activation: str = Field(default="relu",
        pattern=r"relu|gelu|swish|silu|mish|geluacc|tanhexp")
    pooling_type: str = Field(default="none", pattern=r"none|average|max")

    enlayer_settings: TransformerEncoderLayerSettings = Field(
        default_factory=lambda: TransformerEncoderLayerSettings())
    encoder_settings: TransformerEncoderSettings = Field(
        default_factory=lambda: TransformerEncoderSettings())

    head_settings: GPoolRecognitionHeadSettings = Field(
        default_factory=lambda: GPoolRecognitionHeadSettings())

    def model_post_init(self, __context):
        # Adjust enlayer_settings.
        self.enlayer_settings.dim_model = self.inter_channels
        self.enlayer_settings.activation = self.activation

        # Adjust head_settings.
        self.head_settings.in_channels = self.inter_channels
        self.head_settings.out_channels = self.out_channels

        # Propagate.
        self.enlayer_settings.model_post_init(__context)
        self.encoder_settings.model_post_init(__context)
        self.head_settings.model_post_init(__context)

    def build_layer(self, fext_settings=None):
        return TransformerEnISLR(self, fext_settings)

# %%
class TransformerEnISLR(nn.Module):
    def __init__(self,
                 settings,
                 fext_settings=None):
        super().__init__()
        assert isinstance(settings, TransformerEnISLRSettings)
        self.settings = settings
        self.fext_settings = fext_settings

        # Feature extraction.
        self.fext_module = create_fext_module(fext_settings)

        # Transformer-Encoder.
        enlayer = settings.enlayer_settings.build_layer()
        self.tr_encoder = settings.encoder_settings.build_layer(enlayer)

        self.head = settings.head_settings.build_layer()

    def _apply_fext(self,
                    feature):
        for layer in self.fext_module:
            feature = layer(feature)
        return feature

    def forward(self,
                feature,
                feature_causal_mask=None,
                feature_pad_mask=None):
        # Feature extraction.
        feature = self._apply_fext(feature)

        # `[N, C, T] -> [N, T, C]`
        feature = feature.permute([0, 2, 1])

        # Adjust mask size.
        if feature_pad_mask is not None:
            if feature_pad_mask.shape[-1] != feature.shape[1]:
                feature_pad_mask = F.interpolate(
                    feature_pad_mask.unsqueeze(1).float(),
                    feature.shape[1],
                    mode="nearest")
                feature_pad_mask = feature_pad_mask.squeeze(1) > 0.5
                if feature_causal_mask is not None:
                    feature_causal_mask = make_causal_mask(feature_pad_mask)

        feature = self.tr_encoder(
            feature=feature,
            causal_mask=feature_causal_mask,
            src_key_padding_mask=feature_pad_mask)
        if torch.isnan(feature).any():
            raise ValueError()

        # `[N, T, C] -> [N, C, T]`
        logit = self.head(feature.permute([0, 2, 1]), feature_pad_mask)
        if torch.isnan(feature).any():
            raise ValueError()
        return logit

# %% [markdown]
# ## Sanity check

# %%
# Access check.
dataset_dir = Path("dataset_top10")
files = list(dataset_dir.iterdir())
dictionary = [fin for fin in files if ".json" in fin.name][0]
hdf5_files = [fin for fin in files if ".hdf5" in fin.name]

print(dictionary)
print(hdf5_files)
# Out:
# dataset_top10/sign_to_prediction_index_map.json
# [PosixPath('dataset_top10/22343.hdf5'), PosixPath('dataset_top10/25571.hdf5'), PosixPath('dataset_top10/26734.hdf5'), PosixPath('dataset_top10/49445.hdf5'), PosixPath('dataset_top10/2044.hdf5'), PosixPath('dataset_top10/28656.hdf5'), PosixPath('dataset_top10/53618.hdf5'), PosixPath('dataset_top10/62590.hdf5'), PosixPath('dataset_top10/37779.hdf5'), PosixPath('dataset_top10/55372.hdf5'), PosixPath('dataset_top10/18796.hdf5'), PosixPath('dataset_top10/27610.hdf5'), PosixPath('dataset_top10/36257.hdf5'), PosixPath('dataset_top10/16069.hdf5'), PosixPath('dataset_top10/32319.hdf5'), PosixPath('dataset_top10/30680.hdf5'), PosixPath('dataset_top10/34503.hdf5'), PosixPath('dataset_top10/61333.hdf5'), PosixPath('dataset_top10/29302.hdf5'), PosixPath('dataset_top10/4718.hdf5'), PosixPath('dataset_top10/37055.hdf5')]

# %%
# Load dictionary.
with open(dictionary, "r") as fread:
    key2token = json.load(fread)

VOCAB = len(key2token)

# %%
_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
swap_pairs, _ = get_fullbody_swappairs()

trans_select_feature = SelectLandmarksAndFeature(landmarks=use_landmarks, features=use_features)
trans_repnan = ReplaceNan()
trans_norm = PartsBasedNormalization(align_mode="framewise", scale_mode="unique")

trans_hflip = RandomHorizontalFlip(
    apply_ratio=0.5,
    num_joints=len(use_landmarks),
    swap_pairs=swap_pairs,
    flip_center=0.5,
    feature_dim=len(use_features),
    include_conf=False
)
trans_saffine = RandomAffineTransform2D(
    apply_ratio=0.5,
    center_joints=[0, 2],
    target_joints=np.arange(0, len(use_landmarks)),
    trans_range=[-0.1, 0.1],
    scale_range=[1.0/1.5, 1.5],
    rot_range=[-30, 30],
    skew_range=[-30, 30]
)
trans_snoise = RandomNoise(
    apply_ratio=0.5,
    scale_range=[1e-3, 1e-2],
    scale_unit="asis",
    noise_type="uniform",
    target_joints=np.arange(0, len(use_landmarks)),
    feature_dim=len(use_features),
    include_conf=False
)
trans_clip =  RandomClip(
    apply_ratio=0.5,
    clip_range=[0.4, 0.6],
    min_apply_size=10
)
trans_twarp = RandomTimeWarping(
    apply_ratio=0.5,
    scale_range=[0.5, 2.0],
    min_apply_size=10
)
trans_drop = RandomDropParts(apply_ratio=0.5)

pre_transforms = Compose([trans_select_feature,
                          trans_repnan])

train_transforms = Compose([
    trans_hflip,
    trans_saffine,
    trans_snoise,
    trans_norm,
    trans_clip,
    trans_twarp,
    trans_drop,
    ToTensor()
])
val_transforms = Compose([trans_norm, ToTensor()])
test_transforms = Compose([trans_norm, ToTensor()])

# %%
batch_size = 2
feature_shape = (len(use_features), -1, len(use_landmarks))
token_shape = (1,)
merge_fn = partial(merge_padded_batch,
                   feature_shape=feature_shape,
                   token_shape=token_shape,
                   feature_padding_val=0.0,
                   token_padding_val=VOCAB)

dataset = HDF5Dataset(hdf5_files, pre_transforms=pre_transforms, transforms=train_transforms)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=merge_fn)
try:
    data = next(iter(dataloader))
    feature_origin = data["feature"]

    print(feature_origin.shape)
except Exception as inst:
    print(inst)
# Out:
# torch.Size([2, 2, 66, 130])

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
inter_channels = 64
pffn_channels = inter_channels * 2
out_channels = VOCAB

dict_linear_fext = {
    "fext_type": "linear",
    "in_channels": in_channels,
    "out_channels": inter_channels,
    "norm_type": "layer",
    "norm_eps": 1e-05,
    "activation": "relu",
    "add_bias": True,
    "dropout": 0.1,
    "channel_first": True,
    "add_residual": False
}

linear_fext_settings = [LinearFeatureExtractorSettings.model_validate(dict_linear_fext)]

islr_settings = TransformerEnISLRSettings(
    in_channels=inter_channels,
    inter_channels=inter_channels,
    out_channels=out_channels)

# Overwrite.
islr_settings.encoder_settings.num_layers = 2
islr_settings.encoder_settings.pe_settings.dim_model = inter_channels
islr_settings.enlayer_settings.dim_pffn = pffn_channels
islr_settings = TransformerEnISLRSettings.model_validate(islr_settings.model_dump())

model_linear = islr_settings.build_layer(linear_fext_settings)

# Sanity check.
print(model_linear)
logit = model_linear(feature_origin)
print(logit.shape)
# Out:
# TransformerEnISLR(
#   (fext_module): ModuleList(
#     (0): LinearFeatureExtractor(
#       (linear): Linear(in_features=260, out_features=64, bias=True)
#       (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       (activation): ReLU()
#       (dropout): Dropout(p=0.1, inplace=False)
#       (residual): Zero()
#     )
#   )
#   (tr_encoder): TransformerEncoder(
#     (pos_encoder): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-1): 2 x PreNormTransformerEncoderLayer(
#         (norm_sattn): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (self_attn): MultiheadAttention(
#           (w_key): Linear(in_features=64, out_features=64, bias=True)
#           (w_value): Linear(in_features=64, out_features=64, bias=True)
#           (w_query): Linear(in_features=64, out_features=64, bias=True)
#           (w_out): Linear(in_features=64, out_features=64, bias=True)
#           (dropout_attn): Dropout(p=0.1, inplace=False)
#         )
#         (norm_pffn): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (pffn): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=128, bias=True)
#           (w_2): Linear(in_features=128, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (norm_tail): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %%
dict_conv_fext = {
    "fext_type": "cnn1d",
    "in_channels": in_channels,
    "out_channels": inter_channels,
    "kernel_size": 3,
    "stride": 1,
    "norm_type": "batch",
    "norm_eps": 1e-5,
    "activation": "relu",
    "causal": False,
    "add_residual": False,
    "add_bias": True,
    "dropout": 0.1
}

conv_fext_settings = [CNN1DFeatureExtractorSettings.model_validate(dict_conv_fext)]
model_cnn1d = islr_settings.build_layer(conv_fext_settings)

# Sanity check.
print(model_cnn1d)
logit = model_cnn1d(feature_origin)
print(logit.shape)
# Out:
# TransformerEnISLR(
#   (fext_module): ModuleList(
#     (0): CNN1DFeatureExtractor(
#       (conv_module): Sequential(
#         (pconv): Conv1d(260, 64, kernel_size=(1,), stride=(1,))
#         (dconv): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,), groups=64)
#       )
#       (norm): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU()
#       (dropout): Dropout(p=0.1, inplace=False)
#       (residual): Zero()
#     )
#   )
#   (tr_encoder): TransformerEncoder(
#     (pos_encoder): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-1): 2 x PreNormTransformerEncoderLayer(
#         (norm_sattn): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (self_attn): MultiheadAttention(
#           (w_key): Linear(in_features=64, out_features=64, bias=True)
#           (w_value): Linear(in_features=64, out_features=64, bias=True)
#           (w_query): Linear(in_features=64, out_features=64, bias=True)
#           (w_out): Linear(in_features=64, out_features=64, bias=True)
#           (dropout_attn): Dropout(p=0.1, inplace=False)
#         )
#         (norm_pffn): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (pffn): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=128, bias=True)
#           (w_2): Linear(in_features=128, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (norm_tail): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])

# %% [markdown]
# # 5. Train and evaluation

# %% [markdown]
# ## 5.1 Set common parameters.

# %%
# Set common parameters.
batch_size = 32
load_into_ram = True
test_pid = 16069
num_workers = os.cpu_count()
print(f"Using {num_workers} cores for data loading.")
lr = 3e-4
label_smoothing = 0.1

epochs = 50
eval_every_n_epochs = 1
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} for computation.")

train_hdf5files = [fin for fin in hdf5_files if str(test_pid) not in fin.name]
val_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]
test_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]

_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
# Out:
# Using 2 cores for data loading.
# Using cuda for computation.

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(train_hdf5files, pre_transforms=pre_transforms,
    transforms=train_transforms, load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(val_hdf5files, pre_transforms=pre_transforms,
    transforms=val_transforms, load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(test_hdf5files, pre_transforms=pre_transforms,
    transforms=test_transforms, load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)

# %% [markdown]
# ## 5.2 Run training process

# %% [markdown]
# ### Linear feature extraction + Transformer

# %%
model_linear = islr_settings.build_layer(linear_fext_settings)
print(model_linear)

loss_fn = nn.CrossEntropyLoss(reduction="mean", label_smoothing=label_smoothing)
optimizer = torch.optim.Adam(model_linear.parameters(), lr=lr)
# Out:
# TransformerEnISLR(
#   (fext_module): ModuleList(
#     (0): LinearFeatureExtractor(
#       (linear): Linear(in_features=260, out_features=64, bias=True)
#       (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       (activation): ReLU()
#       (dropout): Dropout(p=0.1, inplace=False)
#       (residual): Zero()
#     )
#   )
#   (tr_encoder): TransformerEncoder(
#     (pos_encoder): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-1): 2 x PreNormTransformerEncoderLayer(
#         (norm_sattn): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (self_attn): MultiheadAttention(
#           (w_key): Linear(in_features=64, out_features=64, bias=True)
#           (w_value): Linear(in_features=64, out_features=64, bias=True)
#           (w_query): Linear(in_features=64, out_features=64, bias=True)
#           (w_out): Linear(in_features=64, out_features=64, bias=True)
#           (dropout_attn): Dropout(p=0.1, inplace=False)
#         )
#         (norm_pffn): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (pffn): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=128, bias=True)
#           (w_2): Linear(in_features=128, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (norm_tail): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model_linear.to(device)

train_losses = []
val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_losses = train_loop(train_dataloader, model_linear, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model_linear, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model_linear, device)
        test_accs.append(acc)
train_losses_linear = np.array(train_losses)
val_losses_linear = np.array(val_losses)
test_accs_linear = np.array(test_accs)

print(f"Minimum validation loss:{val_losses_linear.min()} at {np.argmin(val_losses_linear)+1} epoch.")
print(f"Maximum accuracy:{test_accs_linear.max()} at {np.argmax(test_accs_linear)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:4.062360 [    0/ 3881]
# loss:1.856617 [ 3200/ 3881]
# Done. Time:10.713473944999976
# Training performance:
#  Avg loss:2.202826
#
# Start validation.
# Done. Time:0.35118736500001546
# Validation performance:
#  Avg loss:1.894282
#
# Start evaluation.
# Done. Time:1.291084839000007
# Test performance:
#  Accuracy:44.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:1.758469 [    0/ 3881]
# loss:1.506688 [ 3200/ 3881]
# Done. Time:9.923929415000003
# Training performance:
#  Avg loss:1.618217
#
# Start validation.
# Done. Time:0.37117460500002153
# Validation performance:
#  Avg loss:1.436850
#
# Start evaluation.
# Done. Time:1.2719227279999927
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.300851 [    0/ 3881]
# loss:1.534976 [ 3200/ 3881]
# Done. Time:7.874599134999983
# Training performance:
#  Avg loss:1.406976
#
# Start validation.
# Done. Time:0.5469660530000056
# Validation performance:
#  Avg loss:1.354646
#
# Start evaluation.
# Done. Time:1.8039924699999972
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.184041 [    0/ 3881]
# loss:1.210084 [ 3200/ 3881]
# Done. Time:7.222900724999988
# Training performance:
#  Avg loss:1.318350
#
# Start validation.
# Done. Time:0.3511777299999892
# Validation performance:
#  Avg loss:1.177806
#
# Start evaluation.
# Done. Time:1.2425289640000017
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.493953 [    0/ 3881]
# loss:1.029056 [ 3200/ 3881]
# Done. Time:9.691262078999983
# Training performance:
#  Avg loss:1.256943
#
# Start validation.
# Done. Time:0.3600943710000024
# Validation performance:
#  Avg loss:1.131644
#
# Start evaluation.
# Done. Time:1.2488439509999978
# Test performance:
#  Accuracy:75.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:1.210276 [    0/ 3881]
# loss:1.318397 [ 3200/ 3881]
# Done. Time:7.128765176000002
# Training performance:
#  Avg loss:1.200292
#
# Start validation.
# Done. Time:0.5516255720000061
# Validation performance:
#  Avg loss:1.083391
#
# Start evaluation.
# Done. Time:1.6516938560000085
# Test performance:
#  Accuracy:78.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.214184 [    0/ 3881]
# loss:1.217446 [ 3200/ 3881]
# Done. Time:11.560086456999983
# Training performance:
#  Avg loss:1.173000
#
# Start validation.
# Done. Time:0.33382083400002216
# Validation performance:
#  Avg loss:1.106938
#
# Start evaluation.
# Done. Time:1.218012870999985
# Test performance:
#  Accuracy:76.5%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.238900 [    0/ 3881]
# loss:1.244124 [ 3200/ 3881]
# Done. Time:9.880837252999982
# Training performance:
#  Avg loss:1.140924
#
# Start validation.
# Done. Time:0.35159928899997794
# Validation performance:
#  Avg loss:0.965703
#
# Start evaluation.
# Done. Time:1.2246765860000153
# Test performance:
#  Accuracy:83.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.166791 [    0/ 3881]
# loss:1.145250 [ 3200/ 3881]
# Done. Time:7.920185167999989
# Training performance:
#  Avg loss:1.099364
#
# Start validation.
# Done. Time:0.5528314389999878
# Validation performance:
#  Avg loss:0.968117
#
# Start evaluation.
# Done. Time:1.8141727329999924
# Test performance:
#  Accuracy:83.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.033454 [    0/ 3881]
# loss:1.068314 [ 3200/ 3881]
# Done. Time:7.120369722999982
# Training performance:
#  Avg loss:1.085092
#
# Start validation.
# Done. Time:0.3343269909999549
# Validation performance:
#  Avg loss:1.022141
#
# Start evaluation.
# Done. Time:1.2364124939999783
# Test performance:
#  Accuracy:79.5%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:0.914428 [    0/ 3881]
# loss:1.058291 [ 3200/ 3881]
# Done. Time:9.940076513999998
# Training performance:
#  Avg loss:1.071859
#
# Start validation.
# Done. Time:0.33579266899999993
# Validation performance:
#  Avg loss:1.022414
#
# Start evaluation.
# Done. Time:1.2367160239999748
# Test performance:
#  Accuracy:80.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:1.180893 [    0/ 3881]
# loss:0.849792 [ 3200/ 3881]
# Done. Time:7.123966049000046
# Training performance:
#  Avg loss:1.054017
#
# Start validation.
# Done. Time:0.5329276850000042
# Validation performance:
#  Avg loss:0.954958
#
# Start evaluation.
# Done. Time:1.6151162310000018
# Test performance:
#  Accuracy:80.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:0.840922 [    0/ 3881]
# loss:1.146880 [ 3200/ 3881]
# Done. Time:8.510420339999996
# Training performance:
#  Avg loss:1.036692
#
# Start validation.
# Done. Time:0.3639797280000039
# Validation performance:
#  Avg loss:0.919519
#
# Start evaluation.
# Done. Time:1.2320810709999819
# Test performance:
#  Accuracy:84.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:0.952898 [    0/ 3881]
# loss:0.758389 [ 3200/ 3881]
# Done. Time:9.58165705099998
# Training performance:
#  Avg loss:1.024100
#
# Start validation.
# Done. Time:0.4457809270000439
# Validation performance:
#  Avg loss:0.902876
#
# Start evaluation.
# Done. Time:1.2585578530000134
# Test performance:
#  Accuracy:86.0%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:0.870458 [    0/ 3881]
# loss:0.835991 [ 3200/ 3881]
# Done. Time:7.117751004000013
# Training performance:
#  Avg loss:1.019909
#
# Start validation.
# Done. Time:0.34505510299999287
# Validation performance:
#  Avg loss:0.925296
#
# Start evaluation.
# Done. Time:1.262586304000024
# Test performance:
#  Accuracy:84.0%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:0.915362 [    0/ 3881]
# loss:1.210051 [ 3200/ 3881]
# Done. Time:9.507460245999994
# Training performance:
#  Avg loss:1.009069
#
# Start validation.
# Done. Time:0.3468658489999825
# Validation performance:
#  Avg loss:0.972907
#
# Start evaluation.
# Done. Time:1.2224298700000418
# Test performance:
#  Accuracy:79.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:0.994627 [    0/ 3881]
# loss:0.858977 [ 3200/ 3881]
# Done. Time:7.950462196999979
# Training performance:
#  Avg loss:1.003641
#
# Start validation.
# Done. Time:0.535579910000024
# Validation performance:
#  Avg loss:0.880531
#
# Start evaluation.
# Done. Time:1.6646708819999958
# Test performance:
#  Accuracy:85.0%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:0.869911 [    0/ 3881]
# loss:1.156774 [ 3200/ 3881]
# Done. Time:7.078930892000017
# Training performance:
#  Avg loss:1.002600
#
# Start validation.
# Done. Time:0.3412416169999801
# Validation performance:
#  Avg loss:0.894181
#
# Start evaluation.
# Done. Time:1.2231316799999945
# Test performance:
#  Accuracy:84.0%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:0.940120 [    0/ 3881]
# loss:0.921211 [ 3200/ 3881]
# Done. Time:9.79714247999999
# Training performance:
#  Avg loss:0.983732
#
# Start validation.
# Done. Time:0.3439200789999859
# Validation performance:
#  Avg loss:0.838744
#
# Start evaluation.
# Done. Time:1.232883384000047
# Test performance:
#  Accuracy:86.0%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.000402 [    0/ 3881]
# loss:0.966182 [ 3200/ 3881]
# Done. Time:7.513610253000024
# Training performance:
#  Avg loss:0.966646
#
# Start validation.
# Done. Time:0.5250270230000069
# Validation performance:
#  Avg loss:0.832556
#
# Start evaluation.
# Done. Time:1.6921579130000168
# Test performance:
#  Accuracy:87.5%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.116339 [    0/ 3881]
# loss:0.922969 [ 3200/ 3881]
# Done. Time:7.517231046999996
# Training performance:
#  Avg loss:0.977846
#
# Start validation.
# Done. Time:0.35403524299999845
# Validation performance:
#  Avg loss:0.950246
#
# Start evaluation.
# Done. Time:1.2348154910000062
# Test performance:
#  Accuracy:80.5%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:1.090236 [    0/ 3881]
# loss:0.963964 [ 3200/ 3881]
# Done. Time:9.775669740000012
# Training performance:
#  Avg loss:0.965630
#
# Start validation.
# Done. Time:0.34093079100000523
# Validation performance:
#  Avg loss:0.846142
#
# Start evaluation.
# Done. Time:1.2170540119999487
# Test performance:
#  Accuracy:90.0%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:0.869917 [    0/ 3881]
# loss:1.185396 [ 3200/ 3881]
# Done. Time:7.151369835999958
# Training performance:
#  Avg loss:0.945487
#
# Start validation.
# Done. Time:0.576244016999965
# Validation performance:
#  Avg loss:0.844503
#
# Start evaluation.
# Done. Time:1.6208932600000026
# Test performance:
#  Accuracy:86.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.046982 [    0/ 3881]
# loss:1.022611 [ 3200/ 3881]
# Done. Time:8.797628595999981
# Training performance:
#  Avg loss:0.959497
#
# Start validation.
# Done. Time:0.3509723299999905
# Validation performance:
#  Avg loss:0.883453
#
# Start evaluation.
# Done. Time:1.2261760460000346
# Test performance:
#  Accuracy:87.5%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:1.163761 [    0/ 3881]
# loss:0.786957 [ 3200/ 3881]
# Done. Time:9.602114211000014
# Training performance:
#  Avg loss:0.960565
#
# Start validation.
# Done. Time:0.4132516090000422
# Validation performance:
#  Avg loss:0.867389
#
# Start evaluation.
# Done. Time:1.2034345679999774
# Test performance:
#  Accuracy:85.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:0.892644 [    0/ 3881]
# loss:0.998928 [ 3200/ 3881]
# Done. Time:7.0638254480000455
# Training performance:
#  Avg loss:0.948762
#
# Start validation.
# Done. Time:0.34535586200001944
# Validation performance:
#  Avg loss:0.829668
#
# Start evaluation.
# Done. Time:1.2813357719999772
# Test performance:
#  Accuracy:88.0%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.071281 [    0/ 3881]
# loss:0.828474 [ 3200/ 3881]
# Done. Time:9.65711802200002
# Training performance:
#  Avg loss:0.950508
#
# Start validation.
# Done. Time:0.3582772279999631
# Validation performance:
#  Avg loss:0.864637
#
# Start evaluation.
# Done. Time:1.2474786029999905
# Test performance:
#  Accuracy:86.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:1.003174 [    0/ 3881]
# loss:0.954060 [ 3200/ 3881]
# Done. Time:8.143148339999982
# Training performance:
#  Avg loss:0.949413
#
# Start validation.
# Done. Time:0.6478171890000226
# Validation performance:
#  Avg loss:0.853790
#
# Start evaluation.
# Done. Time:1.3873321110000347
# Test performance:
#  Accuracy:84.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.896901 [    0/ 3881]
# loss:0.863084 [ 3200/ 3881]
# Done. Time:7.1135768580000445
# Training performance:
#  Avg loss:0.914509
#
# Start validation.
# Done. Time:0.3405095630000119
# Validation performance:
#  Avg loss:0.824036
#
# Start evaluation.
# Done. Time:1.2056015370000068
# Test performance:
#  Accuracy:88.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.765174 [    0/ 3881]
# loss:0.687438 [ 3200/ 3881]
# Done. Time:9.881842151
# Training performance:
#  Avg loss:0.918689
#
# Start validation.
# Done. Time:0.35450046199997587
# Validation performance:
#  Avg loss:0.814827
#
# Start evaluation.
# Done. Time:1.2244060529999956
# Test performance:
#  Accuracy:89.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.905339 [    0/ 3881]
# loss:1.097071 [ 3200/ 3881]
# Done. Time:7.887600752000026
# Training performance:
#  Avg loss:0.912965
#
# Start validation.
# Done. Time:0.517955986000004
# Validation performance:
#  Avg loss:0.830456
#
# Start evaluation.
# Done. Time:1.774893786000007
# Test performance:
#  Accuracy:87.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.949271 [    0/ 3881]
# loss:1.069284 [ 3200/ 3881]
# Done. Time:7.075205433999997
# Training performance:
#  Avg loss:0.919767
#
# Start validation.
# Done. Time:0.3463774039999521
# Validation performance:
#  Avg loss:0.845518
#
# Start evaluation.
# Done. Time:1.2282760540000481
# Test performance:
#  Accuracy:87.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.901758 [    0/ 3881]
# loss:0.689425 [ 3200/ 3881]
# Done. Time:12.333892583000022
# Training performance:
#  Avg loss:0.915947
#
# Start validation.
# Done. Time:0.3445530010000084
# Validation performance:
#  Avg loss:0.766482
#
# Start evaluation.
# Done. Time:1.2094839200000251
# Test performance:
#  Accuracy:90.0%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.700975 [    0/ 3881]
# loss:1.014072 [ 3200/ 3881]
# Done. Time:7.096732249000013
# Training performance:
#  Avg loss:0.914440
#
# Start validation.
# Done. Time:0.3465345479999655
# Validation performance:
#  Avg loss:0.842163
#
# Start evaluation.
# Done. Time:1.4667324420000227
# Test performance:
#  Accuracy:84.5%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:1.039140 [    0/ 3881]
# loss:0.884660 [ 3200/ 3881]
# Done. Time:9.20712045199997
# Training performance:
#  Avg loss:0.914029
#
# Start validation.
# Done. Time:0.35203068300006635
# Validation performance:
#  Avg loss:0.843493
#
# Start evaluation.
# Done. Time:1.2168722469999693
# Test performance:
#  Accuracy:90.0%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.878728 [    0/ 3881]
# loss:0.879807 [ 3200/ 3881]
# Done. Time:8.827910991000067
# Training performance:
#  Avg loss:0.912827
#
# Start validation.
# Done. Time:0.4511789120000458
# Validation performance:
#  Avg loss:0.792120
#
# Start evaluation.
# Done. Time:1.2358979560000307
# Test performance:
#  Accuracy:89.5%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.894978 [    0/ 3881]
# loss:1.016743 [ 3200/ 3881]
# Done. Time:6.98694189899993
# Training performance:
#  Avg loss:0.897609
#
# Start validation.
# Done. Time:0.3425052219999998
# Validation performance:
#  Avg loss:0.813874
#
# Start evaluation.
# Done. Time:1.2118400040000097
# Test performance:
#  Accuracy:90.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.957287 [    0/ 3881]
# loss:0.744190 [ 3200/ 3881]
# Done. Time:9.728210756000067
# Training performance:
#  Avg loss:0.900428
#
# Start validation.
# Done. Time:0.3561757209999996
# Validation performance:
#  Avg loss:0.779642
#
# Start evaluation.
# Done. Time:1.230883695999978
# Test performance:
#  Accuracy:88.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.843640 [    0/ 3881]
# loss:1.067515 [ 3200/ 3881]
# Done. Time:8.254838457999995
# Training performance:
#  Avg loss:0.907535
#
# Start validation.
# Done. Time:0.5400448110000298
# Validation performance:
#  Avg loss:0.819352
#
# Start evaluation.
# Done. Time:1.5002386300000126
# Test performance:
#  Accuracy:86.5%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.956398 [    0/ 3881]
# loss:0.813983 [ 3200/ 3881]
# Done. Time:6.931703625999944
# Training performance:
#  Avg loss:0.896637
#
# Start validation.
# Done. Time:0.3515998060000811
# Validation performance:
#  Avg loss:0.816453
#
# Start evaluation.
# Done. Time:1.2323700110000573
# Test performance:
#  Accuracy:87.0%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.916422 [    0/ 3881]
# loss:0.793701 [ 3200/ 3881]
# Done. Time:9.580344930000024
# Training performance:
#  Avg loss:0.880357
#
# Start validation.
# Done. Time:0.33397000599995863
# Validation performance:
#  Avg loss:0.760862
#
# Start evaluation.
# Done. Time:1.2377439990000312
# Test performance:
#  Accuracy:91.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.750155 [    0/ 3881]
# loss:1.259215 [ 3200/ 3881]
# Done. Time:7.761574290999988
# Training performance:
#  Avg loss:0.910077
#
# Start validation.
# Done. Time:0.556608100999938
# Validation performance:
#  Avg loss:0.909631
#
# Start evaluation.
# Done. Time:1.762247904999981
# Test performance:
#  Accuracy:84.0%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.820544 [    0/ 3881]
# loss:0.968400 [ 3200/ 3881]
# Done. Time:7.183188201000007
# Training performance:
#  Avg loss:0.897589
#
# Start validation.
# Done. Time:0.3469895480000105
# Validation performance:
#  Avg loss:0.829495
#
# Start evaluation.
# Done. Time:1.2342846060000738
# Test performance:
#  Accuracy:85.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:1.018058 [    0/ 3881]
# loss:1.087309 [ 3200/ 3881]
# Done. Time:9.716657299000076
# Training performance:
#  Avg loss:0.878071
#
# Start validation.
# Done. Time:0.33932256499997493
# Validation performance:
#  Avg loss:0.805866
#
# Start evaluation.
# Done. Time:1.228239283999983
# Test performance:
#  Accuracy:86.5%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.820508 [    0/ 3881]
# loss:0.931328 [ 3200/ 3881]
# Done. Time:7.204181225999946
# Training performance:
#  Avg loss:0.887039
#
# Start validation.
# Done. Time:0.5458141649999106
# Validation performance:
#  Avg loss:0.805781
#
# Start evaluation.
# Done. Time:1.62722432999999
# Test performance:
#  Accuracy:87.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.841275 [    0/ 3881]
# loss:0.849768 [ 3200/ 3881]
# Done. Time:8.576709112999993
# Training performance:
#  Avg loss:0.889765
#
# Start validation.
# Done. Time:0.3520415250000042
# Validation performance:
#  Avg loss:0.871610
#
# Start evaluation.
# Done. Time:1.2183294420000266
# Test performance:
#  Accuracy:85.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.826132 [    0/ 3881]
# loss:0.934883 [ 3200/ 3881]
# Done. Time:9.582750587999953
# Training performance:
#  Avg loss:0.891094
#
# Start validation.
# Done. Time:0.35623451099991144
# Validation performance:
#  Avg loss:0.791768
#
# Start evaluation.
# Done. Time:1.2187643720000096
# Test performance:
#  Accuracy:88.5%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.648862 [    0/ 3881]
# loss:0.752532 [ 3200/ 3881]
# Done. Time:7.087029514000051
# Training performance:
#  Avg loss:0.864895
#
# Start validation.
# Done. Time:0.34172984399992856
# Validation performance:
#  Avg loss:0.861921
#
# Start evaluation.
# Done. Time:1.3976417050000691
# Test performance:
#  Accuracy:85.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.922401 [    0/ 3881]
# loss:0.766619 [ 3200/ 3881]
# Done. Time:9.338074615999972
# Training performance:
#  Avg loss:0.872550
#
# Start validation.
# Done. Time:0.35239393399990604
# Validation performance:
#  Avg loss:0.795492
#
# Start evaluation.
# Done. Time:1.237545694000005
# Test performance:
#  Accuracy:89.5%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.997563 [    0/ 3881]
# loss:0.832069 [ 3200/ 3881]
# Done. Time:8.466729444000066
# Training performance:
#  Avg loss:0.879011
#
# Start validation.
# Done. Time:0.6205663220000588
# Validation performance:
#  Avg loss:0.773825
#
# Start evaluation.
# Done. Time:1.381203117000041
# Test performance:
#  Accuracy:89.0%
# Minimum validation loss:0.7608617459024701 at 41 epoch.
# Maximum accuracy:91.0 at 41 epoch.

# %% [markdown]
# ### Temporal CNN feature extraction + Transformer

# %%
model_cnn1d = islr_settings.build_layer(conv_fext_settings)
print(model_cnn1d)

loss_fn = nn.CrossEntropyLoss(reduction="mean", label_smoothing=label_smoothing)
optimizer = torch.optim.Adam(model_cnn1d.parameters(), lr=lr)
# Out:
# TransformerEnISLR(
#   (fext_module): ModuleList(
#     (0): CNN1DFeatureExtractor(
#       (conv_module): Sequential(
#         (pconv): Conv1d(260, 64, kernel_size=(1,), stride=(1,))
#         (dconv): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,), groups=64)
#       )
#       (norm): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU()
#       (dropout): Dropout(p=0.1, inplace=False)
#       (residual): Zero()
#     )
#   )
#   (tr_encoder): TransformerEncoder(
#     (pos_encoder): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-1): 2 x PreNormTransformerEncoderLayer(
#         (norm_sattn): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (self_attn): MultiheadAttention(
#           (w_key): Linear(in_features=64, out_features=64, bias=True)
#           (w_value): Linear(in_features=64, out_features=64, bias=True)
#           (w_query): Linear(in_features=64, out_features=64, bias=True)
#           (w_out): Linear(in_features=64, out_features=64, bias=True)
#           (dropout_attn): Dropout(p=0.1, inplace=False)
#         )
#         (norm_pffn): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (pffn): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=128, bias=True)
#           (w_2): Linear(in_features=128, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (norm_tail): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model_cnn1d.to(device)

train_losses = []
val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_losses = train_loop(train_dataloader, model_cnn1d, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model_cnn1d, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model_cnn1d, device)
        test_accs.append(acc)
train_losses_cnn1d = np.array(train_losses)
val_losses_cnn1d = np.array(val_losses)
test_accs_cnn1d = np.array(test_accs)

print(f"Minimum validation loss:{val_losses_cnn1d.min()} at {np.argmin(val_losses_cnn1d)+1} epoch.")
print(f"Maximum accuracy:{test_accs_cnn1d.max()} at {np.argmax(test_accs_cnn1d)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:3.344191 [    0/ 3881]
# loss:1.897593 [ 3200/ 3881]
# Done. Time:8.151687570000036
# Training performance:
#  Avg loss:2.152220
#
# Start validation.
# Done. Time:0.3615144530000407
# Validation performance:
#  Avg loss:1.717918
#
# Start evaluation.
# Done. Time:1.6748401469999408
# Test performance:
#  Accuracy:44.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:1.827535 [    0/ 3881]
# loss:1.669457 [ 3200/ 3881]
# Done. Time:9.333325417999959
# Training performance:
#  Avg loss:1.675808
#
# Start validation.
# Done. Time:0.37905387499995413
# Validation performance:
#  Avg loss:1.585341
#
# Start evaluation.
# Done. Time:1.2638963049998893
# Test performance:
#  Accuracy:64.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.403587 [    0/ 3881]
# loss:1.379744 [ 3200/ 3881]
# Done. Time:9.139851852999982
# Training performance:
#  Avg loss:1.475605
#
# Start validation.
# Done. Time:0.4759826490000023
# Validation performance:
#  Avg loss:1.251244
#
# Start evaluation.
# Done. Time:1.2904554340000232
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.255857 [    0/ 3881]
# loss:1.394558 [ 3200/ 3881]
# Done. Time:7.222879329999955
# Training performance:
#  Avg loss:1.375365
#
# Start validation.
# Done. Time:0.36344247600004564
# Validation performance:
#  Avg loss:1.248149
#
# Start evaluation.
# Done. Time:1.4407079160000649
# Test performance:
#  Accuracy:70.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.354402 [    0/ 3881]
# loss:1.379046 [ 3200/ 3881]
# Done. Time:9.663396366000029
# Training performance:
#  Avg loss:1.304837
#
# Start validation.
# Done. Time:0.3902272269999685
# Validation performance:
#  Avg loss:1.180133
#
# Start evaluation.
# Done. Time:1.2702140160000681
# Test performance:
#  Accuracy:69.0%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:0.964321 [    0/ 3881]
# loss:1.333684 [ 3200/ 3881]
# Done. Time:8.621924352000065
# Training performance:
#  Avg loss:1.247272
#
# Start validation.
# Done. Time:0.46196770300002754
# Validation performance:
#  Avg loss:1.116431
#
# Start evaluation.
# Done. Time:1.2886990989999276
# Test performance:
#  Accuracy:75.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:1.078892 [    0/ 3881]
# loss:1.076872 [ 3200/ 3881]
# Done. Time:7.256079751000016
# Training performance:
#  Avg loss:1.217343
#
# Start validation.
# Done. Time:0.3684241779999411
# Validation performance:
#  Avg loss:1.189398
#
# Start evaluation.
# Done. Time:1.530129259999967
# Test performance:
#  Accuracy:68.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:1.100653 [    0/ 3881]
# loss:1.036881 [ 3200/ 3881]
# Done. Time:12.235453021000012
# Training performance:
#  Avg loss:1.192501
#
# Start validation.
# Done. Time:0.36723230699999476
# Validation performance:
#  Avg loss:1.100515
#
# Start evaluation.
# Done. Time:1.2564558429999124
# Test performance:
#  Accuracy:79.5%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:1.069287 [    0/ 3881]
# loss:1.032437 [ 3200/ 3881]
# Done. Time:9.647522864000052
# Training performance:
#  Avg loss:1.168522
#
# Start validation.
# Done. Time:0.36008575500000006
# Validation performance:
#  Avg loss:1.097444
#
# Start evaluation.
# Done. Time:1.266032755000083
# Test performance:
#  Accuracy:76.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:1.209870 [    0/ 3881]
# loss:1.251976 [ 3200/ 3881]
# Done. Time:7.041170068999918
# Training performance:
#  Avg loss:1.144859
#
# Start validation.
# Done. Time:0.42314323599998716
# Validation performance:
#  Avg loss:1.039136
#
# Start evaluation.
# Done. Time:1.6490083800000548
# Test performance:
#  Accuracy:80.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:1.035326 [    0/ 3881]
# loss:0.847973 [ 3200/ 3881]
# Done. Time:9.033589068000083
# Training performance:
#  Avg loss:1.104129
#
# Start validation.
# Done. Time:0.3574241210000082
# Validation performance:
#  Avg loss:1.075508
#
# Start evaluation.
# Done. Time:1.3097984730000007
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:0.952926 [    0/ 3881]
# loss:1.186804 [ 3200/ 3881]
# Done. Time:9.584500160999937
# Training performance:
#  Avg loss:1.106938
#
# Start validation.
# Done. Time:0.46928911399993467
# Validation performance:
#  Avg loss:1.013891
#
# Start evaluation.
# Done. Time:1.4045133339999438
# Test performance:
#  Accuracy:80.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:1.158020 [    0/ 3881]
# loss:1.213346 [ 3200/ 3881]
# Done. Time:7.090218956999934
# Training performance:
#  Avg loss:1.079716
#
# Start validation.
# Done. Time:0.39233174399998916
# Validation performance:
#  Avg loss:0.982423
#
# Start evaluation.
# Done. Time:1.4630038220000188
# Test performance:
#  Accuracy:83.0%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:1.288248 [    0/ 3881]
# loss:1.009177 [ 3200/ 3881]
# Done. Time:9.611177805000011
# Training performance:
#  Avg loss:1.078627
#
# Start validation.
# Done. Time:0.3706271519999973
# Validation performance:
#  Avg loss:0.935419
#
# Start evaluation.
# Done. Time:1.2837716269999646
# Test performance:
#  Accuracy:83.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:0.847894 [    0/ 3881]
# loss:1.048023 [ 3200/ 3881]
# Done. Time:8.810908458999961
# Training performance:
#  Avg loss:1.055146
#
# Start validation.
# Done. Time:0.5452647659999457
# Validation performance:
#  Avg loss:0.969728
#
# Start evaluation.
# Done. Time:1.2802485150000393
# Test performance:
#  Accuracy:81.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:1.148086 [    0/ 3881]
# loss:0.835601 [ 3200/ 3881]
# Done. Time:7.272294263000049
# Training performance:
#  Avg loss:1.045766
#
# Start validation.
# Done. Time:0.3824373499999183
# Validation performance:
#  Avg loss:0.986190
#
# Start evaluation.
# Done. Time:1.4599391510000714
# Test performance:
#  Accuracy:82.0%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:0.804161 [    0/ 3881]
# loss:1.104647 [ 3200/ 3881]
# Done. Time:9.700477016999912
# Training performance:
#  Avg loss:1.024426
#
# Start validation.
# Done. Time:0.38723156999992625
# Validation performance:
#  Avg loss:0.996380
#
# Start evaluation.
# Done. Time:1.3012153509999962
# Test performance:
#  Accuracy:79.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:1.152409 [    0/ 3881]
# loss:0.995675 [ 3200/ 3881]
# Done. Time:8.827956191999988
# Training performance:
#  Avg loss:1.028600
#
# Start validation.
# Done. Time:0.555261832000042
# Validation performance:
#  Avg loss:0.923835
#
# Start evaluation.
# Done. Time:1.2891110240000216
# Test performance:
#  Accuracy:83.0%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:1.199407 [    0/ 3881]
# loss:1.168649 [ 3200/ 3881]
# Done. Time:7.104400639999994
# Training performance:
#  Avg loss:1.014108
#
# Start validation.
# Done. Time:0.36925672899997153
# Validation performance:
#  Avg loss:0.904781
#
# Start evaluation.
# Done. Time:1.3721670630000062
# Test performance:
#  Accuracy:86.0%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:1.018526 [    0/ 3881]
# loss:0.891836 [ 3200/ 3881]
# Done. Time:9.81310332399994
# Training performance:
#  Avg loss:1.018148
#
# Start validation.
# Done. Time:0.36787962000005336
# Validation performance:
#  Avg loss:0.922093
#
# Start evaluation.
# Done. Time:1.268135636000011
# Test performance:
#  Accuracy:84.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:1.035252 [    0/ 3881]
# loss:1.165302 [ 3200/ 3881]
# Done. Time:8.837396457000068
# Training performance:
#  Avg loss:1.014810
#
# Start validation.
# Done. Time:0.5352084900000591
# Validation performance:
#  Avg loss:0.914759
#
# Start evaluation.
# Done. Time:1.2970731259999866
# Test performance:
#  Accuracy:84.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:0.805054 [    0/ 3881]
# loss:0.937048 [ 3200/ 3881]
# Done. Time:7.231997988999979
# Training performance:
#  Avg loss:0.991584
#
# Start validation.
# Done. Time:0.3773709019999387
# Validation performance:
#  Avg loss:0.937094
#
# Start evaluation.
# Done. Time:1.4187310080000088
# Test performance:
#  Accuracy:83.0%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:1.013560 [    0/ 3881]
# loss:1.255062 [ 3200/ 3881]
# Done. Time:9.756814063999968
# Training performance:
#  Avg loss:0.999259
#
# Start validation.
# Done. Time:0.36474267899995994
# Validation performance:
#  Avg loss:0.988851
#
# Start evaluation.
# Done. Time:1.2512161949999836
# Test performance:
#  Accuracy:81.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:1.114789 [    0/ 3881]
# loss:1.126825 [ 3200/ 3881]
# Done. Time:8.96794858599992
# Training performance:
#  Avg loss:0.993594
#
# Start validation.
# Done. Time:0.5071257029999288
# Validation performance:
#  Avg loss:0.870545
#
# Start evaluation.
# Done. Time:1.2847823130000506
# Test performance:
#  Accuracy:87.5%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:0.945831 [    0/ 3881]
# loss:0.862851 [ 3200/ 3881]
# Done. Time:7.030364960999918
# Training performance:
#  Avg loss:0.982941
#
# Start validation.
# Done. Time:0.37894772799995735
# Validation performance:
#  Avg loss:0.869319
#
# Start evaluation.
# Done. Time:1.3603119320000587
# Test performance:
#  Accuracy:85.0%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:1.066639 [    0/ 3881]
# loss:0.816654 [ 3200/ 3881]
# Done. Time:9.624705376999941
# Training performance:
#  Avg loss:0.978355
#
# Start validation.
# Done. Time:0.3555310169999757
# Validation performance:
#  Avg loss:0.919762
#
# Start evaluation.
# Done. Time:1.3101595959999486
# Test performance:
#  Accuracy:83.0%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:1.095552 [    0/ 3881]
# loss:1.069901 [ 3200/ 3881]
# Done. Time:8.879537116000051
# Training performance:
#  Avg loss:0.961215
#
# Start validation.
# Done. Time:0.5410926130000462
# Validation performance:
#  Avg loss:0.892472
#
# Start evaluation.
# Done. Time:1.2715467430000444
# Test performance:
#  Accuracy:84.0%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.901925 [    0/ 3881]
# loss:1.062674 [ 3200/ 3881]
# Done. Time:7.075582678999922
# Training performance:
#  Avg loss:0.957099
#
# Start validation.
# Done. Time:0.37024974700000257
# Validation performance:
#  Avg loss:0.865215
#
# Start evaluation.
# Done. Time:1.3281978569999637
# Test performance:
#  Accuracy:84.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.871639 [    0/ 3881]
# loss:1.070277 [ 3200/ 3881]
# Done. Time:9.848007016999986
# Training performance:
#  Avg loss:0.963301
#
# Start validation.
# Done. Time:0.37852246500006004
# Validation performance:
#  Avg loss:0.918071
#
# Start evaluation.
# Done. Time:1.2891272800000024
# Test performance:
#  Accuracy:84.0%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.765797 [    0/ 3881]
# loss:0.836870 [ 3200/ 3881]
# Done. Time:9.251707617999955
# Training performance:
#  Avg loss:0.955371
#
# Start validation.
# Done. Time:0.5025439180000149
# Validation performance:
#  Avg loss:0.873052
#
# Start evaluation.
# Done. Time:1.3027459730000146
# Test performance:
#  Accuracy:86.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.931215 [    0/ 3881]
# loss:1.152992 [ 3200/ 3881]
# Done. Time:7.2338077269999985
# Training performance:
#  Avg loss:0.953674
#
# Start validation.
# Done. Time:0.3670775150000054
# Validation performance:
#  Avg loss:0.870334
#
# Start evaluation.
# Done. Time:1.4448998800000936
# Test performance:
#  Accuracy:85.5%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:1.176852 [    0/ 3881]
# loss:0.824995 [ 3200/ 3881]
# Done. Time:9.55278380499999
# Training performance:
#  Avg loss:0.952088
#
# Start validation.
# Done. Time:0.3689379810000446
# Validation performance:
#  Avg loss:0.853571
#
# Start evaluation.
# Done. Time:1.2837752519999412
# Test performance:
#  Accuracy:88.0%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.843259 [    0/ 3881]
# loss:0.884145 [ 3200/ 3881]
# Done. Time:9.627508605999992
# Training performance:
#  Avg loss:0.941038
#
# Start validation.
# Done. Time:0.7059749449999799
# Validation performance:
#  Avg loss:0.919617
#
# Start evaluation.
# Done. Time:2.0096843659999877
# Test performance:
#  Accuracy:82.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.872039 [    0/ 3881]
# loss:1.187852 [ 3200/ 3881]
# Done. Time:7.253219418999947
# Training performance:
#  Avg loss:0.923020
#
# Start validation.
# Done. Time:0.36565360299994154
# Validation performance:
#  Avg loss:0.896515
#
# Start evaluation.
# Done. Time:1.4417182959999764
# Test performance:
#  Accuracy:86.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.861971 [    0/ 3881]
# loss:1.153495 [ 3200/ 3881]
# Done. Time:9.656506554000089
# Training performance:
#  Avg loss:0.921928
#
# Start validation.
# Done. Time:0.37244851100012966
# Validation performance:
#  Avg loss:0.845890
#
# Start evaluation.
# Done. Time:1.326254032999941
# Test performance:
#  Accuracy:88.0%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.791872 [    0/ 3881]
# loss:0.982373 [ 3200/ 3881]
# Done. Time:8.851882486000022
# Training performance:
#  Avg loss:0.928199
#
# Start validation.
# Done. Time:0.5263247039999897
# Validation performance:
#  Avg loss:0.850331
#
# Start evaluation.
# Done. Time:1.3228218239999023
# Test performance:
#  Accuracy:86.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:1.097237 [    0/ 3881]
# loss:0.755552 [ 3200/ 3881]
# Done. Time:7.086696546999974
# Training performance:
#  Avg loss:0.936229
#
# Start validation.
# Done. Time:0.36422196100011206
# Validation performance:
#  Avg loss:0.839377
#
# Start evaluation.
# Done. Time:1.3683962529999008
# Test performance:
#  Accuracy:87.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.830762 [    0/ 3881]
# loss:1.024704 [ 3200/ 3881]
# Done. Time:9.710086500999978
# Training performance:
#  Avg loss:0.913479
#
# Start validation.
# Done. Time:0.38934206399994764
# Validation performance:
#  Avg loss:0.851977
#
# Start evaluation.
# Done. Time:1.3279402129999198
# Test performance:
#  Accuracy:83.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:1.026169 [    0/ 3881]
# loss:0.946059 [ 3200/ 3881]
# Done. Time:8.314639980000038
# Training performance:
#  Avg loss:0.911569
#
# Start validation.
# Done. Time:0.660704603999875
# Validation performance:
#  Avg loss:0.856980
#
# Start evaluation.
# Done. Time:1.375980686000048
# Test performance:
#  Accuracy:85.5%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.789659 [    0/ 3881]
# loss:1.171910 [ 3200/ 3881]
# Done. Time:7.254127443999778
# Training performance:
#  Avg loss:0.926570
#
# Start validation.
# Done. Time:0.3723661050000828
# Validation performance:
#  Avg loss:0.825806
#
# Start evaluation.
# Done. Time:1.3175579270000526
# Test performance:
#  Accuracy:87.0%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.984548 [    0/ 3881]
# loss:0.906422 [ 3200/ 3881]
# Done. Time:10.078182577999996
# Training performance:
#  Avg loss:0.917091
#
# Start validation.
# Done. Time:0.3831640040000366
# Validation performance:
#  Avg loss:0.850806
#
# Start evaluation.
# Done. Time:1.294232546000103
# Test performance:
#  Accuracy:85.5%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:1.147115 [    0/ 3881]
# loss:0.826339 [ 3200/ 3881]
# Done. Time:8.29545542599999
# Training performance:
#  Avg loss:0.905454
#
# Start validation.
# Done. Time:0.6043300139999701
# Validation performance:
#  Avg loss:0.880853
#
# Start evaluation.
# Done. Time:1.3577242119999937
# Test performance:
#  Accuracy:86.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.847663 [    0/ 3881]
# loss:0.801015 [ 3200/ 3881]
# Done. Time:7.211042152000118
# Training performance:
#  Avg loss:0.912316
#
# Start validation.
# Done. Time:0.3588808340000469
# Validation performance:
#  Avg loss:0.821177
#
# Start evaluation.
# Done. Time:1.2984707040000103
# Test performance:
#  Accuracy:88.5%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.768476 [    0/ 3881]
# loss:0.910830 [ 3200/ 3881]
# Done. Time:9.937547461000122
# Training performance:
#  Avg loss:0.907633
#
# Start validation.
# Done. Time:0.38148467399992114
# Validation performance:
#  Avg loss:0.874312
#
# Start evaluation.
# Done. Time:1.289158931999964
# Test performance:
#  Accuracy:86.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.719944 [    0/ 3881]
# loss:0.774893 [ 3200/ 3881]
# Done. Time:8.810984273000031
# Training performance:
#  Avg loss:0.900370
#
# Start validation.
# Done. Time:0.5752964119999433
# Validation performance:
#  Avg loss:0.856502
#
# Start evaluation.
# Done. Time:1.383940111000129
# Test performance:
#  Accuracy:86.0%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.959102 [    0/ 3881]
# loss:0.984213 [ 3200/ 3881]
# Done. Time:7.320172650000131
# Training performance:
#  Avg loss:0.897026
#
# Start validation.
# Done. Time:0.40339446699999826
# Validation performance:
#  Avg loss:0.858925
#
# Start evaluation.
# Done. Time:1.5803823899998406
# Test performance:
#  Accuracy:84.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:1.111325 [    0/ 3881]
# loss:0.721006 [ 3200/ 3881]
# Done. Time:9.75279019200002
# Training performance:
#  Avg loss:0.902822
#
# Start validation.
# Done. Time:0.3779634410000199
# Validation performance:
#  Avg loss:0.862263
#
# Start evaluation.
# Done. Time:1.3501878929998838
# Test performance:
#  Accuracy:84.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:1.107619 [    0/ 3881]
# loss:0.926974 [ 3200/ 3881]
# Done. Time:9.116631690999839
# Training performance:
#  Avg loss:0.896141
#
# Start validation.
# Done. Time:0.4889282680001088
# Validation performance:
#  Avg loss:0.854258
#
# Start evaluation.
# Done. Time:1.2905742919999739
# Test performance:
#  Accuracy:88.0%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.978006 [    0/ 3881]
# loss:0.793047 [ 3200/ 3881]
# Done. Time:7.0526763689999825
# Training performance:
#  Avg loss:0.887449
#
# Start validation.
# Done. Time:0.36405215800004953
# Validation performance:
#  Avg loss:0.840483
#
# Start evaluation.
# Done. Time:1.3736705850001272
# Test performance:
#  Accuracy:85.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.819880 [    0/ 3881]
# loss:0.834647 [ 3200/ 3881]
# Done. Time:9.668498794000016
# Training performance:
#  Avg loss:0.879742
#
# Start validation.
# Done. Time:0.37793765500009613
# Validation performance:
#  Avg loss:0.882479
#
# Start evaluation.
# Done. Time:1.2778452180000386
# Test performance:
#  Accuracy:85.0%
# Minimum validation loss:0.8211765544755119 at 43 epoch.
# Maximum accuracy:88.5 at 43 epoch.

# %% [markdown]
# ### Plort result
# #### Recognition performance

# %%
import matplotlib.pyplot as plt

plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(val_losses_linear)+1)
plt.plot(xs, val_losses_linear, label="Linear + Transformer", marker=".")
plt.plot(xs, val_losses_cnn1d, label="CNN1D + Transformer", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.ylim([0.0, 2.5])
plt.legend()
plt.show()

# %%
plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(test_accs_linear)+1)
plt.plot(xs, test_accs_linear, label="Linear + Transformer", marker=".")
plt.plot(xs, test_accs_cnn1d, label="CNN1D + Transformer", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.ylim([0.0, 100.0])
plt.legend()
plt.show()
