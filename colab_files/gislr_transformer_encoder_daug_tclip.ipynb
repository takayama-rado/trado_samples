# %% [markdown]
# <a href="https://colab.research.google.com/github/takayama-rado/trado_samples/blob/main/colab_files/gislr_transformer_encoder_daug_tclip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Download dataset and modules

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Copy to local.
# !cp drive/MyDrive/Datasets/gislr_dataset_top10.zip gislr_top10.zip

# %%
# !unzip -o gislr_top10.zip
# Out:
# Archive:  gislr_top10.zip
#    creating: dataset_top10/
#   inflating: dataset_top10/16069.hdf5
#   inflating: dataset_top10/18796.hdf5
#   inflating: dataset_top10/2044.hdf5
#   inflating: dataset_top10/22343.hdf5
#   inflating: dataset_top10/25571.hdf5
#   inflating: dataset_top10/26734.hdf5
#   inflating: dataset_top10/27610.hdf5
#   inflating: dataset_top10/28656.hdf5
#   inflating: dataset_top10/29302.hdf5
#   inflating: dataset_top10/30680.hdf5
#   inflating: dataset_top10/32319.hdf5
#   inflating: dataset_top10/34503.hdf5
#   inflating: dataset_top10/36257.hdf5
#   inflating: dataset_top10/37055.hdf5
#   inflating: dataset_top10/37779.hdf5
#   inflating: dataset_top10/4718.hdf5
#   inflating: dataset_top10/49445.hdf5
#   inflating: dataset_top10/53618.hdf5
#   inflating: dataset_top10/55372.hdf5
#   inflating: dataset_top10/61333.hdf5
#   inflating: dataset_top10/62590.hdf5
#   inflating: dataset_top10/LICENSE.txt
#   inflating: dataset_top10/sign_to_prediction_index_map.json

# %%
# !ls dataset_top10
# Out:
# 16069.hdf5  25571.hdf5	29302.hdf5  36257.hdf5	49445.hdf5  62590.hdf5
# 18796.hdf5  26734.hdf5	30680.hdf5  37055.hdf5	53618.hdf5  LICENSE.txt
# 2044.hdf5   27610.hdf5	32319.hdf5  37779.hdf5	55372.hdf5  sign_to_prediction_index_map.json
# 22343.hdf5  28656.hdf5	34503.hdf5  4718.hdf5	61333.hdf5

# %%
# !cat dataset_top10/sign_to_prediction_index_map.json
# Out:
# {
#     "listen": 0,
#     "look": 1,
#     "shhh": 2,
#     "donkey": 3,
#     "mouse": 4,
#     "duck": 5,
#     "uncle": 6,
#     "hear": 7,
#     "pretend": 8,
#     "cow": 9
# }

# %%
# !cat dataset_top10/LICENSE.txt
# Out:
# The dataset provided by Natsuki Takayama (Takayama Research and Development Office) is licensed under CC-BY 4.0.
# Author: Copyright 2024 Natsuki Takayama
# Title: GISLR Top 10 dataset
# Original licenser: Deaf Professional Arts Network and the Georgia Institute of Technology
# Modification
# - Extract 10 most frequent words.
# - Packaged into HDF5 format.

# %%
import h5py
with h5py.File("dataset_top10/16069.hdf5", "r") as fread:
    keys = list(fread.keys())
    print(keys)
    group = fread[keys[0]]
    print(group.keys())
    feature = group["feature"][:]
    token = group["token"][:]
    print(feature.shape)
    print(token)
# Out:
# ['1109479272', '11121526', '1120349077', '1125456612', '1159046211', '1169128497', '1186032553', '1223803476', '1259708636', '1281972067', '129232566', '1334702305', '1340979012', '1352964057', '1370052047', '1383455381', '1431148933', '1435203624', '1437919781', '1458770030', '1462881097', '1469867050', '1474050058', '147607644', '1513539919', '1520635928', '1524297234', '153676122', '1537751003', '1542212461', '1551759770', '158232956', '1585855916', '1632709119', '1638742455', '1696757219', '177479476', '1779635114', '1791684792', '1801566440', '1831167282', '1867385690', '1880570146', '1901587887', '1910121429', '1919659282', '192873038', '1935012113', '1949620203', '195098847', '1983552660', '1989475963', '1998715062', '2007709802', '2036010239', '2036360025', '2046296211', '2082116372', '2098813002', '2109640010', '2121879330', '2141852087', '2148832702', '2152013823', '2166805079', '2176613834', '2184232774', '2213965523', '2249630763', '2256677805', '2263287955', '2263683020', '2264826605', '2270117351', '2281372282', '2285328250', '2322449232', '2326092712', '2336131857', '2346410171', '2405684784', '2467219838', '2473091535', '2488751095', '2515673021', '252176572', '2555449229', '2601816518', '2624310025', '2672738462', '2679264929', '2708514724', '2708544445', '2721276879', '2723773273', '2728839865', '2740241949', '2758304792', '2772051790', '2779816680', '2804441762', '2811346655', '2811646800', '2820103955', '2839681895', '2900998385', '2976200180', '2994456336', '3057994128', '3095010437', '3104317075', '3109672704', '3137179145', '3153285641', '3173321541', '3181666887', '3201889607', '3208820205', '3248401349', '3280527321', '3283246198', '3300057240', '3355963469', '3378306304', '3383637897', '3395075403', '3399503065', '3417877266', '3433092803', '347484677', '348956807', '3490841593', '3509324997', '3527069516', '3537611572', '3543711249', '3550826234', '3574700791', '3577812263', '3608551465', '3609537739', '3622960580', '3666781780', '3701422761', '3721927307', '3751410902', '3756613238', '3769544385', '3783554953', '3794712078', '380369091', '3813230821', '3817572483', '3843929707', '3869664504', '3892179393', '3923913515', '3981562204', '4078929101', '4101587978', '4150900444', '4191136837', '4200829752', '4209136328', '420958416', '422113773', '42222766', '4233346443', '4233985575', '4236057556', '4252161228', '425542996', '4276854486', '4294775577', '431609031', '439844759', '446236576', '470582324', '472128010', '492897929', '537402693', '5501547', '561170018', '593416697', '631898947', '649410423', '654529993', '678960043', '699907539', '707716966', '713615518', '778875120', '792981518', '796465415', '798649922', '856068671', '923153024', '957739544', '970593849', '976754415']
# <KeysViewHDF5 ['feature', 'token']>
# (3, 23, 543)
# [1]

# %%
# !wget https://github.com/takayama-rado/trado_samples/archive/master.zip
# Out:
# --2024-05-12 23:45:22--  https://github.com/takayama-rado/trado_samples/archive/master.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/takayama-rado/trado_samples/zip/main [following]
# --2024-05-12 23:45:22--  https://codeload.github.com/takayama-rado/trado_samples/zip/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.114.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.114.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [          <=>       ]  75.01M  19.9MB/s    in 3.8s
#
# 2024-05-12 23:45:26 (19.9 MB/s) - ‘master.zip’ saved [78654650]

# %%
# !unzip -o master.zip -d master
# Out:
# Archive:  master.zip
# 18df7dbc09a3a110463b4a5fa789d9a634b5b282
#    creating: master/trado_samples-main/
#   inflating: master/trado_samples-main/.gitignore
#   inflating: master/trado_samples-main/LICENSE
#   inflating: master/trado_samples-main/README.md
#    creating: master/trado_samples-main/colab_files/
#  extracting: master/trado_samples-main/colab_files/.gitkeep
#   inflating: master/trado_samples-main/colab_files/exp_affine_np_einsum.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_jax_static.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_mpholistic_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_mpothers_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_jax.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_numpy.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_tensorflow.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_torch.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_jax.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_numpy_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_numpy_1.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_tensorflow.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_torch.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_access_dataset.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_normalize_landmarks.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_rnn_islr_model_1.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_rnn_islr_model_2.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_rnn_islr_model_3.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_select_landmarks.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_simple_attention.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_simple_islr_model.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_transformer_encoder.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_transformer_encoder_daug_hflip.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_transformer_encoder_daug_tclip.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_transformer_encoder_w_ls.ipynb
#    creating: master/trado_samples-main/src/
#    creating: master/trado_samples-main/src/modules_gislr/
#  extracting: master/trado_samples-main/src/modules_gislr/__init__.py
#   inflating: master/trado_samples-main/src/modules_gislr/dataset.py
#   inflating: master/trado_samples-main/src/modules_gislr/defines.py
#   inflating: master/trado_samples-main/src/modules_gislr/draw_functions.py
#   inflating: master/trado_samples-main/src/modules_gislr/layers.py
#   inflating: master/trado_samples-main/src/modules_gislr/train_functions.py
#   inflating: master/trado_samples-main/src/modules_gislr/transforms.py
#   inflating: master/trado_samples-main/src/modules_gislr/utils.py
#    creating: master/trado_samples-main/test_data/
#   inflating: master/trado_samples-main/test_data/finger_far0.mp4
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static.npy
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static_affine.npy
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static_interp.npy
#   inflating: master/trado_samples-main/test_data/finger_middle0.mp4
#   inflating: master/trado_samples-main/test_data/finger_near0.mp4
#   inflating: master/trado_samples-main/test_data/hand_only.mp4

# %%
# !mv master/trado_samples-main/src/modules_gislr .

# %%
# !rm -rf master master.zip gislr_top10.zip

# %%
# !ls
# Out:
# dataset_top10  drive  modules_gislr  sample_data

# %% [markdown]
# # 2. Load library

# %%
import copy
import json
import math
import os
import random
import sys
from functools import partial
from inspect import signature
from pathlib import Path
from typing import (
    Any,
    Dict,
    List
)

# Third party's modules
import numpy as np

import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import (
    DataLoader)

from torchvision.transforms import Compose

# Local modules
sys.path.append("modules_gislr")
from modules_gislr.dataset import (
    HDF5Dataset,
    merge_padded_batch)
from modules_gislr.defines import (
    get_fullbody_landmarks
)
from modules_gislr.layers import (
    Identity,
    GPoolRecognitionHead,
    TransformerEnISLR
)
from modules_gislr.train_functions import (
    test_loop,
    val_loop,
    train_loop
)
from modules_gislr.transforms import (
    PartsBasedNormalization,
    ReplaceNan,
    SelectLandmarksAndFeature,
    ToTensor
)

# %% [markdown]
# # 3. Implement temporal clipping.

# %%
class RandomClip():
    """Clip sequence randomly.

    # Args:
      - apply_ratio: The ratio to apply augmentation.
      - clip_range: The range of clipping.
      - offset: The offset of clip range.
        if offset < 0, this is determined randomly.
      - min_apply_size: The minimum temporal length to apply augmentation.
    """
    def __init__(self,
                 apply_ratio,
                 clip_range,
                 offset=-1,
                 min_apply_size=10):
        self.apply_ratio = apply_ratio
        self.clip_range = clip_range
        self.offset = offset
        self.min_apply_size = min_apply_size

    def __call__(self,
                 data: Dict[str, Any]) -> Dict[str, Any]:
        """Execute clipping.
        """
        if random.random() > self.apply_ratio:
            return data

        feature = data["feature"]
        base_timelen = feature.shape[1]
        if base_timelen > self.min_apply_size:
            aug_tscale = np.random.random() * (self.clip_range[1] - self.clip_range[0]) + self.clip_range[0]
            aug_timelen = int(base_timelen * (1 - aug_tscale))
            if aug_timelen < base_timelen:
                if self.offset < 0:
                    offset = np.random.randint(0, base_timelen - aug_timelen)
                else:
                    offset = self.offset
                # `[C, T, J]`
                feature = feature[:, offset: aug_timelen + offset, :]

        data["feature"] = feature
        return data

    def __str__(self):
        return f"{self.__class__.__name__}:{self.__dict__}"

# %% [markdown]
# # 4. Sanity check

# %%
# Access check.
dataset_dir = Path("dataset_top10")
files = list(dataset_dir.iterdir())
dictionary = [fin for fin in files if ".json" in fin.name][0]
hdf5_files = [fin for fin in files if ".hdf5" in fin.name]

print(dictionary)
print(hdf5_files)
# Out:
# dataset_top10/sign_to_prediction_index_map.json
# [PosixPath('dataset_top10/53618.hdf5'), PosixPath('dataset_top10/22343.hdf5'), PosixPath('dataset_top10/28656.hdf5'), PosixPath('dataset_top10/27610.hdf5'), PosixPath('dataset_top10/37055.hdf5'), PosixPath('dataset_top10/26734.hdf5'), PosixPath('dataset_top10/55372.hdf5'), PosixPath('dataset_top10/36257.hdf5'), PosixPath('dataset_top10/61333.hdf5'), PosixPath('dataset_top10/2044.hdf5'), PosixPath('dataset_top10/4718.hdf5'), PosixPath('dataset_top10/18796.hdf5'), PosixPath('dataset_top10/34503.hdf5'), PosixPath('dataset_top10/62590.hdf5'), PosixPath('dataset_top10/49445.hdf5'), PosixPath('dataset_top10/30680.hdf5'), PosixPath('dataset_top10/32319.hdf5'), PosixPath('dataset_top10/37779.hdf5'), PosixPath('dataset_top10/25571.hdf5'), PosixPath('dataset_top10/29302.hdf5'), PosixPath('dataset_top10/16069.hdf5')]

# %%
# Load dictionary.
with open(dictionary, "r") as fread:
    key2token = json.load(fread)

VOCAB = len(key2token)

# %%
_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
trans_select_feature = SelectLandmarksAndFeature(landmarks=use_landmarks, features=use_features)
trans_repnan = ReplaceNan()
trans_norm = PartsBasedNormalization(align_mode="framewise", scale_mode="unique")

pre_transforms = Compose([trans_select_feature,
                          trans_repnan,
                          trans_norm])
transforms_default = Compose([ToTensor()])

transforms_w_daug = Compose([
    RandomClip(
        apply_ratio=0.5,
        clip_range=(0.4, 0.6)),
    ToTensor()])

# %%
batch_size = 2
feature_shape = (len(use_features), -1, len(use_landmarks))
token_shape = (1,)
merge_fn = partial(merge_padded_batch,
                   feature_shape=feature_shape,
                   token_shape=token_shape,
                   feature_padding_val=0.0,
                   token_padding_val=0)

dataset = HDF5Dataset(hdf5_files, pre_transforms=pre_transforms, transforms=transforms_w_daug)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=merge_fn)
try:
    data = next(iter(dataloader))
    feature_origin = data["feature"]

    print(feature_origin.shape)
except Exception as inst:
    print(inst)
# Out:
# torch.Size([2, 2, 64, 130])

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
inter_channels = 64
out_channels = VOCAB
activation = "relu"
tren_num_layers = 2
tren_num_heads = 2
tren_dim_ffw = 256
tren_dropout_pe = 0.1
tren_dropout = 0.1
tren_layer_norm_eps = 1e-5
tren_norm_first = True
tren_add_bias = True
tren_add_tailnorm = True

model = TransformerEnISLR(in_channels=in_channels,
                          inter_channels=inter_channels,
                          out_channels=out_channels,
                          activation=activation,
                          tren_num_layers=tren_num_layers,
                          tren_num_heads=tren_num_heads,
                          tren_dim_ffw=tren_dim_ffw,
                          tren_dropout_pe=tren_dropout_pe,
                          tren_dropout=tren_dropout,
                          tren_layer_norm_eps=tren_layer_norm_eps,
                          tren_norm_first=tren_norm_first,
                          tren_add_bias=tren_add_bias,
                          tren_add_tailnorm=tren_add_tailnorm)
print(model)

# Sanity check.
logit = model(feature_origin)
print(logit.shape)
attw0 = model.tr_encoder.layers[0].attw.detach().cpu().numpy()
attw1 = model.tr_encoder.layers[0].attw.detach().cpu().numpy()
print(attw0.shape, attw1.shape)
# Out:
# TransformerEnISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (tr_encoder): TransformerEncoder(
#     (pos_encoder): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (w_key): Linear(in_features=64, out_features=64, bias=True)
#           (w_value): Linear(in_features=64, out_features=64, bias=True)
#           (w_query): Linear(in_features=64, out_features=64, bias=True)
#           (w_out): Linear(in_features=64, out_features=64, bias=True)
#           (dropout_attn): Dropout(p=0.1, inplace=False)
#         )
#         (ffw): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=256, bias=True)
#           (w_2): Linear(in_features=256, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#         (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])
# (2, 2, 64, 64) (2, 2, 64, 64)

# %% [markdown]
# # 5. Train and evaluation

# %% [markdown]
# ## 5.1 Set common parameters.

# %%
# Set common parameters.
batch_size = 32
load_into_ram = True
test_pid = 16069
num_workers = os.cpu_count()
print(f"Using {num_workers} cores for data loading.")
lr = 3e-4

epochs = 50
eval_every_n_epochs = 1
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} for computation.")

train_hdf5files = [fin for fin in hdf5_files if str(test_pid) not in fin.name]
val_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]
test_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]

_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
# Out:
# Using 2 cores for data loading.
# Using cuda for computation.

# %% [markdown]
# ## 5.2 Run training process

# %% [markdown]
# ### Default settings

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(
    train_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_default,
    load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(
    val_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_default,
    load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(
    test_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_default,
    load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)

# %%
tren_norm_first = True
tren_add_tailnorm = True

model_default = TransformerEnISLR(
    in_channels=in_channels,
    inter_channels=inter_channels,
    out_channels=out_channels,
    activation=activation,
    tren_num_layers=tren_num_layers,
    tren_num_heads=tren_num_heads,
    tren_dim_ffw=tren_dim_ffw,
    tren_dropout_pe=tren_dropout_pe,
    tren_dropout=tren_dropout,
    tren_layer_norm_eps=tren_layer_norm_eps,
    tren_norm_first=tren_norm_first,
    tren_add_bias=tren_add_bias,
    tren_add_tailnorm=tren_add_tailnorm)
print(model_default)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model_default.parameters(), lr=lr)
# Out:
# TransformerEnISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (tr_encoder): TransformerEncoder(
#     (pos_encoder): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (w_key): Linear(in_features=64, out_features=64, bias=True)
#           (w_value): Linear(in_features=64, out_features=64, bias=True)
#           (w_query): Linear(in_features=64, out_features=64, bias=True)
#           (w_out): Linear(in_features=64, out_features=64, bias=True)
#           (dropout_attn): Dropout(p=0.1, inplace=False)
#         )
#         (ffw): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=256, bias=True)
#           (w_2): Linear(in_features=256, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#         (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model_default.to(device)

train_losses = []
val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_losses = train_loop(train_dataloader, model_default, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model_default, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model_default, device)
        test_accs.append(acc)
train_losses_default = np.array(train_losses)
val_losses_default = np.array(val_losses)
test_accs_default = np.array(test_accs)

print(f"Minimum validation loss:{val_losses_default.min()} at {np.argmin(val_losses_default)+1} epoch.")
print(f"Maximum accuracy:{test_accs_default.max()} at {np.argmax(test_accs_default)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# loss:3.339170 [    0/ 3881]
# loss:1.838009 [ 3200/ 3881]
# Done. Time:5.526299692999999
# Training performance:
#  Avg loss:2.149870
#
# Start validation.
# Done. Time:0.22855789999999843
# Validation performance:
#  Avg loss:2.059021
#
# Start evaluation.
# Done. Time:1.176137577999981
# Test performance:
#  Accuracy:23.5%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:1.597369 [    0/ 3881]
# loss:1.334700 [ 3200/ 3881]
# Done. Time:2.6676118849999853
# Training performance:
#  Avg loss:1.522084
#
# Start validation.
# Done. Time:0.2233618369999988
# Validation performance:
#  Avg loss:1.887988
#
# Start evaluation.
# Done. Time:1.0812963029999878
# Test performance:
#  Accuracy:38.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.532413 [    0/ 3881]
# loss:1.077160 [ 3200/ 3881]
# Done. Time:2.6096855220000066
# Training performance:
#  Avg loss:1.174907
#
# Start validation.
# Done. Time:0.22558674499998688
# Validation performance:
#  Avg loss:1.469660
#
# Start evaluation.
# Done. Time:1.1970473490000018
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.136439 [    0/ 3881]
# loss:0.657850 [ 3200/ 3881]
# Done. Time:5.878691348999979
# Training performance:
#  Avg loss:0.978590
#
# Start validation.
# Done. Time:0.22973550999998338
# Validation performance:
#  Avg loss:1.476256
#
# Start evaluation.
# Done. Time:1.097642129999997
# Test performance:
#  Accuracy:48.5%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:0.697657 [    0/ 3881]
# loss:0.431979 [ 3200/ 3881]
# Done. Time:2.6258842659999857
# Training performance:
#  Avg loss:0.880030
#
# Start validation.
# Done. Time:0.22715117799998552
# Validation performance:
#  Avg loss:1.540129
#
# Start evaluation.
# Done. Time:1.1001144419999775
# Test performance:
#  Accuracy:56.0%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:0.891786 [    0/ 3881]
# loss:0.833968 [ 3200/ 3881]
# Done. Time:2.6386771690000046
# Training performance:
#  Avg loss:0.801569
#
# Start validation.
# Done. Time:0.23906186099998195
# Validation performance:
#  Avg loss:1.399705
#
# Start evaluation.
# Done. Time:1.2513040229999888
# Test performance:
#  Accuracy:54.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:0.598035 [    0/ 3881]
# loss:0.823094 [ 3200/ 3881]
# Done. Time:4.567263953999998
# Training performance:
#  Avg loss:0.722752
#
# Start validation.
# Done. Time:0.23690696099998831
# Validation performance:
#  Avg loss:1.259302
#
# Start evaluation.
# Done. Time:1.099518905000025
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:0.693028 [    0/ 3881]
# loss:0.501259 [ 3200/ 3881]
# Done. Time:2.645026453000014
# Training performance:
#  Avg loss:0.678249
#
# Start validation.
# Done. Time:0.22198267100000635
# Validation performance:
#  Avg loss:1.349823
#
# Start evaluation.
# Done. Time:1.101173853000006
# Test performance:
#  Accuracy:58.5%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:0.665748 [    0/ 3881]
# loss:0.476263 [ 3200/ 3881]
# Done. Time:2.6781075609999903
# Training performance:
#  Avg loss:0.622348
#
# Start validation.
# Done. Time:0.2304510559999926
# Validation performance:
#  Avg loss:1.186085
#
# Start evaluation.
# Done. Time:1.092476975000011
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:0.609503 [    0/ 3881]
# loss:0.373481 [ 3200/ 3881]
# Done. Time:4.374344317000009
# Training performance:
#  Avg loss:0.577121
#
# Start validation.
# Done. Time:0.35116450799998233
# Validation performance:
#  Avg loss:1.079654
#
# Start evaluation.
# Done. Time:1.1228607899999759
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:0.733205 [    0/ 3881]
# loss:0.552568 [ 3200/ 3881]
# Done. Time:2.771163281999975
# Training performance:
#  Avg loss:0.550276
#
# Start validation.
# Done. Time:0.22433574199999384
# Validation performance:
#  Avg loss:1.194255
#
# Start evaluation.
# Done. Time:1.102445921999987
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:0.525908 [    0/ 3881]
# loss:0.334668 [ 3200/ 3881]
# Done. Time:2.608787514999989
# Training performance:
#  Avg loss:0.518923
#
# Start validation.
# Done. Time:0.24510550499999795
# Validation performance:
#  Avg loss:1.135153
#
# Start evaluation.
# Done. Time:1.1037539590000165
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:0.768067 [    0/ 3881]
# loss:0.592317 [ 3200/ 3881]
# Done. Time:3.9563276820000226
# Training performance:
#  Avg loss:0.508059
#
# Start validation.
# Done. Time:0.40301635000000147
# Validation performance:
#  Avg loss:1.233840
#
# Start evaluation.
# Done. Time:1.192269926999984
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:0.485027 [    0/ 3881]
# loss:0.407783 [ 3200/ 3881]
# Done. Time:2.7508026200000018
# Training performance:
#  Avg loss:0.473755
#
# Start validation.
# Done. Time:0.22045038699999964
# Validation performance:
#  Avg loss:0.874475
#
# Start evaluation.
# Done. Time:1.134314455000009
# Test performance:
#  Accuracy:74.0%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:0.450329 [    0/ 3881]
# loss:0.309025 [ 3200/ 3881]
# Done. Time:2.6639079450000054
# Training performance:
#  Avg loss:0.474541
#
# Start validation.
# Done. Time:0.23123207999998385
# Validation performance:
#  Avg loss:1.042896
#
# Start evaluation.
# Done. Time:1.090560197000002
# Test performance:
#  Accuracy:61.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:0.380027 [    0/ 3881]
# loss:0.314889 [ 3200/ 3881]
# Done. Time:3.6962764519999496
# Training performance:
#  Avg loss:0.440906
#
# Start validation.
# Done. Time:0.3480721149999795
# Validation performance:
#  Avg loss:1.147718
#
# Start evaluation.
# Done. Time:1.5913361190000046
# Test performance:
#  Accuracy:65.0%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:0.322451 [    0/ 3881]
# loss:0.518835 [ 3200/ 3881]
# Done. Time:2.739214254999979
# Training performance:
#  Avg loss:0.411516
#
# Start validation.
# Done. Time:0.2302072240000257
# Validation performance:
#  Avg loss:1.017897
#
# Start evaluation.
# Done. Time:1.1147743450000007
# Test performance:
#  Accuracy:67.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:0.294533 [    0/ 3881]
# loss:0.513567 [ 3200/ 3881]
# Done. Time:2.600940950999984
# Training performance:
#  Avg loss:0.405971
#
# Start validation.
# Done. Time:0.22390889499996547
# Validation performance:
#  Avg loss:0.875334
#
# Start evaluation.
# Done. Time:1.1112486150000223
# Test performance:
#  Accuracy:74.0%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:0.256714 [    0/ 3881]
# loss:0.998155 [ 3200/ 3881]
# Done. Time:3.0754419589999884
# Training performance:
#  Avg loss:0.380608
#
# Start validation.
# Done. Time:0.359243580999987
# Validation performance:
#  Avg loss:0.873572
#
# Start evaluation.
# Done. Time:1.5134379840000065
# Test performance:
#  Accuracy:73.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:0.193956 [    0/ 3881]
# loss:0.424225 [ 3200/ 3881]
# Done. Time:3.6566922290000434
# Training performance:
#  Avg loss:0.376743
#
# Start validation.
# Done. Time:0.23706321800000296
# Validation performance:
#  Avg loss:0.964408
#
# Start evaluation.
# Done. Time:1.084851485999991
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:0.507306 [    0/ 3881]
# loss:0.166747 [ 3200/ 3881]
# Done. Time:2.602279597000006
# Training performance:
#  Avg loss:0.368506
#
# Start validation.
# Done. Time:0.23374308399996835
# Validation performance:
#  Avg loss:1.224586
#
# Start evaluation.
# Done. Time:1.0996276799999691
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:0.747839 [    0/ 3881]
# loss:0.469709 [ 3200/ 3881]
# Done. Time:2.6670019150000144
# Training performance:
#  Avg loss:0.356805
#
# Start validation.
# Done. Time:0.2251422489999868
# Validation performance:
#  Avg loss:0.844311
#
# Start evaluation.
# Done. Time:1.3131662260000212
# Test performance:
#  Accuracy:77.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:0.286112 [    0/ 3881]
# loss:0.333774 [ 3200/ 3881]
# Done. Time:4.3168823400000065
# Training performance:
#  Avg loss:0.338876
#
# Start validation.
# Done. Time:0.23015205899997682
# Validation performance:
#  Avg loss:0.860558
#
# Start evaluation.
# Done. Time:1.1104292669999722
# Test performance:
#  Accuracy:75.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:0.225522 [    0/ 3881]
# loss:0.362137 [ 3200/ 3881]
# Done. Time:2.639476129000002
# Training performance:
#  Avg loss:0.338148
#
# Start validation.
# Done. Time:0.25902180700001054
# Validation performance:
#  Avg loss:1.087900
#
# Start evaluation.
# Done. Time:1.1005846639999959
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:0.384278 [    0/ 3881]
# loss:0.307117 [ 3200/ 3881]
# Done. Time:2.6190161149999653
# Training performance:
#  Avg loss:0.340074
#
# Start validation.
# Done. Time:0.23253816299995833
# Validation performance:
#  Avg loss:0.824645
#
# Start evaluation.
# Done. Time:1.1523368820000428
# Test performance:
#  Accuracy:78.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:0.420744 [    0/ 3881]
# loss:0.360348 [ 3200/ 3881]
# Done. Time:4.873943852000025
# Training performance:
#  Avg loss:0.324090
#
# Start validation.
# Done. Time:0.4281113389999973
# Validation performance:
#  Avg loss:0.761328
#
# Start evaluation.
# Done. Time:1.4827224279999882
# Test performance:
#  Accuracy:81.0%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:0.280216 [    0/ 3881]
# loss:0.329672 [ 3200/ 3881]
# Done. Time:3.8098042910000345
# Training performance:
#  Avg loss:0.302923
#
# Start validation.
# Done. Time:0.23266314099998908
# Validation performance:
#  Avg loss:0.875053
#
# Start evaluation.
# Done. Time:1.1081769589999908
# Test performance:
#  Accuracy:76.0%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.176483 [    0/ 3881]
# loss:0.671349 [ 3200/ 3881]
# Done. Time:2.698328332000017
# Training performance:
#  Avg loss:0.294162
#
# Start validation.
# Done. Time:0.23341461600000457
# Validation performance:
#  Avg loss:0.881965
#
# Start evaluation.
# Done. Time:1.2682212099999788
# Test performance:
#  Accuracy:73.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.301166 [    0/ 3881]
# loss:0.113690 [ 3200/ 3881]
# Done. Time:4.581915579999986
# Training performance:
#  Avg loss:0.278328
#
# Start validation.
# Done. Time:0.24340006200003472
# Validation performance:
#  Avg loss:0.865233
#
# Start evaluation.
# Done. Time:1.1023420740000347
# Test performance:
#  Accuracy:75.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.341615 [    0/ 3881]
# loss:0.233089 [ 3200/ 3881]
# Done. Time:2.691545278000035
# Training performance:
#  Avg loss:0.297115
#
# Start validation.
# Done. Time:0.24283574199995428
# Validation performance:
#  Avg loss:0.909306
#
# Start evaluation.
# Done. Time:1.1051906449999933
# Test performance:
#  Accuracy:72.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.292433 [    0/ 3881]
# loss:0.341375 [ 3200/ 3881]
# Done. Time:2.6032468939999944
# Training performance:
#  Avg loss:0.295446
#
# Start validation.
# Done. Time:0.24074730799998179
# Validation performance:
#  Avg loss:0.750528
#
# Start evaluation.
# Done. Time:1.184687795000002
# Test performance:
#  Accuracy:79.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.113681 [    0/ 3881]
# loss:0.303743 [ 3200/ 3881]
# Done. Time:4.78501077300001
# Training performance:
#  Avg loss:0.275911
#
# Start validation.
# Done. Time:0.2975848629999973
# Validation performance:
#  Avg loss:0.794827
#
# Start evaluation.
# Done. Time:1.1042554119999863
# Test performance:
#  Accuracy:79.0%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.218352 [    0/ 3881]
# loss:0.350985 [ 3200/ 3881]
# Done. Time:2.6412418240000193
# Training performance:
#  Avg loss:0.266494
#
# Start validation.
# Done. Time:0.232536548999974
# Validation performance:
#  Avg loss:0.913224
#
# Start evaluation.
# Done. Time:1.1078679319999765
# Test performance:
#  Accuracy:71.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.174561 [    0/ 3881]
# loss:0.280532 [ 3200/ 3881]
# Done. Time:2.6807082580000383
# Training performance:
#  Avg loss:0.274526
#
# Start validation.
# Done. Time:0.22472153000001072
# Validation performance:
#  Avg loss:0.942576
#
# Start evaluation.
# Done. Time:1.120259458000021
# Test performance:
#  Accuracy:74.0%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.192660 [    0/ 3881]
# loss:0.218070 [ 3200/ 3881]
# Done. Time:3.9219334560000334
# Training performance:
#  Avg loss:0.253279
#
# Start validation.
# Done. Time:0.3816965340000138
# Validation performance:
#  Avg loss:1.134175
#
# Start evaluation.
# Done. Time:1.2219803529999922
# Test performance:
#  Accuracy:65.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.222069 [    0/ 3881]
# loss:0.164900 [ 3200/ 3881]
# Done. Time:2.705821738999987
# Training performance:
#  Avg loss:0.257641
#
# Start validation.
# Done. Time:0.24834478299999319
# Validation performance:
#  Avg loss:0.947668
#
# Start evaluation.
# Done. Time:1.0962555760000328
# Test performance:
#  Accuracy:71.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.163512 [    0/ 3881]
# loss:0.180886 [ 3200/ 3881]
# Done. Time:2.6627209910000147
# Training performance:
#  Avg loss:0.255612
#
# Start validation.
# Done. Time:0.23190168200000016
# Validation performance:
#  Avg loss:0.971848
#
# Start evaluation.
# Done. Time:1.1248720109999795
# Test performance:
#  Accuracy:72.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.242041 [    0/ 3881]
# loss:0.345236 [ 3200/ 3881]
# Done. Time:3.7499029470000096
# Training performance:
#  Avg loss:0.251413
#
# Start validation.
# Done. Time:0.37059644999999364
# Validation performance:
#  Avg loss:1.087166
#
# Start evaluation.
# Done. Time:1.518256106000024
# Test performance:
#  Accuracy:70.0%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.308584 [    0/ 3881]
# loss:0.099791 [ 3200/ 3881]
# Done. Time:2.719140830000015
# Training performance:
#  Avg loss:0.240184
#
# Start validation.
# Done. Time:0.22493936400002212
# Validation performance:
#  Avg loss:1.159728
#
# Start evaluation.
# Done. Time:1.09074627800004
# Test performance:
#  Accuracy:75.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.271887 [    0/ 3881]
# loss:0.306251 [ 3200/ 3881]
# Done. Time:2.639743173999989
# Training performance:
#  Avg loss:0.222208
#
# Start validation.
# Done. Time:0.23781965000000582
# Validation performance:
#  Avg loss:0.931741
#
# Start evaluation.
# Done. Time:1.1023595229999614
# Test performance:
#  Accuracy:74.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.283310 [    0/ 3881]
# loss:0.122195 [ 3200/ 3881]
# Done. Time:3.1512556659999973
# Training performance:
#  Avg loss:0.229393
#
# Start validation.
# Done. Time:0.35872347999998055
# Validation performance:
#  Avg loss:0.944057
#
# Start evaluation.
# Done. Time:1.5377358279999953
# Test performance:
#  Accuracy:74.5%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.313107 [    0/ 3881]
# loss:0.243020 [ 3200/ 3881]
# Done. Time:2.9593609300000026
# Training performance:
#  Avg loss:0.231860
#
# Start validation.
# Done. Time:0.24660861500001374
# Validation performance:
#  Avg loss:1.104874
#
# Start evaluation.
# Done. Time:1.133681581000019
# Test performance:
#  Accuracy:69.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.420385 [    0/ 3881]
# loss:0.160172 [ 3200/ 3881]
# Done. Time:2.5893923200000017
# Training performance:
#  Avg loss:0.226709
#
# Start validation.
# Done. Time:0.24043291500004216
# Validation performance:
#  Avg loss:1.007843
#
# Start evaluation.
# Done. Time:1.1084423960000436
# Test performance:
#  Accuracy:73.5%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.166623 [    0/ 3881]
# loss:0.142518 [ 3200/ 3881]
# Done. Time:2.8287535570000273
# Training performance:
#  Avg loss:0.232089
#
# Start validation.
# Done. Time:0.3724715710000055
# Validation performance:
#  Avg loss:0.812626
#
# Start evaluation.
# Done. Time:1.4337380950000238
# Test performance:
#  Accuracy:82.5%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.069680 [    0/ 3881]
# loss:0.179739 [ 3200/ 3881]
# Done. Time:3.9492227179999873
# Training performance:
#  Avg loss:0.205326
#
# Start validation.
# Done. Time:0.22624247700002798
# Validation performance:
#  Avg loss:0.861272
#
# Start evaluation.
# Done. Time:1.0849665279999954
# Test performance:
#  Accuracy:80.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.070207 [    0/ 3881]
# loss:0.235655 [ 3200/ 3881]
# Done. Time:2.6451849190000303
# Training performance:
#  Avg loss:0.201288
#
# Start validation.
# Done. Time:0.23836958900000127
# Validation performance:
#  Avg loss:0.829782
#
# Start evaluation.
# Done. Time:1.1109680399999888
# Test performance:
#  Accuracy:81.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.116393 [    0/ 3881]
# loss:0.267558 [ 3200/ 3881]
# Done. Time:2.6614269370000443
# Training performance:
#  Avg loss:0.209012
#
# Start validation.
# Done. Time:0.23035717900000918
# Validation performance:
#  Avg loss:0.740254
#
# Start evaluation.
# Done. Time:1.286563779000005
# Test performance:
#  Accuracy:83.5%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.159278 [    0/ 3881]
# loss:0.183499 [ 3200/ 3881]
# Done. Time:4.4908937540000124
# Training performance:
#  Avg loss:0.206125
#
# Start validation.
# Done. Time:0.24460913499996195
# Validation performance:
#  Avg loss:1.073101
#
# Start evaluation.
# Done. Time:1.1027834299999881
# Test performance:
#  Accuracy:70.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.142854 [    0/ 3881]
# loss:0.224989 [ 3200/ 3881]
# Done. Time:2.7107187249999924
# Training performance:
#  Avg loss:0.193776
#
# Start validation.
# Done. Time:0.236466332999953
# Validation performance:
#  Avg loss:0.898988
#
# Start evaluation.
# Done. Time:1.114461929000015
# Test performance:
#  Accuracy:79.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.247186 [    0/ 3881]
# loss:0.305739 [ 3200/ 3881]
# Done. Time:2.642088887
# Training performance:
#  Avg loss:0.194697
#
# Start validation.
# Done. Time:0.23894152299999405
# Validation performance:
#  Avg loss:0.879709
#
# Start evaluation.
# Done. Time:1.1367939610000235
# Test performance:
#  Accuracy:80.5%
# Minimum validation loss:0.7402541786432266 at 47 epoch.
# Maximum accuracy:83.5 at 47 epoch.

# %% [markdown]
# ### Apply temporal clipping.

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(
    train_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_w_daug,
    load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(
    val_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_default,
    load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(
    test_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_default,
    load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)

# %%
tren_norm_first = True
tren_add_tailnorm = True

model_pnorm = TransformerEnISLR(
    in_channels=in_channels,
    inter_channels=inter_channels,
    out_channels=out_channels,
    activation=activation,
    tren_num_layers=tren_num_layers,
    tren_num_heads=tren_num_heads,
    tren_dim_ffw=tren_dim_ffw,
    tren_dropout_pe=tren_dropout_pe,
    tren_dropout=tren_dropout,
    tren_layer_norm_eps=tren_layer_norm_eps,
    tren_norm_first=tren_norm_first,
    tren_add_bias=tren_add_bias,
    tren_add_tailnorm=tren_add_tailnorm)
print(model_pnorm)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model_pnorm.parameters(), lr=lr)
# Out:
# TransformerEnISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (tr_encoder): TransformerEncoder(
#     (pos_encoder): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (w_key): Linear(in_features=64, out_features=64, bias=True)
#           (w_value): Linear(in_features=64, out_features=64, bias=True)
#           (w_query): Linear(in_features=64, out_features=64, bias=True)
#           (w_out): Linear(in_features=64, out_features=64, bias=True)
#           (dropout_attn): Dropout(p=0.1, inplace=False)
#         )
#         (ffw): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=256, bias=True)
#           (w_2): Linear(in_features=256, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#         (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model_pnorm.to(device)

train_losses = []
val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_losses = train_loop(train_dataloader, model_pnorm, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model_pnorm, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model_pnorm, device)
        test_accs.append(acc)
train_losses_w_daug = np.array(train_losses)
val_losses_w_daug = np.array(val_losses)
test_accs_w_daug = np.array(test_accs)

print(f"Minimum validation loss:{val_losses_w_daug.min()} at {np.argmin(val_losses_w_daug)+1} epoch.")
print(f"Maximum accuracy:{test_accs_w_daug.max()} at {np.argmax(test_accs_w_daug)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:3.691115 [    0/ 3881]
# loss:1.857471 [ 3200/ 3881]
# Done. Time:2.6034424019999847
# Training performance:
#  Avg loss:2.157840
#
# Start validation.
# Done. Time:0.2655083749999676
# Validation performance:
#  Avg loss:2.200953
#
# Start evaluation.
# Done. Time:1.16119697299996
# Test performance:
#  Accuracy:20.0%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:1.926785 [    0/ 3881]
# loss:1.208736 [ 3200/ 3881]
# Done. Time:2.5188894199999936
# Training performance:
#  Avg loss:1.473611
#
# Start validation.
# Done. Time:0.2638579209999534
# Validation performance:
#  Avg loss:1.592254
#
# Start evaluation.
# Done. Time:1.4189664869999774
# Test performance:
#  Accuracy:49.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:0.932599 [    0/ 3881]
# loss:0.966061 [ 3200/ 3881]
# Done. Time:4.161285310000039
# Training performance:
#  Avg loss:1.183091
#
# Start validation.
# Done. Time:0.27961699500002624
# Validation performance:
#  Avg loss:1.377485
#
# Start evaluation.
# Done. Time:1.172108776000016
# Test performance:
#  Accuracy:57.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.083212 [    0/ 3881]
# loss:1.126743 [ 3200/ 3881]
# Done. Time:2.5890845729999796
# Training performance:
#  Avg loss:1.029619
#
# Start validation.
# Done. Time:0.2822756859999913
# Validation performance:
#  Avg loss:1.381863
#
# Start evaluation.
# Done. Time:1.195288694999988
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:0.844946 [    0/ 3881]
# loss:1.054638 [ 3200/ 3881]
# Done. Time:2.605172218000007
# Training performance:
#  Avg loss:0.907687
#
# Start validation.
# Done. Time:0.27188882100000455
# Validation performance:
#  Avg loss:1.366914
#
# Start evaluation.
# Done. Time:1.2865882049999868
# Test performance:
#  Accuracy:50.0%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:0.816124 [    0/ 3881]
# loss:0.763875 [ 3200/ 3881]
# Done. Time:4.5448198679999905
# Training performance:
#  Avg loss:0.861754
#
# Start validation.
# Done. Time:0.2774314199999708
# Validation performance:
#  Avg loss:1.200630
#
# Start evaluation.
# Done. Time:1.2510644630000343
# Test performance:
#  Accuracy:58.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:0.905587 [    0/ 3881]
# loss:1.020506 [ 3200/ 3881]
# Done. Time:2.692726171000004
# Training performance:
#  Avg loss:0.801716
#
# Start validation.
# Done. Time:0.2631791510000312
# Validation performance:
#  Avg loss:1.224432
#
# Start evaluation.
# Done. Time:1.211088693000022
# Test performance:
#  Accuracy:53.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:0.760885 [    0/ 3881]
# loss:0.916963 [ 3200/ 3881]
# Done. Time:4.065882708000004
# Training performance:
#  Avg loss:0.749555
#
# Start validation.
# Done. Time:0.4654379450000192
# Validation performance:
#  Avg loss:1.174882
#
# Start evaluation.
# Done. Time:1.6235865139999532
# Test performance:
#  Accuracy:63.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:0.874956 [    0/ 3881]
# loss:0.817938 [ 3200/ 3881]
# Done. Time:3.7330701960000283
# Training performance:
#  Avg loss:0.713364
#
# Start validation.
# Done. Time:0.2767522720000102
# Validation performance:
#  Avg loss:1.086573
#
# Start evaluation.
# Done. Time:1.1602533220000169
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:0.831938 [    0/ 3881]
# loss:0.904548 [ 3200/ 3881]
# Done. Time:2.7296554600000036
# Training performance:
#  Avg loss:0.677520
#
# Start validation.
# Done. Time:0.2700173869999958
# Validation performance:
#  Avg loss:1.127344
#
# Start evaluation.
# Done. Time:1.1961697070000241
# Test performance:
#  Accuracy:62.0%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:0.638849 [    0/ 3881]
# loss:0.693012 [ 3200/ 3881]
# Done. Time:2.5664940179999576
# Training performance:
#  Avg loss:0.630862
#
# Start validation.
# Done. Time:0.2771793280000452
# Validation performance:
#  Avg loss:0.930560
#
# Start evaluation.
# Done. Time:1.445701323000037
# Test performance:
#  Accuracy:70.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:0.547993 [    0/ 3881]
# loss:0.685357 [ 3200/ 3881]
# Done. Time:4.309043182000039
# Training performance:
#  Avg loss:0.621426
#
# Start validation.
# Done. Time:0.2912087359999873
# Validation performance:
#  Avg loss:0.898212
#
# Start evaluation.
# Done. Time:1.1704445070000133
# Test performance:
#  Accuracy:70.5%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:0.594754 [    0/ 3881]
# loss:0.675677 [ 3200/ 3881]
# Done. Time:2.6589931519999936
# Training performance:
#  Avg loss:0.590471
#
# Start validation.
# Done. Time:0.27955565300004537
# Validation performance:
#  Avg loss:0.910161
#
# Start evaluation.
# Done. Time:1.1653112390000047
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:0.400709 [    0/ 3881]
# loss:0.349425 [ 3200/ 3881]
# Done. Time:2.6142652060000273
# Training performance:
#  Avg loss:0.562338
#
# Start validation.
# Done. Time:0.27032029700001203
# Validation performance:
#  Avg loss:0.771312
#
# Start evaluation.
# Done. Time:1.1930258730000105
# Test performance:
#  Accuracy:75.0%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:0.630764 [    0/ 3881]
# loss:0.511041 [ 3200/ 3881]
# Done. Time:4.673056773000042
# Training performance:
#  Avg loss:0.536531
#
# Start validation.
# Done. Time:0.38741547099999707
# Validation performance:
#  Avg loss:1.062293
#
# Start evaluation.
# Done. Time:1.1601550479999787
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:0.598604 [    0/ 3881]
# loss:0.695489 [ 3200/ 3881]
# Done. Time:2.6508081839999704
# Training performance:
#  Avg loss:0.551672
#
# Start validation.
# Done. Time:0.26933169300002646
# Validation performance:
#  Avg loss:0.755642
#
# Start evaluation.
# Done. Time:1.1717309019999789
# Test performance:
#  Accuracy:76.0%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:0.625597 [    0/ 3881]
# loss:0.210228 [ 3200/ 3881]
# Done. Time:2.7347915510000007
# Training performance:
#  Avg loss:0.530099
#
# Start validation.
# Done. Time:0.28499944800000776
# Validation performance:
#  Avg loss:0.834328
#
# Start evaluation.
# Done. Time:1.1626742010000157
# Test performance:
#  Accuracy:71.0%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:0.183836 [    0/ 3881]
# loss:0.352088 [ 3200/ 3881]
# Done. Time:4.143613371000015
# Training performance:
#  Avg loss:0.523526
#
# Start validation.
# Done. Time:0.3999684379999735
# Validation performance:
#  Avg loss:0.761169
#
# Start evaluation.
# Done. Time:1.1851005070000156
# Test performance:
#  Accuracy:74.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:0.398588 [    0/ 3881]
# loss:0.314537 [ 3200/ 3881]
# Done. Time:2.761353593000024
# Training performance:
#  Avg loss:0.496815
#
# Start validation.
# Done. Time:0.29162588700000924
# Validation performance:
#  Avg loss:0.722385
#
# Start evaluation.
# Done. Time:1.2371170050000728
# Test performance:
#  Accuracy:76.0%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:0.589685 [    0/ 3881]
# loss:0.623295 [ 3200/ 3881]
# Done. Time:2.6663893139999573
# Training performance:
#  Avg loss:0.463776
#
# Start validation.
# Done. Time:0.26183221899998443
# Validation performance:
#  Avg loss:0.658420
#
# Start evaluation.
# Done. Time:1.1578864199999543
# Test performance:
#  Accuracy:75.5%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:0.367381 [    0/ 3881]
# loss:0.353728 [ 3200/ 3881]
# Done. Time:4.05841677300009
# Training performance:
#  Avg loss:0.442594
#
# Start validation.
# Done. Time:0.389907911000023
# Validation performance:
#  Avg loss:0.650777
#
# Start evaluation.
# Done. Time:1.1711906749999343
# Test performance:
#  Accuracy:76.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:0.298400 [    0/ 3881]
# loss:0.409829 [ 3200/ 3881]
# Done. Time:2.5793956830000297
# Training performance:
#  Avg loss:0.462553
#
# Start validation.
# Done. Time:0.2822586219999721
# Validation performance:
#  Avg loss:0.736541
#
# Start evaluation.
# Done. Time:1.1754390720000174
# Test performance:
#  Accuracy:75.0%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:0.323770 [    0/ 3881]
# loss:0.707144 [ 3200/ 3881]
# Done. Time:2.702331574000027
# Training performance:
#  Avg loss:0.457792
#
# Start validation.
# Done. Time:0.28191750799999227
# Validation performance:
#  Avg loss:0.680940
#
# Start evaluation.
# Done. Time:1.1861940900000718
# Test performance:
#  Accuracy:79.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:0.484584 [    0/ 3881]
# loss:0.391101 [ 3200/ 3881]
# Done. Time:4.137243487999967
# Training performance:
#  Avg loss:0.452287
#
# Start validation.
# Done. Time:0.6359260469999981
# Validation performance:
#  Avg loss:0.708582
#
# Start evaluation.
# Done. Time:1.1832004630000483
# Test performance:
#  Accuracy:79.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:0.528646 [    0/ 3881]
# loss:0.927122 [ 3200/ 3881]
# Done. Time:2.7342152590000524
# Training performance:
#  Avg loss:0.433864
#
# Start validation.
# Done. Time:0.2737856369999463
# Validation performance:
#  Avg loss:0.733516
#
# Start evaluation.
# Done. Time:1.1765816370000266
# Test performance:
#  Accuracy:73.0%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:0.515805 [    0/ 3881]
# loss:0.538943 [ 3200/ 3881]
# Done. Time:2.747462229000007
# Training performance:
#  Avg loss:0.436466
#
# Start validation.
# Done. Time:0.27444852500002526
# Validation performance:
#  Avg loss:0.755373
#
# Start evaluation.
# Done. Time:1.1682038960000227
# Test performance:
#  Accuracy:74.0%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:0.546527 [    0/ 3881]
# loss:0.304582 [ 3200/ 3881]
# Done. Time:4.4064099180000085
# Training performance:
#  Avg loss:0.422876
#
# Start validation.
# Done. Time:0.35871808100000635
# Validation performance:
#  Avg loss:0.818016
#
# Start evaluation.
# Done. Time:1.1642412510000213
# Test performance:
#  Accuracy:74.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.452613 [    0/ 3881]
# loss:0.331013 [ 3200/ 3881]
# Done. Time:2.6919764740000574
# Training performance:
#  Avg loss:0.429915
#
# Start validation.
# Done. Time:0.2578830579999476
# Validation performance:
#  Avg loss:0.692433
#
# Start evaluation.
# Done. Time:1.1736511609999525
# Test performance:
#  Accuracy:77.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.307465 [    0/ 3881]
# loss:0.334420 [ 3200/ 3881]
# Done. Time:2.7512339539999857
# Training performance:
#  Avg loss:0.405181
#
# Start validation.
# Done. Time:0.26876919200003613
# Validation performance:
#  Avg loss:0.686772
#
# Start evaluation.
# Done. Time:1.1638166129999945
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.424233 [    0/ 3881]
# loss:0.162159 [ 3200/ 3881]
# Done. Time:4.357244741000045
# Training performance:
#  Avg loss:0.391485
#
# Start validation.
# Done. Time:0.3704908150000392
# Validation performance:
#  Avg loss:0.754343
#
# Start evaluation.
# Done. Time:1.1652484649999906
# Test performance:
#  Accuracy:77.5%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.351347 [    0/ 3881]
# loss:0.238986 [ 3200/ 3881]
# Done. Time:2.7020639569999503
# Training performance:
#  Avg loss:0.385331
#
# Start validation.
# Done. Time:0.2635312630000044
# Validation performance:
#  Avg loss:0.920813
#
# Start evaluation.
# Done. Time:1.1629301020000185
# Test performance:
#  Accuracy:67.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.491347 [    0/ 3881]
# loss:0.543038 [ 3200/ 3881]
# Done. Time:2.747329522999962
# Training performance:
#  Avg loss:0.413253
#
# Start validation.
# Done. Time:0.27065887300000213
# Validation performance:
#  Avg loss:0.973207
#
# Start evaluation.
# Done. Time:1.1683781180000778
# Test performance:
#  Accuracy:66.0%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.764351 [    0/ 3881]
# loss:0.317666 [ 3200/ 3881]
# Done. Time:4.1475469830000975
# Training performance:
#  Avg loss:0.384819
#
# Start validation.
# Done. Time:0.3909036400000332
# Validation performance:
#  Avg loss:0.831986
#
# Start evaluation.
# Done. Time:1.1693237439999393
# Test performance:
#  Accuracy:76.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.395010 [    0/ 3881]
# loss:0.308611 [ 3200/ 3881]
# Done. Time:2.689638448999972
# Training performance:
#  Avg loss:0.378242
#
# Start validation.
# Done. Time:0.2725764320000508
# Validation performance:
#  Avg loss:0.747730
#
# Start evaluation.
# Done. Time:1.1700024410000651
# Test performance:
#  Accuracy:74.5%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.294018 [    0/ 3881]
# loss:0.386118 [ 3200/ 3881]
# Done. Time:2.6151210069999706
# Training performance:
#  Avg loss:0.385935
#
# Start validation.
# Done. Time:0.26640106699994703
# Validation performance:
#  Avg loss:0.796624
#
# Start evaluation.
# Done. Time:1.1891422759999841
# Test performance:
#  Accuracy:75.0%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.301730 [    0/ 3881]
# loss:0.404727 [ 3200/ 3881]
# Done. Time:4.248698003000072
# Training performance:
#  Avg loss:0.381005
#
# Start validation.
# Done. Time:0.41324429700000564
# Validation performance:
#  Avg loss:0.726500
#
# Start evaluation.
# Done. Time:1.1903571950000469
# Test performance:
#  Accuracy:76.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.112192 [    0/ 3881]
# loss:0.292588 [ 3200/ 3881]
# Done. Time:2.6646091750000096
# Training performance:
#  Avg loss:0.375532
#
# Start validation.
# Done. Time:0.2708470989999796
# Validation performance:
#  Avg loss:0.718068
#
# Start evaluation.
# Done. Time:1.1916616560000648
# Test performance:
#  Accuracy:77.5%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.382869 [    0/ 3881]
# loss:0.287586 [ 3200/ 3881]
# Done. Time:2.7412286679999625
# Training performance:
#  Avg loss:0.361220
#
# Start validation.
# Done. Time:0.2741308020000588
# Validation performance:
#  Avg loss:0.679536
#
# Start evaluation.
# Done. Time:1.1891829460000736
# Test performance:
#  Accuracy:80.0%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.157516 [    0/ 3881]
# loss:0.156655 [ 3200/ 3881]
# Done. Time:4.452860547
# Training performance:
#  Avg loss:0.341112
#
# Start validation.
# Done. Time:0.38914358199997423
# Validation performance:
#  Avg loss:0.633167
#
# Start evaluation.
# Done. Time:1.3089788820000194
# Test performance:
#  Accuracy:81.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.288607 [    0/ 3881]
# loss:0.252418 [ 3200/ 3881]
# Done. Time:4.502851002000057
# Training performance:
#  Avg loss:0.368037
#
# Start validation.
# Done. Time:0.2770443880000357
# Validation performance:
#  Avg loss:0.748939
#
# Start evaluation.
# Done. Time:1.1748857280000493
# Test performance:
#  Accuracy:74.0%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.396489 [    0/ 3881]
# loss:0.356566 [ 3200/ 3881]
# Done. Time:2.6203591539999707
# Training performance:
#  Avg loss:0.358057
#
# Start validation.
# Done. Time:0.4132789650000177
# Validation performance:
#  Avg loss:0.565816
#
# Start evaluation.
# Done. Time:1.5257625230000258
# Test performance:
#  Accuracy:80.5%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.334735 [    0/ 3881]
# loss:0.573344 [ 3200/ 3881]
# Done. Time:4.02004583400003
# Training performance:
#  Avg loss:0.344583
#
# Start validation.
# Done. Time:0.2695205170000463
# Validation performance:
#  Avg loss:0.779800
#
# Start evaluation.
# Done. Time:1.1446170670000129
# Test performance:
#  Accuracy:75.0%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.143693 [    0/ 3881]
# loss:0.243247 [ 3200/ 3881]
# Done. Time:2.6350348949999898
# Training performance:
#  Avg loss:0.329149
#
# Start validation.
# Done. Time:0.272898046000023
# Validation performance:
#  Avg loss:0.712096
#
# Start evaluation.
# Done. Time:1.1983548729999711
# Test performance:
#  Accuracy:78.5%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.161477 [    0/ 3881]
# loss:0.570663 [ 3200/ 3881]
# Done. Time:2.553024722000032
# Training performance:
#  Avg loss:0.350018
#
# Start validation.
# Done. Time:0.2590365029999475
# Validation performance:
#  Avg loss:0.799810
#
# Start evaluation.
# Done. Time:1.3924171070000284
# Test performance:
#  Accuracy:74.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.332752 [    0/ 3881]
# loss:0.364672 [ 3200/ 3881]
# Done. Time:4.503362459999948
# Training performance:
#  Avg loss:0.319879
#
# Start validation.
# Done. Time:0.26986788199997136
# Validation performance:
#  Avg loss:0.608413
#
# Start evaluation.
# Done. Time:1.174528701999975
# Test performance:
#  Accuracy:80.0%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.414835 [    0/ 3881]
# loss:0.513077 [ 3200/ 3881]
# Done. Time:2.6313998870000432
# Training performance:
#  Avg loss:0.322959
#
# Start validation.
# Done. Time:0.27463864300000296
# Validation performance:
#  Avg loss:0.708514
#
# Start evaluation.
# Done. Time:1.185859961999995
# Test performance:
#  Accuracy:76.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.343165 [    0/ 3881]
# loss:0.429004 [ 3200/ 3881]
# Done. Time:2.620807634000016
# Training performance:
#  Avg loss:0.333574
#
# Start validation.
# Done. Time:0.2630028720000155
# Validation performance:
#  Avg loss:0.696733
#
# Start evaluation.
# Done. Time:1.1752174539999487
# Test performance:
#  Accuracy:76.0%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.496075 [    0/ 3881]
# loss:0.483895 [ 3200/ 3881]
# Done. Time:4.5016255350000165
# Training performance:
#  Avg loss:0.307140
#
# Start validation.
# Done. Time:0.39895562999993217
# Validation performance:
#  Avg loss:0.687499
#
# Start evaluation.
# Done. Time:1.1929278079999222
# Test performance:
#  Accuracy:76.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.189738 [    0/ 3881]
# loss:0.134865 [ 3200/ 3881]
# Done. Time:2.6981119980000585
# Training performance:
#  Avg loss:0.314462
#
# Start validation.
# Done. Time:0.2659948450000229
# Validation performance:
#  Avg loss:0.588096
#
# Start evaluation.
# Done. Time:1.1911309639999672
# Test performance:
#  Accuracy:85.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.259931 [    0/ 3881]
# loss:0.373041 [ 3200/ 3881]
# Done. Time:2.6280245650000325
# Training performance:
#  Avg loss:0.306037
#
# Start validation.
# Done. Time:0.2697617049999508
# Validation performance:
#  Avg loss:0.600310
#
# Start evaluation.
# Done. Time:1.1771742509999967
# Test performance:
#  Accuracy:79.5%
# Minimum validation loss:0.5658157552991595 at 41 epoch.
# Maximum accuracy:85.0 at 49 epoch.

# %% [markdown]
# ### Plort result
# #### Recognition performance

# %%
import matplotlib.pyplot as plt

plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(val_losses_default)+1)
plt.plot(xs, val_losses_default, label="Default", marker=".")
plt.plot(xs, val_losses_w_daug, label="+ T-Clip", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.ylim([0.0, 2.5])
plt.legend()
plt.show()

# %%
plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(test_accs_default)+1)
plt.plot(xs, test_accs_default, label="Default", marker=".")
plt.plot(xs, test_accs_w_daug, label="+ T-Clip", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.ylim([0.0, 100.0])
plt.legend()
plt.show()
