# %% [markdown]
# <a href="https://colab.research.google.com/github/takayama-rado/trado_samples/blob/main/colab_files/gislr_transformer_encoder_daug_tclip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Download dataset and modules

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Copy to local.
# !cp drive/MyDrive/Datasets/gislr_dataset_top10.zip gislr_top10.zip

# %%
# !unzip -o gislr_top10.zip
# Out:
# Archive:  gislr_top10.zip
#    creating: dataset_top10/
#   inflating: dataset_top10/16069.hdf5
#   inflating: dataset_top10/18796.hdf5
#   inflating: dataset_top10/2044.hdf5
#   inflating: dataset_top10/22343.hdf5
#   inflating: dataset_top10/25571.hdf5
#   inflating: dataset_top10/26734.hdf5
#   inflating: dataset_top10/27610.hdf5
#   inflating: dataset_top10/28656.hdf5
#   inflating: dataset_top10/29302.hdf5
#   inflating: dataset_top10/30680.hdf5
#   inflating: dataset_top10/32319.hdf5
#   inflating: dataset_top10/34503.hdf5
#   inflating: dataset_top10/36257.hdf5
#   inflating: dataset_top10/37055.hdf5
#   inflating: dataset_top10/37779.hdf5
#   inflating: dataset_top10/4718.hdf5
#   inflating: dataset_top10/49445.hdf5
#   inflating: dataset_top10/53618.hdf5
#   inflating: dataset_top10/55372.hdf5
#   inflating: dataset_top10/61333.hdf5
#   inflating: dataset_top10/62590.hdf5
#   inflating: dataset_top10/LICENSE.txt
#   inflating: dataset_top10/sign_to_prediction_index_map.json

# %%
# !ls dataset_top10
# Out:
# 16069.hdf5  25571.hdf5	29302.hdf5  36257.hdf5	49445.hdf5  62590.hdf5
# 18796.hdf5  26734.hdf5	30680.hdf5  37055.hdf5	53618.hdf5  LICENSE.txt
# 2044.hdf5   27610.hdf5	32319.hdf5  37779.hdf5	55372.hdf5  sign_to_prediction_index_map.json
# 22343.hdf5  28656.hdf5	34503.hdf5  4718.hdf5	61333.hdf5

# %%
# !cat dataset_top10/sign_to_prediction_index_map.json
# Out:
# {
#     "listen": 0,
#     "look": 1,
#     "shhh": 2,
#     "donkey": 3,
#     "mouse": 4,
#     "duck": 5,
#     "uncle": 6,
#     "hear": 7,
#     "pretend": 8,
#     "cow": 9
# }

# %%
# !cat dataset_top10/LICENSE.txt
# Out:
# The dataset provided by Natsuki Takayama (Takayama Research and Development Office) is licensed under CC-BY 4.0.
# Author: Copyright 2024 Natsuki Takayama
# Title: GISLR Top 10 dataset
# Original licenser: Deaf Professional Arts Network and the Georgia Institute of Technology
# Modification
# - Extract 10 most frequent words.
# - Packaged into HDF5 format.

# %%
import h5py
with h5py.File("dataset_top10/16069.hdf5", "r") as fread:
    keys = list(fread.keys())
    print(keys)
    group = fread[keys[0]]
    print(group.keys())
    feature = group["feature"][:]
    token = group["token"][:]
    print(feature.shape)
    print(token)
# Out:
# ['1109479272', '11121526', '1120349077', '1125456612', '1159046211', '1169128497', '1186032553', '1223803476', '1259708636', '1281972067', '129232566', '1334702305', '1340979012', '1352964057', '1370052047', '1383455381', '1431148933', '1435203624', '1437919781', '1458770030', '1462881097', '1469867050', '1474050058', '147607644', '1513539919', '1520635928', '1524297234', '153676122', '1537751003', '1542212461', '1551759770', '158232956', '1585855916', '1632709119', '1638742455', '1696757219', '177479476', '1779635114', '1791684792', '1801566440', '1831167282', '1867385690', '1880570146', '1901587887', '1910121429', '1919659282', '192873038', '1935012113', '1949620203', '195098847', '1983552660', '1989475963', '1998715062', '2007709802', '2036010239', '2036360025', '2046296211', '2082116372', '2098813002', '2109640010', '2121879330', '2141852087', '2148832702', '2152013823', '2166805079', '2176613834', '2184232774', '2213965523', '2249630763', '2256677805', '2263287955', '2263683020', '2264826605', '2270117351', '2281372282', '2285328250', '2322449232', '2326092712', '2336131857', '2346410171', '2405684784', '2467219838', '2473091535', '2488751095', '2515673021', '252176572', '2555449229', '2601816518', '2624310025', '2672738462', '2679264929', '2708514724', '2708544445', '2721276879', '2723773273', '2728839865', '2740241949', '2758304792', '2772051790', '2779816680', '2804441762', '2811346655', '2811646800', '2820103955', '2839681895', '2900998385', '2976200180', '2994456336', '3057994128', '3095010437', '3104317075', '3109672704', '3137179145', '3153285641', '3173321541', '3181666887', '3201889607', '3208820205', '3248401349', '3280527321', '3283246198', '3300057240', '3355963469', '3378306304', '3383637897', '3395075403', '3399503065', '3417877266', '3433092803', '347484677', '348956807', '3490841593', '3509324997', '3527069516', '3537611572', '3543711249', '3550826234', '3574700791', '3577812263', '3608551465', '3609537739', '3622960580', '3666781780', '3701422761', '3721927307', '3751410902', '3756613238', '3769544385', '3783554953', '3794712078', '380369091', '3813230821', '3817572483', '3843929707', '3869664504', '3892179393', '3923913515', '3981562204', '4078929101', '4101587978', '4150900444', '4191136837', '4200829752', '4209136328', '420958416', '422113773', '42222766', '4233346443', '4233985575', '4236057556', '4252161228', '425542996', '4276854486', '4294775577', '431609031', '439844759', '446236576', '470582324', '472128010', '492897929', '537402693', '5501547', '561170018', '593416697', '631898947', '649410423', '654529993', '678960043', '699907539', '707716966', '713615518', '778875120', '792981518', '796465415', '798649922', '856068671', '923153024', '957739544', '970593849', '976754415']
# <KeysViewHDF5 ['feature', 'token']>
# (3, 23, 543)
# [1]

# %%
# !wget https://github.com/takayama-rado/trado_samples/archive/master.zip
# Out:
# --2024-05-10 23:35:43--  https://github.com/takayama-rado/trado_samples/archive/master.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/takayama-rado/trado_samples/zip/main [following]
# --2024-05-10 23:35:43--  https://codeload.github.com/takayama-rado/trado_samples/zip/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [            <=>     ]  74.93M  17.9MB/s    in 4.2s
#
# 2024-05-10 23:35:48 (17.9 MB/s) - ‘master.zip’ saved [78568554]

# %%
# !unzip -o master.zip -d master
# Out:
# Archive:  master.zip
# 02dfcf052bf69c6239c4ce2da14250d7e2bad802
#    creating: master/trado_samples-main/
#   inflating: master/trado_samples-main/.gitignore
#   inflating: master/trado_samples-main/LICENSE
#   inflating: master/trado_samples-main/README.md
#    creating: master/trado_samples-main/colab_files/
#  extracting: master/trado_samples-main/colab_files/.gitkeep
#   inflating: master/trado_samples-main/colab_files/exp_affine_np_einsum.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_jax_static.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_mpholistic_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_mpothers_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_jax.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_numpy.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_tensorflow.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_affine_torch.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_jax.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_numpy_0.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_numpy_1.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_tensorflow.ipynb
#   inflating: master/trado_samples-main/colab_files/exp_track_interp_torch.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_access_dataset.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_normalize_landmarks.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_rnn_islr_model_1.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_rnn_islr_model_2.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_rnn_islr_model_3.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_select_landmarks.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_simple_attention.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_simple_islr_model.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_transformer_encoder.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_transformer_encoder_daug_hflip.ipynb
#   inflating: master/trado_samples-main/colab_files/gislr_transformer_encoder_w_ls.ipynb
#    creating: master/trado_samples-main/src/
#    creating: master/trado_samples-main/src/modules_gislr/
#  extracting: master/trado_samples-main/src/modules_gislr/__init__.py
#   inflating: master/trado_samples-main/src/modules_gislr/dataset.py
#   inflating: master/trado_samples-main/src/modules_gislr/defines.py
#   inflating: master/trado_samples-main/src/modules_gislr/draw_functions.py
#   inflating: master/trado_samples-main/src/modules_gislr/layers.py
#   inflating: master/trado_samples-main/src/modules_gislr/train_functions.py
#   inflating: master/trado_samples-main/src/modules_gislr/transforms.py
#   inflating: master/trado_samples-main/src/modules_gislr/utils.py
#    creating: master/trado_samples-main/test_data/
#   inflating: master/trado_samples-main/test_data/finger_far0.mp4
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static.npy
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static_affine.npy
#   inflating: master/trado_samples-main/test_data/finger_far0_non_static_interp.npy
#   inflating: master/trado_samples-main/test_data/finger_middle0.mp4
#   inflating: master/trado_samples-main/test_data/finger_near0.mp4
#   inflating: master/trado_samples-main/test_data/hand_only.mp4

# %%
# !mv master/trado_samples-main/src/modules_gislr .

# %%
# !rm -rf master master.zip gislr_top10.zip

# %%
# !ls
# Out:
# dataset_top10  drive  modules_gislr  sample_data

# %% [markdown]
# # 2. Load library

# %%
import copy
import json
import math
import os
import random
import sys
from functools import partial
from inspect import signature
from pathlib import Path
from typing import (
    Any,
    Dict,
    List
)

# Third party's modules
import numpy as np

import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import (
    DataLoader)

from torchvision.transforms import Compose

# Local modules
sys.path.append("modules_gislr")
from modules_gislr.dataset import (
    HDF5Dataset,
    merge_padded_batch)
from modules_gislr.defines import (
    get_fullbody_landmarks
)
from modules_gislr.layers import (
    Identity,
    GPoolRecognitionHead,
    TransformerEnISLR
)
from modules_gislr.train_functions import (
    test_loop,
    val_loop,
    train_loop
)
from modules_gislr.transforms import (
    PartsBasedNormalization,
    ReplaceNan,
    SelectLandmarksAndFeature,
    ToTensor
)

# %% [markdown]
# # 3. Implement temporal clipping.

# %%
class RandomClip():
    """Clip sequence randomly.

    # Args:
      - apply_ratio: The ratio to apply augmentation.
      - clip_range: The range of clipping.
      - offset: The offset of clip range.
        if offset < 0, this is determined randomly.
      - min_apply_size: The minimum temporal length to apply augmentation.
    """
    def __init__(self,
                 apply_ratio,
                 clip_range,
                 offset=-1,
                 min_apply_size=10):
        self.apply_ratio = apply_ratio
        self.clip_range = clip_range
        self.offset = offset
        self.min_apply_size = min_apply_size

    def __call__(self,
                 data: Dict[str, Any]) -> Dict[str, Any]:
        """Execute clipping.
        """
        if random.random() > self.apply_ratio:
            return data

        feature = data["feature"]
        base_timelen = feature.shape[1]
        if base_timelen > self.min_apply_size:
            aug_tscale = np.random.random() * (self.clip_range[1] - self.clip_range[0]) + self.clip_range[0]
            aug_timelen = int(base_timelen * (1 - aug_tscale))
            if aug_timelen < base_timelen:
                if self.offset < 0:
                    offset = np.random.randint(0, base_timelen - aug_timelen)
                else:
                    offset = self.offset
                # `[C, T, J]`
                feature = feature[:, offset: aug_timelen + offset, :]

        data["feature"] = feature
        return data

    def __str__(self):
        return f"{self.__class__.__name__}:{self.__dict__}"

# %% [markdown]
# # 4. Sanity check

# %%
# Access check.
dataset_dir = Path("dataset_top10")
files = list(dataset_dir.iterdir())
dictionary = [fin for fin in files if ".json" in fin.name][0]
hdf5_files = [fin for fin in files if ".hdf5" in fin.name]

print(dictionary)
print(hdf5_files)
# Out:
# dataset_top10/sign_to_prediction_index_map.json
# [PosixPath('dataset_top10/53618.hdf5'), PosixPath('dataset_top10/22343.hdf5'), PosixPath('dataset_top10/28656.hdf5'), PosixPath('dataset_top10/27610.hdf5'), PosixPath('dataset_top10/37055.hdf5'), PosixPath('dataset_top10/26734.hdf5'), PosixPath('dataset_top10/55372.hdf5'), PosixPath('dataset_top10/36257.hdf5'), PosixPath('dataset_top10/61333.hdf5'), PosixPath('dataset_top10/2044.hdf5'), PosixPath('dataset_top10/4718.hdf5'), PosixPath('dataset_top10/18796.hdf5'), PosixPath('dataset_top10/34503.hdf5'), PosixPath('dataset_top10/62590.hdf5'), PosixPath('dataset_top10/49445.hdf5'), PosixPath('dataset_top10/30680.hdf5'), PosixPath('dataset_top10/32319.hdf5'), PosixPath('dataset_top10/37779.hdf5'), PosixPath('dataset_top10/25571.hdf5'), PosixPath('dataset_top10/29302.hdf5'), PosixPath('dataset_top10/16069.hdf5')]

# %%
# Load dictionary.
with open(dictionary, "r") as fread:
    key2token = json.load(fread)

VOCAB = len(key2token)

# %%
_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
trans_select_feature = SelectLandmarksAndFeature(landmarks=use_landmarks, features=use_features)
trans_repnan = ReplaceNan()
trans_norm = PartsBasedNormalization(align_mode="framewise", scale_mode="unique")

pre_transforms = Compose([trans_select_feature,
                          trans_repnan,
                          trans_norm])
transforms_default = Compose([ToTensor()])

transforms_w_daug = Compose([
    RandomClip(
        apply_ratio=0.5,
        clip_range=(0.1, 0.3)),
    ToTensor()])

# %%
batch_size = 2
feature_shape = (len(use_features), -1, len(use_landmarks))
token_shape = (1,)
merge_fn = partial(merge_padded_batch,
                   feature_shape=feature_shape,
                   token_shape=token_shape,
                   feature_padding_val=0.0,
                   token_padding_val=0)

dataset = HDF5Dataset(hdf5_files, pre_transforms=pre_transforms, transforms=transforms_w_daug)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=merge_fn)
try:
    data = next(iter(dataloader))
    feature_origin = data["feature"]

    print(feature_origin.shape)
except Exception as inst:
    print(inst)
# Out:
# torch.Size([2, 2, 51, 130])

# %%
# Define model.
# in_channels: J * C (130*2=260)
#   J: use_landmarks (130)
#   C: use_channels (2)
# out_channels: 10
in_channels = len(use_landmarks) * len(use_features)
inter_channels = 64
out_channels = VOCAB
activation = "relu"
tren_num_layers = 2
tren_num_heads = 2
tren_dim_ffw = 256
tren_dropout_pe = 0.1
tren_dropout = 0.1
tren_layer_norm_eps = 1e-5
tren_norm_first = True
tren_add_bias = True
tren_add_tailnorm = True

model = TransformerEnISLR(in_channels=in_channels,
                          inter_channels=inter_channels,
                          out_channels=out_channels,
                          activation=activation,
                          tren_num_layers=tren_num_layers,
                          tren_num_heads=tren_num_heads,
                          tren_dim_ffw=tren_dim_ffw,
                          tren_dropout_pe=tren_dropout_pe,
                          tren_dropout=tren_dropout,
                          tren_layer_norm_eps=tren_layer_norm_eps,
                          tren_norm_first=tren_norm_first,
                          tren_add_bias=tren_add_bias,
                          tren_add_tailnorm=tren_add_tailnorm)
print(model)

# Sanity check.
logit = model(feature_origin)
print(logit.shape)
attw0 = model.tr_encoder.layers[0].attw.detach().cpu().numpy()
attw1 = model.tr_encoder.layers[0].attw.detach().cpu().numpy()
print(attw0.shape, attw1.shape)
# Out:
# TransformerEnISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (tr_encoder): TransformerEncoder(
#     (pos_encoder): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (w_key): Linear(in_features=64, out_features=64, bias=True)
#           (w_value): Linear(in_features=64, out_features=64, bias=True)
#           (w_query): Linear(in_features=64, out_features=64, bias=True)
#           (w_out): Linear(in_features=64, out_features=64, bias=True)
#           (dropout_attn): Dropout(p=0.1, inplace=False)
#         )
#         (ffw): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=256, bias=True)
#           (w_2): Linear(in_features=256, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#         (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# torch.Size([2, 10])
# (2, 2, 51, 51) (2, 2, 51, 51)

# %% [markdown]
# # 5. Train and evaluation

# %% [markdown]
# ## 5.1 Set common parameters.

# %%
# Set common parameters.
batch_size = 32
load_into_ram = True
test_pid = 16069
num_workers = os.cpu_count()
print(f"Using {num_workers} cores for data loading.")
lr = 3e-4

epochs = 50
eval_every_n_epochs = 1
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} for computation.")

train_hdf5files = [fin for fin in hdf5_files if str(test_pid) not in fin.name]
val_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]
test_hdf5files = [fin for fin in hdf5_files if str(test_pid) in fin.name]

_, use_landmarks = get_fullbody_landmarks()
use_features = ["x", "y"]
# Out:
# Using 2 cores for data loading.
# Using cuda for computation.

# %% [markdown]
# ## 5.2 Run training process

# %% [markdown]
# ### Default settings

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(
    train_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_default,
    load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(
    val_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_default,
    load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(
    test_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_default,
    load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)

# %%
tren_norm_first = True
tren_add_tailnorm = True

model_default = TransformerEnISLR(
    in_channels=in_channels,
    inter_channels=inter_channels,
    out_channels=out_channels,
    activation=activation,
    tren_num_layers=tren_num_layers,
    tren_num_heads=tren_num_heads,
    tren_dim_ffw=tren_dim_ffw,
    tren_dropout_pe=tren_dropout_pe,
    tren_dropout=tren_dropout,
    tren_layer_norm_eps=tren_layer_norm_eps,
    tren_norm_first=tren_norm_first,
    tren_add_bias=tren_add_bias,
    tren_add_tailnorm=tren_add_tailnorm)
print(model_default)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model_default.parameters(), lr=lr)
# Out:
# TransformerEnISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (tr_encoder): TransformerEncoder(
#     (pos_encoder): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (w_key): Linear(in_features=64, out_features=64, bias=True)
#           (w_value): Linear(in_features=64, out_features=64, bias=True)
#           (w_query): Linear(in_features=64, out_features=64, bias=True)
#           (w_out): Linear(in_features=64, out_features=64, bias=True)
#           (dropout_attn): Dropout(p=0.1, inplace=False)
#         )
#         (ffw): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=256, bias=True)
#           (w_2): Linear(in_features=256, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#         (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model_default.to(device)

train_losses = []
val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_losses = train_loop(train_dataloader, model_default, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model_default, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model_default, device)
        test_accs.append(acc)
train_losses_default = np.array(train_losses)
val_losses_default = np.array(val_losses)
test_accs_default = np.array(test_accs)

print(f"Minimum validation loss:{val_losses_default.min()} at {np.argmin(val_losses_default)+1} epoch.")
print(f"Maximum accuracy:{test_accs_default.max()} at {np.argmax(test_accs_default)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# loss:5.268224 [    0/ 3881]
# loss:2.055366 [ 3200/ 3881]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Done. Time:5.1784009909999895
# Training performance:
#  Avg loss:2.192806
#
# Start validation.
# Done. Time:0.23157469800000285
# Validation performance:
#  Avg loss:2.074346
#
# Start evaluation.
# Done. Time:1.1308482379999987
# Test performance:
#  Accuracy:28.0%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:1.791945 [    0/ 3881]
# loss:1.431693 [ 3200/ 3881]
# Done. Time:2.603811315999991
# Training performance:
#  Avg loss:1.576821
#
# Start validation.
# Done. Time:0.22614887299999964
# Validation performance:
#  Avg loss:1.799592
#
# Start evaluation.
# Done. Time:1.0752466020000213
# Test performance:
#  Accuracy:43.0%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.642232 [    0/ 3881]
# loss:1.601364 [ 3200/ 3881]
# Done. Time:2.5920861140000113
# Training performance:
#  Avg loss:1.277053
#
# Start validation.
# Done. Time:0.21355970199999774
# Validation performance:
#  Avg loss:1.605577
#
# Start evaluation.
# Done. Time:1.325265829999978
# Test performance:
#  Accuracy:47.0%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.139080 [    0/ 3881]
# loss:0.973677 [ 3200/ 3881]
# Done. Time:5.167703926999991
# Training performance:
#  Avg loss:1.049967
#
# Start validation.
# Done. Time:0.2236250549999852
# Validation performance:
#  Avg loss:1.471948
#
# Start evaluation.
# Done. Time:1.087618512000006
# Test performance:
#  Accuracy:52.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:1.064149 [    0/ 3881]
# loss:0.698665 [ 3200/ 3881]
# Done. Time:2.5920544610000036
# Training performance:
#  Avg loss:0.908182
#
# Start validation.
# Done. Time:0.22259436799998866
# Validation performance:
#  Avg loss:1.405416
#
# Start evaluation.
# Done. Time:1.0854392699999948
# Test performance:
#  Accuracy:49.0%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:0.745090 [    0/ 3881]
# loss:0.692139 [ 3200/ 3881]
# Done. Time:2.8925600129999793
# Training performance:
#  Avg loss:0.811977
#
# Start validation.
# Done. Time:0.22541725499999643
# Validation performance:
#  Avg loss:1.328732
#
# Start evaluation.
# Done. Time:1.315027065999999
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:0.866169 [    0/ 3881]
# loss:0.775802 [ 3200/ 3881]
# Done. Time:4.298064268000019
# Training performance:
#  Avg loss:0.732599
#
# Start validation.
# Done. Time:0.23680642799999418
# Validation performance:
#  Avg loss:1.169653
#
# Start evaluation.
# Done. Time:1.0876633480000066
# Test performance:
#  Accuracy:61.0%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:0.662253 [    0/ 3881]
# loss:0.537632 [ 3200/ 3881]
# Done. Time:2.5702225560000045
# Training performance:
#  Avg loss:0.687616
#
# Start validation.
# Done. Time:0.3062757180000233
# Validation performance:
#  Avg loss:1.190117
#
# Start evaluation.
# Done. Time:1.1592557890000137
# Test performance:
#  Accuracy:59.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:0.675368 [    0/ 3881]
# loss:0.867559 [ 3200/ 3881]
# Done. Time:2.6107808890000115
# Training performance:
#  Avg loss:0.638093
#
# Start validation.
# Done. Time:0.22582415399998013
# Validation performance:
#  Avg loss:0.969174
#
# Start evaluation.
# Done. Time:1.1366515420000098
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:0.441742 [    0/ 3881]
# loss:0.763862 [ 3200/ 3881]
# Done. Time:4.506207904999997
# Training performance:
#  Avg loss:0.583668
#
# Start validation.
# Done. Time:0.3443251669999938
# Validation performance:
#  Avg loss:1.083814
#
# Start evaluation.
# Done. Time:1.0882551729999932
# Test performance:
#  Accuracy:59.5%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:0.523100 [    0/ 3881]
# loss:0.747515 [ 3200/ 3881]
# Done. Time:2.659171072999982
# Training performance:
#  Avg loss:0.545161
#
# Start validation.
# Done. Time:0.2246366939999973
# Validation performance:
#  Avg loss:0.826899
#
# Start evaluation.
# Done. Time:1.0877551310000229
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:0.445505 [    0/ 3881]
# loss:0.580119 [ 3200/ 3881]
# Done. Time:2.5937311410000063
# Training performance:
#  Avg loss:0.519410
#
# Start validation.
# Done. Time:0.21976204400002075
# Validation performance:
#  Avg loss:1.020423
#
# Start evaluation.
# Done. Time:1.1056570549999947
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:0.225890 [    0/ 3881]
# loss:0.730511 [ 3200/ 3881]
# Done. Time:3.705969011999997
# Training performance:
#  Avg loss:0.494514
#
# Start validation.
# Done. Time:0.3384503579999887
# Validation performance:
#  Avg loss:0.936915
#
# Start evaluation.
# Done. Time:1.528454148999998
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:0.772759 [    0/ 3881]
# loss:0.408234 [ 3200/ 3881]
# Done. Time:2.772211456000008
# Training performance:
#  Avg loss:0.461778
#
# Start validation.
# Done. Time:0.22011024400001133
# Validation performance:
#  Avg loss:0.748853
#
# Start evaluation.
# Done. Time:1.112908368999996
# Test performance:
#  Accuracy:75.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:0.415881 [    0/ 3881]
# loss:0.681936 [ 3200/ 3881]
# Done. Time:2.599865784000002
# Training performance:
#  Avg loss:0.440920
#
# Start validation.
# Done. Time:0.2231762829999866
# Validation performance:
#  Avg loss:0.809865
#
# Start evaluation.
# Done. Time:1.0929119570000125
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:0.354355 [    0/ 3881]
# loss:0.167489 [ 3200/ 3881]
# Done. Time:2.768330806000023
# Training performance:
#  Avg loss:0.418679
#
# Start validation.
# Done. Time:0.37043017499999564
# Validation performance:
#  Avg loss:0.639094
#
# Start evaluation.
# Done. Time:1.3871065570000098
# Test performance:
#  Accuracy:76.5%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:0.487655 [    0/ 3881]
# loss:0.525283 [ 3200/ 3881]
# Done. Time:4.074895632000022
# Training performance:
#  Avg loss:0.421228
#
# Start validation.
# Done. Time:0.2256504780000057
# Validation performance:
#  Avg loss:0.668374
#
# Start evaluation.
# Done. Time:1.100172439000005
# Test performance:
#  Accuracy:79.0%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:0.515579 [    0/ 3881]
# loss:0.376900 [ 3200/ 3881]
# Done. Time:2.6283301930000107
# Training performance:
#  Avg loss:0.390574
#
# Start validation.
# Done. Time:0.22754080900000417
# Validation performance:
#  Avg loss:0.815472
#
# Start evaluation.
# Done. Time:1.1321398270000032
# Test performance:
#  Accuracy:72.0%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:0.426372 [    0/ 3881]
# loss:0.336858 [ 3200/ 3881]
# Done. Time:2.6220089690000066
# Training performance:
#  Avg loss:0.366076
#
# Start validation.
# Done. Time:0.23487996699998348
# Validation performance:
#  Avg loss:0.691036
#
# Start evaluation.
# Done. Time:1.175328363999995
# Test performance:
#  Accuracy:75.5%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:0.254716 [    0/ 3881]
# loss:0.321245 [ 3200/ 3881]
# Done. Time:4.500637769000008
# Training performance:
#  Avg loss:0.365636
#
# Start validation.
# Done. Time:0.36567966900000215
# Validation performance:
#  Avg loss:0.675157
#
# Start evaluation.
# Done. Time:1.109204941999991
# Test performance:
#  Accuracy:79.0%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:0.610644 [    0/ 3881]
# loss:0.215430 [ 3200/ 3881]
# Done. Time:2.6614506180000035
# Training performance:
#  Avg loss:0.342436
#
# Start validation.
# Done. Time:0.22552492100001587
# Validation performance:
#  Avg loss:0.766457
#
# Start evaluation.
# Done. Time:1.1353883380000127
# Test performance:
#  Accuracy:76.5%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:0.305985 [    0/ 3881]
# loss:0.541581 [ 3200/ 3881]
# Done. Time:2.5591544939999835
# Training performance:
#  Avg loss:0.338658
#
# Start validation.
# Done. Time:0.25127743799998825
# Validation performance:
#  Avg loss:0.742220
#
# Start evaluation.
# Done. Time:1.1056291200000032
# Test performance:
#  Accuracy:73.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:0.281883 [    0/ 3881]
# loss:0.484460 [ 3200/ 3881]
# Done. Time:3.779939741000021
# Training performance:
#  Avg loss:0.330426
#
# Start validation.
# Done. Time:0.36151680500000793
# Validation performance:
#  Avg loss:0.752719
#
# Start evaluation.
# Done. Time:1.4299371480000218
# Test performance:
#  Accuracy:73.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:0.289179 [    0/ 3881]
# loss:0.356374 [ 3200/ 3881]
# Done. Time:4.788956928000005
# Training performance:
#  Avg loss:0.336326
#
# Start validation.
# Done. Time:0.3567106870000316
# Validation performance:
#  Avg loss:0.717823
#
# Start evaluation.
# Done. Time:1.1189468499999862
# Test performance:
#  Accuracy:75.0%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:0.267676 [    0/ 3881]
# loss:0.624561 [ 3200/ 3881]
# Done. Time:2.6416782329999933
# Training performance:
#  Avg loss:0.301656
#
# Start validation.
# Done. Time:0.2296141509999643
# Validation performance:
#  Avg loss:0.881032
#
# Start evaluation.
# Done. Time:1.4209946830000035
# Test performance:
#  Accuracy:66.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:0.287267 [    0/ 3881]
# loss:0.307487 [ 3200/ 3881]
# Done. Time:4.262648813999988
# Training performance:
#  Avg loss:0.313926
#
# Start validation.
# Done. Time:0.23867658599999686
# Validation performance:
#  Avg loss:0.835401
#
# Start evaluation.
# Done. Time:1.1008240320000482
# Test performance:
#  Accuracy:73.5%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:0.171852 [    0/ 3881]
# loss:0.206504 [ 3200/ 3881]
# Done. Time:2.565071773999989
# Training performance:
#  Avg loss:0.292899
#
# Start validation.
# Done. Time:0.2242311480000012
# Validation performance:
#  Avg loss:0.691829
#
# Start evaluation.
# Done. Time:1.0979878050000025
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.257135 [    0/ 3881]
# loss:0.228303 [ 3200/ 3881]
# Done. Time:2.689424115999998
# Training performance:
#  Avg loss:0.282537
#
# Start validation.
# Done. Time:0.22112167999995336
# Validation performance:
#  Avg loss:0.741860
#
# Start evaluation.
# Done. Time:1.0928940789999615
# Test performance:
#  Accuracy:75.5%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.197640 [    0/ 3881]
# loss:0.255216 [ 3200/ 3881]
# Done. Time:4.415286859999981
# Training performance:
#  Avg loss:0.288117
#
# Start validation.
# Done. Time:0.39589161100002457
# Validation performance:
#  Avg loss:0.696375
#
# Start evaluation.
# Done. Time:1.1308799059999615
# Test performance:
#  Accuracy:80.0%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.208996 [    0/ 3881]
# loss:0.573969 [ 3200/ 3881]
# Done. Time:2.6750157440000066
# Training performance:
#  Avg loss:0.282349
#
# Start validation.
# Done. Time:0.24701396000000386
# Validation performance:
#  Avg loss:0.776211
#
# Start evaluation.
# Done. Time:1.1112538339999674
# Test performance:
#  Accuracy:75.5%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.114830 [    0/ 3881]
# loss:0.307931 [ 3200/ 3881]
# Done. Time:2.6998376810000195
# Training performance:
#  Avg loss:0.302308
#
# Start validation.
# Done. Time:0.2410709899999688
# Validation performance:
#  Avg loss:0.566581
#
# Start evaluation.
# Done. Time:1.089509975999988
# Test performance:
#  Accuracy:80.5%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.275466 [    0/ 3881]
# loss:0.156083 [ 3200/ 3881]
# Done. Time:3.7872485529999835
# Training performance:
#  Avg loss:0.258836
#
# Start validation.
# Done. Time:0.35043467499997405
# Validation performance:
#  Avg loss:0.762803
#
# Start evaluation.
# Done. Time:1.3163744529999803
# Test performance:
#  Accuracy:74.0%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.153530 [    0/ 3881]
# loss:0.109641 [ 3200/ 3881]
# Done. Time:2.6213310240000283
# Training performance:
#  Avg loss:0.255266
#
# Start validation.
# Done. Time:0.2416055989999677
# Validation performance:
#  Avg loss:0.604971
#
# Start evaluation.
# Done. Time:1.107032434999951
# Test performance:
#  Accuracy:83.5%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.167585 [    0/ 3881]
# loss:0.500018 [ 3200/ 3881]
# Done. Time:2.5813424130000158
# Training performance:
#  Avg loss:0.258828
#
# Start validation.
# Done. Time:0.2433543579999764
# Validation performance:
#  Avg loss:0.840866
#
# Start evaluation.
# Done. Time:1.1192167510000104
# Test performance:
#  Accuracy:73.5%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.131499 [    0/ 3881]
# loss:0.141746 [ 3200/ 3881]
# Done. Time:3.264480792000029
# Training performance:
#  Avg loss:0.246269
#
# Start validation.
# Done. Time:0.3798308369999859
# Validation performance:
#  Avg loss:0.672877
#
# Start evaluation.
# Done. Time:1.581251873000042
# Test performance:
#  Accuracy:77.5%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.102127 [    0/ 3881]
# loss:0.170827 [ 3200/ 3881]
# Done. Time:2.733730134000041
# Training performance:
#  Avg loss:0.235719
#
# Start validation.
# Done. Time:0.22612957600000527
# Validation performance:
#  Avg loss:0.622720
#
# Start evaluation.
# Done. Time:1.1346813030000362
# Test performance:
#  Accuracy:81.5%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.534994 [    0/ 3881]
# loss:0.337229 [ 3200/ 3881]
# Done. Time:2.7484711199999765
# Training performance:
#  Avg loss:0.235903
#
# Start validation.
# Done. Time:0.22600215699998216
# Validation performance:
#  Avg loss:1.064859
#
# Start evaluation.
# Done. Time:1.1307300640000335
# Test performance:
#  Accuracy:73.0%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.254832 [    0/ 3881]
# loss:0.190881 [ 3200/ 3881]
# Done. Time:3.138267886000051
# Training performance:
#  Avg loss:0.230379
#
# Start validation.
# Done. Time:0.3495678000000453
# Validation performance:
#  Avg loss:0.784652
#
# Start evaluation.
# Done. Time:1.4560510869999916
# Test performance:
#  Accuracy:77.0%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.228385 [    0/ 3881]
# loss:0.239174 [ 3200/ 3881]
# Done. Time:3.6564647419999687
# Training performance:
#  Avg loss:0.223882
#
# Start validation.
# Done. Time:0.21951681299998427
# Validation performance:
#  Avg loss:0.697361
#
# Start evaluation.
# Done. Time:1.1000833140000168
# Test performance:
#  Accuracy:80.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.194665 [    0/ 3881]
# loss:0.202158 [ 3200/ 3881]
# Done. Time:2.6455055669999865
# Training performance:
#  Avg loss:0.224661
#
# Start validation.
# Done. Time:0.22605873700001666
# Validation performance:
#  Avg loss:0.728326
#
# Start evaluation.
# Done. Time:1.096793802000036
# Test performance:
#  Accuracy:78.0%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.276810 [    0/ 3881]
# loss:0.121115 [ 3200/ 3881]
# Done. Time:2.5881368909999765
# Training performance:
#  Avg loss:0.207690
#
# Start validation.
# Done. Time:0.23396596899999622
# Validation performance:
#  Avg loss:0.843834
#
# Start evaluation.
# Done. Time:1.3293511699999954
# Test performance:
#  Accuracy:73.5%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.097096 [    0/ 3881]
# loss:0.248224 [ 3200/ 3881]
# Done. Time:4.362934670000016
# Training performance:
#  Avg loss:0.209069
#
# Start validation.
# Done. Time:0.22509339399999817
# Validation performance:
#  Avg loss:0.777183
#
# Start evaluation.
# Done. Time:1.119095802000004
# Test performance:
#  Accuracy:75.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.060137 [    0/ 3881]
# loss:0.108558 [ 3200/ 3881]
# Done. Time:2.6032662050000113
# Training performance:
#  Avg loss:0.215200
#
# Start validation.
# Done. Time:0.2236722160000113
# Validation performance:
#  Avg loss:0.727461
#
# Start evaluation.
# Done. Time:1.1538587709999888
# Test performance:
#  Accuracy:78.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.288403 [    0/ 3881]
# loss:0.063672 [ 3200/ 3881]
# Done. Time:2.6749360820000447
# Training performance:
#  Avg loss:0.203419
#
# Start validation.
# Done. Time:0.22315929699999515
# Validation performance:
#  Avg loss:0.871638
#
# Start evaluation.
# Done. Time:1.1018804539999678
# Test performance:
#  Accuracy:76.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.207329 [    0/ 3881]
# loss:0.531281 [ 3200/ 3881]
# Done. Time:4.3471885550000025
# Training performance:
#  Avg loss:0.204504
#
# Start validation.
# Done. Time:0.3549640859999954
# Validation performance:
#  Avg loss:0.969245
#
# Start evaluation.
# Done. Time:1.1239712480000321
# Test performance:
#  Accuracy:71.5%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.064553 [    0/ 3881]
# loss:0.160284 [ 3200/ 3881]
# Done. Time:2.6526524379999614
# Training performance:
#  Avg loss:0.186650
#
# Start validation.
# Done. Time:0.24301273899999387
# Validation performance:
#  Avg loss:0.669549
#
# Start evaluation.
# Done. Time:1.133436076999999
# Test performance:
#  Accuracy:78.5%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.250798 [    0/ 3881]
# loss:0.259394 [ 3200/ 3881]
# Done. Time:2.621530034999978
# Training performance:
#  Avg loss:0.186854
#
# Start validation.
# Done. Time:0.2270657479999727
# Validation performance:
#  Avg loss:0.716726
#
# Start evaluation.
# Done. Time:1.1396556609999493
# Test performance:
#  Accuracy:78.5%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.245865 [    0/ 3881]
# loss:0.156644 [ 3200/ 3881]
# Done. Time:3.82675293799997
# Training performance:
#  Avg loss:0.203279
#
# Start validation.
# Done. Time:0.34584059299999126
# Validation performance:
#  Avg loss:0.869104
#
# Start evaluation.
# Done. Time:1.2459885559999861
# Test performance:
#  Accuracy:79.0%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.116956 [    0/ 3881]
# loss:0.313064 [ 3200/ 3881]
# Done. Time:2.6719133889999966
# Training performance:
#  Avg loss:0.196095
#
# Start validation.
# Done. Time:0.2266253509999956
# Validation performance:
#  Avg loss:0.780788
#
# Start evaluation.
# Done. Time:1.1127901680000036
# Test performance:
#  Accuracy:76.0%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.045656 [    0/ 3881]
# loss:0.197980 [ 3200/ 3881]
# Done. Time:2.6260865829999602
# Training performance:
#  Avg loss:0.168568
#
# Start validation.
# Done. Time:0.24179299399997944
# Validation performance:
#  Avg loss:0.869866
#
# Start evaluation.
# Done. Time:1.1382016919999955
# Test performance:
#  Accuracy:77.5%
# Minimum validation loss:0.566581015075956 at 31 epoch.
# Maximum accuracy:83.5 at 33 epoch.

# %% [markdown]
# ### Apply temporal clipping.

# %%
# Build dataloaders.
train_dataset = HDF5Dataset(
    train_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_w_daug,
    load_into_ram=load_into_ram)
val_dataset = HDF5Dataset(
    val_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_default,
    load_into_ram=load_into_ram)
test_dataset = HDF5Dataset(
    test_hdf5files,
    pre_transforms=pre_transforms,
    transforms=transforms_default,
    load_into_ram=load_into_ram)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=1, collate_fn=merge_fn, num_workers=num_workers, shuffle=False)

# %%
tren_norm_first = True
tren_add_tailnorm = True

model_pnorm = TransformerEnISLR(
    in_channels=in_channels,
    inter_channels=inter_channels,
    out_channels=out_channels,
    activation=activation,
    tren_num_layers=tren_num_layers,
    tren_num_heads=tren_num_heads,
    tren_dim_ffw=tren_dim_ffw,
    tren_dropout_pe=tren_dropout_pe,
    tren_dropout=tren_dropout,
    tren_layer_norm_eps=tren_layer_norm_eps,
    tren_norm_first=tren_norm_first,
    tren_add_bias=tren_add_bias,
    tren_add_tailnorm=tren_add_tailnorm)
print(model_pnorm)

loss_fn = nn.CrossEntropyLoss(reduction="mean")
optimizer = torch.optim.Adam(model_pnorm.parameters(), lr=lr)
# Out:
# TransformerEnISLR(
#   (linear): Linear(in_features=260, out_features=64, bias=True)
#   (activation): ReLU()
#   (tr_encoder): TransformerEncoder(
#     (pos_encoder): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (w_key): Linear(in_features=64, out_features=64, bias=True)
#           (w_value): Linear(in_features=64, out_features=64, bias=True)
#           (w_query): Linear(in_features=64, out_features=64, bias=True)
#           (w_out): Linear(in_features=64, out_features=64, bias=True)
#           (dropout_attn): Dropout(p=0.1, inplace=False)
#         )
#         (ffw): PositionwiseFeedForward(
#           (w_1): Linear(in_features=64, out_features=256, bias=True)
#           (w_2): Linear(in_features=256, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation): ReLU()
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#         (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (head): GPoolRecognitionHead(
#     (head): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Train, validation, and evaluation.
model_pnorm.to(device)

train_losses = []
val_losses = []
test_accs = []
print("Start training.")
for epoch in range(epochs):
    print("-" * 80)
    print(f"Epoch {epoch+1}")

    train_losses = train_loop(train_dataloader, model_pnorm, loss_fn, optimizer, device)
    val_loss = val_loop(val_dataloader, model_pnorm, loss_fn, device)
    val_losses.append(val_loss)

    if (epoch+1) % eval_every_n_epochs == 0:
        acc = test_loop(test_dataloader, model_pnorm, device)
        test_accs.append(acc)
train_losses_w_daug = np.array(train_losses)
val_losses_w_daug = np.array(val_losses)
test_accs_w_daug = np.array(test_accs)

print(f"Minimum validation loss:{val_losses_w_daug.min()} at {np.argmin(val_losses_w_daug)+1} epoch.")
print(f"Maximum accuracy:{test_accs_w_daug.max()} at {np.argmax(test_accs_w_daug)*eval_every_n_epochs+1} epoch.")
# Out:
# Start training.
# --------------------------------------------------------------------------------
# Epoch 1
# Start training.
# loss:2.664879 [    0/ 3881]
# loss:1.795605 [ 3200/ 3881]
# Done. Time:2.665047247000018
# Training performance:
#  Avg loss:2.117695
#
# Start validation.
# Done. Time:0.2852729829999703
# Validation performance:
#  Avg loss:2.041165
#
# Start evaluation.
# Done. Time:1.1537461239999516
# Test performance:
#  Accuracy:33.0%
# --------------------------------------------------------------------------------
# Epoch 2
# Start training.
# loss:1.525354 [    0/ 3881]
# loss:1.490144 [ 3200/ 3881]
# Done. Time:2.585730176000027
# Training performance:
#  Avg loss:1.512224
#
# Start validation.
# Done. Time:0.2585746740000445
# Validation performance:
#  Avg loss:1.713880
#
# Start evaluation.
# Done. Time:1.1624881600000094
# Test performance:
#  Accuracy:43.5%
# --------------------------------------------------------------------------------
# Epoch 3
# Start training.
# loss:1.173425 [    0/ 3881]
# loss:1.057014 [ 3200/ 3881]
# Done. Time:4.481809260999967
# Training performance:
#  Avg loss:1.176353
#
# Start validation.
# Done. Time:0.37895684300002586
# Validation performance:
#  Avg loss:1.471544
#
# Start evaluation.
# Done. Time:1.32379275400001
# Test performance:
#  Accuracy:45.5%
# --------------------------------------------------------------------------------
# Epoch 4
# Start training.
# loss:1.219471 [    0/ 3881]
# loss:0.730131 [ 3200/ 3881]
# Done. Time:4.463337142
# Training performance:
#  Avg loss:1.004214
#
# Start validation.
# Done. Time:0.25488908899995977
# Validation performance:
#  Avg loss:1.389668
#
# Start evaluation.
# Done. Time:1.1408199020000325
# Test performance:
#  Accuracy:55.0%
# --------------------------------------------------------------------------------
# Epoch 5
# Start training.
# loss:0.934256 [    0/ 3881]
# loss:1.183088 [ 3200/ 3881]
# Done. Time:2.797322374000032
# Training performance:
#  Avg loss:0.897345
#
# Start validation.
# Done. Time:0.38911257899997054
# Validation performance:
#  Avg loss:1.202858
#
# Start evaluation.
# Done. Time:1.5329825019999817
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 6
# Start training.
# loss:0.942101 [    0/ 3881]
# loss:0.629634 [ 3200/ 3881]
# Done. Time:4.021677554999997
# Training performance:
#  Avg loss:0.825903
#
# Start validation.
# Done. Time:0.25132475499998463
# Validation performance:
#  Avg loss:1.127344
#
# Start evaluation.
# Done. Time:1.1823898889999782
# Test performance:
#  Accuracy:60.5%
# --------------------------------------------------------------------------------
# Epoch 7
# Start training.
# loss:0.742783 [    0/ 3881]
# loss:0.583792 [ 3200/ 3881]
# Done. Time:2.67269818799997
# Training performance:
#  Avg loss:0.761573
#
# Start validation.
# Done. Time:0.24956534499995087
# Validation performance:
#  Avg loss:1.237754
#
# Start evaluation.
# Done. Time:1.1441054779999718
# Test performance:
#  Accuracy:57.5%
# --------------------------------------------------------------------------------
# Epoch 8
# Start training.
# loss:0.810364 [    0/ 3881]
# loss:0.612755 [ 3200/ 3881]
# Done. Time:2.5882260239999937
# Training performance:
#  Avg loss:0.706392
#
# Start validation.
# Done. Time:0.26564847299999883
# Validation performance:
#  Avg loss:1.169691
#
# Start evaluation.
# Done. Time:1.3370974779999756
# Test performance:
#  Accuracy:64.0%
# --------------------------------------------------------------------------------
# Epoch 9
# Start training.
# loss:0.590783 [    0/ 3881]
# loss:0.326080 [ 3200/ 3881]
# Done. Time:4.604512373000034
# Training performance:
#  Avg loss:0.669230
#
# Start validation.
# Done. Time:0.27006309399996553
# Validation performance:
#  Avg loss:0.969092
#
# Start evaluation.
# Done. Time:1.1500095389999956
# Test performance:
#  Accuracy:67.5%
# --------------------------------------------------------------------------------
# Epoch 10
# Start training.
# loss:0.820767 [    0/ 3881]
# loss:0.369336 [ 3200/ 3881]
# Done. Time:2.6554294619999723
# Training performance:
#  Avg loss:0.631239
#
# Start validation.
# Done. Time:0.2680059939999637
# Validation performance:
#  Avg loss:0.753189
#
# Start evaluation.
# Done. Time:1.1551047320000407
# Test performance:
#  Accuracy:71.5%
# --------------------------------------------------------------------------------
# Epoch 11
# Start training.
# loss:0.806988 [    0/ 3881]
# loss:0.652887 [ 3200/ 3881]
# Done. Time:2.651728681999998
# Training performance:
#  Avg loss:0.600415
#
# Start validation.
# Done. Time:0.2664415499999677
# Validation performance:
#  Avg loss:0.811979
#
# Start evaluation.
# Done. Time:1.1933434570000259
# Test performance:
#  Accuracy:69.0%
# --------------------------------------------------------------------------------
# Epoch 12
# Start training.
# loss:0.523015 [    0/ 3881]
# loss:0.527606 [ 3200/ 3881]
# Done. Time:4.4468591179999635
# Training performance:
#  Avg loss:0.573641
#
# Start validation.
# Done. Time:0.3763913489999595
# Validation performance:
#  Avg loss:0.763333
#
# Start evaluation.
# Done. Time:1.1780793300000028
# Test performance:
#  Accuracy:74.0%
# --------------------------------------------------------------------------------
# Epoch 13
# Start training.
# loss:0.547251 [    0/ 3881]
# loss:0.524753 [ 3200/ 3881]
# Done. Time:2.6436822279999888
# Training performance:
#  Avg loss:0.521495
#
# Start validation.
# Done. Time:0.2582832500000336
# Validation performance:
#  Avg loss:0.964997
#
# Start evaluation.
# Done. Time:1.167485642000031
# Test performance:
#  Accuracy:70.0%
# --------------------------------------------------------------------------------
# Epoch 14
# Start training.
# loss:0.843911 [    0/ 3881]
# loss:0.685812 [ 3200/ 3881]
# Done. Time:2.6266188669999906
# Training performance:
#  Avg loss:0.527100
#
# Start validation.
# Done. Time:0.25382299400001784
# Validation performance:
#  Avg loss:0.841912
#
# Start evaluation.
# Done. Time:1.1360194989999854
# Test performance:
#  Accuracy:71.5%
# --------------------------------------------------------------------------------
# Epoch 15
# Start training.
# loss:0.938530 [    0/ 3881]
# loss:0.338202 [ 3200/ 3881]
# Done. Time:4.221812220999993
# Training performance:
#  Avg loss:0.497069
#
# Start validation.
# Done. Time:0.3819449769999892
# Validation performance:
#  Avg loss:0.692503
#
# Start evaluation.
# Done. Time:1.1399551499999916
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 16
# Start training.
# loss:0.654705 [    0/ 3881]
# loss:0.497872 [ 3200/ 3881]
# Done. Time:2.692569665999997
# Training performance:
#  Avg loss:0.461323
#
# Start validation.
# Done. Time:0.252795510999988
# Validation performance:
#  Avg loss:0.890639
#
# Start evaluation.
# Done. Time:1.155632742000023
# Test performance:
#  Accuracy:70.0%
# --------------------------------------------------------------------------------
# Epoch 17
# Start training.
# loss:0.283359 [    0/ 3881]
# loss:0.418841 [ 3200/ 3881]
# Done. Time:2.6864264330000083
# Training performance:
#  Avg loss:0.452776
#
# Start validation.
# Done. Time:0.25836075600000186
# Validation performance:
#  Avg loss:0.720675
#
# Start evaluation.
# Done. Time:1.167054396000026
# Test performance:
#  Accuracy:81.5%
# --------------------------------------------------------------------------------
# Epoch 18
# Start training.
# loss:0.261827 [    0/ 3881]
# loss:0.508758 [ 3200/ 3881]
# Done. Time:4.157103599999971
# Training performance:
#  Avg loss:0.439175
#
# Start validation.
# Done. Time:0.3687869990000081
# Validation performance:
#  Avg loss:0.804686
#
# Start evaluation.
# Done. Time:1.1620440949999988
# Test performance:
#  Accuracy:72.5%
# --------------------------------------------------------------------------------
# Epoch 19
# Start training.
# loss:0.484555 [    0/ 3881]
# loss:0.520546 [ 3200/ 3881]
# Done. Time:2.7085666249999463
# Training performance:
#  Avg loss:0.440239
#
# Start validation.
# Done. Time:0.25829773099997055
# Validation performance:
#  Avg loss:0.775092
#
# Start evaluation.
# Done. Time:1.1629389089999904
# Test performance:
#  Accuracy:74.0%
# --------------------------------------------------------------------------------
# Epoch 20
# Start training.
# loss:0.434514 [    0/ 3881]
# loss:0.437199 [ 3200/ 3881]
# Done. Time:2.6563360430000102
# Training performance:
#  Avg loss:0.410358
#
# Start validation.
# Done. Time:0.2556263920000106
# Validation performance:
#  Avg loss:0.795285
#
# Start evaluation.
# Done. Time:1.1476982309999926
# Test performance:
#  Accuracy:71.5%
# --------------------------------------------------------------------------------
# Epoch 21
# Start training.
# loss:0.247648 [    0/ 3881]
# loss:0.621262 [ 3200/ 3881]
# Done. Time:4.034210196000004
# Training performance:
#  Avg loss:0.407507
#
# Start validation.
# Done. Time:0.3927969359999679
# Validation performance:
#  Avg loss:0.797952
#
# Start evaluation.
# Done. Time:1.4652157639999928
# Test performance:
#  Accuracy:71.0%
# --------------------------------------------------------------------------------
# Epoch 22
# Start training.
# loss:0.290553 [    0/ 3881]
# loss:0.430975 [ 3200/ 3881]
# Done. Time:2.698706819999984
# Training performance:
#  Avg loss:0.398783
#
# Start validation.
# Done. Time:0.26205852999999024
# Validation performance:
#  Avg loss:0.734260
#
# Start evaluation.
# Done. Time:1.181217495999988
# Test performance:
#  Accuracy:73.5%
# --------------------------------------------------------------------------------
# Epoch 23
# Start training.
# loss:0.291792 [    0/ 3881]
# loss:0.276844 [ 3200/ 3881]
# Done. Time:2.6757669289999626
# Training performance:
#  Avg loss:0.389424
#
# Start validation.
# Done. Time:0.25750379999999495
# Validation performance:
#  Avg loss:0.945341
#
# Start evaluation.
# Done. Time:1.1657091469999727
# Test performance:
#  Accuracy:68.5%
# --------------------------------------------------------------------------------
# Epoch 24
# Start training.
# loss:0.412730 [    0/ 3881]
# loss:0.311216 [ 3200/ 3881]
# Done. Time:4.425802196999996
# Training performance:
#  Avg loss:0.392276
#
# Start validation.
# Done. Time:0.4014289469999994
# Validation performance:
#  Avg loss:0.700637
#
# Start evaluation.
# Done. Time:1.1956819409999753
# Test performance:
#  Accuracy:79.5%
# --------------------------------------------------------------------------------
# Epoch 25
# Start training.
# loss:0.296807 [    0/ 3881]
# loss:0.274338 [ 3200/ 3881]
# Done. Time:2.6113313600000083
# Training performance:
#  Avg loss:0.380579
#
# Start validation.
# Done. Time:0.2733296110000083
# Validation performance:
#  Avg loss:0.705773
#
# Start evaluation.
# Done. Time:1.1867990449999866
# Test performance:
#  Accuracy:79.5%
# --------------------------------------------------------------------------------
# Epoch 26
# Start training.
# loss:0.299530 [    0/ 3881]
# loss:0.564838 [ 3200/ 3881]
# Done. Time:2.740668194999955
# Training performance:
#  Avg loss:0.388389
#
# Start validation.
# Done. Time:0.26925539299998036
# Validation performance:
#  Avg loss:0.735119
#
# Start evaluation.
# Done. Time:1.2233210000000554
# Test performance:
#  Accuracy:70.0%
# --------------------------------------------------------------------------------
# Epoch 27
# Start training.
# loss:0.228851 [    0/ 3881]
# loss:0.322837 [ 3200/ 3881]
# Done. Time:4.366332790000001
# Training performance:
#  Avg loss:0.357810
#
# Start validation.
# Done. Time:0.3752106829999775
# Validation performance:
#  Avg loss:0.779043
#
# Start evaluation.
# Done. Time:1.1645538679999845
# Test performance:
#  Accuracy:77.5%
# --------------------------------------------------------------------------------
# Epoch 28
# Start training.
# loss:0.410835 [    0/ 3881]
# loss:0.532925 [ 3200/ 3881]
# Done. Time:2.7252012120000018
# Training performance:
#  Avg loss:0.340140
#
# Start validation.
# Done. Time:0.2574116129999311
# Validation performance:
#  Avg loss:0.773416
#
# Start evaluation.
# Done. Time:1.2252034129999174
# Test performance:
#  Accuracy:73.0%
# --------------------------------------------------------------------------------
# Epoch 29
# Start training.
# loss:0.371801 [    0/ 3881]
# loss:0.096642 [ 3200/ 3881]
# Done. Time:2.6519639939999706
# Training performance:
#  Avg loss:0.327818
#
# Start validation.
# Done. Time:0.2619766110000228
# Validation performance:
#  Avg loss:0.831429
#
# Start evaluation.
# Done. Time:1.143649936000088
# Test performance:
#  Accuracy:75.5%
# --------------------------------------------------------------------------------
# Epoch 30
# Start training.
# loss:0.287047 [    0/ 3881]
# loss:0.172133 [ 3200/ 3881]
# Done. Time:4.156307778999917
# Training performance:
#  Avg loss:0.342551
#
# Start validation.
# Done. Time:0.4215182630000527
# Validation performance:
#  Avg loss:0.735231
#
# Start evaluation.
# Done. Time:1.1703402009999309
# Test performance:
#  Accuracy:77.0%
# --------------------------------------------------------------------------------
# Epoch 31
# Start training.
# loss:0.306365 [    0/ 3881]
# loss:0.137351 [ 3200/ 3881]
# Done. Time:2.703580464999959
# Training performance:
#  Avg loss:0.313356
#
# Start validation.
# Done. Time:0.2610760049999499
# Validation performance:
#  Avg loss:1.040346
#
# Start evaluation.
# Done. Time:1.165763679999941
# Test performance:
#  Accuracy:71.0%
# --------------------------------------------------------------------------------
# Epoch 32
# Start training.
# loss:0.406189 [    0/ 3881]
# loss:0.538148 [ 3200/ 3881]
# Done. Time:2.7166307740000093
# Training performance:
#  Avg loss:0.321603
#
# Start validation.
# Done. Time:0.27315867800007254
# Validation performance:
#  Avg loss:0.850417
#
# Start evaluation.
# Done. Time:1.1593479570000227
# Test performance:
#  Accuracy:71.5%
# --------------------------------------------------------------------------------
# Epoch 33
# Start training.
# loss:0.214878 [    0/ 3881]
# loss:0.330722 [ 3200/ 3881]
# Done. Time:4.042169877000106
# Training performance:
#  Avg loss:0.306489
#
# Start validation.
# Done. Time:0.4014539510000077
# Validation performance:
#  Avg loss:0.960601
#
# Start evaluation.
# Done. Time:1.304113799999982
# Test performance:
#  Accuracy:70.0%
# --------------------------------------------------------------------------------
# Epoch 34
# Start training.
# loss:0.495097 [    0/ 3881]
# loss:0.359000 [ 3200/ 3881]
# Done. Time:4.615753898999969
# Training performance:
#  Avg loss:0.312109
#
# Start validation.
# Done. Time:0.27632490099995266
# Validation performance:
#  Avg loss:0.816318
#
# Start evaluation.
# Done. Time:1.1789207339999166
# Test performance:
#  Accuracy:79.5%
# --------------------------------------------------------------------------------
# Epoch 35
# Start training.
# loss:0.311211 [    0/ 3881]
# loss:0.196900 [ 3200/ 3881]
# Done. Time:2.664558607999993
# Training performance:
#  Avg loss:0.289859
#
# Start validation.
# Done. Time:0.3941644509999378
# Validation performance:
#  Avg loss:0.765865
#
# Start evaluation.
# Done. Time:1.5386242879999372
# Test performance:
#  Accuracy:81.0%
# --------------------------------------------------------------------------------
# Epoch 36
# Start training.
# loss:0.276917 [    0/ 3881]
# loss:0.553623 [ 3200/ 3881]
# Done. Time:3.7543260520000103
# Training performance:
#  Avg loss:0.298666
#
# Start validation.
# Done. Time:0.2657653679999612
# Validation performance:
#  Avg loss:0.748353
#
# Start evaluation.
# Done. Time:1.174882104000062
# Test performance:
#  Accuracy:79.0%
# --------------------------------------------------------------------------------
# Epoch 37
# Start training.
# loss:0.094002 [    0/ 3881]
# loss:0.384850 [ 3200/ 3881]
# Done. Time:2.804349788999957
# Training performance:
#  Avg loss:0.283604
#
# Start validation.
# Done. Time:0.25788569600001665
# Validation performance:
#  Avg loss:1.048671
#
# Start evaluation.
# Done. Time:1.1697321130000091
# Test performance:
#  Accuracy:70.5%
# --------------------------------------------------------------------------------
# Epoch 38
# Start training.
# loss:0.312426 [    0/ 3881]
# loss:0.527255 [ 3200/ 3881]
# Done. Time:2.651292501999933
# Training performance:
#  Avg loss:0.300277
#
# Start validation.
# Done. Time:0.2606213660000094
# Validation performance:
#  Avg loss:0.858798
#
# Start evaluation.
# Done. Time:1.4483845830000064
# Test performance:
#  Accuracy:75.5%
# --------------------------------------------------------------------------------
# Epoch 39
# Start training.
# loss:0.560493 [    0/ 3881]
# loss:0.448788 [ 3200/ 3881]
# Done. Time:4.207212352999932
# Training performance:
#  Avg loss:0.286827
#
# Start validation.
# Done. Time:0.26408446899995397
# Validation performance:
#  Avg loss:0.987252
#
# Start evaluation.
# Done. Time:1.1631374080000114
# Test performance:
#  Accuracy:70.0%
# --------------------------------------------------------------------------------
# Epoch 40
# Start training.
# loss:0.470718 [    0/ 3881]
# loss:0.173960 [ 3200/ 3881]
# Done. Time:2.673026993999997
# Training performance:
#  Avg loss:0.265859
#
# Start validation.
# Done. Time:0.25543457200001285
# Validation performance:
#  Avg loss:0.830132
#
# Start evaluation.
# Done. Time:1.193192780000004
# Test performance:
#  Accuracy:76.5%
# --------------------------------------------------------------------------------
# Epoch 41
# Start training.
# loss:0.126274 [    0/ 3881]
# loss:0.195893 [ 3200/ 3881]
# Done. Time:2.6716896279999673
# Training performance:
#  Avg loss:0.259710
#
# Start validation.
# Done. Time:0.25864475099990614
# Validation performance:
#  Avg loss:0.860207
#
# Start evaluation.
# Done. Time:1.315831481000032
# Test performance:
#  Accuracy:78.0%
# --------------------------------------------------------------------------------
# Epoch 42
# Start training.
# loss:0.188196 [    0/ 3881]
# loss:0.228965 [ 3200/ 3881]
# Done. Time:4.428839129999915
# Training performance:
#  Avg loss:0.255982
#
# Start validation.
# Done. Time:0.2867119290000346
# Validation performance:
#  Avg loss:0.969591
#
# Start evaluation.
# Done. Time:1.1647226929999306
# Test performance:
#  Accuracy:75.5%
# --------------------------------------------------------------------------------
# Epoch 43
# Start training.
# loss:0.170562 [    0/ 3881]
# loss:0.250578 [ 3200/ 3881]
# Done. Time:2.749654468000017
# Training performance:
#  Avg loss:0.254254
#
# Start validation.
# Done. Time:0.2583215199999813
# Validation performance:
#  Avg loss:1.000188
#
# Start evaluation.
# Done. Time:1.1517685390000452
# Test performance:
#  Accuracy:76.0%
# --------------------------------------------------------------------------------
# Epoch 44
# Start training.
# loss:0.178572 [    0/ 3881]
# loss:0.174278 [ 3200/ 3881]
# Done. Time:2.6172151100000747
# Training performance:
#  Avg loss:0.246934
#
# Start validation.
# Done. Time:0.2567011990000765
# Validation performance:
#  Avg loss:0.965270
#
# Start evaluation.
# Done. Time:1.1707558340000332
# Test performance:
#  Accuracy:75.0%
# --------------------------------------------------------------------------------
# Epoch 45
# Start training.
# loss:0.218095 [    0/ 3881]
# loss:0.510805 [ 3200/ 3881]
# Done. Time:4.434272007000004
# Training performance:
#  Avg loss:0.251500
#
# Start validation.
# Done. Time:0.3779643500000702
# Validation performance:
#  Avg loss:0.873389
#
# Start evaluation.
# Done. Time:1.1742806529999825
# Test performance:
#  Accuracy:79.0%
# --------------------------------------------------------------------------------
# Epoch 46
# Start training.
# loss:0.094869 [    0/ 3881]
# loss:0.214880 [ 3200/ 3881]
# Done. Time:2.6114375180000025
# Training performance:
#  Avg loss:0.251531
#
# Start validation.
# Done. Time:0.2694127299999991
# Validation performance:
#  Avg loss:1.029568
#
# Start evaluation.
# Done. Time:1.1429815819999476
# Test performance:
#  Accuracy:72.0%
# --------------------------------------------------------------------------------
# Epoch 47
# Start training.
# loss:0.206482 [    0/ 3881]
# loss:0.186167 [ 3200/ 3881]
# Done. Time:2.6402908029999708
# Training performance:
#  Avg loss:0.251349
#
# Start validation.
# Done. Time:0.27748605900001166
# Validation performance:
#  Avg loss:0.841324
#
# Start evaluation.
# Done. Time:1.2094508629999154
# Test performance:
#  Accuracy:76.5%
# --------------------------------------------------------------------------------
# Epoch 48
# Start training.
# loss:0.370477 [    0/ 3881]
# loss:0.255070 [ 3200/ 3881]
# Done. Time:4.186332679999964
# Training performance:
#  Avg loss:0.232930
#
# Start validation.
# Done. Time:0.38150779800002965
# Validation performance:
#  Avg loss:0.905594
#
# Start evaluation.
# Done. Time:1.1668563629999653
# Test performance:
#  Accuracy:76.5%
# --------------------------------------------------------------------------------
# Epoch 49
# Start training.
# loss:0.301143 [    0/ 3881]
# loss:0.252900 [ 3200/ 3881]
# Done. Time:2.6218317420000403
# Training performance:
#  Avg loss:0.240638
#
# Start validation.
# Done. Time:0.27239209800006847
# Validation performance:
#  Avg loss:0.748651
#
# Start evaluation.
# Done. Time:1.153971327000022
# Test performance:
#  Accuracy:79.5%
# --------------------------------------------------------------------------------
# Epoch 50
# Start training.
# loss:0.217852 [    0/ 3881]
# loss:0.252825 [ 3200/ 3881]
# Done. Time:2.755491789999951
# Training performance:
#  Avg loss:0.237230
#
# Start validation.
# Done. Time:0.2614174699999694
# Validation performance:
#  Avg loss:0.937518
#
# Start evaluation.
# Done. Time:1.1671215630000233
# Test performance:
#  Accuracy:76.5%
# Minimum validation loss:0.6925029158592224 at 15 epoch.
# Maximum accuracy:81.5 at 17 epoch.

# %% [markdown]
# ### Plort result
# #### Recognition performance

# %%
import matplotlib.pyplot as plt

plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(val_losses_default)+1)
plt.plot(xs, val_losses_default, label="Default", marker=".")
plt.plot(xs, val_losses_w_daug, label="+ T-Clip", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.ylim([0.0, 2.5])
plt.legend()
plt.show()

# %%
plt.grid(axis="y", linestyle="dotted", color="k")

xs = np.arange(1, len(test_accs_default)+1)
plt.plot(xs, test_accs_default, label="Default", marker=".")
plt.plot(xs, test_accs_w_daug, label="+ T-Clip", marker=".")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.ylim([0.0, 100.0])
plt.legend()
plt.show()
